# %% [markdown]
# # LCP Project: analysis of MAGIC04 dataset
# ### Description
#
# The data are Monte Carlo generated to simulate registration of high energy gamma particles in a ground-based atmospheric Cherenkov gamma telescope using the imaging technique. Cherenkov gamma telescope observes high energy gamma rays, taking advantage of the radiation emitted by charged particles produced inside the electromagnetic showers initiated by the gammas, and developing in the atmosphere. This Cherenkov radiation (of visible to UV wavelengths) leaks through the atmosphere and gets recorded in the detector, allowing reconstruction of the shower parameters. The available information consists of pulses left by the incoming Cherenkov photons on the photomultiplier tubes, arranged in a plane, the camera. Depending on the energy of the primary gamma, a total of few hundreds to some 10000 Cherenkov photons get collected, in patterns (called the shower image), allowing to discriminate statistically those caused by primary gammas (signal) from the images of hadronic showers initiated by cosmic rays in the upper atmosphere (background).
#
# Typically, the image of a shower after some pre-processing is an elongated cluster. Its long axis is oriented towards the camera center if the shower axis is parallel to the telescope's optical axis, i.e. if the telescope axis is directed towards a point source. A principal component analysis is performed in the camera plane, which results in a correlation axis and defines an ellipse. If the depositions were distributed as a bivariate Gaussian, this would be an equidensity ellipse. The characteristic parameters of this ellipse (often called Hillas parameters) are among the image parameters that can be used for discrimination. The energy depositions are typically asymmetric along the major axis, and this asymmetry can also be used in discrimination. There are, in addition, further discriminating characteristics, like the extent of the cluster in the image plane, or the total sum of depositions.
#
# The program was run with parameters allowing to observe events with energies down to below 50 GeV.
#
# ### Dataset
#
# Attribute Information:
#
# 1. fLength: continuous # major axis of ellipse [mm]
# 2. fWidth: continuous # minor axis of ellipse [mm]
# 3. fSize: continuous # 10-log of sum of content of all pixels [in #phot]
# 4. fConc: continuous # ratio of sum of two highest pixels over fSize [ratio]
# 5. fConc1: continuous # ratio of highest pixel over fSize [ratio]
# 6. fAsym: continuous # distance from highest pixel to center, projected onto major axis [mm]
# 7. fM3Long: continuous # 3rd root of third moment along major axis [mm]
# 8. fM3Trans: continuous # 3rd root of third moment along minor axis [mm]
# 9. fAlpha: continuous # angle of major axis with vector to origin [deg]
# 10. fDist: continuous # distance from origin to center of ellipse [mm]
# 11. class: g,h # gamma (signal), hadron (background)
#
# g = gamma (signal): 12332
# h = hadron (background): 6688
#
# For technical reasons, the number of h events is underestimated. In the real data, the h class represents the majority of the events.
#
# The simple classification accuracy is not meaningful for this data, since classifying a background event as signal is worse than classifying a signal event as background. For comparison of different classifiers an ROC curve has to be used. The relevant points on this curve are those, where the probability of accepting a background event as signal is below one of the following thresholds: 0.01, 0.02, 0.05, 0.1, 0.2 depending on the required quality of the sample of the accepted events for different experiments.
#
#
# ### References
#
# [1] Bock, R.K., Chilingarian, A., Gaug, M., Hakl, F., Hengstebeck, T., Jirina, M., Klaschka, J., Kotrc, E., Savicky, P., Towers, S., Vaicilius, A., Wittek W. (2004).
# Methods for multidimensional event classification: a case study using images from a Cherenkov gamma-ray telescope.
# Nucl.Instr.Meth. A, 516, pp. 511-528.
#
# [2] P. Savicky, E. Kotrc.
# Experimental Study of Leaf Confidences for Random Forest.
# Proceedings of COMPSTAT 2004, In: Computational Statistics. (Ed.: Antoch J.) - Heidelberg, Physica Verlag 2004, pp. 1767-1774.
#
# [3] J. Dvorak, P. Savicky.
# Softening Splits in Decision Trees Using Simulated Annealing.
# Proceedings of ICANNGA 2007, Warsaw, (Ed.: Beliczynski et. al), Part I, LNCS 4431, pp. 721-729.
#
# [4] Aharonian, F. et al.
# The Energy Spectrum of TeV Gamma-Rays from the Crab Nebula as measured by the HEGRA system of imaging air Cherenkov telescopes
# Astrophys. J. 539 (2000) 317-324
#
# [5] Aleksic, J. et al.
# Measurement of the Crab Nebula spectrum over three decades in energy with the MAGIC telescopes
# Journal of High Energy Astrophysics, 5–6 (2015) 30-38.

# %% [markdown]
# # Part 0: setup
# First, we import the libraries

# %%
# math libraries
import numpy as np
import pandas as pd
import numpy.random as npr
import matplotlib.pyplot as plt
from scipy import linalg as la
from matplotlib import patches
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
import matplotlib.patheffects as path_effects
import seaborn as sns
import random as rnd

# general OS libraries
from time import time
import gzip
import os
import operator
import warnings
from IPython.core.interactiveshell import InteractiveShell

# ML libraries
import sklearn
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, roc_auc_score, auc
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Perceptron
from sklearn.datasets import make_classification
from sklearn.svm import NuSVC
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.exceptions import ConvergenceWarning
from sklearn.model_selection import train_test_split
from sklearn.metrics import make_scorer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression

warnings.filterwarnings('ignore')

# %% [markdown]
# Then, we import the dataset and we put it into a DataFrame:

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data

file_name="magic04.data"
data = pd.DataFrame(pd.read_csv(file_name))
data.columns=['fLength','fWidth','fSize',
        'fConc','fConc1','fAsym',
        'fM3Long','fM3Trans','fAlpha','fDist','category']
data   
#### save data in a DataFrame
# Out:
# --2025-03-16 02:41:11--  https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data
# 128.195.10.252ive.ics.uci.edu (archive.ics.uci.edu)...
# connected. to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443...
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘magic04.data.2’
#
# magic04.data.2          [                <=> ]   1.41M   413KB/s    in 3.5s
#
# 2025-03-16 02:41:16 (413 KB/s) - ‘magic04.data.2’ saved [1477391]
#         fLength    fWidth   fSize   fConc  fConc1     fAsym   fM3Long  \
# 0       31.6036   11.7235  2.5185  0.5303  0.3773   26.2722   23.8238
# 1      162.0520  136.0310  4.0612  0.0374  0.0187  116.7410  -64.8580
# 2       23.8172    9.5728  2.3385  0.6147  0.3922   27.2107   -6.4633
# 3       75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277   28.5525
# 4       51.6240   21.1502  2.9085  0.2420  0.1340   50.8761   43.1887
# ...         ...       ...     ...     ...     ...       ...       ...
# 19014   21.3846   10.9170  2.6161  0.5857  0.3934   15.2618   11.5245
# 19015   28.9452    6.7020  2.2672  0.5351  0.2784   37.0816   13.1853
# 19016   75.4455   47.5305  3.4483  0.1417  0.0549   -9.3561   41.0562
# 19017  120.5135   76.9018  3.9939  0.0944  0.0683    5.8043  -93.5224
# 19018  187.1814   53.0014  3.2093  0.2876  0.1539 -167.3125 -168.4558
#
#        fM3Trans   fAlpha     fDist category
# 0       -9.9574   6.3609  205.2610        g
# 1      -45.2160  76.9600  256.7880        g
# 2       -7.1513  10.4490  116.7370        g
# 3       21.8393   4.6480  356.4620        g
# 4        9.8145   3.6130  238.0980        g
# ...         ...      ...       ...      ...
# 19014    2.8766   2.4229  106.8258        h
# 19015   -2.9632  86.7975  247.4560        h
# 19016   -9.4662  30.2987  256.5166        h
# 19017  -63.8389  84.6874  408.3166        h
# 19018   31.4755  52.7310  272.3174        h
#
# [19019 rows x 11 columns]

# %% [markdown]
# In this cell we print the number of data of each label and the relative frequence

# %%
print('All data points:',len(data['fAlpha']),'points for',len(data.columns[:]),'columns')
print('labels and their relative frequencies:')

ngamma = len(data[data['category'] == 'g'] )
nback = len(data[data['category'] == 'h'] )
print(f'signal: \t{ngamma} \t {round(ngamma/len(data['fAlpha'])*100,2)}%')
print(f'background:\t {nback} \t {round(nback/len(data['fAlpha'])*100,2)}%')
# Out:
#   Cell In[3], line 6
#     print(f'signal: \t{ngamma} \t {round(ngamma/len(data['fAlpha'])*100,2)}%')
#                                                           ^
# SyntaxError: invalid syntax

# %% [markdown]
# We observe that about 2/3 of the dataset is labelled as signal, while only 1/3 as background. The dataset is indeed built underestimating the amount of background signal acquired.

# %% [markdown]
# Here we write some useful functions for the code

# %% [markdown]
# ## ML functions

# %%
# this function divides the dataset in input in parts_to_be_split parts. One of them is returned as test_set
# the other ones are the training_set. Indexes of the chosen data can be accessed (test_indexes, train_indexes)
# (for example in a K-fold)

def split_train_test_set(data,parts_to_be_split):
    indexes = np.arange(0,data.shape[0],1)
    rnd.shuffle(indexes)
    len_test_set = int(len(indexes) / parts_to_be_split)

    test_indexes = indexes[:len_test_set]
    train_indexes = indexes[len_test_set:]

    train_set = data.iloc[train_indexes]
    test_set = data.iloc[test_indexes]
    
    return train_set, test_set

# this function takes col category and returns as Y (target), the other columns are X (labels)
def split_X_Y(data):
    Y = data['category']
    X = data.drop('category',axis=1)

    return X,Y

# this function takes the point that has the lowest distance from FPR=0 and TPR=1 and computes Q for that point values
def get_best_Q(fpr,tpr):
    distances = np.zeros(len(fpr))
    
    for i in range(len(fpr)):
        distances[i] = np.sqrt(fpr[i]**2+(1-tpr[i])**2)
        
    min_dist_idx = np.argmin(distances)
    
    best_Q = tpr[min_dist_idx] / np.sqrt(fpr[min_dist_idx])
    return best_Q

# %% [markdown]
# ## Other functions
# ### Cutting functions

# %%
# this function finds cut value starting from possible max
def find_max_cut_value(X_train,Y_train,sel_label,min_hadrons):
    new_X = X_train[X_train.columns[sel_label]]
    new_data = np.vstack((new_X,Y_train))
    new_data_sorted = new_data[:, new_data[0].argsort()]
    
    
    # setup vars, cut value is  set to max of the label, so that in worst scenario all points are true hadrons
    true_hadrons = 0
    max_cut_value = new_data_sorted[0,0]
    
    for i in range(new_data_sorted.shape[1]):
        if new_data_sorted[1,i] == -1:
            true_hadrons += 1
        if true_hadrons == min_hadrons:
            max_cut_value = new_data_sorted[0,i]
            
    return max_cut_value

# this functions returns the number of true positive and false positive points on test set
def find_tp_fp(X_test,Y_test,sel_label,cut_value):
    new_X = X_test[X_test.columns[sel_label]]
    new_data = np.vstack((new_X,Y_test))
    new_data_sorted = new_data[:, new_data[0].argsort()]
    new_data_sorted_reversed = new_data_sorted[:, ::-1] #reverse!! STARTING FROM MAXX
    fp = 0
    tp = 0
    
    for i in range(new_data_sorted_reversed.shape[1]):
        if new_data_sorted_reversed[0,i] < cut_value:
            if new_data_sorted_reversed[1,i] == 1:
                tp += 1
            if new_data_sorted_reversed[1,i] == -1:
                fp += 1
                
    return tp, fp # true positive, false positive

# %% [markdown]
# # Part 1: study of the dataset

# %% [markdown]
# ### Part 1.1 Camera plane reconstruction
# The following code recontrsucts the traces detected by the telescope camera. In orange and red are represented the detected gammas, while in blue are represented the detected hadrons

# %%
datasig = data[data['category'] == 'g'] 
databkg = data[data['category'] == 'h'] 
# visualize data
n_ellipses = 20

# ellipse parameters
random_angle_sig = 2 * np.pi * np.random.uniform(0, 1, size=n_ellipses)
sig_idx = np.random.randint(0,10000, size=n_ellipses)
sig_ellipse_params = [ 
    {
        'center': (datasig['fDist'][idx] * np.cos(random_angle_sig[i]), datasig['fDist'][idx] * np.sin(random_angle_sig[i])),  
        'width': datasig['fWidth'][idx], 
        'height': datasig['fLength'][idx], 
        'angle': datasig['fAlpha'][idx],
        'alpha': datasig['fSize'][idx]/data['fSize'].max()
        } 
    for i, idx in enumerate(sig_idx)
    ]

random_angle_bkg = 2 * np.pi * np.random.uniform(0, 1, size=n_ellipses)
bkg_idx = np.random.randint(13000,19000, size=n_ellipses)
bkg_ellipse_params = [ 
    {
        'center': (databkg['fDist'][idx] * np.cos(random_angle_bkg[i]), databkg['fDist'][idx] * np.sin(random_angle_bkg[i])),
        'width': databkg['fWidth'][idx], 
        'height': databkg['fLength'][idx], 
        'angle': databkg['fAlpha'][idx],
        'alpha': databkg['fSize'][idx]/data['fSize'].max()
        } 
    for i, idx in enumerate(bkg_idx)
    ]

fig, ax = plt.subplots(figsize=(10,12))

ax.grid(alpha=0.3)

# plot ellipses
radius = 500
camera_circle = patches.Circle((0,0), radius, alpha=0.15, color='#7a7a7a')
ax.add_patch(camera_circle)

bkg_ellipses = []
sig_ellipses = []

for params in bkg_ellipse_params:
    ellipse = patches.Ellipse(
        xy=params['center'], 
        width=params['width'], 
        height=params['height'], 
        angle=(params['angle'] - 90 + 180*np.arctan(params['center'][1] / params['center'][0])/np.pi), 
        fill=True, 
        alpha=params['alpha'], 
        color='C0'
        )
    ax.add_patch(ellipse)
    bkg_ellipses.append(ellipse)

for params in sig_ellipse_params:
    ellipse = patches.Ellipse(
        xy=params['center'], 
        width=params['width'], 
        height=params['height'], 
        angle=(params['angle'] - 90 + 180*np.arctan(params['center'][1] / params['center'][0])/np.pi),
        alpha=params['alpha'], 
        color='C1'
        )
    ax.add_patch(ellipse)
    sig_ellipses.append(ellipse)

ax.set_xlim(-radius, radius)
ax.set_ylim(-radius, radius)
ax.set_aspect('equal')

legend_labels = ['Camera Plane', 'Hadron', 'Gamma']
legend_handles = [camera_circle, bkg_ellipses[0], sig_ellipses[0]]
ax.legend(legend_handles, legend_labels, loc='lower right')

center_cross_size = 15
ax.plot([0, 0], [-center_cross_size, center_cross_size], color='black', linewidth=1)
ax.plot([-center_cross_size, center_cross_size], [0, 0], color='black', linewidth=1)

# color scale indicating alpha for background ellipses
bkg_alphas = [params['alpha'] for params in bkg_ellipse_params]
bkg_norm = Normalize(vmin=0, vmax=100)
bkg_scalar_map = ScalarMappable(norm=bkg_norm, cmap='Blues')
bkg_scalar_map.set_array(bkg_alphas)
bkg_colorbar = plt.colorbar(bkg_scalar_map, ax=ax, fraction=0.033, pad = 0.15)
bkg_colorbar.set_label('hadron #photons %')

# color scale indicating alpha for signal ellipses
sig_alphas = [params['alpha'] for params in sig_ellipse_params]
sig_norm = Normalize(vmin=0, vmax=100)
sig_scalar_map = ScalarMappable(norm=sig_norm, cmap='Oranges')
sig_scalar_map.set_array(sig_alphas)
sig_colorbar = plt.colorbar(sig_scalar_map, ax=ax, fraction=0.04, pad = 0.1)
sig_colorbar.set_label('gamma #photons %')

ax.set_xlabel('X-axis (mm)')
ax.set_ylabel('Y-axis (mm)')

plt.show();

# %% [markdown]
# This recontstruction resembles the acquisition of some signals. It is observed that the orange ellypses, representing data labeled as "gamma", are mostly radially oriented, while the orientation of the "hadrons" ellypses seems random. We can conclude that the photon shower axis is parallel to the telescope's optical axis. The colorbars represent the alpha parameter of the represented particles.

# %% [markdown]
# ### Part 1.2 plot of the features
# the following code plots histograms for each feature, in red there are gammas (signal), in blue hadrons (background). The code saves the histograms in a directory named 'part_1_plots'

# %%
fig, ax = plt.subplots(nrows=5, ncols=2, figsize=(20, 34))
fig.subplots_adjust(hspace=0.3)

udm = ['fLength ', 'fWidth ', 'fSize ', 'fConc ', 'fConc1 ', 
       'fAsym ', 'fM3Long ', 'fM3Trans ', 'fAlpha ', 'fDist ']

units = ['(mm)','(mm)','(#phot)','(ratio)','(ratio)','(mm)','(mm)','(mm)','(deg)','(mm)']
features = ['fLength', 'fWidth', 'fSize', 'fConc', 'fConc1', 
            'fAsym', 'fM3Long', 'fM3Trans', 'fAlpha', 'fDist']
bins = 40

avgs_g = []
avgs_h = []
stds_g = []
stds_h = []
lambdas = []

for i in range(5):
    for j in range(2):
            
        idx = 2 * i + j  # Update index to match new layout
        if (udm[idx] == 'fWidth (mm)'):
            bins = 50
        
        min_val = min(datasig[features[idx]].min(), databkg[features[idx]].min())
        max_val = max(datasig[features[idx]].max(), databkg[features[idx]].max())
        common_bins = np.linspace(min_val, max_val, bins + 1)
        
        #ax[i, j].grid()
        sns.histplot(datasig[features[idx]], bins = common_bins, kde=False, color='red', alpha=0.6, label='gamma', ax=ax[i, j], edgecolor='#383734', linewidth=0.5)
        sns.histplot(databkg[features[idx]], bins = common_bins, kde=False, color='blue', alpha=0.5, label='hadron', ax=ax[i, j], edgecolor='#383734', linewidth=0.5)
        mu_g = np.mean(datasig[features[idx]])
        mu_h = np.mean(databkg[features[idx]])
        std_g = np.std(datasig[features[idx]])
        std_h = np.std(databkg[features[idx]])
        avgs_g.append(mu_g)
        avgs_h.append(mu_h)
        stds_g.append(std_g)
        stds_h.append(std_h)
        lambdas.append(abs(mu_g-mu_h)/(std_g**2 + std_h**2)**(1/2))
        
        ax[i, j].axvline(mu_g,c='#990000', label= f'$\gamma$ mean = {round(mu_g,1)}±{round(std_g,1)}', lw=1.8)
        ax[i, j].axvline(mu_h,c='navy',label= f'h mean = {round(mu_h,1)}±{round(std_h,1)}', lw=1.7,alpha=0.7)
        ax[i, j].set_xlabel(f'{udm[idx]}{units[idx]}', fontsize=24)
        ax[i, j].set_ylabel(f'counts / {round(common_bins[1]-common_bins[0],2)} {units[idx]}', fontsize=24)
        ax[i, j].tick_params(axis='both', which='major', labelsize=16)
        ax[i, j].legend(loc='best', fontsize=18)
        ax[i, j].set_title(f'Histogram of {udm[idx]}', fontsize=26)
        
        '''if (udm[idx] == 'fLength (mm)'):
            ax[i, j].set_xlim(-5,260)
        if (udm[idx] == 'fWidth (mm)'):
            ax[i, j].set_xlim(-10,120)'''
            
        
        #ax[i, j].text(x=3,y=160,s=fr"$\mu_{{g}}$={mu_g:.2f} $\pm$ {l_std_g_high:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='#990000'))
        #ax[i, j].text(x=3,y=130,s=fr"$\mu_{{h}}$={mu_h:.2f} $\pm$ {l_std_h_high:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='navy'))

    
#plt.tight_layout()
plt.show();

# %%
print(f'feature \t gamma \t \thadrons \tcompatibility (lambda)')
for i in range(len(avgs_g)):
    print(f'{udm[i]}{units[i]}\t',f'{round(avgs_g[i],1)} \u00B1 {round(stds_g[i],1)}', f'\t{round(avgs_h[i],1)} \u00B1 {round(stds_h[i],1)}', f'\t\033[32m{round(lambdas[i],2)}\033[0m')
# Out:
# feature 	 gamma 	 	hadrons 	compatibility (lambda)
# fLength (mm)	 43.7 ± 26.2 	70.9 ± 57.9 	0.43
# fWidth (mm)	 18.6 ± 9.0 	28.8 ± 27.2 	0.36
# fSize (#phot)	 2.8 ± 0.5 	2.9 ± 0.5 	0.17
# fConc (ratio)	 0.4 ± 0.2 	0.4 ± 0.2 	0.04
# fConc1 (ratio)	 0.2 ± 0.1 	0.2 ± 0.1 	0.01
# fAsym (mm)	 3.2 ± 39.6 	-18.3 ± 82.3 	0.24
# fM3Long (mm)	 17.8 ± 33.9 	-2.8 ± 70.7 	0.26
# fM3Trans (mm)	 0.2 ± 13.6 	0.4 ± 29.9 	0.01
# fAlpha (deg)	 18.8 ± 21.5 	44.0 ± 26.0 	0.75
# fDist (mm)	 190.2 ± 70.3 	200.4 ± 81.9 	0.09

# %% [markdown]
# We observe that the mean values of all features for hadrons and gammas are compatible. Also they distribute in similar shapes, except for `fAlpha`. Therefore is not possible to distinguish signal from background from the distributions.

# %% [markdown]
# # Part 2: studying the correlations
# in this section each feature will be confronted with all the others. Results will be put in a 2D correlation matrix (n_features x n_features) to visualize the results
#
# First we rescale all features to have average = 0 and dev_std = 1 (Alpha is rescaled in this part, but will be restored for the later sections).

# %%
X = data[['fLength','fWidth','fSize',
        'fConc','fConc1','fAsym',
        'fM3Long','fM3Trans','fAlpha','fDist']]
Y = data['category']
print(X['fAlpha'])
# Out:
# 0         6.3609
# 1        76.9600
# 2        10.4490
# 3         4.6480
# 4         3.6130
#           ...
# 19014     2.4229
# 19015    86.7975
# 19016    30.2987
# 19017    84.6874
# 19018    52.7310
# Name: fAlpha, Length: 19019, dtype: float64

# %%
X_rescaled = X.copy()
original_alpha = X['fAlpha'].copy()

for i in range(X.shape[1]):
    h = X[str(X.columns[i])]
    avg = np.average(h)
    std = np.std(h)
    h = h - avg
    h = h / std
    X_rescaled[str(X_rescaled.columns[i])] = h
    
print('avg length:',round(np.average(X_rescaled['fLength']),15))
print('std length:',round(np.std(X_rescaled['fLength']),15))
# Out:
# avg length: 0.0
# std length: 1.0

# %% [markdown]
# The following cell computes the correlation matrix taking apart gammas from hadrons

# %%
Xg_rescaled = X_rescaled[Y == 'g']
Xh_rescaled = X_rescaled[Y == 'h']
features = features[:10]


cov = np.zeros((Xg_rescaled.shape[1],Xg_rescaled.shape[1]))
for i in range(Xg_rescaled.shape[1]):
    h = Xg_rescaled[str(Xg_rescaled.columns[i])]
    for j in range(Xg_rescaled.shape[1]):
        v = Xg_rescaled[str(Xg_rescaled.columns[j])]
        cov[i,j] = (np.cov(h,v)[0,1])
        
std_devs = np.std(Xg_rescaled, axis=0)
cov = cov / np.outer(std_devs, std_devs) # the data for gamma events are not normalized with respsect to themselv   



ticks = np.arange(0,10,1)
x_ticks = np.arange(cov.shape[1]) + 0.5
y_ticks = np.arange(cov.shape[0]) + 0.5

fig, ax = plt.subplots(1, 2, figsize=(16, 8))
cax = ax[0].imshow(cov, cmap='coolwarm', interpolation='nearest')
fig.colorbar(cax)
ax[0].set_xticks(ticks, minor=False)
ax[0].set_yticks(ticks, minor=False)
ax[0].set_xticklabels(features,rotation=90)
ax[0].set_yticklabels(features)
ax[0].grid(which='minor', color='black', linewidth=2)

for i in range(cov.shape[0]):
    for j in range(cov.shape[1]):
        ax[0].text(j, i, f'{cov[i, j]:.2f}', ha='center', va='center', color='black', fontsize=10)

#ax[0].plot([-0.5, cov.shape[1]-0.5], [-0.5, cov.shape[0]-0.5], color='black', linewidth=2, linestyle='-')
#ax[0].plot([-0.5, cov.shape[1]-0.5], [-0.5, cov.shape[0]-0.5], color='black', linewidth=2, linestyle='-')
ax[0].set_title('GAMMA EVENTS FEATURES CORRELATION')

cov = np.zeros((Xh_rescaled.shape[1],Xh_rescaled.shape[1]))
for i in range(Xh_rescaled.shape[1]):
    h = Xh_rescaled[str(Xh_rescaled.columns[i])]
    for j in range(Xh_rescaled.shape[1]):
        v = Xh_rescaled[str(Xh_rescaled.columns[j])]
        cov[i,j] = (np.cov(h,v)[0,1])
        
std_devs = np.std(Xh_rescaled, axis=0)
cov = cov / np.outer(std_devs, std_devs)

cax = ax[1].imshow(cov, cmap='coolwarm', interpolation='nearest')
fig.colorbar(cax)
ax[1].set_xticks(ticks, minor=False)
ax[1].set_yticks(ticks, minor=False)
ax[1].set_xticklabels(features, rotation=90)
ax[1].set_yticklabels(features)
ax[1].grid(which='minor', color='black', linewidth=1)

for i in range(cov.shape[0]):
    for j in range(cov.shape[1]):
        ax[1].text(j, i, f'{cov[i, j]:.2f}', ha='center', va='center', color='black', fontsize=10)

#ax[1].plot([-0.5, cov.shape[1]-0.5], [-0.5, cov.shape[0]-0.5], color='black', linewidth=2, linestyle='-')
ax[1].set_title('HADRON EVENTS FEATURES CORRELATION')

plt.show();

# %% [markdown]
# We observe that the most correlated features are the first 5. The correlation between the first 3 is positive, while correlation between `fConc1` and `fConc2` is negative, and very close to 1. This is in agreement for both signal and background events. Differences can be seen while observing other parameters:
# - `fAlpha`: this parameter is slightly correlated to the others for gamma events, but sees almost no correlation for background ones
# - `fAsym`: this parameter sees the opposite than `fAlpha`
# - `fM3Long`: the correlation of this parameter is present for both signal and background events, but has its sign swapped

# %% [markdown]
# ## Part 2.1: Correlation between features and label
# In this part we check the correlation between features and label Y. This is done to find the most informative parameters for the classification.

# %%
# Calculate the correlation between each feature and the label Y

Y_array = np.where(Y == 'g', 1, -1)
Y_array = np.array(Y_array) 
feature_names = data.columns[:10]

correlations = np.zeros(X_rescaled.shape[1])  
for i in range(X_rescaled.shape[1]):
    feature = X_rescaled.iloc[:, i]  
    correlations[i] = np.corrcoef(feature, Y_array)[0, 1]

# create a bar plot to display the correlations
fig, ax = plt.subplots(figsize=(14.5, 10))

bars = ax.bar(feature_names, correlations, color='teal', edgecolor='black', linewidth=1.2,alpha=0.8)

# add correlation values on top of each bar
for i, corr in enumerate(correlations):
    ax.text(i, corr + 0.035 if corr>=0 else corr-0.035, f'{corr:.2f}', ha='center', va='bottom', fontsize=12, color='black', fontweight='bold')

ax.set_ylabel('Correlation with Label Y', fontsize=16, fontweight='bold')
ax.set_ylim(-0.53,0.3)
ax.set_title('Correlation between features and label Y', fontsize=20, fontweight='bold')
ax.set_xticks(np.arange(len(feature_names)))
ax.set_xticklabels(feature_names, fontsize=16, fontweight='bold', rotation=20, ha='right')

x_line = np.linspace(-0.6,len(feature_names),100)
y_line = np.linspace(0,0,100)
ax.plot(x_line, y_line, linestyle='dotted', color='black') 
ax.set_xlim(-0.6,9.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# The features most strongly correlated with the label Y, and thus most informative for distinguishing between gamma and hadron events, are `fAlpha`
# , `flength` and `fWidth` This is coherent with our observations from the feature histograms, where these features exhibit more distinct distributions between the two classes.

# %% [markdown]
# # Part 3: comparison of the features rescaled

# %% [markdown]
# In this section we analyze the distributions of the `fWidth` and `fLength` parameters. First of all we have computed the mean and standard deviation for both samples and we rescaled them. Then the distribution of both "`fWidth` and `fLength` was plotted dividing the gamma from the hadron events.
#
# We then used the `fSize` parameter to apply a cut to both the signals (gamma) and background (hadron) events and considered only the tails of their distribution. Since `fSize` is proportional to the number of photons, for both the width and lenght distribution we defined as "High energy events" the data points higher than 𝜇+𝜎
# (right-side tail) and as "Low energy events" the data points lower than 𝜇−𝜎. Considering 𝜇 and 𝜎 rispectively as the mean and standard deviation of the rescaled width and lenght distributions.
#
# From this comparison we can clearly see that in the high energy tail the signal is more clustered and separated from the background, despite having a smaller number of gamma events in this energy region. Meanwhile in the low energy tail signal and background events are more evenly distributed.
#
# Therefore,considering only the high energy region could give us an edge while classifying the events into signal and background.

# %%
## find mean and std

mu_l=data['fLength'].mean()
std_l=data['fLength'].std()
mu_w=data['fWidth'].mean()
std_w=data['fWidth'].std()
print('Length attribute:   mean = ', round(mu_l,3), '    std = ', round(std_l,3))
print('Width attribute:    mean = ', round(mu_w,3), '   std = ', round(std_w,3))
data['scaled_fLength']= (data['fLength']-mu_l)/std_l   ##add a scaled comlumn to the DataFrame
data['scaled_fWidth']= (data['fWidth']-mu_w)/std_w
# Out:
# Length attribute:   mean =  53.251     std =  42.366
# Width attribute:    mean =  22.181    std =  18.346

# %%
###plots of the scaled distribution before cutting 

bins = 32
common_bins = np.linspace(min(data['scaled_fLength']), max(data['scaled_fLength']), bins + 1)

fig, ax = plt.subplots(1, 2, figsize=(12,5))
sns.histplot(data,x=data['scaled_fLength'],hue='category',bins = common_bins, kde=False, ax=ax[0], palette=['red','blue'], edgecolor='#383734', linewidth=0.5)
ax[0].set_title("Distribution of Scaled fLenght", fontsize=14)
ax[0].set_xlabel("Scaled fLength", fontsize=12)
ax[0].set_ylabel("Count", fontsize=12)
ax[0].set_xlim(-1.5, 5.5)  
legend = ax[0].get_legend()

ax[0].legend(['Hadron', 'Gamma'], title='Category')

bins = 45
common_bins = np.linspace(min(data['scaled_fWidth']), max(data['scaled_fWidth']), bins + 1)
sns.histplot(data,x=data['scaled_fWidth'],hue='category',bins = common_bins, kde=False, ax=ax[1], palette=['red','blue'], edgecolor='#383734', linewidth=0.5)
ax[1].set_title("Distribution of Scaled fWidth", fontsize=14)
ax[1].set_xlabel("Scaled fWidth", fontsize=12)
ax[1].set_ylabel("Count", fontsize=12)
ax[1].set_xticks(range(-1,9))
ax[1].set_xlim(-1.5, 6)  
legend = ax[1].get_legend()
ax[1].legend(['Hadron', 'Gamma'], title='Category');

# %%
median_fSize = data['fSize'].median()
min_fSize = data['fSize'].min()
max_fSize = data['fSize'].max()
mean_fSize = data['fSize'].mean()
std_fSize = data['fSize'].std()
print("Statistichal informations of fSize: \nmedian=",median_fSize, '\nmin=', min_fSize, '\nmax=', max_fSize, '\nmean=', round(mean_fSize,3), '\nstd=', round(std_fSize,3))
# Out:
# Statistichal informations of fSize:
# median= 2.7396
# min= 1.9413
# max= 5.3233
# mean= 2.825
# std= 0.473

# %%
#### plots at high energy

fig, ax = plt.subplots(1, 2, figsize=(12,5))
fig.suptitle('High Energy Events (high fSize values)', fontsize=18)

fig.subplots_adjust(top=0.85)  

##useful variables
ng_high=len(data[data['category'] == 'g']['scaled_fLength'][data['fSize'] >= mean_fSize+std_fSize])
nh_high=len(data[data['category'] == 'h']['scaled_fLength'][data['fSize'] >= mean_fSize+std_fSize])
l_mu_g_high=data[data['category'] == 'g']['scaled_fLength'][data['fSize'] >= mean_fSize+std_fSize].mean()
l_mu_h_high=data[data['category'] == 'h']['scaled_fLength'][data['fSize'] >= mean_fSize+std_fSize].mean()
l_std_g_high=data[data['category'] == 'g']['scaled_fLength'][data['fSize'] >= mean_fSize+std_fSize].std()
l_std_h_high=data[data['category'] == 'h']['scaled_fLength'][data['fSize'] >= mean_fSize+std_fSize].std()
w_mu_g_high=data[data['category'] == 'g']['scaled_fWidth'][data['fSize'] >= mean_fSize+std_fSize].mean()
w_mu_h_high=data[data['category'] == 'h']['scaled_fWidth'][data['fSize'] >= mean_fSize+std_fSize].mean()
w_std_g_high=data[data['category'] == 'g']['scaled_fWidth'][data['fSize'] >= mean_fSize+std_fSize].std()
w_std_h_high=data[data['category'] == 'h']['scaled_fWidth'][data['fSize'] >= mean_fSize+std_fSize].std()

##plot length - high energy
sns.histplot(data,x=data['scaled_fLength'][data['fSize'] >= mean_fSize+std_fSize],hue='category',hue_order=['g', 'h'], kde=False, color='blue', ax=ax[0], palette=['red','blue'], edgecolor='#383734', linewidth=0.5,bins=32)

ax[0].legend(['Hadron', 'Gamma'], title='Category')
ax[0].set_title("Distribution of Scaled fLenght", fontsize=14)
ax[0].set_xlabel("Scaled fLength", fontsize=12)
ax[0].set_ylabel("Count", fontsize=12)
ax[0].axvline(l_mu_g_high,c='#990000', label= r'$\mu_{g}$', lw=1.8)
ax[0].axvline(l_mu_h_high,c='navy',label=r'$\mu_{h}$', lw=1.7)
legend = ax[0].get_legend()

ax[0].text(x=3,y=180,s=f"# of gamma events: {ng_high} \n# of hadron events: {nh_high}", fontsize=9, color='black')
ax[0].text(x=3,y=160,s=fr"$\mu_{{g}}$={l_mu_g_high:.2f} $\pm$ {l_std_g_high:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='#990000'))
ax[0].text(x=3,y=130,s=fr"$\mu_{{h}}$={l_mu_h_high:.2f} $\pm$ {l_std_h_high:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='navy'))

#plot width - high energy
sns.histplot(data,x=data['scaled_fWidth'][data['fSize'] >= mean_fSize+std_fSize],hue='category', kde=False, color='blue', ax=ax[1], palette=['red','blue'], edgecolor='#383734', linewidth=0.5,bins=40)
ax[1].legend(['Hadron', 'Gamma'], title='Category')
ax[1].set_title("Distribution of Scaled fWidth", fontsize=14)
ax[1].set_xlabel("Scaled fWidth", fontsize=12)
ax[1].set_ylabel("Count", fontsize=12)
ax[1].set_xlim(-1,8.5)
ax[1].axvline(w_mu_g_high,c='#990000', lw = 1.8) #label= r'$\mu_{g}$', lw=1.8)
ax[1].axvline(w_mu_h_high,c='navy', lw = 1.7) #label=r'$\mu_{h}$', lw=1.7)
legend = ax[1].get_legend()

ax[1].text(x=4,y=350,s=f"# of gamma events: {ng_high} \n# of hadron events: {nh_high}", fontsize=9, color='black')
ax[1].text(x=4,y=315,s=fr"$\mu_{{g}}$={w_mu_g_high:.2f} $\pm$ {w_std_g_high:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='#990000'))
ax[1].text(x=4,y=260,s=fr"$\mu_{{h}}$={w_mu_h_high:.2f} $\pm$ {w_std_h_high:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='navy'))

#### plots at low energy

fig1, ax1 = plt.subplots(1, 2, figsize=(12,5))
fig1.suptitle('Low Energy Events (low fSize values)', fontsize=18)
fig.subplots_adjust(top=0.85)  
###useful variables
ng_low=len(data[data['category'] == 'g']['scaled_fLength'][data['fSize'] <= mean_fSize-std_fSize])
nh_low=len(data[data['category'] == 'h']['scaled_fLength'][data['fSize'] <= mean_fSize-std_fSize])
l_mu_g_low=data[data['category'] == 'g']['scaled_fLength'][data['fSize'] <= mean_fSize-std_fSize].mean()
l_mu_h_low=data[data['category'] == 'h']['scaled_fLength'][data['fSize'] <= mean_fSize-std_fSize].mean()
l_std_g_low=data[data['category'] == 'g']['scaled_fLength'][data['fSize'] <= mean_fSize-std_fSize].std()
l_std_h_low=data[data['category'] == 'h']['scaled_fLength'][data['fSize'] <= mean_fSize-std_fSize].std()
w_mu_g_low=data[data['category'] == 'g']['scaled_fWidth'][data['fSize'] <= mean_fSize-std_fSize].mean()
w_mu_h_low=data[data['category'] == 'h']['scaled_fWidth'][data['fSize'] <= mean_fSize-std_fSize].mean()
w_std_g_low=data[data['category'] == 'g']['scaled_fWidth'][data['fSize'] <= mean_fSize-std_fSize].std()
w_std_h_low=data[data['category'] == 'h']['scaled_fWidth'][data['fSize'] <= mean_fSize-std_fSize].std()

## plot length - low energy
sns.histplot(data,x=data['scaled_fLength'][data['fSize'] <= mean_fSize-std_fSize],hue='category', kde=False, color='blue', ax=ax1[0], palette=['red','blue'],edgecolor='#383734', linewidth=0.5, bins=180)
ax1[0].set_title("Distribution of Scaled fLenght", fontsize=14)
ax1[0].legend(['Hadron', 'Gamma'], title='Category')
ax1[0].set_xlabel("Scaled fLength", fontsize=12)
ax1[0].set_ylabel("Count", fontsize=12)
ax1[0].axvline(l_mu_g_low,c='#990000', label= r'$\mu_{g}$', lw=1.8)
ax1[0].axvline(l_mu_h_low,c='navy',label=r'$\mu_{h}$', lw=1.7,alpha=0.7)
legend = ax[0].get_legend()

ax1[0].set_xlim(-1.1,-0.1)
ax1[0].text(x=-0.55,y=230,s=f"# of gamma events: {ng_low} \n# of hadron events: {nh_low} ", fontsize=9, color='black')
ax1[0].text(x=-0.55,y=208,s=fr"$\mu_{{g}}$={l_mu_g_low:.2f} $\pm$ {l_std_g_low:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='#990000'))
ax1[0].text(x=-0.55,y=178,s=fr"$\mu_{{h}}$={l_mu_h_low:.2f} $\pm$ {l_std_h_low:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='navy'))

## plot width - low energy
sns.histplot(data,x=data['scaled_fWidth'][data['fSize'] <= mean_fSize-std_fSize],hue='category', kde=False, color='blue', ax=ax1[1], palette=['red','blue'], edgecolor='#383734', linewidth=0.5,bins=30)
ax1[1].set_title("Distribution of Scaled fWidth", fontsize=14)
ax1[1].legend(['Hadron', 'Gamma'], title='Category')
ax1[1].set_xlabel("Scaled fWidth", fontsize=12)
ax1[1].set_ylabel("Count", fontsize=12)
ax1[1].set_xlim(-1.3,0.0)
ax1[1].axvline(w_mu_g_low,c='#990000', label= r'$\mu_{g}$', lw=1.8)
ax1[1].axvline(w_mu_h_low,c='navy',label=r'$\mu_{h}$', lw=1.7)
legend = ax[1].get_legend()
ax1[1].text(x=-0.54,y=350,s=f"# of gamma events: {ng_low} \n# of hadron events: {nh_low}", fontsize=9, color='black')
ax1[1].text(x=-0.54,y=320,s=fr"$\mu_{{g}}$={l_mu_g_low:.2f} $\pm$ {l_std_g_low:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='#990000'))
ax1[1].text(x=-0.54,y=280,s=fr"$\mu_{{h}}$={l_mu_h_low:.2f} $\pm$ {l_std_h_low:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='navy'))


plt.show();

# %% [markdown]
# # Part 4: PCA
# In this part we will perform Principal Component Analysis (PCA). PCA is a statistical tecnique used for reducing the dimensionality of the problem. PCA is done studying in which directions of the feature space the dataset shows significant patterns. This is done computing the covariance matrix and finding its eigenvalues and eigenvectors. The eigenvectors are then used to redefine the feature space and aling data along them. Eigenvectors whose eigenvalues are higher correspond to directions of highest variance in the dataset. This way we can reduce the dimensionality of the problem and focus on the most significant directions. PCA is done separately for signal and background events, to find significative differences in spread for different labels.

# %%
file_name="magic04.data"
data = pd.DataFrame(pd.read_csv(file_name))

df= pd.DataFrame(data.values, columns=['fLength','fWidth','fSize','fConc','fConc1','fAsym','fM3Long','fM3Trans','fAlpha','fDist','class'])
df_1=df[df['class']=='g']
df_0=df[df['class']=='h']
df_1 = df_1.drop(columns=['class']) # no need for label to perform PCA
df_0 = df_0.drop(columns=['class']) 

print("Shape of signal data frame:",np.shape(df_1))
print("Shape of bkg data frame:",np.shape(df_0))
# Out:
# Shape of signal data frame: (12331, 10)
# Shape of bkg data frame: (6688, 10)

# %%
# We re-scale the data-set to mean zero and unitary std before executing the PCA   
for column in df_1.columns: 
    mean =df_1[column].mean()
    std= df_1[column].std()
    df_1[column]= (df_1[column]-mean)/std
for column in df_0.columns: 
    mean =df_0[column].mean()
    std= df_0[column].std()
    df_0[column]= (df_0[column]-mean)/std

# %%
df_1
# Out:
#         fLength     fWidth     fSize     fConc    fConc1     fAsym   fM3Long  \
# 0      -0.46046  -0.760816 -0.573381  0.823995  1.527718  0.581262  0.177195
# 1      4.523403  13.006763  2.757867  -1.94532 -1.848775   2.86389 -2.435386
# 2     -0.757944  -0.999015 -0.962066  1.298189  1.668012  0.604942 -0.715068
# 3      1.202731   1.365333  0.814225 -0.375535 -0.299882 -0.221084  0.316503
# 4      0.304432   0.283231   0.26877 -0.795793 -0.763137  1.202046  0.747688
# ...         ...        ...       ...       ...       ...       ...       ...
# 12326 -1.176177  -0.791727 -0.870077  1.979703  1.557848 -0.462468 -0.368425
# 12327 -0.641711   0.221696  0.197295 -0.223838  0.001423 -0.168803 -1.113903
# 12328 -0.823883  -0.852587 -1.057078  0.867819  0.723612  0.303856  0.012389
# 12329  0.480086   0.012071  0.314549 -0.741856 -0.713234    2.3551 -1.741272
# 12330  -0.46394    0.07684  0.375227 -0.483971 -0.598361  0.881792  0.113829
#
#        fM3Trans    fAlpha     fDist
# 0     -0.748903 -0.578221  0.213696
# 1     -3.350675  2.708118  0.946671
# 2     -0.541838 -0.387922 -1.045563
# 3      1.597412 -0.657955   2.36454
# 4      0.710088 -0.706133  0.680804
# ...         ...       ...       ...
# 12326  0.843377  0.103778  0.196285
# 12327 -0.682203 -0.688826  0.217067
# 12328  0.531735  0.106385 -0.952475
# 12329  0.825343 -0.599163  0.099156
# 12330 -0.904986 -0.055937  -0.27044
#
# [12331 rows x 10 columns]

# %%
df_0
# Out:
#         fLength    fWidth     fSize     fConc    fConc1     fAsym   fM3Long  \
# 12331  0.392734  0.336335  0.509333 -1.078145 -0.955834  0.869326  1.300189
# 12332  0.535902 -0.249909  0.864505 -1.400203 -1.198949 -0.434994  0.649403
# 12333  0.506171 -0.254443  0.435676 -0.325283 -0.587349 -0.363269  0.855943
# 12334    0.3574 -0.366573 -0.397221  0.336609  1.084807 -0.417957  -1.34382
# 12335 -0.568118 -0.592947 -0.053908  0.178717 -0.179052 -0.403375  0.158383
# ...         ...       ...       ...       ...       ...       ...       ...
# 19014 -0.855161 -0.657545 -0.591972  1.105678  1.520212  0.407652  0.203334
# 19015 -0.724699  -0.81255 -1.317922  0.841131  0.546058  0.672784  0.226829
# 19016  0.077684  0.688905  1.139571 -1.215647 -1.347189  0.108521  0.621122
# 19017  0.855352  1.769025  2.274791 -1.462941 -1.233679  0.292734 -1.282777
# 19018  2.005736  0.890095  0.642288 -0.452851  -0.50857 -1.810805 -2.342868
#
#        fM3Trans    fAlpha     fDist
# 12331   0.38302 -1.149281  0.384367
# 12332 -0.515505  1.711764  0.910031
# 12333 -0.333989 -0.892876  1.783286
# 12334 -0.583383  0.765787 -0.850547
# 12335  0.254152 -0.748348 -0.446646
# ...         ...       ...       ...
# 19014  0.084175  -1.59954 -1.143376
# 19015 -0.111018  1.647644   0.57434
# 19016 -0.328377 -0.526731   0.68501
# 19017 -2.145759  1.566436  2.539158
# 19018   1.04008  0.336584  0.878007
#
# [6688 rows x 10 columns]

# %%
cov_1 = df_1.cov()
cov_0 = df_0.cov()
cov_1
# Out:
#            fLength    fWidth     fSize     fConc    fConc1     fAsym  \
# fLength   1.000000  0.695644  0.766118 -0.710209 -0.679994 -0.120212
# fWidth    0.695644  1.000000  0.855155 -0.761340 -0.731434 -0.002589
# fSize     0.766118  0.855155  1.000000 -0.863440 -0.825395  0.029039
# fConc    -0.710209 -0.761340 -0.863440  1.000000  0.979332 -0.033398
# fConc1   -0.679994 -0.731434 -0.825395  0.979332  1.000000 -0.037624
# fAsym    -0.120212 -0.002589  0.029039 -0.033398 -0.037624  1.000000
# fM3Long   0.542507  0.422045  0.540963 -0.452184 -0.433913  0.162435
# fM3Trans  0.012337  0.044016  0.022622 -0.017356 -0.016053 -0.005598
# fAlpha   -0.443232 -0.296886 -0.458023  0.482322  0.463536 -0.004571
# fDist     0.602479  0.389206  0.459641 -0.368592 -0.347123 -0.178190
#
#            fM3Long  fM3Trans    fAlpha     fDist
# fLength   0.542507  0.012337 -0.443232  0.602479
# fWidth    0.422045  0.044016 -0.296886  0.389206
# fSize     0.540963  0.022622 -0.458023  0.459641
# fConc    -0.452184 -0.017356  0.482322 -0.368592
# fConc1   -0.433913 -0.016053  0.463536 -0.347123
# fAsym     0.162435 -0.005598 -0.004571 -0.178190
# fM3Long   1.000000  0.008234 -0.271465  0.294765
# fM3Trans  0.008234  1.000000 -0.007311  0.009752
# fAlpha   -0.271465 -0.007311  1.000000 -0.425032
# fDist     0.294765  0.009752 -0.425032  1.000000

# %%
cov_0
# Out:
#            fLength    fWidth     fSize     fConc    fConc1     fAsym  \
# fLength   1.000000  0.773884  0.747319 -0.688524 -0.651879 -0.423194
# fWidth    0.773884  1.000000  0.790355 -0.672618 -0.638750 -0.304118
# fSize     0.747319  0.790355  1.000000 -0.839128 -0.796837 -0.305340
# fConc    -0.688524 -0.672618 -0.839128  1.000000  0.972725  0.238806
# fConc1   -0.651879 -0.638750 -0.796837  0.972725  1.000000  0.220317
# fAsym    -0.423194 -0.304118 -0.305340  0.238806  0.220317  1.000000
# fM3Long  -0.307349 -0.296956 -0.223553  0.124154  0.115716  0.285738
# fM3Trans  0.013007  0.039519  0.010992 -0.007704 -0.008235  0.006849
# fAlpha   -0.009282  0.041617 -0.004228 -0.010714 -0.015137  0.053334
# fDist     0.325267  0.354997  0.394842 -0.267684 -0.245179 -0.229049
#
#            fM3Long  fM3Trans    fAlpha     fDist
# fLength  -0.307349  0.013007 -0.009282  0.325267
# fWidth   -0.296956  0.039519  0.041617  0.354997
# fSize    -0.223553  0.010992 -0.004228  0.394842
# fConc     0.124154 -0.007704 -0.010714 -0.267684
# fConc1    0.115716 -0.008235 -0.015137 -0.245179
# fAsym     0.285738  0.006849  0.053334 -0.229049
# fM3Long   1.000000 -0.026806 -0.001489 -0.131121
# fM3Trans -0.026806  1.000000  0.010832  0.013150
# fAlpha   -0.001489  0.010832  1.000000 -0.097112
# fDist    -0.131121  0.013150 -0.097112  1.000000

# %%
l_1,V_1= la.eig(cov_1)
l_1=l_1.real
V_1=V_1.real
print("Eigenvalues Gamma events:", l_1,'\n')
print("Eigenvectors Gamma events:", V_1,'\n')
# Out:
# Eigenvalues Gamma events: [5.04135896 1.18671249 1.00189813 0.86259252 0.73828989 0.52867675
#  0.01763177 0.10500615 0.29317529 0.22465805]
#
# Eigenvectors Gamma events: [[ 3.86563154e-01 -1.64161550e-01  1.87852855e-02  5.17321758e-02
#   -2.27306595e-01  6.21165157e-02 -1.64670468e-02 -2.62838530e-02
#   -3.75283692e-02  8.73323351e-01]
#  [ 3.76614052e-01  6.58692554e-02 -5.96665086e-02 -3.13862948e-01
#   -9.53882263e-02  2.55432045e-01  4.24256844e-03 -4.90484637e-01
#   -6.23609927e-01 -2.18920288e-01]
#  [ 4.17121017e-01  7.65050692e-02 -1.22260020e-02 -1.38753617e-01
#   -1.93685374e-02  6.00347575e-02 -1.05957925e-01  8.36960174e-01
#   -2.44851708e-01 -1.58410555e-01]
#  [-4.09538760e-01 -1.17040480e-01  9.64678415e-03  2.30228965e-01
#   -2.25834045e-01  6.25170832e-02 -7.50095221e-01  4.79749462e-02
#   -3.77875580e-01  5.32663335e-02]
#  [-3.98738464e-01 -1.26974491e-01  9.56015222e-03  2.43724055e-01
#   -2.46152389e-01  7.37984117e-02  6.52335699e-01  1.94150192e-01
#   -4.81400557e-01  6.61244443e-02]
#  [-1.90622395e-03  8.04052066e-01  3.28590356e-02  3.80203807e-01
#    9.19693200e-02  4.28997470e-01  9.83604836e-04 -9.79016721e-03
#    1.56041455e-02  1.22574473e-01]
#  [ 2.71903952e-01  2.41249770e-01  3.78642354e-02  3.23906107e-01
#   -6.32530906e-01 -5.46456330e-01  8.61015132e-03 -1.03440095e-01
#    5.50948287e-02 -2.21356334e-01]
#  [ 1.26092933e-02 -7.19184389e-03 -9.93064376e-01  1.11114138e-01
#    9.57172582e-03 -1.53254329e-02 -2.12728561e-04  9.64915066e-03
#    2.61091729e-02  1.28354940e-02]
#  [-2.57574835e-01  1.45524116e-01 -6.79277022e-02 -5.49090461e-01
#   -6.21464113e-01  3.39978798e-01  1.14649466e-02  7.84584893e-02
#    3.13437642e-01  5.46497448e-03]
#  [ 2.59975576e-01 -4.55091241e-01  4.94837864e-02  4.51483873e-01
#   -1.80007439e-01  5.65210973e-01  9.61549203e-03 -3.45139415e-02
#    2.70203068e-01 -3.04727483e-01]]

# %%
l_0,V_0= la.eig(cov_0)
l_0=l_0.real
V_0=V_0.real
print("Eigenvalues background events:", l_0,'\n')
print("Eigenvectors background events:", V_0,'\n')
# Out:
# Eigenvalues background events: [4.42388448 0.02391582 0.14984033 0.2221564  0.43740477 1.20808117
#  0.69931975 0.80384168 1.03760086 0.99395472]
#
# Eigenvectors background events: [[-4.13567164e-01 -2.63725151e-02 -1.06784542e-01  7.64522513e-01
#   -4.62230622e-01 -8.23597651e-02 -5.41729191e-02  7.12962716e-02
#    4.76672675e-02 -4.04817037e-02]
#  [-4.10369824e-01  1.18010294e-02  4.74225410e-01 -4.98487549e-01
#   -5.76267380e-01 -9.62312079e-03  1.32890905e-01 -2.68784361e-02
#    8.66124162e-02 -4.11274819e-03]
#  [-4.39407630e-01 -1.02147327e-01 -8.06450398e-01 -3.56019314e-01
#   -3.84986171e-02  1.09655517e-01  5.96543774e-02 -1.63618469e-02
#   -4.11859284e-02  1.85943597e-02]
#  [ 4.26015621e-01 -7.48302786e-01 -1.36062501e-01 -5.34223025e-02
#   -3.57161556e-01 -2.95977603e-01  2.83083846e-02 -1.28650819e-01
#    6.42454683e-02 -2.32311900e-02]
#  [ 4.12889561e-01  6.54722945e-01 -2.94628020e-01 -7.73629598e-02
#   -4.28069468e-01 -3.13905698e-01  2.86139245e-02 -1.45244984e-01
#    6.18974490e-02 -2.33016102e-02]
#  [ 2.10557832e-01 -7.40397142e-04 -3.55910497e-02  1.47422983e-01
#   -1.46018555e-01  5.34160663e-01  7.75942210e-01 -3.19883815e-02
#   -6.50820677e-02  1.36639359e-01]
#  [ 1.56723710e-01 -9.82568990e-03 -1.68716012e-03 -8.72677373e-03
#   -2.86536343e-01  5.81070528e-01 -5.65135446e-01 -2.90368802e-01
#   -3.54285779e-01  1.62189920e-01]
#  [-1.12947495e-02  3.15103998e-04 -1.47230802e-02  1.26216402e-02
#    2.33848465e-02 -3.73288613e-02 -8.88561614e-02  3.08618973e-02
#    4.39405146e-01  8.91981616e-01]
#  [ 2.80804609e-03  1.13046169e-03 -2.41165114e-02  3.27484558e-02
#    6.09854767e-02  3.00604868e-01 -9.24616134e-02 -4.17620174e-01
#    7.67868956e-01 -3.62871549e-01]
#  [-2.15592824e-01  3.67233256e-03  7.71910499e-02  9.15713297e-02
#    1.85143711e-01 -2.83254481e-01  1.90571725e-01 -8.34016294e-01
#   -2.60993030e-01  1.56949242e-01]]

# %%
#GAMMA EVENTS
# sort eigenvalues in descending order and get sorted indices
sorted_indices = np.argsort(l_1)[::-1]
l_sorted = l_1[sorted_indices] 
 
variance_explained = l_sorted / np.sum(l_sorted) # ratio of the variance of the data explained by each feature

# cumulative variance explained
cumulative_variance = np.cumsum(variance_explained)

feature_names = df_1.columns.tolist()
pca_list = []
for i in range(len(feature_names)):
    pca_list.append(f'PC_{i+1}')

# features ordered from most important to least important to variability 
top_features = []
for i in range(len(feature_names)):
    most_important_feature_idx = sorted_indices[i]  # Index of the feature with the largest eigenvalue
    top_features.append(feature_names[most_important_feature_idx])

fig, ax1 = plt.subplots(figsize=(16, 8))

ax1.bar(pca_list, variance_explained, color='Orange', edgecolor='black',alpha=0.75)

ax2 = ax1.twinx()
ax2.plot(pca_list, cumulative_variance, label='Cumulative Variance Explained', marker='o', color='red')

ax1.set_ylabel('Variance Explained',fontsize=20)
ax2.set_ylabel('Cumulative Variance Explained',fontsize=20)
ax1.set_xlabel('# Principal component',fontsize=20)

plt.title('Gamma events: variance explained by each feature',fontsize=26)
ax2.legend(loc='upper center',fontsize=16)

plt.xticks(rotation=45, ha='right', fontsize=45)  
ax1.tick_params(axis='y', labelsize=16)  
ax2.tick_params(axis='y', labelsize=16)
ax1.tick_params(axis='x', labelsize=16)
plt.grid()
plt.show()
print("\n")

#BACKGROUND EVENTS 
sorted_indices = np.argsort(l_0)[::-1]
l_sorted = l_0[sorted_indices] 
 
variance_explained = l_sorted / np.sum(l_sorted) # ratio of the variance of the data explained by each feature

# cumulative variance explained
cumulative_variance = np.cumsum(variance_explained)

feature_names = df_0.columns.tolist()

# features ordered from most important to least important to variability 
top_features = []
for i in range(len(feature_names)):
    most_important_feature_idx = sorted_indices[i]  # Index of the feature with the largest eigenvalue
    top_features.append(feature_names[most_important_feature_idx])

fig, ax1 = plt.subplots(figsize=(16, 8))

ax1.bar(pca_list, variance_explained, color='Orange', edgecolor='black',alpha=0.75)

ax2 = ax1.twinx()
ax2.plot(pca_list, cumulative_variance, label='Cumulative Variance Explained', marker='o', color='blue')

ax1.set_ylabel('Variance Explained',fontsize=20)
ax1.set_xlabel('# Principal component',fontsize=20)
ax2.set_ylabel('Cumulative Variance Explained',fontsize=20)


plt.title('Background events: variance explained by each feature',fontsize=26)
ax2.legend(loc='upper center',fontsize=16)

plt.xticks(rotation=45, ha='right', fontsize=18)  
ax1.tick_params(axis='y', labelsize=16)  
ax2.tick_params(axis='y', labelsize=16)
ax1.tick_params(axis='x', labelsize=16)
plt.grid()
plt.show()

# %% [markdown]
# We notice that, for both signal and background events, the first principal component contributes to about half of the variabiality of the dataset, while the least 4 components account for less than 5%. However, it is not possible to identify on which basis it is convenient to work (the eigenvectors of signal or hadron events). For this reason and also beacuse of the limited number of features of the dataset, we decide to perform the following classification analysis with the complete dataset of features.

# %% [markdown]
# # Part 5: Machine Learning Analysis
#
# In this section we are going to implement several ML binary classification algorithms to distinguish between gamma and hadron events. We choose as objective for each model to maximize the ROC curve area in the False Positive Rate (FPR) range [0-0.2]. We will not be using the fAlpha feature to train the models at this stage; it will be considered separately as a special feature in a later analysis.
#
# The ROC curve plots the TPR, i.e: the fraction of actual gamma samples correctly identified as gamma, versus the False Positive Rate (FPR), i.e: the fraction of actual hadrons events incorrectly classified as gamma by the model. To do so, it's necessary to estimate a probability for the predicted class, not just to assign the predicted label. We will call *gammaness* the probability returned by each prediction model for a certain event to be a gamma event. Imposing different threshold values on the gammaness for the acceptance of an event as either gamma or hadron, we can obtain the ROC curve. The Area Under the ROC Curve (AUC) represents the overall probability that the model will distinguish between the two classes. However, in our case we are mostly interested in avoiding false positives, we do not really care about loss minimization per se or about the model performance at high FPR. This is the reason why we choose to maximize the partial AUC in a region that is a better indicator of how well the model performs for our specific needs.
# For each model, when needed, we implement a grid search on the hyperparameters using the K-fold cross validation tecnique on the training set. The best model will be the one maximizing the average partial ROC area over the K configurations.
#
# Another metric we will be using in the following analysis is the quality factor $Q=\frac{\epsilon_{\gamma}}{\sqrt{\epsilon_h}}$, where ${\epsilon_{\gamma}}$ represents the fraction of correctly classified signals (TPR), and ${{\epsilon_h}}$ represents the fraction of hadrons incorrectly classified as gammas (FPR). Our objective is to minimize the false positives while correctly identifying signals, which correpsonds to maximizing Q.

# %% [markdown]
# ## Part 5.1: Perceptron
# First, we try to implement a simple linear classification model with the Perceptron algorithm. We associate label +1 to gamma events and -1 to hadron events. We randomly split the dataset into training and test set (80% and 20% of total data respectively).

# %%
# Alpha has not to be normalized (reset to original value)
X_rescaled['fAlpha'] = original_alpha.copy()

new_Y = []

# gammas are +1    hadrons are -1

for i in range(len(Y)):
    if (Y.iloc[i] == 'g'):
        new_Y.append(1)
    if(Y.iloc[i] == 'h'):
        new_Y.append(-1)
        
Y_df = pd.DataFrame({'category' : new_Y})
data_rescaled_and_indexed = pd.merge(X_rescaled, Y_df,left_index=True, right_index=True)

# divide dataset in 5 parts, taking 1 as test set ( 20 % )
# remove alpha

parts_to_be_split = 5 
train_set, test_set = split_train_test_set( data_rescaled_and_indexed , parts_to_be_split )
train_alpha = train_set['fAlpha']
train_set = train_set.drop('fAlpha',axis=1)
test_alpha = test_set['fAlpha']
test_set = test_set.drop('fAlpha',axis=1)
X_train, Y_train = split_X_Y(train_set)
X_test, Y_test = split_X_Y(test_set)

print('Train set shapes:',np.shape(X_train),np.shape(Y_train))
print('Absolute and relative frequence of points in Training set:')
print(f'Signal: {len(Y_train[Y_train == 1])} points \t {round(len(Y_train[Y_train == 1])/len(Y_train)*100,2)}%')
print(f'Back: {len(Y_train[Y_train == -1])} points \t {round(len(Y_train[Y_train == -1])/len(Y_train)*100,2)}%\n')

print('Test set shapes:',np.shape(X_test),np.shape(Y_test))
print('Absolute and relative frequence of points in Test set:')
print(f'Signal: {len(Y_test[Y_test == 1])} points \t {round(len(Y_test[Y_test == 1])/len(Y_test)*100,2)}%')
print(f'Back: {len(Y_test[Y_test == -1])} points \t {round(len(Y_test[Y_test == -1])/len(Y_test)*100,2)}%\n')
# Out:
# Train set shapes: (15216, 9) (15216,)
# Absolute and relative frequence of points in Training set:
# Signal: 9843 points 	 64.69%
# Back: 5373 points 	 35.31%
#
# Test set shapes: (3803, 9) (3803,)
# Absolute and relative frequence of points in Test set:
# Signal: 2488 points 	 65.42%
# Back: 1315 points 	 34.58%

# %% [markdown]
# The following cell performs the training. We train 10000 perceptrons algorithms to find the best performance achievable by the model.

# %%
n_attempts = 10000
limit = 0.2 
best_scores = []
best_f = []
best_t = []
best_score = 0

# K fold definition
K = 5
limit = 0.2 
kf = KFold(n_splits=K, shuffle=True, random_state=42) 

#print('n_iter, score')
for i in range (n_attempts):
    auc_fold = 0
    filtered_auc_fold = 0
    
    state = abs(np.random.normal(size=1))
    state = int(state[0] * 1000000)
    perceptron = Perceptron(alpha=0.01,penalty='l2',max_iter=10000,tol=1e-4,random_state=state,n_iter_no_change=10)
    
    for train_idx, val_idx in kf.split(data_rescaled_and_indexed):  ###gets the index of training and validation set
                
        train_K=data_rescaled_and_indexed.iloc[train_idx]
        valid_K=data_rescaled_and_indexed.iloc[val_idx]
        X_train_K, Y_train_K = split_X_Y(train_K)
        X_valid_K, Y_valid_K = split_X_Y(valid_K)
    
    
        fitted = perceptron.fit(X_train_K,Y_train_K)
    
        decision_values = perceptron.decision_function(X_valid_K)

        fpr, tpr, thresholds = roc_curve(Y_valid_K, decision_values)
    
        # here i filter data to compute roc curve area for fpr in range 0 -> 0.8
        fpr_filtered = fpr[fpr <= limit]
        tpr_filtered = tpr[:len(fpr_filtered)]
    
        auc_filtered_K = np.trapz(tpr_filtered, fpr_filtered)
        auc_K = roc_auc_score(Y_valid_K, decision_values)
        auc_fold += auc_K / K
        filtered_auc_fold += auc_filtered_K / K
    
    # score is better if filtered is better, though saving all 
    if (filtered_auc_fold > best_score):
        best_score = filtered_auc_fold
        best_scores.append(auc_fold)

        #best_f.append(fpr)
        best_fpr = fpr
        best_tpr = tpr
        #best_t.append(tpr)
        best_perceptron = perceptron
        #print(i, auc)

print('Trained',n_attempts,'perceptrons')
print("best AUC-ROC Score:", round(best_scores[len(best_scores)-1],3) )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 30
#      26 X_train_K, Y_train_K = split_X_Y(train_K)
#      27 X_valid_K, Y_valid_K = split_X_Y(valid_K)
# ---> 30 fitted = perceptron.fit(X_train_K,Y_train_K)
#      32 decision_values = perceptron.decision_function(X_valid_K)
#      34 fpr, tpr, thresholds = roc_curve(Y_valid_K, decision_values)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:907, in BaseSGDClassifier.fit(self, X, y, coef_init, intercept_init, sample_weight)
#     878 """Fit linear model with Stochastic Gradient Descent.
#     879
#     880 Parameters
#    (...)
#     903     Returns an instance of self.
#     904 """
#     905 self._more_validate_params()
# --> 907 return self._fit(
#     908     X,
#     909     y,
#     910     alpha=self.alpha,
#     911     C=1.0,
#     912     loss=self.loss,
#     913     learning_rate=self.learning_rate,
#     914     coef_init=coef_init,
#     915     intercept_init=intercept_init,
#     916     sample_weight=sample_weight,
#     917 )
#
# File ~/.local/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:694, in BaseSGDClassifier._fit(self, X, y, alpha, C, loss, learning_rate, coef_init, intercept_init, sample_weight)
#     691 # Clear iteration count for multiple call to fit.
#     692 self.t_ = 1.0
# --> 694 self._partial_fit(
#     695     X,
#     696     y,
#     697     alpha,
#     698     C,
#     699     loss,
#     700     learning_rate,
#     701     self.max_iter,
#     702     classes,
#     703     sample_weight,
#     704     coef_init,
#     705     intercept_init,
#     706 )
#     708 if (
#     709     self.tol is not None
#     710     and self.tol > -np.inf
#     711     and self.n_iter_ == self.max_iter
#     712 ):
#     713     warnings.warn(
#     714         (
#     715             "Maximum number of iteration reached before "
#    (...)
#     719         ConvergenceWarning,
#     720     )
#
# File ~/.local/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:638, in BaseSGDClassifier._partial_fit(self, X, y, alpha, C, loss, learning_rate, max_iter, classes, sample_weight, coef_init, intercept_init)
#     628     self._fit_multiclass(
#     629         X,
#     630         y,
#    (...)
#     635         max_iter=max_iter,
#     636     )
#     637 elif n_classes == 2:
# --> 638     self._fit_binary(
#     639         X,
#     640         y,
#     641         alpha=alpha,
#     642         C=C,
#     643         learning_rate=learning_rate,
#     644         sample_weight=sample_weight,
#     645         max_iter=max_iter,
#     646     )
#     647 else:
#     648     raise ValueError(
#     649         "The number of classes has to be greater than one; got %d class"
#     650         % n_classes
#     651     )
#
# File ~/.local/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:725, in BaseSGDClassifier._fit_binary(self, X, y, alpha, C, sample_weight, learning_rate, max_iter)
#     723 def _fit_binary(self, X, y, alpha, C, sample_weight, learning_rate, max_iter):
#     724     """Fit a binary classifier on X and y."""
# --> 725     coef, intercept, n_iter_ = fit_binary(
#     726         self,
#     727         1,
#     728         X,
#     729         y,
#     730         alpha,
#     731         C,
#     732         learning_rate,
#     733         max_iter,
#     734         self._expanded_class_weight[1],
#     735         self._expanded_class_weight[0],
#     736         sample_weight,
#     737         random_state=self.random_state,
#     738     )
#     740     self.t_ += n_iter_ * X.shape[0]
#     741     self.n_iter_ = n_iter_
#
# File ~/.local/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:453, in fit_binary(est, i, X, y, alpha, C, learning_rate, max_iter, pos_weight, neg_weight, sample_weight, validation_mask, random_state)
#     450 tol = est.tol if est.tol is not None else -np.inf
#     452 _plain_sgd = _get_plain_sgd_function(input_dtype=coef.dtype)
# --> 453 coef, intercept, average_coef, average_intercept, n_iter_ = _plain_sgd(
#     454     coef,
#     455     intercept,
#     456     average_coef,
#     457     average_intercept,
#     458     est.loss_function_,
#     459     penalty_type,
#     460     alpha,
#     461     C,
#     462     est.l1_ratio,
#     463     dataset,
#     464     validation_mask,
#     465     est.early_stopping,
#     466     validation_score_cb,
#     467     int(est.n_iter_no_change),
#     468     max_iter,
#     469     tol,
#     470     int(est.fit_intercept),
#     471     int(est.verbose),
#     472     int(est.shuffle),
#     473     seed,
#     474     pos_weight,
#     475     neg_weight,
#     476     learning_rate_type,
#     477     est.eta0,
#     478     est.power_t,
#     479     0,
#     480     est.t_,
#     481     intercept_decay,
#     482     est.average,
#     483 )
#     485 if est.average:
#     486     if len(est.classes_) == 2:
#
# KeyboardInterrupt:

# %% [markdown]
# Here we plot the confusion matrix for the best model:

# %%
def normalize_cm(cm):
    norm_cm = np.zeros(shape=(2,2))
    bkg = cm[0,0] + cm[0,1]  # first row is bkg
    sig = cm[1,0] + cm[1,1]  # second row is signal
    norm_cm[0,0] = round(cm[0,0] / bkg,3)
    norm_cm[0,1] = round(cm[0,1] / bkg,3)
    norm_cm[1,0] = round(cm[1,0] / sig,3)
    norm_cm[1,1] = round(cm[1,1] / sig,3)
    
    return norm_cm


def plot_cm(cm,method_name):
    fig = plt.figure()
    im = plt.imshow(cm, cmap='seismic',alpha=0.8, interpolation='nearest')
    plt.xticks([0,1], ['bkg', 'signal'],ha="right",rotation=0,fontsize=12)
    plt.yticks([0,1], ['bkg', 'signal'],ha="right",rotation=0,fontsize=12)
    fmt = '.2f'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            text = plt.text(j, i, format(cm[i, j], fmt),
            ha="center", va="center",
            color="white")
            text.set_path_effects([path_effects.withStroke(linewidth=1.5, foreground='black')])
            
    fig.tight_layout()
    fig.colorbar(im, location = 'right') 

    plt.xlabel('predicted label',fontsize=14)
    plt.ylabel('true label',fontsize=14)

    plt.title(f'{method_name} confusion matrix',fontsize=16)
    plt.show()

# %%
model = best_perceptron
best_perceptron.fit(X_train,Y_train)
Y_pred = model.predict(X_test)

cm = sklearn.metrics.confusion_matrix(Y_test,Y_pred)

# %%
perceptron_cm = normalize_cm(cm)

print('Confusion matrix:')
print(perceptron_cm)
plot_cm(perceptron_cm,method_name='Perceptron')

# %% [markdown]
# In the end we plot the ROC curve obtained and determine the Q value of the best model. We save it in a variable that will be used later as confrontation.

# %%
def plot_roc(fpr,tpr,auc,method_name,color):
    limit = 0.2
    fpr_filtered = fpr[fpr <= limit]
    tpr_filtered = tpr[:len(fpr_filtered)]
    
    auc_thresh = np.trapz(tpr_filtered, fpr_filtered)
    
    idx = np.argmax(fpr > limit) - 1 
    fpr_thresh = fpr[idx]
    tpr_thresh = tpr[idx]
    #print(fpr_thresh,tpr_thresh)
            
    fig = plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {auc:.3f})',c=color)
    #plt.scatter(fpr_thresh,tpr_thresh,c='red')
    plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Diagonal line (random classifier)
    plt.xlim(-0.05,1.05)
    plt.ylim(-0.05,1.05)
    plt.fill_between(fpr[:idx+1], tpr[:idx+1], color=color,alpha=0.2, label= f'Partial ROC (Partial AUC = {auc_thresh:.3f})')
    plt.axvline(x=fpr_thresh, ymin=-0.05, ymax=tpr_thresh-0.02, color='green', linestyle='--', label='FPR = 0.2')
    plt.axhline(y=tpr_thresh, xmin=-0.05, xmax=fpr_thresh+0.025, color='green', linestyle='--')
    
    plt.title(f'{method_name} ROC Curve',fontsize=16)
    plt.xlabel('False Positive Rate (FPR)',fontsize=14)
    plt.ylabel('True Positive Rate (TPR)',fontsize=14)
    plt.xticks(fontsize=11)
    plt.yticks(fontsize=11)
    plt.legend(loc='lower right',fontsize=11)
    plt.grid(True)
    plt.show();

# %%
fig = plt.figure(figsize=(8, 6))

fpr_perceptron = best_fpr
tpr_perceptron = best_tpr

Q_perceptron = perceptron_cm[1][1]/ np.sqrt(perceptron_cm[0][1])
print('Perceptron Q value:',round(Q_perceptron,3))

plot_roc(fpr_perceptron,tpr_perceptron,best_scores[len(best_f)-1],"Perceptron","#4466fc");

# %% [markdown]
# ## Part 5.2: Logistic Regression (version 3)

# %% [markdown]
# Logistic regression allows to pose a classification problem as a regression problem, where the predicted label is the probability for a sample to belong to a certain class. Thus, in our case the output of the algorithm is the *gammaness*. We can then choose a threshold for the *gammaness* to assign gamma (+1) as the predicted label. The learning problem is to find the sigmoid function
# $\sigma_{\mathbf{w}}(\mathbf{x}) =\frac{1}{1 + e^{-(\mathbf{w}^T \mathbf{x})}}$
# that minimizes the loss:
#
# $$
# \mathcal{L}(\mathbf{y}, \sigma_{\mathbf{w}}(\mathbf{x})) + \lambda||\mathbf{w}||^2
# $$
# where:
# $$
# \mathcal{L}(\mathbf{y}, \sigma_{\mathbf{w}}(\mathbf{x})) = -\sum_{i=1}^{n} \left[ y_i \log(\sigma_{\mathbf{w}}(\mathbf{x}_i)) + (1 - y_i) \log(1 - \sigma_{\mathbf{w}}(\mathbf{x}_i)) \right]$$
# and we use the Tikhonov regularization technique to prevent overfitting.
#
# To find the best hyper-parameter $C=\frac{1}{\lambda}$ for model we choose the usual 0.5 threshold for the *gammaness* and perform a K-fold cross validation, where again we keep as best model the one that maximizes the partial AUC.

# %%
# this function determines the partial area under the curve, up to FPR<=0.2
def partial_auc_at_fpr(y_true, y_pred_proba):
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_proba)
    valid_indices = fpr <= 0.2  # indices where FPR <= 0.2
    partial_fpr = fpr[valid_indices]
    partial_tpr = tpr[valid_indices]
    # check if there are at least 2 points for partial AUC calculation
    if len(partial_fpr) < 2:
        return 0  # return 0 if not enough points to calculate AUC

    partial_auc = auc(partial_fpr, partial_tpr)
    return partial_auc

def full_auc_scorer(y_true, y_pred_proba):
    fpr, tpr, _ = roc_curve(y_true, y_pred_proba)
    return auc(fpr, tpr)

# create scoring function (partial AUC) to implement a grid-search
partial_auc_scorer = make_scorer(partial_auc_at_fpr, greater_is_better=True)

# %%
auc_scorer = make_scorer(full_auc_scorer, greater_is_better=True, response_method='predict') 

# hyper-parameters 
param_grid = {'C': [0.001,0.005,0.01,0.05,0.1,0.5,1,5,10,50,100,500,1000]} # we use Tikhonov regularization: in the loss we add a term proportional to the norm squared of w (C=1/lambda)

# grid search with K-fold validation
K=5

fprs = []
tprs = []
aucs = []
partial_aucs = []
C = []
for c in param_grid['C']:
        auc_value=0
        partial_auc=0
        print(f"Training model with regularization constant c = {c}")
        C.append(c)
        for i in range(K):
            train_K, valid_K = split_train_test_set(train_set,K)
            X_train_K, Y_train_K = split_X_Y(train_K)
            X_valid_K, Y_valid_K = split_X_Y(valid_K)
            model= LogisticRegression(penalty='l2',tol=1e-5,C=c,solver='lbfgs',max_iter=int(1e6)) # 'lbfgs' approximates up to the the second derivative of the loss function to optimize the coefficients, best for large datasets 
            model.fit(X_train_K,Y_train_K)
                    
            y_pred_proba = model.predict_proba(X_valid_K)[:, 1]  
            fpr, tpr, _ = roc_curve(Y_valid_K, y_pred_proba)
            fprs.append(fpr)
            tprs.append(tpr)
            auc_value_k = auc(fpr, tpr)
            # keep fpr less than 0.2 (if not able to find it, partial auc is set to zero)
            partial_fpr = fpr[fpr <= 0.2]
            if (len(partial_fpr) < 2 ):
                partial_auc=0
            else:
                partial_tpr = tpr[:len(partial_fpr)]
                partial_auc_k = auc(partial_fpr, partial_tpr)
            partial_auc += partial_auc_k/K
            auc_value += auc_value_k/K
        print('Partial AUC:', partial_auc)
        partial_aucs.append(partial_auc)
        print('AUC:', auc_value,'\n')
        aucs.append(auc_value)

# %%
best_partial_auc = np.max(np.array(partial_aucs))
best_auc= np.max(np.array(aucs))
best_index = np.where(partial_aucs==best_partial_auc)[0]
print('Best model with regularization constant c=',C[best_index[0]])
print('Best partial AUC (validation set):', best_partial_auc)
print('AUC of best model (validation set):', best_auc,'\n')

best_model = LogisticRegression(penalty='l2', C= C[best_index[0]],solver='lbfgs',max_iter=300)
best_model.fit(X_train,Y_train) # retrain the best
y_pred_proba_test = model.predict_proba(X_test)[:, 1]  
fpr_test, tpr_test, _ = roc_curve(Y_test, y_pred_proba_test)
auc_test= auc(fpr_test,tpr_test)

partial_fpr_test = fpr_test[fpr_test <= 0.2]
if (len(partial_fpr_test)<2):
    partial_auc_test=0
else:
    partial_tpr_test = tpr_test[:len(partial_fpr_test)]
    partial_auc_test = auc(partial_fpr_test, partial_tpr_test)
print('Best Partial AUC (test set):', round(partial_auc_test,3))
print('AUC of best model (test set):', round(auc_test,3))

# %%
Y_pred = best_model.predict(X_test)
cm = sklearn.metrics.confusion_matrix(Y_test,Y_pred)
log_cm = normalize_cm(cm)

print('Confusion matrix:')
print(log_cm)
plot_cm(log_cm,method_name='Logistic Regression')

# %% [markdown]
# Here we plot the best model for ROC curve

# %%
fpr_log = fpr_test
tpr_log = tpr_test
Q_log = log_cm[1][1]/ np.sqrt(log_cm[0][1])
print('Q value of best model:',Q_log)

plot_roc(fpr_log,tpr_log,auc_test,'Logistic Regression','#d173b8')

# %% [markdown]
# ## Part 5.3: SVM
# In this part we consider a soft SVM model. The hyperparameters to choose for the model are:
#
# - the Kernel function: linear, polynomial with degree 3, RBF (Radial Basis Function) and sigmoid, which defines the shape of the boundary;
# - the parameter $\nu$, which controls the size of the margin: a lower $\nu$ defines a model with a larger margin;
# - the parameter $\gamma$, which controls how close to the training points the margin bends: low $\gamma$ values define a smooth, almost linear boundary, while high values define a fractal-like boundary.

# %%
alphaCol = data_rescaled_and_indexed['fAlpha'] 
data_rescaled_and_indexed = data_rescaled_and_indexed.drop('fAlpha',axis = 1)
print(np.shape(data_rescaled_and_indexed))

# %%
# list with all possible kernels (poly uses deg = 3 as standard value)
kernels = ['linear','poly','rbf','sigmoid']


# list with all nu values (upper bound on fraction of margin errors)
nus = [ 0.5 , 0.1 , 0.05 , 0.01 ]

# list with all gamma values (by default is 1/(n_features*X.var()) )
gammas = [ 0.1, 0.01, 0.001, 0.0001 ]

best_auc_score = 0

# tolerance for stopping criteria (default is 1e-3) (default max_iter is inf)
tolerance = 1e-6
max_iter = int(2e4)

# K fold definition
K = 5
limit = 0.2 
kf = KFold(n_splits=K, shuffle=True, random_state=42) 
kFoldInfo = 0

start_time = time()


for kernel_type in kernels:
    for nu in nus:
        for gamma in gammas:
            print(f'training SVM with {kernel_type} kernel...')
            partial_auc = 0
            auc_value = 0
            for train_idx, val_idx in kf.split(data_rescaled_and_indexed):  ###gets the index of training and validation set
                
                train_K=data_rescaled_and_indexed.iloc[train_idx]
                valid_K=data_rescaled_and_indexed.iloc[val_idx]
                X_train_K, Y_train_K = split_X_Y(train_K)
                X_valid_K, Y_valid_K = split_X_Y(valid_K)
                
                if kFoldInfo == 0:
                    print("Train fold size:",np.shape(X_train_K),"\t Test fold size:",np.shape(X_valid_K))
                    KFoldInfo = 1
                
                clf = make_pipeline(StandardScaler(), NuSVC(nu=nu,kernel=kernel_type,gamma=gamma,probability=True,tol=tolerance,max_iter=max_iter),verbose=False)
    
                fitted = clf.fit(X_train_K, Y_train_K)
                pred = clf.predict(X_valid_K)
                errors = np.sum(pred != Y_valid_K) / len(Y_valid_K)
                
                pred_prob = clf.predict_proba(X_valid_K)[:, 1]
                fpr, tpr, thresholds = roc_curve(Y_valid_K, pred_prob)
                
                auc_value_k = auc(fpr, tpr)
                fpr_filtered = fpr[fpr <= limit]

                if (len(fpr_filtered) < 2 ):
                    partial_auc=0
                else:
                    tpr_filtered = tpr[:len(fpr_filtered)]
                    partial_auc_k = np.trapz(fpr_filtered, tpr_filtered)
                partial_auc += partial_auc_k/K
                auc_value += auc_value_k/K                 
            if(partial_auc > best_auc_score):
                best_auc_score = partial_auc
                best_model = clf
                best_tpr = tpr
                best_fpr = fpr
                best_auc = auc_value
                best_kernel = kernel_type
                best_nu = nu
                best_gamma = gamma
                print(partial_auc.round(3),best_auc.round(3), kernel_type, nu, gamma)
            print('elapsed time:',round(time()-start_time,3),'s')
            start_time = time()

print('best results are for')
print('kernel:',best_kernel,'nu:',best_nu,'gamma:',best_gamma,'with auc:',best_auc)
# Out:
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 46.334 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 45.968 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 10.452 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 6.942 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 38.009 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 38.192 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 3.065 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 1.531 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# 0.058 0.843 rbf 0.5 0.1
# elapsed time: 191.902 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 203.707 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 220.233 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 221.421 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 96.079 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 81.527 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 75.832 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 79.999 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 82.59 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 65.822 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 59.99 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 65.882 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 75.124 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 53.215 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 47.447 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 47.212 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 301.029 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 264.088 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 212.79 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 172.647 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 69.793 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 63.591 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 76.892 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 35.984 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 36.563 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 30.731 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 56.223 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 21.026 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 9.351 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 7.684 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 29.675 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 3.502 s
# best results are for
# kernel: rbf nu: 0.5 gamma: 0.1 with auc: 0.8425681555779255

# %% [markdown]
# Here we have the confusion matrix

# %%
best_pred = best_model.predict(X_test)
cm = sklearn.metrics.confusion_matrix(Y_test,best_pred)
SVM_cm = normalize_cm(cm)

print('Confusion matrix:')
print(SVM_cm)
plot_cm(SVM_cm,method_name='SVM')

# %% [markdown]
# The best curve is then plotted and saved

# %%
tpr_SVM = best_tpr
fpr_SVM = best_fpr
Q_SVM = get_best_Q(fpr_SVM,tpr_SVM)
Q_SVM = SVM_cm[1][1]/ np.sqrt(SVM_cm[0][1])


print('best SVM Q value:',Q_SVM)

plot_roc(fpr_SVM,tpr_SVM,best_auc,"SVM","darkorange")

# %% [markdown]
# ## Part 5.4: Random Forest
# Here we are going to implement a Random Forest classification algorithm. A Random Forest is composed of different decision tree predictors. For each tree, at each iteration, the data are split into two branches according to a threshold value for one of the features. At each split, the best feature and the best threshold value are chosen by minimizing the entropy function
# 𝐻 given by:
# $$
# \displaystyle H = - \sum_{i=+1,-1} f_i \log_2(f_i)
# $$
# where $f_i$ is the fraction of points of class $i=+1,-1$ in the training set. The splitting continues until either a maximum depth for the tree is reached, in which case the most frequent class of the branch is assigned to all points, or the points of the branch all belong to the same class (in this case the branch is called a leaf). Different trees are built by randomly drawing data with replacement from the test set, applying the algorithm to each tree. The final label for a point is chosen based on a majority vote of the trees results.
#
# The hyperparameters of the model to choose are the ***number of trees*** and the ***maximum depth*** of the trees. Again we implement a K-fold cross validation to choose as best hyperparameters the ones that maximize the partial area under the ROC curve of the classifier. To build the ROC curve we need to estimate the probability for the points to belong to a certain class. This can be done because each tree, at the last decision step, assigns a class label based on the majority class of the training samples that reached that final leaf node, but also keeps track of the proportion of the classes in that leaf node. For example, suppose a test point ends up in a leaf node where, out of 100 training samples that ended up there, 80 belonged to class 1 and 20 belonged to class -1. The *gammaness* of the point would be 0.8, while the probability of it belonging to class -1 would be 0.2.
#
# We will use the class `RandomForestClassifier` from `scikit-learn` to implement and train the Forest and to predict the labels with their probabilities.

# %%
from time import time

num_trees= np.arange(40,300,10)
max_depth= np.arange(10,40,2)
accuracies=[]
roc_areas=[]
best_area=0
best_acc=0
best_model= [] # stores best number of trees and best max depth
partial_aucs = []

start_time = time()

max_iter = len(num_trees) * len(max_depth)
iteration = 0

K = 5
kf = KFold(n_splits=K, shuffle=True, random_state=42) 

for tree in num_trees:
    for depth in max_depth:
        ############accuracies?
        partial_auc = 0
        auc_value = 0
        accuracy = 0
        for i, (train_index, test_index) in enumerate(kf.split(X)):
            print(f"  Fold n. {i}")
            train_K=data_rescaled_and_indexed.iloc[train_idx]
            valid_K = data_rescaled_and_indexed.iloc[test_index]

            X_train_K, Y_train_K = split_X_Y(train_K)
            X_valid_K, Y_valid_K = split_X_Y(valid_K)
            forest = RandomForestClassifier(n_estimators=tree,  # number of trees
                                           max_depth= depth, 
                                           max_features=X_train.shape[1],   # number of features for each split (random subset)
                                           bootstrap=True,    # bagging (sampling with replacement)
                                           max_samples=1.0,   # percentage of samples to use for each tree (100% of data)
                                           random_state=10,
                                           n_jobs=-1)
            # train each model, predict labels and probability of each label
            forest.fit(X_train_K, Y_train_K)
            Y_pred = forest.predict(X_valid_K)
            y_pred_prob = forest.predict_proba(X_valid_K)[:, 1] # probability for the validation points to belong to class +1 or -1
            # accuracy on validation set
            accuracy_k = accuracy_score(Y_valid_K, Y_pred)
            iteration +=1 
            print(f'elapsed time: {round(time()-start_time,2)}s, done {iteration} out of {max_iter*K}')
            print('Number of trees:',tree,', Maximum depth',depth,':') 
            print('Accuracy:',accuracy_k)
            # false positive rates and the true positive rates for different threshold values 
            fpr, tpr, thresholds = roc_curve(Y_valid_K, y_pred_prob)

            # area under the ROC curve on validation set 
            roc_auc_k = auc(fpr, tpr)
            roc_areas.append(roc_auc_k)
            '''if(roc_auc>best_area):
                best_area= roc_auc
                best_acc= accuracy
                best_model=[tree,depth]
                '''
            partial_fpr = fpr[fpr <= 0.2]
            if (len(partial_fpr) < 2 ):
                partial_auc = 0
            else:
                partial_tpr = tpr[:len(partial_fpr)]
                partial_auc_k = auc(partial_fpr, partial_tpr)
            partial_auc += partial_auc_k/K
            auc_value += roc_auc_k/K
        
        partial_aucs.append(partial_auc)
        if(partial_auc>best_area):
            best_area= partial_auc
            best_total_auc = auc_value
            best_acc= accuracy
            best_model=[tree,depth]
        print('\033[91mArea under ROC curve:',round(auc_value,3),'Selected area:',round(partial_auc,3),'\033[0m')
        print('\n')
        
print('Best number of trees:', best_model[0],'\n')
print('Best maximum depth:', best_model[1],'\n')
print('Area under ROC curve of best model:',best_area)
# Out:
# elapsed time: 114.45s, done 62 out of 1950
# Number of trees: 40 , Maximum depth 34 :
# Accuracy: 0.9994742376445847
#   Fold n. 2
# elapsed time: 116.6s, done 63 out of 1950
# Number of trees: 40 , Maximum depth 34 :
# Accuracy: 0.9989484752891693
#   Fold n. 3
# elapsed time: 118.7s, done 64 out of 1950
# Number of trees: 40 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 120.77s, done 65 out of 1950
# Number of trees: 40 , Maximum depth 34 :
# Accuracy: 0.8348672100972916
# Area under ROC curve: 0.976 Selected area: 0.166
#
#
#   Fold n. 0
# elapsed time: 122.8s, done 66 out of 1950
# Number of trees: 40 , Maximum depth 36 :
# Accuracy: 0.9994742376445847
#   Fold n. 1
# elapsed time: 124.91s, done 67 out of 1950
# Number of trees: 40 , Maximum depth 36 :
# Accuracy: 0.9994742376445847
#   Fold n. 2
# elapsed time: 126.99s, done 68 out of 1950
# Number of trees: 40 , Maximum depth 36 :
# Accuracy: 0.9989484752891693
#   Fold n. 3
# elapsed time: 129.02s, done 69 out of 1950
# Number of trees: 40 , Maximum depth 36 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 131.11s, done 70 out of 1950
# Number of trees: 40 , Maximum depth 36 :
# Accuracy: 0.8367078622140416
# Area under ROC curve: 0.976 Selected area: 0.163
#
#
#   Fold n. 0
# elapsed time: 133.13s, done 71 out of 1950
# Number of trees: 40 , Maximum depth 38 :
# Accuracy: 0.9994742376445847
#   Fold n. 1
# elapsed time: 135.19s, done 72 out of 1950
# Number of trees: 40 , Maximum depth 38 :
# Accuracy: 0.9994742376445847
#   Fold n. 2
# elapsed time: 137.28s, done 73 out of 1950
# Number of trees: 40 , Maximum depth 38 :
# Accuracy: 0.9989484752891693
#   Fold n. 3
# elapsed time: 139.38s, done 74 out of 1950
# Number of trees: 40 , Maximum depth 38 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 141.5s, done 75 out of 1950
# Number of trees: 40 , Maximum depth 38 :
# Accuracy: 0.835919011306863
# Area under ROC curve: 0.976 Selected area: 0.164
#
#
#   Fold n. 0
# elapsed time: 143.05s, done 76 out of 1950
# Number of trees: 50 , Maximum depth 10 :
# Accuracy: 0.8551524710830705
#   Fold n. 1
# elapsed time: 144.56s, done 77 out of 1950
# Number of trees: 50 , Maximum depth 10 :
# Accuracy: 0.8533123028391167
#   Fold n. 2
# elapsed time: 146.07s, done 78 out of 1950
# Number of trees: 50 , Maximum depth 10 :
# Accuracy: 0.86198738170347
#   Fold n. 3
# elapsed time: 147.63s, done 79 out of 1950
# Number of trees: 50 , Maximum depth 10 :
# Accuracy: 0.8467402733964248
#   Fold n. 4
# elapsed time: 149.21s, done 80 out of 1950
# Number of trees: 50 , Maximum depth 10 :
# Accuracy: 0.815145937417828
# Area under ROC curve: 0.895 Selected area: 0.112
#
#
#   Fold n. 0
# elapsed time: 150.93s, done 81 out of 1950
# Number of trees: 50 , Maximum depth 12 :
# Accuracy: 0.8830178759200841
#   Fold n. 1
# elapsed time: 152.67s, done 82 out of 1950
# Number of trees: 50 , Maximum depth 12 :
# Accuracy: 0.8759200841219769
#   Fold n. 2
# elapsed time: 154.42s, done 83 out of 1950
# Number of trees: 50 , Maximum depth 12 :
# Accuracy: 0.8835436382754994
#   Fold n. 3
# elapsed time: 156.17s, done 84 out of 1950
# Number of trees: 50 , Maximum depth 12 :
# Accuracy: 0.8785488958990536
#   Fold n. 4
# elapsed time: 157.89s, done 85 out of 1950
# Number of trees: 50 , Maximum depth 12 :
# Accuracy: 0.8261898501183277
# Area under ROC curve: 0.923 Selected area: 0.131
#
#
#   Fold n. 0
# elapsed time: 159.85s, done 86 out of 1950
# Number of trees: 50 , Maximum depth 14 :
# Accuracy: 0.9056256572029443
#   Fold n. 1
# elapsed time: 161.81s, done 87 out of 1950
# Number of trees: 50 , Maximum depth 14 :
# Accuracy: 0.908254468980021
#   Fold n. 2
# elapsed time: 163.73s, done 88 out of 1950
# Number of trees: 50 , Maximum depth 14 :
# Accuracy: 0.9095688748685594
#   Fold n. 3
# elapsed time: 165.63s, done 89 out of 1950
# Number of trees: 50 , Maximum depth 14 :
# Accuracy: 0.9045741324921136
#   Fold n. 4
# elapsed time: 167.62s, done 90 out of 1950
# Number of trees: 50 , Maximum depth 14 :
# Accuracy: 0.8311859058637917
# Area under ROC curve: 0.944 Selected area: 0.149
#
#
#   Fold n. 0
# elapsed time: 169.73s, done 91 out of 1950
# Number of trees: 50 , Maximum depth 16 :
# Accuracy: 0.924553101997897
#   Fold n. 1
# elapsed time: 171.81s, done 92 out of 1950
# Number of trees: 50 , Maximum depth 16 :
# Accuracy: 0.9290220820189274
#   Fold n. 2
# elapsed time: 173.97s, done 93 out of 1950
# Number of trees: 50 , Maximum depth 16 :
# Accuracy: 0.9319137749737119
#   Fold n. 3
# elapsed time: 176.15s, done 94 out of 1950
# Number of trees: 50 , Maximum depth 16 :
# Accuracy: 0.9250788643533123
#   Fold n. 4
# elapsed time: 178.37s, done 95 out of 1950
# Number of trees: 50 , Maximum depth 16 :
# Accuracy: 0.8332895082829346
# Area under ROC curve: 0.958 Selected area: 0.152
#
#
#   Fold n. 0
# elapsed time: 180.69s, done 96 out of 1950
# Number of trees: 50 , Maximum depth 18 :
# Accuracy: 0.9421661409043113
#   Fold n. 1
# elapsed time: 182.93s, done 97 out of 1950
# Number of trees: 50 , Maximum depth 18 :
# Accuracy: 0.9453207150368034
#   Fold n. 2
# elapsed time: 185.22s, done 98 out of 1950
# Number of trees: 50 , Maximum depth 18 :
# Accuracy: 0.9471608832807571
#   Fold n. 3
# elapsed time: 187.5s, done 99 out of 1950
# Number of trees: 50 , Maximum depth 18 :
# Accuracy: 0.943217665615142
#   Fold n. 4
# elapsed time: 189.8s, done 100 out of 1950
# Number of trees: 50 , Maximum depth 18 :
# Accuracy: 0.8351301603996845
# Area under ROC curve: 0.967 Selected area: 0.145
#
#
#   Fold n. 0
# elapsed time: 192.15s, done 101 out of 1950
# Number of trees: 50 , Maximum depth 20 :
# Accuracy: 0.9582018927444795
#   Fold n. 1
# elapsed time: 194.5s, done 102 out of 1950
# Number of trees: 50 , Maximum depth 20 :
# Accuracy: 0.9584647739221872
#   Fold n. 2
# elapsed time: 196.87s, done 103 out of 1950
# Number of trees: 50 , Maximum depth 20 :
# Accuracy: 0.9639852786540484
#   Fold n. 3
# elapsed time: 199.24s, done 104 out of 1950
# Number of trees: 50 , Maximum depth 20 :
# Accuracy: 0.9584647739221872
#   Fold n. 4
# elapsed time: 201.6s, done 105 out of 1950
# Number of trees: 50 , Maximum depth 20 :
# Accuracy: 0.8351301603996845
# Area under ROC curve: 0.972 Selected area: 0.124
#
#
#   Fold n. 0
# elapsed time: 204.02s, done 106 out of 1950
# Number of trees: 50 , Maximum depth 22 :
# Accuracy: 0.9692429022082019
#   Fold n. 1
# elapsed time: 206.46s, done 107 out of 1950
# Number of trees: 50 , Maximum depth 22 :
# Accuracy: 0.9708201892744479
#   Fold n. 2
# elapsed time: 208.9s, done 108 out of 1950
# Number of trees: 50 , Maximum depth 22 :
# Accuracy: 0.9747634069400631
#   Fold n. 3
# elapsed time: 211.34s, done 109 out of 1950
# Number of trees: 50 , Maximum depth 22 :
# Accuracy: 0.9681913774973712
#   Fold n. 4
# elapsed time: 213.84s, done 110 out of 1950
# Number of trees: 50 , Maximum depth 22 :
# Accuracy: 0.8361819616092558
# Area under ROC curve: 0.975 Selected area: 0.172
#
#
#   Fold n. 0
# elapsed time: 216.34s, done 111 out of 1950
# Number of trees: 50 , Maximum depth 24 :
# Accuracy: 0.9818611987381703
#   Fold n. 1
# elapsed time: 218.86s, done 112 out of 1950
# Number of trees: 50 , Maximum depth 24 :
# Accuracy: 0.9826498422712934
#   Fold n. 2
# elapsed time: 221.4s, done 113 out of 1950
# Number of trees: 50 , Maximum depth 24 :
# Accuracy: 0.9850157728706624
#   Fold n. 3
# elapsed time: 223.92s, done 114 out of 1950
# Number of trees: 50 , Maximum depth 24 :
# Accuracy: 0.9800210304942166
#   Fold n. 4
# elapsed time: 226.42s, done 115 out of 1950
# Number of trees: 50 , Maximum depth 24 :
# Accuracy: 0.8374967131212201
# Area under ROC curve: 0.975 Selected area: 0.174
#
#
#   Fold n. 0
# elapsed time: 229.05s, done 116 out of 1950
# Number of trees: 50 , Maximum depth 26 :
# Accuracy: 0.9897476340694006
#   Fold n. 1
# elapsed time: 231.63s, done 117 out of 1950
# Number of trees: 50 , Maximum depth 26 :
# Accuracy: 0.9879074658254469
#   Fold n. 2
# elapsed time: 234.18s, done 118 out of 1950
# Number of trees: 50 , Maximum depth 26 :
# Accuracy: 0.9918506834910621
#   Fold n. 3
# elapsed time: 236.76s, done 119 out of 1950
# Number of trees: 50 , Maximum depth 26 :
# Accuracy: 0.9892218717139852
#   Fold n. 4
# elapsed time: 239.39s, done 120 out of 1950
# Number of trees: 50 , Maximum depth 26 :
# Accuracy: 0.8353931107020773
# Area under ROC curve: 0.976 Selected area: 0.176
#
#
#   Fold n. 0
# elapsed time: 241.96s, done 121 out of 1950
# Number of trees: 50 , Maximum depth 28 :
# Accuracy: 0.9944794952681388
#   Fold n. 1
# elapsed time: 244.54s, done 122 out of 1950
# Number of trees: 50 , Maximum depth 28 :
# Accuracy: 0.9926393270241851
#   Fold n. 2
# elapsed time: 247.13s, done 123 out of 1950
# Number of trees: 50 , Maximum depth 28 :
# Accuracy: 0.9971083070452156
#   Fold n. 3
# elapsed time: 249.75s, done 124 out of 1950
# Number of trees: 50 , Maximum depth 28 :
# Accuracy: 0.9957939011566772
#   Fold n. 4
# elapsed time: 252.38s, done 125 out of 1950
# Number of trees: 50 , Maximum depth 28 :
# Accuracy: 0.8409150670523271
# Area under ROC curve: 0.976 Selected area: 0.177
#
#
#   Fold n. 0
# elapsed time: 255.14s, done 126 out of 1950
# Number of trees: 50 , Maximum depth 30 :
# Accuracy: 0.9971083070452156
#   Fold n. 1
# elapsed time: 257.72s, done 127 out of 1950
# Number of trees: 50 , Maximum depth 30 :
# Accuracy: 0.9965825446898002
#   Fold n. 2
# elapsed time: 260.31s, done 128 out of 1950
# Number of trees: 50 , Maximum depth 30 :
# Accuracy: 0.9986855941114616
#   Fold n. 3
# elapsed time: 262.97s, done 129 out of 1950
# Number of trees: 50 , Maximum depth 30 :
# Accuracy: 0.9989484752891693
#   Fold n. 4
# elapsed time: 265.59s, done 130 out of 1950
# Number of trees: 50 , Maximum depth 30 :
# Accuracy: 0.8361819616092558
# Area under ROC curve: 0.976 Selected area: 0.174
#
#
#   Fold n. 0
# elapsed time: 268.19s, done 131 out of 1950
# Number of trees: 50 , Maximum depth 32 :
# Accuracy: 0.9989484752891693
#   Fold n. 1
# elapsed time: 270.79s, done 132 out of 1950
# Number of trees: 50 , Maximum depth 32 :
# Accuracy: 0.9989484752891693
#   Fold n. 2
# elapsed time: 273.41s, done 133 out of 1950
# Number of trees: 50 , Maximum depth 32 :
# Accuracy: 0.9994742376445847
#   Fold n. 3
# elapsed time: 276.01s, done 134 out of 1950
# Number of trees: 50 , Maximum depth 32 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 278.62s, done 135 out of 1950
# Number of trees: 50 , Maximum depth 32 :
# Accuracy: 0.8390744149355772
# Area under ROC curve: 0.976 Selected area: 0.178
#
#
#   Fold n. 0
# elapsed time: 281.24s, done 136 out of 1950
# Number of trees: 50 , Maximum depth 34 :
# Accuracy: 0.9997371188222923
#   Fold n. 1
# elapsed time: 283.84s, done 137 out of 1950
# Number of trees: 50 , Maximum depth 34 :
# Accuracy: 0.9997371188222923
#   Fold n. 2
# elapsed time: 286.48s, done 138 out of 1950
# Number of trees: 50 , Maximum depth 34 :
# Accuracy: 0.9994742376445847
#   Fold n. 3
# elapsed time: 289.17s, done 139 out of 1950
# Number of trees: 50 , Maximum depth 34 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 291.81s, done 140 out of 1950
# Number of trees: 50 , Maximum depth 34 :
# Accuracy: 0.8356560610044702
# Area under ROC curve: 0.976 Selected area: 0.177
#
#
#   Fold n. 0
# elapsed time: 294.41s, done 141 out of 1950
# Number of trees: 50 , Maximum depth 36 :
# Accuracy: 0.9997371188222923
#   Fold n. 1
# elapsed time: 297.01s, done 142 out of 1950
# Number of trees: 50 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 299.66s, done 143 out of 1950
# Number of trees: 50 , Maximum depth 36 :
# Accuracy: 0.9997371188222923
#   Fold n. 3
# elapsed time: 302.26s, done 144 out of 1950
# Number of trees: 50 , Maximum depth 36 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 304.92s, done 145 out of 1950
# Number of trees: 50 , Maximum depth 36 :
# Accuracy: 0.8385485143307915
# Area under ROC curve: 0.976 Selected area: 0.168
#
#
#   Fold n. 0
# elapsed time: 307.58s, done 146 out of 1950
# Number of trees: 50 , Maximum depth 38 :
# Accuracy: 0.9997371188222923
#   Fold n. 1
# elapsed time: 310.24s, done 147 out of 1950
# Number of trees: 50 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 312.9s, done 148 out of 1950
# Number of trees: 50 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 315.56s, done 149 out of 1950
# Number of trees: 50 , Maximum depth 38 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 318.2s, done 150 out of 1950
# Number of trees: 50 , Maximum depth 38 :
# Accuracy: 0.8369708125164343
# Area under ROC curve: 0.976 Selected area: 0.175
#
#
#   Fold n. 0
# elapsed time: 320.01s, done 151 out of 1950
# Number of trees: 60 , Maximum depth 10 :
# Accuracy: 0.8564668769716088
#   Fold n. 1
# elapsed time: 321.82s, done 152 out of 1950
# Number of trees: 60 , Maximum depth 10 :
# Accuracy: 0.8530494216614091
#   Fold n. 2
# elapsed time: 323.61s, done 153 out of 1950
# Number of trees: 60 , Maximum depth 10 :
# Accuracy: 0.8606729758149316
#   Fold n. 3
# elapsed time: 325.44s, done 154 out of 1950
# Number of trees: 60 , Maximum depth 10 :
# Accuracy: 0.8464773922187171
#   Fold n. 4
# elapsed time: 327.28s, done 155 out of 1950
# Number of trees: 60 , Maximum depth 10 :
# Accuracy: 0.8148829871154352
# Area under ROC curve: 0.895 Selected area: 0.112
#
#
#   Fold n. 0
# elapsed time: 329.33s, done 156 out of 1950
# Number of trees: 60 , Maximum depth 12 :
# Accuracy: 0.8803890641430073
#   Fold n. 1
# elapsed time: 331.4s, done 157 out of 1950
# Number of trees: 60 , Maximum depth 12 :
# Accuracy: 0.8751314405888538
#   Fold n. 2
# elapsed time: 333.48s, done 158 out of 1950
# Number of trees: 60 , Maximum depth 12 :
# Accuracy: 0.8838065194532071
#   Fold n. 3
# elapsed time: 335.56s, done 159 out of 1950
# Number of trees: 60 , Maximum depth 12 :
# Accuracy: 0.879074658254469
#   Fold n. 4
# elapsed time: 337.64s, done 160 out of 1950
# Number of trees: 60 , Maximum depth 12 :
# Accuracy: 0.8254009992111491
# Area under ROC curve: 0.923 Selected area: 0.131
#
#
#   Fold n. 0
# elapsed time: 339.92s, done 161 out of 1950
# Number of trees: 60 , Maximum depth 14 :
# Accuracy: 0.9045741324921136
#   Fold n. 1
# elapsed time: 342.24s, done 162 out of 1950
# Number of trees: 60 , Maximum depth 14 :
# Accuracy: 0.908254468980021
#   Fold n. 2
# elapsed time: 344.51s, done 163 out of 1950
# Number of trees: 60 , Maximum depth 14 :
# Accuracy: 0.9095688748685594
#   Fold n. 3
# elapsed time: 346.82s, done 164 out of 1950
# Number of trees: 60 , Maximum depth 14 :
# Accuracy: 0.9035226077812829
#   Fold n. 4
# elapsed time: 349.14s, done 165 out of 1950
# Number of trees: 60 , Maximum depth 14 :
# Accuracy: 0.8285564028398633
# Area under ROC curve: 0.944 Selected area: 0.15
#
#
#   Fold n. 0
# elapsed time: 351.61s, done 166 out of 1950
# Number of trees: 60 , Maximum depth 16 :
# Accuracy: 0.9242902208201893
#   Fold n. 1
# elapsed time: 354.15s, done 167 out of 1950
# Number of trees: 60 , Maximum depth 16 :
# Accuracy: 0.9305993690851735
#   Fold n. 2
# elapsed time: 356.63s, done 168 out of 1950
# Number of trees: 60 , Maximum depth 16 :
# Accuracy: 0.9311251314405888
#   Fold n. 3
# elapsed time: 359.21s, done 169 out of 1950
# Number of trees: 60 , Maximum depth 16 :
# Accuracy: 0.9250788643533123
#   Fold n. 4
# elapsed time: 361.65s, done 170 out of 1950
# Number of trees: 60 , Maximum depth 16 :
# Accuracy: 0.8303970549566132
# Area under ROC curve: 0.959 Selected area: 0.158
#
#
#   Fold n. 0
# elapsed time: 364.28s, done 171 out of 1950
# Number of trees: 60 , Maximum depth 18 :
# Accuracy: 0.9429547844374343
#   Fold n. 1
# elapsed time: 366.96s, done 172 out of 1950
# Number of trees: 60 , Maximum depth 18 :
# Accuracy: 0.944794952681388
#   Fold n. 2
# elapsed time: 369.62s, done 173 out of 1950
# Number of trees: 60 , Maximum depth 18 :
# Accuracy: 0.9463722397476341
#   Fold n. 3
# elapsed time: 372.34s, done 174 out of 1950
# Number of trees: 60 , Maximum depth 18 :
# Accuracy: 0.943217665615142
#   Fold n. 4
# elapsed time: 375.05s, done 175 out of 1950
# Number of trees: 60 , Maximum depth 18 :
# Accuracy: 0.8385485143307915
# Area under ROC curve: 0.968 Selected area: 0.15
#
#
#   Fold n. 0
# elapsed time: 377.83s, done 176 out of 1950
# Number of trees: 60 , Maximum depth 20 :
# Accuracy: 0.9582018927444795
#   Fold n. 1
# elapsed time: 380.62s, done 177 out of 1950
# Number of trees: 60 , Maximum depth 20 :
# Accuracy: 0.9582018927444795
#   Fold n. 2
# elapsed time: 383.39s, done 178 out of 1950
# Number of trees: 60 , Maximum depth 20 :
# Accuracy: 0.9624079915878023
#   Fold n. 3
# elapsed time: 386.18s, done 179 out of 1950
# Number of trees: 60 , Maximum depth 20 :
# Accuracy: 0.9579390115667719
#   Fold n. 4
# elapsed time: 388.95s, done 180 out of 1950
# Number of trees: 60 , Maximum depth 20 :
# Accuracy: 0.8353931107020773
# Area under ROC curve: 0.973 Selected area: 0.133
#
#
#   Fold n. 0
# elapsed time: 391.8s, done 181 out of 1950
# Number of trees: 60 , Maximum depth 22 :
# Accuracy: 0.9697686645636172
#   Fold n. 1
# elapsed time: 394.7s, done 182 out of 1950
# Number of trees: 60 , Maximum depth 22 :
# Accuracy: 0.9713459516298633
#   Fold n. 2
# elapsed time: 397.57s, done 183 out of 1950
# Number of trees: 60 , Maximum depth 22 :
# Accuracy: 0.9742376445846478
#   Fold n. 3
# elapsed time: 400.51s, done 184 out of 1950
# Number of trees: 60 , Maximum depth 22 :
# Accuracy: 0.9687171398527865
#   Fold n. 4
# elapsed time: 403.54s, done 185 out of 1950
# Number of trees: 60 , Maximum depth 22 :
# Accuracy: 0.834341309492506
# Area under ROC curve: 0.975 Selected area: 0.166
#
#
#   Fold n. 0
# elapsed time: 406.52s, done 186 out of 1950
# Number of trees: 60 , Maximum depth 24 :
# Accuracy: 0.9810725552050473
#   Fold n. 1
# elapsed time: 409.48s, done 187 out of 1950
# Number of trees: 60 , Maximum depth 24 :
# Accuracy: 0.981335436382755
#   Fold n. 2
# elapsed time: 412.41s, done 188 out of 1950
# Number of trees: 60 , Maximum depth 24 :
# Accuracy: 0.9852786540483701
#   Fold n. 3
# elapsed time: 415.39s, done 189 out of 1950
# Number of trees: 60 , Maximum depth 24 :
# Accuracy: 0.980546792849632
#   Fold n. 4
# elapsed time: 418.36s, done 190 out of 1950
# Number of trees: 60 , Maximum depth 24 :
# Accuracy: 0.8369708125164343
# Area under ROC curve: 0.976 Selected area: 0.177
#
#
#   Fold n. 0
# elapsed time: 421.37s, done 191 out of 1950
# Number of trees: 60 , Maximum depth 26 :
# Accuracy: 0.9886961093585699
#   Fold n. 1
# elapsed time: 424.43s, done 192 out of 1950
# Number of trees: 60 , Maximum depth 26 :
# Accuracy: 0.9884332281808622
#   Fold n. 2
# elapsed time: 427.42s, done 193 out of 1950
# Number of trees: 60 , Maximum depth 26 :
# Accuracy: 0.9915878023133544
#   Fold n. 3
# elapsed time: 430.52s, done 194 out of 1950
# Number of trees: 60 , Maximum depth 26 :
# Accuracy: 0.9889589905362776
#   Fold n. 4
# elapsed time: 433.57s, done 195 out of 1950
# Number of trees: 60 , Maximum depth 26 :
# Accuracy: 0.8348672100972916
# Area under ROC curve: 0.976 Selected area: 0.178
#
#
#   Fold n. 0
# elapsed time: 436.66s, done 196 out of 1950
# Number of trees: 60 , Maximum depth 28 :
# Accuracy: 0.9947423764458465
#   Fold n. 1
# elapsed time: 439.73s, done 197 out of 1950
# Number of trees: 60 , Maximum depth 28 :
# Accuracy: 0.9926393270241851
#   Fold n. 2
# elapsed time: 442.78s, done 198 out of 1950
# Number of trees: 60 , Maximum depth 28 :
# Accuracy: 0.9973711882229233
#   Fold n. 3
# elapsed time: 445.85s, done 199 out of 1950
# Number of trees: 60 , Maximum depth 28 :
# Accuracy: 0.9952681388012619
#   Fold n. 4
# elapsed time: 448.87s, done 200 out of 1950
# Number of trees: 60 , Maximum depth 28 :
# Accuracy: 0.8403891664475415
# Area under ROC curve: 0.976 Selected area: 0.173
#
#
#   Fold n. 0
# elapsed time: 451.97s, done 201 out of 1950
# Number of trees: 60 , Maximum depth 30 :
# Accuracy: 0.9971083070452156
#   Fold n. 1
# elapsed time: 455.06s, done 202 out of 1950
# Number of trees: 60 , Maximum depth 30 :
# Accuracy: 0.9973711882229233
#   Fold n. 2
# elapsed time: 458.14s, done 203 out of 1950
# Number of trees: 60 , Maximum depth 30 :
# Accuracy: 0.999211356466877
#   Fold n. 3
# elapsed time: 461.2s, done 204 out of 1950
# Number of trees: 60 , Maximum depth 30 :
# Accuracy: 0.998422712933754
#   Fold n. 4
# elapsed time: 464.35s, done 205 out of 1950
# Number of trees: 60 , Maximum depth 30 :
# Accuracy: 0.8356560610044702
# Area under ROC curve: 0.976 Selected area: 0.175
#
#
#   Fold n. 0
# elapsed time: 467.44s, done 206 out of 1950
# Number of trees: 60 , Maximum depth 32 :
# Accuracy: 0.9994742376445847
#   Fold n. 1
# elapsed time: 470.59s, done 207 out of 1950
# Number of trees: 60 , Maximum depth 32 :
# Accuracy: 0.9989484752891693
#   Fold n. 2
# elapsed time: 473.7s, done 208 out of 1950
# Number of trees: 60 , Maximum depth 32 :
# Accuracy: 0.9997371188222923
#   Fold n. 3
# elapsed time: 476.8s, done 209 out of 1950
# Number of trees: 60 , Maximum depth 32 :
# Accuracy: 0.9994742376445847
#   Fold n. 4
# elapsed time: 480.0s, done 210 out of 1950
# Number of trees: 60 , Maximum depth 32 :
# Accuracy: 0.8396003155403629
# Area under ROC curve: 0.976 Selected area: 0.174
#
#
#   Fold n. 0
# elapsed time: 483.13s, done 211 out of 1950
# Number of trees: 60 , Maximum depth 34 :
# Accuracy: 0.9997371188222923
#   Fold n. 1
# elapsed time: 486.23s, done 212 out of 1950
# Number of trees: 60 , Maximum depth 34 :
# Accuracy: 0.9994742376445847
#   Fold n. 2
# elapsed time: 489.37s, done 213 out of 1950
# Number of trees: 60 , Maximum depth 34 :
# Accuracy: 0.9997371188222923
#   Fold n. 3
# elapsed time: 492.55s, done 214 out of 1950
# Number of trees: 60 , Maximum depth 34 :
# Accuracy: 0.9994742376445847
#   Fold n. 4
# elapsed time: 495.68s, done 215 out of 1950
# Number of trees: 60 , Maximum depth 34 :
# Accuracy: 0.835919011306863
# Area under ROC curve: 0.976 Selected area: 0.17
#
#
#   Fold n. 0
# elapsed time: 498.76s, done 216 out of 1950
# Number of trees: 60 , Maximum depth 36 :
# Accuracy: 0.9997371188222923
#   Fold n. 1
# elapsed time: 501.84s, done 217 out of 1950
# Number of trees: 60 , Maximum depth 36 :
# Accuracy: 0.9997371188222923
#   Fold n. 2
# elapsed time: 504.95s, done 218 out of 1950
# Number of trees: 60 , Maximum depth 36 :
# Accuracy: 0.9997371188222923
#   Fold n. 3
# elapsed time: 508.05s, done 219 out of 1950
# Number of trees: 60 , Maximum depth 36 :
# Accuracy: 0.9994742376445847
#   Fold n. 4
# elapsed time: 511.22s, done 220 out of 1950
# Number of trees: 60 , Maximum depth 36 :
# Accuracy: 0.837759663423613
# Area under ROC curve: 0.976 Selected area: 0.167
#
#
#   Fold n. 0
# elapsed time: 514.31s, done 221 out of 1950
# Number of trees: 60 , Maximum depth 38 :
# Accuracy: 0.9997371188222923
#   Fold n. 1
# elapsed time: 517.47s, done 222 out of 1950
# Number of trees: 60 , Maximum depth 38 :
# Accuracy: 0.9997371188222923
#   Fold n. 2
# elapsed time: 520.69s, done 223 out of 1950
# Number of trees: 60 , Maximum depth 38 :
# Accuracy: 0.9997371188222923
#   Fold n. 3
# elapsed time: 523.81s, done 224 out of 1950
# Number of trees: 60 , Maximum depth 38 :
# Accuracy: 0.9994742376445847
#   Fold n. 4
# elapsed time: 526.88s, done 225 out of 1950
# Number of trees: 60 , Maximum depth 38 :
# Accuracy: 0.8367078622140416
# Area under ROC curve: 0.976 Selected area: 0.166
#
#
#   Fold n. 0
# elapsed time: 528.98s, done 226 out of 1950
# Number of trees: 70 , Maximum depth 10 :
# Accuracy: 0.8583070452155626
#   Fold n. 1
# elapsed time: 531.03s, done 227 out of 1950
# Number of trees: 70 , Maximum depth 10 :
# Accuracy: 0.852260778128286
#   Fold n. 2
# elapsed time: 533.1s, done 228 out of 1950
# Number of trees: 70 , Maximum depth 10 :
# Accuracy: 0.8643533123028391
#   Fold n. 3
# elapsed time: 535.19s, done 229 out of 1950
# Number of trees: 70 , Maximum depth 10 :
# Accuracy: 0.8480546792849631
#   Fold n. 4
# elapsed time: 537.24s, done 230 out of 1950
# Number of trees: 70 , Maximum depth 10 :
# Accuracy: 0.8159347883250065
# Area under ROC curve: 0.897 Selected area: 0.113
#
#
#   Fold n. 0
# elapsed time: 539.7s, done 231 out of 1950
# Number of trees: 70 , Maximum depth 12 :
# Accuracy: 0.8827549947423764
#   Fold n. 1
# elapsed time: 542.08s, done 232 out of 1950
# Number of trees: 70 , Maximum depth 12 :
# Accuracy: 0.8769716088328076
#   Fold n. 2
# elapsed time: 544.49s, done 233 out of 1950
# Number of trees: 70 , Maximum depth 12 :
# Accuracy: 0.8848580441640379
#   Fold n. 3
# elapsed time: 546.89s, done 234 out of 1950
# Number of trees: 70 , Maximum depth 12 :
# Accuracy: 0.879074658254469
#   Fold n. 4
# elapsed time: 549.24s, done 235 out of 1950
# Number of trees: 70 , Maximum depth 12 :
# Accuracy: 0.8264528004207204
# Area under ROC curve: 0.924 Selected area: 0.132
#
#
#   Fold n. 0
# elapsed time: 551.86s, done 236 out of 1950
# Number of trees: 70 , Maximum depth 14 :
# Accuracy: 0.9053627760252366
#   Fold n. 1
# elapsed time: 554.51s, done 237 out of 1950
# Number of trees: 70 , Maximum depth 14 :
# Accuracy: 0.9079915878023134
#   Fold n. 2
# elapsed time: 557.15s, done 238 out of 1950
# Number of trees: 70 , Maximum depth 14 :
# Accuracy: 0.9098317560462671
#   Fold n. 3
# elapsed time: 559.76s, done 239 out of 1950
# Number of trees: 70 , Maximum depth 14 :
# Accuracy: 0.9037854889589906
#   Fold n. 4
# elapsed time: 562.44s, done 240 out of 1950
# Number of trees: 70 , Maximum depth 14 :
# Accuracy: 0.8301341046542203
# Area under ROC curve: 0.945 Selected area: 0.15
#
#
#   Fold n. 0
# elapsed time: 565.29s, done 241 out of 1950
# Number of trees: 70 , Maximum depth 16 :
# Accuracy: 0.9256046267087277
#   Fold n. 1
# elapsed time: 568.17s, done 242 out of 1950
# Number of trees: 70 , Maximum depth 16 :
# Accuracy: 0.9282334384858044
#   Fold n. 2
# elapsed time: 571.03s, done 243 out of 1950
# Number of trees: 70 , Maximum depth 16 :
# Accuracy: 0.9295478443743428
#   Fold n. 3
# elapsed time: 573.93s, done 244 out of 1950
# Number of trees: 70 , Maximum depth 16 :
# Accuracy: 0.92534174553102
#   Fold n. 4
# elapsed time: 576.77s, done 245 out of 1950
# Number of trees: 70 , Maximum depth 16 :
# Accuracy: 0.8317118064685775
# Area under ROC curve: 0.959 Selected area: 0.157
#
#
#   Fold n. 0
# elapsed time: 579.89s, done 246 out of 1950
# Number of trees: 70 , Maximum depth 18 :
# Accuracy: 0.9413774973711883
#   Fold n. 1
# elapsed time: 582.94s, done 247 out of 1950
# Number of trees: 70 , Maximum depth 18 :
# Accuracy: 0.9463722397476341
#   Fold n. 2
# elapsed time: 586.0s, done 248 out of 1950
# Number of trees: 70 , Maximum depth 18 :
# Accuracy: 0.9471608832807571
#   Fold n. 3
# elapsed time: 589.1s, done 249 out of 1950
# Number of trees: 70 , Maximum depth 18 :
# Accuracy: 0.9434805467928497
#   Fold n. 4
# elapsed time: 592.12s, done 250 out of 1950
# Number of trees: 70 , Maximum depth 18 :
# Accuracy: 0.8353931107020773
# Area under ROC curve: 0.968 Selected area: 0.141
#
#
#   Fold n. 0
# elapsed time: 595.3s, done 251 out of 1950
# Number of trees: 70 , Maximum depth 20 :
# Accuracy: 0.9579390115667719
#   Fold n. 1
# elapsed time: 598.5s, done 252 out of 1950
# Number of trees: 70 , Maximum depth 20 :
# Accuracy: 0.9571503680336488
#   Fold n. 2
# elapsed time: 601.72s, done 253 out of 1950
# Number of trees: 70 , Maximum depth 20 :
# Accuracy: 0.964248159831756
#   Fold n. 3
# elapsed time: 604.91s, done 254 out of 1950
# Number of trees: 70 , Maximum depth 20 :
# Accuracy: 0.9576761303890642
#   Fold n. 4
# elapsed time: 608.13s, done 255 out of 1950
# Number of trees: 70 , Maximum depth 20 :
# Accuracy: 0.8364449119116487
# Area under ROC curve: 0.973 Selected area: 0.115
#
#
#   Fold n. 0
# elapsed time: 611.46s, done 256 out of 1950
# Number of trees: 70 , Maximum depth 22 :
# Accuracy: 0.9697686645636172
#   Fold n. 1
# elapsed time: 614.83s, done 257 out of 1950
# Number of trees: 70 , Maximum depth 22 :
# Accuracy: 0.9718717139852786
#   Fold n. 2
# elapsed time: 618.17s, done 258 out of 1950
# Number of trees: 70 , Maximum depth 22 :
# Accuracy: 0.9750262881177708
#   Fold n. 3
# elapsed time: 621.56s, done 259 out of 1950
# Number of trees: 70 , Maximum depth 22 :
# Accuracy: 0.9689800210304942
#   Fold n. 4
# elapsed time: 624.92s, done 260 out of 1950
# Number of trees: 70 , Maximum depth 22 :
# Accuracy: 0.835919011306863
# Area under ROC curve: 0.975 Selected area: 0.167
#
#
#   Fold n. 0
# elapsed time: 628.32s, done 261 out of 1950
# Number of trees: 70 , Maximum depth 24 :
# Accuracy: 0.9810725552050473
#   Fold n. 1
# elapsed time: 631.73s, done 262 out of 1950
# Number of trees: 70 , Maximum depth 24 :
# Accuracy: 0.981335436382755
#   Fold n. 2
# elapsed time: 635.14s, done 263 out of 1950
# Number of trees: 70 , Maximum depth 24 :
# Accuracy: 0.9855415352260778
#   Fold n. 3
# elapsed time: 638.54s, done 264 out of 1950
# Number of trees: 70 , Maximum depth 24 :
# Accuracy: 0.9789695057833859
#   Fold n. 4
# elapsed time: 641.94s, done 265 out of 1950
# Number of trees: 70 , Maximum depth 24 :
# Accuracy: 0.8367078622140416
# Area under ROC curve: 0.976 Selected area: 0.176
#
#
#   Fold n. 0
# elapsed time: 645.5s, done 266 out of 1950
# Number of trees: 70 , Maximum depth 26 :
# Accuracy: 0.9892218717139852
#   Fold n. 1
# elapsed time: 648.98s, done 267 out of 1950
# Number of trees: 70 , Maximum depth 26 :
# Accuracy: 0.9884332281808622
#   Fold n. 2
# elapsed time: 652.41s, done 268 out of 1950
# Number of trees: 70 , Maximum depth 26 :
# Accuracy: 0.9931650893796005
#   Fold n. 3
# elapsed time: 655.9s, done 269 out of 1950
# Number of trees: 70 , Maximum depth 26 :
# Accuracy: 0.9886961093585699
#   Fold n. 4
# elapsed time: 659.41s, done 270 out of 1950
# Number of trees: 70 , Maximum depth 26 :
# Accuracy: 0.8364449119116487
# Area under ROC curve: 0.976 Selected area: 0.177
#
#
#   Fold n. 0
# elapsed time: 662.91s, done 271 out of 1950
# Number of trees: 70 , Maximum depth 28 :
# Accuracy: 0.9952681388012619
#   Fold n. 1
# elapsed time: 666.4s, done 272 out of 1950
# Number of trees: 70 , Maximum depth 28 :
# Accuracy: 0.9934279705573081
#   Fold n. 2
# elapsed time: 669.99s, done 273 out of 1950
# Number of trees: 70 , Maximum depth 28 :
# Accuracy: 0.9981598317560463
#   Fold n. 3
# elapsed time: 673.45s, done 274 out of 1950
# Number of trees: 70 , Maximum depth 28 :
# Accuracy: 0.9963196635120926
#   Fold n. 4
# elapsed time: 676.94s, done 275 out of 1950
# Number of trees: 70 , Maximum depth 28 :
# Accuracy: 0.8382855640283986
# Area under ROC curve: 0.976 Selected area: 0.176
#
#
#   Fold n. 0
# elapsed time: 680.49s, done 276 out of 1950
# Number of trees: 70 , Maximum depth 30 :
# Accuracy: 0.998422712933754
#   Fold n. 1
# elapsed time: 684.01s, done 277 out of 1950
# Number of trees: 70 , Maximum depth 30 :
# Accuracy: 0.9976340694006309
#   Fold n. 2
# elapsed time: 687.63s, done 278 out of 1950
# Number of trees: 70 , Maximum depth 30 :
# Accuracy: 0.9989484752891693
#   Fold n. 3
# elapsed time: 691.2s, done 279 out of 1950
# Number of trees: 70 , Maximum depth 30 :
# Accuracy: 0.9986855941114616
#   Fold n. 4
# elapsed time: 694.75s, done 280 out of 1950
# Number of trees: 70 , Maximum depth 30 :
# Accuracy: 0.8374967131212201
# Area under ROC curve: 0.976 Selected area: 0.176
#
#
#   Fold n. 0
# elapsed time: 698.26s, done 281 out of 1950
# Number of trees: 70 , Maximum depth 32 :
# Accuracy: 0.9997371188222923
#   Fold n. 1
# elapsed time: 701.93s, done 282 out of 1950
# Number of trees: 70 , Maximum depth 32 :
# Accuracy: 0.9994742376445847
#   Fold n. 2
# elapsed time: 705.44s, done 283 out of 1950
# Number of trees: 70 , Maximum depth 32 :
# Accuracy: 0.9994742376445847
#   Fold n. 3
# elapsed time: 709.06s, done 284 out of 1950
# Number of trees: 70 , Maximum depth 32 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 712.64s, done 285 out of 1950
# Number of trees: 70 , Maximum depth 32 :
# Accuracy: 0.8380226137260058
# Area under ROC curve: 0.976 Selected area: 0.175
#
#
#   Fold n. 0
# elapsed time: 716.16s, done 286 out of 1950
# Number of trees: 70 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 719.76s, done 287 out of 1950
# Number of trees: 70 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 723.39s, done 288 out of 1950
# Number of trees: 70 , Maximum depth 34 :
# Accuracy: 0.9994742376445847
#   Fold n. 3
# elapsed time: 726.94s, done 289 out of 1950
# Number of trees: 70 , Maximum depth 34 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 730.47s, done 290 out of 1950
# Number of trees: 70 , Maximum depth 34 :
# Accuracy: 0.8364449119116487
# Area under ROC curve: 0.976 Selected area: 0.175
#
#
#   Fold n. 0
# elapsed time: 734.22s, done 291 out of 1950
# Number of trees: 70 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 737.78s, done 292 out of 1950
# Number of trees: 70 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 741.34s, done 293 out of 1950
# Number of trees: 70 , Maximum depth 36 :
# Accuracy: 0.9994742376445847
#   Fold n. 3
# elapsed time: 744.87s, done 294 out of 1950
# Number of trees: 70 , Maximum depth 36 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 748.44s, done 295 out of 1950
# Number of trees: 70 , Maximum depth 36 :
# Accuracy: 0.8356560610044702
# Area under ROC curve: 0.976 Selected area: 0.17
#
#
#   Fold n. 0
# elapsed time: 751.99s, done 296 out of 1950
# Number of trees: 70 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 755.55s, done 297 out of 1950
# Number of trees: 70 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 759.09s, done 298 out of 1950
# Number of trees: 70 , Maximum depth 38 :
# Accuracy: 0.9997371188222923
#   Fold n. 3
# elapsed time: 762.63s, done 299 out of 1950
# Number of trees: 70 , Maximum depth 38 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 766.48s, done 300 out of 1950
# Number of trees: 70 , Maximum depth 38 :
# Accuracy: 0.8346042597948987
# Area under ROC curve: 0.976 Selected area: 0.169
#
#
#   Fold n. 0
# elapsed time: 768.78s, done 301 out of 1950
# Number of trees: 80 , Maximum depth 10 :
# Accuracy: 0.8577812828601472
#   Fold n. 1
# elapsed time: 771.11s, done 302 out of 1950
# Number of trees: 80 , Maximum depth 10 :
# Accuracy: 0.8533123028391167
#   Fold n. 2
# elapsed time: 773.54s, done 303 out of 1950
# Number of trees: 80 , Maximum depth 10 :
# Accuracy: 0.8638275499474237
#   Fold n. 3
# elapsed time: 775.89s, done 304 out of 1950
# Number of trees: 80 , Maximum depth 10 :
# Accuracy: 0.8480546792849631
#   Fold n. 4
# elapsed time: 778.23s, done 305 out of 1950
# Number of trees: 80 , Maximum depth 10 :
# Accuracy: 0.8190901919537208
# Area under ROC curve: 0.896 Selected area: 0.113
#
#
#   Fold n. 0
# elapsed time: 780.96s, done 306 out of 1950
# Number of trees: 80 , Maximum depth 12 :
# Accuracy: 0.8830178759200841
#   Fold n. 1
# elapsed time: 783.62s, done 307 out of 1950
# Number of trees: 80 , Maximum depth 12 :
# Accuracy: 0.8780231335436383
#   Fold n. 2
# elapsed time: 786.42s, done 308 out of 1950
# Number of trees: 80 , Maximum depth 12 :
# Accuracy: 0.8851209253417456
#   Fold n. 3
# elapsed time: 789.15s, done 309 out of 1950
# Number of trees: 80 , Maximum depth 12 :
# Accuracy: 0.880651945320715
#   Fold n. 4
# elapsed time: 791.93s, done 310 out of 1950
# Number of trees: 80 , Maximum depth 12 :
# Accuracy: 0.8261898501183277
# Area under ROC curve: 0.923 Selected area: 0.131
#
#
#   Fold n. 0
# elapsed time: 794.89s, done 311 out of 1950
# Number of trees: 80 , Maximum depth 14 :
# Accuracy: 0.9061514195583596
#   Fold n. 1
# elapsed time: 797.82s, done 312 out of 1950
# Number of trees: 80 , Maximum depth 14 :
# Accuracy: 0.9093059936908517
#   Fold n. 2
# elapsed time: 800.78s, done 313 out of 1950
# Number of trees: 80 , Maximum depth 14 :
# Accuracy: 0.9098317560462671
#   Fold n. 3
# elapsed time: 803.73s, done 314 out of 1950
# Number of trees: 80 , Maximum depth 14 :
# Accuracy: 0.9043112513144059
#   Fold n. 4
# elapsed time: 806.83s, done 315 out of 1950
# Number of trees: 80 , Maximum depth 14 :
# Accuracy: 0.8322377070733631
# Area under ROC curve: 0.945 Selected area: 0.15
#
#
#   Fold n. 0
# elapsed time: 810.0s, done 316 out of 1950
# Number of trees: 80 , Maximum depth 16 :
# Accuracy: 0.9263932702418507
#   Fold n. 1
# elapsed time: 813.35s, done 317 out of 1950
# Number of trees: 80 , Maximum depth 16 :
# Accuracy: 0.9290220820189274
#   Fold n. 2
# elapsed time: 816.54s, done 318 out of 1950
# Number of trees: 80 , Maximum depth 16 :
# Accuracy: 0.9298107255520505
#   Fold n. 3
# elapsed time: 819.77s, done 319 out of 1950
# Number of trees: 80 , Maximum depth 16 :
# Accuracy: 0.926919032597266
#   Fold n. 4
# elapsed time: 822.93s, done 320 out of 1950
# Number of trees: 80 , Maximum depth 16 :
# Accuracy: 0.8327636076781488
# Area under ROC curve: 0.959 Selected area: 0.157
#
#
#   Fold n. 0
# elapsed time: 826.34s, done 321 out of 1950
# Number of trees: 80 , Maximum depth 18 :
# Accuracy: 0.942429022082019
#   Fold n. 1
# elapsed time: 829.74s, done 322 out of 1950
# Number of trees: 80 , Maximum depth 18 :
# Accuracy: 0.9466351209253417
#   Fold n. 2
# elapsed time: 833.21s, done 323 out of 1950
# Number of trees: 80 , Maximum depth 18 :
# Accuracy: 0.9474237644584648
#   Fold n. 3
# elapsed time: 836.63s, done 324 out of 1950
# Number of trees: 80 , Maximum depth 18 :
# Accuracy: 0.9434805467928497
#   Fold n. 4
# elapsed time: 840.13s, done 325 out of 1950
# Number of trees: 80 , Maximum depth 18 :
# Accuracy: 0.8353931107020773
# Area under ROC curve: 0.968 Selected area: 0.143
#
#
#   Fold n. 0
# elapsed time: 843.86s, done 326 out of 1950
# Number of trees: 80 , Maximum depth 20 :
# Accuracy: 0.9574132492113565
#   Fold n. 1
# elapsed time: 847.59s, done 327 out of 1950
# Number of trees: 80 , Maximum depth 20 :
# Accuracy: 0.9582018927444795
#   Fold n. 2
# elapsed time: 851.19s, done 328 out of 1950
# Number of trees: 80 , Maximum depth 20 :
# Accuracy: 0.9639852786540484
#   Fold n. 3
# elapsed time: 854.79s, done 329 out of 1950
# Number of trees: 80 , Maximum depth 20 :
# Accuracy: 0.9592534174553102
#   Fold n. 4
# elapsed time: 858.42s, done 330 out of 1950
# Number of trees: 80 , Maximum depth 20 :
# Accuracy: 0.835919011306863
# Area under ROC curve: 0.973 Selected area: 0.116
#
#
#   Fold n. 0
# elapsed time: 862.21s, done 331 out of 1950
# Number of trees: 80 , Maximum depth 22 :
# Accuracy: 0.9692429022082019
#   Fold n. 1
# elapsed time: 865.96s, done 332 out of 1950
# Number of trees: 80 , Maximum depth 22 :
# Accuracy: 0.9708201892744479
#   Fold n. 2
# elapsed time: 869.69s, done 333 out of 1950
# Number of trees: 80 , Maximum depth 22 :
# Accuracy: 0.9771293375394322
#   Fold n. 3
# elapsed time: 873.44s, done 334 out of 1950
# Number of trees: 80 , Maximum depth 22 :
# Accuracy: 0.9708201892744479
#   Fold n. 4
# elapsed time: 877.15s, done 335 out of 1950
# Number of trees: 80 , Maximum depth 22 :
# Accuracy: 0.8356560610044702
# Area under ROC curve: 0.975 Selected area: 0.169
#
#
#   Fold n. 0
# elapsed time: 881.02s, done 336 out of 1950
# Number of trees: 80 , Maximum depth 24 :
# Accuracy: 0.980546792849632
#   Fold n. 1
# elapsed time: 884.82s, done 337 out of 1950
# Number of trees: 80 , Maximum depth 24 :
# Accuracy: 0.982124079915878
#   Fold n. 2
# elapsed time: 888.82s, done 338 out of 1950
# Number of trees: 80 , Maximum depth 24 :
# Accuracy: 0.9847528916929548
#   Fold n. 3
# elapsed time: 892.82s, done 339 out of 1950
# Number of trees: 80 , Maximum depth 24 :
# Accuracy: 0.9794952681388013
#   Fold n. 4
# elapsed time: 896.63s, done 340 out of 1950
# Number of trees: 80 , Maximum depth 24 :
# Accuracy: 0.8374967131212201
# Area under ROC curve: 0.976 Selected area: 0.174
#
#
#   Fold n. 0
# elapsed time: 900.77s, done 341 out of 1950
# Number of trees: 80 , Maximum depth 26 :
# Accuracy: 0.9894847528916929
#   Fold n. 1
# elapsed time: 904.64s, done 342 out of 1950
# Number of trees: 80 , Maximum depth 26 :
# Accuracy: 0.9886961093585699
#   Fold n. 2
# elapsed time: 908.68s, done 343 out of 1950
# Number of trees: 80 , Maximum depth 26 :
# Accuracy: 0.9926393270241851
#   Fold n. 3
# elapsed time: 912.78s, done 344 out of 1950
# Number of trees: 80 , Maximum depth 26 :
# Accuracy: 0.9894847528916929
#   Fold n. 4
# elapsed time: 916.65s, done 345 out of 1950
# Number of trees: 80 , Maximum depth 26 :
# Accuracy: 0.8369708125164343
# Area under ROC curve: 0.976 Selected area: 0.178
#
#
#   Fold n. 0
# elapsed time: 920.62s, done 346 out of 1950
# Number of trees: 80 , Maximum depth 28 :
# Accuracy: 0.9957939011566772
#   Fold n. 1
# elapsed time: 924.56s, done 347 out of 1950
# Number of trees: 80 , Maximum depth 28 :
# Accuracy: 0.9931650893796005
#   Fold n. 2
# elapsed time: 928.68s, done 348 out of 1950
# Number of trees: 80 , Maximum depth 28 :
# Accuracy: 0.9978969505783386
#   Fold n. 3
# elapsed time: 932.62s, done 349 out of 1950
# Number of trees: 80 , Maximum depth 28 :
# Accuracy: 0.9965825446898002
#   Fold n. 4
# elapsed time: 936.58s, done 350 out of 1950
# Number of trees: 80 , Maximum depth 28 :
# Accuracy: 0.8382855640283986
# Area under ROC curve: 0.976 Selected area: 0.176
#
#
#   Fold n. 0
# elapsed time: 940.58s, done 351 out of 1950
# Number of trees: 80 , Maximum depth 30 :
# Accuracy: 0.9978969505783386
#   Fold n. 1
# elapsed time: 944.53s, done 352 out of 1950
# Number of trees: 80 , Maximum depth 30 :
# Accuracy: 0.9976340694006309
#   Fold n. 2
# elapsed time: 948.52s, done 353 out of 1950
# Number of trees: 80 , Maximum depth 30 :
# Accuracy: 0.9989484752891693
#   Fold n. 3
# elapsed time: 952.63s, done 354 out of 1950
# Number of trees: 80 , Maximum depth 30 :
# Accuracy: 0.9994742376445847
#   Fold n. 4
# elapsed time: 956.67s, done 355 out of 1950
# Number of trees: 80 , Maximum depth 30 :
# Accuracy: 0.8369708125164343
# Area under ROC curve: 0.976 Selected area: 0.175
#
#
#   Fold n. 0
# elapsed time: 960.91s, done 356 out of 1950
# Number of trees: 80 , Maximum depth 32 :
# Accuracy: 0.9997371188222923
#   Fold n. 1
# elapsed time: 964.95s, done 357 out of 1950
# Number of trees: 80 , Maximum depth 32 :
# Accuracy: 0.9997371188222923
#   Fold n. 2
# elapsed time: 969.14s, done 358 out of 1950
# Number of trees: 80 , Maximum depth 32 :
# Accuracy: 0.9994742376445847
#   Fold n. 3
# elapsed time: 973.27s, done 359 out of 1950
# Number of trees: 80 , Maximum depth 32 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 977.38s, done 360 out of 1950
# Number of trees: 80 , Maximum depth 32 :
# Accuracy: 0.8388114646331843
# Area under ROC curve: 0.976 Selected area: 0.175
#
#
#   Fold n. 0
# elapsed time: 981.37s, done 361 out of 1950
# Number of trees: 80 , Maximum depth 34 :
# Accuracy: 0.9997371188222923
#   Fold n. 1
# elapsed time: 985.36s, done 362 out of 1950
# Number of trees: 80 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 989.42s, done 363 out of 1950
# Number of trees: 80 , Maximum depth 34 :
# Accuracy: 0.9997371188222923
#   Fold n. 3
# elapsed time: 993.4s, done 364 out of 1950
# Number of trees: 80 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 997.45s, done 365 out of 1950
# Number of trees: 80 , Maximum depth 34 :
# Accuracy: 0.8388114646331843
# Area under ROC curve: 0.976 Selected area: 0.172
#
#
#   Fold n. 0
# elapsed time: 1001.39s, done 366 out of 1950
# Number of trees: 80 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 1005.38s, done 367 out of 1950
# Number of trees: 80 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 1009.43s, done 368 out of 1950
# Number of trees: 80 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 1013.44s, done 369 out of 1950
# Number of trees: 80 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 1017.44s, done 370 out of 1950
# Number of trees: 80 , Maximum depth 36 :
# Accuracy: 0.837759663423613
# Area under ROC curve: 0.976 Selected area: 0.175
#
#
#   Fold n. 0
# elapsed time: 1021.47s, done 371 out of 1950
# Number of trees: 80 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 1025.47s, done 372 out of 1950
# Number of trees: 80 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 1029.63s, done 373 out of 1950
# Number of trees: 80 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 1033.59s, done 374 out of 1950
# Number of trees: 80 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 1037.59s, done 375 out of 1950
# Number of trees: 80 , Maximum depth 38 :
# Accuracy: 0.8372337628188272
# Area under ROC curve: 0.976 Selected area: 0.17
#
#
#   Fold n. 0
# elapsed time: 1040.2s, done 376 out of 1950
# Number of trees: 90 , Maximum depth 10 :
# Accuracy: 0.8590956887486856
#   Fold n. 1
# elapsed time: 1042.82s, done 377 out of 1950
# Number of trees: 90 , Maximum depth 10 :
# Accuracy: 0.8541009463722398
#   Fold n. 2
# elapsed time: 1045.52s, done 378 out of 1950
# Number of trees: 90 , Maximum depth 10 :
# Accuracy: 0.863564668769716
#   Fold n. 3
# elapsed time: 1048.21s, done 379 out of 1950
# Number of trees: 90 , Maximum depth 10 :
# Accuracy: 0.8483175604626709
#   Fold n. 4
# elapsed time: 1050.83s, done 380 out of 1950
# Number of trees: 90 , Maximum depth 10 :
# Accuracy: 0.8190901919537208
# Area under ROC curve: 0.897 Selected area: 0.113
#
#
#   Fold n. 0
# elapsed time: 1053.86s, done 381 out of 1950
# Number of trees: 90 , Maximum depth 12 :
# Accuracy: 0.8835436382754994
#   Fold n. 1
# elapsed time: 1056.83s, done 382 out of 1950
# Number of trees: 90 , Maximum depth 12 :
# Accuracy: 0.8785488958990536
#   Fold n. 2
# elapsed time: 1059.85s, done 383 out of 1950
# Number of trees: 90 , Maximum depth 12 :
# Accuracy: 0.8851209253417456
#   Fold n. 3
# elapsed time: 1062.93s, done 384 out of 1950
# Number of trees: 90 , Maximum depth 12 :
# Accuracy: 0.8809148264984227
#   Fold n. 4
# elapsed time: 1065.89s, done 385 out of 1950
# Number of trees: 90 , Maximum depth 12 :
# Accuracy: 0.8267157507231133
# Area under ROC curve: 0.924 Selected area: 0.132
#
#
#   Fold n. 0
# elapsed time: 1069.21s, done 386 out of 1950
# Number of trees: 90 , Maximum depth 14 :
# Accuracy: 0.9053627760252366
#   Fold n. 1
# elapsed time: 1072.59s, done 387 out of 1950
# Number of trees: 90 , Maximum depth 14 :
# Accuracy: 0.9098317560462671
#   Fold n. 2
# elapsed time: 1075.9s, done 388 out of 1950
# Number of trees: 90 , Maximum depth 14 :
# Accuracy: 0.9095688748685594
#   Fold n. 3
# elapsed time: 1079.22s, done 389 out of 1950
# Number of trees: 90 , Maximum depth 14 :
# Accuracy: 0.9048370136698213
#   Fold n. 4
# elapsed time: 1082.63s, done 390 out of 1950
# Number of trees: 90 , Maximum depth 14 :
# Accuracy: 0.832500657375756
# Area under ROC curve: 0.945 Selected area: 0.149
#
#
#   Fold n. 0
# elapsed time: 1086.28s, done 391 out of 1950
# Number of trees: 90 , Maximum depth 16 :
# Accuracy: 0.9263932702418507
#   Fold n. 1
# elapsed time: 1089.9s, done 392 out of 1950
# Number of trees: 90 , Maximum depth 16 :
# Accuracy: 0.9290220820189274
#   Fold n. 2
# elapsed time: 1093.53s, done 393 out of 1950
# Number of trees: 90 , Maximum depth 16 :
# Accuracy: 0.9313880126182965
#   Fold n. 3
# elapsed time: 1097.25s, done 394 out of 1950
# Number of trees: 90 , Maximum depth 16 :
# Accuracy: 0.926919032597266
#   Fold n. 4
# elapsed time: 1100.93s, done 395 out of 1950
# Number of trees: 90 , Maximum depth 16 :
# Accuracy: 0.8338154088877202
# Area under ROC curve: 0.959 Selected area: 0.158
#
#
#   Fold n. 0
# elapsed time: 1104.78s, done 396 out of 1950
# Number of trees: 90 , Maximum depth 18 :
# Accuracy: 0.9419032597266036
#   Fold n. 1
# elapsed time: 1108.7s, done 397 out of 1950
# Number of trees: 90 , Maximum depth 18 :
# Accuracy: 0.9453207150368034
#   Fold n. 2
# elapsed time: 1112.56s, done 398 out of 1950
# Number of trees: 90 , Maximum depth 18 :
# Accuracy: 0.9466351209253417
#   Fold n. 3
# elapsed time: 1116.58s, done 399 out of 1950
# Number of trees: 90 , Maximum depth 18 :
# Accuracy: 0.944794952681388
#   Fold n. 4
# elapsed time: 1120.54s, done 400 out of 1950
# Number of trees: 90 , Maximum depth 18 :
# Accuracy: 0.8353931107020773
# Area under ROC curve: 0.968 Selected area: 0.122
#
#
#   Fold n. 0
# elapsed time: 1124.6s, done 401 out of 1950
# Number of trees: 90 , Maximum depth 20 :
# Accuracy: 0.9582018927444795
#   Fold n. 1
# elapsed time: 1128.65s, done 402 out of 1950
# Number of trees: 90 , Maximum depth 20 :
# Accuracy: 0.9582018927444795
#   Fold n. 2
# elapsed time: 1132.74s, done 403 out of 1950
# Number of trees: 90 , Maximum depth 20 :
# Accuracy: 0.9652996845425867
#   Fold n. 3
# elapsed time: 1136.9s, done 404 out of 1950
# Number of trees: 90 , Maximum depth 20 :
# Accuracy: 0.9587276550998949
#   Fold n. 4
# elapsed time: 1141.05s, done 405 out of 1950
# Number of trees: 90 , Maximum depth 20 :
# Accuracy: 0.8353931107020773
# Area under ROC curve: 0.973 Selected area: 0.111
#
#
#   Fold n. 0
# elapsed time: 1145.26s, done 406 out of 1950
# Number of trees: 90 , Maximum depth 22 :
# Accuracy: 0.9692429022082019
#   Fold n. 1
# elapsed time: 1149.5s, done 407 out of 1950
# Number of trees: 90 , Maximum depth 22 :
# Accuracy: 0.9718717139852786
#   Fold n. 2
# elapsed time: 1153.72s, done 408 out of 1950
# Number of trees: 90 , Maximum depth 22 :
# Accuracy: 0.9760778128286015
#   Fold n. 3
# elapsed time: 1157.96s, done 409 out of 1950
# Number of trees: 90 , Maximum depth 22 :
# Accuracy: 0.9700315457413249
#   Fold n. 4
# elapsed time: 1162.32s, done 410 out of 1950
# Number of trees: 90 , Maximum depth 22 :
# Accuracy: 0.8367078622140416
# Area under ROC curve: 0.975 Selected area: 0.137
#
#
#   Fold n. 0
# elapsed time: 1166.72s, done 411 out of 1950
# Number of trees: 90 , Maximum depth 24 :
# Accuracy: 0.979758149316509
#   Fold n. 1
# elapsed time: 1171.19s, done 412 out of 1950
# Number of trees: 90 , Maximum depth 24 :
# Accuracy: 0.982124079915878
#   Fold n. 2
# elapsed time: 1175.54s, done 413 out of 1950
# Number of trees: 90 , Maximum depth 24 :
# Accuracy: 0.9855415352260778
#   Fold n. 3
# elapsed time: 1179.89s, done 414 out of 1950
# Number of trees: 90 , Maximum depth 24 :
# Accuracy: 0.980546792849632
#   Fold n. 4
# elapsed time: 1184.29s, done 415 out of 1950
# Number of trees: 90 , Maximum depth 24 :
# Accuracy: 0.8361819616092558
# Area under ROC curve: 0.976 Selected area: 0.174
#
#
#   Fold n. 0
# elapsed time: 1188.73s, done 416 out of 1950
# ...
# Number of trees: 280 , Maximum depth 22 :
# Accuracy: 0.9716088328075709
#   Fold n. 4
# elapsed time: 12726.88s, done 1835 out of 1950
# Number of trees: 280 , Maximum depth 22 :
# Accuracy: 0.8380226137260058
# Area under ROC curve: 0.976 Selected area: 0.069
#
#
#   Fold n. 0
# elapsed time: 12740.39s, done 1836 out of 1950
# Number of trees: 280 , Maximum depth 24 :
# Accuracy: 0.9810725552050473
#   Fold n. 1
# elapsed time: 12753.43s, done 1837 out of 1950
# Number of trees: 280 , Maximum depth 24 :
# Accuracy: 0.9826498422712934
#   Fold n. 2
# elapsed time: 12766.64s, done 1838 out of 1950
# Number of trees: 280 , Maximum depth 24 :
# Accuracy: 0.9858044164037855
#   Fold n. 3
# elapsed time: 12780.2s, done 1839 out of 1950
# Number of trees: 280 , Maximum depth 24 :
# Accuracy: 0.980546792849632
#   Fold n. 4
# elapsed time: 12793.31s, done 1840 out of 1950
# Number of trees: 280 , Maximum depth 24 :
# Accuracy: 0.8414409676571128
# Area under ROC curve: 0.976 Selected area: 0.097
#
#
#   Fold n. 0
# elapsed time: 12807.04s, done 1841 out of 1950
# Number of trees: 280 , Maximum depth 26 :
# Accuracy: 0.9900105152471083
#   Fold n. 1
# elapsed time: 12820.4s, done 1842 out of 1950
# Number of trees: 280 , Maximum depth 26 :
# Accuracy: 0.9889589905362776
#   Fold n. 2
# elapsed time: 12833.72s, done 1843 out of 1950
# Number of trees: 280 , Maximum depth 26 :
# Accuracy: 0.9939537329127235
#   Fold n. 3
# elapsed time: 12847.14s, done 1844 out of 1950
# Number of trees: 280 , Maximum depth 26 :
# Accuracy: 0.9889589905362776
#   Fold n. 4
# elapsed time: 12860.57s, done 1845 out of 1950
# Number of trees: 280 , Maximum depth 26 :
# Accuracy: 0.8390744149355772
# Area under ROC curve: 0.977 Selected area: 0.171
#
#
#   Fold n. 0
# elapsed time: 12874.16s, done 1846 out of 1950
# Number of trees: 280 , Maximum depth 28 :
# Accuracy: 0.9950052576235542
#   Fold n. 1
# elapsed time: 12887.71s, done 1847 out of 1950
# Number of trees: 280 , Maximum depth 28 :
# Accuracy: 0.9942166140904312
#   Fold n. 2
# elapsed time: 12901.17s, done 1848 out of 1950
# Number of trees: 280 , Maximum depth 28 :
# Accuracy: 0.9976340694006309
#   Fold n. 3
# elapsed time: 12914.59s, done 1849 out of 1950
# Number of trees: 280 , Maximum depth 28 :
# Accuracy: 0.9973711882229233
#   Fold n. 4
# elapsed time: 12928.15s, done 1850 out of 1950
# Number of trees: 280 , Maximum depth 28 :
# Accuracy: 0.8403891664475415
# Area under ROC curve: 0.977 Selected area: 0.174
#
#
#   Fold n. 0
# elapsed time: 12941.85s, done 1851 out of 1950
# Number of trees: 280 , Maximum depth 30 :
# Accuracy: 0.998422712933754
#   Fold n. 1
# elapsed time: 12955.5s, done 1852 out of 1950
# Number of trees: 280 , Maximum depth 30 :
# Accuracy: 0.9976340694006309
#   Fold n. 2
# elapsed time: 12969.05s, done 1853 out of 1950
# Number of trees: 280 , Maximum depth 30 :
# Accuracy: 0.999211356466877
#   Fold n. 3
# elapsed time: 12982.62s, done 1854 out of 1950
# Number of trees: 280 , Maximum depth 30 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 12996.59s, done 1855 out of 1950
# Number of trees: 280 , Maximum depth 30 :
# Accuracy: 0.837759663423613
# Area under ROC curve: 0.977 Selected area: 0.179
#
#
#   Fold n. 0
# elapsed time: 13010.32s, done 1856 out of 1950
# Number of trees: 280 , Maximum depth 32 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 13023.92s, done 1857 out of 1950
# Number of trees: 280 , Maximum depth 32 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 13037.47s, done 1858 out of 1950
# Number of trees: 280 , Maximum depth 32 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 13051.23s, done 1859 out of 1950
# Number of trees: 280 , Maximum depth 32 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 13065.01s, done 1860 out of 1950
# Number of trees: 280 , Maximum depth 32 :
# Accuracy: 0.83933736523797
# Area under ROC curve: 0.977 Selected area: 0.18
#
#
#   Fold n. 0
# elapsed time: 13078.8s, done 1861 out of 1950
# Number of trees: 280 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 13092.41s, done 1862 out of 1950
# Number of trees: 280 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 13106.09s, done 1863 out of 1950
# Number of trees: 280 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 13119.82s, done 1864 out of 1950
# Number of trees: 280 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 13133.85s, done 1865 out of 1950
# Number of trees: 280 , Maximum depth 34 :
# Accuracy: 0.8398632658427557
# Area under ROC curve: 0.977 Selected area: 0.179
#
#
#   Fold n. 0
# elapsed time: 13147.78s, done 1866 out of 1950
# Number of trees: 280 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 13161.39s, done 1867 out of 1950
# Number of trees: 280 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 13175.02s, done 1868 out of 1950
# Number of trees: 280 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 13188.7s, done 1869 out of 1950
# Number of trees: 280 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 13202.34s, done 1870 out of 1950
# Number of trees: 280 , Maximum depth 36 :
# Accuracy: 0.8396003155403629
# Area under ROC curve: 0.977 Selected area: 0.181
#
#
#   Fold n. 0
# elapsed time: 13216.08s, done 1871 out of 1950
# Number of trees: 280 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 13229.8s, done 1872 out of 1950
# Number of trees: 280 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 13243.64s, done 1873 out of 1950
# Number of trees: 280 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 13257.76s, done 1874 out of 1950
# Number of trees: 280 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 13271.4s, done 1875 out of 1950
# Number of trees: 280 , Maximum depth 38 :
# Accuracy: 0.8403891664475415
# Area under ROC curve: 0.977 Selected area: 0.178
#
#
#   Fold n. 0
# elapsed time: 13279.56s, done 1876 out of 1950
# Number of trees: 290 , Maximum depth 10 :
# Accuracy: 0.860410094637224
#   Fold n. 1
# elapsed time: 13287.97s, done 1877 out of 1950
# Number of trees: 290 , Maximum depth 10 :
# Accuracy: 0.8548895899053628
#   Fold n. 2
# elapsed time: 13296.33s, done 1878 out of 1950
# Number of trees: 290 , Maximum depth 10 :
# Accuracy: 0.863564668769716
#   Fold n. 3
# elapsed time: 13304.54s, done 1879 out of 1950
# Number of trees: 290 , Maximum depth 10 :
# Accuracy: 0.8480546792849631
#   Fold n. 4
# elapsed time: 13312.95s, done 1880 out of 1950
# Number of trees: 290 , Maximum depth 10 :
# Accuracy: 0.8198790428608993
# Area under ROC curve: 0.898 Selected area: 0.114
#
#
#   Fold n. 0
# elapsed time: 13322.57s, done 1881 out of 1950
# Number of trees: 290 , Maximum depth 12 :
# Accuracy: 0.8835436382754994
#   Fold n. 1
# elapsed time: 13331.98s, done 1882 out of 1950
# Number of trees: 290 , Maximum depth 12 :
# Accuracy: 0.8788117770767613
#   Fold n. 2
# elapsed time: 13341.37s, done 1883 out of 1950
# Number of trees: 290 , Maximum depth 12 :
# Accuracy: 0.8861724500525763
#   Fold n. 3
# elapsed time: 13350.79s, done 1884 out of 1950
# Number of trees: 290 , Maximum depth 12 :
# Accuracy: 0.881440588853838
#   Fold n. 4
# elapsed time: 13360.42s, done 1885 out of 1950
# Number of trees: 290 , Maximum depth 12 :
# Accuracy: 0.8280305022350776
# Area under ROC curve: 0.925 Selected area: 0.133
#
#
#   Fold n. 0
# elapsed time: 13371.16s, done 1886 out of 1950
# Number of trees: 290 , Maximum depth 14 :
# Accuracy: 0.905888538380652
#   Fold n. 1
# elapsed time: 13381.82s, done 1887 out of 1950
# Number of trees: 290 , Maximum depth 14 :
# Accuracy: 0.9095688748685594
#   Fold n. 2
# elapsed time: 13392.5s, done 1888 out of 1950
# Number of trees: 290 , Maximum depth 14 :
# Accuracy: 0.9098317560462671
#   Fold n. 3
# elapsed time: 13402.9s, done 1889 out of 1950
# Number of trees: 290 , Maximum depth 14 :
# Accuracy: 0.9056256572029443
#   Fold n. 4
# elapsed time: 13413.66s, done 1890 out of 1950
# Number of trees: 290 , Maximum depth 14 :
# Accuracy: 0.8314488561661846
# Area under ROC curve: 0.946 Selected area: 0.151
#
#
#   Fold n. 0
# elapsed time: 13425.45s, done 1891 out of 1950
# Number of trees: 290 , Maximum depth 16 :
# Accuracy: 0.9282334384858044
#   Fold n. 1
# elapsed time: 13436.74s, done 1892 out of 1950
# Number of trees: 290 , Maximum depth 16 :
# Accuracy: 0.9295478443743428
#   Fold n. 2
# elapsed time: 13448.03s, done 1893 out of 1950
# Number of trees: 290 , Maximum depth 16 :
# Accuracy: 0.9300736067297581
#   Fold n. 3
# elapsed time: 13459.42s, done 1894 out of 1950
# Number of trees: 290 , Maximum depth 16 :
# Accuracy: 0.9274447949526814
#   Fold n. 4
# elapsed time: 13471.03s, done 1895 out of 1950
# Number of trees: 290 , Maximum depth 16 :
# Accuracy: 0.8340783591901131
# Area under ROC curve: 0.96 Selected area: 0.156
#
#
#   Fold n. 0
# elapsed time: 13483.08s, done 1896 out of 1950
# Number of trees: 290 , Maximum depth 18 :
# Accuracy: 0.942429022082019
#   Fold n. 1
# elapsed time: 13495.17s, done 1897 out of 1950
# Number of trees: 290 , Maximum depth 18 :
# Accuracy: 0.9453207150368034
#   Fold n. 2
# elapsed time: 13507.22s, done 1898 out of 1950
# Number of trees: 290 , Maximum depth 18 :
# Accuracy: 0.9476866456361724
#   Fold n. 3
# elapsed time: 13519.23s, done 1899 out of 1950
# Number of trees: 290 , Maximum depth 18 :
# Accuracy: 0.943217665615142
#   Fold n. 4
# elapsed time: 13531.3s, done 1900 out of 1950
# Number of trees: 290 , Maximum depth 18 :
# Accuracy: 0.8372337628188272
# Area under ROC curve: 0.969 Selected area: 0.131
#
#
#   Fold n. 0
# elapsed time: 13544.06s, done 1901 out of 1950
# Number of trees: 290 , Maximum depth 20 :
# Accuracy: 0.9571503680336488
#   Fold n. 1
# elapsed time: 13556.77s, done 1902 out of 1950
# Number of trees: 290 , Maximum depth 20 :
# Accuracy: 0.9563617245005258
#   Fold n. 2
# elapsed time: 13569.44s, done 1903 out of 1950
# Number of trees: 290 , Maximum depth 20 :
# Accuracy: 0.96267087276551
#   Fold n. 3
# elapsed time: 13582.61s, done 1904 out of 1950
# Number of trees: 290 , Maximum depth 20 :
# Accuracy: 0.9592534174553102
#   Fold n. 4
# elapsed time: 13595.34s, done 1905 out of 1950
# Number of trees: 290 , Maximum depth 20 :
# Accuracy: 0.8356560610044702
# Area under ROC curve: 0.974 Selected area: 0.103
#
#
#   Fold n. 0
# elapsed time: 13608.61s, done 1906 out of 1950
# Number of trees: 290 , Maximum depth 22 :
# Accuracy: 0.9700315457413249
#   Fold n. 1
# elapsed time: 13621.79s, done 1907 out of 1950
# Number of trees: 290 , Maximum depth 22 :
# Accuracy: 0.9718717139852786
#   Fold n. 2
# elapsed time: 13635.03s, done 1908 out of 1950
# Number of trees: 290 , Maximum depth 22 :
# Accuracy: 0.9760778128286015
#   Fold n. 3
# elapsed time: 13648.22s, done 1909 out of 1950
# Number of trees: 290 , Maximum depth 22 :
# Accuracy: 0.9713459516298633
#   Fold n. 4
# elapsed time: 13661.85s, done 1910 out of 1950
# Number of trees: 290 , Maximum depth 22 :
# Accuracy: 0.8385485143307915
# Area under ROC curve: 0.976 Selected area: 0.07
#
#
#   Fold n. 0
# elapsed time: 13675.42s, done 1911 out of 1950
# Number of trees: 290 , Maximum depth 24 :
# Accuracy: 0.9808096740273397
#   Fold n. 1
# elapsed time: 13688.99s, done 1912 out of 1950
# Number of trees: 290 , Maximum depth 24 :
# Accuracy: 0.9826498422712934
#   Fold n. 2
# elapsed time: 13702.65s, done 1913 out of 1950
# Number of trees: 290 , Maximum depth 24 :
# Accuracy: 0.9860672975814931
#   Fold n. 3
# elapsed time: 13716.26s, done 1914 out of 1950
# Number of trees: 290 , Maximum depth 24 :
# Accuracy: 0.9818611987381703
#   Fold n. 4
# elapsed time: 13729.88s, done 1915 out of 1950
# Number of trees: 290 , Maximum depth 24 :
# Accuracy: 0.8409150670523271
# Area under ROC curve: 0.976 Selected area: 0.139
#
#
#   Fold n. 0
# elapsed time: 13743.69s, done 1916 out of 1950
# Number of trees: 290 , Maximum depth 26 :
# Accuracy: 0.9892218717139852
#   Fold n. 1
# elapsed time: 13757.47s, done 1917 out of 1950
# Number of trees: 290 , Maximum depth 26 :
# Accuracy: 0.9889589905362776
#   Fold n. 2
# elapsed time: 13771.27s, done 1918 out of 1950
# Number of trees: 290 , Maximum depth 26 :
# Accuracy: 0.9939537329127235
#   Fold n. 3
# elapsed time: 13785.11s, done 1919 out of 1950
# Number of trees: 290 , Maximum depth 26 :
# Accuracy: 0.9889589905362776
#   Fold n. 4
# elapsed time: 13798.99s, done 1920 out of 1950
# Number of trees: 290 , Maximum depth 26 :
# Accuracy: 0.8396003155403629
# Area under ROC curve: 0.977 Selected area: 0.174
#
#
#   Fold n. 0
# elapsed time: 13812.92s, done 1921 out of 1950
# Number of trees: 290 , Maximum depth 28 :
# Accuracy: 0.9950052576235542
#   Fold n. 1
# elapsed time: 13826.97s, done 1922 out of 1950
# Number of trees: 290 , Maximum depth 28 :
# Accuracy: 0.9947423764458465
#   Fold n. 2
# elapsed time: 13840.98s, done 1923 out of 1950
# Number of trees: 290 , Maximum depth 28 :
# Accuracy: 0.9978969505783386
#   Fold n. 3
# elapsed time: 13855.0s, done 1924 out of 1950
# Number of trees: 290 , Maximum depth 28 :
# Accuracy: 0.9968454258675079
#   Fold n. 4
# elapsed time: 13868.92s, done 1925 out of 1950
# Number of trees: 290 , Maximum depth 28 :
# Accuracy: 0.8401262161451486
# Area under ROC curve: 0.977 Selected area: 0.175
#
#
#   Fold n. 0
# elapsed time: 13882.98s, done 1926 out of 1950
# Number of trees: 290 , Maximum depth 30 :
# Accuracy: 0.998422712933754
#   Fold n. 1
# elapsed time: 13897.11s, done 1927 out of 1950
# Number of trees: 290 , Maximum depth 30 :
# Accuracy: 0.9976340694006309
#   Fold n. 2
# elapsed time: 13911.28s, done 1928 out of 1950
# Number of trees: 290 , Maximum depth 30 :
# Accuracy: 0.9994742376445847
#   Fold n. 3
# elapsed time: 13925.34s, done 1929 out of 1950
# Number of trees: 290 , Maximum depth 30 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 13939.48s, done 1930 out of 1950
# Number of trees: 290 , Maximum depth 30 :
# Accuracy: 0.837759663423613
# Area under ROC curve: 0.977 Selected area: 0.179
#
#
#   Fold n. 0
# elapsed time: 13953.64s, done 1931 out of 1950
# Number of trees: 290 , Maximum depth 32 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 13967.83s, done 1932 out of 1950
# Number of trees: 290 , Maximum depth 32 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 13981.95s, done 1933 out of 1950
# Number of trees: 290 , Maximum depth 32 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 13996.07s, done 1934 out of 1950
# Number of trees: 290 , Maximum depth 32 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 14010.18s, done 1935 out of 1950
# Number of trees: 290 , Maximum depth 32 :
# Accuracy: 0.8390744149355772
# Area under ROC curve: 0.977 Selected area: 0.18
#
#
#   Fold n. 0
# elapsed time: 14024.82s, done 1936 out of 1950
# Number of trees: 290 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 14039.39s, done 1937 out of 1950
# Number of trees: 290 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 14053.56s, done 1938 out of 1950
# Number of trees: 290 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 14067.78s, done 1939 out of 1950
# Number of trees: 290 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 14081.99s, done 1940 out of 1950
# Number of trees: 290 , Maximum depth 34 :
# Accuracy: 0.8390744149355772
# Area under ROC curve: 0.977 Selected area: 0.18
#
#
#   Fold n. 0
# elapsed time: 14096.25s, done 1941 out of 1950
# Number of trees: 290 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 14110.98s, done 1942 out of 1950
# Number of trees: 290 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 14125.17s, done 1943 out of 1950
# Number of trees: 290 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 14139.35s, done 1944 out of 1950
# Number of trees: 290 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 14153.57s, done 1945 out of 1950
# Number of trees: 290 , Maximum depth 36 :
# Accuracy: 0.8388114646331843
# Area under ROC curve: 0.977 Selected area: 0.18
#
#
#   Fold n. 0
# elapsed time: 14168.21s, done 1946 out of 1950
# Number of trees: 290 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 14182.48s, done 1947 out of 1950
# Number of trees: 290 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 14196.71s, done 1948 out of 1950
# Number of trees: 290 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 14210.93s, done 1949 out of 1950
# Number of trees: 290 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 14225.14s, done 1950 out of 1950
# Number of trees: 290 , Maximum depth 38 :
# Accuracy: 0.8396003155403629
# Area under ROC curve: 0.977 Selected area: 0.181
#
#
# Best number of trees: 290
#
# Best maximum depth: 38
#
# Area under ROC curve of best model: 0.18122901956348395

# %%
print(round(best_area,3))
print(round(best_total_auc,3))

# %% [markdown]
# Now we train again the best Random Forest found on the whole training set and calculate the partial AUC of the best model.

# %%
X_train_np = np.array(X_train)
Y_train_np = np.array(Y_train)
X_test_np = np.array(X_test)
Y_test_np = np.array(Y_test)

best_forest = RandomForestClassifier(n_estimators=best_model[0], max_depth= best_model[1], max_features=X_train_np.shape[1],bootstrap=True,max_samples=1.0,random_state=10,n_jobs=-1)

best_forest.fit(X_train_np,Y_train_np)
Y_pred = best_forest.predict(X_test_np)
accuracy = accuracy_score(Y_test_np, Y_pred)
print('Accuracy of best Random Forest:',round(accuracy,3))

y_pred_prob = best_forest.predict_proba(X_test_np)[:, 1]
fpr, tpr, thresholds = roc_curve(Y_test_np, y_pred_prob)
partial_fpr = fpr[fpr <= 0.2]
partial_tpr = tpr[:len(partial_fpr)]
partial_auc = auc(partial_fpr, partial_tpr)
roc_auc_best = auc(fpr, tpr)
print('Partial AUC of the best Random Forest:',round(partial_auc,3))
print('AUC of the best Random Forest:',round(roc_auc_best,3))

# %% [markdown]
# Here we plot the confusion matrix:

# %%
cm = sklearn.metrics.confusion_matrix(Y_test,Y_pred)
RF_cm = normalize_cm(cm)

print('Confusion matrix:')
print(RF_cm)
plot_cm(RF_cm,method_name='Random Forest')

# %% [markdown]
# Finally we compute the *Q* value of the best Forest on the test set and plot the ROC curve of the relative algorithm.

# %%
fpr_rforest = fpr
tpr_rforest = tpr
Q_rforest = RF_cm[1][1]/ np.sqrt(RF_cm[0][1])

print('best random forest Q:',Q_rforest)

plot_roc(fpr_rforest,tpr_rforest,roc_auc_best,"Random forest","darkgreen")

# %% [markdown]
# ## Part 5.5: FFNN
# In this section we implement a Feedforward Fully connected Neural Network as a classification algorithm. The hyperparameters to choose to tailor the NN are its architecture, i.e. the  ***number of layers*** and the ***number of neurons*** in each layer, and the ***initial learning rate*** to update weights using *Stochastic Gradient Descent* (SGD) during loss minimization. We choose as activation function for each layer the *ReLu* function (common choice) and an adaptive learning rate over the iterations.

# %%
# redefine NN cycle
hidden_layer_sizes = [(18,), (36,), (54,), (36,18), (54,18), (54,36), (54,36,18)]
learning_rate_init = [ 0.1 , 0.01 , 0.001 ]

start_time = time()

auc_scorer = make_scorer(full_auc_scorer, greater_is_better=True, response_method='predict' ) 

parameters = []
fprs = []
tprs = []
aucs = []
partial_aucs = []
hls = []
lrs = []
models = []
K = 5
kf = KFold(n_splits=K, shuffle=True, random_state=42) 

for size in hidden_layer_sizes:
    for lr in learning_rate_init:
        print(f"Training MLP of size {size} and lr {lr}...")
        print("Validation AUC \t Partial AUC")
        lrs.append(lr)
        hls.append(size)
        partial_auc = 0
        auc_value = 0

        for i, (train_idx, val_idx) in enumerate(kf.split(X)):
            
            #print(f" Fold n. {i}")
            train_K=data_rescaled_and_indexed.iloc[train_idx]
            valid_K=data_rescaled_and_indexed.iloc[val_idx]
            X_train_K, Y_train_K = split_X_Y(train_K)
            X_valid_K, Y_valid_K = split_X_Y(valid_K)
            
            MLP = MLPClassifier(hidden_layer_sizes=size,
                                activation='relu', 
                                max_iter=1000, 
                                alpha=1e-4, 
                                solver='adam', 
                                tol=1e-5, 
                                learning_rate='adaptive',
                                learning_rate_init=lr,
                                verbose=0)
            
            MLP.fit(X_train_K,Y_train_K)
            parameters.append(MLP.coefs_)
            models.append(MLP)
            
            y_pred_proba = MLP.predict_proba(X_valid_K)[:, 1]  
    
            fpr, tpr, _ = roc_curve(Y_valid_K, y_pred_proba)
            fprs.append(fpr)
            tprs.append(tpr)
            auc_value_k = auc(fpr, tpr)
        
            
            # search for fpr less than 0.2 (if not able fpr is set to zero)
            partial_fpr = fpr[fpr <= 0.2]
            if (len(partial_fpr) < 2 ):
                partial_auc = 0
            else:
                partial_tpr = tpr[:len(partial_fpr)]
                partial_auc_k = auc(partial_fpr, partial_tpr)
                
            print(f"Fold {i+1}:", round(auc_value_k,3),f"\t",round(partial_auc_k,3))
            partial_auc += partial_auc_k/K
            auc_value += auc_value_k/K                 
        partial_aucs.append(partial_auc)
        aucs.append(auc_value)
        
        elapsed_time = time() - start_time
        start_time = time()
        print(f"Time needed for training: {elapsed_time:.2f} seconds")
        print("total AUC:",round(auc_value,3),"\t partial AUC:",round(partial_auc,3),'\n')
        print('\n')

# %% [markdown]
# Here we train again the best model on all the training set. Then we test its performance and plot it, as well as the confusion matrix

# %%
best_index_thresh = np.argmax(np.array(partial_aucs))
best_partial_auc_thresh = partial_aucs[best_index_thresh]
best_auc_thresh = aucs[best_index_thresh]
best_fpr_thresh = fprs[best_index_thresh]
best_tpr_thresh = tprs[best_index_thresh]
best_model_NN = models[best_index_thresh]
best_lr = lrs[best_index_thresh]
best_size = hls[best_index_thresh]

best_model_NN.fit(X_train_np,Y_train_np)
print(f"Best Learning Rate: {best_lr}, Best Hidden Layer Size: {best_size}")
print(f"Partial AUC of best model: {round(best_partial_auc_thresh,3)}")
print(f"AUC of best model: {round(best_auc_thresh,3)}")

# %%
#print(best_model)
Y_pred = best_model_NN.predict(X_test_np)
cm = sklearn.metrics.confusion_matrix(Y_test_np,Y_pred)
NN_cm = normalize_cm(cm)

print('Confusion matrix:')
print(NN_cm)
plot_cm(NN_cm,method_name='NN')

# %%
Q_NN = NN_cm[1][1]/ np.sqrt(NN_cm[0][1])
auc_value = auc(fpr_NN, tpr_NN)

print('Best NN Q value:',round(Q_NN,3))

idx = np.argmax(best_fpr_thresh > 0.2) - 1 
fpr_thresh = best_fpr_thresh[idx]
tpr_thresh = best_tpr_thresh[idx]

fig = plt.figure(figsize=(8, 6))
plt.plot(best_fpr_thresh, best_tpr_thresh, label=f'ROC Curve (AUC = {round(best_auc_thresh,3)})',c='red')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # (random classifier)
plt.xlim(-0.05,1.05)
plt.ylim(-0.05,1.05)
plt.fill_between(best_fpr_thresh[:idx+1], best_tpr_thresh[:idx+1],color='red',alpha=0.2, label=f'Partial ROC (Partial AUC = {round(best_partial_auc_thresh,3)})')
plt.axvline(x=fpr_thresh, ymin=-0.05, ymax=tpr_thresh-0.02, color='green', linestyle='--', label='FPR = 0.2')
plt.axhline(y=tpr_thresh, xmin=-0.05, xmax=fpr_thresh+0.025, color='green', linestyle='--')
plt.title(f'FFNN ROC Curve',fontsize=16)
plt.xlabel('False Positive Rate (FPR)',fontsize=14)
plt.ylabel('True Positive Rate (TPR)',fontsize=14)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.legend(loc='lower right',fontsize=11)
plt.grid(True)
plt.show();

# %% [markdown]
# Now we plot the ROC curves of all algorithms for visual comparison:

# %%
print('best NN Q value:',Q_NN.round(3))
print('best perceptron Q value:',Q_perceptron.round(3))
print('best SVM Q value:',Q_SVM.round(3))
print('best random forest Q value:',Q_rforest.round(3))
print('best log_reg Q value:',Q_log.round(3))

line_width = 3
transparency = 0.7
plt.figure(figsize=(10,8))
plt.grid()
plt.title('ROC comparison',fontsize=20)
plt.plot([0, 1], [0, 1], linestyle='--', color='grey')
plt.plot(fpr_log,tpr_log,label='log ROC',lw=line_width,alpha=transparency,c='pink')
plt.plot(fpr_perceptron,tpr_perceptron,label='perceptron ROC',lw=line_width,alpha=transparency,c='blue')
plt.plot(fpr_SVM,tpr_SVM,label='SVM ROC',lw=line_width,alpha=transparency,c='darkorange')
plt.plot(fpr_rforest,tpr_rforest,label='random forest ROC',lw=line_width,alpha=transparency,c='darkgreen')
plt.plot(fpr_NN,tpr_NN,c='red',label='NN ROC',lw=line_width,alpha=transparency)
plt.xlabel('false positive rate',fontsize=16)
plt.ylabel('true positive rate',fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc=4,fontsize=12)
plt.show()

# %% [markdown]
# # Part 6: cut on Alpha parameter
# In this section we perform a cut on the Alpha feature, which we found to be the most informative to discriminate between signal and backgrund in the previous analysis. We impose a threshold such that events with a smaller Alpha will be classified as gammas, the ramining as background. We want to study the performance of this parameter: we determine the overall best value for the Alpha cut, as well as the value that allows to select as gamma at least 10% of the total true gamma events.

# %%
X_train['fAlpha'] = train_alpha
X_test['fAlpha'] = test_alpha
print(X_train.columns[:])
print(X_train.shape[:])

# %%
tot_hadrons = len(Y_test[Y_test == -1])
tot_gammas = len(Y_test[Y_test == 1])
tot_hadrons_train = len(Y_train[Y_train == -1])
sel_label = 9
# sel label = Alpha == 9

cut_values = []
rates = []
absolute_tp = []
absolute_fp = []

# setting minimum threshold as 0.90 (editable)
thresh = 0.90

#print('cut value    tp    fp     tp / all')
for i in range(1,tot_hadrons):
    cut_value = find_max_cut_value(X_train,Y_train,sel_label,i)
    
    # to check how the cut value behaves we get the results on test set
    tp, fp = find_tp_fp(X_test,Y_test,sel_label,cut_value)
    if (tp+fp == 0):
        tp = 1
    #print(cut_value,'  ',tp,'  ',fp,'  ',tp/(tp+fp))
    cut_values.append(cut_value)
    rates.append(tp/(tp+fp))
    absolute_tp.append(tp)
    absolute_fp.append(fp)
    
    if (tp/(tp+fp) > thresh):
        best_cut_thresh = cut_value
        rate_thresh = tp/(tp+fp)
        tp_thresh = tp
        fp_thresh = fp

rates = np.array(rates)
mask = np.where(rates < 1,rates,0)
index = np.argmax(mask)
best_rate = rates[index]
best_cut = cut_values[index]
best_tp = absolute_tp[index]
best_fp = absolute_fp[index]

print('total gammas:',tot_gammas,', tot hadrons:',tot_hadrons,', tot test points:',tot_gammas+tot_hadrons)
print('Best cut value is Alpha =',round(best_cut,4),', with rate:',round(best_rate,4))
print('#TP:',best_tp,'  #FP:',best_fp)
print('Rate of saved gammas:',round(best_tp / tot_gammas,4))
print(' ')
print('Given threshold rate = 0.9, best cut is:',round(best_cut_thresh,4),'with rate',round(rate_thresh,4))
print('#TP:',tp_thresh,'#FP:',fp_thresh,'rate of saved gammas:',round(tp_thresh / tot_gammas,4))

plt.axhline(y=0.9, color='g', linestyle=':',label='threshold')  # Dotted green line
plt.scatter(cut_values,rates, s= 5,label='TP / all accepted')
plt.scatter(best_cut,best_rate,c='red',s=10,label='best rate')
plt.scatter(best_cut_thresh,rate_thresh,c='orange',s=10,label='best threshold rate')
plt.legend()
plt.title('Cut values for Alpha')
plt.xlabel('Alpha values')
plt.ylabel('TPR')
plt.show();

# %% [markdown]
# # Part 7: Grid search for best gammaness and Alpha cut

# %%
print(best_forest)

# %% [markdown]
# We now apply the best model found in the previous part, i.e: the Random Forest, to look for the combination of parameters *gammaness* and *alpha_cut* that maximizes the quality factor *Q*.
#
# What we do is label as background (hadrons) all samples with fAlpha greater than the *alpha_cut* value considered; then we apply the best Random Forest classification to the remaining samples, labelling as gammas only the samples with a predicted probability of belonging to class +1 greater than *gammaness*. Finally, we determine the TPR and FPR to calculate the correspondent Q value.
# To avoid choosing the best combination of *alpha cut* and *gammaness* solely on the performance on a specific test set, we run the same algorithm on different test sets and choose as best case the one that returns the highest average Q value over the iterations.

# %%
# !wget -q https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data

file_name="magic04.data"
data = pd.DataFrame(pd.read_csv(file_name))
data.columns=['fLength','fWidth','fSize',
        'fConc','fConc1','fAsym',
        'fM3Long','fM3Trans','fAlpha','fDist','category']

# %%
data_rescaled = data
original_alpha = data['fAlpha'].copy()

for i in data.drop(columns=['category']).columns:
    h = data[i]
    avg = np.mean(h.astype(float))
    std = np.std(h)
    h = h - avg
    h = h / std
    data_rescaled[i]= h
    
print('avg length:',np.average(data_rescaled['fLength']))
print('dev_std length:',np.std(data_rescaled['fLength']))
data_rescaled['fAlpha'] = original_alpha
data_rescaled['category'] = data['category']
data_rescaled['category'] = data_rescaled['category'].replace({'g':1,'h':-1})

# %%
N=10
test_predictions=[]
gammaness= np.arange(0.8,0.96,0.01)
alpha_cut= np.arange(2,15,1)

for i in range(1,N+1):
    print('Iteration:',i,'\n')
    
    train_set, test_set = split_train_test_set( data_rescaled, 5)
    X_train, Y_train = split_X_Y(train_set)
    X_test, Y_test = split_X_Y(test_set)
    
    best_forest.fit(X_train,Y_train) 

    for alpha in alpha_cut:
        print('\n')
        for g in gammaness:

            test_data = [ X_test[ X_test['fAlpha']<alpha], Y_test[X_test['fAlpha']<alpha] ] 
            discarded_data = X_test[X_test['fAlpha'] >= alpha]
            discarded_labels = Y_test[X_test['fAlpha'] >= alpha] # we directly classify these points as hadrons 
            
            y_pred_prob = best_forest.predict_proba(test_data[0])[:, 1]
            y_pred_label = np.where(y_pred_prob > g, 1, -1)
        
            selected_gammas= np.sum(y_pred_label==1)
            selected_hadrons= np.sum(y_pred_label==-1) + ( X_test.shape[0]-len(test_data[0])) # samples in alpha cut classified as hadron by the model + all samples previously discarded
    
            total_gammas = np.sum(Y_test==1) # over all the test set (before alpha cut)
            total_hadrons = np.sum(Y_test==-1)
            
            true_positives = np.sum( (y_pred_label==1) & (test_data[1]==1) )
            false_positives = np.sum( (y_pred_label==1) & (test_data[1]==-1) )
            true_negatives= np.sum((y_pred_label == -1) & (test_data[1] == -1)) + np.sum((discarded_labels == -1))
            false_negatives= np.sum((y_pred_label == -1) & (test_data[1] == 1)) + np.sum((discarded_labels == 1))
            
            if false_positives != 0:
                epsilon_gamma = true_positives / total_gammas # TPR
                epsilon_hadron = false_positives / total_hadrons # FPR
                Q = epsilon_gamma/np.sqrt(epsilon_hadron)
            else:
                epsilon_hadron= 0
                epsilon_gamma = true_positives / total_gammas
                Q = 'inf'
                
            test_predictions.append({
            'iteration': i,   
            'alpha_cut': alpha,
            'gamma': g,
            'test_data': test_data, 
            'pred_probs': y_pred_prob,
            'pred label': y_pred_label,
            'selected gammas': selected_gammas,
            'selected hadrons': selected_hadrons,
            'total gammas': total_gammas,
            'total hadrons': total_hadrons,
            'true positives': true_positives,
            'false positives': false_positives,
            'true negatives': true_negatives,
            'false negatives': false_negatives,
            'Q': Q })

            if Q != 'inf':
                print(f"With alpha cut {alpha} and gammaness {g:.2f}, Q = {Q:.4f}")
            else:
                print(f"With alpha cut {alpha} and gammanesss {g:.2f}, Q = {Q}")
            print(f"True positives {true_positives}; False positives {false_positives}")
# Out:
# With alpha cut 8 and gammaness 0.81, Q = 2.5405
# True positives 1030; False positives 34
# With alpha cut 8 and gammaness 0.82, Q = 2.5233
# True positives 1023; False positives 34
# With alpha cut 8 and gammaness 0.83, Q = 2.6167
# True positives 1013; False positives 31
# With alpha cut 8 and gammaness 0.84, Q = 2.5831
# True positives 1000; False positives 31
# With alpha cut 8 and gammaness 0.85, Q = 2.6520
# True positives 993; False positives 29
# With alpha cut 8 and gammaness 0.86, Q = 2.7125
# True positives 980; False positives 27
# With alpha cut 8 and gammaness 0.87, Q = 2.6516
# True positives 958; False positives 27
# With alpha cut 8 and gammaness 0.88, Q = 2.6824
# True positives 951; False positives 26
# With alpha cut 8 and gammaness 0.89, Q = 2.8130
# True positives 938; False positives 23
# With alpha cut 8 and gammaness 0.90, Q = 2.7560
# True positives 919; False positives 23
# With alpha cut 8 and gammaness 0.91, Q = 2.7110
# True positives 904; False positives 23
# With alpha cut 8 and gammaness 0.92, Q = 2.7137
# True positives 885; False positives 22
# With alpha cut 8 and gammaness 0.93, Q = 2.8046
# True positives 850; False positives 19
# With alpha cut 8 and gammaness 0.94, Q = 3.0079
# True positives 810; False positives 15
# With alpha cut 8 and gammaness 0.95, Q = 3.1678
# True positives 763; False positives 12
#
#
# With alpha cut 9 and gammaness 0.80, Q = 2.5921
# True positives 1111; False positives 38
# With alpha cut 9 and gammaness 0.81, Q = 2.6198
# True positives 1108; False positives 37
# With alpha cut 9 and gammaness 0.82, Q = 2.5985
# True positives 1099; False positives 37
# With alpha cut 9 and gammaness 0.83, Q = 2.6861
# True positives 1089; False positives 34
# With alpha cut 9 and gammaness 0.84, Q = 2.6540
# True positives 1076; False positives 34
# With alpha cut 9 and gammaness 0.85, Q = 2.7179
# True positives 1069; False positives 32
# With alpha cut 9 and gammaness 0.86, Q = 2.7729
# True positives 1056; False positives 30
# With alpha cut 9 and gammaness 0.87, Q = 2.7125
# True positives 1033; False positives 30
# With alpha cut 9 and gammaness 0.88, Q = 2.7348
# True positives 1024; False positives 29
# With alpha cut 9 and gammaness 0.89, Q = 2.8488
# True positives 1010; False positives 26
# With alpha cut 9 and gammaness 0.90, Q = 2.8448
# True positives 989; False positives 25
# With alpha cut 9 and gammaness 0.91, Q = 2.8565
# True positives 973; False positives 24
# With alpha cut 9 and gammaness 0.92, Q = 2.8520
# True positives 951; False positives 23
# With alpha cut 9 and gammaness 0.93, Q = 2.9330
# True positives 912; False positives 20
# With alpha cut 9 and gammaness 0.94, Q = 3.1174
# True positives 867; False positives 16
# With alpha cut 9 and gammaness 0.95, Q = 3.2510
# True positives 815; False positives 13
#
#
# With alpha cut 10 and gammaness 0.80, Q = 2.5368
# True positives 1170; False positives 44
# With alpha cut 10 and gammaness 0.81, Q = 2.5596
# True positives 1167; False positives 43
# With alpha cut 10 and gammaness 0.82, Q = 2.5332
# True positives 1155; False positives 43
# With alpha cut 10 and gammaness 0.83, Q = 2.6691
# True positives 1144; False positives 38
# With alpha cut 10 and gammaness 0.84, Q = 2.6388
# True positives 1131; False positives 38
# With alpha cut 10 and gammaness 0.85, Q = 2.7276
# True positives 1122; False positives 35
# With alpha cut 10 and gammaness 0.86, Q = 2.7690
# True positives 1106; False positives 33
# With alpha cut 10 and gammaness 0.87, Q = 2.7114
# True positives 1083; False positives 33
# With alpha cut 10 and gammaness 0.88, Q = 2.7665
# True positives 1071; False positives 31
# With alpha cut 10 and gammaness 0.89, Q = 2.8648
# True positives 1054; False positives 28
# With alpha cut 10 and gammaness 0.90, Q = 2.8509
# True positives 1030; False positives 27
# With alpha cut 10 and gammaness 0.91, Q = 2.8516
# True positives 1011; False positives 26
# With alpha cut 10 and gammaness 0.92, Q = 2.8362
# True positives 986; False positives 25
# With alpha cut 10 and gammaness 0.93, Q = 2.8915
# True positives 943; False positives 22
# With alpha cut 10 and gammaness 0.94, Q = 3.0408
# True positives 897; False positives 18
# With alpha cut 10 and gammaness 0.95, Q = 3.1231
# True positives 841; False positives 15
#
#
# With alpha cut 11 and gammaness 0.80, Q = 2.6344
# True positives 1215; False positives 44
# With alpha cut 11 and gammaness 0.81, Q = 2.6561
# True positives 1211; False positives 43
# With alpha cut 11 and gammaness 0.82, Q = 2.6276
# True positives 1198; False positives 43
# With alpha cut 11 and gammaness 0.83, Q = 2.7648
# True positives 1185; False positives 38
# With alpha cut 11 and gammaness 0.84, Q = 2.7321
# True positives 1171; False positives 38
# With alpha cut 11 and gammaness 0.85, Q = 2.8200
# True positives 1160; False positives 35
# With alpha cut 11 and gammaness 0.86, Q = 2.8567
# True positives 1141; False positives 33
# With alpha cut 11 and gammaness 0.87, Q = 2.7891
# True positives 1114; False positives 33
# With alpha cut 11 and gammaness 0.88, Q = 2.8440
# True positives 1101; False positives 31
# With alpha cut 11 and gammaness 0.89, Q = 2.9409
# True positives 1082; False positives 28
# With alpha cut 11 and gammaness 0.90, Q = 2.9229
# True positives 1056; False positives 27
# With alpha cut 11 and gammaness 0.91, Q = 2.9222
# True positives 1036; False positives 26
# With alpha cut 11 and gammaness 0.92, Q = 2.8966
# True positives 1007; False positives 25
# With alpha cut 11 and gammaness 0.93, Q = 2.9498
# True positives 962; False positives 22
# With alpha cut 11 and gammaness 0.94, Q = 3.0950
# True positives 913; False positives 18
# With alpha cut 11 and gammaness 0.95, Q = 3.1750
# True positives 855; False positives 15
#
#
# With alpha cut 12 and gammaness 0.80, Q = 2.6412
# True positives 1259; False positives 47
# With alpha cut 12 and gammaness 0.81, Q = 2.6592
# True positives 1254; False positives 46
# With alpha cut 12 and gammaness 0.82, Q = 2.6543
# True positives 1238; False positives 45
# With alpha cut 12 and gammaness 0.83, Q = 2.7834
# True positives 1224; False positives 40
# With alpha cut 12 and gammaness 0.84, Q = 2.7470
# True positives 1208; False positives 40
# With alpha cut 12 and gammaness 0.85, Q = 2.8645
# True positives 1195; False positives 36
# With alpha cut 12 and gammaness 0.86, Q = 2.9007
# True positives 1176; False positives 34
# With alpha cut 12 and gammaness 0.87, Q = 2.8291
# True positives 1147; False positives 34
# With alpha cut 12 and gammaness 0.88, Q = 2.9267
# True positives 1133; False positives 31
# With alpha cut 12 and gammaness 0.89, Q = 3.0279
# True positives 1114; False positives 28
# With alpha cut 12 and gammaness 0.90, Q = 3.0087
# True positives 1087; False positives 27
# With alpha cut 12 and gammaness 0.91, Q = 3.0096
# True positives 1067; False positives 26
# With alpha cut 12 and gammaness 0.92, Q = 2.9743
# True positives 1034; False positives 25
# With alpha cut 12 and gammaness 0.93, Q = 3.0265
# True positives 987; False positives 22
# With alpha cut 12 and gammaness 0.94, Q = 3.1696
# True positives 935; False positives 18
# With alpha cut 12 and gammaness 0.95, Q = 3.2270
# True positives 869; False positives 15
#
#
# With alpha cut 13 and gammaness 0.80, Q = 2.5919
# True positives 1287; False positives 51
# With alpha cut 13 and gammaness 0.81, Q = 2.6075
# True positives 1282; False positives 50
# With alpha cut 13 and gammaness 0.82, Q = 2.5991
# True positives 1265; False positives 49
# With alpha cut 13 and gammaness 0.83, Q = 2.7103
# True positives 1250; False positives 44
# With alpha cut 13 and gammaness 0.84, Q = 2.6756
# True positives 1234; False positives 44
# With alpha cut 13 and gammaness 0.85, Q = 2.7743
# True positives 1220; False positives 40
# With alpha cut 13 and gammaness 0.86, Q = 2.8021
# True positives 1201; False positives 38
# With alpha cut 13 and gammaness 0.87, Q = 2.7664
# True positives 1170; False positives 37
# With alpha cut 13 and gammaness 0.88, Q = 2.8917
# True positives 1155; False positives 33
# With alpha cut 13 and gammaness 0.89, Q = 2.9803
# True positives 1135; False positives 30
# With alpha cut 13 and gammaness 0.90, Q = 2.9592
# True positives 1108; False positives 29
# With alpha cut 13 and gammaness 0.91, Q = 2.9572
# True positives 1088; False positives 28
# With alpha cut 13 and gammaness 0.92, Q = 2.9701
# True positives 1053; False positives 26
# With alpha cut 13 and gammaness 0.93, Q = 3.0169
# True positives 1006; False positives 23
# With alpha cut 13 and gammaness 0.94, Q = 3.1412
# True positives 952; False positives 19
# With alpha cut 13 and gammaness 0.95, Q = 3.1749
# True positives 883; False positives 16
#
#
# With alpha cut 14 and gammaness 0.80, Q = 2.6077
# True positives 1320; False positives 53
# With alpha cut 14 and gammaness 0.81, Q = 2.6227
# True positives 1315; False positives 52
# With alpha cut 14 and gammaness 0.82, Q = 2.6381
# True positives 1297; False positives 50
# With alpha cut 14 and gammaness 0.83, Q = 2.7443
# True positives 1280; False positives 45
# With alpha cut 14 and gammaness 0.84, Q = 2.7100
# True positives 1264; False positives 45
# With alpha cut 14 and gammaness 0.85, Q = 2.8032
# True positives 1248; False positives 41
# With alpha cut 14 and gammaness 0.86, Q = 2.8304
# True positives 1229; False positives 39
# With alpha cut 14 and gammaness 0.87, Q = 2.7881
# True positives 1195; False positives 38
# With alpha cut 14 and gammaness 0.88, Q = 2.9056
# True positives 1178; False positives 34
# With alpha cut 14 and gammaness 0.89, Q = 2.9887
# True positives 1157; False positives 31
# With alpha cut 14 and gammaness 0.90, Q = 3.0153
# True positives 1129; False positives 29
# With alpha cut 14 and gammaness 0.91, Q = 3.0116
# True positives 1108; False positives 28
# With alpha cut 14 and gammaness 0.92, Q = 3.0209
# True positives 1071; False positives 26
# With alpha cut 14 and gammaness 0.93, Q = 3.0679
# True positives 1023; False positives 23
# With alpha cut 14 and gammaness 0.94, Q = 3.1940
# True positives 968; False positives 19
# With alpha cut 14 and gammaness 0.95, Q = 3.2216
# True positives 896; False positives 16
# Iteration: 2
#
#
#
# With alpha cut 2 and gammaness 0.80, Q = 1.9370
# True positives 323; False positives 6
# With alpha cut 2 and gammaness 0.81, Q = 1.9310
# True positives 322; False positives 6
# With alpha cut 2 and gammaness 0.82, Q = 2.0956
# True positives 319; False positives 5
# With alpha cut 2 and gammaness 0.83, Q = 2.0825
# True positives 317; False positives 5
# With alpha cut 2 and gammaness 0.84, Q = 2.0693
# True positives 315; False positives 5
# With alpha cut 2 and gammaness 0.85, Q = 2.0628
# True positives 314; False positives 5
# With alpha cut 2 and gammaness 0.86, Q = 2.0365
# True positives 310; False positives 5
# With alpha cut 2 and gammaness 0.87, Q = 1.9905
# True positives 303; False positives 5
# With alpha cut 2 and gammaness 0.88, Q = 1.9445
# True positives 296; False positives 5
# With alpha cut 2 and gammaness 0.89, Q = 1.8985
# True positives 289; False positives 5
# With alpha cut 2 and gammaness 0.90, Q = 1.8657
# True positives 284; False positives 5
# With alpha cut 2 and gammaness 0.91, Q = 1.8394
# True positives 280; False positives 5
# With alpha cut 2 and gammaness 0.92, Q = 1.7803
# True positives 271; False positives 5
# With alpha cut 2 and gammaness 0.93, Q = 1.6883
# True positives 257; False positives 5
# With alpha cut 2 and gammaness 0.94, Q = 1.8068
# True positives 246; False positives 4
# With alpha cut 2 and gammaness 0.95, Q = 2.4098
# True positives 232; False positives 2
#
#
# With alpha cut 3 and gammaness 0.80, Q = 2.1791
# True positives 492; False positives 11
# With alpha cut 3 and gammaness 0.81, Q = 2.1747
# True positives 491; False positives 11
# With alpha cut 3 and gammaness 0.82, Q = 2.2576
# True positives 486; False positives 10
# With alpha cut 3 and gammaness 0.83, Q = 2.2390
# True positives 482; False positives 10
# With alpha cut 3 and gammaness 0.84, Q = 2.2111
# True positives 476; False positives 10
# With alpha cut 3 and gammaness 0.85, Q = 2.1925
# True positives 472; False positives 10
# With alpha cut 3 and gammaness 0.86, Q = 2.2818
# True positives 466; False positives 9
# With alpha cut 3 and gammaness 0.87, Q = 2.2328
# True positives 456; False positives 9
# With alpha cut 3 and gammaness 0.88, Q = 2.1789
# True positives 445; False positives 9
# With alpha cut 3 and gammaness 0.89, Q = 2.1300
# True positives 435; False positives 9
# With alpha cut 3 and gammaness 0.90, Q = 2.0859
# True positives 426; False positives 9
# With alpha cut 3 and gammaness 0.91, Q = 2.1865
# True positives 421; False positives 8
# With alpha cut 3 and gammaness 0.92, Q = 2.1190
# True positives 408; False positives 8
# With alpha cut 3 and gammaness 0.93, Q = 2.1653
# True positives 390; False positives 7
# With alpha cut 3 and gammaness 0.94, Q = 2.2129
# True positives 369; False positives 6
# With alpha cut 3 and gammaness 0.95, Q = 2.5560
# True positives 348; False positives 4
#
#
# With alpha cut 4 and gammaness 0.80, Q = 2.2267
# True positives 625; False positives 17
# With alpha cut 4 and gammaness 0.81, Q = 2.2231
# True positives 624; False positives 17
# With alpha cut 4 and gammaness 0.82, Q = 2.2732
# True positives 619; False positives 16
# With alpha cut 4 and gammaness 0.83, Q = 2.2475
# True positives 612; False positives 16
# With alpha cut 4 and gammaness 0.84, Q = 2.2144
# True positives 603; False positives 16
# With alpha cut 4 and gammaness 0.85, Q = 2.1924
# True positives 597; False positives 16
# With alpha cut 4 and gammaness 0.86, Q = 2.2416
# True positives 591; False positives 15
# With alpha cut 4 and gammaness 0.87, Q = 2.1960
# True positives 579; False positives 15
# With alpha cut 4 and gammaness 0.88, Q = 2.1467
# True positives 566; False positives 15
# With alpha cut 4 and gammaness 0.89, Q = 2.1710
# True positives 553; False positives 14
# With alpha cut 4 and gammaness 0.90, Q = 2.1279
# True positives 542; False positives 14
# With alpha cut 4 and gammaness 0.91, Q = 2.2771
# True positives 537; False positives 12
# With alpha cut 4 and gammaness 0.92, Q = 2.2093
# True positives 521; False positives 12
# With alpha cut 4 and gammaness 0.93, Q = 2.2057
# True positives 498; False positives 11
# With alpha cut 4 and gammaness 0.94, Q = 2.1925
# True positives 472; False positives 10
# With alpha cut 4 and gammaness 0.95, Q = 2.2955
# True positives 442; False positives 8
#
#
# With alpha cut 5 and gammaness 0.80, Q = 2.3081
# True positives 737; False positives 22
# With alpha cut 5 and gammaness 0.81, Q = 2.4109
# True positives 734; False positives 20
# With alpha cut 5 and gammaness 0.82, Q = 2.4567
# True positives 729; False positives 19
# With alpha cut 5 and gammaness 0.83, Q = 2.4298
# True positives 721; False positives 19
# With alpha cut 5 and gammaness 0.84, Q = 2.3961
# True positives 711; False positives 19
# With alpha cut 5 and gammaness 0.85, Q = 2.3758
# True positives 705; False positives 19
# With alpha cut 5 and gammaness 0.86, Q = 2.4868
# True positives 698; False positives 17
# With alpha cut 5 and gammaness 0.87, Q = 2.4333
# True positives 683; False positives 17
# With alpha cut 5 and gammaness 0.88, Q = 2.3799
# True positives 668; False positives 17
# With alpha cut 5 and gammaness 0.89, Q = 2.4054
# True positives 655; False positives 16
# With alpha cut 5 and gammaness 0.90, Q = 2.3540
# True positives 641; False positives 16
# With alpha cut 5 and gammaness 0.91, Q = 2.4851
# True positives 633; False positives 14
# With alpha cut 5 and gammaness 0.92, Q = 2.4144
# True positives 615; False positives 14
# With alpha cut 5 and gammaness 0.93, Q = 2.3956
# True positives 588; False positives 13
# With alpha cut 5 and gammaness 0.94, Q = 2.3789
# True positives 561; False positives 12
# With alpha cut 5 and gammaness 0.95, Q = 2.4387
# True positives 525; False positives 10
#
#
# With alpha cut 6 and gammaness 0.80, Q = 2.4343
# True positives 845; False positives 26
# With alpha cut 6 and gammaness 0.81, Q = 2.5187
# True positives 840; False positives 24
# With alpha cut 6 and gammaness 0.82, Q = 2.5576
# True positives 835; False positives 23
# With alpha cut 6 and gammaness 0.83, Q = 2.5331
# True positives 827; False positives 23
# With alpha cut 6 and gammaness 0.84, Q = 2.4994
# True positives 816; False positives 23
# With alpha cut 6 and gammaness 0.85, Q = 2.4779
# True positives 809; False positives 23
# With alpha cut 6 and gammaness 0.86, Q = 2.5676
# True positives 801; False positives 21
# With alpha cut 6 and gammaness 0.87, Q = 2.5163
# True positives 785; False positives 21
# With alpha cut 6 and gammaness 0.88, Q = 2.4650
# True positives 769; False positives 21
# With alpha cut 6 and gammaness 0.89, Q = 2.4766
# True positives 754; False positives 20
# With alpha cut 6 and gammaness 0.90, Q = 2.4803
# True positives 736; False positives 19
# With alpha cut 6 and gammaness 0.91, Q = 2.5865
# True positives 726; False positives 17
# With alpha cut 6 and gammaness 0.92, Q = 2.5153
# True positives 706; False positives 17
# With alpha cut 6 and gammaness 0.93, Q = 2.4825
# True positives 676; False positives 16
# With alpha cut 6 and gammaness 0.94, Q = 2.5283
# True positives 644; False positives 14
# With alpha cut 6 and gammaness 0.95, Q = 2.5697
# True positives 606; False positives 12
#
#
# With alpha cut 7 and gammaness 0.80, Q = 2.4642
# True positives 934; False positives 31
# With alpha cut 7 and gammaness 0.81, Q = 2.5286
# True positives 927; False positives 29
# With alpha cut 7 and gammaness 0.82, Q = 2.5540
# True positives 920; False positives 28
# With alpha cut 7 and gammaness 0.83, Q = 2.5318
# True positives 912; False positives 28
# With alpha cut 7 and gammaness 0.84, Q = 2.4984
# True positives 900; False positives 28
# With alpha cut 7 and gammaness 0.85, Q = 2.4790
# True positives 893; False positives 28
# With alpha cut 7 and gammaness 0.86, Q = 2.5467
# True positives 884; False positives 26
# With alpha cut 7 and gammaness 0.87, Q = 2.4948
# True positives 866; False positives 26
# With alpha cut 7 and gammaness 0.88, Q = 2.4401
# True positives 847; False positives 26
# With alpha cut 7 and gammaness 0.89, Q = 2.4267
# True positives 826; False positives 25
# With alpha cut 7 and gammaness 0.90, Q = 2.4198
# True positives 807; False positives 24
# With alpha cut 7 and gammaness 0.91, Q = 2.4929
# True positives 796; False positives 22
# With alpha cut 7 and gammaness 0.92, Q = 2.4240
# True positives 774; False positives 22
# With alpha cut 7 and gammaness 0.93, Q = 2.3785
# True positives 742; False positives 21
# With alpha cut 7 and gammaness 0.94, Q = 2.4479
# True positives 707; False positives 18
# With alpha cut 7 and gammaness 0.95, Q = 2.5184
# True positives 664; False positives 15
#
#
# With alpha cut 8 and gammaness 0.80, Q = 2.5369
# True positives 1007; False positives 34
# With alpha cut 8 and gammaness 0.81, Q = 2.6383
# True positives 1000; False positives 31
# With alpha cut 8 and gammaness 0.82, Q = 2.6605
# True positives 992; False positives 30
# With alpha cut 8 and gammaness 0.83, Q = 2.6390
# True positives 984; False positives 30
# With alpha cut 8 and gammaness 0.84, Q = 2.6041
# True positives 971; False positives 30
# With alpha cut 8 and gammaness 0.85, Q = 2.5854
# True positives 964; False positives 30
# With alpha cut 8 and gammaness 0.86, Q = 2.6484
# True positives 954; False positives 28
# With alpha cut 8 and gammaness 0.87, Q = 2.5928
# True positives 934; False positives 28
# With alpha cut 8 and gammaness 0.88, Q = 2.5401
# True positives 915; False positives 28
# With alpha cut 8 and gammaness 0.89, Q = 2.5189
# True positives 891; False positives 27
# With alpha cut 8 and gammaness 0.90, Q = 2.5063
# True positives 870; False positives 26
# With alpha cut 8 and gammaness 0.91, Q = 2.5667
# True positives 856; False positives 24
# With alpha cut 8 and gammaness 0.92, Q = 2.4917
# True positives 831; False positives 24
# With alpha cut 8 and gammaness 0.93, Q = 2.4381
# True positives 796; False positives 23
# With alpha cut 8 and gammaness 0.94, Q = 2.4963
# True positives 760; False positives 20
# With alpha cut 8 and gammaness 0.95, Q = 2.6111
# True positives 711; False positives 16
#
#
# With alpha cut 9 and gammaness 0.80, Q = 2.6033
# True positives 1078; False positives 37
# With alpha cut 9 and gammaness 0.81, Q = 2.6981
# True positives 1071; False positives 34
# With alpha cut 9 and gammaness 0.82, Q = 2.7182
# True positives 1063; False positives 33
# With alpha cut 9 and gammaness 0.83, Q = 2.6978
# True positives 1055; False positives 33
# With alpha cut 9 and gammaness 0.84, Q = 2.6620
# True positives 1041; False positives 33
# With alpha cut 9 and gammaness 0.85, Q = 2.6389
# True positives 1032; False positives 33
# With alpha cut 9 and gammaness 0.86, Q = 2.6937
# True positives 1021; False positives 31
# With alpha cut 9 and gammaness 0.87, Q = 2.6383
# True positives 1000; False positives 31
# With alpha cut 9 and gammaness 0.88, Q = 2.6283
# True positives 980; False positives 30
# With alpha cut 9 and gammaness 0.89, Q = 2.6456
# True positives 953; False positives 28
# With alpha cut 9 and gammaness 0.90, Q = 2.6291
# True positives 930; False positives 27
# With alpha cut 9 and gammaness 0.91, Q = 2.6911
# True positives 916; False positives 25
# With alpha cut 9 and gammaness 0.92, Q = 2.6118
# True positives 889; False positives 25
# With alpha cut 9 and gammaness 0.93, Q = 2.5487
# True positives 850; False positives 24
# With alpha cut 9 and gammaness 0.94, Q = 2.5997
# True positives 811; False positives 21
# With alpha cut 9 and gammaness 0.95, Q = 2.6863
# True positives 754; False positives 17
#
#
# With alpha cut 10 and gammaness 0.80, Q = 2.6839
# True positives 1141; False positives 39
# With alpha cut 10 and gammaness 0.81, Q = 2.7763
# True positives 1134; False positives 36
# With alpha cut 10 and gammaness 0.82, Q = 2.8266
# True positives 1122; False positives 34
# With alpha cut 10 and gammaness 0.83, Q = 2.8039
# True positives 1113; False positives 34
# With alpha cut 10 and gammaness 0.84, Q = 2.7686
# True positives 1099; False positives 34
# With alpha cut 10 and gammaness 0.85, Q = 2.7409
# True positives 1088; False positives 34
# With alpha cut 10 and gammaness 0.86, Q = 2.7915
# True positives 1075; False positives 32
# With alpha cut 10 and gammaness 0.87, Q = 2.7240
# True positives 1049; False positives 32
# With alpha cut 10 and gammaness 0.88, Q = 2.7069
# True positives 1026; False positives 31
# With alpha cut 10 and gammaness 0.89, Q = 2.7649
# True positives 996; False positives 28
# With alpha cut 10 and gammaness 0.90, Q = 2.7450
# True positives 971; False positives 27
# With alpha cut 10 and gammaness 0.91, Q = 2.8028
# True positives 954; False positives 25
# With alpha cut 10 and gammaness 0.92, Q = 2.7205
# True positives 926; False positives 25
# With alpha cut 10 and gammaness 0.93, Q = 2.6537
# True positives 885; False positives 24
# With alpha cut 10 and gammaness 0.94, Q = 2.6926
# True positives 840; False positives 21
# With alpha cut 10 and gammaness 0.95, Q = 2.7611
# True positives 775; False positives 17
#
#
# With alpha cut 11 and gammaness 0.80, Q = 2.7483
# True positives 1198; False positives 41
# With alpha cut 11 and gammaness 0.81, Q = 2.8357
# True positives 1190; False positives 38
# With alpha cut 11 and gammaness 0.82, Q = 2.8791
# True positives 1176; False positives 36
# With alpha cut 11 and gammaness 0.83, Q = 2.8498
# True positives 1164; False positives 36
# With alpha cut 11 and gammaness 0.84, Q = 2.8529
# True positives 1149; False positives 35
# With alpha cut 11 and gammaness 0.85, Q = 2.8231
# True positives 1137; False positives 35
# With alpha cut 11 and gammaness 0.86, Q = 2.8742
# True positives 1124; False positives 33
# With alpha cut 11 and gammaness 0.87, Q = 2.8077
# True positives 1098; False positives 33
# With alpha cut 11 and gammaness 0.88, Q = 2.7837
# True positives 1072; False positives 32
# With alpha cut 11 and gammaness 0.89, Q = 2.8314
# True positives 1038; False positives 29
# With alpha cut 11 and gammaness 0.90, Q = 2.8066
# True positives 1011; False positives 28
# With alpha cut 11 and gammaness 0.91, Q = 2.8578
# True positives 992; False positives 26
# With alpha cut 11 and gammaness 0.92, Q = 2.7598
# True positives 958; False positives 26
# With alpha cut 11 and gammaness 0.93, Q = 2.6823
# True positives 913; False positives 25
# With alpha cut 11 and gammaness 0.94, Q = 2.7121
# True positives 866; False positives 22
# With alpha cut 11 and gammaness 0.95, Q = 2.7560
# True positives 796; False positives 18
#
#
# With alpha cut 12 and gammaness 0.80, Q = 2.7778
# True positives 1240; False positives 43
# With alpha cut 12 and gammaness 0.81, Q = 2.8615
# True positives 1232; False positives 40
# With alpha cut 12 and gammaness 0.82, Q = 2.9366
# True positives 1216; False positives 37
# With alpha cut 12 and gammaness 0.83, Q = 2.9076
# True positives 1204; False positives 37
# With alpha cut 12 and gammaness 0.84, Q = 2.9473
# True positives 1187; False positives 35
# With alpha cut 12 and gammaness 0.85, Q = 2.9125
# True positives 1173; False positives 35
# With alpha cut 12 and gammaness 0.86, Q = 2.9637
# True positives 1159; False positives 33
# With alpha cut 12 and gammaness 0.87, Q = 2.8921
# True positives 1131; False positives 33
# With alpha cut 12 and gammaness 0.88, Q = 2.8590
# True positives 1101; False positives 32
# With alpha cut 12 and gammaness 0.89, Q = 2.9023
# True positives 1064; False positives 29
# With alpha cut 12 and gammaness 0.90, Q = 2.8788
# True positives 1037; False positives 28
# With alpha cut 12 and gammaness 0.91, Q = 2.9154
# True positives 1012; False positives 26
# With alpha cut 12 and gammaness 0.92, Q = 2.8146
# True positives 977; False positives 26
# With alpha cut 12 and gammaness 0.93, Q = 2.7352
# True positives 931; False positives 25
# With alpha cut 12 and gammaness 0.94, Q = 2.7623
# True positives 882; False positives 22
# With alpha cut 12 and gammaness 0.95, Q = 2.7976
# True positives 808; False positives 18
#
#
# With alpha cut 13 and gammaness 0.80, Q = 2.8169
# True positives 1272; False positives 44
# With alpha cut 13 and gammaness 0.81, Q = 2.8998
# True positives 1264; False positives 41
# With alpha cut 13 and gammaness 0.82, Q = 2.9715
# True positives 1247; False positives 38
# With alpha cut 13 and gammaness 0.83, Q = 2.9429
# True positives 1235; False positives 38
# With alpha cut 13 and gammaness 0.84, Q = 2.9795
# True positives 1217; False positives 36
# With alpha cut 13 and gammaness 0.85, Q = 2.9821
# True positives 1201; False positives 35
# With alpha cut 13 and gammaness 0.86, Q = 3.0327
# True positives 1186; False positives 33
# With alpha cut 13 and gammaness 0.87, Q = 2.9611
# True positives 1158; False positives 33
# With alpha cut 13 and gammaness 0.88, Q = 2.9240
# True positives 1126; False positives 32
# With alpha cut 13 and gammaness 0.89, Q = 2.9678
# True positives 1088; False positives 29
# With alpha cut 13 and gammaness 0.90, Q = 2.9371
# True positives 1058; False positives 28
# With alpha cut 13 and gammaness 0.91, Q = 2.9730
# True positives 1032; False positives 26
# With alpha cut 13 and gammaness 0.92, Q = 2.8693
# True positives 996; False positives 26
# With alpha cut 13 and gammaness 0.93, Q = 2.7851
# True positives 948; False positives 25
# With alpha cut 13 and gammaness 0.94, Q = 2.7967
# True positives 893; False positives 22
# With alpha cut 13 and gammaness 0.95, Q = 2.8287
# True positives 817; False positives 18
#
#
# With alpha cut 14 and gammaness 0.80, Q = 2.8401
# True positives 1297; False positives 45
# With alpha cut 14 and gammaness 0.81, Q = 2.9172
# True positives 1287; False positives 42
# With alpha cut 14 and gammaness 0.82, Q = 2.9873
# True positives 1270; False positives 39
# With alpha cut 14 and gammaness 0.83, Q = 2.9567
# True positives 1257; False positives 39
# With alpha cut 14 and gammaness 0.84, Q = 2.9897
# True positives 1238; False positives 37
# With alpha cut 14 and gammaness 0.85, Q = 2.9893
# True positives 1221; False positives 36
# With alpha cut 14 and gammaness 0.86, Q = 3.0357
# True positives 1205; False positives 34
# With alpha cut 14 and gammaness 0.87, Q = 2.9651
# True positives 1177; False positives 34
# With alpha cut 14 and gammaness 0.88, Q = 2.9279
# True positives 1145; False positives 33
# With alpha cut 14 and gammaness 0.89, Q = 2.9689
# True positives 1107; False positives 30
# With alpha cut 14 and gammaness 0.90, Q = 2.9269
# True positives 1073; False positives 29
# With alpha cut 14 and gammaness 0.91, Q = 3.0162
# True positives 1047; False positives 26
# With alpha cut 14 and gammaness 0.92, Q = 2.9097
# True positives 1010; False positives 26
# With alpha cut 14 and gammaness 0.93, Q = 2.8204
# True positives 960; False positives 25
# With alpha cut 14 and gammaness 0.94, Q = 2.8312
# True positives 904; False positives 22
# With alpha cut 14 and gammaness 0.95, Q = 2.8599
# True positives 826; False positives 18
# Iteration: 3
#
#
#
# With alpha cut 2 and gammaness 0.80, Q = 1.5593
# True positives 331; False positives 10
# With alpha cut 2 and gammaness 0.81, Q = 1.6387
# True positives 330; False positives 9
# With alpha cut 2 and gammaness 0.82, Q = 1.7223
# True positives 327; False positives 8
# With alpha cut 2 and gammaness 0.83, Q = 1.7170
# True positives 326; False positives 8
# With alpha cut 2 and gammaness 0.84, Q = 1.7065
# True positives 324; False positives 8
# With alpha cut 2 and gammaness 0.85, Q = 1.6854
# True positives 320; False positives 8
# With alpha cut 2 and gammaness 0.86, Q = 1.6749
# True positives 318; False positives 8
# With alpha cut 2 and gammaness 0.87, Q = 1.7455
# True positives 310; False positives 7
# With alpha cut 2 and gammaness 0.88, Q = 1.8428
# True positives 303; False positives 6
# With alpha cut 2 and gammaness 0.89, Q = 1.8063
# True positives 297; False positives 6
# With alpha cut 2 and gammaness 0.90, Q = 1.7819
# True positives 293; False positives 6
# With alpha cut 2 and gammaness 0.91, Q = 1.9121
# True positives 287; False positives 5
# With alpha cut 2 and gammaness 0.92, Q = 1.8787
# True positives 282; False positives 5
# With alpha cut 2 and gammaness 0.93, Q = 2.0335
# True positives 273; False positives 4
# With alpha cut 2 and gammaness 0.94, Q = 1.9143
# True positives 257; False positives 4
# With alpha cut 2 and gammaness 0.95, Q = 2.5913
# True positives 246; False positives 2
#
#
# With alpha cut 3 and gammaness 0.80, Q = 1.6089
# True positives 483; False positives 20
# With alpha cut 3 and gammaness 0.81, Q = 1.6889
# True positives 481; False positives 18
# With alpha cut 3 and gammaness 0.82, Q = 1.7198
# True positives 476; False positives 17
# With alpha cut 3 and gammaness 0.83, Q = 1.7616
# True positives 473; False positives 16
# With alpha cut 3 and gammaness 0.84, Q = 1.7504
# True positives 470; False positives 16
# With alpha cut 3 and gammaness 0.85, Q = 1.7318
# True positives 465; False positives 16
# With alpha cut 3 and gammaness 0.86, Q = 1.7132
# True positives 460; False positives 16
# With alpha cut 3 and gammaness 0.87, Q = 1.7347
# True positives 451; False positives 15
# With alpha cut 3 and gammaness 0.88, Q = 1.7558
# True positives 441; False positives 14
# With alpha cut 3 and gammaness 0.89, Q = 1.7279
# True positives 434; False positives 14
# With alpha cut 3 and gammaness 0.90, Q = 1.7642
# True positives 427; False positives 13
# With alpha cut 3 and gammaness 0.91, Q = 1.7976
# True positives 418; False positives 12
# With alpha cut 3 and gammaness 0.92, Q = 1.7632
# True positives 410; False positives 12
# With alpha cut 3 and gammaness 0.93, Q = 1.7922
# True positives 399; False positives 11
# With alpha cut 3 and gammaness 0.94, Q = 1.6978
# True positives 378; False positives 11
# With alpha cut 3 and gammaness 0.95, Q = 2.0326
# True positives 361; False positives 7
#
#
# With alpha cut 4 and gammaness 0.80, Q = 1.9321
# True positives 622; False positives 23
# With alpha cut 4 and gammaness 0.81, Q = 2.0155
# True positives 620; False positives 21
# With alpha cut 4 and gammaness 0.82, Q = 2.0453
# True positives 614; False positives 20
# With alpha cut 4 and gammaness 0.83, Q = 2.0882
# True positives 611; False positives 19
# With alpha cut 4 and gammaness 0.84, Q = 2.0711
# True positives 606; False positives 19
# With alpha cut 4 and gammaness 0.85, Q = 2.0540
# True positives 601; False positives 19
# With alpha cut 4 and gammaness 0.86, Q = 2.0369
# True positives 596; False positives 19
# With alpha cut 4 and gammaness 0.87, Q = 2.0611
# True positives 587; False positives 18
# With alpha cut 4 and gammaness 0.88, Q = 2.0848
# True positives 577; False positives 17
# With alpha cut 4 and gammaness 0.89, Q = 2.1154
# True positives 568; False positives 16
# With alpha cut 4 and gammaness 0.90, Q = 2.1463
# True positives 558; False positives 15
# With alpha cut 4 and gammaness 0.91, Q = 2.1739
# True positives 546; False positives 14
# With alpha cut 4 and gammaness 0.92, Q = 2.1261
# True positives 534; False positives 14
# With alpha cut 4 and gammaness 0.93, Q = 2.1402
# True positives 518; False positives 13
# With alpha cut 4 and gammaness 0.94, Q = 2.0328
# True positives 492; False positives 13
# With alpha cut 4 and gammaness 0.95, Q = 2.3339
# True positives 470; False positives 9
#
#
# With alpha cut 5 and gammaness 0.80, Q = 2.0372
# True positives 749; False positives 30
# With alpha cut 5 and gammaness 0.81, Q = 2.0918
# True positives 743; False positives 28
# With alpha cut 5 and gammaness 0.82, Q = 2.1129
# True positives 737; False positives 27
# With alpha cut 5 and gammaness 0.83, Q = 2.1869
# True positives 734; False positives 25
# With alpha cut 5 and gammaness 0.84, Q = 2.1690
# True positives 728; False positives 25
# With alpha cut 5 and gammaness 0.85, Q = 2.1541
# True positives 723; False positives 25
# With alpha cut 5 and gammaness 0.86, Q = 2.1303
# True positives 715; False positives 25
# With alpha cut 5 and gammaness 0.87, Q = 2.1438
# True positives 705; False positives 24
# With alpha cut 5 and gammaness 0.88, Q = 2.1589
# True positives 695; False positives 23
# With alpha cut 5 and gammaness 0.89, Q = 2.1756
# True positives 685; False positives 22
# With alpha cut 5 and gammaness 0.90, Q = 2.1878
# True positives 673; False positives 21
# With alpha cut 5 and gammaness 0.91, Q = 2.2591
# True positives 661; False positives 19
# With alpha cut 5 and gammaness 0.92, Q = 2.2078
# True positives 646; False positives 19
# With alpha cut 5 and gammaness 0.93, Q = 2.2618
# True positives 626; False positives 17
# With alpha cut 5 and gammaness 0.94, Q = 2.1642
# True positives 599; False positives 17
# With alpha cut 5 and gammaness 0.95, Q = 2.3592
# True positives 571; False positives 13
#
#
# With alpha cut 6 and gammaness 0.80, Q = 2.1767
# True positives 852; False positives 34
# With alpha cut 6 and gammaness 0.81, Q = 2.2279
# True positives 846; False positives 32
# With alpha cut 6 and gammaness 0.82, Q = 2.2448
# True positives 839; False positives 31
# With alpha cut 6 and gammaness 0.83, Q = 2.3127
# True positives 836; False positives 29
# With alpha cut 6 and gammaness 0.84, Q = 2.2961
# True positives 830; False positives 29
# With alpha cut 6 and gammaness 0.85, Q = 2.3226
# True positives 825; False positives 28
# With alpha cut 6 and gammaness 0.86, Q = 2.3001
# True positives 817; False positives 28
# With alpha cut 6 and gammaness 0.87, Q = 2.3079
# True positives 805; False positives 27
# With alpha cut 6 and gammaness 0.88, Q = 2.3226
# True positives 795; False positives 26
# With alpha cut 6 and gammaness 0.89, Q = 2.3840
# True positives 784; False positives 24
# With alpha cut 6 and gammaness 0.90, Q = 2.3918
# True positives 770; False positives 23
# With alpha cut 6 and gammaness 0.91, Q = 2.4609
# True positives 757; False positives 21
# With alpha cut 6 and gammaness 0.92, Q = 2.4121
# True positives 742; False positives 21
# With alpha cut 6 and gammaness 0.93, Q = 2.4641
# True positives 721; False positives 19
# With alpha cut 6 and gammaness 0.94, Q = 2.3513
# True positives 688; False positives 19
# With alpha cut 6 and gammaness 0.95, Q = 2.5117
# True positives 653; False positives 15
#
#
# With alpha cut 7 and gammaness 0.80, Q = 2.2280
# True positives 934; False positives 39
# With alpha cut 7 and gammaness 0.81, Q = 2.2678
# True positives 926; False positives 37
# With alpha cut 7 and gammaness 0.82, Q = 2.2793
# True positives 918; False positives 36
# With alpha cut 7 and gammaness 0.83, Q = 2.3300
# True positives 912; False positives 34
# With alpha cut 7 and gammaness 0.84, Q = 2.3147
# True positives 906; False positives 34
# With alpha cut 7 and gammaness 0.85, Q = 2.3339
# True positives 900; False positives 33
# With alpha cut 7 and gammaness 0.86, Q = 2.3132
# True positives 892; False positives 33
# With alpha cut 7 and gammaness 0.87, Q = 2.3519
# True positives 879; False positives 31
# With alpha cut 7 and gammaness 0.88, Q = 2.3581
# True positives 867; False positives 30
# With alpha cut 7 and gammaness 0.89, Q = 2.4014
# True positives 853; False positives 28
# With alpha cut 7 and gammaness 0.90, Q = 2.3996
# True positives 837; False positives 27
# With alpha cut 7 and gammaness 0.91, Q = 2.4521
# True positives 823; False positives 25
# With alpha cut 7 and gammaness 0.92, Q = 2.4014
# True positives 806; False positives 25
# With alpha cut 7 and gammaness 0.93, Q = 2.4322
# True positives 783; False positives 23
# With alpha cut 7 and gammaness 0.94, Q = 2.3080
# True positives 743; False positives 23
# With alpha cut 7 and gammaness 0.95, Q = 2.4614
# True positives 701; False positives 18
#
#
# With alpha cut 8 and gammaness 0.80, Q = 2.2540
# True positives 1015; False positives 45
# With alpha cut 8 and gammaness 0.81, Q = 2.2832
# True positives 1005; False positives 43
# With alpha cut 8 and gammaness 0.82, Q = 2.2918
# True positives 997; False positives 42
# With alpha cut 8 and gammaness 0.83, Q = 2.3248
# True positives 987; False positives 40
# With alpha cut 8 and gammaness 0.84, Q = 2.3083
# True positives 980; False positives 40
# With alpha cut 8 and gammaness 0.85, Q = 2.3234
# True positives 974; False positives 39
# With alpha cut 8 and gammaness 0.86, Q = 2.3272
# True positives 963; False positives 38
# With alpha cut 8 and gammaness 0.87, Q = 2.3562
# True positives 949; False positives 36
# With alpha cut 8 and gammaness 0.88, Q = 2.3569
# True positives 936; False positives 35
# With alpha cut 8 and gammaness 0.89, Q = 2.4254
# True positives 921; False positives 32
# With alpha cut 8 and gammaness 0.90, Q = 2.4161
# True positives 903; False positives 31
# With alpha cut 8 and gammaness 0.91, Q = 2.5487
# True positives 889; False positives 27
# With alpha cut 8 and gammaness 0.92, Q = 2.4828
# True positives 866; False positives 27
# With alpha cut 8 and gammaness 0.93, Q = 2.5057
# True positives 841; False positives 25
# With alpha cut 8 and gammaness 0.94, Q = 2.3716
# True positives 796; False positives 25
# With alpha cut 8 and gammaness 0.95, Q = 2.5017
# True positives 751; False positives 20
#
#
# With alpha cut 9 and gammaness 0.80, Q = 2.3533
# True positives 1083; False positives 47
# With alpha cut 9 and gammaness 0.81, Q = 2.3828
# True positives 1073; False positives 45
# With alpha cut 9 and gammaness 0.82, Q = 2.4172
# True positives 1064; False positives 43
# With alpha cut 9 and gammaness 0.83, Q = 2.4475
# True positives 1052; False positives 41
# With alpha cut 9 and gammaness 0.84, Q = 2.4266
# True positives 1043; False positives 41
# With alpha cut 9 and gammaness 0.85, Q = 2.4402
# True positives 1036; False positives 40
# With alpha cut 9 and gammaness 0.86, Q = 2.4427
# True positives 1024; False positives 39
# With alpha cut 9 and gammaness 0.87, Q = 2.4687
# True positives 1008; False positives 37
# With alpha cut 9 and gammaness 0.88, Q = 2.4655
# True positives 993; False positives 36
# With alpha cut 9 and gammaness 0.89, Q = 2.5310
# True positives 976; False positives 33
# With alpha cut 9 and gammaness 0.90, Q = 2.5176
# True positives 956; False positives 32
# With alpha cut 9 and gammaness 0.91, Q = 2.6407
# True positives 938; False positives 28
# With alpha cut 9 and gammaness 0.92, Q = 2.5732
# True positives 914; False positives 28
# With alpha cut 9 and gammaness 0.93, Q = 2.6428
# True positives 887; False positives 25
# With alpha cut 9 and gammaness 0.94, Q = 2.5057
# True positives 841; False positives 25
# With alpha cut 9 and gammaness 0.95, Q = 2.6349
# True positives 791; False positives 20
#
#
# With alpha cut 10 and gammaness 0.80, Q = 2.3927
# True positives 1147; False positives 51
# With alpha cut 10 and gammaness 0.81, Q = 2.4155
# True positives 1135; False positives 49
# With alpha cut 10 and gammaness 0.82, Q = 2.4710
# True positives 1125; False positives 46
# With alpha cut 10 and gammaness 0.83, Q = 2.4996
# True positives 1113; False positives 44
# With alpha cut 10 and gammaness 0.84, Q = 2.4794
# True positives 1104; False positives 44
# With alpha cut 10 and gammaness 0.85, Q = 2.4922
# True positives 1097; False positives 43
# With alpha cut 10 and gammaness 0.86, Q = 2.4895
# True positives 1083; False positives 42
# With alpha cut 10 and gammaness 0.87, Q = 2.5062
# True positives 1064; False positives 40
# With alpha cut 10 and gammaness 0.88, Q = 2.4928
# True positives 1045; False positives 39
# With alpha cut 10 and gammaness 0.89, Q = 2.5524
# True positives 1028; False positives 36
# With alpha cut 10 and gammaness 0.90, Q = 2.5307
# True positives 1005; False positives 35
# With alpha cut 10 and gammaness 0.91, Q = 2.6381
# True positives 986; False positives 31
# With alpha cut 10 and gammaness 0.92, Q = 2.5659
# True positives 959; False positives 31
# With alpha cut 10 and gammaness 0.93, Q = 2.6098
# True positives 927; False positives 28
# With alpha cut 10 and gammaness 0.94, Q = 2.4718
# True positives 878; False positives 28
# With alpha cut 10 and gammaness 0.95, Q = 2.5565
# True positives 823; False positives 23
#
#
# With alpha cut 11 and gammaness 0.80, Q = 2.4347
# True positives 1201; False positives 54
# With alpha cut 11 and gammaness 0.81, Q = 2.4542
# True positives 1188; False positives 52
# With alpha cut 11 and gammaness 0.82, Q = 2.5048
# True positives 1177; False positives 49
# With alpha cut 11 and gammaness 0.83, Q = 2.5293
# True positives 1164; False positives 47
# With alpha cut 11 and gammaness 0.84, Q = 2.5054
# True positives 1153; False positives 47
# With alpha cut 11 and gammaness 0.85, Q = 2.5427
# True positives 1145; False positives 45
# With alpha cut 11 and gammaness 0.86, Q = 2.5649
# True positives 1129; False positives 43
# With alpha cut 11 and gammaness 0.87, Q = 2.5801
# True positives 1109; False positives 41
# With alpha cut 11 and gammaness 0.88, Q = 2.5604
# True positives 1087; False positives 40
# With alpha cut 11 and gammaness 0.89, Q = 2.6181
# True positives 1069; False positives 37
# With alpha cut 11 and gammaness 0.90, Q = 2.5896
# True positives 1043; False positives 36
# With alpha cut 11 and gammaness 0.91, Q = 2.6861
# True positives 1020; False positives 32
# With alpha cut 11 and gammaness 0.92, Q = 2.6045
# True positives 989; False positives 32
# With alpha cut 11 and gammaness 0.93, Q = 2.6418
# True positives 955; False positives 29
# With alpha cut 11 and gammaness 0.94, Q = 2.5035
# True positives 905; False positives 29
# With alpha cut 11 and gammaness 0.95, Q = 2.5756
# True positives 847; False positives 24
#
#
# With alpha cut 12 and gammaness 0.80, Q = 2.4625
# True positives 1248; False positives 57
# With alpha cut 12 and gammaness 0.81, Q = 2.4768
# True positives 1233; False positives 55
# With alpha cut 12 and gammaness 0.82, Q = 2.5224
# True positives 1221; False positives 52
# With alpha cut 12 and gammaness 0.83, Q = 2.5429
# True positives 1207; False positives 50
# With alpha cut 12 and gammaness 0.84, Q = 2.5134
# True positives 1193; False positives 50
# With alpha cut 12 and gammaness 0.85, Q = 2.5437
# True positives 1183; False positives 48
# With alpha cut 12 and gammaness 0.86, Q = 2.5611
# True positives 1166; False positives 46
# With alpha cut 12 and gammaness 0.87, Q = 2.5737
# True positives 1146; False positives 44
# With alpha cut 12 and gammaness 0.88, Q = 2.5535
# True positives 1124; False positives 43
# With alpha cut 12 and gammaness 0.89, Q = 2.5981
# True positives 1103; False positives 40
# With alpha cut 12 and gammaness 0.90, Q = 2.5644
# True positives 1075; False positives 39
# With alpha cut 12 and gammaness 0.91, Q = 2.6465
# True positives 1051; False positives 35
# With alpha cut 12 and gammaness 0.92, Q = 2.5659
# True positives 1019; False positives 35
# With alpha cut 12 and gammaness 0.93, Q = 2.5861
# True positives 982; False positives 32
# With alpha cut 12 and gammaness 0.94, Q = 2.5240
# True positives 928; False positives 30
# With alpha cut 12 and gammaness 0.95, Q = 2.5832
# True positives 867; False positives 25
#
#
# With alpha cut 13 and gammaness 0.80, Q = 2.4941
# True positives 1286; False positives 59
# With alpha cut 13 and gammaness 0.81, Q = 2.5079
# True positives 1271; False positives 57
# With alpha cut 13 and gammaness 0.82, Q = 2.5503
# True positives 1258; False positives 54
# With alpha cut 13 and gammaness 0.83, Q = 2.5699
# True positives 1244; False positives 52
# With alpha cut 13 and gammaness 0.84, Q = 2.5327
# True positives 1226; False positives 52
# With alpha cut 13 and gammaness 0.85, Q = 2.5576
# True positives 1214; False positives 50
# With alpha cut 13 and gammaness 0.86, Q = 2.5652
# True positives 1193; False positives 48
# With alpha cut 13 and gammaness 0.87, Q = 2.5743
# True positives 1172; False positives 46
# With alpha cut 13 and gammaness 0.88, Q = 2.5538
# True positives 1150; False positives 45
# With alpha cut 13 and gammaness 0.89, Q = 2.5906
# True positives 1127; False positives 42
# With alpha cut 13 and gammaness 0.90, Q = 2.5545
# True positives 1098; False positives 41
# With alpha cut 13 and gammaness 0.91, Q = 2.6254
# True positives 1072; False positives 37
# With alpha cut 13 and gammaness 0.92, Q = 2.5348
# True positives 1035; False positives 37
# With alpha cut 13 and gammaness 0.93, Q = 2.5829
# True positives 996; False positives 33
# With alpha cut 13 and gammaness 0.94, Q = 2.5097
# True positives 938; False positives 31
# With alpha cut 13 and gammaness 0.95, Q = 2.6100
# True positives 876; False positives 25
#
#
# With alpha cut 14 and gammaness 0.80, Q = 2.5158
# True positives 1319; False positives 61
# With alpha cut 14 and gammaness 0.81, Q = 2.5290
# True positives 1304; False positives 59
# With alpha cut 14 and gammaness 0.82, Q = 2.5680
# True positives 1290; False positives 56
# With alpha cut 14 and gammaness 0.83, Q = 2.6111
# True positives 1276; False positives 53
# With alpha cut 14 and gammaness 0.84, Q = 2.5722
# True positives 1257; False positives 53
# With alpha cut 14 and gammaness 0.85, Q = 2.5971
# True positives 1245; False positives 51
# With alpha cut 14 and gammaness 0.86, Q = 2.5985
# True positives 1221; False positives 49
# With alpha cut 14 and gammaness 0.87, Q = 2.6314
# True positives 1198; False positives 46
# With alpha cut 14 and gammaness 0.88, Q = 2.6094
# True positives 1175; False positives 45
# With alpha cut 14 and gammaness 0.89, Q = 2.6458
# True positives 1151; False positives 42
# With alpha cut 14 and gammaness 0.90, Q = 2.6104
# True positives 1122; False positives 41
# With alpha cut 14 and gammaness 0.91, Q = 2.6768
# True positives 1093; False positives 37
# With alpha cut 14 and gammaness 0.92, Q = 2.5813
# True positives 1054; False positives 37
# With alpha cut 14 and gammaness 0.93, Q = 2.6322
# True positives 1015; False positives 33
# With alpha cut 14 and gammaness 0.94, Q = 2.5579
# True positives 956; False positives 31
# With alpha cut 14 and gammaness 0.95, Q = 2.6606
# True positives 893; False positives 25
# Iteration: 4
#
#
#
# With alpha cut 2 and gammaness 0.80, Q = 1.6933
# True positives 341; False positives 9
# With alpha cut 2 and gammaness 0.81, Q = 1.6784
# True positives 338; False positives 9
# With alpha cut 2 and gammaness 0.82, Q = 1.8862
# True positives 335; False positives 7
# With alpha cut 2 and gammaness 0.83, Q = 1.8750
# True positives 333; False positives 7
# With alpha cut 2 and gammaness 0.84, Q = 2.0009
# True positives 329; False positives 6
# With alpha cut 2 and gammaness 0.85, Q = 1.9887
# True positives 327; False positives 6
# With alpha cut 2 and gammaness 0.86, Q = 1.9583
# True positives 322; False positives 6
# With alpha cut 2 and gammaness 0.87, Q = 2.0719
# True positives 311; False positives 5
# With alpha cut 2 and gammaness 0.88, Q = 2.0520
# True positives 308; False positives 5
# With alpha cut 2 and gammaness 0.89, Q = 2.5975
# True positives 302; False positives 3
# With alpha cut 2 and gammaness 0.90, Q = 2.5803
# True positives 300; False positives 3
# With alpha cut 2 and gammaness 0.91, Q = 2.5545
# True positives 297; False positives 3
# With alpha cut 2 and gammaness 0.92, Q = 3.0232
# True positives 287; False positives 2
# With alpha cut 2 and gammaness 0.93, Q = 2.8336
# True positives 269; False positives 2
# With alpha cut 2 and gammaness 0.94, Q = 3.8882
# True positives 261; False positives 1
# With alpha cut 2 and gammaness 0.95, Q = 3.7392
# True positives 251; False positives 1
#
#
# With alpha cut 3 and gammaness 0.80, Q = 2.0771
# True positives 483; False positives 12
# With alpha cut 3 and gammaness 0.81, Q = 2.0599
# True positives 479; False positives 12
# With alpha cut 3 and gammaness 0.82, Q = 2.2424
# ...
# With alpha cut 3 and gammaness 0.90, Q = 2.3374
# True positives 449; False positives 8
# With alpha cut 3 and gammaness 0.91, Q = 2.4375
# True positives 438; False positives 7
# With alpha cut 3 and gammaness 0.92, Q = 2.5607
# True positives 426; False positives 6
# With alpha cut 3 and gammaness 0.93, Q = 2.6997
# True positives 410; False positives 5
# With alpha cut 3 and gammaness 0.94, Q = 2.8933
# True positives 393; False positives 4
# With alpha cut 3 and gammaness 0.95, Q = 2.7313
# True positives 371; False positives 4
#
#
# With alpha cut 4 and gammaness 0.80, Q = 2.2037
# True positives 635; False positives 18
# With alpha cut 4 and gammaness 0.81, Q = 2.1899
# True positives 631; False positives 18
# With alpha cut 4 and gammaness 0.82, Q = 2.1795
# True positives 628; False positives 18
# With alpha cut 4 and gammaness 0.83, Q = 2.2896
# True positives 622; False positives 16
# With alpha cut 4 and gammaness 0.84, Q = 2.3571
# True positives 620; False positives 15
# With alpha cut 4 and gammaness 0.85, Q = 2.4358
# True positives 619; False positives 14
# With alpha cut 4 and gammaness 0.86, Q = 2.4910
# True positives 610; False positives 13
# With alpha cut 4 and gammaness 0.87, Q = 2.4502
# True positives 600; False positives 13
# With alpha cut 4 and gammaness 0.88, Q = 2.5035
# True positives 589; False positives 12
# With alpha cut 4 and gammaness 0.89, Q = 2.4610
# True positives 579; False positives 12
# With alpha cut 4 and gammaness 0.90, Q = 2.5216
# True positives 568; False positives 11
# With alpha cut 4 and gammaness 0.91, Q = 2.5795
# True positives 554; False positives 10
# With alpha cut 4 and gammaness 0.92, Q = 2.6454
# True positives 539; False positives 9
# With alpha cut 4 and gammaness 0.93, Q = 2.8939
# True positives 520; False positives 7
# With alpha cut 4 and gammaness 0.94, Q = 2.9875
# True positives 497; False positives 6
# With alpha cut 4 and gammaness 0.95, Q = 3.0619
# True positives 465; False positives 5
#
#
# With alpha cut 5 and gammaness 0.80, Q = 2.4130
# True positives 751; False positives 21
# With alpha cut 5 and gammaness 0.81, Q = 2.4001
# True positives 747; False positives 21
# With alpha cut 5 and gammaness 0.82, Q = 2.3873
# True positives 743; False positives 21
# With alpha cut 5 and gammaness 0.83, Q = 2.4895
# True positives 737; False positives 19
# With alpha cut 5 and gammaness 0.84, Q = 2.5473
# True positives 734; False positives 18
# With alpha cut 5 and gammaness 0.85, Q = 2.6982
# True positives 733; False positives 16
# With alpha cut 5 and gammaness 0.86, Q = 2.7372
# True positives 720; False positives 15
# With alpha cut 5 and gammaness 0.87, Q = 2.6916
# True positives 708; False positives 15
# With alpha cut 5 and gammaness 0.88, Q = 2.8463
# True positives 697; False positives 13
# With alpha cut 5 and gammaness 0.89, Q = 2.7892
# True positives 683; False positives 13
# With alpha cut 5 and gammaness 0.90, Q = 2.8520
# True positives 671; False positives 12
# With alpha cut 5 and gammaness 0.91, Q = 2.9034
# True positives 654; False positives 11
# With alpha cut 5 and gammaness 0.92, Q = 2.9520
# True positives 634; False positives 10
# With alpha cut 5 and gammaness 0.93, Q = 3.2015
# True positives 615; False positives 8
# With alpha cut 5 and gammaness 0.94, Q = 3.2779
# True positives 589; False positives 7
# With alpha cut 5 and gammaness 0.95, Q = 3.3181
# True positives 552; False positives 6
#
#
# With alpha cut 6 and gammaness 0.80, Q = 2.5266
# True positives 858; False positives 25
# With alpha cut 6 and gammaness 0.81, Q = 2.5148
# True positives 854; False positives 25
# With alpha cut 6 and gammaness 0.82, Q = 2.6066
# True positives 849; False positives 23
# With alpha cut 6 and gammaness 0.83, Q = 2.7022
# True positives 841; False positives 21
# With alpha cut 6 and gammaness 0.84, Q = 2.8307
# True positives 838; False positives 19
# With alpha cut 6 and gammaness 0.85, Q = 2.9854
# True positives 836; False positives 17
# With alpha cut 6 and gammaness 0.86, Q = 3.0184
# True positives 820; False positives 16
# With alpha cut 6 and gammaness 0.87, Q = 2.9706
# True positives 807; False positives 16
# With alpha cut 6 and gammaness 0.88, Q = 3.1245
# True positives 794; False positives 14
# With alpha cut 6 and gammaness 0.89, Q = 3.0655
# True positives 779; False positives 14
# With alpha cut 6 and gammaness 0.90, Q = 3.2473
# True positives 764; False positives 12
# With alpha cut 6 and gammaness 0.91, Q = 3.3118
# True positives 746; False positives 11
# With alpha cut 6 and gammaness 0.92, Q = 3.3617
# True positives 722; False positives 10
# With alpha cut 6 and gammaness 0.93, Q = 3.6232
# True positives 696; False positives 8
# With alpha cut 6 and gammaness 0.94, Q = 3.6952
# True positives 664; False positives 7
# With alpha cut 6 and gammaness 0.95, Q = 3.7208
# True positives 619; False positives 6
#
#
# With alpha cut 7 and gammaness 0.80, Q = 2.6045
# True positives 936; False positives 28
# With alpha cut 7 and gammaness 0.81, Q = 2.5850
# True positives 929; False positives 28
# With alpha cut 7 and gammaness 0.82, Q = 2.7151
# True positives 922; False positives 25
# With alpha cut 7 and gammaness 0.83, Q = 2.8030
# True positives 913; False positives 23
# With alpha cut 7 and gammaness 0.84, Q = 2.9239
# True positives 910; False positives 21
# With alpha cut 7 and gammaness 0.85, Q = 3.0638
# True positives 907; False positives 19
# With alpha cut 7 and gammaness 0.86, Q = 3.0922
# True positives 891; False positives 18
# With alpha cut 7 and gammaness 0.87, Q = 3.0367
# True positives 875; False positives 18
# With alpha cut 7 and gammaness 0.88, Q = 3.1693
# True positives 861; False positives 16
# With alpha cut 7 and gammaness 0.89, Q = 3.2124
# True positives 845; False positives 15
# With alpha cut 7 and gammaness 0.90, Q = 3.3772
# True positives 827; False positives 13
# With alpha cut 7 and gammaness 0.91, Q = 3.4344
# True positives 808; False positives 12
# With alpha cut 7 and gammaness 0.92, Q = 3.4761
# True positives 783; False positives 11
# With alpha cut 7 and gammaness 0.93, Q = 3.7006
# True positives 754; False positives 9
# With alpha cut 7 and gammaness 0.94, Q = 3.7169
# True positives 714; False positives 8
# With alpha cut 7 and gammaness 0.95, Q = 4.0154
# True positives 668; False positives 6
#
#
# With alpha cut 8 and gammaness 0.80, Q = 2.5286
# True positives 1016; False positives 35
# With alpha cut 8 and gammaness 0.81, Q = 2.5087
# True positives 1008; False positives 35
# With alpha cut 8 and gammaness 0.82, Q = 2.5976
# True positives 998; False positives 32
# With alpha cut 8 and gammaness 0.83, Q = 2.6586
# True positives 989; False positives 30
# With alpha cut 8 and gammaness 0.84, Q = 2.8472
# True positives 986; False positives 26
# With alpha cut 8 and gammaness 0.85, Q = 2.9514
# True positives 982; False positives 24
# With alpha cut 8 and gammaness 0.86, Q = 2.9627
# True positives 965; False positives 23
# With alpha cut 8 and gammaness 0.87, Q = 2.9074
# True positives 947; False positives 23
# With alpha cut 8 and gammaness 0.88, Q = 2.9849
# True positives 929; False positives 21
# With alpha cut 8 and gammaness 0.89, Q = 3.0739
# True positives 910; False positives 19
# With alpha cut 8 and gammaness 0.90, Q = 3.3721
# True positives 887; False positives 15
# With alpha cut 8 and gammaness 0.91, Q = 3.4118
# True positives 867; False positives 14
# With alpha cut 8 and gammaness 0.92, Q = 3.4262
# True positives 839; False positives 13
# With alpha cut 8 and gammaness 0.93, Q = 3.5915
# True positives 809; False positives 11
# With alpha cut 8 and gammaness 0.94, Q = 3.5759
# True positives 768; False positives 10
# With alpha cut 8 and gammaness 0.95, Q = 3.7429
# True positives 719; False positives 8
#
#
# With alpha cut 9 and gammaness 0.80, Q = 2.5446
# True positives 1093; False positives 40
# With alpha cut 9 and gammaness 0.81, Q = 2.5259
# True positives 1085; False positives 40
# With alpha cut 9 and gammaness 0.82, Q = 2.6021
# True positives 1075; False positives 37
# With alpha cut 9 and gammaness 0.83, Q = 2.6481
# True positives 1064; False positives 35
# With alpha cut 9 and gammaness 0.84, Q = 2.8058
# True positives 1061; False positives 31
# With alpha cut 9 and gammaness 0.85, Q = 2.8900
# True positives 1057; False positives 29
# With alpha cut 9 and gammaness 0.86, Q = 2.8911
# True positives 1039; False positives 28
# With alpha cut 9 and gammaness 0.87, Q = 2.8326
# True positives 1018; False positives 28
# With alpha cut 9 and gammaness 0.88, Q = 2.9360
# True positives 997; False positives 25
# With alpha cut 9 and gammaness 0.89, Q = 3.0607
# True positives 975; False positives 22
# With alpha cut 9 and gammaness 0.90, Q = 3.3004
# True positives 951; False positives 18
# With alpha cut 9 and gammaness 0.91, Q = 3.3211
# True positives 930; False positives 17
# With alpha cut 9 and gammaness 0.92, Q = 3.3018
# True positives 897; False positives 16
# With alpha cut 9 and gammaness 0.93, Q = 3.5201
# True positives 862; False positives 13
# With alpha cut 9 and gammaness 0.94, Q = 3.4854
# True positives 820; False positives 12
# With alpha cut 9 and gammaness 0.95, Q = 3.5712
# True positives 767; False positives 10
#
#
# With alpha cut 10 and gammaness 0.80, Q = 2.4316
# True positives 1156; False positives 49
# With alpha cut 10 and gammaness 0.81, Q = 2.4126
# True positives 1147; False positives 49
# With alpha cut 10 and gammaness 0.82, Q = 2.4662
# True positives 1136; False positives 46
# With alpha cut 10 and gammaness 0.83, Q = 2.4950
# True positives 1124; False positives 44
# With alpha cut 10 and gammaness 0.84, Q = 2.6406
# True positives 1120; False positives 39
# With alpha cut 10 and gammaness 0.85, Q = 2.7387
# True positives 1116; False positives 36
# With alpha cut 10 and gammaness 0.86, Q = 2.7252
# True positives 1095; False positives 35
# With alpha cut 10 and gammaness 0.87, Q = 2.6705
# True positives 1073; False positives 35
# With alpha cut 10 and gammaness 0.88, Q = 2.7356
# True positives 1051; False positives 32
# With alpha cut 10 and gammaness 0.89, Q = 2.8577
# True positives 1027; False positives 28
# With alpha cut 10 and gammaness 0.90, Q = 3.0085
# True positives 1001; False positives 24
# With alpha cut 10 and gammaness 0.91, Q = 3.0026
# True positives 978; False positives 23
# With alpha cut 10 and gammaness 0.92, Q = 2.9571
# True positives 942; False positives 22
# With alpha cut 10 and gammaness 0.93, Q = 3.0570
# True positives 905; False positives 19
# With alpha cut 10 and gammaness 0.94, Q = 3.1436
# True positives 854; False positives 16
# With alpha cut 10 and gammaness 0.95, Q = 3.2506
# True positives 796; False positives 13
#
#
# With alpha cut 11 and gammaness 0.80, Q = 2.5071
# True positives 1216; False positives 51
# With alpha cut 11 and gammaness 0.81, Q = 2.4865
# True positives 1206; False positives 51
# With alpha cut 11 and gammaness 0.82, Q = 2.5622
# True positives 1193; False positives 47
# With alpha cut 11 and gammaness 0.83, Q = 2.5900
# True positives 1180; False positives 45
# With alpha cut 11 and gammaness 0.84, Q = 2.7355
# True positives 1175; False positives 40
# With alpha cut 11 and gammaness 0.85, Q = 2.8224
# True positives 1166; False positives 37
# With alpha cut 11 and gammaness 0.86, Q = 2.8000
# True positives 1141; False positives 36
# With alpha cut 11 and gammaness 0.87, Q = 2.7436
# True positives 1118; False positives 36
# With alpha cut 11 and gammaness 0.88, Q = 2.8423
# True positives 1092; False positives 32
# With alpha cut 11 and gammaness 0.89, Q = 2.9634
# True positives 1065; False positives 28
# With alpha cut 11 and gammaness 0.90, Q = 3.1167
# True positives 1037; False positives 24
# With alpha cut 11 and gammaness 0.91, Q = 3.0978
# True positives 1009; False positives 23
# With alpha cut 11 and gammaness 0.92, Q = 3.0481
# True positives 971; False positives 22
# With alpha cut 11 and gammaness 0.93, Q = 3.1516
# True positives 933; False positives 19
# With alpha cut 11 and gammaness 0.94, Q = 3.2319
# True positives 878; False positives 16
# With alpha cut 11 and gammaness 0.95, Q = 3.3323
# True positives 816; False positives 13
#
#
# With alpha cut 12 and gammaness 0.80, Q = 2.5645
# True positives 1268; False positives 53
# With alpha cut 12 and gammaness 0.81, Q = 2.5423
# True positives 1257; False positives 53
# With alpha cut 12 and gammaness 0.82, Q = 2.6167
# True positives 1244; False positives 49
# With alpha cut 12 and gammaness 0.83, Q = 2.6395
# True positives 1229; False positives 47
# With alpha cut 12 and gammaness 0.84, Q = 2.7763
# True positives 1222; False positives 42
# With alpha cut 12 and gammaness 0.85, Q = 2.8576
# True positives 1212; False positives 39
# With alpha cut 12 and gammaness 0.86, Q = 2.8304
# True positives 1185; False positives 38
# With alpha cut 12 and gammaness 0.87, Q = 2.8079
# True positives 1160; False positives 37
# With alpha cut 12 and gammaness 0.88, Q = 2.9014
# True positives 1132; False positives 33
# With alpha cut 12 and gammaness 0.89, Q = 3.0185
# True positives 1104; False positives 29
# With alpha cut 12 and gammaness 0.90, Q = 3.1627
# True positives 1074; False positives 25
# With alpha cut 12 and gammaness 0.91, Q = 3.1378
# True positives 1044; False positives 24
# With alpha cut 12 and gammaness 0.92, Q = 3.0763
# True positives 1002; False positives 23
# With alpha cut 12 and gammaness 0.93, Q = 3.1640
# True positives 961; False positives 20
# With alpha cut 12 and gammaness 0.94, Q = 3.2247
# True positives 903; False positives 17
# With alpha cut 12 and gammaness 0.95, Q = 3.2937
# True positives 837; False positives 14
#
#
# With alpha cut 13 and gammaness 0.80, Q = 2.5451
# True positives 1305; False positives 57
# With alpha cut 13 and gammaness 0.81, Q = 2.5197
# True positives 1292; False positives 57
# With alpha cut 13 and gammaness 0.82, Q = 2.5868
# True positives 1279; False positives 53
# With alpha cut 13 and gammaness 0.83, Q = 2.6320
# True positives 1264; False positives 50
# With alpha cut 13 and gammaness 0.84, Q = 2.7568
# True positives 1256; False positives 45
# With alpha cut 13 and gammaness 0.85, Q = 2.8286
# True positives 1245; False positives 42
# With alpha cut 13 and gammaness 0.86, Q = 2.8008
# True positives 1218; False positives 41
# With alpha cut 13 and gammaness 0.87, Q = 2.8057
# True positives 1190; False positives 39
# With alpha cut 13 and gammaness 0.88, Q = 2.8895
# True positives 1161; False positives 35
# With alpha cut 13 and gammaness 0.89, Q = 3.0404
# True positives 1131; False positives 30
# With alpha cut 13 and gammaness 0.90, Q = 3.1677
# True positives 1097; False positives 26
# With alpha cut 13 and gammaness 0.91, Q = 3.1421
# True positives 1067; False positives 25
# With alpha cut 13 and gammaness 0.92, Q = 3.0596
# True positives 1018; False positives 24
# With alpha cut 13 and gammaness 0.93, Q = 3.1391
# True positives 977; False positives 21
# With alpha cut 13 and gammaness 0.94, Q = 3.2747
# True positives 917; False positives 17
# With alpha cut 13 and gammaness 0.95, Q = 3.3449
# True positives 850; False positives 14
#
#
# With alpha cut 14 and gammaness 0.80, Q = 2.5514
# True positives 1331; False positives 59
# With alpha cut 14 and gammaness 0.81, Q = 2.5265
# True positives 1318; False positives 59
# With alpha cut 14 and gammaness 0.82, Q = 2.5889
# True positives 1304; False positives 55
# With alpha cut 14 and gammaness 0.83, Q = 2.6299
# True positives 1288; False positives 52
# With alpha cut 14 and gammaness 0.84, Q = 2.7491
# True positives 1280; False positives 47
# With alpha cut 14 and gammaness 0.85, Q = 2.8146
# True positives 1268; False positives 44
# With alpha cut 14 and gammaness 0.86, Q = 2.7865
# True positives 1241; False positives 43
# With alpha cut 14 and gammaness 0.87, Q = 2.7847
# True positives 1211; False positives 41
# With alpha cut 14 and gammaness 0.88, Q = 2.8982
# True positives 1181; False positives 36
# With alpha cut 14 and gammaness 0.89, Q = 3.0385
# True positives 1149; False positives 31
# With alpha cut 14 and gammaness 0.90, Q = 3.1595
# True positives 1115; False positives 27
# With alpha cut 14 and gammaness 0.91, Q = 3.1273
# True positives 1083; False positives 26
# With alpha cut 14 and gammaness 0.92, Q = 3.0420
# True positives 1033; False positives 25
# With alpha cut 14 and gammaness 0.93, Q = 3.1140
# True positives 992; False positives 22
# With alpha cut 14 and gammaness 0.94, Q = 3.2345
# True positives 932; False positives 18
# With alpha cut 14 and gammaness 0.95, Q = 3.2885
# True positives 865; False positives 15

# %% [markdown]
# To handle the very few cases that return 0 false positives and thus an "infinite" Q value, we decide to consider the median of the Q values across the different iterations instead of the average. To estimate the standard deviation of the values found we ignore these cases.

# %%
test_predictions_df = pd.DataFrame(test_predictions)
test_predictions_df['Q'] = test_predictions_df['Q'].replace('inf', 1e20) # assign very high value to Q to find median
test_predictions_df.groupby(['alpha_cut', 'gamma'])['Q'].agg(
    median_Q = 'median',
    std= lambda x: np.std(x[x != 1e20])).reset_index()

# %%
grouped_pred = test_predictions_df.groupby(['alpha_cut', 'gamma'])['Q'].agg(
    median= 'median',
    std= lambda x: np.std(x[x != 1e20]) ).reset_index()

max_mean_row = grouped_pred.loc[grouped_pred['median'].idxmax()]

max_mean = max_mean_row['median']
std_dev = max_mean_row['std']

print(f"The best average Q value found is {max_mean:.2f} ± {std_dev/(N)**0.5:.2f}")
print(f"The best Alpha cut found is {max_mean_row['alpha_cut']:.0f}° ")
print(f"The best gammaness found is {max_mean_row['gamma']:.2f}")

# %%
selected = test_predictions_df[
    (test_predictions_df['gamma'] == max_mean_row['gamma']) & 
    (test_predictions_df['alpha_cut'] == max_mean_row['alpha_cut'])]

selected_gammas = selected['selected gammas']/selected['total gammas']
avg_selected_gammas= selected_gammas.mean()
std_selected_gammas= selected_gammas.std()
print(f"With these best parameters, the average fraction of selected gammas is ({avg_selected_gammas*100:.2f} ± {std_selected_gammas*100/(N)**0.5:.2f})%")

# %% [markdown]
# This means that, applying this technique on the given dataset with $N_{\gamma} = 12332$ true gamma events, we would identify $n_{\gamma} = (4199 ± 1)$ events as gamma, disregarding the remaining as backgorund. In particular we have the following average performance for the algorithm in terms of TPR, FPR, TNR, FNR:

# %%
tpr = selected['true positives']/selected['total gammas']
tpr_avg = tpr.mean()

fpr = selected['false positives']/selected['total hadrons']
fpr_avg = fpr.mean()

tnr = selected['true negatives']/selected['total hadrons']
tnr_avg= tnr.mean()

fnr = selected['false negatives']/selected['total gammas']
fnr_avg= fnr.mean()

confusion_matrix = np.array([[tpr_avg, fnr_avg], [fpr_avg, tnr_avg]])

fig, ax = plt.subplots(figsize=(9, 9))
cax = ax.matshow(confusion_matrix, cmap='seismic',alpha=0.75)

ax.set_xticks([0, 1])
ax.set_xticklabels(['gamma', 'background'],fontsize=12)
ax.xaxis.set_ticks_position('bottom')
ax.set_yticks([0, 1])
ax.set_yticklabels(['gamma', 'background'],fontsize=12)

path_effects_white = [path_effects.withStroke(linewidth=1.8, foreground='white')]

# Adding text with white contour
text_params = {'ha': 'center', 'va': 'center', 'color': 'black', 'fontsize': 12, 'path_effects': path_effects_white}


ax.text(0, 0, f'TPR: {tpr_avg:.3f}', ha='center', va='center', color='black',fontsize=12)
ax.text(1, 0, f'FNR: {fnr_avg:.3f}', **text_params)
ax.text(0, 1, f'FPR: {fpr_avg:.3f}', **text_params)
ax.text(1, 1, f'TNR: {tnr_avg:.3f}', **text_params)

fig.colorbar(cax)

ax.set_title('Confusion matrix of final classification strategy',fontsize=15)
ax.set_xlabel('Assigned Labels',fontsize=13.5)
ax.set_ylabel('True Labels',fontsize=13.5)

plt.show()

# %% [markdown]
# # Part 8: Calculation of the observation time

# %% [markdown]
# Assuming that the telescope has a collection area of 10^9 cm^2 and that we are observing gamma rays between 50 GeV and 50 TeV, to what observation time does this measurement corresponds? (assume here the Crab spectrum measured by HEGRA [Aharonian, F. et al. 2000])

# %% [markdown]
# ------da rivedere descrizione-------
# - da capire +- 0.5
# - da capire se vogliamo dividere il range 0.05 Tev - 50 Tev in due e usare il primo integrale per 1-50 e il secondo (log) per 0.05-1 (al momento non sono divisi)

# %% [markdown]
# To calculate the observation time corresponding to the Cherenkov telescope measurement, we use the Crab Nebula spectrum measured by HEGRA. Then, converting the telescope's collection area to square meters ( $A = 10^9 \, \text{cm}^2 = 10^5 \, \text{m}^2 $), we can determine
# the event rate by integrating the flux over the energy range from **50 GeV to 50 TeV**:
#
# $$
# R = A \cdot J_{\gamma} =  A \int_{0.05 \, TeV}^{50 \, TeV} \frac{dJ_{\gamma}}{dE} dE
# $$
#
# This integration provides the **event rate in photons per second**. Given the total number of recorded events $n_\gamma$, we can then calculate the **observation time** by dividing the number of events by the event rate:
#
# $$
# \Delta t = \frac{n_{\gamma}}{R}
# $$

# %%
# Constants
A = 10**9 * 1e-4  # collection area in m^2
E0 = 1.0  # TeV
Emin = 0.05  # TeV = 50 GeV
Emax = 50  # TeV
n_gamma, sigma_n_gamma = 4000, 200 #--------------------------------------insert our value here---------------------------

# Constants for the first integral
alpha1, alpha1_err = 2.59, 0.03
c1, c1_err = 2.79e-7, 0.02e-7

# Constants for the second integral
c2, c2_err = 2.67e-7, 0.01e-7
alpha2, alpha2_err = 2.47, 0.1
beta, beta_err = 0.11, 0.1

# %% [markdown]
# Primo integrale con errore dato da derivate parziali

# %% [markdown]
# # First integral
# According to the study by **Aharonian et al. (2000)**, the differential flux of gamma rays in the range of $1-20 \, \text{TeV}$ is given by:
#
# $$
# \frac{dJ_{\gamma}}{dE} = (2.79 \pm 0.02) \times 10^{-7} \left( \frac{E}{1 \, \text{TeV}} \right)^{(-2.59 \pm 0.03)} \, \text{ph} \, \text{m}^{-2} \, \text{s}^{-1} \, \text{TeV}^{-1}
# $$
# $$
# \frac{dJ_{\gamma}}{dE} = c_1 \cdot \left( \frac{E}{E_0} \right)^{- \alpha_1} \, \text{ph} \, \text{m}^{-2} \, \text{s}^{-1} \, \text{TeV}^{-1}
# $$
# with:
# $$
# c_1 = (2.79 \pm 0.02) \times 10^{-7}, E_0 = 1 \, \text{TeV}, \alpha_1 = 2.59 \pm 0.03
# $$
# so the integral will be:
# $$
# J_\gamma = \frac{E_0^{\alpha_1} \cdot c_1}{-\alpha_1 + 1} \cdot \left( E_{\text{max}}^{-\alpha_1 + 1} - E_{\text{min}}^{-\alpha_1 + 1} \right)
# $$
# with $E_{\text{min}} = 0.05 \, \text{TeV}, E_{\text{max}} = 50 \, \text{TeV} $

# %% [markdown]
# ### Error Propagation
#
# We have uncertainties in the following parameters:
#
# $$
# c_1 = (2.79 \pm 0.02) \times 10^{-7}
# $$
# $$
# \alpha_1 = 2.59 \pm 0.03
# $$
#
# Using the general error propagation formula the total uncertainty in R:
#
# $$
# \sigma_R = \sqrt{ \left( \frac{\partial R}{\partial c_1} \sigma_{c_1} \right)^2 + \left( \frac{\partial R}{\partial \alpha_1} \sigma_{\alpha_1} \right)^2 }
# $$
#
# The error for the time will be:
# $$
# \sigma_t = t \sqrt{ \left( \frac{\sigma_{n_{\gamma}}}{n_{\gamma}} \right)^2 + \left( \frac{\sigma_R}{R} \right)^2 }
# $$

# %%
import sympy as sp

def uncertainty(A, E0, Emin, Emax, c1, c1_err, alpha1, alpha1_err):
    #definisco i simboli
    c1_sym, alpha1_sym, Emin_sym, Emax_sym, E0_sym, A_sym = sp.symbols('c1 alpha1 Emin Emax E0 A')
    
    #definizione di R 
    R = (A_sym * c1_sym * (E0_sym**alpha1_sym) / (-alpha1_sym + 1)) * (Emax_sym**(-alpha1_sym + 1) - Emin_sym**(-alpha1_sym + 1))

    #calcolo le derivate parziali rispetto a c1 e alpha1
    dR_dc1 = sp.diff(R, c1_sym)
    dR_dalpha1 = sp.diff(R, alpha1_sym)
    
    #conversione a funzioni
    dR_dc1_func = sp.lambdify((A_sym, E0_sym, Emin_sym, Emax_sym, c1_sym, alpha1_sym), dR_dc1, 'numpy')
    dR_dalpha1_func = sp.lambdify((A_sym, E0_sym, Emin_sym, Emax_sym, c1_sym, alpha1_sym), dR_dalpha1, 'numpy')
    
    #calcolo il valore delle derivate e di R
    dR_dc1_val = dR_dc1_func(A, E0, Emin, Emax, c1, alpha1)
    dR_dalpha1_val = dR_dalpha1_func(A, E0, Emin, Emax, c1, alpha1)
    R_val = (A * c1 * (E0**alpha1) / (-alpha1 + 1)) * (Emax**(-alpha1 + 1) - Emin**(-alpha1 + 1))
    
    #incertezza totale su R
    sigma_R = np.sqrt((dR_dc1_val * c1_err) ** 2 + (dR_dalpha1_val * alpha1_err) ** 2)
    
    return R_val, sigma_R


#valore dell'errore su R
R_val, sigma_R = uncertainty(A, E0, Emin, Emax, c1, c1_err, alpha1, alpha1_err)

t1 = (n_gamma / R_val) / 60
sigma_t1 = t1 * (np.sqrt((sigma_n_gamma / n_gamma)**2 + (sigma_R/R_val)**2)) / 60

print(f"t1 = {t1:.2f} ± {sigma_t1:.2f} minutes")

# %% [markdown]
# ## Second integral
# At low energies there is a slight flattening of the spectrum. A fit with a logarithmic steepening of the power law spectrum gives (according to the study by **Aharonian et al. (2000)**):
# $$
# \frac{dJ_{\gamma}}{dE} = (2.67 \pm 0.01) \times 10^{-7} \left( \frac{E}{1 \, \text{TeV}} \right)^{(-2.47 \pm 0.1) -(0.11 \pm 0.1) \, \log(E)} \, \text{ph} \, \text{m}^{-2} \, \text{s}^{-1} \, \text{TeV}^{-1}
# $$
# $$
# \frac{dJ_{\gamma}}{dE} = c_2 \cdot \left( \frac{E}{E_0} \right)^{- \alpha_2 - \beta \, \log(E)} \, \text{ph} \, \text{m}^{-2} \, \text{s}^{-1} \, \text{TeV}^{-1}
# $$
# with:
# $$
# c_2 = (2.67 \pm 0.01) \times 10^{-7}, E_0 = 1 \, \text{TeV}, \alpha_2 = 2.47 \pm 0.1, \beta = 0.11 \pm 0.1
# $$
# Because of the logarithmic correction, it's impossible to integrate it analytically in a straightforward way. Hence, to calculate this integral, we use two numerical integration methods: Romberg integration and Simpson's Rule.

# %% [markdown]
# ###  Romberg integration
# usando romb - da capire
# #### using .quad

# %%
from scipy.integrate import quad

#definisco l'integranda
def dJ_gamma(E, c2, alpha2, beta):
    return c2 * (E / E0) ** (-alpha2 - beta * np.log(E))

#definisco R
def R(c2, alpha2, beta):
    integral, _ = quad(dJ_gamma, Emin, Emax, args=(c2, alpha2, beta))
    return A * integral

#Monte Carlo for the error
N = 10000
c2_mc = np.random.normal(c2, c2_err, N)
alpha2_mc = np.random.normal(alpha2, alpha2_err, N)
beta_mc = np.random.normal(beta, beta_err, N)

R_mc = np.array([R(c2, alpha2, beta) for c2, alpha2, beta in zip(c2_mc, alpha2_mc, beta_mc)])

#calcolo valor medio e errore di R
R_mean = np.mean(R_mc)
R_std = np.std(R_mc)

#propago su t
t2 = (n_gamma / R_mean)/60
sigma_t2 = t2 * (np.sqrt((sigma_n_gamma / n_gamma)**2 + (R_std/R_mean)**2)) / 60

print(f"t2 = {t2:.2f} +- {sigma_t2:.2f} minutes")

# %% [markdown]
# ### Simpson's Rule

# %% [markdown]
# The trapezoidal rule estimates the area under a curve by approximating the curve with straight-line segments. We can often get a
# better result if we approximate the function instead with curves of some kind, Simpson’s rule does exactly this, using quadratic curves.

# %%
import numpy as np
from scipy.integrate import simpson

n = int(10e5)
E_values = np.linspace(Emin, Emax, n)

def dJ_gamma2(E, c2, alpha2, beta):
    return c2 * (E / E0) ** (-alpha2 - beta * np.log(E))

J_gamma_values = dJ_gamma2(E_values, c2, alpha2, beta)
J_gamma = simpson(J_gamma_values, E_values)

R = A * J_gamma

def partial_derivatives():
    dJ_dc2 = J_gamma / c2
    dJ_dalpha2 = -J_gamma * np.log(E_values / E0)
    dJ_dalpha2 = simpson(dJ_dalpha2, E_values)
    dJ_dbeta = -J_gamma * np.log(E_values/E0) * np.log(E_values)
    dJ_dbeta = simpson(dJ_dbeta, E_values)

    return dJ_dc2, dJ_dalpha2, dJ_dbeta

dJ_dc2, dJ_dalpha2, dJ_dbeta = partial_derivatives()

sigma_J = np.sqrt(
    (dJ_dc2 * c2_err) ** 2 +
    (dJ_dalpha2 * alpha2_err) ** 2 +
    (dJ_dbeta * beta_err) ** 2
)

sigma_R = sigma_J

t2_s = (n_gamma / R)/60
sigma_t2_s = t2_s * (np.sqrt((sigma_n_gamma / n_gamma)**2 + (sigma_R/R)**2)) / 60

print(f"t2 = {t2_s:.2f} +- {sigma_t2_s:.2f} minutes")
