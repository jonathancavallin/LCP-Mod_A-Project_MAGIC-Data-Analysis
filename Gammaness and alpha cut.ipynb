# %% [markdown]
# We now apply the best model found in the previous part, i.e: the Random Forest, to look for the combination of parameters *gammaness* and *alpha_cut* that maximizes the quality factor *Q*. What we do is label as background (hadrons) all samples with fAlpha greater than the *alpha_cut* value considered; then we apply the best Random Forest classification to the remaining samples, labelling as gammas only the samples with a predicted probability of belonging to class +1 greater than *gammaness*. Then we determine the TPR and FPR to calculate the correspondent Q value.
# To avoid choosing the best combination of *alpha cut* and *gammaness* solely on the performance on a specific test set, we run the same algorithm on different test sets and choose as best case the one that returns the highest average Q value over the iterations.

# %%
data_rescaled_and_indexed['fAlpha']= data_rescaled_and_indexed['fAlpha']*data['fAlpha'].std() + data['fAlpha'].mean()

# %%
N=10
test_predictions=[]
gammaness= np.arange(0.8,0.96,0.01)
alpha_cut= np.arange(2,15,1)

for i in range(1,N+1):
    print('Iteration:',i,'\n')
    
    train_set, test_set = split_train_test_set( data_rescaled_and_indexed, 5)
    X_train, Y_train = split_X_Y(train_set)
    X_test, Y_test = split_X_Y(test_set)
    
    best_forest = RandomForestClassifier(n_estimators=290, max_depth= 28, max_features=X_train.shape[1],bootstrap=True,max_samples=1.0,random_state=10,n_jobs=-1)
    best_forest.fit(X_train,Y_train) 

    for alpha in alpha_cut:
        print('\n')
        for g in gammaness:

            test_data = [ X_test[ X_test['fAlpha']<alpha], Y_test[X_test['fAlpha']<alpha] ] 
            discarded_data = X_test[X_test['fAlpha'] >= alpha]
            discarded_labels = Y_test[X_test['fAlpha'] >= alpha] # we directly classify these points as hadrons 
            
            y_pred_prob = best_forest.predict_proba(test_data[0])[:, 1]
            y_pred_label = np.where(y_pred_prob > g, 1, -1)
        
            selected_gammas= np.sum(y_pred_label==1)
            selected_hadrons= np.sum(y_pred_label==-1) + ( X_test.shape[0]-len(test_data[0])) # samples in alpha cut classified as hadron by the model + all samples previously discarded
    
            total_gammas = np.sum(Y_test==1) # over all the test set (before alpha cut)
            total_hadrons = np.sum(Y_test==-1)
            
            true_positives = np.sum( (y_pred_label==1) & (test_data[1]==1) )
            false_positives = np.sum( (y_pred_label==1) & (test_data[1]==-1) )
            true_negatives= np.sum((y_pred_label == -1) & (test_data[1] == -1)) + np.sum((discarded_labels == -1))
            false_negatives= np.sum((y_pred_label == -1) & (test_data[1] == 1)) + np.sum((discarded_labels == 1))
            
            if false_positives != 0:
                epsilon_gamma = true_positives / total_gammas # TPR
                epsilon_hadron = false_positives / total_hadrons # FPR
                Q = epsilon_gamma/np.sqrt(epsilon_hadron)
            else:
                epsilon_hadron= 0
                epsilon_gamma = true_positives / total_gammas
                Q = 'inf'
                
            test_predictions.append({
            'iteration': i,   
            'alpha_cut': alpha,
            'gamma': g,
            'test_data': test_data, 
            'pred_probs': y_pred_prob,
            'pred label': y_pred_label,
            'selected gammas': selected_gammas,
            'selected hadrons': selected_hadrons,
            'total gammas': total_gammas,
            'total hadrons': total_hadrons,
            'true positives': true_positives,
            'false positives': false_positives,
            'true negatives': true_negatives,
            'false negatives': false_negatives,
            'Q': Q })

            if Q != 'inf':
                print(f"With alpha cut {alpha} and gammaness {g:.2f}, Q = {Q:.4f}")
            else:
                print(f"With alpha cut {alpha} and gammanesss {g:.2f}, Q = {Q}")
            print(f"True positives {true_positives}; False positives {false_positives}")
# Out:
# Iteration: 1
#
#
#
# With alpha cut 2 and gammaness 0.80, Q = 1.6351
# True positives 316; False positives 9
# With alpha cut 2 and gammaness 0.81, Q = 1.6144
# True positives 312; False positives 9
# With alpha cut 2 and gammaness 0.82, Q = 1.7013
# True positives 310; False positives 8
# With alpha cut 2 and gammaness 0.83, Q = 1.6958
# True positives 309; False positives 8
# With alpha cut 2 and gammaness 0.84, Q = 1.8012
# True positives 307; False positives 7
# With alpha cut 2 and gammaness 0.85, Q = 1.7777
# True positives 303; False positives 7
# With alpha cut 2 and gammaness 0.86, Q = 1.7660
# True positives 301; False positives 7
# With alpha cut 2 and gammaness 0.87, Q = 1.7425
# True positives 297; False positives 7
# With alpha cut 2 and gammaness 0.88, Q = 1.7190
# True positives 293; False positives 7
# With alpha cut 2 and gammaness 0.89, Q = 1.6780
# True positives 286; False positives 7
# With alpha cut 2 and gammaness 0.90, Q = 2.1809
# True positives 281; False positives 4
# With alpha cut 2 and gammaness 0.91, Q = 2.1577
# True positives 278; False positives 4
# With alpha cut 2 and gammaness 0.92, Q = 2.4197
# True positives 270; False positives 3
# With alpha cut 2 and gammaness 0.93, Q = 2.3391
# True positives 261; False positives 3
# With alpha cut 2 and gammaness 0.94, Q = 2.2495
# True positives 251; False positives 3
# With alpha cut 2 and gammaness 0.95, Q = 2.1598
# True positives 241; False positives 3
#
#
# With alpha cut 3 and gammaness 0.80, Q = 1.6327
# True positives 482; False positives 21
# With alpha cut 3 and gammaness 0.81, Q = 1.6124
# True positives 476; False positives 21
# With alpha cut 3 and gammaness 0.82, Q = 1.6880
# True positives 474; False positives 19
# With alpha cut 3 and gammaness 0.83, Q = 1.6844
# True positives 473; False positives 19
# With alpha cut 3 and gammaness 0.84, Q = 1.7123
# True positives 468; False positives 18
# With alpha cut 3 and gammaness 0.85, Q = 1.7393
# True positives 462; False positives 17
# With alpha cut 3 and gammaness 0.86, Q = 1.7205
# True positives 457; False positives 17
# With alpha cut 3 and gammaness 0.87, Q = 1.6979
# True positives 451; False positives 17
# With alpha cut 3 and gammaness 0.88, Q = 1.6791
# True positives 446; False positives 17
# With alpha cut 3 and gammaness 0.89, Q = 1.6997
# True positives 438; False positives 16
# With alpha cut 3 and gammaness 0.90, Q = 1.9179
# True positives 428; False positives 12
# With alpha cut 3 and gammaness 0.91, Q = 1.9844
# True positives 424; False positives 11
# With alpha cut 3 and gammaness 0.92, Q = 2.0322
# True positives 414; False positives 10
# With alpha cut 3 and gammaness 0.93, Q = 1.9537
# True positives 398; False positives 10
# With alpha cut 3 and gammaness 0.94, Q = 2.1074
# True positives 384; False positives 8
# With alpha cut 3 and gammaness 0.95, Q = 2.1708
# True positives 370; False positives 7
#
#
# With alpha cut 4 and gammaness 0.80, Q = 1.8692
# True positives 614; False positives 26
# With alpha cut 4 and gammaness 0.81, Q = 1.8509
# True positives 608; False positives 26
# With alpha cut 4 and gammaness 0.82, Q = 1.9170
# True positives 605; False positives 24
# With alpha cut 4 and gammaness 0.83, Q = 1.9106
# True positives 603; False positives 24
# With alpha cut 4 and gammaness 0.84, Q = 1.9258
# True positives 595; False positives 23
# With alpha cut 4 and gammaness 0.85, Q = 1.9426
# True positives 587; False positives 22
# With alpha cut 4 and gammaness 0.86, Q = 1.9228
# True positives 581; False positives 22
# With alpha cut 4 and gammaness 0.87, Q = 1.8963
# True positives 573; False positives 22
# With alpha cut 4 and gammaness 0.88, Q = 1.9138
# True positives 565; False positives 21
# With alpha cut 4 and gammaness 0.89, Q = 1.9264
# True positives 555; False positives 20
# With alpha cut 4 and gammaness 0.90, Q = 2.1033
# True positives 542; False positives 16
# With alpha cut 4 and gammaness 0.91, Q = 2.1322
# True positives 532; False positives 15
# With alpha cut 4 and gammaness 0.92, Q = 2.1573
# True positives 520; False positives 14
# With alpha cut 4 and gammaness 0.93, Q = 2.0868
# True positives 503; False positives 14
# With alpha cut 4 and gammaness 0.94, Q = 2.1509
# True positives 480; False positives 12
# With alpha cut 4 and gammaness 0.95, Q = 2.3750
# True positives 459; False positives 9
#
#
# With alpha cut 5 and gammaness 0.80, Q = 2.0086
# True positives 732; False positives 32
# With alpha cut 5 and gammaness 0.81, Q = 1.9894
# True positives 725; False positives 32
# With alpha cut 5 and gammaness 0.82, Q = 2.0462
# True positives 722; False positives 30
# With alpha cut 5 and gammaness 0.83, Q = 2.0405
# True positives 720; False positives 30
# With alpha cut 5 and gammaness 0.84, Q = 2.0523
# True positives 712; False positives 29
# With alpha cut 5 and gammaness 0.85, Q = 2.0623
# True positives 703; False positives 28
# With alpha cut 5 and gammaness 0.86, Q = 2.0417
# True positives 696; False positives 28
# With alpha cut 5 and gammaness 0.87, Q = 2.0124
# True positives 686; False positives 28
# With alpha cut 5 and gammaness 0.88, Q = 2.0254
# True positives 678; False positives 27
# With alpha cut 5 and gammaness 0.89, Q = 2.0244
# True positives 665; False positives 26
# With alpha cut 5 and gammaness 0.90, Q = 2.1445
# True positives 648; False positives 22
# With alpha cut 5 and gammaness 0.91, Q = 2.1577
# True positives 637; False positives 21
# With alpha cut 5 and gammaness 0.92, Q = 2.1589
# True positives 622; False positives 20
# With alpha cut 5 and gammaness 0.93, Q = 2.1438
# True positives 602; False positives 19
# With alpha cut 5 and gammaness 0.94, Q = 2.1685
# True positives 576; False positives 17
# With alpha cut 5 and gammaness 0.95, Q = 2.2817
# True positives 550; False positives 14
#
#
# With alpha cut 6 and gammaness 0.80, Q = 2.0837
# True positives 849; False positives 40
# With alpha cut 6 and gammaness 0.81, Q = 2.0666
# True positives 842; False positives 40
# With alpha cut 6 and gammaness 0.82, Q = 2.1654
# True positives 837; False positives 36
# With alpha cut 6 and gammaness 0.83, Q = 2.1577
# True positives 834; False positives 36
# With alpha cut 6 and gammaness 0.84, Q = 2.1909
# True positives 823; False positives 34
# With alpha cut 6 and gammaness 0.85, Q = 2.1968
# True positives 813; False positives 33
# With alpha cut 6 and gammaness 0.86, Q = 2.2090
# True positives 805; False positives 32
# With alpha cut 6 and gammaness 0.87, Q = 2.2025
# True positives 790; False positives 31
# With alpha cut 6 and gammaness 0.88, Q = 2.2512
# True positives 781; False positives 29
# With alpha cut 6 and gammaness 0.89, Q = 2.2412
# True positives 764; False positives 28
# With alpha cut 6 and gammaness 0.90, Q = 2.3574
# True positives 744; False positives 24
# With alpha cut 6 and gammaness 0.91, Q = 2.3628
# True positives 730; False positives 23
# With alpha cut 6 and gammaness 0.92, Q = 2.3596
# True positives 713; False positives 22
# With alpha cut 6 and gammaness 0.93, Q = 2.3305
# True positives 688; False positives 21
# With alpha cut 6 and gammaness 0.94, Q = 2.3361
# True positives 656; False positives 19
# With alpha cut 6 and gammaness 0.95, Q = 2.4332
# True positives 627; False positives 16
#
#
# With alpha cut 7 and gammaness 0.80, Q = 2.1740
# True positives 929; False positives 44
# With alpha cut 7 and gammaness 0.81, Q = 2.1576
# True positives 922; False positives 44
# With alpha cut 7 and gammaness 0.82, Q = 2.2482
# True positives 916; False positives 40
# With alpha cut 7 and gammaness 0.83, Q = 2.2359
# True positives 911; False positives 40
# With alpha cut 7 and gammaness 0.84, Q = 2.2638
# True positives 899; False positives 38
# With alpha cut 7 and gammaness 0.85, Q = 2.2661
# True positives 888; False positives 37
# With alpha cut 7 and gammaness 0.86, Q = 2.2767
# True positives 880; False positives 36
# With alpha cut 7 and gammaness 0.87, Q = 2.2670
# True positives 864; False positives 35
# With alpha cut 7 and gammaness 0.88, Q = 2.3049
# True positives 853; False positives 33
# With alpha cut 7 and gammaness 0.89, Q = 2.2885
# True positives 834; False positives 32
# With alpha cut 7 and gammaness 0.90, Q = 2.3879
# True positives 814; False positives 28
# With alpha cut 7 and gammaness 0.91, Q = 2.4293
# True positives 798; False positives 26
# With alpha cut 7 and gammaness 0.92, Q = 2.4683
# True positives 779; False positives 24
# With alpha cut 7 and gammaness 0.93, Q = 2.4372
# True positives 753; False positives 23
# With alpha cut 7 and gammaness 0.94, Q = 2.4852
# True positives 716; False positives 20
# With alpha cut 7 and gammaness 0.95, Q = 2.5563
# True positives 679; False positives 17
#
#
# With alpha cut 8 and gammaness 0.80, Q = 2.2642
# True positives 1000; False positives 47
# With alpha cut 8 and gammaness 0.81, Q = 2.2461
# True positives 992; False positives 47
# With alpha cut 8 and gammaness 0.82, Q = 2.3317
# True positives 985; False positives 43
# With alpha cut 8 and gammaness 0.83, Q = 2.3198
# True positives 980; False positives 43
# With alpha cut 8 and gammaness 0.84, Q = 2.3709
# True positives 966; False positives 40
# With alpha cut 8 and gammaness 0.85, Q = 2.3738
# True positives 955; False positives 39
# With alpha cut 8 and gammaness 0.86, Q = 2.3847
# True positives 947; False positives 38
# With alpha cut 8 and gammaness 0.87, Q = 2.3758
# True positives 931; False positives 37
# With alpha cut 8 and gammaness 0.88, Q = 2.4087
# True positives 918; False positives 35
# With alpha cut 8 and gammaness 0.89, Q = 2.3879
# True positives 897; False positives 34
# With alpha cut 8 and gammaness 0.90, Q = 2.4713
# True positives 872; False positives 30
# With alpha cut 8 and gammaness 0.91, Q = 2.5082
# True positives 855; False positives 28
# With alpha cut 8 and gammaness 0.92, Q = 2.5419
# True positives 835; False positives 26
# With alpha cut 8 and gammaness 0.93, Q = 2.4992
# True positives 805; False positives 25
# With alpha cut 8 and gammaness 0.94, Q = 2.5218
# True positives 762; False positives 22
# With alpha cut 8 and gammaness 0.95, Q = 2.5747
# True positives 723; False positives 19
#
#
# With alpha cut 9 and gammaness 0.80, Q = 2.3643
# True positives 1077; False positives 50
# With alpha cut 9 and gammaness 0.81, Q = 2.3467
# True positives 1069; False positives 50
# With alpha cut 9 and gammaness 0.82, Q = 2.4551
# True positives 1061; False positives 45
# With alpha cut 9 and gammaness 0.83, Q = 2.4436
# True positives 1056; False positives 45
# With alpha cut 9 and gammaness 0.84, Q = 2.4958
# True positives 1042; False positives 42
# With alpha cut 9 and gammaness 0.85, Q = 2.4994
# True positives 1031; False positives 41
# With alpha cut 9 and gammaness 0.86, Q = 2.5108
# True positives 1023; False positives 40
# With alpha cut 9 and gammaness 0.87, Q = 2.4906
# True positives 1002; False positives 39
# With alpha cut 9 and gammaness 0.88, Q = 2.5587
# True positives 989; False positives 36
# With alpha cut 9 and gammaness 0.89, Q = 2.5372
# True positives 967; False positives 35
# With alpha cut 9 and gammaness 0.90, Q = 2.6179
# True positives 939; False positives 31
# With alpha cut 9 and gammaness 0.91, Q = 2.6519
# True positives 920; False positives 29
# With alpha cut 9 and gammaness 0.92, Q = 2.7216
# True positives 894; False positives 26
# With alpha cut 9 and gammaness 0.93, Q = 2.6730
# True positives 861; False positives 25
# With alpha cut 9 and gammaness 0.94, Q = 2.6972
# True positives 815; False positives 22
# With alpha cut 9 and gammaness 0.95, Q = 2.7350
# True positives 768; False positives 19
#
#
# With alpha cut 10 and gammaness 0.80, Q = 2.4060
# True positives 1139; False positives 54
# With alpha cut 10 and gammaness 0.81, Q = 2.4094
# True positives 1130; False positives 53
# With alpha cut 10 and gammaness 0.82, Q = 2.5094
# True positives 1120; False positives 48
# With alpha cut 10 and gammaness 0.83, Q = 2.4959
# True positives 1114; False positives 48
# With alpha cut 10 and gammaness 0.84, Q = 2.5431
# True positives 1099; False positives 45
# With alpha cut 10 and gammaness 0.85, Q = 2.5437
# True positives 1087; False positives 44
# With alpha cut 10 and gammaness 0.86, Q = 2.5495
# True positives 1077; False positives 43
# With alpha cut 10 and gammaness 0.87, Q = 2.5245
# True positives 1054; False positives 42
# With alpha cut 10 and gammaness 0.88, Q = 2.5801
# True positives 1038; False positives 39
# With alpha cut 10 and gammaness 0.89, Q = 2.5800
# True positives 1011; False positives 37
# With alpha cut 10 and gammaness 0.90, Q = 2.6562
# True positives 983; False positives 33
# With alpha cut 10 and gammaness 0.91, Q = 2.6792
# True positives 961; False positives 31
# With alpha cut 10 and gammaness 0.92, Q = 2.7370
# True positives 933; False positives 28
# With alpha cut 10 and gammaness 0.93, Q = 2.6737
# True positives 895; False positives 27
# With alpha cut 10 and gammaness 0.94, Q = 2.7415
# True positives 847; False positives 23
# With alpha cut 10 and gammaness 0.95, Q = 2.7698
# True positives 798; False positives 20
#
#
# With alpha cut 11 and gammaness 0.80, Q = 2.4194
# True positives 1187; False positives 58
# With alpha cut 11 and gammaness 0.81, Q = 2.4656
# True positives 1178; False positives 55
# With alpha cut 11 and gammaness 0.82, Q = 2.5640
# True positives 1168; False positives 50
# With alpha cut 11 and gammaness 0.83, Q = 2.5465
# True positives 1160; False positives 50
# With alpha cut 11 and gammaness 0.84, Q = 2.6160
# True positives 1143; False positives 46
# With alpha cut 11 and gammaness 0.85, Q = 2.6055
# True positives 1126; False positives 45
# With alpha cut 11 and gammaness 0.86, Q = 2.6116
# True positives 1116; False positives 44
# With alpha cut 11 and gammaness 0.87, Q = 2.6156
# True positives 1092; False positives 42
# With alpha cut 11 and gammaness 0.88, Q = 2.6671
# True positives 1073; False positives 39
# With alpha cut 11 and gammaness 0.89, Q = 2.6667
# True positives 1045; False positives 37
# With alpha cut 11 and gammaness 0.90, Q = 2.7454
# True positives 1016; False positives 33
# With alpha cut 11 and gammaness 0.91, Q = 2.7657
# True positives 992; False positives 31
# With alpha cut 11 and gammaness 0.92, Q = 2.8191
# True positives 961; False positives 28
# With alpha cut 11 and gammaness 0.93, Q = 2.7513
# True positives 921; False positives 27
# With alpha cut 11 and gammaness 0.94, Q = 2.8224
# True positives 872; False positives 23
# With alpha cut 11 and gammaness 0.95, Q = 2.8427
# True positives 819; False positives 20
#
#
# With alpha cut 12 and gammaness 0.80, Q = 2.3937
# True positives 1224; False positives 63
# With alpha cut 12 and gammaness 0.81, Q = 2.4348
# True positives 1215; False positives 60
# With alpha cut 12 and gammaness 0.82, Q = 2.5180
# True positives 1203; False positives 55
# With alpha cut 12 and gammaness 0.83, Q = 2.5012
# True positives 1195; False positives 55
# With alpha cut 12 and gammaness 0.84, Q = 2.5562
# True positives 1176; False positives 51
# With alpha cut 12 and gammaness 0.85, Q = 2.5443
# True positives 1159; False positives 50
# With alpha cut 12 and gammaness 0.86, Q = 2.5721
# True positives 1148; False positives 48
# With alpha cut 12 and gammaness 0.87, Q = 2.6009
# True positives 1124; False positives 45
# With alpha cut 12 and gammaness 0.88, Q = 2.6443
# True positives 1104; False positives 42
# With alpha cut 12 and gammaness 0.89, Q = 2.6360
# True positives 1074; False positives 40
# With alpha cut 12 and gammaness 0.90, Q = 2.6958
# True positives 1042; False positives 36
# With alpha cut 12 and gammaness 0.91, Q = 2.7074
# True positives 1017; False positives 34
# With alpha cut 12 and gammaness 0.92, Q = 2.7944
# True positives 986; False positives 30
# With alpha cut 12 and gammaness 0.93, Q = 2.7240
# True positives 945; False positives 29
# With alpha cut 12 and gammaness 0.94, Q = 2.8839
# True positives 891; False positives 23
# With alpha cut 12 and gammaness 0.95, Q = 2.9087
# True positives 838; False positives 20
#
#
# With alpha cut 13 and gammaness 0.80, Q = 2.3511
# True positives 1249; False positives 68
# With alpha cut 13 and gammaness 0.81, Q = 2.3855
# True positives 1239; False positives 65
# With alpha cut 13 and gammaness 0.82, Q = 2.4796
# True positives 1227; False positives 59
# With alpha cut 13 and gammaness 0.83, Q = 2.4614
# True positives 1218; False positives 59
# With alpha cut 13 and gammaness 0.84, Q = 2.5096
# True positives 1199; False positives 55
# With alpha cut 13 and gammaness 0.85, Q = 2.4926
# True positives 1180; False positives 54
# With alpha cut 13 and gammaness 0.86, Q = 2.5164
# True positives 1169; False positives 52
# With alpha cut 13 and gammaness 0.87, Q = 2.5368
# True positives 1144; False positives 49
# With alpha cut 13 and gammaness 0.88, Q = 2.5940
# True positives 1121; False positives 45
# With alpha cut 13 and gammaness 0.89, Q = 2.5802
# True positives 1090; False positives 43
# With alpha cut 13 and gammaness 0.90, Q = 2.6248
# True positives 1056; False positives 39
# With alpha cut 13 and gammaness 0.91, Q = 2.7051
# True positives 1031; False positives 35
# With alpha cut 13 and gammaness 0.92, Q = 2.8255
# True positives 997; False positives 30
# With alpha cut 13 and gammaness 0.93, Q = 2.7499
# True positives 954; False positives 29
# With alpha cut 13 and gammaness 0.94, Q = 2.9098
# True positives 899; False positives 23
# With alpha cut 13 and gammaness 0.95, Q = 2.9364
# True positives 846; False positives 20
#
#
# With alpha cut 14 and gammaness 0.80, Q = 2.3599
# True positives 1281; False positives 71
# With alpha cut 14 and gammaness 0.81, Q = 2.3906
# True positives 1270; False positives 68
# With alpha cut 14 and gammaness 0.82, Q = 2.4721
# True positives 1254; False positives 62
# With alpha cut 14 and gammaness 0.83, Q = 2.4485
# True positives 1242; False positives 62
# With alpha cut 14 and gammaness 0.84, Q = 2.4887
# True positives 1221; False positives 58
# With alpha cut 14 and gammaness 0.85, Q = 2.4713
# True positives 1202; False positives 57
# With alpha cut 14 and gammaness 0.86, Q = 2.4929
# True positives 1191; False positives 55
# With alpha cut 14 and gammaness 0.87, Q = 2.5056
# True positives 1164; False positives 52
# With alpha cut 14 and gammaness 0.88, Q = 2.5812
# True positives 1140; False positives 47
# With alpha cut 14 and gammaness 0.89, Q = 2.5662
# True positives 1109; False positives 45
# With alpha cut 14 and gammaness 0.90, Q = 2.6036
# True positives 1074; False positives 41
# With alpha cut 14 and gammaness 0.91, Q = 2.7113
# True positives 1048; False positives 36
# With alpha cut 14 and gammaness 0.92, Q = 2.8214
# True positives 1012; False positives 31
# With alpha cut 14 and gammaness 0.93, Q = 2.7377
# True positives 966; False positives 30
# With alpha cut 14 and gammaness 0.94, Q = 2.9454
# True positives 910; False positives 23
# With alpha cut 14 and gammaness 0.95, Q = 2.9746
# True positives 857; False positives 20
# Iteration: 2
#
#
#
# With alpha cut 2 and gammaness 0.80, Q = 1.7158
# True positives 324; False positives 8
# With alpha cut 2 and gammaness 0.81, Q = 1.8343
# True positives 324; False positives 7
# With alpha cut 2 and gammaness 0.82, Q = 1.8230
# True positives 322; False positives 7
# With alpha cut 2 and gammaness 0.83, Q = 1.8173
# True positives 321; False positives 7
# With alpha cut 2 and gammaness 0.84, Q = 1.8003
# True positives 318; False positives 7
# With alpha cut 2 and gammaness 0.85, Q = 1.7946
# True positives 317; False positives 7
# With alpha cut 2 and gammaness 0.86, Q = 1.7890
# True positives 316; False positives 7
# With alpha cut 2 and gammaness 0.87, Q = 1.9140
# True positives 313; False positives 6
# With alpha cut 2 and gammaness 0.88, Q = 1.8956
# True positives 310; False positives 6
# With alpha cut 2 and gammaness 0.89, Q = 1.8528
# True positives 303; False positives 6
# With alpha cut 2 and gammaness 0.90, Q = 1.8100
# True positives 296; False positives 6
# With alpha cut 2 and gammaness 0.91, Q = 1.7795
# True positives 291; False positives 6
# With alpha cut 2 and gammaness 0.92, Q = 2.1419
# True positives 286; False positives 4
# With alpha cut 2 and gammaness 0.93, Q = 2.4300
# True positives 281; False positives 3
# With alpha cut 2 and gammaness 0.94, Q = 2.8597
# True positives 270; False positives 2
# With alpha cut 2 and gammaness 0.95, Q = 2.7114
# True positives 256; False positives 2
#
#
# With alpha cut 3 and gammaness 0.80, Q = 1.9135
# True positives 478; False positives 14
# With alpha cut 3 and gammaness 0.81, Q = 1.9774
# True positives 476; False positives 13
# With alpha cut 3 and gammaness 0.82, Q = 1.9650
# True positives 473; False positives 13
# With alpha cut 3 and gammaness 0.83, Q = 2.0322
# True positives 470; False positives 12
# With alpha cut 3 and gammaness 0.84, Q = 2.0193
# True positives 467; False positives 12
# With alpha cut 3 and gammaness 0.85, Q = 2.0063
# True positives 464; False positives 12
# With alpha cut 3 and gammaness 0.86, Q = 1.9977
# True positives 462; False positives 12
# With alpha cut 3 and gammaness 0.87, Q = 2.0639
# True positives 457; False positives 11
# With alpha cut 3 and gammaness 0.88, Q = 2.0368
# True positives 451; False positives 11
# With alpha cut 3 and gammaness 0.89, Q = 2.0983
# True positives 443; False positives 10
# With alpha cut 3 and gammaness 0.90, Q = 2.1719
# True positives 435; False positives 9
# With alpha cut 3 and gammaness 0.91, Q = 2.1319
# True positives 427; False positives 9
# With alpha cut 3 and gammaness 0.92, Q = 2.3778
# True positives 420; False positives 7
# With alpha cut 3 and gammaness 0.93, Q = 2.7598
# True positives 412; False positives 5
# With alpha cut 3 and gammaness 0.94, Q = 3.4418
# True positives 398; False positives 3
# With alpha cut 3 and gammaness 0.95, Q = 3.2516
# True positives 376; False positives 3
#
#
# With alpha cut 4 and gammaness 0.80, Q = 2.1168
# True positives 616; False positives 19
# With alpha cut 4 and gammaness 0.81, Q = 2.1677
# True positives 614; False positives 18
# With alpha cut 4 and gammaness 0.82, Q = 2.1571
# True positives 611; False positives 18
# With alpha cut 4 and gammaness 0.83, Q = 2.2088
# True positives 608; False positives 17
# With alpha cut 4 and gammaness 0.84, Q = 2.1906
# True positives 603; False positives 17
# With alpha cut 4 and gammaness 0.85, Q = 2.1761
# True positives 599; False positives 17
# With alpha cut 4 and gammaness 0.86, Q = 2.1615
# True positives 595; False positives 17
# With alpha cut 4 and gammaness 0.87, Q = 2.2018
# True positives 588; False positives 16
# With alpha cut 4 and gammaness 0.88, Q = 2.1756
# True positives 581; False positives 16
# With alpha cut 4 and gammaness 0.89, Q = 2.2083
# True positives 571; False positives 15
# With alpha cut 4 and gammaness 0.90, Q = 2.3347
# True positives 562; False positives 13
# With alpha cut 4 and gammaness 0.91, Q = 2.2932
# True positives 552; False positives 13
# With alpha cut 4 and gammaness 0.92, Q = 2.4433
# True positives 541; False positives 11
# With alpha cut 4 and gammaness 0.93, Q = 2.6412
# True positives 529; False positives 9
# With alpha cut 4 and gammaness 0.94, Q = 3.1125
# True positives 509; False positives 6
# With alpha cut 4 and gammaness 0.95, Q = 2.9413
# True positives 481; False positives 6
#
#
# With alpha cut 5 and gammaness 0.80, Q = 2.3663
# True positives 741; False positives 22
# With alpha cut 5 and gammaness 0.81, Q = 2.4089
# True positives 737; False positives 21
# With alpha cut 5 and gammaness 0.82, Q = 2.3861
# True positives 730; False positives 21
# With alpha cut 5 and gammaness 0.83, Q = 2.4349
# True positives 727; False positives 20
# With alpha cut 5 and gammaness 0.84, Q = 2.4148
# True positives 721; False positives 20
# With alpha cut 5 and gammaness 0.85, Q = 2.3981
# True positives 716; False positives 20
# With alpha cut 5 and gammaness 0.86, Q = 2.3780
# True positives 710; False positives 20
# With alpha cut 5 and gammaness 0.87, Q = 2.4123
# True positives 702; False positives 19
# With alpha cut 5 and gammaness 0.88, Q = 2.3779
# True positives 692; False positives 19
# With alpha cut 5 and gammaness 0.89, Q = 2.4043
# True positives 681; False positives 18
# With alpha cut 5 and gammaness 0.90, Q = 2.5014
# True positives 668; False positives 16
# With alpha cut 5 and gammaness 0.91, Q = 2.4565
# True positives 656; False positives 16
# With alpha cut 5 and gammaness 0.92, Q = 2.5740
# True positives 643; False positives 14
# With alpha cut 5 and gammaness 0.93, Q = 2.6981
# True positives 624; False positives 12
# With alpha cut 5 and gammaness 0.94, Q = 3.0007
# True positives 601; False positives 9
# With alpha cut 5 and gammaness 0.95, Q = 2.8260
# True positives 566; False positives 9
#
#
# With alpha cut 6 and gammaness 0.80, Q = 2.5087
# True positives 854; False positives 26
# With alpha cut 6 and gammaness 0.81, Q = 2.5464
# True positives 850; False positives 25
# With alpha cut 6 and gammaness 0.82, Q = 2.5254
# True positives 843; False positives 25
# With alpha cut 6 and gammaness 0.83, Q = 2.5622
# True positives 838; False positives 24
# With alpha cut 6 and gammaness 0.84, Q = 2.5408
# True positives 831; False positives 24
# With alpha cut 6 and gammaness 0.85, Q = 2.5255
# True positives 826; False positives 24
# With alpha cut 6 and gammaness 0.86, Q = 2.5071
# True positives 820; False positives 24
# With alpha cut 6 and gammaness 0.87, Q = 2.5899
# True positives 811; False positives 22
# With alpha cut 6 and gammaness 0.88, Q = 2.6116
# True positives 799; False positives 21
# With alpha cut 6 and gammaness 0.89, Q = 2.6326
# True positives 786; False positives 20
# With alpha cut 6 and gammaness 0.90, Q = 2.7973
# True positives 770; False positives 17
# With alpha cut 6 and gammaness 0.91, Q = 2.7464
# True positives 756; False positives 17
# With alpha cut 6 and gammaness 0.92, Q = 2.8580
# True positives 739; False positives 15
# With alpha cut 6 and gammaness 0.93, Q = 2.9537
# True positives 711; False positives 13
# With alpha cut 6 and gammaness 0.94, Q = 3.2446
# True positives 685; False positives 10
# With alpha cut 6 and gammaness 0.95, Q = 3.2104
# True positives 643; False positives 9
#
#
# With alpha cut 7 and gammaness 0.80, Q = 2.3504
# True positives 915; False positives 34
# With alpha cut 7 and gammaness 0.81, Q = 2.3728
# True positives 910; False positives 33
# With alpha cut 7 and gammaness 0.82, Q = 2.3519
# True positives 902; False positives 33
# With alpha cut 7 and gammaness 0.83, Q = 2.4104
# True positives 896; False positives 31
# With alpha cut 7 and gammaness 0.84, Q = 2.4284
# True positives 888; False positives 30
# With alpha cut 7 and gammaness 0.85, Q = 2.4147
# True positives 883; False positives 30
# With alpha cut 7 and gammaness 0.86, Q = 2.4365
# True positives 876; False positives 29
# With alpha cut 7 and gammaness 0.87, Q = 2.4992
# True positives 867; False positives 27
# With alpha cut 7 and gammaness 0.88, Q = 2.5087
# True positives 854; False positives 26
# With alpha cut 7 and gammaness 0.89, Q = 2.5134
# True positives 839; False positives 25
# With alpha cut 7 and gammaness 0.90, Q = 2.6186
# True positives 820; False positives 22
# With alpha cut 7 and gammaness 0.91, Q = 2.5643
# True positives 803; False positives 22
# With alpha cut 7 and gammaness 0.92, Q = 2.6975
# True positives 785; False positives 19
# With alpha cut 7 and gammaness 0.93, Q = 2.8235
# True positives 754; False positives 16
# With alpha cut 7 and gammaness 0.94, Q = 3.0160
# True positives 726; False positives 13
# With alpha cut 7 and gammaness 0.95, Q = 2.9230
# True positives 676; False positives 12
#
#
# With alpha cut 8 and gammaness 0.80, Q = 2.3205
# True positives 992; False positives 41
# With alpha cut 8 and gammaness 0.81, Q = 2.3352
# True positives 986; False positives 40
# With alpha cut 8 and gammaness 0.82, Q = 2.3162
# True positives 978; False positives 40
# With alpha cut 8 and gammaness 0.83, Q = 2.3569
# True positives 970; False positives 38
# With alpha cut 8 and gammaness 0.84, Q = 2.3689
# True positives 962; False positives 37
# With alpha cut 8 and gammaness 0.85, Q = 2.3492
# True positives 954; False positives 37
# With alpha cut 8 and gammaness 0.86, Q = 2.3566
# True positives 944; False positives 36
# With alpha cut 8 and gammaness 0.87, Q = 2.3993
# True positives 934; False positives 34
# With alpha cut 8 and gammaness 0.88, Q = 2.4387
# True positives 921; False positives 32
# With alpha cut 8 and gammaness 0.89, Q = 2.4293
# True positives 903; False positives 31
# With alpha cut 8 and gammaness 0.90, Q = 2.4967
# True positives 882; False positives 28
# With alpha cut 8 and gammaness 0.91, Q = 2.4906
# True positives 864; False positives 27
# With alpha cut 8 and gammaness 0.92, Q = 2.5805
# True positives 844; False positives 24
# With alpha cut 8 and gammaness 0.93, Q = 2.6443
# True positives 809; False positives 21
# With alpha cut 8 and gammaness 0.94, Q = 2.9171
# True positives 779; False positives 16
# With alpha cut 8 and gammaness 0.95, Q = 2.7962
# True positives 723; False positives 15
#
#
# With alpha cut 9 and gammaness 0.80, Q = 2.4252
# True positives 1074; False positives 44
# With alpha cut 9 and gammaness 0.81, Q = 2.4395
# True positives 1068; False positives 43
# With alpha cut 9 and gammaness 0.82, Q = 2.4190
# True positives 1059; False positives 43
# With alpha cut 9 and gammaness 0.83, Q = 2.4539
# True positives 1049; False positives 41
# With alpha cut 9 and gammaness 0.84, Q = 2.4630
# True positives 1040; False positives 40
# With alpha cut 9 and gammaness 0.85, Q = 2.4394
# True positives 1030; False positives 40
# With alpha cut 9 and gammaness 0.86, Q = 2.4465
# True positives 1020; False positives 39
# With alpha cut 9 and gammaness 0.87, Q = 2.5114
# True positives 1006; False positives 36
# With alpha cut 9 and gammaness 0.88, Q = 2.5482
# True positives 992; False positives 34
# With alpha cut 9 and gammaness 0.89, Q = 2.5737
# True positives 972; False positives 32
# With alpha cut 9 and gammaness 0.90, Q = 2.6452
# True positives 951; False positives 29
# With alpha cut 9 and gammaness 0.91, Q = 2.6297
# True positives 929; False positives 28
# With alpha cut 9 and gammaness 0.92, Q = 2.7201
# True positives 908; False positives 25
# With alpha cut 9 and gammaness 0.93, Q = 2.7815
# True positives 871; False positives 22
# With alpha cut 9 and gammaness 0.94, Q = 3.0370
# True positives 836; False positives 17
# With alpha cut 9 and gammaness 0.95, Q = 2.8909
# True positives 772; False positives 16
#
#
# With alpha cut 10 and gammaness 0.80, Q = 2.4956
# True positives 1130; False positives 46
# With alpha cut 10 and gammaness 0.81, Q = 2.5097
# True positives 1124; False positives 45
# With alpha cut 10 and gammaness 0.82, Q = 2.5133
# True positives 1113; False positives 44
# With alpha cut 10 and gammaness 0.83, Q = 2.5447
# True positives 1101; False positives 42
# With alpha cut 10 and gammaness 0.84, Q = 2.5545
# True positives 1092; False positives 41
# With alpha cut 10 and gammaness 0.85, Q = 2.5241
# True positives 1079; False positives 41
# With alpha cut 10 and gammaness 0.86, Q = 2.5294
# True positives 1068; False positives 40
# With alpha cut 10 and gammaness 0.87, Q = 2.5807
# True positives 1048; False positives 37
# With alpha cut 10 and gammaness 0.88, Q = 2.6154
# True positives 1033; False positives 35
# With alpha cut 10 and gammaness 0.89, Q = 2.6413
# True positives 1013; False positives 33
# With alpha cut 10 and gammaness 0.90, Q = 2.7046
# True positives 989; False positives 30
# With alpha cut 10 and gammaness 0.91, Q = 2.6785
# True positives 963; False positives 29
# With alpha cut 10 and gammaness 0.92, Q = 2.7583
# True positives 939; False positives 26
# With alpha cut 10 and gammaness 0.93, Q = 2.8109
# True positives 900; False positives 23
# With alpha cut 10 and gammaness 0.94, Q = 3.0397
# True positives 861; False positives 18
# With alpha cut 10 and gammaness 0.95, Q = 2.9695
# True positives 793; False positives 16
#
#
# With alpha cut 11 and gammaness 0.80, Q = 2.6148
# True positives 1184; False positives 46
# With alpha cut 11 and gammaness 0.81, Q = 2.6281
# True positives 1177; False positives 45
# With alpha cut 11 and gammaness 0.82, Q = 2.6307
# True positives 1165; False positives 44
# With alpha cut 11 and gammaness 0.83, Q = 2.6625
# True positives 1152; False positives 42
# With alpha cut 11 and gammaness 0.84, Q = 2.6738
# True positives 1143; False positives 41
# With alpha cut 11 and gammaness 0.85, Q = 2.6410
# True positives 1129; False positives 41
# With alpha cut 11 and gammaness 0.86, Q = 2.6454
# True positives 1117; False positives 40
# With alpha cut 11 and gammaness 0.87, Q = 2.6989
# True positives 1096; False positives 37
# With alpha cut 11 and gammaness 0.88, Q = 2.7318
# True positives 1079; False positives 35
# With alpha cut 11 and gammaness 0.89, Q = 2.7561
# True positives 1057; False positives 33
# With alpha cut 11 and gammaness 0.90, Q = 2.8222
# True positives 1032; False positives 30
# With alpha cut 11 and gammaness 0.91, Q = 2.7926
# True positives 1004; False positives 29
# With alpha cut 11 and gammaness 0.92, Q = 2.8641
# True positives 975; False positives 26
# With alpha cut 11 and gammaness 0.93, Q = 2.9046
# True positives 930; False positives 23
# With alpha cut 11 and gammaness 0.94, Q = 3.1245
# True positives 885; False positives 18
# With alpha cut 11 and gammaness 0.95, Q = 3.0481
# True positives 814; False positives 16
#
#
# With alpha cut 12 and gammaness 0.80, Q = 2.6405
# True positives 1234; False positives 49
# With alpha cut 12 and gammaness 0.81, Q = 2.6484
# True positives 1225; False positives 48
# With alpha cut 12 and gammaness 0.82, Q = 2.6502
# True positives 1213; False positives 47
# With alpha cut 12 and gammaness 0.83, Q = 2.6794
# True positives 1200; False positives 45
# With alpha cut 12 and gammaness 0.84, Q = 2.6826
# True positives 1188; False positives 44
# With alpha cut 12 and gammaness 0.85, Q = 2.6465
# True positives 1172; False positives 44
# With alpha cut 12 and gammaness 0.86, Q = 2.6497
# True positives 1160; False positives 43
# With alpha cut 12 and gammaness 0.87, Q = 2.7271
# True positives 1137; False positives 39
# With alpha cut 12 and gammaness 0.88, Q = 2.7530
# True positives 1118; False positives 37
# With alpha cut 12 and gammaness 0.89, Q = 2.7724
# True positives 1095; False positives 35
# With alpha cut 12 and gammaness 0.90, Q = 2.8332
# True positives 1070; False positives 32
# With alpha cut 12 and gammaness 0.91, Q = 2.7951
# True positives 1039; False positives 31
# With alpha cut 12 and gammaness 0.92, Q = 2.8477
# True positives 1006; False positives 28
# With alpha cut 12 and gammaness 0.93, Q = 2.8669
# True positives 957; False positives 25
# With alpha cut 12 and gammaness 0.94, Q = 3.0479
# True positives 910; False positives 20
# With alpha cut 12 and gammaness 0.95, Q = 2.9515
# True positives 836; False positives 18
#
#
# With alpha cut 13 and gammaness 0.80, Q = 2.6616
# True positives 1269; False positives 51
# With alpha cut 13 and gammaness 0.81, Q = 2.6690
# True positives 1260; False positives 50
# With alpha cut 13 and gammaness 0.82, Q = 2.6705
# True positives 1248; False positives 49
# With alpha cut 13 and gammaness 0.83, Q = 2.6961
# True positives 1234; False positives 47
# With alpha cut 13 and gammaness 0.84, Q = 2.6987
# True positives 1222; False positives 46
# With alpha cut 13 and gammaness 0.85, Q = 2.6590
# True positives 1204; False positives 46
# With alpha cut 13 and gammaness 0.86, Q = 2.6571
# True positives 1190; False positives 45
# With alpha cut 13 and gammaness 0.87, Q = 2.7252
# True positives 1165; False positives 41
# With alpha cut 13 and gammaness 0.88, Q = 2.7487
# True positives 1146; False positives 39
# With alpha cut 13 and gammaness 0.89, Q = 2.7629
# True positives 1122; False positives 37
# With alpha cut 13 and gammaness 0.90, Q = 2.8077
# True positives 1093; False positives 34
# With alpha cut 13 and gammaness 0.91, Q = 2.7639
# True positives 1060; False positives 33
# With alpha cut 13 and gammaness 0.92, Q = 2.7976
# True positives 1023; False positives 30
# With alpha cut 13 and gammaness 0.93, Q = 2.8048
# True positives 973; False positives 27
# With alpha cut 13 and gammaness 0.94, Q = 2.9539
# True positives 925; False positives 22
# With alpha cut 13 and gammaness 0.95, Q = 2.8369
# True positives 847; False positives 20
#
#
# With alpha cut 14 and gammaness 0.80, Q = 2.6281
# True positives 1313; False positives 56
# With alpha cut 14 and gammaness 0.81, Q = 2.6559
# True positives 1303; False positives 54
# With alpha cut 14 and gammaness 0.82, Q = 2.6562
# True positives 1291; False positives 53
# With alpha cut 14 and gammaness 0.83, Q = 2.6721
# True positives 1274; False positives 51
# With alpha cut 14 and gammaness 0.84, Q = 2.6733
# True positives 1262; False positives 50
# With alpha cut 14 and gammaness 0.85, Q = 2.6330
# True positives 1243; False positives 50
# With alpha cut 14 and gammaness 0.86, Q = 2.6298
# True positives 1229; False positives 49
# With alpha cut 14 and gammaness 0.87, Q = 2.6861
# True positives 1203; False positives 45
# With alpha cut 14 and gammaness 0.88, Q = 2.7022
# True positives 1183; False positives 43
# With alpha cut 14 and gammaness 0.89, Q = 2.7042
# True positives 1156; False positives 41
# With alpha cut 14 and gammaness 0.90, Q = 2.7360
# True positives 1126; False positives 38
# With alpha cut 14 and gammaness 0.91, Q = 2.6792
# True positives 1088; False positives 37
# With alpha cut 14 and gammaness 0.92, Q = 2.6921
# True positives 1048; False positives 34
# With alpha cut 14 and gammaness 0.93, Q = 2.6741
# True positives 994; False positives 31
# With alpha cut 14 and gammaness 0.94, Q = 2.8771
# True positives 941; False positives 24
# With alpha cut 14 and gammaness 0.95, Q = 2.7464
# True positives 860; False positives 22
# Iteration: 3
#
#
#
# With alpha cut 2 and gammaness 0.80, Q = 2.1980
# True positives 338; False positives 5
# With alpha cut 2 and gammaness 0.81, Q = 2.1655
# True positives 333; False positives 5
# With alpha cut 2 and gammaness 0.82, Q = 2.3774
# True positives 327; False positives 4
# With alpha cut 2 and gammaness 0.83, Q = 2.3411
# True positives 322; False positives 4
# With alpha cut 2 and gammaness 0.84, Q = 2.3266
# True positives 320; False positives 4
# With alpha cut 2 and gammaness 0.85, Q = 2.6697
# True positives 318; False positives 3
# With alpha cut 2 and gammaness 0.86, Q = 2.6361
# True positives 314; False positives 3
# With alpha cut 2 and gammaness 0.87, Q = 2.6025
# True positives 310; False positives 3
# With alpha cut 2 and gammaness 0.88, Q = 2.5605
# True positives 305; False positives 3
# With alpha cut 2 and gammaness 0.89, Q = 2.5270
# True positives 301; False positives 3
# With alpha cut 2 and gammaness 0.90, Q = 2.5186
# True positives 300; False positives 3
# With alpha cut 2 and gammaness 0.91, Q = 2.4514
# True positives 292; False positives 3
# With alpha cut 2 and gammaness 0.92, Q = 2.9715
# True positives 289; False positives 2
# With alpha cut 2 and gammaness 0.93, Q = 2.8687
# True positives 279; False positives 2
# With alpha cut 2 and gammaness 0.94, Q = 3.8970
# True positives 268; False positives 1
# With alpha cut 2 and gammanesss 0.95, Q = inf
# True positives 252; False positives 0
#
#
# With alpha cut 3 and gammaness 0.80, Q = 2.2807
# True positives 496; False positives 10
# With alpha cut 3 and gammaness 0.81, Q = 2.2485
# True positives 489; False positives 10
# With alpha cut 3 and gammaness 0.82, Q = 2.3411
# True positives 483; False positives 9
# With alpha cut 3 and gammaness 0.83, Q = 2.3169
# True positives 478; False positives 9
# With alpha cut 3 and gammaness 0.84, Q = 2.3023
# True positives 475; False positives 9
# With alpha cut 3 and gammaness 0.85, Q = 2.4163
# True positives 470; False positives 8
# With alpha cut 3 and gammaness 0.86, Q = 2.3649
# True positives 460; False positives 8
# With alpha cut 3 and gammaness 0.87, Q = 2.3289
# True positives 453; False positives 8
# With alpha cut 3 and gammaness 0.88, Q = 2.3032
# True positives 448; False positives 8
# With alpha cut 3 and gammaness 0.89, Q = 2.4292
# True positives 442; False positives 7
# With alpha cut 3 and gammaness 0.90, Q = 2.4072
# True positives 438; False positives 7
# With alpha cut 3 and gammaness 0.91, Q = 2.3358
# True positives 425; False positives 7
# With alpha cut 3 and gammaness 0.92, Q = 2.4933
# True positives 420; False positives 6
# With alpha cut 3 and gammaness 0.93, Q = 2.4161
# True positives 407; False positives 6
# With alpha cut 3 and gammaness 0.94, Q = 2.5426
# True positives 391; False positives 5
# With alpha cut 3 and gammaness 0.95, Q = 3.0810
# True positives 367; False positives 3
#
#
# With alpha cut 4 and gammaness 0.80, Q = 2.2571
# True positives 640; False positives 17
# With alpha cut 4 and gammaness 0.81, Q = 2.2253
# True positives 631; False positives 17
# With alpha cut 4 and gammaness 0.82, Q = 2.2648
# True positives 623; False positives 16
# With alpha cut 4 and gammaness 0.83, Q = 2.2466
# True positives 618; False positives 16
# With alpha cut 4 and gammaness 0.84, Q = 2.2320
# True positives 614; False positives 16
# With alpha cut 4 and gammaness 0.85, Q = 2.2865
# True positives 609; False positives 15
# With alpha cut 4 and gammaness 0.86, Q = 2.2452
# True positives 598; False positives 15
# With alpha cut 4 and gammaness 0.87, Q = 2.2114
# True positives 589; False positives 15
# With alpha cut 4 and gammaness 0.88, Q = 2.1926
# True positives 584; False positives 15
# With alpha cut 4 and gammaness 0.89, Q = 2.2385
# True positives 576; False positives 14
# With alpha cut 4 and gammaness 0.90, Q = 2.2947
# True positives 569; False positives 13
# With alpha cut 4 and gammaness 0.91, Q = 2.2342
# True positives 554; False positives 13
# With alpha cut 4 and gammaness 0.92, Q = 2.2919
# True positives 546; False positives 12
# With alpha cut 4 and gammaness 0.93, Q = 2.3237
# True positives 530; False positives 11
# With alpha cut 4 and gammaness 0.94, Q = 2.3405
# True positives 509; False positives 10
# With alpha cut 4 and gammaness 0.95, Q = 2.4677
# True positives 480; False positives 8
#
#
# With alpha cut 5 and gammaness 0.80, Q = 2.5186
# True positives 755; False positives 19
# With alpha cut 5 and gammaness 0.81, Q = 2.4853
# True positives 745; False positives 19
# With alpha cut 5 and gammaness 0.82, Q = 2.5259
# True positives 737; False positives 18
# With alpha cut 5 and gammaness 0.83, Q = 2.5054
# True positives 731; False positives 18
# With alpha cut 5 and gammaness 0.84, Q = 2.4882
# True positives 726; False positives 18
# With alpha cut 5 and gammaness 0.85, Q = 2.5286
# True positives 717; False positives 17
# With alpha cut 5 and gammaness 0.86, Q = 2.4793
# True positives 703; False positives 17
# With alpha cut 5 and gammaness 0.87, Q = 2.4440
# True positives 693; False positives 17
# With alpha cut 5 and gammaness 0.88, Q = 2.4123
# True positives 684; False positives 17
# With alpha cut 5 and gammaness 0.89, Q = 2.4356
# True positives 670; False positives 16
# With alpha cut 5 and gammaness 0.90, Q = 2.4817
# True positives 661; False positives 15
# With alpha cut 5 and gammaness 0.91, Q = 2.4179
# True positives 644; False positives 15
# With alpha cut 5 and gammaness 0.92, Q = 2.5528
# True positives 633; False positives 13
# With alpha cut 5 and gammaness 0.93, Q = 2.5773
# True positives 614; False positives 12
# With alpha cut 5 and gammaness 0.94, Q = 2.5911
# True positives 591; False positives 11
# With alpha cut 5 and gammaness 0.95, Q = 2.6852
# True positives 554; False positives 9
#
#
# With alpha cut 6 and gammaness 0.80, Q = 2.4981
# True positives 859; False positives 25
# With alpha cut 6 and gammaness 0.81, Q = 2.4691
# True positives 849; False positives 25
# With alpha cut 6 and gammaness 0.82, Q = 2.4933
# True positives 840; False positives 24
# With alpha cut 6 and gammaness 0.83, Q = 2.4725
# True positives 833; False positives 24
# With alpha cut 6 and gammaness 0.84, Q = 2.5075
# True positives 827; False positives 23
# With alpha cut 6 and gammaness 0.85, Q = 2.5359
# True positives 818; False positives 22
# With alpha cut 6 and gammaness 0.86, Q = 2.4863
# True positives 802; False positives 22
# With alpha cut 6 and gammaness 0.87, Q = 2.5131
# True positives 792; False positives 21
# With alpha cut 6 and gammaness 0.88, Q = 2.5426
# True positives 782; False positives 20
# With alpha cut 6 and gammaness 0.89, Q = 2.5620
# True positives 768; False positives 19
# With alpha cut 6 and gammaness 0.90, Q = 2.5876
# True positives 755; False positives 18
# With alpha cut 6 and gammaness 0.91, Q = 2.5294
# True positives 738; False positives 18
# With alpha cut 6 and gammaness 0.92, Q = 2.6355
# True positives 725; False positives 16
# With alpha cut 6 and gammaness 0.93, Q = 2.7320
# True positives 703; False positives 14
# With alpha cut 6 and gammaness 0.94, Q = 2.7263
# True positives 676; False positives 13
# With alpha cut 6 and gammaness 0.95, Q = 2.7796
# True positives 634; False positives 11
#
#
# With alpha cut 7 and gammaness 0.80, Q = 2.5328
# True positives 938; False positives 29
# With alpha cut 7 and gammaness 0.81, Q = 2.5058
# True positives 928; False positives 29
# With alpha cut 7 and gammaness 0.82, Q = 2.5254
# True positives 919; False positives 28
# With alpha cut 7 and gammaness 0.83, Q = 2.5062
# True positives 912; False positives 28
# With alpha cut 7 and gammaness 0.84, Q = 2.5326
# True positives 905; False positives 27
# With alpha cut 7 and gammaness 0.85, Q = 2.5551
# True positives 896; False positives 26
# With alpha cut 7 and gammaness 0.86, Q = 2.5095
# True positives 880; False positives 26
# With alpha cut 7 and gammaness 0.87, Q = 2.5243
# True positives 868; False positives 25
# With alpha cut 7 and gammaness 0.88, Q = 2.5924
# True positives 855; False positives 23
# With alpha cut 7 and gammaness 0.89, Q = 2.5979
# True positives 838; False positives 22
# With alpha cut 7 and gammaness 0.90, Q = 2.6146
# True positives 824; False positives 21
# With alpha cut 7 and gammaness 0.91, Q = 2.5480
# True positives 803; False positives 21
# With alpha cut 7 and gammaness 0.92, Q = 2.6287
# True positives 788; False positives 19
# With alpha cut 7 and gammaness 0.93, Q = 2.7664
# True positives 761; False positives 16
# With alpha cut 7 and gammaness 0.94, Q = 2.7445
# True positives 731; False positives 15
# With alpha cut 7 and gammaness 0.95, Q = 2.7706
# True positives 687; False positives 13
#
#
# With alpha cut 8 and gammaness 0.80, Q = 2.4332
# True positives 1004; False positives 36
# With alpha cut 8 and gammaness 0.81, Q = 2.4090
# True positives 994; False positives 36
# With alpha cut 8 and gammaness 0.82, Q = 2.4161
# True positives 983; False positives 35
# With alpha cut 8 and gammaness 0.83, Q = 2.4339
# True positives 976; False positives 34
# With alpha cut 8 and gammaness 0.84, Q = 2.4477
# True positives 967; False positives 33
# With alpha cut 8 and gammaness 0.85, Q = 2.4600
# True positives 957; False positives 32
# With alpha cut 8 and gammaness 0.86, Q = 2.4188
# True positives 941; False positives 32
# With alpha cut 8 and gammaness 0.87, Q = 2.4262
# True positives 929; False positives 31
# With alpha cut 8 and gammaness 0.88, Q = 2.4734
# True positives 916; False positives 29
# With alpha cut 8 and gammaness 0.89, Q = 2.4649
# True positives 897; False positives 28
# With alpha cut 8 and gammaness 0.90, Q = 2.4682
# True positives 882; False positives 27
# With alpha cut 8 and gammaness 0.91, Q = 2.4553
# True positives 861; False positives 26
# With alpha cut 8 and gammaness 0.92, Q = 2.5022
# True positives 843; False positives 24
# With alpha cut 8 and gammaness 0.93, Q = 2.6434
# True positives 813; False positives 20
# With alpha cut 8 and gammaness 0.94, Q = 2.6768
# True positives 781; False positives 18
# With alpha cut 8 and gammaness 0.95, Q = 2.6683
# True positives 734; False positives 16
#
#
# With alpha cut 9 and gammaness 0.80, Q = 2.4601
# True positives 1070; False positives 40
# With alpha cut 9 and gammaness 0.81, Q = 2.4371
# True positives 1060; False positives 40
# With alpha cut 9 and gammaness 0.82, Q = 2.4425
# True positives 1049; False positives 39
# With alpha cut 9 and gammaness 0.83, Q = 2.4509
# True positives 1039; False positives 38
# With alpha cut 9 and gammaness 0.84, Q = 2.4622
# True positives 1030; False positives 37
# With alpha cut 9 and gammaness 0.85, Q = 2.4720
# True positives 1020; False positives 36
# With alpha cut 9 and gammaness 0.86, Q = 2.4283
# True positives 1002; False positives 36
# With alpha cut 9 and gammaness 0.87, Q = 2.4308
# True positives 989; False positives 35
# With alpha cut 9 and gammaness 0.88, Q = 2.4680
# True positives 975; False positives 33
# With alpha cut 9 and gammaness 0.89, Q = 2.4497
# True positives 953; False positives 32
# With alpha cut 9 and gammaness 0.90, Q = 2.4471
# True positives 937; False positives 31
# With alpha cut 9 and gammaness 0.91, Q = 2.4653
# True positives 913; False positives 29
# With alpha cut 9 and gammaness 0.92, Q = 2.4990
# True positives 893; False positives 27
# With alpha cut 9 and gammaness 0.93, Q = 2.6106
# True positives 861; False positives 23
# With alpha cut 9 and gammaness 0.94, Q = 2.6922
# True positives 828; False positives 20
# With alpha cut 9 and gammaness 0.95, Q = 2.6733
# True positives 780; False positives 18
#
#
# With alpha cut 10 and gammaness 0.80, Q = 2.3989
# True positives 1131; False positives 47
# With alpha cut 10 and gammaness 0.81, Q = 2.3777
# True positives 1121; False positives 47
# With alpha cut 10 and gammaness 0.82, Q = 2.3712
# True positives 1106; False positives 46
# With alpha cut 10 and gammaness 0.83, Q = 2.3757
# ...
# With alpha cut 3 and gammaness 0.90, Q = 2.4976
# True positives 472; False positives 8
# With alpha cut 3 and gammaness 0.91, Q = 2.6248
# True positives 464; False positives 7
# With alpha cut 3 and gammaness 0.92, Q = 2.5683
# True positives 454; False positives 7
# With alpha cut 3 and gammaness 0.93, Q = 2.6640
# True positives 436; False positives 6
# With alpha cut 3 and gammaness 0.94, Q = 3.1206
# True positives 417; False positives 4
# With alpha cut 3 and gammaness 0.95, Q = 2.9784
# True positives 398; False positives 4
#
#
# With alpha cut 4 and gammaness 0.80, Q = 2.4134
# True positives 645; False positives 16
# With alpha cut 4 and gammaness 0.81, Q = 2.4022
# True positives 642; False positives 16
# With alpha cut 4 and gammaness 0.82, Q = 2.4732
# True positives 640; False positives 15
# With alpha cut 4 and gammaness 0.83, Q = 2.4578
# True positives 636; False positives 15
# With alpha cut 4 and gammaness 0.84, Q = 2.5120
# True positives 628; False positives 14
# With alpha cut 4 and gammaness 0.85, Q = 2.6701
# True positives 618; False positives 12
# With alpha cut 4 and gammaness 0.86, Q = 2.6399
# True positives 611; False positives 12
# With alpha cut 4 and gammaness 0.87, Q = 2.7347
# True positives 606; False positives 11
# With alpha cut 4 and gammaness 0.88, Q = 2.7211
# True positives 603; False positives 11
# With alpha cut 4 and gammaness 0.89, Q = 2.6760
# True positives 593; False positives 11
# With alpha cut 4 and gammaness 0.90, Q = 2.6219
# True positives 581; False positives 11
# With alpha cut 4 and gammaness 0.91, Q = 2.6978
# True positives 570; False positives 10
# With alpha cut 4 and gammaness 0.92, Q = 2.6410
# True positives 558; False positives 10
# With alpha cut 4 and gammaness 0.93, Q = 2.6741
# True positives 536; False positives 9
# With alpha cut 4 and gammaness 0.94, Q = 2.8907
# True positives 511; False positives 7
# With alpha cut 4 and gammaness 0.95, Q = 2.7436
# True positives 485; False positives 7
#
#
# With alpha cut 5 and gammaness 0.80, Q = 2.6199
# True positives 763; False positives 19
# With alpha cut 5 and gammaness 0.81, Q = 2.6096
# True positives 760; False positives 19
# With alpha cut 5 and gammaness 0.82, Q = 2.6740
# True positives 758; False positives 18
# With alpha cut 5 and gammaness 0.83, Q = 2.6599
# True positives 754; False positives 18
# With alpha cut 5 and gammaness 0.84, Q = 2.7080
# True positives 746; False positives 17
# With alpha cut 5 and gammaness 0.85, Q = 2.9361
# True positives 734; False positives 14
# With alpha cut 5 and gammaness 0.86, Q = 2.8960
# True positives 724; False positives 14
# With alpha cut 5 and gammaness 0.87, Q = 2.9722
# True positives 716; False positives 13
# With alpha cut 5 and gammaness 0.88, Q = 2.9556
# True positives 712; False positives 13
# With alpha cut 5 and gammaness 0.89, Q = 2.9016
# True positives 699; False positives 13
# With alpha cut 5 and gammaness 0.90, Q = 2.8227
# True positives 680; False positives 13
# With alpha cut 5 and gammaness 0.91, Q = 2.8689
# True positives 664; False positives 12
# With alpha cut 5 and gammaness 0.92, Q = 2.8170
# True positives 652; False positives 12
# With alpha cut 5 and gammaness 0.93, Q = 2.8159
# True positives 624; False positives 11
# With alpha cut 5 and gammaness 0.94, Q = 2.9734
# True positives 596; False positives 9
# With alpha cut 5 and gammaness 0.95, Q = 2.8387
# True positives 569; False positives 9
#
#
# With alpha cut 6 and gammaness 0.80, Q = 2.7213
# True positives 872; False positives 23
# With alpha cut 6 and gammaness 0.81, Q = 2.7729
# True positives 869; False positives 22
# With alpha cut 6 and gammaness 0.82, Q = 2.8982
# True positives 866; False positives 20
# With alpha cut 6 and gammaness 0.83, Q = 2.8849
# True positives 862; False positives 20
# With alpha cut 6 and gammaness 0.84, Q = 2.9289
# True positives 853; False positives 19
# With alpha cut 6 and gammaness 0.85, Q = 3.1430
# True positives 840; False positives 16
# With alpha cut 6 and gammaness 0.86, Q = 3.1998
# True positives 828; False positives 15
# With alpha cut 6 and gammaness 0.87, Q = 3.3997
# True positives 819; False positives 13
# With alpha cut 6 and gammaness 0.88, Q = 3.3790
# True positives 814; False positives 13
# With alpha cut 6 and gammaness 0.89, Q = 3.3209
# True positives 800; False positives 13
# With alpha cut 6 and gammaness 0.90, Q = 3.2337
# True positives 779; False positives 13
# With alpha cut 6 and gammaness 0.91, Q = 3.2836
# True positives 760; False positives 12
# With alpha cut 6 and gammaness 0.92, Q = 3.2145
# True positives 744; False positives 12
# With alpha cut 6 and gammaness 0.93, Q = 3.2040
# True positives 710; False positives 11
# With alpha cut 6 and gammaness 0.94, Q = 3.3725
# True positives 676; False positives 9
# With alpha cut 6 and gammaness 0.95, Q = 3.2029
# True positives 642; False positives 9
#
#
# With alpha cut 7 and gammaness 0.80, Q = 2.8120
# True positives 958; False positives 26
# With alpha cut 7 and gammaness 0.81, Q = 2.8587
# True positives 955; False positives 25
# With alpha cut 7 and gammaness 0.82, Q = 2.9710
# True positives 952; False positives 23
# With alpha cut 7 and gammaness 0.83, Q = 2.9554
# True positives 947; False positives 23
# With alpha cut 7 and gammaness 0.84, Q = 2.9867
# True positives 936; False positives 22
# With alpha cut 7 and gammaness 0.85, Q = 3.1624
# True positives 921; False positives 19
# With alpha cut 7 and gammaness 0.86, Q = 3.1996
# True positives 907; False positives 18
# With alpha cut 7 and gammaness 0.87, Q = 3.3601
# True positives 898; False positives 16
# With alpha cut 7 and gammaness 0.88, Q = 3.3376
# True positives 892; False positives 16
# With alpha cut 7 and gammaness 0.89, Q = 3.2815
# True positives 877; False positives 16
# With alpha cut 7 and gammaness 0.90, Q = 3.1992
# True positives 855; False positives 16
# With alpha cut 7 and gammaness 0.91, Q = 3.3401
# True positives 835; False positives 14
# With alpha cut 7 and gammaness 0.92, Q = 3.2641
# True positives 816; False positives 14
# With alpha cut 7 and gammaness 0.93, Q = 3.2337
# True positives 779; False positives 13
# With alpha cut 7 and gammaness 0.94, Q = 3.4976
# True positives 739; False positives 10
# With alpha cut 7 and gammaness 0.95, Q = 3.4823
# True positives 698; False positives 9
#
#
# With alpha cut 8 and gammaness 0.80, Q = 2.8960
# True positives 1042; False positives 29
# With alpha cut 8 and gammaness 0.81, Q = 2.9388
# True positives 1039; False positives 28
# With alpha cut 8 and gammaness 0.82, Q = 3.0380
# True positives 1035; False positives 26
# With alpha cut 8 and gammaness 0.83, Q = 3.0233
# True positives 1030; False positives 26
# With alpha cut 8 and gammaness 0.84, Q = 3.0473
# True positives 1018; False positives 25
# With alpha cut 8 and gammaness 0.85, Q = 3.1941
# True positives 1001; False positives 22
# With alpha cut 8 and gammaness 0.86, Q = 3.2203
# True positives 986; False positives 21
# With alpha cut 8 and gammaness 0.87, Q = 3.3512
# True positives 976; False positives 19
# With alpha cut 8 and gammaness 0.88, Q = 3.3100
# True positives 964; False positives 19
# With alpha cut 8 and gammaness 0.89, Q = 3.2517
# True positives 947; False positives 19
# With alpha cut 8 and gammaness 0.90, Q = 3.1727
# True positives 924; False positives 19
# With alpha cut 8 and gammaness 0.91, Q = 3.2779
# True positives 903; False positives 17
# With alpha cut 8 and gammaness 0.92, Q = 3.1944
# True positives 880; False positives 17
# With alpha cut 8 and gammaness 0.93, Q = 3.1505
# True positives 842; False positives 16
# With alpha cut 8 and gammaness 0.94, Q = 3.3126
# True positives 798; False positives 13
# With alpha cut 8 and gammaness 0.95, Q = 3.5639
# True positives 753; False positives 10
#
#
# With alpha cut 9 and gammaness 0.80, Q = 2.8685
# True positives 1101; False positives 33
# With alpha cut 9 and gammaness 0.81, Q = 2.8998
# True positives 1096; False positives 32
# With alpha cut 9 and gammaness 0.82, Q = 2.9840
# True positives 1092; False positives 30
# With alpha cut 9 and gammaness 0.83, Q = 2.9703
# True positives 1087; False positives 30
# With alpha cut 9 and gammaness 0.84, Q = 3.0350
# True positives 1073; False positives 28
# With alpha cut 9 and gammaness 0.85, Q = 3.2231
# True positives 1055; False positives 24
# With alpha cut 9 and gammaness 0.86, Q = 3.2425
# True positives 1039; False positives 23
# With alpha cut 9 and gammaness 0.87, Q = 3.3575
# True positives 1028; False positives 21
# With alpha cut 9 and gammaness 0.88, Q = 3.3150
# True positives 1015; False positives 21
# With alpha cut 9 and gammaness 0.89, Q = 3.3367
# True positives 997; False positives 20
# With alpha cut 9 and gammaness 0.90, Q = 3.2597
# True positives 974; False positives 20
# With alpha cut 9 and gammaness 0.91, Q = 3.3584
# True positives 952; False positives 18
# With alpha cut 9 and gammaness 0.92, Q = 3.2702
# True positives 927; False positives 18
# With alpha cut 9 and gammaness 0.93, Q = 3.2198
# True positives 887; False positives 17
# With alpha cut 9 and gammaness 0.94, Q = 3.3641
# True positives 841; False positives 14
# With alpha cut 9 and gammaness 0.95, Q = 3.5831
# True positives 794; False positives 11
#
#
# With alpha cut 10 and gammaness 0.80, Q = 2.8715
# True positives 1167; False positives 37
# With alpha cut 10 and gammaness 0.81, Q = 2.8986
# True positives 1162; False positives 36
# With alpha cut 10 and gammaness 0.82, Q = 3.0144
# True positives 1157; False positives 33
# With alpha cut 10 and gammaness 0.83, Q = 3.0014
# True positives 1152; False positives 33
# With alpha cut 10 and gammaness 0.84, Q = 3.0537
# True positives 1136; False positives 31
# With alpha cut 10 and gammaness 0.85, Q = 3.2174
# True positives 1117; False positives 27
# With alpha cut 10 and gammaness 0.86, Q = 3.2229
# True positives 1098; False positives 26
# With alpha cut 10 and gammaness 0.87, Q = 3.3117
# True positives 1084; False positives 24
# With alpha cut 10 and gammaness 0.88, Q = 3.2628
# True positives 1068; False positives 24
# With alpha cut 10 and gammaness 0.89, Q = 3.2675
# True positives 1047; False positives 23
# With alpha cut 10 and gammaness 0.90, Q = 3.1895
# True positives 1022; False positives 23
# With alpha cut 10 and gammaness 0.91, Q = 3.2628
# True positives 999; False positives 21
# With alpha cut 10 and gammaness 0.92, Q = 3.1746
# True positives 972; False positives 21
# With alpha cut 10 and gammaness 0.93, Q = 3.1899
# True positives 929; False positives 19
# With alpha cut 10 and gammaness 0.94, Q = 3.2852
# True positives 878; False positives 16
# With alpha cut 10 and gammaness 0.95, Q = 3.5861
# True positives 830; False positives 12
#
#
# With alpha cut 11 and gammaness 0.80, Q = 2.7990
# True positives 1212; False positives 42
# With alpha cut 11 and gammaness 0.81, Q = 2.8213
# True positives 1207; False positives 41
# With alpha cut 11 and gammaness 0.82, Q = 2.9184
# True positives 1202; False positives 38
# With alpha cut 11 and gammaness 0.83, Q = 2.9038
# True positives 1196; False positives 38
# With alpha cut 11 and gammaness 0.84, Q = 2.9410
# True positives 1179; False positives 36
# With alpha cut 11 and gammaness 0.85, Q = 3.0638
# True positives 1158; False positives 32
# With alpha cut 11 and gammaness 0.86, Q = 3.1042
# True positives 1136; False positives 30
# With alpha cut 11 and gammaness 0.87, Q = 3.1735
# True positives 1122; False positives 28
# With alpha cut 11 and gammaness 0.88, Q = 3.1198
# True positives 1103; False positives 28
# With alpha cut 11 and gammaness 0.89, Q = 3.1759
# True positives 1082; False positives 26
# With alpha cut 11 and gammaness 0.90, Q = 3.1550
# True positives 1054; False positives 25
# With alpha cut 11 and gammaness 0.91, Q = 3.2113
# True positives 1029; False positives 23
# With alpha cut 11 and gammaness 0.92, Q = 3.1846
# True positives 998; False positives 22
# With alpha cut 11 and gammaness 0.93, Q = 3.1861
# True positives 952; False positives 20
# With alpha cut 11 and gammaness 0.94, Q = 3.2597
# True positives 898; False positives 17
# With alpha cut 11 and gammaness 0.95, Q = 3.5243
# True positives 849; False positives 13
#
#
# With alpha cut 12 and gammaness 0.80, Q = 2.6727
# True positives 1250; False positives 49
# With alpha cut 12 and gammaness 0.81, Q = 2.6896
# True positives 1245; False positives 48
# With alpha cut 12 and gammaness 0.82, Q = 2.7979
# True positives 1240; False positives 44
# With alpha cut 12 and gammaness 0.83, Q = 2.7776
# True positives 1231; False positives 44
# With alpha cut 12 and gammaness 0.84, Q = 2.8353
# True positives 1213; False positives 41
# With alpha cut 12 and gammaness 0.85, Q = 2.9734
# True positives 1192; False positives 36
# With alpha cut 12 and gammaness 0.86, Q = 3.0379
# True positives 1166; False positives 33
# With alpha cut 12 and gammaness 0.87, Q = 3.0940
# True positives 1151; False positives 31
# With alpha cut 12 and gammaness 0.88, Q = 3.0403
# True positives 1131; False positives 31
# With alpha cut 12 and gammaness 0.89, Q = 3.0794
# True positives 1108; False positives 29
# With alpha cut 12 and gammaness 0.90, Q = 3.1108
# True positives 1080; False positives 27
# With alpha cut 12 and gammaness 0.91, Q = 3.1580
# True positives 1055; False positives 25
# With alpha cut 12 and gammaness 0.92, Q = 3.1284
# True positives 1024; False positives 24
# With alpha cut 12 and gammaness 0.93, Q = 3.1080
# True positives 974; False positives 22
# With alpha cut 12 and gammaness 0.94, Q = 3.1418
# True positives 915; False positives 19
# With alpha cut 12 and gammaness 0.95, Q = 3.3466
# True positives 866; False positives 15
#
#
# With alpha cut 13 and gammaness 0.80, Q = 2.6233
# True positives 1276; False positives 53
# With alpha cut 13 and gammaness 0.81, Q = 2.6359
# True positives 1270; False positives 52
# With alpha cut 13 and gammaness 0.82, Q = 2.7595
# True positives 1264; False positives 47
# With alpha cut 13 and gammaness 0.83, Q = 2.7398
# True positives 1255; False positives 47
# With alpha cut 13 and gammaness 0.84, Q = 2.8234
# True positives 1237; False positives 43
# With alpha cut 13 and gammaness 0.85, Q = 2.9524
# True positives 1216; False positives 38
# With alpha cut 13 and gammaness 0.86, Q = 3.0519
# True positives 1189; False positives 34
# With alpha cut 13 and gammaness 0.87, Q = 3.1062
# True positives 1174; False positives 32
# With alpha cut 13 and gammaness 0.88, Q = 3.0480
# True positives 1152; False positives 32
# With alpha cut 13 and gammaness 0.89, Q = 3.0851
# True positives 1129; False positives 30
# With alpha cut 13 and gammaness 0.90, Q = 3.1655
# True positives 1099; False positives 27
# With alpha cut 13 and gammaness 0.91, Q = 3.2149
# True positives 1074; False positives 25
# With alpha cut 13 and gammaness 0.92, Q = 3.1773
# True positives 1040; False positives 24
# With alpha cut 13 and gammaness 0.93, Q = 3.1527
# True positives 988; False positives 22
# With alpha cut 13 and gammaness 0.94, Q = 3.1864
# True positives 928; False positives 19
# With alpha cut 13 and gammaness 0.95, Q = 3.3891
# True positives 877; False positives 15
#
#
# With alpha cut 14 and gammaness 0.80, Q = 2.6089
# True positives 1316; False positives 57
# With alpha cut 14 and gammaness 0.81, Q = 2.6180
# True positives 1309; False positives 56
# With alpha cut 14 and gammaness 0.82, Q = 2.7266
# True positives 1301; False positives 51
# With alpha cut 14 and gammaness 0.83, Q = 2.7078
# True positives 1292; False positives 51
# With alpha cut 14 and gammaness 0.84, Q = 2.8092
# True positives 1273; False positives 46
# With alpha cut 14 and gammaness 0.85, Q = 2.9241
# True positives 1251; False positives 41
# With alpha cut 14 and gammaness 0.86, Q = 3.0092
# True positives 1223; False positives 37
# With alpha cut 14 and gammaness 0.87, Q = 3.0510
# True positives 1206; False positives 35
# With alpha cut 14 and gammaness 0.88, Q = 3.0263
# True positives 1179; False positives 34
# With alpha cut 14 and gammaness 0.89, Q = 3.0559
# True positives 1155; False positives 32
# With alpha cut 14 and gammaness 0.90, Q = 3.1184
# True positives 1122; False positives 29
# With alpha cut 14 and gammaness 0.91, Q = 3.1598
# True positives 1097; False positives 27
# With alpha cut 14 and gammaness 0.92, Q = 3.1790
# True positives 1062; False positives 25
# With alpha cut 14 and gammaness 0.93, Q = 3.1395
# True positives 1006; False positives 23
# With alpha cut 14 and gammaness 0.94, Q = 3.1593
# True positives 944; False positives 20
# With alpha cut 14 and gammaness 0.95, Q = 3.4471
# True positives 892; False positives 15

# %% [markdown]
# To handle the very few cases that return 0 false positives and thus an "infinite" Q value, we decide to consider the median of the Q values across the different iterations instead of the average. To estimate the standard deviation of the values found we ignore these cases.

# %%
test_predictions_df = pd.DataFrame(test_predictions)
test_predictions_df['Q'] = test_predictions_df['Q'].replace('inf', 1e20) # assign very high value to Q to find median
test_predictions_df.groupby(['alpha_cut', 'gamma'])['Q'].agg(
    median_Q = 'median',
    std= lambda x: np.std(x[x != 1e20])).reset_index()
# Out:
#      alpha_cut  gamma  median_Q       std
# 0            2   0.80  1.717138  0.186885
# 1            2   0.81  1.787606  0.173683
# 2            2   0.82  1.776653  0.215635
# 3            2   0.83  1.864144  0.216674
# 4            2   0.84  1.960847  0.185657
# ..         ...    ...       ...       ...
# 203         14   0.91  2.699509  0.231376
# 204         14   0.92  2.721513  0.247925
# 205         14   0.93  2.793130  0.314908
# 206         14   0.94  2.904786  0.338199
# 207         14   0.95  3.002473  0.476680
#
# [208 rows x 4 columns]

# %%
grouped_pred = test_predictions_df.groupby(['alpha_cut', 'gamma'])['Q'].agg(
    median= 'median',
    std= lambda x: np.std(x[x != 1e20]) ).reset_index()

max_mean_row = grouped_pred.loc[grouped_pred['median'].idxmax()]

max_mean = max_mean_row['median']
std_dev = max_mean_row['std']

print(f"The best average Q value found is {max_mean:.2f} ± {std_dev/(N)**0.5:.2f}")
print(f"The best Alpha cut found is {max_mean_row['alpha_cut']:.0f}° ")
print(f"The best gammaness found is {max_mean_row['gamma']:.2f}")
# Out:
# The best average Q value found is 3.01 ± 0.15
# The best Alpha cut found is 13°
# The best gammaness found is 0.95

# %%
selected = test_predictions_df[
    (test_predictions_df['gamma'] == 0.9500000000000002) & 
    (test_predictions_df['alpha_cut'] == 13.0)]

selected_gammas = selected['selected gammas']/selected['total gammas']
avg_selected_gammas= selected_gammas.mean()
std_selected_gammas= selected_gammas.std()
print(f"With these best parameters, the average fraction of selected gammas is ({avg_selected_gammas*100:.1f} ± {std_selected_gammas*100/(N)**0.5:.1f})%")
# Out:
# With these best parameters, the average fraction of selected gammas is (36.0 ± 0.2)%

# %% [markdown]
# This means that, applying this technique on the given dataset with $N_{\gamma} = 12332$ true gamma events, we would identify $n_{\gamma} = (4440 ± 25)$ events as gamma, disregarding the remaining as backgorund. In particular we have the following average performance for the algorithm in terms of TPR, FPR, TNR, FNR:

# %%
tpr = selected['true positives']/selected['total gammas']
tpr_avg = tpr.mean()

fpr = selected['false positives']/selected['total hadrons']
fpr_avg = fpr.mean()

tnr = selected['true negatives']/selected['total hadrons']
tnr_avg= tnr.mean()

fnr = selected['false negatives']/selected['total gammas']
fnr_avg= fnr.mean()

confusion_matrix = np.array([[tpr_avg, fpr_avg], [fnr_avg, tnr_avg]])

fig, ax = plt.subplots(figsize=(9, 9))
cax = ax.matshow(confusion_matrix, cmap='Blues')

ax.set_xticks([0, 1])
ax.set_xticklabels(['gamma', 'background'],fontsize=12)
ax.set_yticks([0, 1])
ax.set_yticklabels(['gamma', 'background'],fontsize=12)


ax.text(0, 0, f'TPR: {tpr_avg:.3f}', ha='center', va='center', color='black',fontsize=12)
ax.text(1, 0, f'FNR: {fnr_avg:.3f}', ha='center', va='center', color='black',fontsize=12)
ax.text(0, 1, f'FPR: {fpr_avg:.3f}', ha='center', va='center', color='black',fontsize=12)
ax.text(1, 1, f'TNR: {tnr_avg:.3f}', ha='center', va='center', color='black',fontsize=12)

fig.colorbar(cax)

ax.set_title('Confusion matrix of final classification strategy',fontsize=15)
ax.set_xlabel('Assigned Labels',fontsize=13.5)
ax.set_ylabel('True Labels',fontsize=13.5)

plt.show()
