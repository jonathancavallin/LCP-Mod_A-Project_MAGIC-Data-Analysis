# %% [markdown]
# # LCP Project: analysis of MAGIC04 dataset
# First, we import the libraries

# %%
# math libraries
import numpy as np
import pandas as pd
import numpy.random as npr
import matplotlib.pyplot as plt
import seaborn as sns
import random as rnd

# general OS libraries
from time import time
import gzip
import os
import operator
import warnings
from IPython.core.interactiveshell import InteractiveShell

# ML libraries
import sklearn
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, roc_auc_score, auc
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Perceptron
from sklearn.datasets import make_classification
from sklearn.svm import NuSVC
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.exceptions import ConvergenceWarning
from sklearn.model_selection import train_test_split
from sklearn.metrics import make_scorer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# Then, we import the dataset and we put it into a DataFrame:

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data
#file_name="/home/samu/LaboratoryOfComputationalPhysics_Y7/Project/magic04.data"
file_name= "magic04.dat"
data = pd.DataFrame(pd.read_csv(file_name))
data.columns=['fLength','fWidth','fSize',
        'fConc','fConc1','fAsym',
        'fM3Long','fM3Trans','fAlpha','fDist','category']
data   
#### save data in a DataFrame
# Out:
#         fLength    fWidth   fSize   fConc  fConc1     fAsym   fM3Long  \
# 0       31.6036   11.7235  2.5185  0.5303  0.3773   26.2722   23.8238
# 1      162.0520  136.0310  4.0612  0.0374  0.0187  116.7410  -64.8580
# 2       23.8172    9.5728  2.3385  0.6147  0.3922   27.2107   -6.4633
# 3       75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277   28.5525
# 4       51.6240   21.1502  2.9085  0.2420  0.1340   50.8761   43.1887
# ...         ...       ...     ...     ...     ...       ...       ...
# 19014   21.3846   10.9170  2.6161  0.5857  0.3934   15.2618   11.5245
# 19015   28.9452    6.7020  2.2672  0.5351  0.2784   37.0816   13.1853
# 19016   75.4455   47.5305  3.4483  0.1417  0.0549   -9.3561   41.0562
# 19017  120.5135   76.9018  3.9939  0.0944  0.0683    5.8043  -93.5224
# 19018  187.1814   53.0014  3.2093  0.2876  0.1539 -167.3125 -168.4558
#
#        fM3Trans   fAlpha     fDist category
# 0       -9.9574   6.3609  205.2610        g
# 1      -45.2160  76.9600  256.7880        g
# 2       -7.1513  10.4490  116.7370        g
# 3       21.8393   4.6480  356.4620        g
# 4        9.8145   3.6130  238.0980        g
# ...         ...      ...       ...      ...
# 19014    2.8766   2.4229  106.8258        h
# 19015   -2.9632  86.7975  247.4560        h
# 19016   -9.4662  30.2987  256.5166        h
# 19017  -63.8389  84.6874  408.3166        h
# 19018   31.4755  52.7310  272.3174        h
#
# [19019 rows x 11 columns]

# %% [markdown]
# Here we write some useful functions for the code

# %% [markdown]
# ## ML functions

# %%
# this function divides the dataset in input in parts_to_be_split parts. One of them is returned as test_set
# the other ones are the training_set. Indexes of the chosen data can be accessed (test_indexes, train_indexes)
# (for example in a K-fold)

def split_train_test_set(data,parts_to_be_split):
    indexes = np.arange(0,data.shape[0],1)
    rnd.shuffle(indexes)
    len_test_set = int(len(indexes) / parts_to_be_split)

    test_indexes = indexes[:len_test_set]
    train_indexes = indexes[len_test_set:]

    train_set = data.iloc[train_indexes]
    test_set = data.iloc[test_indexes]
    
    return train_set, test_set

# this function takes col category and returns as Y (target), the other columns are X (labels)
def split_X_Y(data):
    Y = data['category']
    X = data.drop('category',axis=1)

    return X,Y

# this function takes the point that has the lowest distance from FPR=0 and TPR=1 and computes Q for that point values
def get_best_Q(fpr,tpr):
    distances = np.zeros(len(fpr))
    
    for i in range(len(fpr)):
        distances[i] = np.sqrt(fpr[i]**2+(1-tpr[i])**2)
        
    min_dist_idx = np.argmin(distances)
    best_Q = tpr[min_dist_idx] / np.sqrt(fpr[min_dist_idx])
    return best_Q

# %% [markdown]
# ## Other useful functions
# ### Cutting functions

# %%
# this function finds cut value starting from possible max
def find_max_cut_value(X_train,Y_train,sel_label,min_hadrons):
    new_X = X_train[X_train.columns[sel_label]]
    new_data = np.vstack((new_X,Y_train))
    new_data_sorted = new_data[:, new_data[0].argsort()]
    
    #new_data_sorted_reversed = new_data_sorted[:, ::-1] #reverse!! STARTING FROM MAXX
    
    # setup vars, cut value is  set to max of the label, so that in worst scenario all points are true hadrons
    true_hadrons = 0
    max_cut_value = new_data_sorted[0,0]
    
    for i in range(new_data_sorted.shape[1]):
        if new_data_sorted[1,i] == -1:
            true_hadrons += 1
        if true_hadrons == min_hadrons:
            max_cut_value = new_data_sorted[0,i]
            
    return max_cut_value

# this functions returns the number of true positive and false positive points on test set
def find_tp_fp(X_test,Y_test,sel_label,cut_value):
    new_X = X_test[X_test.columns[sel_label]]
    new_data = np.vstack((new_X,Y_test))
    new_data_sorted = new_data[:, new_data[0].argsort()]
    new_data_sorted_reversed = new_data_sorted[:, ::-1] #reverse!! STARTING FROM MAXX
    fp = 0
    tp = 0
    
    for i in range(new_data_sorted_reversed.shape[1]):
        if new_data_sorted_reversed[0,i] < cut_value:
            if new_data_sorted_reversed[1,i] == 1:
                tp += 1
            if new_data_sorted_reversed[1,i] == -1:
                fp += 1
                
    return tp, fp # true positive, false positive

# %% [markdown]
# # Part 1: plot of the features
# the following code plots histograms for each feature, in red there are gammas (signal), in blue hadrons (background). The code saves the histograms in a directory named 'part_1_plots'

# %%
dir_name = 'part_1_plots'

if not os.path.exists(dir_name):
    os.makedirs(dir_name)


# X contains features, Y contains categories
X = data.loc[:,'fLength':'fDist']
Y = data.loc[:,'category']


for i in range(X.shape[1]):
    x_g = []
    x_h = []
    X_temp = X[str(X.columns[i])]
    for j in range(X.shape[0]):
        if (Y[j] == 'g'):
            x_g.append(X_temp[j])
        if (Y[j] == 'h'):
            x_h.append(X_temp[j])
    
    titolo = 'Hist of feature ' + str(i) + ' : ' + X.columns[i]
    img_name = 'hist_'+str(i)+'_'+X.columns[i]+'.png'
    
    ax = sns.histplot(x_h,label='hadron',alpha=0.5,color='blue', edgecolor='black')
    ax2 = sns.histplot(x_g,label='gamma',alpha=0.5,color='red', edgecolor='black')
    t = plt.title(titolo)
    lgnd = plt.legend()
    plt.savefig(os.path.join(dir_name, img_name))  # Save the plot

    plt.show()
# Out:
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Part 3: Study of features' correlation
# In this section we study the correlation between the features. Results will be presented using 2D correlation matrices. We repeat the analysis using all the samples and distinguishing between gamma and background events to spot possible differences. Strongly correlated input features would suggest that we could reduce the dimensionality of the problem disregarding some of them, while still keeping most of the information and variability of the dataset. This will be properly studied performing a Principal Component Analysis in the following part.
# First, we rescale all the features to have zero mean and unitary standard deviation, which will be useful also for the classification algorithms section.

# %%
X_rescaled = X
for i in range(X.shape[1]):
    h = X[str(X.columns[i])]
    avg = np.average(h)
    std = np.std(h)
    h = h - avg
    h = h / std
    X_rescaled[str(X_rescaled.columns[i])] = h
    
#print('media length:',np.average(X_rescaled['fLength']))
#print('dev_std length:',np.std(X_rescaled['fLength']))

# %% [markdown]
# This cell computes and prints the correlation matrix for all the data

# %%
cov = np.zeros((X_rescaled.shape[1],X_rescaled.shape[1]))
for i in range(X_rescaled.shape[1]):
    h = X_rescaled[str(X_rescaled.columns[i])]
    for j in range(X_rescaled.shape[1]):
        v = X_rescaled[str(X_rescaled.columns[j])]
        cov[i,j] = (np.cov(h,v)[0,1])
            
ticks = np.arange(0,10,1)
fig, ax = plt.subplots(figsize=(8, 8))
cax = ax.imshow(cov, cmap='coolwarm', interpolation='nearest')
fig.colorbar(cax)
ax.set_xticks(np.arange(-0.5, cov.shape[1], 1), minor=True)
ax.set_yticks(np.arange(-0.5, cov.shape[0], 1), minor=True)
ax.grid(which='minor', color='black', linewidth=1)

for i in range(cov.shape[0]):
    for j in range(cov.shape[1]):
        ax.text(j, i, f'{cov[i, j]:.2f}', ha='center', va='center', color='black', fontsize=10) # adds covariance text to each grid
ax.plot([-0.5, cov.shape[1]-0.5], [-0.5, cov.shape[0]-0.5], color='black', linewidth=2, linestyle='-')
plt.title('FEATURES CORRELATION',fontweight='bold')
plt.show();

# %% [markdown]
# It looks like we have good correlation between
# - features 0-1
# - features 0-2
# - features 3-4
#
# And good anti-correlation between
# - features 2-3
# - features 2-4

# %% [markdown]
# The following cell computes the correlation matrix taking apart gammas from hadrons

# %%
Xg_rescaled = X_rescaled[Y == 'g']
Xh_rescaled = X_rescaled[Y == 'h']

cov = np.zeros((Xg_rescaled.shape[1],Xg_rescaled.shape[1]))
for i in range(Xg_rescaled.shape[1]):
    h = Xg_rescaled[str(Xg_rescaled.columns[i])]
    for j in range(Xg_rescaled.shape[1]):
        v = Xg_rescaled[str(Xg_rescaled.columns[j])]
        cov[i,j] = (np.cov(h,v)[0,1])
        
std_devs = np.std(Xg_rescaled, axis=0)
cov = cov / np.outer(std_devs, std_devs) # the data for gamma events are not normalized with respsect to themselv   

ticks = np.arange(0,10,1)
fig, ax = plt.subplots(1, 2, figsize=(16, 8))
cax = ax[0].imshow(cov, cmap='coolwarm', interpolation='nearest')
fig.colorbar(cax)
ax[0].set_xticks(np.arange(-0.5, cov.shape[1], 1), minor=True)
ax[0].set_yticks(np.arange(-0.5, cov.shape[0], 1), minor=True)
ax[0].grid(which='minor', color='black', linewidth=1)

for i in range(cov.shape[0]):
    for j in range(cov.shape[1]):
        ax[0].text(j, i, f'{cov[i, j]:.2f}', ha='center', va='center', color='black', fontsize=10)

ax[0].plot([-0.5, cov.shape[1]-0.5], [-0.5, cov.shape[0]-0.5], color='black', linewidth=2, linestyle='-')
ax[0].plot([-0.5, cov.shape[1]-0.5], [-0.5, cov.shape[0]-0.5], color='black', linewidth=2, linestyle='-')
ax[0].set_title('GAMMA EVENTS FEATURES CORRELATION',fontweight='bold')

cov = np.zeros((Xh_rescaled.shape[1],Xh_rescaled.shape[1]))
for i in range(Xh_rescaled.shape[1]):
    h = Xh_rescaled[str(Xh_rescaled.columns[i])]
    for j in range(Xh_rescaled.shape[1]):
        v = Xh_rescaled[str(Xh_rescaled.columns[j])]
        cov[i,j] = (np.cov(h,v)[0,1])
        
std_devs = np.std(Xh_rescaled, axis=0)
cov = cov / np.outer(std_devs, std_devs)

cax = ax[1].imshow(cov, cmap='coolwarm', interpolation='nearest')
fig.colorbar(cax)
ax[1].set_xticks(np.arange(-0.5, cov.shape[1], 1), minor=True)
ax[1].set_yticks(np.arange(-0.5, cov.shape[0], 1), minor=True)
ax[1].grid(which='minor', color='black', linewidth=1)

for i in range(cov.shape[0]):
    for j in range(cov.shape[1]):
        ax[1].text(j, i, f'{cov[i, j]:.2f}', ha='center', va='center', color='black', fontsize=10)

ax[1].plot([-0.5, cov.shape[1]-0.5], [-0.5, cov.shape[0]-0.5], color='black', linewidth=2, linestyle='-')
ax[1].set_title('HADRON EVENTS FEATURES CORRELATION',fontweight='bold')

plt.show();

# %% [markdown]
# # Correlation between features and label (Jonny)

# %%
# Calculate the correlation between each feature and the label Y

Y_array = np.where(Y == 'g', 1, -1)
Y_array = np.array(Y_array) 
feature_names = data.columns[:10]

correlations = np.zeros(X_rescaled.shape[1])  
for i in range(X_rescaled.shape[1]):
    feature = X_rescaled.iloc[:, i]  
    correlations[i] = np.corrcoef(feature, Y_array)[0, 1]

# create a bar plot to display the correlations
fig, ax = plt.subplots(figsize=(14.5, 10))

bars = ax.bar(feature_names, correlations, color='teal', edgecolor='black', linewidth=1.2,alpha=0.8)

# add correlation values on top of each bar
for i, corr in enumerate(correlations):
    ax.text(i, corr + 0.035 if corr>=0 else corr-0.035, f'{corr:.2f}', ha='center', va='bottom', fontsize=12, color='black', fontweight='bold')

ax.set_ylabel('Correlation with Label Y', fontsize=14, fontweight='bold')
ax.set_ylim(-0.53,0.3)
ax.set_title('Correlation between features and label Y', fontsize=16, fontweight='bold')
ax.set_xticks(np.arange(len(feature_names)))
ax.set_xticklabels(feature_names, fontsize=12, fontweight='bold', rotation=20, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# The features most strongly correlated with the label Y, and thus most informative for distinguishing between gamma and hadron events, are $Alpha$, $Length$ and $Width$. This is coherent with our observations from the feature histograms, where these features exhibit more distinct distributions between the two classes.

# %% [markdown]
# # Part 2: Comparison of the features rescaled

# %% [markdown]
# # Part 4: PCA

# %% [markdown]
# # Part 5: Machine Learning Analysis
# In this section we are going to implement several ML binary classification algorithms to distinguish between gamma and hadron events. We choose as objective for each model to maximize the ROC curve area in the False Positive Rate (FPR) range $[0,0.2]$.
#
# The ROC curve plots the TPR, i.e: the fraction of actual gamma samples correctly identified as gamma, versus the False Positive Rate (FPR), i.e: the fraction of actual hadrons events incorrectly classified as gamma by the model. To do so, it's necessary to estimate a probability for the predicted class, not just to assign the predicted label. We will call $\textbf{\textit{gammaness}}$ the probability returned by each prediction model for a certain event to be a gamma event. Imposing different threshold values on the gammaness for the acceptance of an event as either gamma or hadron, we can obtain the ROC curve. The Area Under the ROC Curve (AUC) represents the overall probability that the model will distinguish between the two classes. However, in our case we are mostly interested in avoiding false positives, we do not really care about loss minimization per se or about the model performance at high FPR. This is the reason why we choose to maximize the partial AUC in a region that is a better indicator of how well the model performs for our specific needs.

# %% [markdown]
# ## Part 5.1: Perceptron
# The following code is about Perceptron algorithm. Scikit learn is going to be used. Also, all the analysis is going to be performed without the feature Alpha
#
# First, we associate +1 label to gammas and -1 label to hadrons. Then we split train and test set (20% of total data)

# %%
new_Y = []

# gammas are +1    hadrons are -1

for i in range(len(Y)):
    if (Y.iloc[i] == 'g'):
        new_Y.append(1)
    if(Y.iloc[i] == 'h'):
        new_Y.append(-1)
        
Y_df = pd.DataFrame({'category' : new_Y})
data_rescaled_and_indexed = pd.merge(X_rescaled, Y_df,left_index=True, right_index=True)

# divide dataset in 5 parts, taking 1 as test set ( 20 % )
# remove alpha



parts_to_be_split = 5 
train_set, test_set = split_train_test_set( data_rescaled_and_indexed , parts_to_be_split )
train_alpha = train_set['fAlpha']
train_set = train_set.drop('fAlpha',axis=1)
test_alpha = test_set['fAlpha']
test_set = test_set.drop('fAlpha',axis=1)
X_train, Y_train = split_X_Y(train_set)
X_test, Y_test = split_X_Y(test_set)

print('Train set shapes:',np.shape(X_train),np.shape(Y_train))
print('Test set shapes:',np.shape(X_test),np.shape(Y_test))
# Out:
# Train set shapes: (15216, 9) (15216,)
# Test set shapes: (3803, 9) (3803,)

# %% [markdown]
# The following cell performs the training. The parameters are set at the beginning and the best model criterion is the one that maximizes ROC area in range [0-0.2]

# %%
n_attempts = 10000
limit = 0.2 
best_scores = []
best_f = []
best_t = []
best_score = 0

print('n_iter, score')
for i in range (n_attempts):
    state = abs(np.random.normal(size=1))
    state = int(state[0] * 1000000)
    perceptron = Perceptron(alpha=0.01,penalty='l2',max_iter=50000,tol=1e-4,random_state=state,n_iter_no_change=10)
    
    fitted = perceptron.fit(X_train,Y_train)
    
    decision_values = perceptron.decision_function(X_test)

    fpr, tpr, thresholds = roc_curve(Y_test, decision_values)
    
    # here i filter data to compute roc curve area for fpr in range 0 -> 0.8
    fpr_filtered = fpr[fpr <= limit]
    tpr_filtered = tpr[:len(fpr_filtered)]
    
    auc_filtered = np.trapz(tpr_filtered, fpr_filtered)
    auc = roc_auc_score(Y_test, decision_values)
    
    # score is better if filtered is better, though saving all 
    if (auc_filtered > best_score):
        best_score = auc_filtered
        best_scores.append(auc)
        best_f.append(fpr)
        best_t.append(tpr)
        print(i, auc)
    
print("best AUC-ROC Score:")
print(best_scores[len(best_scores)-1])
# Out:
# n_iter, score
# 0 0.5242643322611676
# 1 0.5745473388716702
# 2 0.6323823733759677
# 8 0.5999206398102674
# 10 0.6292802500486471
# 17 0.6806960150936859
# 42 0.699308145063839
# 58 0.6698012213295301
# 72 0.6783694988474167
# 6349 0.6970017586120445
# best AUC-ROC Score:
# 0.6970017586120445

# %% [markdown]
# In the end we take the ROC curve and the best Q value (the one closest to the point (0,1)). We save it in a variable that will be used later as confrontation.

# %%
fig = plt.figure(figsize=(8, 6))

fpr_perceptron = best_f[len(best_f)-1] 
tpr_perceptron = best_t[len(best_f)-1]
Q_perceptron = get_best_Q(fpr_perceptron,tpr_perceptron)

print('Q value:',Q_perceptron)
plt.plot(fpr_perceptron, tpr_perceptron, label=f'ROC Curve (AUC = {best_scores[len(best_f)-1]:.3f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Diagonal line (random classifier)
plt.title('Perceptron ROC Curve')
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.legend(loc='lower right')
plt.grid(True)
plt.show();
# Out:
# Q value: 1.046792229905368

# %% [markdown]
# ## Part 5.2: SVM
# In this part the same dataset is analyzed with soft SVM. Different kernels are tried (linear,poly with deg 3,rbf and sigmoid), as well as different values for parameters such as nu and gamma

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_curve, auc
from sklearn.svm import NuSVC
import time

# list with all possible kernels (poly uses deg = 3 as standard value)
kernels = ['linear','poly','rbf','sigmoid']


# list with all nu values (upper bound on fraction of margin errors)
nus = [ 0.5 , 0.1 , 0.05 , 0.01 ]

# list with all gamma values (by default is 1/(n_features*X.var()) )
gammas = [ 0.1, 0.01, 0.001, 0.0001 ]

best_auc_score = 0

# tolerance for stopping criteria (default is 1e-3) (default max_iter is inf)
tolerance = 1e-6
max_iter = int(1e4)

start_time = time.time()

for kernel_type in kernels:
    for nu in nus:
        for gamma in gammas:
            print(f'training SVM with {kernel_type} kernel...')
            clf = make_pipeline(StandardScaler(), NuSVC(nu=nu,kernel=kernel_type,gamma=gamma,probability=True,tol=tolerance,max_iter=max_iter),verbose=False)

            fitted = clf.fit(X_train, Y_train)
            pred = clf.predict(X_test)
            errors = np.sum(pred != Y_test) / len(Y_test)
            
            pred_prob = clf.predict_proba(X_test)[:, 1]
            fpr, tpr, thresholds = roc_curve(Y_test, pred_prob)
            
            roc_auc = auc(fpr, tpr)
            
            fpr_filtered = fpr[fpr <= limit]
            tpr_filtered = tpr[:len(fpr_filtered)]
    
            auc_filtered = np.trapz(tpr_filtered, fpr_filtered)
              
            if(auc_filtered > best_auc_score):
                best_auc_score = auc_filtered
                best_tpr = tpr
                best_fpr = fpr
                best_auc = roc_auc
                best_kernel = kernel_type
                best_nu = nu
                best_gamma = gamma
                print(auc_filtered.round(3),best_auc.round(3), kernel_type, nu, gamma)
            print('elapsed time:',time.time()-start_time)
            start_time = time.time()

print('best results are for')
print('kernel:',best_kernel,'nu:',best_nu,'gamma:',best_gamma,'with auc:',best_auc)
# Out:
# training SVM with linear kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# 0.001 0.346 linear 0.5 0.1
# elapsed time: 24.18678379058838
# training SVM with linear kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# 0.011 0.54 linear 0.5 0.01
# elapsed time: 21.61507749557495
# training SVM with linear kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# 0.03 0.616 linear 0.5 0.001
# elapsed time: 21.83802342414856
# training SVM with linear kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 21.901559114456177
# training SVM with linear kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 10.726551532745361
# training SVM with linear kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 8.812822818756104
# training SVM with linear kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 7.9511730670928955
# training SVM with linear kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 8.096796751022339
# training SVM with linear kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 6.148699522018433
# training SVM with linear kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 6.291765928268433
# training SVM with linear kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 6.337647914886475
# training SVM with linear kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 6.33115816116333
# training SVM with linear kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 4.8998863697052
# training SVM with linear kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 6.808542251586914
# training SVM with linear kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 6.344388961791992
# training SVM with linear kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 4.5541863441467285
# training SVM with poly kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# 0.06 0.785 poly 0.5 0.1
# elapsed time: 30.823195934295654
# training SVM with poly kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 30.451175689697266
# training SVM with poly kernel...
# 0.069 0.801 poly 0.5 0.001
# elapsed time: 25.44858145713806
# training SVM with poly kernel...
# elapsed time: 14.867043256759644
# training SVM with poly kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 7.921769857406616
# training SVM with poly kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 7.8955042362213135
# training SVM with poly kernel...
# elapsed time: 3.9056200981140137
# training SVM with poly kernel...
# elapsed time: 2.819467306137085
# training SVM with poly kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 6.1416919231414795
# training SVM with poly kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 6.120949983596802
# training SVM with poly kernel...
# elapsed time: 2.1555328369140625
# training SVM with poly kernel...
# elapsed time: 1.3919200897216797
# training SVM with poly kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 4.737052917480469
# training SVM with poly kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 5.0292441844940186
# training SVM with poly kernel...
# elapsed time: 0.6785123348236084
# training SVM with poly kernel...
# elapsed time: 0.3078627586364746
# training SVM with rbf kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# 0.089 0.844 rbf 0.5 0.1
# elapsed time: 39.45743536949158
# training SVM with rbf kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 40.28648018836975
# training SVM with rbf kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 41.834031105041504
# training SVM with rbf kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 43.7575843334198
# training SVM with rbf kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 15.051624774932861
# training SVM with rbf kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 12.826814651489258
# training SVM with rbf kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 11.677820205688477
# training SVM with rbf kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 11.942949771881104
# training SVM with rbf kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 12.278342723846436
# training SVM with rbf kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 9.710479259490967
# training SVM with rbf kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 8.704010963439941
# training SVM with rbf kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 8.950604677200317
# training SVM with rbf kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 10.412477731704712
# training SVM with rbf kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 7.228765964508057
# training SVM with rbf kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 6.274868011474609
# training SVM with rbf kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 6.525046110153198
# training SVM with sigmoid kernel...
# elapsed time: 362.0465404987335
# training SVM with sigmoid kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 52.19610047340393
# training SVM with sigmoid kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 38.85346746444702
# training SVM with sigmoid kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 33.8926899433136
# training SVM with sigmoid kernel...
# elapsed time: 13.90858006477356
# training SVM with sigmoid kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 13.304558992385864
# training SVM with sigmoid kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 16.84815526008606
# training SVM with sigmoid kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 10.137037515640259
# training SVM with sigmoid kernel...
# elapsed time: 8.715142488479614
# training SVM with sigmoid kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 6.486491441726685
# training SVM with sigmoid kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 8.856568098068237
# training SVM with sigmoid kernel...
# elapsed time: 3.134467601776123
# training SVM with sigmoid kernel...
# elapsed time: 1.7710177898406982
# training SVM with sigmoid kernel...
# elapsed time: 1.6530852317810059
# training SVM with sigmoid kernel...
# /usr/lib/python3/dist-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# elapsed time: 4.263887405395508
# training SVM with sigmoid kernel...
# elapsed time: 0.8065440654754639
# best results are for
# kernel: rbf nu: 0.5 gamma: 0.1 with auc: 0.8443646640367801

# %% [markdown]
# The best curve is then plotted and saved

# %%
tpr_SVM = best_tpr
fpr_SVM = best_fpr
Q_SVM = get_best_Q(fpr_SVM,tpr_SVM)

print('best SVM Q value:',Q_SVM)
plt.figure(figsize=(8, 6))
plt.plot(best_fpr, best_tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % best_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'ROC Curve for SVM with {best_kernel} kernel')
plt.legend(loc='lower right')
plt.show();
# Out:
# best SVM Q value: 1.5720029472731898

# %% [markdown]
# Let's check how SVM performed in comparison to Perceptron

# %%
plt.figure(figsize=(8, 6))
plt.plot(fpr_SVM, tpr_SVM, color='darkorange', lw=2, label='SVM ROC' % best_auc)
plt.plot(fpr_perceptron, tpr_perceptron, color='blue', lw=2, label='Perceptron ROC' % best_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'ROC Curve for SVM with {best_kernel} kernel')
plt.legend(loc='lower right')
plt.show();

# %% [markdown]
# ## Part 5.3: Random Forest
# Here we are going to implement a Random Forest classification algorithm. A Random Forest is composed of different decision tree predictors. For each tree, at each iteration, the data are split into two branches according to a threshold value for one of the features. At each split, the best feature and the best threshold value are chosen by minimizing the entropy function
# 𝐻 given by:
# $$
# \displaystyle H = - \sum_{i=+1,-1} f_i \log_2(f_i)
# $$
# where $f_i$ is the fraction of points of class $i=+1,-1$ in the training set. The splitting continues until either a maximum depth for the tree is reached, in which case the most frequent class of the branch is assigned to all points, or the points of the branch all belong to the same class (in this case the branch is called a leaf). Different trees are built by randomly drawing data with replacement from the test set, applying the algorithm to each tree. The final label for a point is chosen based on a majority vote of the trees results.
#
# The hyper-parameters of the model are the **number of trees** and the **maximum depth** of the trees. We are going to implement a K-fold cross validation to choose as best hyper-parameters the ones that maximize the area under the ROC curve of the classifier. To build the ROC curve we need to estimate the probability for the points to belong to a certain class. This can be done because each tree, at the last decision step, assigns a class label based on the majority class of the training samples that reached that final leaf node, but also keeps track of the proportion of the classes in that leaf node. For example, suppose a test point ends up in a leaf node where, out of 100 training samples that ended up there, 80 belonged to class 1 and 20 belonged to class -1. The probability of the point belonging to class 1 would be 0.8, while the probability of it belonging to class -1 would be 0.2.
#
# We will use the class `RandomForestClassifier` from `scikit-learn` to implement and train the Forest and to predict the labels with their probabilities.
#
#
# **UTILIZZIAMO COME CRITERIO L'INTERA AREA SOTTO LA CURVA O SOLO FINO AD UNA CERTA SOGLIA DI FALSE POSITIVES??**

# %%
num_trees= np.arange(40,300,10)
max_depth= np.arange(10,40,2)
accuracies=[]
roc_areas=[]
best_area=0
best_acc=0
best_model= [] # stores best number of trees and best max depth
partial_aucs = []

start_time = time.time()

max_iter = len(num_trees) * len(max_depth)
iteration = 0

for tree in num_trees:
    for depth in max_depth: 
        forest = RandomForestClassifier(n_estimators=tree,  # number of trees
                                       max_depth= depth, 
                                       max_features=X_train.shape[1],   # number of features for each split (random subset)
                                       bootstrap=True,    # bagging (sampling with replacement)
                                       max_samples=1.0,   # percentage of samples to use for each tree (100% of data)
                                       random_state=10,
                                       n_jobs=-1)
        # train each model, predict labels and probability of each label
        forest.fit(X_train, Y_train)
        Y_pred = forest.predict(X_test)
        y_pred_prob = forest.predict_proba(X_test)[:, 1] # probability for the validation points to belong to class +1 or -1
        # accuracy on validation set
        accuracy = accuracy_score(Y_test, Y_pred)
        accuracies.append(accuracy)
        iteration +=1 
        print(f'elapsed time: {round(time.time()-start_time,2)}s, done {iteration} out of {max_iter}')
        print('Number of trees:',tree,', Maximum depth',depth,':') 
        print('Accuracy:',accuracy)
        # false positive rates and the true positive rates for different threshold values 
        fpr, tpr, thresholds = roc_curve(Y_test, y_pred_prob)
        # area under the ROC curve on validation set 
        roc_auc = auc(fpr, tpr)
        roc_areas.append(roc_auc)
        '''if(roc_auc>best_area):
            best_area= roc_auc
            best_acc= accuracy
            best_model=[tree,depth]
            '''
        partial_fpr = fpr[fpr <= 0.2]
        if (len(partial_fpr) < 2 ):
            partial_auc = 0
        else:
            partial_tpr = tpr[:len(partial_fpr)]
            partial_auc = auc(partial_fpr, partial_tpr)
        partial_aucs.append(partial_auc)
        if(partial_auc>best_area):
            best_area= partial_auc
            best_total_auc = roc_auc
            best_acc= accuracy
            best_model=[tree,depth]
        print('Area under ROC curve:',roc_auc,'Selected area:',partial_auc,'\n')
        
print('Best number of trees:', best_model[0],'\n')
print('Best maximum depth:', best_model[1],'\n')
print('Area under ROC curve of best model:',best_area)
# Out:
# elapsed time: 0.94s, done 1 out of 390
# Number of trees: 40 , Maximum depth 10 :
# Accuracy: 0.8154088877202209
# Area under ROC curve: 0.857634316053633 Selected area: 0.095624453674328
#
# elapsed time: 2.01s, done 2 out of 390
# Number of trees: 40 , Maximum depth 12 :
# Accuracy: 0.8214567446752564
# Area under ROC curve: 0.8688632339063818 Selected area: 0.10380950260497843
#
# elapsed time: 3.17s, done 3 out of 390
# Number of trees: 40 , Maximum depth 14 :
# Accuracy: 0.8235603470943992
# Area under ROC curve: 0.8763089703854123 Selected area: 0.10871720749731147
#
# elapsed time: 4.54s, done 4 out of 390
# Number of trees: 40 , Maximum depth 16 :
# Accuracy: 0.8225085458848278
# Area under ROC curve: 0.8783222548297782 Selected area: 0.10910607852693825
#
# elapsed time: 6.06s, done 5 out of 390
# Number of trees: 40 , Maximum depth 18 :
# Accuracy: 0.8264528004207204
# Area under ROC curve: 0.8795812819751111 Selected area: 0.11007673111657532
#
# elapsed time: 7.65s, done 6 out of 390
# Number of trees: 40 , Maximum depth 20 :
# Accuracy: 0.8288193531422561
# Area under ROC curve: 0.8801423237468746 Selected area: 0.10946444986796684
#
# elapsed time: 9.45s, done 7 out of 390
# Number of trees: 40 , Maximum depth 22 :
# Accuracy: 0.8256639495135419
# Area under ROC curve: 0.8793604642296602 Selected area: 0.10895541006526321
#
# elapsed time: 11.4s, done 8 out of 390
# Number of trees: 40 , Maximum depth 24 :
# Accuracy: 0.8235603470943992
# Area under ROC curve: 0.8787620603393639 Selected area: 0.10885018613959953
#
# elapsed time: 13.14s, done 9 out of 390
# Number of trees: 40 , Maximum depth 26 :
# Accuracy: 0.8259268998159348
# Area under ROC curve: 0.87953126248581 Selected area: 0.10942739274632006
#
# elapsed time: 14.8s, done 10 out of 390
# Number of trees: 40 , Maximum depth 28 :
# Accuracy: 0.8275046016302918
# Area under ROC curve: 0.8798762139638555 Selected area: 0.10998462205700882
#
# elapsed time: 16.5s, done 11 out of 390
# Number of trees: 40 , Maximum depth 30 :
# Accuracy: 0.8246121483039706
# Area under ROC curve: 0.8800913892669155 Selected area: 0.10687289132777957
#
# elapsed time: 18.22s, done 12 out of 390
# Number of trees: 40 , Maximum depth 32 :
# Accuracy: 0.8267157507231133
# Area under ROC curve: 0.8805034400598769 Selected area: 0.10952529674672022
#
# elapsed time: 19.94s, done 13 out of 390
# Number of trees: 40 , Maximum depth 34 :
# Accuracy: 0.8259268998159348
# Area under ROC curve: 0.8791846335248916 Selected area: 0.10185615004870802
#
# elapsed time: 21.77s, done 14 out of 390
# Number of trees: 40 , Maximum depth 36 :
# Accuracy: 0.8211937943728636
# Area under ROC curve: 0.8798577616522535 Selected area: 0.10518442856698434
#
# elapsed time: 23.54s, done 15 out of 390
# Number of trees: 40 , Maximum depth 38 :
# Accuracy: 0.8243491980015777
# Area under ROC curve: 0.8792393804659255 Selected area: 0.103179836533869
#
# elapsed time: 24.89s, done 16 out of 390
# Number of trees: 50 , Maximum depth 10 :
# Accuracy: 0.8159347883250065
# Area under ROC curve: 0.8582796894643706 Selected area: 0.09632533651831415
#
# elapsed time: 26.34s, done 17 out of 390
# Number of trees: 50 , Maximum depth 12 :
# Accuracy: 0.8204049434656849
# Area under ROC curve: 0.8692740647117994 Selected area: 0.10417214390241075
#
# elapsed time: 27.96s, done 18 out of 390
# Number of trees: 50 , Maximum depth 14 :
# Accuracy: 0.8230344464896134
# Area under ROC curve: 0.8756567345447402 Selected area: 0.10814671082208252
#
# elapsed time: 29.68s, done 19 out of 390
# Number of trees: 50 , Maximum depth 16 :
# Accuracy: 0.8285564028398633
# Area under ROC curve: 0.8783346072036605 Selected area: 0.1097520619314477
#
# elapsed time: 31.53s, done 20 out of 390
# Number of trees: 50 , Maximum depth 18 :
# Accuracy: 0.8293452537470418
# Area under ROC curve: 0.8798928362941414 Selected area: 0.1102478343696111
#
# elapsed time: 33.5s, done 21 out of 390
# Number of trees: 50 , Maximum depth 20 :
# Accuracy: 0.8298711543518275
# Area under ROC curve: 0.8802112530431064 Selected area: 0.11048679942977782
#
# elapsed time: 35.77s, done 22 out of 390
# Number of trees: 50 , Maximum depth 22 :
# Accuracy: 0.8269787010255062
# Area under ROC curve: 0.8801595560709325 Selected area: 0.10918980017214024
#
# elapsed time: 37.81s, done 23 out of 390
# Number of trees: 50 , Maximum depth 24 :
# Accuracy: 0.8272416513278991
# Area under ROC curve: 0.8798271094652124 Selected area: 0.1097433695201972
#
# elapsed time: 40.05s, done 24 out of 390
# Number of trees: 50 , Maximum depth 26 :
# Accuracy: 0.8301341046542203
# Area under ROC curve: 0.8804964251314993 Selected area: 0.11038005051968419
#
# elapsed time: 42.4s, done 25 out of 390
# Number of trees: 50 , Maximum depth 28 :
# Accuracy: 0.8282934525374704
# Area under ROC curve: 0.8805096924960396 Selected area: 0.10744216801546458
#
# elapsed time: 44.63s, done 26 out of 390
# Number of trees: 50 , Maximum depth 30 :
# Accuracy: 0.8293452537470418
# Area under ROC curve: 0.8806998580544494 Selected area: 0.10855296667421024
#
# elapsed time: 47.09s, done 27 out of 390
# Number of trees: 50 , Maximum depth 32 :
# Accuracy: 0.8293452537470418
# Area under ROC curve: 0.8809435505663487 Selected area: 0.10713396866217996
#
# elapsed time: 49.59s, done 28 out of 390
# Number of trees: 50 , Maximum depth 34 :
# Accuracy: 0.8296082040494347
# Area under ROC curve: 0.8797543677079058 Selected area: 0.10413981423249669
#
# elapsed time: 52.03s, done 29 out of 390
# Number of trees: 50 , Maximum depth 36 :
# Accuracy: 0.8275046016302918
# Area under ROC curve: 0.8805333297547032 Selected area: 0.10388712431246075
#
# elapsed time: 54.21s, done 30 out of 390
# Number of trees: 50 , Maximum depth 38 :
# Accuracy: 0.8282934525374704
# Area under ROC curve: 0.8800213924815825 Selected area: 0.10077661357077544
#
# elapsed time: 55.73s, done 31 out of 390
# Number of trees: 60 , Maximum depth 10 :
# Accuracy: 0.8143570865106495
# Area under ROC curve: 0.8587274248929918 Selected area: 0.09691718297556182
#
# elapsed time: 57.56s, done 32 out of 390
# Number of trees: 60 , Maximum depth 12 :
# Accuracy: 0.8204049434656849
# Area under ROC curve: 0.869596446420282 Selected area: 0.10325700074602238
#
# elapsed time: 59.59s, done 33 out of 390
# Number of trees: 60 , Maximum depth 14 :
# Accuracy: 0.8230344464896134
# Area under ROC curve: 0.8753590575840221 Selected area: 0.10790271331329707
#
# elapsed time: 61.65s, done 34 out of 390
# Number of trees: 60 , Maximum depth 16 :
# Accuracy: 0.8269787010255062
# Area under ROC curve: 0.8775586951257228 Selected area: 0.10896196749831184
#
# elapsed time: 63.84s, done 35 out of 390
# Number of trees: 60 , Maximum depth 18 :
# Accuracy: 0.8259268998159348
# Area under ROC curve: 0.8795825019626549 Selected area: 0.1100114617829752
#
# elapsed time: 66.49s, done 36 out of 390
# Number of trees: 60 , Maximum depth 20 :
# Accuracy: 0.8280305022350776
# Area under ROC curve: 0.8799312659017751 Selected area: 0.11012888558407818
#
# elapsed time: 69.2s, done 37 out of 390
# Number of trees: 60 , Maximum depth 22 :
# Accuracy: 0.8261898501183277
# Area under ROC curve: 0.8794861229466847 Selected area: 0.10898850222739226
#
# elapsed time: 71.73s, done 38 out of 390
# Number of trees: 60 , Maximum depth 24 :
# Accuracy: 0.8280305022350776
# Area under ROC curve: 0.8797325604305579 Selected area: 0.10926818437183757
#
# elapsed time: 74.22s, done 39 out of 390
# Number of trees: 60 , Maximum depth 26 :
# Accuracy: 0.8301341046542203
# Area under ROC curve: 0.8795628296635091 Selected area: 0.10938774315114244
#
# elapsed time: 76.74s, done 40 out of 390
# Number of trees: 60 , Maximum depth 28 :
# Accuracy: 0.8282934525374704
# Area under ROC curve: 0.8794261910585891 Selected area: 0.10807732403052164
#
# elapsed time: 79.55s, done 41 out of 390
# Number of trees: 60 , Maximum depth 30 :
# Accuracy: 0.829082303444649
# Area under ROC curve: 0.8796694260751596 Selected area: 0.10799954982459628
#
# elapsed time: 82.3s, done 42 out of 390
# Number of trees: 60 , Maximum depth 32 :
# Accuracy: 0.8280305022350776
# Area under ROC curve: 0.8800195625002669 Selected area: 0.10759466645845546
#
# elapsed time: 84.96s, done 43 out of 390
# Number of trees: 60 , Maximum depth 34 :
# Accuracy: 0.8301341046542203
# Area under ROC curve: 0.8791007593812467 Selected area: 0.10381102758940831
#
# elapsed time: 87.63s, done 44 out of 390
# Number of trees: 60 , Maximum depth 36 :
# Accuracy: 0.8285564028398633
# Area under ROC curve: 0.8798425118079546 Selected area: 0.10401766297966099
# elapsed time: 90.28s, done 45 out of 390
# Number of trees: 60 , Maximum depth 38 :
# Accuracy: 0.8264528004207204
# Area under ROC curve: 0.8793362169772247 Selected area: 0.10215184452966737
#
# elapsed time: 92.14s, done 46 out of 390
# Number of trees: 70 , Maximum depth 10 :
# Accuracy: 0.8159347883250065
# Area under ROC curve: 0.8586559031232293 Selected area: 0.09554118952445495
#
# elapsed time: 94.07s, done 47 out of 390
# Number of trees: 70 , Maximum depth 12 :
# Accuracy: 0.8204049434656849
# Area under ROC curve: 0.8696839805265589 Selected area: 0.1043958591182784
#
# elapsed time: 96.7s, done 48 out of 390
# Number of trees: 70 , Maximum depth 14 :
# Accuracy: 0.8243491980015777
# Area under ROC curve: 0.8748154006347595 Selected area: 0.10728600960984189
#
# elapsed time: 99.6s, done 49 out of 390
# Number of trees: 70 , Maximum depth 16 :
# Accuracy: 0.8282934525374704
# Area under ROC curve: 0.8776796263910145 Selected area: 0.10893055281905573
#
# elapsed time: 102.99s, done 50 out of 390
# Number of trees: 70 , Maximum depth 18 :
# Accuracy: 0.8277675519326847
# Area under ROC curve: 0.8796720185486906 Selected area: 0.10992209769538254
#
# elapsed time: 106.19s, done 51 out of 390
# Number of trees: 70 , Maximum depth 20 :
# Accuracy: 0.8298711543518275
# Area under ROC curve: 0.8802734724078467 Selected area: 0.10955838890884925
#
# elapsed time: 109.56s, done 52 out of 390
# Number of trees: 70 , Maximum depth 22 :
# Accuracy: 0.8293452537470418
# Area under ROC curve: 0.8795346174515558 Selected area: 0.10944981001743972
#
# elapsed time: 112.85s, done 53 out of 390
# Number of trees: 70 , Maximum depth 24 :
# Accuracy: 0.8319747567709703
# Area under ROC curve: 0.8795771645171503 Selected area: 0.10890523807751923
#
# elapsed time: 116.27s, done 54 out of 390
# Number of trees: 70 , Maximum depth 26 :
# Accuracy: 0.8303970549566132
# Area under ROC curve: 0.8793503993324229 Selected area: 0.10771163276422946
#
# elapsed time: 119.77s, done 55 out of 390
# Number of trees: 70 , Maximum depth 28 :
# Accuracy: 0.8306600052590061
# Area under ROC curve: 0.8796253540251355 Selected area: 0.10932201632221336
#
# elapsed time: 123.41s, done 56 out of 390
# Number of trees: 70 , Maximum depth 30 :
# Accuracy: 0.829082303444649
# Area under ROC curve: 0.8796941308229242 Selected area: 0.10903714923070637
#
# elapsed time: 126.82s, done 57 out of 390
# Number of trees: 70 , Maximum depth 32 :
# Accuracy: 0.8301341046542203
# Area under ROC curve: 0.8794859704482417 Selected area: 0.1087850693044424
#
# elapsed time: 130.2s, done 58 out of 390
# Number of trees: 70 , Maximum depth 34 :
# Accuracy: 0.8296082040494347
# Area under ROC curve: 0.8787358306071695 Selected area: 0.10819169786276484
#
# elapsed time: 133.56s, done 59 out of 390
# Number of trees: 70 , Maximum depth 36 :
# Accuracy: 0.8296082040494347
# Area under ROC curve: 0.879363666696963 Selected area: 0.1063829138304498
#
# elapsed time: 136.97s, done 60 out of 390
# Number of trees: 70 , Maximum depth 38 :
# Accuracy: 0.8269787010255062
# Area under ROC curve: 0.8789804381097269 Selected area: 0.10535156686050236
#
# elapsed time: 139.31s, done 61 out of 390
# Number of trees: 80 , Maximum depth 10 :
# Accuracy: 0.8169865895345779
# Area under ROC curve: 0.8587469446936947 Selected area: 0.09681500901875792
#
# elapsed time: 142.15s, done 62 out of 390
# Number of trees: 80 , Maximum depth 12 :
# Accuracy: 0.8225085458848278
# Area under ROC curve: 0.8696833705327869 Selected area: 0.10431976239522595
#
# elapsed time: 145.3s, done 63 out of 390
# Number of trees: 80 , Maximum depth 14 :
# Accuracy: 0.8248750986063634
# Area under ROC curve: 0.8749980937694626 Selected area: 0.1072655748184811
#
# elapsed time: 148.61s, done 64 out of 390
# Number of trees: 80 , Maximum depth 16 :
# Accuracy: 0.8277675519326847
# Area under ROC curve: 0.8776520241728332 Selected area: 0.10872696739766288
#
# elapsed time: 152.34s, done 65 out of 390
# Number of trees: 80 , Maximum depth 18 :
# Accuracy: 0.8269787010255062
# Area under ROC curve: 0.8793757140739593 Selected area: 0.10964516052291104
#
# elapsed time: 156.73s, done 66 out of 390
# Number of trees: 80 , Maximum depth 20 :
# Accuracy: 0.8303970549566132
# Area under ROC curve: 0.8798338193967038 Selected area: 0.10927413181111421
#
# elapsed time: 161.25s, done 67 out of 390
# Number of trees: 80 , Maximum depth 22 :
# Accuracy: 0.829082303444649
# Area under ROC curve: 0.8795350749468849 Selected area: 0.10880977405220693
#
# elapsed time: 165.92s, done 68 out of 390
# Number of trees: 80 , Maximum depth 24 :
# Accuracy: 0.8306600052590061
# Area under ROC curve: 0.8794688906226267 Selected area: 0.10882395640740508
#
# elapsed time: 170.73s, done 69 out of 390
# Number of trees: 80 , Maximum depth 26 :
# Accuracy: 0.8319747567709703
# Area under ROC curve: 0.8794060612641146 Selected area: 0.10894031271940713
#
# elapsed time: 175.8s, done 70 out of 390
# Number of trees: 80 , Maximum depth 28 :
# Accuracy: 0.830922955561399
# Area under ROC curve: 0.8796965707980122 Selected area: 0.10791979313891203
#
# elapsed time: 181.13s, done 71 out of 390
# Number of trees: 80 , Maximum depth 30 :
# Accuracy: 0.8306600052590061
# Area under ROC curve: 0.8796367914083596 Selected area: 0.1088875482581323
#
# elapsed time: 186.14s, done 72 out of 390
# Number of trees: 80 , Maximum depth 32 :
# Accuracy: 0.830922955561399
# Area under ROC curve: 0.8798114021255842 Selected area: 0.10647670037288919
#
# elapsed time: 191.27s, done 73 out of 390
# Number of trees: 80 , Maximum depth 34 :
# Accuracy: 0.8288193531422561
# Area under ROC curve: 0.8790914569762243 Selected area: 0.10128336589683419
#
# elapsed time: 196.51s, done 74 out of 390
# Number of trees: 80 , Maximum depth 36 :
# Accuracy: 0.8298711543518275
# Area under ROC curve: 0.879417803644225 Selected area: 0.09988205770419083
#
# elapsed time: 201.55s, done 75 out of 390
# Number of trees: 80 , Maximum depth 38 :
# Accuracy: 0.8303970549566132
# Area under ROC curve: 0.879515555146182 Selected area: 0.1086694754846553
#
# elapsed time: 205.01s, done 76 out of 390
# Number of trees: 90 , Maximum depth 10 :
# Accuracy: 0.8156718380226137
# Area under ROC curve: 0.8585127070852606 Selected area: 0.0965676565442267
#
# elapsed time: 208.83s, done 77 out of 390
# Number of trees: 90 , Maximum depth 12 :
# Accuracy: 0.8219826452800421
# Area under ROC curve: 0.8697526048259047 Selected area: 0.10382353246173358
#
# elapsed time: 213.06s, done 78 out of 390
# Number of trees: 90 , Maximum depth 14 :
# Accuracy: 0.8254009992111491
# Area under ROC curve: 0.8752608485867359 Selected area: 0.10747754765423846
#
# elapsed time: 217.75s, done 79 out of 390
# Number of trees: 90 , Maximum depth 16 :
# Accuracy: 0.8280305022350776
# Area under ROC curve: 0.8781525240627293 Selected area: 0.10786443620410635
#
# elapsed time: 222.66s, done 80 out of 390
# Number of trees: 90 , Maximum depth 18 :
# Accuracy: 0.8261898501183277
# Area under ROC curve: 0.8798118596209134 Selected area: 0.10998507955233779
#
# elapsed time: 227.67s, done 81 out of 390
# Number of trees: 90 , Maximum depth 20 :
# Accuracy: 0.8298711543518275
# Area under ROC curve: 0.8805467496176864 Selected area: 0.11038279549165804
#
# elapsed time: 232.98s, done 82 out of 390
# Number of trees: 90 , Maximum depth 22 :
# Accuracy: 0.8285564028398633
# Area under ROC curve: 0.8803750363708787 Selected area: 0.11004348645600329
#
# elapsed time: 238.51s, done 83 out of 390
# Number of trees: 90 , Maximum depth 24 :
# Accuracy: 0.8280305022350776
# Area under ROC curve: 0.8806251338173837 Selected area: 0.10911172096932892
#
# elapsed time: 244.06s, done 84 out of 390
# Number of trees: 90 , Maximum depth 26 :
# Accuracy: 0.8303970549566132
# Area under ROC curve: 0.8801932582268336 Selected area: 0.10959224356319322
#
# elapsed time: 249.8s, done 85 out of 390
# Number of trees: 90 , Maximum depth 28 :
# Accuracy: 0.8319747567709703
# Area under ROC curve: 0.880287349766159 Selected area: 0.10827252203755
#
# elapsed time: 255.44s, done 86 out of 390
# Number of trees: 90 , Maximum depth 30 :
# Accuracy: 0.829082303444649
# Area under ROC curve: 0.8805469021161293 Selected area: 0.10712634374003041
#
# elapsed time: 261.18s, done 87 out of 390
# Number of trees: 90 , Maximum depth 32 :
# Accuracy: 0.8314488561661846
# Area under ROC curve: 0.8807079404719278 Selected area: 0.10777232714453985
#
# elapsed time: 266.94s, done 88 out of 390
# Number of trees: 90 , Maximum depth 34 :
# Accuracy: 0.8301341046542203
# Area under ROC curve: 0.8800098025999156 Selected area: 0.1078566587835138
# elapsed time: 272.65s, done 89 out of 390
# Number of trees: 90 , Maximum depth 36 :
# Accuracy: 0.8303970549566132
# Area under ROC curve: 0.880353076595088 Selected area: 0.10700800494826948
#
# elapsed time: 278.28s, done 90 out of 390
# Number of trees: 90 , Maximum depth 38 :
# Accuracy: 0.8306600052590061
# Area under ROC curve: 0.8805226548636939 Selected area: 0.10641676848479377
#
# elapsed time: 282.05s, done 91 out of 390
# Number of trees: 100 , Maximum depth 10 :
# Accuracy: 0.8167236392321852
# Area under ROC curve: 0.8583698160441783 Selected area: 0.09582697160661989
#
# elapsed time: 286.26s, done 92 out of 390
# Number of trees: 100 , Maximum depth 12 :
# Accuracy: 0.8211937943728636
# Area under ROC curve: 0.8697609922402694 Selected area: 0.10372074851115773
#
# elapsed time: 290.47s, done 93 out of 390
# Number of trees: 100 , Maximum depth 14 :
# Accuracy: 0.8256639495135419
# Area under ROC curve: 0.8756000051239478 Selected area: 0.10778971196704082
#
# elapsed time: 295.43s, done 94 out of 390
# Number of trees: 100 , Maximum depth 16 :
# Accuracy: 0.8282934525374704
# Area under ROC curve: 0.878125684336763 Selected area: 0.10897447237063712
#
# elapsed time: 300.3s, done 95 out of 390
# Number of trees: 100 , Maximum depth 18 :
# Accuracy: 0.8267157507231133
# Area under ROC curve: 0.880050519684194 Selected area: 0.11007749360879027
#
# elapsed time: 305.66s, done 96 out of 390
# Number of trees: 100 , Maximum depth 20 :
# Accuracy: 0.8303970549566132
# Area under ROC curve: 0.8808528139927692 Selected area: 0.11044287987819645
#
# elapsed time: 311.32s, done 97 out of 390
# Number of trees: 100 , Maximum depth 22 :
# Accuracy: 0.8296082040494347
# Area under ROC curve: 0.8804924601719817 Selected area: 0.11001069929076025
#
# elapsed time: 316.77s, done 98 out of 390
# Number of trees: 100 , Maximum depth 24 :
# Accuracy: 0.8282934525374704
# Area under ROC curve: 0.8810435895449507 Selected area: 0.11003021909146309
#
# elapsed time: 322.3s, done 99 out of 390
# Number of trees: 100 , Maximum depth 26 :
# Accuracy: 0.8280305022350776
# Area under ROC curve: 0.8809624603732795 Selected area: 0.10997791212551719
#
# elapsed time: 327.22s, done 100 out of 390
# Number of trees: 100 , Maximum depth 28 :
# Accuracy: 0.8317118064685775
# Area under ROC curve: 0.8811004714641862 Selected area: 0.1099109653090442
#
# elapsed time: 332.26s, done 101 out of 390
# Number of trees: 100 , Maximum depth 30 :
# Accuracy: 0.8280305022350776
# Area under ROC curve: 0.8809182358248122 Selected area: 0.10656682695269681
#
# elapsed time: 338.24s, done 102 out of 390
# Number of trees: 100 , Maximum depth 32 :
# Accuracy: 0.8306600052590061
# Area under ROC curve: 0.8811944105050687 Selected area: 0.10865819059987396
#
# elapsed time: 343.37s, done 103 out of 390
# Number of trees: 100 , Maximum depth 34 :
# Accuracy: 0.8285564028398633
# Area under ROC curve: 0.8806130864403875 Selected area: 0.10640197613582365
#
# elapsed time: 349.1s, done 104 out of 390
# Number of trees: 100 , Maximum depth 36 :
# Accuracy: 0.8296082040494347
# Area under ROC curve: 0.8808177393508813 Selected area: 0.10550848775833999
#
# elapsed time: 354.81s, done 105 out of 390
# Number of trees: 100 , Maximum depth 38 :
# Accuracy: 0.8280305022350776
# Area under ROC curve: 0.8809720677751881 Selected area: 0.1042756903452016
#
# elapsed time: 358.13s, done 106 out of 390
# Number of trees: 110 , Maximum depth 10 :
# Accuracy: 0.8167236392321852
# Area under ROC curve: 0.8590013120966036 Selected area: 0.09681775399073177
#
# elapsed time: 361.94s, done 107 out of 390
# Number of trees: 110 , Maximum depth 12 :
# Accuracy: 0.8225085458848278
# Area under ROC curve: 0.8704354928536179 Selected area: 0.10477497024755378
#
# elapsed time: 366.59s, done 108 out of 390
# Number of trees: 110 , Maximum depth 14 :
# Accuracy: 0.8272416513278991
# Area under ROC curve: 0.8763156803169039 Selected area: 0.10814701581896849
#
# elapsed time: 371.31s, done 109 out of 390
# Number of trees: 110 , Maximum depth 16 :
# Accuracy: 0.8298711543518275
# Area under ROC curve: 0.87911112927537 Selected area: 0.10966544281582885
#
# elapsed time: 376.47s, done 110 out of 390
# Number of trees: 110 , Maximum depth 18 :
# Accuracy: 0.8296082040494347
# Area under ROC curve: 0.8806329112379763 Selected area: 0.11042747753545437
#
# elapsed time: 381.53s, done 111 out of 390
# Number of trees: 110 , Maximum depth 20 :
# Accuracy: 0.8319747567709703
# Area under ROC curve: 0.8813246441753829 Selected area: 0.11019857737252504
#
# elapsed time: 386.66s, done 112 out of 390
# Number of trees: 110 , Maximum depth 22 :
# Accuracy: 0.8296082040494347
# Area under ROC curve: 0.8809758802362627 Selected area: 0.10897248989087821
#
# elapsed time: 391.91s, done 113 out of 390
# Number of trees: 110 , Maximum depth 24 :
# Accuracy: 0.8285564028398633
# Area under ROC curve: 0.8814777526121458 Selected area: 0.11020010235695495
#
# elapsed time: 397.78s, done 114 out of 390
# Number of trees: 110 , Maximum depth 26 :
# Accuracy: 0.8298711543518275
# Area under ROC curve: 0.8816110362513199 Selected area: 0.11028214651928406
#
# elapsed time: 404.16s, done 115 out of 390
# Number of trees: 110 , Maximum depth 28 :
# Accuracy: 0.8322377070733631
# Area under ROC curve: 0.8814772951168167 Selected area: 0.11006453124113603
#
# elapsed time: 409.62s, done 116 out of 390
# Number of trees: 110 , Maximum depth 30 :
# Accuracy: 0.8285564028398633
# Area under ROC curve: 0.8812683722499193 Selected area: 0.10722409524198759
#
# elapsed time: 415.94s, done 117 out of 390
# Number of trees: 110 , Maximum depth 32 :
# Accuracy: 0.8288193531422561
# Area under ROC curve: 0.8812403125364089 Selected area: 0.10616606104451673
#
# elapsed time: 421.81s, done 118 out of 390
# Number of trees: 110 , Maximum depth 34 :
# Accuracy: 0.8306600052590061
# Area under ROC curve: 0.8808525089958832 Selected area: 0.10767015318773596
#
# elapsed time: 427.83s, done 119 out of 390
# Number of trees: 110 , Maximum depth 36 :
# Accuracy: 0.8298711543518275
# Area under ROC curve: 0.8811090113769937 Selected area: 0.10784750887693437
#
# elapsed time: 433.59s, done 120 out of 390
# Number of trees: 110 , Maximum depth 38 :
# Accuracy: 0.8288193531422561
# Area under ROC curve: 0.8809990599995974 Selected area: 0.10703164220693305
#
# elapsed time: 437.34s, done 121 out of 390
# Number of trees: 120 , Maximum depth 10 :
# Accuracy: 0.8164606889297923
# Area under ROC curve: 0.85922853477666 Selected area: 0.09707120640298261
#
# elapsed time: 442.0s, done 122 out of 390
# Number of trees: 120 , Maximum depth 12 :
# Accuracy: 0.8217196949776492
# Area under ROC curve: 0.8704383903240348 Selected area: 0.10483093717613143
#
# elapsed time: 446.61s, done 123 out of 390
# Number of trees: 120 , Maximum depth 14 :
# Accuracy: 0.8272416513278991
# Area under ROC curve: 0.8764620788221752 Selected area: 0.1076843355429341
#
# elapsed time: 452.07s, done 124 out of 390
# Number of trees: 120 , Maximum depth 16 :
# Accuracy: 0.829082303444649
# Area under ROC curve: 0.8792541728148957 Selected area: 0.1097031099312476
#
# elapsed time: 457.92s, done 125 out of 390
# Number of trees: 120 , Maximum depth 18 :
# Accuracy: 0.829082303444649
# Area under ROC curve: 0.8808637938806645 Selected area: 0.11048451195313297
#
# elapsed time: 463.94s, done 126 out of 390
# Number of trees: 120 , Maximum depth 20 :
# Accuracy: 0.8314488561661846
# Area under ROC curve: 0.8815701666685982 Selected area: 0.1101406279641885
#
# elapsed time: 469.7s, done 127 out of 390
# Number of trees: 120 , Maximum depth 22 :
# Accuracy: 0.8288193531422561
# Area under ROC curve: 0.8814475579204335 Selected area: 0.11025561179020363
#
# elapsed time: 476.46s, done 128 out of 390
# Number of trees: 120 , Maximum depth 24 :
# Accuracy: 0.8296082040494347
# Area under ROC curve: 0.8817032978093293 Selected area: 0.11019262993324837
#
# elapsed time: 482.44s, done 129 out of 390
# Number of trees: 120 , Maximum depth 26 :
# Accuracy: 0.832500657375756
# Area under ROC curve: 0.8818150791680417 Selected area: 0.11011638071175295
#
# elapsed time: 489.08s, done 130 out of 390
# Number of trees: 120 , Maximum depth 28 :
# Accuracy: 0.8338154088877202
# Area under ROC curve: 0.8816662406876825 Selected area: 0.10998309707257889
#
# elapsed time: 495.86s, done 131 out of 390
# Number of trees: 120 , Maximum depth 30 :
# Accuracy: 0.8288193531422561
# Area under ROC curve: 0.8814097383065719 Selected area: 0.10950501445380244
# elapsed time: 502.31s, done 132 out of 390
# Number of trees: 120 , Maximum depth 32 :
# Accuracy: 0.8314488561661846
# Area under ROC curve: 0.8815209096715122 Selected area: 0.10848464737175033
#
# elapsed time: 509.14s, done 133 out of 390
# Number of trees: 120 , Maximum depth 34 :
# Accuracy: 0.8327636076781488
# Area under ROC curve: 0.8810664643113993 Selected area: 0.1057010932918375
#
# elapsed time: 515.61s, done 134 out of 390
# Number of trees: 120 , Maximum depth 36 :
# Accuracy: 0.8330265579805417
# Area under ROC curve: 0.8813456889605157 Selected area: 0.10652793984973415
#
# elapsed time: 521.75s, done 135 out of 390
# Number of trees: 120 , Maximum depth 38 :
# Accuracy: 0.830922955561399
# Area under ROC curve: 0.8812390925488651 Selected area: 0.10692916325324318
#
# elapsed time: 525.66s, done 136 out of 390
# Number of trees: 130 , Maximum depth 10 :
# Accuracy: 0.8169865895345779
# Area under ROC curve: 0.8592309747517478 Selected area: 0.09661523605843984
#
# elapsed time: 530.42s, done 137 out of 390
# Number of trees: 130 , Maximum depth 12 :
# Accuracy: 0.8211937943728636
# Area under ROC curve: 0.8703940132771245 Selected area: 0.10416589146624812
#
# elapsed time: 535.8s, done 138 out of 390
# Number of trees: 130 , Maximum depth 14 :
# Accuracy: 0.8288193531422561
# Area under ROC curve: 0.8765278056511043 Selected area: 0.10831933905954821
#
# elapsed time: 542.12s, done 139 out of 390
# Number of trees: 130 , Maximum depth 16 :
# Accuracy: 0.8282934525374704
# Area under ROC curve: 0.8790925244653252 Selected area: 0.10956952129518757
#
# elapsed time: 548.0s, done 140 out of 390
# Number of trees: 130 , Maximum depth 18 :
# Accuracy: 0.8288193531422561
# Area under ROC curve: 0.8806800332568605 Selected area: 0.11044882731747309
#
# elapsed time: 554.81s, done 141 out of 390
# Number of trees: 130 , Maximum depth 20 :
# Accuracy: 0.8298711543518275
# Area under ROC curve: 0.8814844625436373 Selected area: 0.11076510908823622
#
# elapsed time: 561.8s, done 142 out of 390
# Number of trees: 130 , Maximum depth 22 :
# Accuracy: 0.8298711543518275
# Area under ROC curve: 0.8814713476775402 Selected area: 0.1102424969241064
#
# elapsed time: 568.35s, done 143 out of 390
# Number of trees: 130 , Maximum depth 24 :
# Accuracy: 0.8311859058637917
# Area under ROC curve: 0.8816230836283161 Selected area: 0.11005782130964445
#
# elapsed time: 574.91s, done 144 out of 390
# Number of trees: 130 , Maximum depth 26 :
# Accuracy: 0.8303970549566132
# Area under ROC curve: 0.8818740960654792 Selected area: 0.1090129019782708
#
# elapsed time: 581.54s, done 145 out of 390
# Number of trees: 130 , Maximum depth 28 :
# Accuracy: 0.8335524585853273
# Area under ROC curve: 0.881575504114103 Selected area: 0.10986674076057684
#
# elapsed time: 588.31s, done 146 out of 390
# Number of trees: 130 , Maximum depth 30 :
# Accuracy: 0.8296082040494347
# Area under ROC curve: 0.8814013508922074 Selected area: 0.10950943690864917
#
# elapsed time: 596.03s, done 147 out of 390
# Number of trees: 130 , Maximum depth 32 :
# Accuracy: 0.8306600052590061
# Area under ROC curve: 0.8816023438400693 Selected area: 0.10975617938940843
#
# elapsed time: 602.43s, done 148 out of 390
# Number of trees: 130 , Maximum depth 34 :
# Accuracy: 0.8303970549566132
# Area under ROC curve: 0.8813273891473568 Selected area: 0.10894473517425388
#
# elapsed time: 609.35s, done 149 out of 390
# Number of trees: 130 , Maximum depth 36 :
# Accuracy: 0.8327636076781488
# Area under ROC curve: 0.8813432489854278 Selected area: 0.10657750184370618
#
# elapsed time: 617.16s, done 150 out of 390
# Number of trees: 130 , Maximum depth 38 :
# Accuracy: 0.8303970549566132
# Area under ROC curve: 0.8812801146300299 Selected area: 0.10585465922392931
#
# elapsed time: 621.8s, done 151 out of 390
# Number of trees: 140 , Maximum depth 10 :
# Accuracy: 0.8172495398369708
# Area under ROC curve: 0.8591783627889159 Selected area: 0.09719823760599405
#
# elapsed time: 627.4s, done 152 out of 390
# Number of trees: 140 , Maximum depth 12 :
# Accuracy: 0.8214567446752564
# Area under ROC curve: 0.8701872253884286 Selected area: 0.1045803822342974
#
# elapsed time: 633.61s, done 153 out of 390
# Number of trees: 140 , Maximum depth 14 :
# Accuracy: 0.8280305022350776
# Area under ROC curve: 0.8765958199566782 Selected area: 0.10840595817516703
#
# elapsed time: 640.62s, done 154 out of 390
# Number of trees: 140 , Maximum depth 16 :
# Accuracy: 0.8288193531422561
# Area under ROC curve: 0.8793198996438245 Selected area: 0.10975099444234676
#
# elapsed time: 647.88s, done 155 out of 390
# Number of trees: 140 , Maximum depth 18 :
# Accuracy: 0.8288193531422561
# Area under ROC curve: 0.8806294037737875 Selected area: 0.11034101091827855
#
# elapsed time: 655.61s, done 156 out of 390
# Number of trees: 140 , Maximum depth 20 :
# Accuracy: 0.8301341046542203
# Area under ROC curve: 0.8813190017329923 Selected area: 0.11065210774197995
#
# elapsed time: 663.16s, done 157 out of 390
# Number of trees: 140 , Maximum depth 22 :
# Accuracy: 0.8314488561661846
# Area under ROC curve: 0.8817388299465461 Selected area: 0.11049289936749748
#
# elapsed time: 670.39s, done 158 out of 390
# Number of trees: 140 , Maximum depth 24 :
# Accuracy: 0.8319747567709703
# Area under ROC curve: 0.8819071882276082 Selected area: 0.11021519970281103
#
# elapsed time: 677.75s, done 159 out of 390
# Number of trees: 140 , Maximum depth 26 :
# Accuracy: 0.830922955561399
# Area under ROC curve: 0.8822612896122329 Selected area: 0.10996022230613027
#
# elapsed time: 685.72s, done 160 out of 390
# Number of trees: 140 , Maximum depth 28 :
# Accuracy: 0.8338154088877202
# Area under ROC curve: 0.8820462668076159 Selected area: 0.11022983955333818
#
# elapsed time: 693.76s, done 161 out of 390
# Number of trees: 140 , Maximum depth 30 :
# Accuracy: 0.8298711543518275
# Area under ROC curve: 0.8817115327252509 Selected area: 0.10848052991378956
#
# elapsed time: 701.61s, done 162 out of 390
# Number of trees: 140 , Maximum depth 32 :
# Accuracy: 0.830922955561399
# Area under ROC curve: 0.8817658221709556 Selected area: 0.10798201250365233
#
# elapsed time: 708.56s, done 163 out of 390
# Number of trees: 140 , Maximum depth 34 :
# Accuracy: 0.8330265579805417
# Area under ROC curve: 0.8817455398780378 Selected area: 0.1091638754368318
#
# elapsed time: 716.3s, done 164 out of 390
# Number of trees: 140 , Maximum depth 36 :
# Accuracy: 0.8327636076781488
# Area under ROC curve: 0.8816785930615649 Selected area: 0.10909586113125785
#
# elapsed time: 725.51s, done 165 out of 390
# Number of trees: 140 , Maximum depth 38 :
# Accuracy: 0.8314488561661846
# Area under ROC curve: 0.8816935379089781 Selected area: 0.10965385293416156
#
# elapsed time: 731.17s, done 166 out of 390
# Number of trees: 150 , Maximum depth 10 :
# Accuracy: 0.8161977386273994
# Area under ROC curve: 0.8592544595119684 Selected area: 0.09719625512623516
#
# elapsed time: 737.58s, done 167 out of 390
# Number of trees: 150 , Maximum depth 12 :
# Accuracy: 0.8206678937680778
# Area under ROC curve: 0.8703755609655227 Selected area: 0.10418434377785002
#
# elapsed time: 744.28s, done 168 out of 390
# Number of trees: 150 , Maximum depth 14 :
# Accuracy: 0.8272416513278991
# Area under ROC curve: 0.8768797720575272 Selected area: 0.10858377135969442
#
# elapsed time: 751.65s, done 169 out of 390
# Number of trees: 150 , Maximum depth 16 :
# Accuracy: 0.8267157507231133
# Area under ROC curve: 0.8796711035580327 Selected area: 0.11014566041280718
#
# elapsed time: 759.58s, done 170 out of 390
# Number of trees: 150 , Maximum depth 18 :
# Accuracy: 0.8282934525374704
# Area under ROC curve: 0.8809430930710198 Selected area: 0.11001024179543129
#
# elapsed time: 767.98s, done 171 out of 390
# Number of trees: 150 , Maximum depth 20 :
# Accuracy: 0.8296082040494347
# Area under ROC curve: 0.8816426034290189 Selected area: 0.10921618240277765
#
# elapsed time: 776.98s, done 172 out of 390
# Number of trees: 150 , Maximum depth 22 :
# Accuracy: 0.8319747567709703
# Area under ROC curve: 0.8820660916052047 Selected area: 0.11098546933835805
#
# elapsed time: 786.3s, done 173 out of 390
# Number of trees: 150 , Maximum depth 24 :
# Accuracy: 0.8303970549566132
# Area under ROC curve: 0.8821780254623601 Selected area: 0.1106145931250042
#
# elapsed time: 795.38s, done 174 out of 390
# Number of trees: 150 , Maximum depth 26 :
# Accuracy: 0.8293452537470418
# Area under ROC curve: 0.8827570620503964 Selected area: 0.11116236753222751
# elapsed time: 804.49s, done 175 out of 390
# Number of trees: 150 , Maximum depth 28 :
# Accuracy: 0.8317118064685775
# Area under ROC curve: 0.882781614299718 Selected area: 0.11102633892107962
#
# elapsed time: 813.82s, done 176 out of 390
# Number of trees: 150 , Maximum depth 30 :
# Accuracy: 0.8306600052590061
# Area under ROC curve: 0.8820883563778814 Selected area: 0.1102360919895008
#
# elapsed time: 823.19s, done 177 out of 390
# Number of trees: 150 , Maximum depth 32 :
# Accuracy: 0.8317118064685775
# Area under ROC curve: 0.8823140540735078 Selected area: 0.10981367130241601
#
# elapsed time: 832.46s, done 178 out of 390
# Number of trees: 150 , Maximum depth 34 :
# Accuracy: 0.830922955561399
# Area under ROC curve: 0.8820168346081186 Selected area: 0.10958522863481565
#
# elapsed time: 841.87s, done 179 out of 390
# Number of trees: 150 , Maximum depth 36 :
# Accuracy: 0.8317118064685775
# Area under ROC curve: 0.8821185510695935 Selected area: 0.10365974913396132
#
# elapsed time: 851.39s, done 180 out of 390
# Number of trees: 150 , Maximum depth 38 :
# Accuracy: 0.8311859058637917
# Area under ROC curve: 0.8821145861100758 Selected area: 0.10596156063246594
#
# elapsed time: 857.3s, done 181 out of 390
# Number of trees: 160 , Maximum depth 10 :
# Accuracy: 0.8167236392321852
# Area under ROC curve: 0.8593875906526993 Selected area: 0.09727723179946333
#
# elapsed time: 863.87s, done 182 out of 390
# Number of trees: 160 , Maximum depth 12 :
# Accuracy: 0.8209308440704707
# Area under ROC curve: 0.8704612650904835 Selected area: 0.1047796976992865
#
# elapsed time: 871.13s, done 183 out of 390
# Number of trees: 160 , Maximum depth 14 :
# Accuracy: 0.8275046016302918
# Area under ROC curve: 0.8770138181889162 Selected area: 0.1086426357586889
#
# elapsed time: 879.13s, done 184 out of 390
# Number of trees: 160 , Maximum depth 16 :
# Accuracy: 0.8282934525374704
# Area under ROC curve: 0.8796113241683803 Selected area: 0.11000048189507985
#
# elapsed time: 887.69s, done 185 out of 390
# Number of trees: 160 , Maximum depth 18 :
# Accuracy: 0.8282934525374704
# Area under ROC curve: 0.8808619638993487 Selected area: 0.11043052750431417
#
# elapsed time: 896.85s, done 186 out of 390
# Number of trees: 160 , Maximum depth 20 :
# Accuracy: 0.8301341046542203
# Area under ROC curve: 0.8815480543943647 Selected area: 0.1095304816937819
#
# elapsed time: 905.96s, done 187 out of 390
# Number of trees: 160 , Maximum depth 22 :
# Accuracy: 0.830922955561399
# Area under ROC curve: 0.8821638431071619 Selected area: 0.11031691616428596
#
# elapsed time: 915.81s, done 188 out of 390
# Number of trees: 160 , Maximum depth 24 :
# Accuracy: 0.8322377070733631
# Area under ROC curve: 0.8820497742718048 Selected area: 0.10978240912160289
#
# elapsed time: 925.79s, done 189 out of 390
# Number of trees: 160 , Maximum depth 26 :
# Accuracy: 0.8306600052590061
# Area under ROC curve: 0.8826940801934413 Selected area: 0.11104646871555442
#
# elapsed time: 935.66s, done 190 out of 390
# Number of trees: 160 , Maximum depth 28 :
# Accuracy: 0.8332895082829346
# Area under ROC curve: 0.8826756278818394 Selected area: 0.10957912869709599
#
# elapsed time: 945.15s, done 191 out of 390
# Number of trees: 160 , Maximum depth 30 :
# Accuracy: 0.830922955561399
# Area under ROC curve: 0.8821755854872723 Selected area: 0.110199187366297
#
# elapsed time: 954.28s, done 192 out of 390
# Number of trees: 160 , Maximum depth 32 :
# Accuracy: 0.8322377070733631
# Area under ROC curve: 0.8822051701852125 Selected area: 0.11016182524776422
#
# elapsed time: 963.87s, done 193 out of 390
# Number of trees: 160 , Maximum depth 34 :
# Accuracy: 0.8303970549566132
# Area under ROC curve: 0.8819633076546289 Selected area: 0.1087983366689826
#
# elapsed time: 973.12s, done 194 out of 390
# Number of trees: 160 , Maximum depth 36 :
# Accuracy: 0.830922955561399
# Area under ROC curve: 0.882177872963917 Selected area: 0.10774014997306877
#
# elapsed time: 982.3s, done 195 out of 390
# Number of trees: 160 , Maximum depth 38 :
# Accuracy: 0.8301341046542203
# Area under ROC curve: 0.8821980027583919 Selected area: 0.10648249531372284
#
# elapsed time: 987.71s, done 196 out of 390
# Number of trees: 170 , Maximum depth 10 :
# Accuracy: 0.8169865895345779
# Area under ROC curve: 0.8596232007471204 Selected area: 0.09685465861393555
#
# elapsed time: 994.35s, done 197 out of 390
# Number of trees: 170 , Maximum depth 12 :
# Accuracy: 0.8209308440704707
# Area under ROC curve: 0.8707787668487904 Selected area: 0.10497703068451672
#
# elapsed time: 1001.5s, done 198 out of 390
# Number of trees: 170 , Maximum depth 14 :
# Accuracy: 0.8277675519326847
# Area under ROC curve: 0.8770232730923817 Selected area: 0.10856913150916729
#
# elapsed time: 1009.43s, done 199 out of 390
# Number of trees: 170 , Maximum depth 16 :
# Accuracy: 0.8288193531422561
# Area under ROC curve: 0.8797552826985636 Selected area: 0.11002671162727427
#
# elapsed time: 1017.55s, done 200 out of 390
# Number of trees: 170 , Maximum depth 18 :
# Accuracy: 0.829082303444649
# Area under ROC curve: 0.8810878140934181 Selected area: 0.1098190087479207
#
# elapsed time: 1025.91s, done 201 out of 390
# Number of trees: 170 , Maximum depth 20 :
# Accuracy: 0.8301341046542203
# Area under ROC curve: 0.8816232361267591 Selected area: 0.11060330824022287
#
# elapsed time: 1035.11s, done 202 out of 390
# Number of trees: 170 , Maximum depth 22 :
# Accuracy: 0.8306600052590061
# Area under ROC curve: 0.882196172777076 Selected area: 0.11074879175483618
#
# elapsed time: 1043.79s, done 203 out of 390
# Number of trees: 170 , Maximum depth 24 :
# Accuracy: 0.8317118064685775
# Area under ROC curve: 0.8823480612262948 Selected area: 0.1105962933118453
#
# elapsed time: 1052.8s, done 204 out of 390
# Number of trees: 170 , Maximum depth 26 :
# Accuracy: 0.8332895082829346
# Area under ROC curve: 0.8830047195218137 Selected area: 0.11112561540746671
#
# elapsed time: 1062.44s, done 205 out of 390
# Number of trees: 170 , Maximum depth 28 :
# Accuracy: 0.8338154088877202
# Area under ROC curve: 0.8828964456272901 Selected area: 0.11083678335644193
#
# elapsed time: 1071.83s, done 206 out of 390
# Number of trees: 170 , Maximum depth 30 :
# Accuracy: 0.8319747567709703
# Area under ROC curve: 0.8825589665729513 Selected area: 0.11040246779080387
#
# elapsed time: 1081.66s, done 207 out of 390
# Number of trees: 170 , Maximum depth 32 :
# Accuracy: 0.830922955561399
# Area under ROC curve: 0.8825885512708915 Selected area: 0.1103600732236524
#
# elapsed time: 1091.39s, done 208 out of 390
# Number of trees: 170 , Maximum depth 34 :
# Accuracy: 0.8306600052590061
# Area under ROC curve: 0.8822812669082648 Selected area: 0.10957790870955209
#
# elapsed time: 1101.48s, done 209 out of 390
# Number of trees: 170 , Maximum depth 36 :
# Accuracy: 0.830922955561399
# Area under ROC curve: 0.882645128193241 Selected area: 0.11039072541069356
#
# elapsed time: 1111.77s, done 210 out of 390
# Number of trees: 170 , Maximum depth 38 :
# Accuracy: 0.8314488561661846
# Area under ROC curve: 0.8826548880935925 Selected area: 0.11036419068161316
#
# elapsed time: 1118.33s, done 211 out of 390
# Number of trees: 180 , Maximum depth 10 :
# Accuracy: 0.8172495398369708
# Area under ROC curve: 0.8596898425667072 Selected area: 0.09739587558811025
#
# elapsed time: 1125.64s, done 212 out of 390
# Number of trees: 180 , Maximum depth 12 :
# Accuracy: 0.8206678937680778
# Area under ROC curve: 0.8709094580144336 Selected area: 0.10448095324946735
#
# elapsed time: 1132.77s, done 213 out of 390
# Number of trees: 180 , Maximum depth 14 :
# Accuracy: 0.8267157507231133
# Area under ROC curve: 0.8771309369931333 Selected area: 0.10861366105452064
#
# elapsed time: 1141.24s, done 214 out of 390
# Number of trees: 180 , Maximum depth 16 :
# Accuracy: 0.8280305022350776
# Area under ROC curve: 0.8797229530286497 Selected area: 0.10933436869609561
#
# elapsed time: 1149.95s, done 215 out of 390
# Number of trees: 180 , Maximum depth 18 :
# Accuracy: 0.8298711543518275
# Area under ROC curve: 0.8810173598127564 Selected area: 0.11035549827036267
#
# elapsed time: 1159.05s, done 216 out of 390
# Number of trees: 180 , Maximum depth 20 :
# Accuracy: 0.8322377070733631
# Area under ROC curve: 0.8815381419955703 Selected area: 0.10992835013154514
#
# elapsed time: 1168.54s, done 217 out of 390
# Number of trees: 180 , Maximum depth 22 :
# Accuracy: 0.8306600052590061
# Area under ROC curve: 0.8819710850752215 Selected area: 0.11059995327447708
# elapsed time: 1178.08s, done 218 out of 390
# Number of trees: 180 , Maximum depth 24 :
# Accuracy: 0.8330265579805417
# Area under ROC curve: 0.8820968962906888 Selected area: 0.11035122831395894
#
# elapsed time: 1187.56s, done 219 out of 390
# Number of trees: 180 , Maximum depth 26 :
# Accuracy: 0.8317118064685775
# Area under ROC curve: 0.8828831782627499 Selected area: 0.11025972924816438
#
# elapsed time: 1198.05s, done 220 out of 390
# Number of trees: 180 , Maximum depth 28 :
# Accuracy: 0.8322377070733631
# Area under ROC curve: 0.8827578245426114 Selected area: 0.11004806140929303
#
# elapsed time: 1208.87s, done 221 out of 390
# Number of trees: 180 , Maximum depth 30 :
# Accuracy: 0.8319747567709703
# Area under ROC curve: 0.8825499691648148 Selected area: 0.11027833405820928
#
# elapsed time: 1219.66s, done 222 out of 390
# Number of trees: 180 , Maximum depth 32 :
# Accuracy: 0.8317118064685775
# Area under ROC curve: 0.8826001411525588 Selected area: 0.1102460043882952
#
# elapsed time: 1230.83s, done 223 out of 390
# Number of trees: 180 , Maximum depth 34 :
# Accuracy: 0.832500657375756
# Area under ROC curve: 0.8822780644409622 Selected area: 0.10949555955033702
#
# elapsed time: 1241.84s, done 224 out of 390
# Number of trees: 180 , Maximum depth 36 :
# Accuracy: 0.830922955561399
# Area under ROC curve: 0.8825495116694859 Selected area: 0.10844469277968671
#
# elapsed time: 1252.66s, done 225 out of 390
# Number of trees: 180 , Maximum depth 38 :
# Accuracy: 0.8327636076781488
# Area under ROC curve: 0.8825883987724485 Selected area: 0.10845521517225307
#
# elapsed time: 1259.62s, done 226 out of 390
# Number of trees: 190 , Maximum depth 10 :
# Accuracy: 0.8167236392321852
# Area under ROC curve: 0.8595214842856455 Selected area: 0.09675812709952233
#
# elapsed time: 1267.43s, done 227 out of 390
# Number of trees: 190 , Maximum depth 12 :
# Accuracy: 0.8222455955824349
# Area under ROC curve: 0.8708573035469307 Selected area: 0.10380477515324567
#
# elapsed time: 1276.03s, done 228 out of 390
# Number of trees: 190 , Maximum depth 14 :
# Accuracy: 0.8267157507231133
# Area under ROC curve: 0.8770729875847969 Selected area: 0.10848525736552231
#
# elapsed time: 1285.23s, done 229 out of 390
# Number of trees: 190 , Maximum depth 16 :
# Accuracy: 0.8275046016302918
# Area under ROC curve: 0.879835191882691 Selected area: 0.10872589990856193
#
# elapsed time: 1295.14s, done 230 out of 390
# Number of trees: 190 , Maximum depth 18 :
# Accuracy: 0.8301341046542203
# Area under ROC curve: 0.8811646733086856 Selected area: 0.11047627703721147
#
# elapsed time: 1305.39s, done 231 out of 390
# Number of trees: 190 , Maximum depth 20 :
# Accuracy: 0.8306600052590061
# Area under ROC curve: 0.8816971978716097 Selected area: 0.1106969422842193
#
# elapsed time: 1316.21s, done 232 out of 390
# Number of trees: 190 , Maximum depth 22 :
# Accuracy: 0.8311859058637917
# Area under ROC curve: 0.8819404328881801 Selected area: 0.11061581311254812
#
# elapsed time: 1327.4s, done 233 out of 390
# Number of trees: 190 , Maximum depth 24 :
# Accuracy: 0.8330265579805417
# Area under ROC curve: 0.8823198490143416 Selected area: 0.11050662422736665
#
# elapsed time: 1338.69s, done 234 out of 390
# Number of trees: 190 , Maximum depth 26 :
# Accuracy: 0.8306600052590061
# Area under ROC curve: 0.8829188628984098 Selected area: 0.1109226399798458
#
# elapsed time: 1350.35s, done 235 out of 390
# Number of trees: 190 , Maximum depth 28 :
# Accuracy: 0.832500657375756
# Area under ROC curve: 0.8828801282938901 Selected area: 0.11076297411003436
#
# elapsed time: 1362.07s, done 236 out of 390
# Number of trees: 190 , Maximum depth 30 :
# Accuracy: 0.8303970549566132
# Area under ROC curve: 0.8827964066486881 Selected area: 0.11051531663861713
#
# elapsed time: 1373.71s, done 237 out of 390
# Number of trees: 190 , Maximum depth 32 :
# Accuracy: 0.8338154088877202
# Area under ROC curve: 0.8829492100885651 Selected area: 0.11057372354228263
#
# elapsed time: 1384.55s, done 238 out of 390
# Number of trees: 190 , Maximum depth 34 :
# Accuracy: 0.8317118064685775
# Area under ROC curve: 0.882747912143817 Selected area: 0.10807534155076277
#
# elapsed time: 1394.65s, done 239 out of 390
# Number of trees: 190 , Maximum depth 36 :
# Accuracy: 0.8306600052590061
# Area under ROC curve: 0.8828307187983612 Selected area: 0.10689881606308799
#
# elapsed time: 1405.76s, done 240 out of 390
# Number of trees: 190 , Maximum depth 38 :
# Accuracy: 0.8314488561661846
# Area under ROC curve: 0.8828497811037348 Selected area: 0.10572595053804501
#
# elapsed time: 1412.38s, done 241 out of 390
# Number of trees: 200 , Maximum depth 10 :
# Accuracy: 0.8175124901393637
# Area under ROC curve: 0.8595098944039782 Selected area: 0.0973348762109139
#
# elapsed time: 1419.95s, done 242 out of 390
# Number of trees: 200 , Maximum depth 12 :
# Accuracy: 0.8217196949776492
# Area under ROC curve: 0.8708344287804822 Selected area: 0.10495400341962507
#
# elapsed time: 1428.6s, done 243 out of 390
# Number of trees: 200 , Maximum depth 14 :
# Accuracy: 0.8267157507231133
# Area under ROC curve: 0.8771725690680698 Selected area: 0.10864812570263657
#
# elapsed time: 1437.7s, done 244 out of 390
# Number of trees: 200 , Maximum depth 16 :
# Accuracy: 0.8285564028398633
# Area under ROC curve: 0.8800546371421547 Selected area: 0.1089641024765137
#
# elapsed time: 1447.27s, done 245 out of 390
# Number of trees: 200 , Maximum depth 18 :
# Accuracy: 0.8303970549566132
# Area under ROC curve: 0.8811019964486164 Selected area: 0.10982388869809641
#
# elapsed time: 1457.58s, done 246 out of 390
# Number of trees: 200 , Maximum depth 20 :
# Accuracy: 0.8301341046542203
# Area under ROC curve: 0.8816976553669387 Selected area: 0.11071142963630341
#
# elapsed time: 1468.34s, done 247 out of 390
# Number of trees: 200 , Maximum depth 22 :
# Accuracy: 0.830922955561399
# Area under ROC curve: 0.8820177495987767 Selected area: 0.11009899588925197
#
# elapsed time: 1479.21s, done 248 out of 390
# Number of trees: 200 , Maximum depth 24 :
# Accuracy: 0.8330265579805417
# Area under ROC curve: 0.8821356308952084 Selected area: 0.11035000832641498
#
# elapsed time: 1489.7s, done 249 out of 390
# Number of trees: 200 , Maximum depth 26 :
# Accuracy: 0.8319747567709703
# Area under ROC curve: 0.8827457771656151 Selected area: 0.11015328533495675
#
# elapsed time: 1501.14s, done 250 out of 390
# Number of trees: 200 , Maximum depth 28 :
# Accuracy: 0.8327636076781488
# Area under ROC curve: 0.8827178699505477 Selected area: 0.11066507010963418
#
# elapsed time: 1512.8s, done 251 out of 390
# Number of trees: 200 , Maximum depth 30 :
# Accuracy: 0.8319747567709703
# Area under ROC curve: 0.8825307543609979 Selected area: 0.11035793824545051
#
# elapsed time: 1524.48s, done 252 out of 390
# Number of trees: 200 , Maximum depth 32 :
# Accuracy: 0.8322377070733631
# ...
# Accuracy: 0.8319747567709703
# Area under ROC curve: 0.8825090995820932 Selected area: 0.11053727641440782
#
# elapsed time: 2187.15s, done 309 out of 390
# Number of trees: 240 , Maximum depth 26 :
# Accuracy: 0.8346042597948987
# Area under ROC curve: 0.8832609169060384 Selected area: 0.11107879838546848
#
# elapsed time: 2200.53s, done 310 out of 390
# Number of trees: 240 , Maximum depth 28 :
# Accuracy: 0.8346042597948987
# Area under ROC curve: 0.8833200863019189 Selected area: 0.11103350634790018
#
# elapsed time: 2213.15s, done 311 out of 390
# Number of trees: 240 , Maximum depth 30 :
# Accuracy: 0.8322377070733631
# Area under ROC curve: 0.8830928636218625 Selected area: 0.1107551966894418
#
# elapsed time: 2227.52s, done 312 out of 390
# Number of trees: 240 , Maximum depth 32 :
# Accuracy: 0.8314488561661846
# Area under ROC curve: 0.8832526819901169 Selected area: 0.11086697804815412
#
# elapsed time: 2242.39s, done 313 out of 390
# Number of trees: 240 , Maximum depth 34 :
# Accuracy: 0.8327636076781488
# Area under ROC curve: 0.882949362587008 Selected area: 0.11053697141752183
#
# elapsed time: 2256.66s, done 314 out of 390
# Number of trees: 240 , Maximum depth 36 :
# Accuracy: 0.8311859058637917
# Area under ROC curve: 0.8829299952847481 Selected area: 0.10937279830372931
#
# elapsed time: 2269.78s, done 315 out of 390
# Number of trees: 240 , Maximum depth 38 :
# Accuracy: 0.8322377070733631
# Area under ROC curve: 0.8830957610922793 Selected area: 0.10951858681522862
#
# elapsed time: 2277.94s, done 316 out of 390
# Number of trees: 250 , Maximum depth 10 :
# Accuracy: 0.8167236392321852
# Area under ROC curve: 0.859979742106833 Selected area: 0.09761745582577602
#
# elapsed time: 2287.22s, done 317 out of 390
# Number of trees: 250 , Maximum depth 12 :
# Accuracy: 0.8198790428608993
# Area under ROC curve: 0.8711208208564191 Selected area: 0.10440256904977002
#
# elapsed time: 2297.04s, done 318 out of 390
# Number of trees: 250 , Maximum depth 14 :
# Accuracy: 0.8269787010255062
# Area under ROC curve: 0.8773124101402925 Selected area: 0.1087231549365881
#
# elapsed time: 2308.36s, done 319 out of 390
# Number of trees: 250 , Maximum depth 16 :
# Accuracy: 0.8285564028398633
# Area under ROC curve: 0.8800494521950931 Selected area: 0.10958568613014463
#
# elapsed time: 2320.0s, done 320 out of 390
# Number of trees: 250 , Maximum depth 18 :
# Accuracy: 0.8298711543518275
# Area under ROC curve: 0.881338979029024 Selected area: 0.11005660132210052
#
# elapsed time: 2332.92s, done 321 out of 390
# Number of trees: 250 , Maximum depth 20 :
# Accuracy: 0.8303970549566132
# Area under ROC curve: 0.8820252220224831 Selected area: 0.11019506990833626
#
# elapsed time: 2346.36s, done 322 out of 390
# Number of trees: 250 , Maximum depth 22 :
# Accuracy: 0.8314488561661846
# Area under ROC curve: 0.8824772274075081 Selected area: 0.11090983011063457
#
# elapsed time: 2359.44s, done 323 out of 390
# Number of trees: 250 , Maximum depth 24 :
# Accuracy: 0.8322377070733631
# Area under ROC curve: 0.8826568705733514 Selected area: 0.11062877548020236
#
# elapsed time: 2372.65s, done 324 out of 390
# Number of trees: 250 , Maximum depth 26 :
# Accuracy: 0.8338154088877202
# Area under ROC curve: 0.883269304320403 Selected area: 0.11052004409034985
#
# elapsed time: 2387.41s, done 325 out of 390
# Number of trees: 250 , Maximum depth 28 :
# Accuracy: 0.8335524585853273
# Area under ROC curve: 0.8834102128817265 Selected area: 0.11115870756959573
#
# elapsed time: 2401.07s, done 326 out of 390
# Number of trees: 250 , Maximum depth 30 :
# Accuracy: 0.8319747567709703
# Area under ROC curve: 0.883067701378769 Selected area: 0.11085554066492981
#
# elapsed time: 2414.92s, done 327 out of 390
# Number of trees: 250 , Maximum depth 32 :
# Accuracy: 0.832500657375756
# Area under ROC curve: 0.8833360986384328 Selected area: 0.11036968062556082
#
# elapsed time: 2427.99s, done 328 out of 390
# Number of trees: 250 , Maximum depth 34 :
# Accuracy: 0.832500657375756
# Area under ROC curve: 0.8831581329554626 Selected area: 0.11074147182957264
#
# elapsed time: 2440.56s, done 329 out of 390
# Number of trees: 250 , Maximum depth 36 :
# Accuracy: 0.8314488561661846
# Area under ROC curve: 0.8830707513476288 Selected area: 0.10949815202386781
#
# elapsed time: 2453.93s, done 330 out of 390
# Number of trees: 250 , Maximum depth 38 :
# Accuracy: 0.8322377070733631
# Area under ROC curve: 0.8831864976658589 Selected area: 0.10898956971649319
#
# elapsed time: 2462.15s, done 331 out of 390
# Number of trees: 260 , Maximum depth 10 :
# Accuracy: 0.8164606889297923
# Area under ROC curve: 0.8599199627171807 Selected area: 0.09759793602507319
#
# elapsed time: 2471.49s, done 332 out of 390
# Number of trees: 260 , Maximum depth 12 :
# Accuracy: 0.8196160925585064
# Area under ROC curve: 0.8711964600841424 Selected area: 0.10445929847056262
#
# elapsed time: 2483.09s, done 333 out of 390
# Number of trees: 260 , Maximum depth 14 :
# Accuracy: 0.8261898501183277
# Area under ROC curve: 0.8774153465893112 Selected area: 0.10766085078271351
#
# elapsed time: 2495.41s, done 334 out of 390
# Number of trees: 260 , Maximum depth 16 :
# Accuracy: 0.8293452537470418
# Area under ROC curve: 0.8801885307751007 Selected area: 0.11028351900527097
#
# elapsed time: 2508.68s, done 335 out of 390
# Number of trees: 260 , Maximum depth 18 :
# Accuracy: 0.8296082040494347
# Area under ROC curve: 0.881273252200095 Selected area: 0.1105998007760341
#
# elapsed time: 2522.43s, done 336 out of 390
# Number of trees: 260 , Maximum depth 20 :
# Accuracy: 0.8306600052590061
# Area under ROC curve: 0.8821258709948572 Selected area: 0.11084029082063074
#
# elapsed time: 2535.95s, done 337 out of 390
# Number of trees: 260 , Maximum depth 22 :
# Accuracy: 0.8319747567709703
# Area under ROC curve: 0.8825013221615008 Selected area: 0.11024966435092698
#
# elapsed time: 2551.0s, done 338 out of 390
# Number of trees: 260 , Maximum depth 24 :
# Accuracy: 0.832500657375756
# Area under ROC curve: 0.8828365137391948 Selected area: 0.11074406430310348
#
# elapsed time: 2565.4s, done 339 out of 390
# Number of trees: 260 , Maximum depth 26 :
# Accuracy: 0.834341309492506
# Area under ROC curve: 0.8832987365199002 Selected area: 0.11047109209014976
#
# elapsed time: 2579.93s, done 340 out of 390
# Number of trees: 260 , Maximum depth 28 :
# Accuracy: 0.8346042597948987
# Area under ROC curve: 0.8835570688823268 Selected area: 0.11125722156376784
#
# elapsed time: 2594.84s, done 341 out of 390
# Number of trees: 260 , Maximum depth 30 :
# Accuracy: 0.8332895082829346
# Area under ROC curve: 0.8831633179025242 Selected area: 0.1109044926651299
#
# elapsed time: 2608.84s, done 342 out of 390
# Number of trees: 260 , Maximum depth 32 :
# Accuracy: 0.8327636076781488
# Area under ROC curve: 0.8834608423647995 Selected area: 0.11104189376226471
#
# elapsed time: 2623.33s, done 343 out of 390
# Number of trees: 260 , Maximum depth 34 :
# Accuracy: 0.8319747567709703
# Area under ROC curve: 0.8833136813673134 Selected area: 0.1084366103622082
#
# elapsed time: 2638.38s, done 344 out of 390
# Number of trees: 260 , Maximum depth 36 :
# Accuracy: 0.8330265579805417
# Area under ROC curve: 0.8831569129679185 Selected area: 0.11012156565881463
#
# elapsed time: 2652.38s, done 345 out of 390
# Number of trees: 260 , Maximum depth 38 :
# Accuracy: 0.8322377070733631
# Area under ROC curve: 0.8833609558846405 Selected area: 0.11027604658156442
#
# elapsed time: 2661.45s, done 346 out of 390
# Number of trees: 270 , Maximum depth 10 :
# Accuracy: 0.8169865895345779
# Area under ROC curve: 0.8600781036025622 Selected area: 0.0976645778446602
# elapsed time: 2671.76s, done 347 out of 390
# Number of trees: 270 , Maximum depth 12 :
# Accuracy: 0.8201419931632922
# Area under ROC curve: 0.8714175828264794 Selected area: 0.10459654706925443
#
# elapsed time: 2682.54s, done 348 out of 390
# Number of trees: 270 , Maximum depth 14 :
# Accuracy: 0.8261898501183277
# Area under ROC curve: 0.8775884323221059 Selected area: 0.10887626337335095
#
# elapsed time: 2694.95s, done 349 out of 390
# Number of trees: 270 , Maximum depth 16 :
# Accuracy: 0.829082303444649
# Area under ROC curve: 0.8803151044827833 Selected area: 0.11039423287488234
#
# elapsed time: 2707.6s, done 350 out of 390
# Number of trees: 270 , Maximum depth 18 :
# Accuracy: 0.8296082040494347
# Area under ROC curve: 0.881372223689596 Selected area: 0.11065531020928276
#
# elapsed time: 2721.07s, done 351 out of 390
# Number of trees: 270 , Maximum depth 20 :
# Accuracy: 0.8301341046542203
# Area under ROC curve: 0.8822596121293603 Selected area: 0.1103518383077309
#
# elapsed time: 2734.06s, done 352 out of 390
# Number of trees: 270 , Maximum depth 22 :
# Accuracy: 0.8317118064685775
# Area under ROC curve: 0.8826506181371887 Selected area: 0.1109898917932048
#
# elapsed time: 2746.87s, done 353 out of 390
# Number of trees: 270 , Maximum depth 24 :
# Accuracy: 0.8330265579805417
# Area under ROC curve: 0.8829087980011724 Selected area: 0.11074589428441936
#
# elapsed time: 2759.8s, done 354 out of 390
# Number of trees: 270 , Maximum depth 26 :
# Accuracy: 0.8346042597948987
# Area under ROC curve: 0.8835909235366708 Selected area: 0.11135299058596612
#
# elapsed time: 2772.94s, done 355 out of 390
# Number of trees: 270 , Maximum depth 28 :
# Accuracy: 0.8346042597948987
# Area under ROC curve: 0.8837993889082392 Selected area: 0.11140102759550827
#
# elapsed time: 2786.51s, done 356 out of 390
# Number of trees: 270 , Maximum depth 30 :
# Accuracy: 0.8338154088877202
# Area under ROC curve: 0.883400605479818 Selected area: 0.1111407127533228
#
# elapsed time: 2799.61s, done 357 out of 390
# Number of trees: 270 , Maximum depth 32 :
# Accuracy: 0.8319747567709703
# Area under ROC curve: 0.8837138372817214 Selected area: 0.11119988214920326
#
# elapsed time: 2812.83s, done 358 out of 390
# Number of trees: 270 , Maximum depth 34 :
# Accuracy: 0.832500657375756
# Area under ROC curve: 0.8835093368696705 Selected area: 0.11100590412971884
#
# elapsed time: 2826.11s, done 359 out of 390
# Number of trees: 270 , Maximum depth 36 :
# Accuracy: 0.8317118064685775
# Area under ROC curve: 0.8834553524208519 Selected area: 0.11037181560376269
#
# elapsed time: 2839.34s, done 360 out of 390
# Number of trees: 270 , Maximum depth 38 :
# Accuracy: 0.832500657375756
# Area under ROC curve: 0.8836214232252688 Selected area: 0.11113247783740128
#
# elapsed time: 2848.45s, done 361 out of 390
# Number of trees: 280 , Maximum depth 10 :
# Accuracy: 0.8177754404417565
# Area under ROC curve: 0.8602226721265175 Selected area: 0.09775211195093698
#
# elapsed time: 2858.53s, done 362 out of 390
# Number of trees: 280 , Maximum depth 12 :
# Accuracy: 0.8209308440704707
# Area under ROC curve: 0.8714904770822289 Selected area: 0.1051699412149002
#
# elapsed time: 2869.74s, done 363 out of 390
# Number of trees: 280 , Maximum depth 14 :
# Accuracy: 0.8267157507231133
# Area under ROC curve: 0.8776601065903116 Selected area: 0.10891286299966878
#
# elapsed time: 2881.05s, done 364 out of 390
# Number of trees: 280 , Maximum depth 16 :
# Accuracy: 0.8285564028398633
# Area under ROC curve: 0.8802588325573196 Selected area: 0.10971469981291493
#
# elapsed time: 2893.02s, done 365 out of 390
# Number of trees: 280 , Maximum depth 18 :
# Accuracy: 0.8301341046542203
# Area under ROC curve: 0.8813995209108916 Selected area: 0.11065805518125661
#
# elapsed time: 2907.91s, done 366 out of 390
# Number of trees: 280 , Maximum depth 20 :
# Accuracy: 0.8303970549566132
# Area under ROC curve: 0.8823782559180071 Selected area: 0.11095756212329073
#
# elapsed time: 2922.8s, done 367 out of 390
# Number of trees: 280 , Maximum depth 22 :
# Accuracy: 0.8317118064685775
# Area under ROC curve: 0.8828127239820881 Selected area: 0.11104479123268153
#
# elapsed time: 2936.73s, done 368 out of 390
# Number of trees: 280 , Maximum depth 24 :
# Accuracy: 0.8335524585853273
# Area under ROC curve: 0.8831521855161858 Selected area: 0.11031173121722429
#
# elapsed time: 2950.25s, done 369 out of 390
# Number of trees: 280 , Maximum depth 26 :
# Accuracy: 0.834341309492506
# Area under ROC curve: 0.8838419359738336 Selected area: 0.11151448643709347
#
# elapsed time: 2964.19s, done 370 out of 390
# Number of trees: 280 , Maximum depth 28 :
# Accuracy: 0.8348672100972916
# Area under ROC curve: 0.8839843695195873 Selected area: 0.1115106739760187
#
# elapsed time: 2978.2s, done 371 out of 390
# Number of trees: 280 , Maximum depth 30 :
# Accuracy: 0.8332895082829346
# Area under ROC curve: 0.8836900475246148 Selected area: 0.11071569959270716
#
# elapsed time: 2991.95s, done 372 out of 390
# Number of trees: 280 , Maximum depth 32 :
# Accuracy: 0.8327636076781488
# Area under ROC curve: 0.8839927569339517 Selected area: 0.11129046622433986
#
# elapsed time: 3005.6s, done 373 out of 390
# Number of trees: 280 , Maximum depth 34 :
# Accuracy: 0.8327636076781488
# Area under ROC curve: 0.8836331656053791 Selected area: 0.10985911583842728
#
# elapsed time: 3020.06s, done 374 out of 390
# Number of trees: 280 , Maximum depth 36 :
# Accuracy: 0.832500657375756
# Area under ROC curve: 0.8837727016807158 Selected area: 0.11058729590370883
#
# elapsed time: 3033.83s, done 375 out of 390
# Number of trees: 280 , Maximum depth 38 :
# Accuracy: 0.8335524585853273
# Area under ROC curve: 0.8838570333196898 Selected area: 0.11005980378940329
#
# elapsed time: 3042.73s, done 376 out of 390
# Number of trees: 290 , Maximum depth 10 :
# Accuracy: 0.8180383907441493
# Area under ROC curve: 0.8601932399270203 Selected area: 0.09779984396359315
#
# elapsed time: 3052.69s, done 377 out of 390
# Number of trees: 290 , Maximum depth 12 :
# Accuracy: 0.8209308440704707
# Area under ROC curve: 0.8714011129946364 Selected area: 0.1051516414017413
#
# elapsed time: 3063.66s, done 378 out of 390
# Number of trees: 290 , Maximum depth 14 :
# Accuracy: 0.8254009992111491
# Area under ROC curve: 0.8775960572442556 Selected area: 0.10890981303080896
#
# elapsed time: 3075.61s, done 379 out of 390
# Number of trees: 290 , Maximum depth 16 :
# Accuracy: 0.8298711543518275
# Area under ROC curve: 0.8802501401460692 Selected area: 0.10974458950774113
#
# elapsed time: 3087.82s, done 380 out of 390
# Number of trees: 290 , Maximum depth 18 :
# Accuracy: 0.8296082040494347
# Area under ROC curve: 0.8814092808112429 Selected area: 0.11010052087368188
#
# elapsed time: 3101.0s, done 381 out of 390
# Number of trees: 290 , Maximum depth 20 :
# Accuracy: 0.8311859058637917
# Area under ROC curve: 0.8822861468584404 Selected area: 0.11092477495804769
#
# elapsed time: 3114.36s, done 382 out of 390
# Number of trees: 290 , Maximum depth 22 :
# Accuracy: 0.8319747567709703
# Area under ROC curve: 0.8827698719196077 Selected area: 0.11097570943800665
#
# elapsed time: 3128.16s, done 383 out of 390
# Number of trees: 290 , Maximum depth 24 :
# Accuracy: 0.8335524585853273
# Area under ROC curve: 0.8830423866372324 Selected area: 0.11027345410803358
#
# elapsed time: 3142.07s, done 384 out of 390
# Number of trees: 290 , Maximum depth 26 :
# Accuracy: 0.8338154088877202
# Area under ROC curve: 0.8838401059925178 Selected area: 0.11154239365216083
#
# elapsed time: 3156.11s, done 385 out of 390
# Number of trees: 290 , Maximum depth 28 :
# Accuracy: 0.8348672100972916
# Area under ROC curve: 0.8839919944417368 Selected area: 0.11156343843729356
#
# elapsed time: 3170.7s, done 386 out of 390
# Number of trees: 290 , Maximum depth 30 :
# Accuracy: 0.8338154088877202
# Area under ROC curve: 0.8836952324716765 Selected area: 0.11131700095342027
#
# elapsed time: 3184.99s, done 387 out of 390
# Number of trees: 290 , Maximum depth 32 :
# Accuracy: 0.8327636076781488
# Area under ROC curve: 0.8840920334203388 Selected area: 0.11075321420968294
#
# elapsed time: 3199.68s, done 388 out of 390
# Number of trees: 290 , Maximum depth 34 :
# Accuracy: 0.8330265579805417
# Area under ROC curve: 0.8837507419049251 Selected area: 0.111120277961962
#
# elapsed time: 3213.85s, done 389 out of 390
# Number of trees: 290 , Maximum depth 36 :
# Accuracy: 0.8330265579805417
# Area under ROC curve: 0.8837885615187867 Selected area: 0.10997150719091157
# elapsed time: 3228.56s, done 390 out of 390
# Number of trees: 290 , Maximum depth 38 :
# Accuracy: 0.8332895082829346
# Area under ROC curve: 0.8839584447842787 Selected area: 0.11133270829304834
#
# Best number of trees: 290
#
# Best maximum depth: 28
#
# Area under ROC curve of best model: 0.11156343843729356

# %%
print(best_area)
print(best_total_auc)
# Out:
# 0.11156343843729356
# 0.8839919944417368

# %% [markdown]
# Now we train again the best Random Forest found on the whole training set. We calculate its accuracy and $Q$ factor on the test set, and find the relative ROC curve of the classifier.

# %%
X_train_np = np.array(X_train)
Y_train_np = np.array(Y_train)
X_test_np = np.array(X_test)
Y_test_np = np.array(Y_test)

best_forest = RandomForestClassifier(n_estimators=best_model[0], max_depth= best_model[1], max_features=X_train_np.shape[1],bootstrap=True,max_samples=1.0,random_state=10,n_jobs=-1)

best_forest.fit(X_train_np,Y_train_np)
Y_pred = best_forest.predict(X_test_np)
accuracy = accuracy_score(Y_test_np, Y_pred)
print('Accuracy of best Random Forest:',accuracy)

y_pred_prob = best_forest.predict_proba(X_test_np)[:, 1]
fpr, tpr, thresholds = roc_curve(Y_test_np, y_pred_prob)
partial_fpr = fpr[fpr <= 0.2]
partial_tpr = tpr[:len(partial_fpr)]
partial_auc = auc(partial_fpr, partial_tpr)
roc_auc_best = auc(fpr, tpr)
print('Area under ROC curve of the best Random Forest:',best_area)
print('Partial area under ROC curve under 0.2 fpr:',partial_auc)
# Out:
# Accuracy of best Random Forest: 0.8348672100972916
# Area under ROC curve of the best Random Forest: 0.11156343843729356
# Partial area under ROC curve under 0.2 fpr: 0.11156343843729356

# %%
Q_rforest = get_best_Q(fpr,tpr)
fpr_rforest = fpr
tpr_rforest = tpr

print('best random forest Q:',Q_rforest)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=1.5, label=f'ROC curve (AUC = {roc_auc_best:.3f})')
plt.plot([0, 1], [0, 1], color='red', linestyle='--') 
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.02])
plt.xlabel('False Positive Rate',fontsize=13.8)
plt.ylabel('True Positive Rate',fontsize=13.8)
plt.title('Random Forest ROC Curve',fontsize=14.3)
plt.grid(alpha=0.4)
plt.legend(loc='best')
plt.show()
# Out:
# best random forest Q: 1.7961638155528008

# %% [markdown]
# ## Part 5.4: Neural Network
# Now we are going to train a Feed-Forward Fully-Connected Neural Network to classify the samples. Different models are going to be trained in a manual grid search in order to find the combination of hyper-parameters that maximize the partial AUC.

# %%
# this function determines the partial area under the curve, up to FPR<=0.2
def partial_auc_at_fpr(y_true, y_pred_proba):
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_proba)
    valid_indices = fpr <= 0.2  # indices where FPR <= 0.2
    partial_fpr = fpr[valid_indices]
    partial_tpr = tpr[valid_indices]
    # check if there are at least 2 points for partial AUC calculation
    if len(partial_fpr) < 2:
        return 0  # return 0 if not enough points to calculate AUC

    partial_auc = auc(partial_fpr, partial_tpr)
    return partial_auc

def full_auc_scorer(y_true, y_pred_proba):
    fpr, tpr, _ = roc_curve(y_true, y_pred_proba)
    return auc(fpr, tpr)

# create scoring function (partial AUC) to implement a grid-search
partial_auc_scorer = make_scorer(partial_auc_at_fpr, greater_is_better=True)

# %%
# redefine NN cycle
hidden_layer_sizes = [(18,), (36,), (54,), (36,18), (54,18), (54,36), (54,36,18)]
learning_rate_init = [ 0.1 , 0.01 , 0.001 ]

start_time = time.time()

auc_scorer = make_scorer(full_auc_scorer, greater_is_better=True, response_method='predict' ) 

parameters = []
fprs = []
tprs = []
aucs = []
partial_aucs = []
hls = []
lrs = []

for size in hidden_layer_sizes:
    for lr in learning_rate_init:
        print(f"Training MLP of size {size} and lr {lr}...")
        lrs.append(lr)
        hls.append(size)
        
        MLP = MLPClassifier(hidden_layer_sizes=size,
                            activation='relu', 
                            max_iter=600, 
                            alpha=1e-4, 
                            solver='sgd', 
                            tol=1e-4, 
                            learning_rate='adaptive',
                            learning_rate_init=lr,
                            verbose=0)
        
        MLP.fit(X_train,Y_train)
        parameters.append(MLP.coefs_)
        
        elapsed_time = time.time() - start_time
        start_time = time.time()
        
        y_pred_proba = MLP.predict_proba(X_test)[:, 1]  

        fpr, tpr, _ = roc_curve(Y_test, y_pred_proba)
        fprs.append(fpr)
        tprs.append(tpr)
        auc_value = auc(fpr, tpr)
        aucs.append(auc_value)
        print("AUC (Test set):", auc_value)
        #print(fpr)
        
        # search for fpr less than 0.2 (if not able fpr is set to zero)
        partial_fpr = fpr[fpr <= 0.2]
        if (len(partial_fpr) < 2 ):
            partial_auc = 0
        else:
            partial_tpr = tpr[:len(partial_fpr)]
            partial_auc = auc(partial_fpr, partial_tpr)
        partial_aucs.append(partial_auc)
        
        print(f"Time needed for training: {elapsed_time:.2f} seconds")
        print("partial AUC:",partial_auc," total AUC:",auc_value,'\n')
# Out:
# Training MLP of size (18,) and lr 0.1...
# AUC (Test set): 0.8677625001448734
# Time needed for training: 4.44 seconds
# partial AUC: 0.10233591015035737  total AUC: 0.8677625001448734
#
# Training MLP of size (18,) and lr 0.01...
# AUC (Test set): 0.8713544484710811
# Time needed for training: 10.18 seconds
# partial AUC: 0.10430344506182593  total AUC: 0.8713544484710811
#
# Training MLP of size (18,) and lr 0.001...
# AUC (Test set): 0.8480148667682104
# Time needed for training: 9.41 seconds
# partial AUC: 0.09285386196206936  total AUC: 0.8480148667682104
#
# Training MLP of size (36,) and lr 0.1...
# AUC (Test set): 0.8770408104133255
# Time needed for training: 6.75 seconds
# partial AUC: 0.10538343903508746  total AUC: 0.8770408104133255
#
# Training MLP of size (36,) and lr 0.01...
# AUC (Test set): 0.8761880391201207
# Time needed for training: 11.43 seconds
# partial AUC: 0.10871370003312267  total AUC: 0.8761880391201207
#
# Training MLP of size (36,) and lr 0.001...
# AUC (Test set): 0.8560350648819877
# Time needed for training: 12.74 seconds
# partial AUC: 0.0972528320485848  total AUC: 0.8560350648819877
#
# Training MLP of size (54,) and lr 0.1...
# AUC (Test set): 0.8795426998690343
# Time needed for training: 7.95 seconds
# partial AUC: 0.10757179169200684  total AUC: 0.8795426998690343
#
# Training MLP of size (54,) and lr 0.01...
# AUC (Test set): 0.8784599609237991
# Time needed for training: 14.37 seconds
# partial AUC: 0.10665466605585958  total AUC: 0.8784599609237991
#
# Training MLP of size (54,) and lr 0.001...
# AUC (Test set): 0.8560927092934383
# Time needed for training: 14.73 seconds
# partial AUC: 0.0974519950151309  total AUC: 0.8560927092934383
#
# Training MLP of size (36, 18) and lr 0.1...
# AUC (Test set): 0.8818899559035503
# Time needed for training: 19.38 seconds
# partial AUC: 0.10649027273431538  total AUC: 0.8818899559035503
#
# Training MLP of size (36, 18) and lr 0.01...
# AUC (Test set): 0.8776407392880519
# Time needed for training: 22.77 seconds
# partial AUC: 0.10658116180633798  total AUC: 0.8776407392880519
#
# Training MLP of size (36, 18) and lr 0.001...
# /usr/lib/python3/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# AUC (Test set): 0.8727064996666384
# Time needed for training: 32.17 seconds
# partial AUC: 0.10583086946682274  total AUC: 0.8727064996666384
#
# Training MLP of size (54, 18) and lr 0.1...
# AUC (Test set): 0.8735223663366396
# Time needed for training: 22.64 seconds
# partial AUC: 0.10242008929088833  total AUC: 0.8735223663366396
#
# Training MLP of size (54, 18) and lr 0.01...
# AUC (Test set): 0.879816587072646
# Time needed for training: 24.71 seconds
# partial AUC: 0.10675562002511955  total AUC: 0.879816587072646
#
# Training MLP of size (54, 18) and lr 0.001...
# /usr/lib/python3/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# AUC (Test set): 0.8725951758032551
# Time needed for training: 42.10 seconds
# partial AUC: 0.105860149167877  total AUC: 0.8725951758032551
#
# Training MLP of size (54, 36) and lr 0.1...
# AUC (Test set): 0.8632842308680028
# Time needed for training: 46.74 seconds
# partial AUC: 0.09375634774768951  total AUC: 0.8632842308680028
#
# Training MLP of size (54, 36) and lr 0.01...
# AUC (Test set): 0.8740253062016237
# Time needed for training: 34.32 seconds
# partial AUC: 0.10130715565394077  total AUC: 0.8740253062016237
#
# Training MLP of size (54, 36) and lr 0.001...
# /usr/lib/python3/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# AUC (Test set): 0.8743059033367269
# Time needed for training: 62.42 seconds
# partial AUC: 0.10645641807997142  total AUC: 0.8743059033367269
#
# Training MLP of size (54, 36, 18) and lr 0.1...
# /usr/lib/python3/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# AUC (Test set): 0.8438110946887231
# Time needed for training: 82.02 seconds
# partial AUC: 0.08539302813718272  total AUC: 0.8438110946887231
#
# Training MLP of size (54, 36, 18) and lr 0.01...
# AUC (Test set): 0.878391031627567
# Time needed for training: 44.73 seconds
# partial AUC: 0.10547524309776796  total AUC: 0.878391031627567
#
# Training MLP of size (54, 36, 18) and lr 0.001...
# AUC (Test set): 0.8682919747389379
# Time needed for training: 78.89 seconds
# partial AUC: 0.10081214570799231  total AUC: 0.8682919747389379
# /usr/lib/python3/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# Saving the best model's performance and plotting it

# %%
best_index_thresh = np.argmax(np.array(partial_aucs))
best_auc_thresh = aucs[best_index_thresh]
best_fpr_thresh = fprs[best_index_thresh]
best_tpr_thresh = tprs[best_index_thresh]
best_model = parameters[best_index_thresh]

fpr_NN = best_fpr_thresh
tpr_NN = best_tpr_thresh
Q_NN = get_best_Q(fpr_NN,tpr_NN)

print('best NN Q value:',Q_NN)

plt.grid()
plt.title('NN best ROC')
plt.plot([0, 1], [0, 1], linestyle='--', color='grey')
plt.plot(best_fpr_thresh,best_tpr_thresh,label='NN ROC',ms=4,alpha=0.5,c='lightblue')
plt.xlabel('false positive rate')
plt.ylabel('true positive rate')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 best_index_thresh = np.argmax(np.array(partial_aucs))
#       2 best_auc_thresh = aucs[best_index_thresh]
#       3 best_fpr_thresh = fprs[best_index_thresh]
#
# NameError: name 'partial_aucs' is not defined

# %% [markdown]
# Now we plot them all

# %%
print('best NN Q value:',Q_NN.round(3))
print('best perceptron Q value:',Q_perceptron.round(3))
print('best SVM Q value:',Q_SVM.round(3))
print('best random forest Q value:',Q_rforest.round(3))

plt.grid()
plt.title('ROC comparison')
plt.plot([0, 1], [0, 1], linestyle='--', color='grey')
plt.plot(fpr_NN,tpr_NN,label='NN ROC',ms=2,alpha=0.4,c='#33ccff')
plt.plot(fpr_perceptron,tpr_perceptron,label='perceptron ROC',ms=2,alpha=0.4,c='red')
plt.plot(fpr_SVM,tpr_SVM,marker='o',label='SVM ROC',ms=2,alpha=0.4,c='orange')
plt.plot(fpr_rforest,tpr_rforest,label='random forest ROC',ms=2,alpha=0.4,c='#1aff1a')
plt.xlabel('false positive rate')
plt.ylabel('true positive rate')
plt.legend()
plt.show()
# Out:
# best NN Q value: 1.679
# best perceptron Q value: 1.047
# best SVM Q value: 1.572
# best random forest Q value: 1.796

# %% [markdown]
# # Part 6: Cutting on alpha parameter
# In this section a cut on alpha parameter is going to be performed. The best value for alpha is going to be determined, as well as the value that lets only 5% of hadron to be accepted as false positives.

# %%
X_train['fAlpha'] = train_alpha
X_test['fAlpha'] = test_alpha
print(X_train.columns[:])
print(X_train.shape[:])
# Out:
# Index(['fLength', 'fWidth', 'fSize', 'fConc', 'fConc1', 'fAsym', 'fM3Long',
#        'fM3Trans', 'fDist', 'fAlpha'],
#       dtype='object')
# (15216, 10)

# %%
tot_hadrons = len(Y_test[Y_test == -1])
tot_gammas = len(Y_test[Y_test == 1])
tot_hadrons_train = len(Y_train[Y_train == -1])
sel_label = 9
# sel label = Alpha == 9

cut_values = []
rates = []
absolute_tp = []
absolute_fp = []

# setting minimum threshold as 0.95 (editable)
thresh = 0.95

#print('cut value    tp    fp     tp / all')
for i in range(1,tot_hadrons):
    cut_value = find_max_cut_value(X_train,Y_train,sel_label,i)
    
    # to check how the cut value behaves we get the results on test set
    tp, fp = find_tp_fp(X_test,Y_test,sel_label,cut_value)
    if (tp+fp == 0):
        tp = 1
    #print(cut_value,'  ',tp,'  ',fp,'  ',tp/(tp+fp))
    cut_values.append(cut_value)
    rates.append(tp/(tp+fp))
    absolute_tp.append(tp)
    absolute_fp.append(fp)
    
    if (tp/(tp+fp) > thresh):
        best_cut_thresh = cut_value
        rate_thresh = tp/(tp+fp)
        tp_thresh = tp
        fp_thresh = fp

index = np.argmax(rates)
best_rate = rates[index]
best_cut = cut_values[index]
best_tp = absolute_tp[index]
best_fp = absolute_fp[index]

print('Total gammas:',tot_gammas,'tot hadrons:',tot_hadrons,'tot test points:',tot_gammas+tot_hadrons)
print('Best cut value is Alpha =',round(best_cut,4),'with rate:',round(best_rate,4))
print('#tp:',best_tp,'  #fp:',best_fp)
print('Rate of saved gammas:',round(best_tp / tot_gammas,4))
print(' ')
print('Given threshold rate = 0.95, best cut is:',round(best_cut_thresh,4),'with rate',round(rate_thresh,4))
print('#tp:',tp_thresh,'#fp:',fp_thresh,'rate of saved gammas:',round(tp_thresh / tot_gammas,4))

plt.axhline(y=0.9, color='g', linestyle=':',label='threshold')  # Dotted green line
plt.scatter(cut_values,rates, s= 5,label='tp / all accepted')
plt.scatter(best_cut,best_rate,c='red',s=10,label='best rate')
plt.scatter(best_cut_thresh,rate_thresh,c='orange',s=10,label='best thresh rate')
plt.legend()
plt.title('Cut values for Alpha (tp / all rate)')
plt.xlabel('Alpha values')
plt.ylabel('True positive rate')
plt.show();
# Out:
# Total gammas: 2456 tot hadrons: 1347 tot test points: 3803
# Best cut value is Alpha = -1.0184 with rate: 0.9427
# #tp: 181   #fp: 11
# Rate of saved gammas: 0.0737
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[122], line 46
#      44 print('Rate of saved gammas:',round(best_tp / tot_gammas,4))
#      45 print(' ')
# ---> 46 print('Given threshold rate = 0.95, best cut is:',round(best_cut_thresh,4),'with rate',round(rate_thresh,4))
#      47 print('#tp:',tp_thresh,'#fp:',fp_thresh,'rate of saved gammas:',round(tp_thresh / tot_gammas,4))
#      49 plt.axhline(y=0.9, color='g', linestyle=':',label='threshold')  # Dotted green line
#
# NameError: name 'best_cut_thresh' is not defined

# %%
print(X_train['fAlpha'].max())
# Out:
# 2.3887613754958332
