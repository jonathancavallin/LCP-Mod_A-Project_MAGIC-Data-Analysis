# %% [markdown]
# # LCP Project: analysis of MAGIC04 dataset
# ### Description
#
# The data are Monte Carlo generated to simulate registration of high energy gamma particles in a ground-based atmospheric Cherenkov gamma telescope using the imaging technique. Cherenkov gamma telescope observes high energy gamma rays, taking advantage of the radiation emitted by charged particles produced inside the electromagnetic showers initiated by the gammas, and developing in the atmosphere. This Cherenkov radiation (of visible to UV wavelengths) leaks through the atmosphere and gets recorded in the detector, allowing reconstruction of the shower parameters. The available information consists of pulses left by the incoming Cherenkov photons on the photomultiplier tubes, arranged in a plane, the camera. Depending on the energy of the primary gamma, a total of few hundreds to some 10000 Cherenkov photons get collected, in patterns (called the shower image), allowing to discriminate statistically those caused by primary gammas (signal) from the images of hadronic showers initiated by cosmic rays in the upper atmosphere (background).
#
# Typically, the image of a shower after some pre-processing is an elongated cluster. Its long axis is oriented towards the camera center if the shower axis is parallel to the telescope's optical axis, i.e. if the telescope axis is directed towards a point source. A principal component analysis is performed in the camera plane, which results in a correlation axis and defines an ellipse. If the depositions were distributed as a bivariate Gaussian, this would be an equidensity ellipse. The characteristic parameters of this ellipse (often called Hillas parameters) are among the image parameters that can be used for discrimination. The energy depositions are typically asymmetric along the major axis, and this asymmetry can also be used in discrimination. There are, in addition, further discriminating characteristics, like the extent of the cluster in the image plane, or the total sum of depositions.
#
# The program was run with parameters allowing to observe events with energies down to below 50 GeV.
#
# ### Dataset
#
# Attribute Information:
#
# 1. fLength: continuous # major axis of ellipse [mm]
# 2. fWidth: continuous # minor axis of ellipse [mm]
# 3. fSize: continuous # 10-log of sum of content of all pixels [in #phot]
# 4. fConc: continuous # ratio of sum of two highest pixels over fSize [ratio]
# 5. fConc1: continuous # ratio of highest pixel over fSize [ratio]
# 6. fAsym: continuous # distance from highest pixel to center, projected onto major axis [mm]
# 7. fM3Long: continuous # 3rd root of third moment along major axis [mm]
# 8. fM3Trans: continuous # 3rd root of third moment along minor axis [mm]
# 9. fAlpha: continuous # angle of major axis with vector to origin [deg]
# 10. fDist: continuous # distance from origin to center of ellipse [mm]
# 11. class: g,h # gamma (signal), hadron (background)
#
# g = gamma (signal): 12332
# h = hadron (background): 6688
#
# For technical reasons, the number of h events is underestimated. In the real data, the h class represents the majority of the events.
#
# The simple classification accuracy is not meaningful for this data, since classifying a background event as signal is worse than classifying a signal event as background. For comparison of different classifiers an ROC curve has to be used. The relevant points on this curve are those, where the probability of accepting a background event as signal is below one of the following thresholds: 0.01, 0.02, 0.05, 0.1, 0.2 depending on the required quality of the sample of the accepted events for different experiments.
#
#
# ### References
#
# [1] Bock, R.K., Chilingarian, A., Gaug, M., Hakl, F., Hengstebeck, T., Jirina, M., Klaschka, J., Kotrc, E., Savicky, P., Towers, S., Vaicilius, A., Wittek W. (2004).
# Methods for multidimensional event classification: a case study using images from a Cherenkov gamma-ray telescope.
# Nucl.Instr.Meth. A, 516, pp. 511-528.
#
# [2] P. Savicky, E. Kotrc.
# Experimental Study of Leaf Confidences for Random Forest.
# Proceedings of COMPSTAT 2004, In: Computational Statistics. (Ed.: Antoch J.) - Heidelberg, Physica Verlag 2004, pp. 1767-1774.
#
# [3] J. Dvorak, P. Savicky.
# Softening Splits in Decision Trees Using Simulated Annealing.
# Proceedings of ICANNGA 2007, Warsaw, (Ed.: Beliczynski et. al), Part I, LNCS 4431, pp. 721-729.
#
# [4] Aharonian, F. et al.
# The Energy Spectrum of TeV Gamma-Rays from the Crab Nebula as measured by the HEGRA system of imaging air Cherenkov telescopes
# Astrophys. J. 539 (2000) 317-324
#
# [5] Aleksic, J. et al.
# Measurement of the Crab Nebula spectrum over three decades in energy with the MAGIC telescopes
# Journal of High Energy Astrophysics, 5–6 (2015) 30-38.

# %% [markdown]
# # Part 0: setup
# First, we import the libraries

# %%
# math libraries
import numpy as np
import pandas as pd
import numpy.random as npr
import matplotlib.pyplot as plt
from scipy import linalg as la
from matplotlib import patches
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
import matplotlib.patheffects as path_effects
import seaborn as sns
import random as rnd

# general OS libraries
from time import time
import gzip
import os
import operator
import warnings
from IPython.core.interactiveshell import InteractiveShell

# ML libraries
import sklearn
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, roc_auc_score, auc
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Perceptron
from sklearn.datasets import make_classification
from sklearn.svm import NuSVC
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.exceptions import ConvergenceWarning
from sklearn.model_selection import train_test_split
from sklearn.metrics import make_scorer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression

warnings.filterwarnings('ignore')

# %% [markdown]
# Then, we import the dataset and we put it into a DataFrame:

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data

file_name="magic04.data"
data = pd.DataFrame(pd.read_csv(file_name))
data.columns=['fLength','fWidth','fSize',
        'fConc','fConc1','fAsym',
        'fM3Long','fM3Trans','fAlpha','fDist','category']
data   
#### save data in a DataFrame
# Out:
# --2025-03-13 16:06:47--  https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘magic04.data.12’
#
# magic04.data.12         [           <=>      ]   1.41M   497KB/s    in 2.9s
#
# 2025-03-13 16:06:52 (497 KB/s) - ‘magic04.data.12’ saved [1477391]
#         fLength    fWidth   fSize   fConc  fConc1     fAsym   fM3Long  \
# 0       31.6036   11.7235  2.5185  0.5303  0.3773   26.2722   23.8238
# 1      162.0520  136.0310  4.0612  0.0374  0.0187  116.7410  -64.8580
# 2       23.8172    9.5728  2.3385  0.6147  0.3922   27.2107   -6.4633
# 3       75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277   28.5525
# 4       51.6240   21.1502  2.9085  0.2420  0.1340   50.8761   43.1887
# ...         ...       ...     ...     ...     ...       ...       ...
# 19014   21.3846   10.9170  2.6161  0.5857  0.3934   15.2618   11.5245
# 19015   28.9452    6.7020  2.2672  0.5351  0.2784   37.0816   13.1853
# 19016   75.4455   47.5305  3.4483  0.1417  0.0549   -9.3561   41.0562
# 19017  120.5135   76.9018  3.9939  0.0944  0.0683    5.8043  -93.5224
# 19018  187.1814   53.0014  3.2093  0.2876  0.1539 -167.3125 -168.4558
#
#        fM3Trans   fAlpha     fDist category
# 0       -9.9574   6.3609  205.2610        g
# 1      -45.2160  76.9600  256.7880        g
# 2       -7.1513  10.4490  116.7370        g
# 3       21.8393   4.6480  356.4620        g
# 4        9.8145   3.6130  238.0980        g
# ...         ...      ...       ...      ...
# 19014    2.8766   2.4229  106.8258        h
# 19015   -2.9632  86.7975  247.4560        h
# 19016   -9.4662  30.2987  256.5166        h
# 19017  -63.8389  84.6874  408.3166        h
# 19018   31.4755  52.7310  272.3174        h
#
# [19019 rows x 11 columns]

# %% [markdown]
# In this cell we print the number of data of each label and the relative frequence

# %%
print('All data points:',len(data['fAlpha']),'points for',len(data.columns[:]),'columns')
print('labels and their relative frequencies:')

ngamma = len(data[data['category'] == 'g'] )
nback = len(data[data['category'] == 'h'] )
print(f'signal: \t{ngamma} \t {round(ngamma/len(data['fAlpha'])*100,2)}%')
print(f'background:\t {nback} \t {round(nback/len(data['fAlpha'])*100,2)}%')
# Out:
# All data points: 19019 points for 11 columns
# labels and their relative frequencies:
# signal: 	12331 	 64.84%
# background:	 6688 	 35.16%

# %% [markdown]
# We observe that about 2/3 of the dataset is labelled as signal, while only 1/3 as background. The dataset is indeed built underestimating the amount of background signal acquired.

# %% [markdown]
# Here we write some useful functions for the code

# %% [markdown]
# ## ML functions

# %%
# this function divides the dataset in input in parts_to_be_split parts. One of them is returned as test_set
# the other ones are the training_set. Indexes of the chosen data can be accessed (test_indexes, train_indexes)
# (for example in a K-fold)

def split_train_test_set(data,parts_to_be_split):
    indexes = np.arange(0,data.shape[0],1)
    rnd.shuffle(indexes)
    len_test_set = int(len(indexes) / parts_to_be_split)

    test_indexes = indexes[:len_test_set]
    train_indexes = indexes[len_test_set:]

    train_set = data.iloc[train_indexes]
    test_set = data.iloc[test_indexes]
    
    return train_set, test_set

# this function takes col category and returns as Y (target), the other columns are X (labels)
def split_X_Y(data):
    Y = data['category']
    X = data.drop('category',axis=1)

    return X,Y

# this function takes the point that has the lowest distance from FPR=0 and TPR=1 and computes Q for that point values
def get_best_Q(fpr,tpr):
    distances = np.zeros(len(fpr))
    
    for i in range(len(fpr)):
        distances[i] = np.sqrt(fpr[i]**2+(1-tpr[i])**2)
        
    min_dist_idx = np.argmin(distances)
    
    best_Q = tpr[min_dist_idx] / np.sqrt(fpr[min_dist_idx])
    return best_Q

# %% [markdown]
# ## Other functions
# ### Cutting functions

# %%
# this function finds cut value starting from possible max
def find_max_cut_value(X_train,Y_train,sel_label,min_hadrons):
    new_X = X_train[X_train.columns[sel_label]]
    new_data = np.vstack((new_X,Y_train))
    new_data_sorted = new_data[:, new_data[0].argsort()]
    
    #new_data_sorted_reversed = new_data_sorted[:, ::-1] #reverse!! STARTING FROM MAXX
    
    # setup vars, cut value is  set to max of the label, so that in worst scenario all points are true hadrons
    true_hadrons = 0
    max_cut_value = new_data_sorted[0,0]
    
    for i in range(new_data_sorted.shape[1]):
        if new_data_sorted[1,i] == -1:
            true_hadrons += 1
        if true_hadrons == min_hadrons:
            max_cut_value = new_data_sorted[0,i]
            
    return max_cut_value

# this functions returns the number of true positive and false positive points on test set
def find_tp_fp(X_test,Y_test,sel_label,cut_value):
    new_X = X_test[X_test.columns[sel_label]]
    new_data = np.vstack((new_X,Y_test))
    new_data_sorted = new_data[:, new_data[0].argsort()]
    new_data_sorted_reversed = new_data_sorted[:, ::-1] #reverse!! STARTING FROM MAXX
    fp = 0
    tp = 0
    
    for i in range(new_data_sorted_reversed.shape[1]):
        if new_data_sorted_reversed[0,i] < cut_value:
            if new_data_sorted_reversed[1,i] == 1:
                tp += 1
            if new_data_sorted_reversed[1,i] == -1:
                fp += 1
                
    return tp, fp # true positive, false positive

# %%
def plot_roc(fpr,tpr,auc,method_name,color):
    fig = plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {auc:.3f})',c=color)
    plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Diagonal line (random classifier)
    plt.title(f'{method_name} ROC Curve',fontsize=16)
    plt.xlabel('False Positive Rate (FPR)',fontsize=14)
    plt.ylabel('True Positive Rate (TPR)',fontsize=14)
    plt.xticks(fontsize=11)
    plt.yticks(fontsize=11)
    plt.legend(loc='lower right',fontsize=11)
    plt.grid(True)
    plt.show();

# %% [markdown]
# # Part 1: study of the dataset

# %% [markdown]
# ### Part 1.1 Camera plane reconstruction
# The following code recontrsucts the traces detected by the telescope camera. In orange and red are represented the detected gammas, while in blue are represented the detected hadrons

# %%
datasig = data[data['category'] == 'g'] 
databkg = data[data['category'] == 'h'] 
# visualize data
n_ellipses = 20

# ellipse parameters
random_angle_sig = 2 * np.pi * np.random.uniform(0, 1, size=n_ellipses)
sig_idx = np.random.randint(0,10000, size=n_ellipses)
sig_ellipse_params = [ 
    {
        'center': (datasig['fDist'][idx] * np.cos(random_angle_sig[i]), datasig['fDist'][idx] * np.sin(random_angle_sig[i])),  
        'width': datasig['fWidth'][idx], 
        'height': datasig['fLength'][idx], 
        'angle': datasig['fAlpha'][idx],
        'alpha': datasig['fSize'][idx]/data['fSize'].max()
        } 
    for i, idx in enumerate(sig_idx)
    ]

random_angle_bkg = 2 * np.pi * np.random.uniform(0, 1, size=n_ellipses)
bkg_idx = np.random.randint(13000,19000, size=n_ellipses)
bkg_ellipse_params = [ 
    {
        'center': (databkg['fDist'][idx] * np.cos(random_angle_bkg[i]), databkg['fDist'][idx] * np.sin(random_angle_bkg[i])),
        'width': databkg['fWidth'][idx], 
        'height': databkg['fLength'][idx], 
        'angle': databkg['fAlpha'][idx],
        'alpha': databkg['fSize'][idx]/data['fSize'].max()
        } 
    for i, idx in enumerate(bkg_idx)
    ]

fig, ax = plt.subplots(figsize=(10,12))

ax.grid(alpha=0.3)

# plot ellipses
radius = 500
camera_circle = patches.Circle((0,0), radius, alpha=0.15, color='#7a7a7a')
ax.add_patch(camera_circle)

bkg_ellipses = []
sig_ellipses = []

for params in bkg_ellipse_params:
    ellipse = patches.Ellipse(
        xy=params['center'], 
        width=params['width'], 
        height=params['height'], 
        angle=(params['angle'] - 90 + 180*np.arctan(params['center'][1] / params['center'][0])/np.pi), 
        fill=True, 
        alpha=params['alpha'], 
        color='C0'
        )
    ax.add_patch(ellipse)
    bkg_ellipses.append(ellipse)

for params in sig_ellipse_params:
    ellipse = patches.Ellipse(
        xy=params['center'], 
        width=params['width'], 
        height=params['height'], 
        angle=(params['angle'] - 90 + 180*np.arctan(params['center'][1] / params['center'][0])/np.pi),
        alpha=params['alpha'], 
        color='C1'
        )
    ax.add_patch(ellipse)
    sig_ellipses.append(ellipse)

ax.set_xlim(-radius, radius)
ax.set_ylim(-radius, radius)
ax.set_aspect('equal')

legend_labels = ['Camera Plane', 'Hadron', 'Gamma']
legend_handles = [camera_circle, bkg_ellipses[0], sig_ellipses[0]]
ax.legend(legend_handles, legend_labels, loc='lower right')

center_cross_size = 15
ax.plot([0, 0], [-center_cross_size, center_cross_size], color='black', linewidth=1)
ax.plot([-center_cross_size, center_cross_size], [0, 0], color='black', linewidth=1)

# color scale indicating alpha for background ellipses
bkg_alphas = [params['alpha'] for params in bkg_ellipse_params]
bkg_norm = Normalize(vmin=0, vmax=100)
bkg_scalar_map = ScalarMappable(norm=bkg_norm, cmap='Blues')
bkg_scalar_map.set_array(bkg_alphas)
bkg_colorbar = plt.colorbar(bkg_scalar_map, ax=ax, fraction=0.033, pad = 0.15)
bkg_colorbar.set_label('hadron #photons %')

# color scale indicating alpha for signal ellipses
sig_alphas = [params['alpha'] for params in sig_ellipse_params]
sig_norm = Normalize(vmin=0, vmax=100)
sig_scalar_map = ScalarMappable(norm=sig_norm, cmap='Oranges')
sig_scalar_map.set_array(sig_alphas)
sig_colorbar = plt.colorbar(sig_scalar_map, ax=ax, fraction=0.04, pad = 0.1)
sig_colorbar.set_label('gamma #photons %')

ax.set_xlabel('X-axis (mm)')
ax.set_ylabel('Y-axis (mm)')

plt.show();

# %% [markdown]
# This recontstruction resembles the acquisition of some signals. It is observed that the orange ellypses, representing data labeled as "gamma", are mostly radially oriented, while the orientation of the "hadrons" ellypses seems random. We can conclude that the photon shower axis is parallel to the telescope's optical axis. The colorbars represent the alpha parameter of the represented particles.

# %% [markdown]
# ### Part 1.2 plot of the features
# the following code plots histograms for each feature, in red there are gammas (signal), in blue hadrons (background). The code saves the histograms in a directory named 'part_1_plots'

# %%
fig, ax = plt.subplots(nrows=5, ncols=2, figsize=(20, 34))
fig.subplots_adjust(hspace=0.3)

udm = ['fLength ', 'fWidth ', 'fSize ', 'fConc ', 'fConc1 ', 
       'fAsym ', 'fM3Long ', 'fM3Trans ', 'fAlpha ', 'fDist ']

units = ['(mm)','(mm)','(#phot)','(ratio)','(ratio)','(mm)','(mm)','(mm)','(deg)','(mm)']
features = ['fLength', 'fWidth', 'fSize', 'fConc', 'fConc1', 
            'fAsym', 'fM3Long', 'fM3Trans', 'fAlpha', 'fDist']
bins = 40

avgs_g = []
avgs_h = []
stds_g = []
stds_h = []
lambdas = []

for i in range(5):
    for j in range(2):
            
        idx = 2 * i + j  # Update index to match new layout
        if (udm[idx] == 'fWidth (mm)'):
            bins = 50
        
        min_val = min(datasig[features[idx]].min(), databkg[features[idx]].min())
        max_val = max(datasig[features[idx]].max(), databkg[features[idx]].max())
        common_bins = np.linspace(min_val, max_val, bins + 1)
        
        #ax[i, j].grid()
        sns.histplot(datasig[features[idx]], bins = common_bins, kde=False, color='red', alpha=0.6, label='gamma', ax=ax[i, j], edgecolor='#383734', linewidth=0.5)
        sns.histplot(databkg[features[idx]], bins = common_bins, kde=False, color='blue', alpha=0.5, label='hadron', ax=ax[i, j], edgecolor='#383734', linewidth=0.5)
        mu_g = np.mean(datasig[features[idx]])
        mu_h = np.mean(databkg[features[idx]])
        std_g = np.std(datasig[features[idx]])
        std_h = np.std(databkg[features[idx]])
        avgs_g.append(mu_g)
        avgs_h.append(mu_h)
        stds_g.append(std_g)
        stds_h.append(std_h)
        lambdas.append(abs(mu_g-mu_h)/(std_g**2 + std_h**2)**(1/2))
        
        ax[i, j].axvline(mu_g,c='#990000', label= f'$\gamma$ mean = {round(mu_g,1)}±{round(std_g,1)}', lw=1.8)
        ax[i, j].axvline(mu_h,c='navy',label= f'h mean = {round(mu_h,1)}±{round(std_h,1)}', lw=1.7,alpha=0.7)
        ax[i, j].set_xlabel(f'{udm[idx]}{units[idx]}', fontsize=24)
        ax[i, j].set_ylabel(f'counts / {round(common_bins[1]-common_bins[0],2)} {units[idx]}', fontsize=24)
        ax[i, j].tick_params(axis='both', which='major', labelsize=16)
        ax[i, j].legend(loc='best', fontsize=18)
        ax[i, j].set_title(f'Histogram of {udm[idx]}', fontsize=26)
        
        '''if (udm[idx] == 'fLength (mm)'):
            ax[i, j].set_xlim(-5,260)
        if (udm[idx] == 'fWidth (mm)'):
            ax[i, j].set_xlim(-10,120)'''
            
        
        #ax[i, j].text(x=3,y=160,s=fr"$\mu_{{g}}$={mu_g:.2f} $\pm$ {l_std_g_high:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='#990000'))
        #ax[i, j].text(x=3,y=130,s=fr"$\mu_{{h}}$={mu_h:.2f} $\pm$ {l_std_h_high:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='navy'))

    
#plt.tight_layout()
plt.show();

# %%
print(f'feature \t gamma \t \thadrons \tcompatibility (lambda)')
for i in range(len(avgs_g)):
    print(f'{udm[i]}{units[i]}\t',f'{round(avgs_g[i],1)} \u00B1 {round(stds_g[i],1)}', f'\t{round(avgs_h[i],1)} \u00B1 {round(stds_h[i],1)}', f'\t\033[32m{round(lambdas[i],2)}\033[0m')
# Out:
# feature 	 gamma 	 	hadrons 	compatibility (lambda)
# fLength (mm)	 43.7 ± 26.2 	70.9 ± 57.9 	0.43
# fWidth (mm)	 18.6 ± 9.0 	28.8 ± 27.2 	0.36
# fSize (#phot)	 2.8 ± 0.5 	2.9 ± 0.5 	0.17
# fConc (ratio)	 0.4 ± 0.2 	0.4 ± 0.2 	0.04
# fConc1 (ratio)	 0.2 ± 0.1 	0.2 ± 0.1 	0.01
# fAsym (mm)	 3.2 ± 39.6 	-18.3 ± 82.3 	0.24
# fM3Long (mm)	 17.8 ± 33.9 	-2.8 ± 70.7 	0.26
# fM3Trans (mm)	 0.2 ± 13.6 	0.4 ± 29.9 	0.01
# fAlpha (deg)	 18.8 ± 21.5 	44.0 ± 26.0 	0.75
# fDist (mm)	 190.2 ± 70.3 	200.4 ± 81.9 	0.09

# %% [markdown]
# We observe that the mean values of all features for hadrons and gammas are compatible. Also they distribute in similar shapes, except for `fAlpha`. Therefore is not possible to distinguish signal from background from the distributions.

# %% [markdown]
# # Part 2: studying the correlations
# in this section each feature will be confronted with all the others. Results will be put in a 2D correlation matrix (n_features x n_features) to visualize the results
#
# First we rescale all features to have average = 0 and dev_std = 1 (Alpha is rescaled in this part, but will be restored for the later sections).

# %%
X = data[['fLength','fWidth','fSize',
        'fConc','fConc1','fAsym',
        'fM3Long','fM3Trans','fAlpha','fDist']]
Y = data['category']
print(X['fAlpha'])
# Out:
# 0         6.3609
# 1        76.9600
# 2        10.4490
# 3         4.6480
# 4         3.6130
#           ...
# 19014     2.4229
# 19015    86.7975
# 19016    30.2987
# 19017    84.6874
# 19018    52.7310
# Name: fAlpha, Length: 19019, dtype: float64

# %%
X_rescaled = X.copy()
original_alpha = X['fAlpha'].copy()

for i in range(X.shape[1]):
    h = X[str(X.columns[i])]
    avg = np.average(h)
    std = np.std(h)
    h = h - avg
    h = h / std
    X_rescaled[str(X_rescaled.columns[i])] = h
    
print('avg length:',round(np.average(X_rescaled['fLength']),15))
print('std length:',round(np.std(X_rescaled['fLength']),15))
# Out:
# avg length: 0.0
# std length: 0.999999999999997

# %% [markdown]
# The following cell computes the correlation matrix taking apart gammas from hadrons

# %%
Xg_rescaled = X_rescaled[Y == 'g']
Xh_rescaled = X_rescaled[Y == 'h']
features = features[:10]


cov = np.zeros((Xg_rescaled.shape[1],Xg_rescaled.shape[1]))
for i in range(Xg_rescaled.shape[1]):
    h = Xg_rescaled[str(Xg_rescaled.columns[i])]
    for j in range(Xg_rescaled.shape[1]):
        v = Xg_rescaled[str(Xg_rescaled.columns[j])]
        cov[i,j] = (np.cov(h,v)[0,1])
        
std_devs = np.std(Xg_rescaled, axis=0)
cov = cov / np.outer(std_devs, std_devs) # the data for gamma events are not normalized with respsect to themselv   



ticks = np.arange(0,10,1)
x_ticks = np.arange(cov.shape[1]) + 0.5
y_ticks = np.arange(cov.shape[0]) + 0.5

fig, ax = plt.subplots(1, 2, figsize=(16, 8))
cax = ax[0].imshow(cov, cmap='coolwarm', interpolation='nearest')
fig.colorbar(cax)
ax[0].set_xticks(ticks, minor=False)
ax[0].set_yticks(ticks, minor=False)
ax[0].set_xticklabels(features,rotation=90)
ax[0].set_yticklabels(features)
ax[0].grid(which='minor', color='black', linewidth=2)

for i in range(cov.shape[0]):
    for j in range(cov.shape[1]):
        ax[0].text(j, i, f'{cov[i, j]:.2f}', ha='center', va='center', color='black', fontsize=10)

#ax[0].plot([-0.5, cov.shape[1]-0.5], [-0.5, cov.shape[0]-0.5], color='black', linewidth=2, linestyle='-')
#ax[0].plot([-0.5, cov.shape[1]-0.5], [-0.5, cov.shape[0]-0.5], color='black', linewidth=2, linestyle='-')
ax[0].set_title('GAMMA EVENTS FEATURES CORRELATION')

cov = np.zeros((Xh_rescaled.shape[1],Xh_rescaled.shape[1]))
for i in range(Xh_rescaled.shape[1]):
    h = Xh_rescaled[str(Xh_rescaled.columns[i])]
    for j in range(Xh_rescaled.shape[1]):
        v = Xh_rescaled[str(Xh_rescaled.columns[j])]
        cov[i,j] = (np.cov(h,v)[0,1])
        
std_devs = np.std(Xh_rescaled, axis=0)
cov = cov / np.outer(std_devs, std_devs)

cax = ax[1].imshow(cov, cmap='coolwarm', interpolation='nearest')
fig.colorbar(cax)
ax[1].set_xticks(ticks, minor=False)
ax[1].set_yticks(ticks, minor=False)
ax[1].set_xticklabels(features, rotation=90)
ax[1].set_yticklabels(features)
ax[1].grid(which='minor', color='black', linewidth=1)

for i in range(cov.shape[0]):
    for j in range(cov.shape[1]):
        ax[1].text(j, i, f'{cov[i, j]:.2f}', ha='center', va='center', color='black', fontsize=10)

#ax[1].plot([-0.5, cov.shape[1]-0.5], [-0.5, cov.shape[0]-0.5], color='black', linewidth=2, linestyle='-')
ax[1].set_title('HADRON EVENTS FEATURES CORRELATION')

plt.show();

# %% [markdown]
# We observe that the most correlated features are the first 5. The correlation between the first 3 is positive, while correlation between `fConc1` and `fConc2` is negative, and very close to 1. This is in agreement for both signal and background events. Differences can be seen while observing other parameters:
# - `fAlpha`: this parameter is slightly correlated to the others for gamma events, but sees almost no correlation for background ones
# - `fAsym`: this parameter sees the opposite than `fAlpha`
# - `fM3Long`: the correlation of this parameter is present for both signal and background events, but has its sign swapped

# %% [markdown]
# ## Part 2.1: Correlation between features and label
# In this part we check the correlation between features and label Y. This is done to find the most informative parameters for the classification.

# %%
# Calculate the correlation between each feature and the label Y

Y_array = np.where(Y == 'g', 1, -1)
Y_array = np.array(Y_array) 
feature_names = data.columns[:10]

correlations = np.zeros(X_rescaled.shape[1])  
for i in range(X_rescaled.shape[1]):
    feature = X_rescaled.iloc[:, i]  
    correlations[i] = np.corrcoef(feature, Y_array)[0, 1]

# create a bar plot to display the correlations
fig, ax = plt.subplots(figsize=(14.5, 10))

bars = ax.bar(feature_names, correlations, color='teal', edgecolor='black', linewidth=1.2,alpha=0.8)

# add correlation values on top of each bar
for i, corr in enumerate(correlations):
    ax.text(i, corr + 0.035 if corr>=0 else corr-0.035, f'{corr:.2f}', ha='center', va='bottom', fontsize=12, color='black', fontweight='bold')

ax.set_ylabel('Correlation with Label Y', fontsize=16, fontweight='bold')
ax.set_ylim(-0.53,0.3)
ax.set_title('Correlation between features and label Y', fontsize=20, fontweight='bold')
ax.set_xticks(np.arange(len(feature_names)))
ax.set_xticklabels(feature_names, fontsize=16, fontweight='bold', rotation=20, ha='right')

x_line = np.linspace(-0.6,len(feature_names),100)
y_line = np.linspace(0,0,100)
ax.plot(x_line, y_line, linestyle='dotted', color='black') 
ax.set_xlim(-0.6,9.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# The features most strongly correlated with the label Y, and thus most informative for distinguishing between gamma and hadron events, are `fAlpha`
# , `flength` and `fWidth` This is coherent with our observations from the feature histograms, where these features exhibit more distinct distributions between the two classes.

# %% [markdown]
# # Part 3: comparison of the features rescaled

# %% [markdown]
# In this section we analyze the distributions of the `fWidth` and `fLength` parameters. First of all we have computed the mean and standard deviation for both samples and we rescaled them. Then the distribution of both "`fWidth` and `fLength` was plotted dividing the gamma from the hadron events.
#
# We then used the `fSize` parameter to apply a cut to both the signals (gamma) and background (hadron) events and considered only the tails of their distribution. Since `fSize` is proportional to the number of photons, for both the width and lenght distribution we defined as "High energy events" the data points higher than 𝜇+𝜎
# (right-side tail) and as "Low energy events" the data points lower than 𝜇−𝜎. Considering 𝜇 and 𝜎 rispectively as the mean and standard deviation of the rescaled width and lenght distributions.
#
# From this comparison we can clearly see that in the high energy tail the signal is more clustered and separated from the background, despite having a smaller number of gamma events in this energy region. Meanwhile in the low energy tail signal and background events are more evenly distributed.
#
# Therefore,considering only the high energy region could give us an edge while classifying the events into signal and background.

# %%
## find mean and std

mu_l=data['fLength'].mean()
std_l=data['fLength'].std()
mu_w=data['fWidth'].mean()
std_w=data['fWidth'].std()
print('Length attribute:   mean = ', round(mu_l,3), '    std = ', round(std_l,3))
print('Width attribute:    mean = ', round(mu_w,3), '   std = ', round(std_w,3))
data['scaled_fLength']= (data['fLength']-mu_l)/std_l   ##add a scaled comlumn to the DataFrame
data['scaled_fWidth']= (data['fWidth']-mu_w)/std_w
# Out:
# Length attribute:   mean =  53.251     std =  42.366
# Width attribute:    mean =  22.181    std =  18.346

# %%
###plots of the scaled distribution before cutting 

bins = 32
common_bins = np.linspace(min(data['scaled_fLength']), max(data['scaled_fLength']), bins + 1)

fig, ax = plt.subplots(1, 2, figsize=(12,5))
sns.histplot(data,x=data['scaled_fLength'],hue='category',bins = common_bins, kde=False, ax=ax[0], palette=['red','blue'], edgecolor='#383734', linewidth=0.5)
ax[0].set_title("Distribution of Scaled fLenght", fontsize=14)
ax[0].set_xlabel("Scaled fLength", fontsize=12)
ax[0].set_ylabel("Count", fontsize=12)
ax[0].set_xlim(-1.5, 5.5)  
legend = ax[0].get_legend()

ax[0].legend(['Hadron', 'Gamma'], title='Category')

bins = 45
common_bins = np.linspace(min(data['scaled_fWidth']), max(data['scaled_fWidth']), bins + 1)
sns.histplot(data,x=data['scaled_fWidth'],hue='category',bins = common_bins, kde=False, ax=ax[1], palette=['red','blue'], edgecolor='#383734', linewidth=0.5)
ax[1].set_title("Distribution of Scaled fWidth", fontsize=14)
ax[1].set_xlabel("Scaled fWidth", fontsize=12)
ax[1].set_ylabel("Count", fontsize=12)
ax[1].set_xticks(range(-1,9))
ax[1].set_xlim(-1.5, 6)  
legend = ax[1].get_legend()
ax[1].legend(['Hadron', 'Gamma'], title='Category');

# %%
median_fSize = data['fSize'].median()
min_fSize = data['fSize'].min()
max_fSize = data['fSize'].max()
mean_fSize = data['fSize'].mean()
std_fSize = data['fSize'].std()
print("Statistichal informations of fSize: \nmedian=",median_fSize, '\nmin=', min_fSize, '\nmax=', max_fSize, '\nmean=', round(mean_fSize,3), '\nstd=', round(std_fSize,3))
# Out:
# Statistichal informations of fSize:
# median= 2.7396
# min= 1.9413
# max= 5.3233
# mean= 2.825
# std= 0.473

# %%
#### plots at high energy

fig, ax = plt.subplots(1, 2, figsize=(12,5))
fig.suptitle('High Energy Events (high fSize values)', fontsize=18)

fig.subplots_adjust(top=0.85)  

##useful variables
ng_high=len(data[data['category'] == 'g']['scaled_fLength'][data['fSize'] >= mean_fSize+std_fSize])
nh_high=len(data[data['category'] == 'h']['scaled_fLength'][data['fSize'] >= mean_fSize+std_fSize])
l_mu_g_high=data[data['category'] == 'g']['scaled_fLength'][data['fSize'] >= mean_fSize+std_fSize].mean()
l_mu_h_high=data[data['category'] == 'h']['scaled_fLength'][data['fSize'] >= mean_fSize+std_fSize].mean()
l_std_g_high=data[data['category'] == 'g']['scaled_fLength'][data['fSize'] >= mean_fSize+std_fSize].std()
l_std_h_high=data[data['category'] == 'h']['scaled_fLength'][data['fSize'] >= mean_fSize+std_fSize].std()
w_mu_g_high=data[data['category'] == 'g']['scaled_fWidth'][data['fSize'] >= mean_fSize+std_fSize].mean()
w_mu_h_high=data[data['category'] == 'h']['scaled_fWidth'][data['fSize'] >= mean_fSize+std_fSize].mean()
w_std_g_high=data[data['category'] == 'g']['scaled_fWidth'][data['fSize'] >= mean_fSize+std_fSize].std()
w_std_h_high=data[data['category'] == 'h']['scaled_fWidth'][data['fSize'] >= mean_fSize+std_fSize].std()

##plot length - high energy
sns.histplot(data,x=data['scaled_fLength'][data['fSize'] >= mean_fSize+std_fSize],hue='category',hue_order=['g', 'h'], kde=False, color='blue', ax=ax[0], palette=['red','blue'], edgecolor='#383734', linewidth=0.5,bins=32)
ax[0].set_title("Distribution of Scaled fLenght", fontsize=14)
ax[0].set_xlabel("Scaled fLength", fontsize=12)
ax[0].set_ylabel("Count", fontsize=12)
ax[0].axvline(l_mu_g_high,c='#990000', label= r'$\mu_{g}$', lw=1.8)
ax[0].axvline(l_mu_h_high,c='navy',label=r'$\mu_{h}$', lw=1.7)
legend = ax[0].get_legend()
ax[0].legend(['Hadron', 'Gamma'], title='Category')
ax[0].text(x=3,y=180,s=f"# of gamma events: {ng_high} \n# of hadron events: {nh_high}", fontsize=9, color='black')
ax[0].text(x=3,y=160,s=fr"$\mu_{{g}}$={l_mu_g_high:.2f} $\pm$ {l_std_g_high:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='#990000'))
ax[0].text(x=3,y=130,s=fr"$\mu_{{h}}$={l_mu_h_high:.2f} $\pm$ {l_std_h_high:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='navy'))

#plot width - high energy
sns.histplot(data,x=data['scaled_fWidth'][data['fSize'] >= mean_fSize+std_fSize],hue='category', kde=False, color='blue', ax=ax[1], palette=['red','blue'], edgecolor='#383734', linewidth=0.5,bins=40)
ax[1].set_title("Distribution of Scaled fWidth", fontsize=14)
ax[1].set_xlabel("Scaled fWidth", fontsize=12)
ax[1].set_ylabel("Count", fontsize=12)
ax[1].set_xlim(-1,8.5)
ax[1].axvline(w_mu_g_high,c='#990000', lw = 1.8) #label= r'$\mu_{g}$', lw=1.8)
ax[1].axvline(w_mu_h_high,c='navy', lw = 1.7) #label=r'$\mu_{h}$', lw=1.7)
legend = ax[1].get_legend()
ax[1].legend(['Hadron', 'Gamma'], title='Category')
ax[1].text(x=4,y=350,s=f"# of gamma events: {ng_high} \n# of hadron events: {nh_high}", fontsize=9, color='black')
ax[1].text(x=4,y=315,s=fr"$\mu_{{g}}$={w_mu_g_high:.2f} $\pm$ {w_std_g_high:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='#990000'))
ax[1].text(x=4,y=260,s=fr"$\mu_{{h}}$={w_mu_h_high:.2f} $\pm$ {w_std_h_high:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='navy'))

#### plots at low energy

fig1, ax1 = plt.subplots(1, 2, figsize=(12,5))
fig1.suptitle('Low Energy Events (low fSize values)', fontsize=18)
fig.subplots_adjust(top=0.85)  
###useful variables
ng_low=len(data[data['category'] == 'g']['scaled_fLength'][data['fSize'] <= mean_fSize-std_fSize])
nh_low=len(data[data['category'] == 'h']['scaled_fLength'][data['fSize'] <= mean_fSize-std_fSize])
l_mu_g_low=data[data['category'] == 'g']['scaled_fLength'][data['fSize'] <= mean_fSize-std_fSize].mean()
l_mu_h_low=data[data['category'] == 'h']['scaled_fLength'][data['fSize'] <= mean_fSize-std_fSize].mean()
l_std_g_low=data[data['category'] == 'g']['scaled_fLength'][data['fSize'] <= mean_fSize-std_fSize].std()
l_std_h_low=data[data['category'] == 'h']['scaled_fLength'][data['fSize'] <= mean_fSize-std_fSize].std()
w_mu_g_low=data[data['category'] == 'g']['scaled_fWidth'][data['fSize'] <= mean_fSize-std_fSize].mean()
w_mu_h_low=data[data['category'] == 'h']['scaled_fWidth'][data['fSize'] <= mean_fSize-std_fSize].mean()
w_std_g_low=data[data['category'] == 'g']['scaled_fWidth'][data['fSize'] <= mean_fSize-std_fSize].std()
w_std_h_low=data[data['category'] == 'h']['scaled_fWidth'][data['fSize'] <= mean_fSize-std_fSize].std()

## plot length - low energy
sns.histplot(data,x=data['scaled_fLength'][data['fSize'] <= mean_fSize-std_fSize],hue='category', kde=False, color='blue', ax=ax1[0], palette=['red','blue'],edgecolor='#383734', linewidth=0.5, bins=180)
ax1[0].set_title("Distribution of Scaled fLenght", fontsize=14)
ax1[0].set_xlabel("Scaled fLength", fontsize=12)
ax1[0].set_ylabel("Count", fontsize=12)
ax1[0].axvline(l_mu_g_low,c='#990000', label= r'$\mu_{g}$', lw=1.8)
ax1[0].axvline(l_mu_h_low,c='navy',label=r'$\mu_{h}$', lw=1.7,alpha=0.7)
legend = ax[0].get_legend()
ax1[0].legend(['Hadron', 'Gamma'], title='Category')
ax1[0].set_xlim(-1.1,-0.1)
ax1[0].text(x=-0.55,y=230,s=f"# of gamma events: {ng_low} \n# of hadron events: {nh_low} ", fontsize=9, color='black')
ax1[0].text(x=-0.55,y=208,s=fr"$\mu_{{g}}$={l_mu_g_low:.2f} $\pm$ {l_std_g_low:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='#990000'))
ax1[0].text(x=-0.55,y=178,s=fr"$\mu_{{h}}$={l_mu_h_low:.2f} $\pm$ {l_std_h_low:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='navy'))

## plot width - low energy
sns.histplot(data,x=data['scaled_fWidth'][data['fSize'] <= mean_fSize-std_fSize],hue='category', kde=False, color='blue', ax=ax1[1], palette=['red','blue'], edgecolor='#383734', linewidth=0.5,bins=30)
ax1[1].set_title("Distribution of Scaled fWidth", fontsize=14)
ax1[1].set_xlabel("Scaled fWidth", fontsize=12)
ax1[1].set_ylabel("Count", fontsize=12)
ax1[1].set_xlim(-1.3,0.0)
ax1[1].axvline(w_mu_g_low,c='#990000', label= r'$\mu_{g}$', lw=1.8)
ax1[1].axvline(w_mu_h_low,c='navy',label=r'$\mu_{h}$', lw=1.7)
legend = ax[1].get_legend()
ax1[1].legend(['Hadron', 'Gamma'], title='Category')
ax1[1].text(x=-0.54,y=350,s=f"# of gamma events: {ng_low} \n# of hadron events: {nh_low}", fontsize=9, color='black')
ax1[1].text(x=-0.54,y=320,s=fr"$\mu_{{g}}$={l_mu_g_low:.2f} $\pm$ {l_std_g_low:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='#990000'))
ax1[1].text(x=-0.54,y=280,s=fr"$\mu_{{h}}$={l_mu_h_low:.2f} $\pm$ {l_std_h_low:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='navy'))


plt.show();

# %% [markdown]
# # Part 4: PCA
# In this part we will perform Principal Component Analysis (PCA). PCA is a statistical tecnique used for reducing the dimensionality of the problem. PCA is done studying in which directions of the feature space the dataset shows significant patterns. This is done computing the covariance matrix and finding its eigenvalues and eigenvectors using Linalg library (la). The eigenvectors are then used to redefine the feature space and aling data along them. Eigenvectors whose eigenvalues are higher correspond to directions of highest variance in the dataset. This way we can reduce the dimensionality of the problem and focus on the most significant directions. PCA is done separately for signal and background events, to find significative differences in spread for different labels.

# %%
file_name="magic04.data"
data = pd.DataFrame(pd.read_csv(file_name))

df= pd.DataFrame(data.values, columns=['fLength','fWidth','fSize','fConc','fConc1','fAsym','fM3Long','fM3Trans','fAlpha','fDist','class'])
df_1=df[df['class']=='g']
df_0=df[df['class']=='h']
df_1 = df_1.drop(columns=['class']) # no need for label to perform PCA
df_0 = df_0.drop(columns=['class']) 

print("Shape of signal data frame:",np.shape(df_1))
print("Shape of bkg data frame:",np.shape(df_0))
# Out:
# Shape of signal data frame: (12331, 10)
# Shape of bkg data frame: (6688, 10)

# %%
# We re-scale the data-set to mean zero and unitary std before executing the PCA   
for column in df_1.columns: 
    mean =df_1[column].mean()
    std= df_1[column].std()
    df_1[column]= (df_1[column]-mean)/std
for column in df_0.columns: 
    mean =df_0[column].mean()
    std= df_0[column].std()
    df_0[column]= (df_0[column]-mean)/std

# %%
df_1
# Out:
#         fLength     fWidth     fSize     fConc    fConc1     fAsym   fM3Long  \
# 0      -0.46046  -0.760816 -0.573381  0.823995  1.527718  0.581262  0.177195
# 1      4.523403  13.006763  2.757867  -1.94532 -1.848775   2.86389 -2.435386
# 2     -0.757944  -0.999015 -0.962066  1.298189  1.668012  0.604942 -0.715068
# 3      1.202731   1.365333  0.814225 -0.375535 -0.299882 -0.221084  0.316503
# 4      0.304432   0.283231   0.26877 -0.795793 -0.763137  1.202046  0.747688
# ...         ...        ...       ...       ...       ...       ...       ...
# 12326 -1.176177  -0.791727 -0.870077  1.979703  1.557848 -0.462468 -0.368425
# 12327 -0.641711   0.221696  0.197295 -0.223838  0.001423 -0.168803 -1.113903
# 12328 -0.823883  -0.852587 -1.057078  0.867819  0.723612  0.303856  0.012389
# 12329  0.480086   0.012071  0.314549 -0.741856 -0.713234    2.3551 -1.741272
# 12330  -0.46394    0.07684  0.375227 -0.483971 -0.598361  0.881792  0.113829
#
#        fM3Trans    fAlpha     fDist
# 0     -0.748903 -0.578221  0.213696
# 1     -3.350675  2.708118  0.946671
# 2     -0.541838 -0.387922 -1.045563
# 3      1.597412 -0.657955   2.36454
# 4      0.710088 -0.706133  0.680804
# ...         ...       ...       ...
# 12326  0.843377  0.103778  0.196285
# 12327 -0.682203 -0.688826  0.217067
# 12328  0.531735  0.106385 -0.952475
# 12329  0.825343 -0.599163  0.099156
# 12330 -0.904986 -0.055937  -0.27044
#
# [12331 rows x 10 columns]

# %%
df_0
# Out:
#         fLength    fWidth     fSize     fConc    fConc1     fAsym   fM3Long  \
# 12331  0.392734  0.336335  0.509333 -1.078145 -0.955834  0.869326  1.300189
# 12332  0.535902 -0.249909  0.864505 -1.400203 -1.198949 -0.434994  0.649403
# 12333  0.506171 -0.254443  0.435676 -0.325283 -0.587349 -0.363269  0.855943
# 12334    0.3574 -0.366573 -0.397221  0.336609  1.084807 -0.417957  -1.34382
# 12335 -0.568118 -0.592947 -0.053908  0.178717 -0.179052 -0.403375  0.158383
# ...         ...       ...       ...       ...       ...       ...       ...
# 19014 -0.855161 -0.657545 -0.591972  1.105678  1.520212  0.407652  0.203334
# 19015 -0.724699  -0.81255 -1.317922  0.841131  0.546058  0.672784  0.226829
# 19016  0.077684  0.688905  1.139571 -1.215647 -1.347189  0.108521  0.621122
# 19017  0.855352  1.769025  2.274791 -1.462941 -1.233679  0.292734 -1.282777
# 19018  2.005736  0.890095  0.642288 -0.452851  -0.50857 -1.810805 -2.342868
#
#        fM3Trans    fAlpha     fDist
# 12331   0.38302 -1.149281  0.384367
# 12332 -0.515505  1.711764  0.910031
# 12333 -0.333989 -0.892876  1.783286
# 12334 -0.583383  0.765787 -0.850547
# 12335  0.254152 -0.748348 -0.446646
# ...         ...       ...       ...
# 19014  0.084175  -1.59954 -1.143376
# 19015 -0.111018  1.647644   0.57434
# 19016 -0.328377 -0.526731   0.68501
# 19017 -2.145759  1.566436  2.539158
# 19018   1.04008  0.336584  0.878007
#
# [6688 rows x 10 columns]

# %%
cov_1 = df_1.cov()
cov_0 = df_0.cov()
cov_1
# Out:
#            fLength    fWidth     fSize     fConc    fConc1     fAsym  \
# fLength   1.000000  0.695644  0.766118 -0.710209 -0.679994 -0.120212
# fWidth    0.695644  1.000000  0.855155 -0.761340 -0.731434 -0.002589
# fSize     0.766118  0.855155  1.000000 -0.863440 -0.825395  0.029039
# fConc    -0.710209 -0.761340 -0.863440  1.000000  0.979332 -0.033398
# fConc1   -0.679994 -0.731434 -0.825395  0.979332  1.000000 -0.037624
# fAsym    -0.120212 -0.002589  0.029039 -0.033398 -0.037624  1.000000
# fM3Long   0.542507  0.422045  0.540963 -0.452184 -0.433913  0.162435
# fM3Trans  0.012337  0.044016  0.022622 -0.017356 -0.016053 -0.005598
# fAlpha   -0.443232 -0.296886 -0.458023  0.482322  0.463536 -0.004571
# fDist     0.602479  0.389206  0.459641 -0.368592 -0.347123 -0.178190
#
#            fM3Long  fM3Trans    fAlpha     fDist
# fLength   0.542507  0.012337 -0.443232  0.602479
# fWidth    0.422045  0.044016 -0.296886  0.389206
# fSize     0.540963  0.022622 -0.458023  0.459641
# fConc    -0.452184 -0.017356  0.482322 -0.368592
# fConc1   -0.433913 -0.016053  0.463536 -0.347123
# fAsym     0.162435 -0.005598 -0.004571 -0.178190
# fM3Long   1.000000  0.008234 -0.271465  0.294765
# fM3Trans  0.008234  1.000000 -0.007311  0.009752
# fAlpha   -0.271465 -0.007311  1.000000 -0.425032
# fDist     0.294765  0.009752 -0.425032  1.000000

# %%
cov_0
# Out:
#            fLength    fWidth     fSize     fConc    fConc1     fAsym  \
# fLength   1.000000  0.773884  0.747319 -0.688524 -0.651879 -0.423194
# fWidth    0.773884  1.000000  0.790355 -0.672618 -0.638750 -0.304118
# fSize     0.747319  0.790355  1.000000 -0.839128 -0.796837 -0.305340
# fConc    -0.688524 -0.672618 -0.839128  1.000000  0.972725  0.238806
# fConc1   -0.651879 -0.638750 -0.796837  0.972725  1.000000  0.220317
# fAsym    -0.423194 -0.304118 -0.305340  0.238806  0.220317  1.000000
# fM3Long  -0.307349 -0.296956 -0.223553  0.124154  0.115716  0.285738
# fM3Trans  0.013007  0.039519  0.010992 -0.007704 -0.008235  0.006849
# fAlpha   -0.009282  0.041617 -0.004228 -0.010714 -0.015137  0.053334
# fDist     0.325267  0.354997  0.394842 -0.267684 -0.245179 -0.229049
#
#            fM3Long  fM3Trans    fAlpha     fDist
# fLength  -0.307349  0.013007 -0.009282  0.325267
# fWidth   -0.296956  0.039519  0.041617  0.354997
# fSize    -0.223553  0.010992 -0.004228  0.394842
# fConc     0.124154 -0.007704 -0.010714 -0.267684
# fConc1    0.115716 -0.008235 -0.015137 -0.245179
# fAsym     0.285738  0.006849  0.053334 -0.229049
# fM3Long   1.000000 -0.026806 -0.001489 -0.131121
# fM3Trans -0.026806  1.000000  0.010832  0.013150
# fAlpha   -0.001489  0.010832  1.000000 -0.097112
# fDist    -0.131121  0.013150 -0.097112  1.000000

# %%
l_1,V_1= la.eig(cov_1)
l_1=l_1.real
V_1=V_1.real
print("Eigenvalues Gamma events:", l_1,'\n')
print("Eigenvectors Gamma events:", V_1,'\n')
# Out:
# Eigenvalues Gamma events: [5.04135896 1.18671249 1.00189813 0.86259252 0.73828989 0.52867675
#  0.01763177 0.10500615 0.29317529 0.22465805]
#
# Eigenvectors Gamma events: [[ 3.86563154e-01  1.64161550e-01 -1.87852855e-02 -5.17321758e-02
#    2.27306595e-01 -6.21165157e-02  1.64670468e-02  2.62838530e-02
#   -3.75283692e-02  8.73323351e-01]
#  [ 3.76614052e-01 -6.58692554e-02  5.96665086e-02  3.13862948e-01
#    9.53882263e-02 -2.55432045e-01 -4.24256844e-03  4.90484637e-01
#   -6.23609927e-01 -2.18920288e-01]
#  [ 4.17121017e-01 -7.65050692e-02  1.22260020e-02  1.38753617e-01
#    1.93685374e-02 -6.00347575e-02  1.05957925e-01 -8.36960174e-01
#   -2.44851708e-01 -1.58410555e-01]
#  [-4.09538760e-01  1.17040480e-01 -9.64678415e-03 -2.30228965e-01
#    2.25834045e-01 -6.25170832e-02  7.50095221e-01 -4.79749462e-02
#   -3.77875580e-01  5.32663335e-02]
#  [-3.98738464e-01  1.26974491e-01 -9.56015222e-03 -2.43724055e-01
#    2.46152389e-01 -7.37984117e-02 -6.52335699e-01 -1.94150192e-01
#   -4.81400557e-01  6.61244443e-02]
#  [-1.90622395e-03 -8.04052066e-01 -3.28590356e-02 -3.80203807e-01
#   -9.19693200e-02 -4.28997470e-01 -9.83604836e-04  9.79016721e-03
#    1.56041455e-02  1.22574473e-01]
#  [ 2.71903952e-01 -2.41249770e-01 -3.78642354e-02 -3.23906107e-01
#    6.32530906e-01  5.46456330e-01 -8.61015132e-03  1.03440095e-01
#    5.50948287e-02 -2.21356334e-01]
#  [ 1.26092933e-02  7.19184389e-03  9.93064376e-01 -1.11114138e-01
#   -9.57172582e-03  1.53254329e-02  2.12728561e-04 -9.64915066e-03
#    2.61091729e-02  1.28354940e-02]
#  [-2.57574835e-01 -1.45524116e-01  6.79277022e-02  5.49090461e-01
#    6.21464113e-01 -3.39978798e-01 -1.14649466e-02 -7.84584893e-02
#    3.13437642e-01  5.46497448e-03]
#  [ 2.59975576e-01  4.55091241e-01 -4.94837864e-02 -4.51483873e-01
#    1.80007439e-01 -5.65210973e-01 -9.61549203e-03  3.45139415e-02
#    2.70203068e-01 -3.04727483e-01]]

# %%
l_0,V_0= la.eig(cov_0)
l_0=l_0.real
V_0=V_0.real
print("Eigenvalues background events:", l_0,'\n')
print("Eigenvectors background events:", V_0,'\n')
# Out:
# Eigenvalues background events: [4.42388448 0.02391582 0.14984033 0.2221564  0.43740477 1.20808117
#  0.69931975 0.80384168 1.03760086 0.99395472]
#
# Eigenvectors background events: [[-4.13567164e-01 -2.63725151e-02 -1.06784542e-01  7.64522513e-01
#   -4.62230622e-01 -8.23597651e-02 -5.41729191e-02  7.12962716e-02
#    4.76672675e-02 -4.04817037e-02]
#  [-4.10369824e-01  1.18010294e-02  4.74225410e-01 -4.98487549e-01
#   -5.76267380e-01 -9.62312079e-03  1.32890905e-01 -2.68784361e-02
#    8.66124162e-02 -4.11274819e-03]
#  [-4.39407630e-01 -1.02147327e-01 -8.06450398e-01 -3.56019314e-01
#   -3.84986171e-02  1.09655517e-01  5.96543774e-02 -1.63618469e-02
#   -4.11859284e-02  1.85943597e-02]
#  [ 4.26015621e-01 -7.48302786e-01 -1.36062501e-01 -5.34223025e-02
#   -3.57161556e-01 -2.95977603e-01  2.83083846e-02 -1.28650819e-01
#    6.42454683e-02 -2.32311900e-02]
#  [ 4.12889561e-01  6.54722945e-01 -2.94628020e-01 -7.73629598e-02
#   -4.28069468e-01 -3.13905698e-01  2.86139245e-02 -1.45244984e-01
#    6.18974490e-02 -2.33016102e-02]
#  [ 2.10557832e-01 -7.40397142e-04 -3.55910497e-02  1.47422983e-01
#   -1.46018555e-01  5.34160663e-01  7.75942210e-01 -3.19883815e-02
#   -6.50820677e-02  1.36639359e-01]
#  [ 1.56723710e-01 -9.82568990e-03 -1.68716012e-03 -8.72677373e-03
#   -2.86536343e-01  5.81070528e-01 -5.65135446e-01 -2.90368802e-01
#   -3.54285779e-01  1.62189920e-01]
#  [-1.12947495e-02  3.15103998e-04 -1.47230802e-02  1.26216402e-02
#    2.33848465e-02 -3.73288613e-02 -8.88561614e-02  3.08618973e-02
#    4.39405146e-01  8.91981616e-01]
#  [ 2.80804609e-03  1.13046169e-03 -2.41165114e-02  3.27484558e-02
#    6.09854767e-02  3.00604868e-01 -9.24616134e-02 -4.17620174e-01
#    7.67868956e-01 -3.62871549e-01]
#  [-2.15592824e-01  3.67233256e-03  7.71910499e-02  9.15713297e-02
#    1.85143711e-01 -2.83254481e-01  1.90571725e-01 -8.34016294e-01
#   -2.60993030e-01  1.56949242e-01]]

# %%
#GAMMA EVENTS
# sort eigenvalues in descending order and get sorted indices
sorted_indices = np.argsort(l_1)[::-1]
l_sorted = l_1[sorted_indices] 
 
variance_explained = l_sorted / np.sum(l_sorted) # ratio of the variance of the data explained by each feature

# cumulative variance explained
cumulative_variance = np.cumsum(variance_explained)

feature_names = df_1.columns.tolist()
pca_list = []
for i in range(len(feature_names)):
    pca_list.append(f'PC_{i+1}')

# features ordered from most important to least important to variability 
top_features = []
for i in range(len(feature_names)):
    most_important_feature_idx = sorted_indices[i]  # Index of the feature with the largest eigenvalue
    top_features.append(feature_names[most_important_feature_idx])

fig, ax1 = plt.subplots(figsize=(16, 8))

ax1.bar(pca_list, variance_explained, color='Orange', edgecolor='black',alpha=0.75)

ax2 = ax1.twinx()
ax2.plot(pca_list, cumulative_variance, label='Cumulative Variance Explained', marker='o', color='red')

ax1.set_ylabel('Variance Explained',fontsize=20)
ax2.set_ylabel('Cumulative Variance Explained',fontsize=20)
ax1.set_xlabel('# Principal component',fontsize=20)

plt.title('Gamma events: variance explained by each feature',fontsize=26)
ax2.legend(loc='upper center',fontsize=16)

plt.xticks(rotation=45, ha='right', fontsize=45)  
ax1.tick_params(axis='y', labelsize=16)  
ax2.tick_params(axis='y', labelsize=16)
ax1.tick_params(axis='x', labelsize=16)
plt.grid()
plt.show()
print("\n")

#BACKGROUND EVENTS 
sorted_indices = np.argsort(l_0)[::-1]
l_sorted = l_0[sorted_indices] 
 
variance_explained = l_sorted / np.sum(l_sorted) # ratio of the variance of the data explained by each feature

# cumulative variance explained
cumulative_variance = np.cumsum(variance_explained)

feature_names = df_0.columns.tolist()

# features ordered from most important to least important to variability 
top_features = []
for i in range(len(feature_names)):
    most_important_feature_idx = sorted_indices[i]  # Index of the feature with the largest eigenvalue
    top_features.append(feature_names[most_important_feature_idx])

fig, ax1 = plt.subplots(figsize=(16, 8))

ax1.bar(pca_list, variance_explained, color='Orange', edgecolor='black',alpha=0.75)

ax2 = ax1.twinx()
ax2.plot(pca_list, cumulative_variance, label='Cumulative Variance Explained', marker='o', color='blue')

ax1.set_ylabel('Variance Explained',fontsize=20)
ax1.set_xlabel('# Principal component',fontsize=20)
ax2.set_ylabel('Cumulative Variance Explained',fontsize=20)


plt.title('Background events: variance explained by each feature',fontsize=26)
ax2.legend(loc='upper center',fontsize=16)

plt.xticks(rotation=45, ha='right', fontsize=18)  
ax1.tick_params(axis='y', labelsize=16)  
ax2.tick_params(axis='y', labelsize=16)
ax1.tick_params(axis='x', labelsize=16)
plt.grid()
plt.show()

# %% [markdown]
# We notice that, for both signal and background events, the first principal component explains about half of the variance of the dataset, while the other component are responsible for about 10% at maximum. Being the principal components linear combinations of the features of the dataset, it is not possible to identify which features of the dataset are most influential. Therefore we perform the following analysis keeping the original dataset.

# %% [markdown]
# # Part 5: Machine Learning Analysis
# In this section we are going to implement several ML algorithms to classify the data in signal and background classes. Metrics used to evaluate data are the area under ROC curve in the range [0-0.2] (false positive rate values), since we mostly want to avoid accpeting hadrons, and the quality factor $Q=\frac{\epsilon_{\gamma}}{\sqrt{\epsilon_h}}$, where ${\epsilon_{\gamma}}$ represents the fraction of correctly classified signals, and ${{\epsilon_h}}$ represents the fraction of hadrons classified as signals. Our objective is to correctly identify signals while also minimizing the false positives (background identified as signals). To this extent, our aim is maximizing area under the ROC curve and the quality factor Q, ignoring the fraction of gamma points classified as background. This way we ensure to have better quality results.
#
# The models are going to be trained on the training set with a K-fold. Moreover, a grid search on the hyperparameters is going to be run.

# %% [markdown]
# ## Part 5.1: Perceptron
# The following code is about Perceptron algorithm. Scikit learn library is going to be used. Also, all the training is going to be performed keeping out the feature Alpha.
#
# First, we associate +1 label to gammas and -1 label to hadrons. Then we split train and test set (20% of total data)

# %%
# Alpha has not to be normalized (reset to original value)
X_rescaled['fAlpha'] = original_alpha.copy()

new_Y = []

# gammas are +1    hadrons are -1

for i in range(len(Y)):
    if (Y.iloc[i] == 'g'):
        new_Y.append(1)
    if(Y.iloc[i] == 'h'):
        new_Y.append(-1)
        
Y_df = pd.DataFrame({'category' : new_Y})
data_rescaled_and_indexed = pd.merge(X_rescaled, Y_df,left_index=True, right_index=True)

# divide dataset in 5 parts, taking 1 as test set ( 20 % )
# remove alpha

parts_to_be_split = 5 
train_set, test_set = split_train_test_set( data_rescaled_and_indexed , parts_to_be_split )
train_alpha = train_set['fAlpha']
train_set = train_set.drop('fAlpha',axis=1)
test_alpha = test_set['fAlpha']
test_set = test_set.drop('fAlpha',axis=1)
X_train, Y_train = split_X_Y(train_set)
X_test, Y_test = split_X_Y(test_set)

print('Train set shapes:',np.shape(X_train),np.shape(Y_train))
print('Absolute and relative frequence of points in Training set:')
print(f'Signal: {len(Y_train[Y_train == 1])} points \t {round(len(Y_train[Y_train == 1])/len(Y_train)*100,2)}%')
print(f'Back: {len(Y_train[Y_train == -1])} points \t {round(len(Y_train[Y_train == -1])/len(Y_train)*100,2)}%\n')

print('Test set shapes:',np.shape(X_test),np.shape(Y_test))
print('Absolute and relative frequence of points in Test set:')
print(f'Signal: {len(Y_test[Y_test == 1])} points \t {round(len(Y_test[Y_test == 1])/len(Y_test)*100,2)}%')
print(f'Back: {len(Y_test[Y_test == -1])} points \t {round(len(Y_test[Y_test == -1])/len(Y_test)*100,2)}%\n')
# Out:
# Train set shapes: (15216, 9) (15216,)
# Absolute and relative frequence of points in Training set:
# Signal: 9813 points 	 64.49%
# Back: 5403 points 	 35.51%
#
# Test set shapes: (3803, 9) (3803,)
# Absolute and relative frequence of points in Test set:
# Signal: 2518 points 	 66.21%
# Back: 1285 points 	 33.79%

# %% [markdown]
# The following cell performs the training. The parameters are set at the beginning and the best model criterion is the one that maximizes ROC area in range [0-0.2]

# %%
n_attempts = 10000
limit = 0.2 
best_scores = []
best_f = []
best_t = []
best_score = 0

# K fold definition
K = 5
limit = 0.2 
kf = KFold(n_splits=K, shuffle=True, random_state=42) 

#print('n_iter, score')
for i in range (n_attempts):
    auc_fold = 0
    filtered_auc_fold = 0
    
    state = abs(np.random.normal(size=1))
    state = int(state[0] * 1000000)
    perceptron = Perceptron(alpha=0.01,penalty='l2',max_iter=10000,tol=1e-4,random_state=state,n_iter_no_change=10)
    
    for train_idx, val_idx in kf.split(data_rescaled_and_indexed):  ###gets the index of training and validation set
                
        train_K=data_rescaled_and_indexed.iloc[train_idx]
        valid_K=data_rescaled_and_indexed.iloc[val_idx]
        X_train_K, Y_train_K = split_X_Y(train_K)
        X_valid_K, Y_valid_K = split_X_Y(valid_K)
    
    
        fitted = perceptron.fit(X_train_K,Y_train_K)
    
        decision_values = perceptron.decision_function(X_valid_K)

        fpr, tpr, thresholds = roc_curve(Y_valid_K, decision_values)
    
        # here i filter data to compute roc curve area for fpr in range 0 -> 0.8
        fpr_filtered = fpr[fpr <= limit]
        tpr_filtered = tpr[:len(fpr_filtered)]
    
        auc_filtered_K = np.trapz(tpr_filtered, fpr_filtered)
        auc_K = roc_auc_score(Y_valid_K, decision_values)
        auc_fold += auc_K / K
        filtered_auc_fold += auc_filtered_K / K
    
    # score is better if filtered is better, though saving all 
    if (filtered_auc_fold > best_score):
        best_score = filtered_auc_fold
        best_scores.append(auc_fold)
        #best_f.append(fpr)
        best_fpr = fpr
        best_tpr = tpr
        #best_t.append(tpr)
        best_perceptron = perceptron
        #print(i, auc)

print('Trained',n_attempts,'perceptrons')
print("best AUC-ROC Score:")
print(round(best_scores[len(best_scores)-1],3))
# Out:
# Trained 10000 perceptrons
# best AUC-ROC Score:
# 0.801

# %% [markdown]
# Here we plot the confusion matrix for the best model:

# %%
def normalize_cm(cm):
    norm_cm = np.zeros(shape=(2,2))
    bkg = cm[0,0] + cm[0,1]  # first row is bkg
    sig = cm[1,0] + cm[1,1]  # second row is signal
    norm_cm[0,0] = round(cm[0,0] / bkg,3)
    norm_cm[0,1] = round(cm[0,1] / bkg,3)
    norm_cm[1,0] = round(cm[1,0] / sig,3)
    norm_cm[1,1] = round(cm[1,1] / sig,3)
    
    return norm_cm


def plot_cm(cm,method_name):
    fig = plt.figure()
    im = plt.imshow(cm, cmap='seismic',alpha=0.8, interpolation='nearest')
    plt.xticks([0,1], ['bkg', 'signal'],ha="right",rotation=0,fontsize=12)
    plt.yticks([0,1], ['bkg', 'signal'],ha="right",rotation=0,fontsize=12)
    fmt = '.2f'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            text = plt.text(j, i, format(cm[i, j], fmt),
            ha="center", va="center",
            color="white")
            text.set_path_effects([path_effects.withStroke(linewidth=1.5, foreground='black')])
            
    fig.tight_layout()
    fig.colorbar(im, location = 'right') 

    plt.xlabel('predicted label',fontsize=14)
    plt.ylabel('true label',fontsize=14)

    plt.title(f'{method_name} confusion matrix',fontsize=16)
    plt.show()

# %%
model = best_perceptron
best_perceptron.fit(X_train,Y_train)
Y_pred = model.predict(X_test)

cm = confusion_matrix(Y_test,Y_pred)

# %%
perceptron_cm = normalize_cm(cm)

print('Confusion matrix:')
print(perceptron_cm)
plot_cm(perceptron_cm,method_name='Perceptron')
# Out:
# Confusion matrix:
# [[0.531 0.469]
#  [0.329 0.671]]

# %% [markdown]
# In the end we take the ROC curve and the best Q value (the one closest to the point (0,1)). We save it in a variable that will be used later as confrontation.

# %%
fig = plt.figure(figsize=(8, 6))

fpr_perceptron = best_fpr
tpr_perceptron = best_tpr

Q_perceptron = perceptron_cm[1][1]/ np.sqrt(perceptron_cm[0][1])
print('Perceptron Q value:',round(Q_perceptron,3))

plot_roc(fpr_perceptron,tpr_perceptron,best_scores[len(best_f)-1],"Perceptron","#4466fc");
# Out:
# Perceptron Q value: 0.98

# %% [markdown]
# ## Part 5.2: Logistic Regression (version 3)

# %% [markdown]
# Logistic regression allows to pose a classification problem as a regression problem, where the predicted label is the probability for a sample to belong to a certain class. Thus, in our case the output of the algorithm is the *gammaness*. We can then choose a threshold for the *gammaness* to assign gamma (+1) as the predicted label. The learning problem is to find the sigmoid function
# $\sigma_{\mathbf{w}}(\mathbf{x}) =\frac{1}{1 + e^{-(\mathbf{w}^T \mathbf{x})}}$
# that minimizes the loss:
#
# $$
# \mathcal{L}(\mathbf{y}, \sigma_{\mathbf{w}}(\mathbf{x})) + \lambda||\mathbf{w}||^2
# $$
# where:
# $$
# \mathcal{L}(\mathbf{y}, \sigma_{\mathbf{w}}(\mathbf{x})) = -\sum_{i=1}^{n} \left[ y_i \log(\sigma_{\mathbf{w}}(\mathbf{x}_i)) + (1 - y_i) \log(1 - \sigma_{\mathbf{w}}(\mathbf{x}_i)) \right]$$
# and we use the Tikhonov regularization technique to prevent overfitting.
#
# To find the best hyper-parameter $C=\frac{1}{\lambda}$ for model we choose the usual 0.5 threshold for the *gammaness* and perform a K-fold cross validation, where again we keep as best model the one that maximizes the partial AUC.

# %%
# this function determines the partial area under the curve, up to FPR<=0.2
def partial_auc_at_fpr(y_true, y_pred_proba):
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_proba)
    valid_indices = fpr <= 0.2  # indices where FPR <= 0.2
    partial_fpr = fpr[valid_indices]
    partial_tpr = tpr[valid_indices]
    # check if there are at least 2 points for partial AUC calculation
    if len(partial_fpr) < 2:
        return 0  # return 0 if not enough points to calculate AUC

    partial_auc = auc(partial_fpr, partial_tpr)
    return partial_auc

def full_auc_scorer(y_true, y_pred_proba):
    fpr, tpr, _ = roc_curve(y_true, y_pred_proba)
    return auc(fpr, tpr)

# create scoring function (partial AUC) to implement a grid-search
partial_auc_scorer = make_scorer(partial_auc_at_fpr, greater_is_better=True)

# %%
auc_scorer = make_scorer(full_auc_scorer, greater_is_better=True, response_method='predict') 

# hyper-parameters 
param_grid = {'C': [0.001,0.005,0.01,0.05,0.1,0.5,1,5,10,50,100,500,1000]} # we use Tikhonov regularization: in the loss we add a term proportional to the norm squared of w (C=1/lambda)

# grid search with K-fold validation
K=5

fprs = []
tprs = []
aucs = []
partial_aucs = []
C = []
for c in param_grid['C']:
        auc_value=0
        partial_auc=0
        print(f"Training model with regularization constant c = {c}")
        C.append(c)
        for i in range(K):
            train_K, valid_K = split_train_test_set(train_set,K)
            X_train_K, Y_train_K = split_X_Y(train_K)
            X_valid_K, Y_valid_K = split_X_Y(valid_K)
            model= LogisticRegression(penalty='l2',tol=1e-5,C=c,solver='lbfgs',max_iter=int(1e6)) # 'lbfgs' approximates up to the the second derivative of the loss function to optimize the coefficients, best for large datasets 
            model.fit(X_train_K,Y_train_K)
                    
            y_pred_proba = model.predict_proba(X_valid_K)[:, 1]  
            fpr, tpr, _ = roc_curve(Y_valid_K, y_pred_proba)
            fprs.append(fpr)
            tprs.append(tpr)
            auc_value_k = auc(fpr, tpr)
            # keep fpr less than 0.2 (if not able to find it, partial auc is set to zero)
            partial_fpr = fpr[fpr <= 0.2]
            if (len(partial_fpr) < 2 ):
                partial_auc=0
            else:
                partial_tpr = tpr[:len(partial_fpr)]
                partial_auc_k = auc(partial_fpr, partial_tpr)
            partial_auc += partial_auc_k/K
            auc_value += auc_value_k/K
        print('Partial AUC:', partial_auc)
        partial_aucs.append(partial_auc)
        print('AUC:', auc_value,'\n')
        aucs.append(auc_value)
# Out:
# Training model with regularization constant c = 0.001
# Partial AUC: 0.043533625986884955
# AUC: 0.7086195125688138
#
# Training model with regularization constant c = 0.005
# Partial AUC: 0.04378700409284516
# AUC: 0.7101440943092829
#
# Training model with regularization constant c = 0.01
# Partial AUC: 0.04449476728603617
# AUC: 0.7223575468188852
#
# Training model with regularization constant c = 0.05
# Partial AUC: 0.045206391570445204
# AUC: 0.7201472607041199
#
# Training model with regularization constant c = 0.1
# Partial AUC: 0.04299233766282897
# AUC: 0.7143541550299713
#
# Training model with regularization constant c = 0.5
# Partial AUC: 0.04077549640588312
# AUC: 0.7093515008282184
#
# Training model with regularization constant c = 1
# Partial AUC: 0.04366948390535941
# AUC: 0.715816345148492
#
# Training model with regularization constant c = 5
# Partial AUC: 0.04441301272232045
# AUC: 0.7185069493179439
#
# Training model with regularization constant c = 10
# Partial AUC: 0.04326711332334762
# AUC: 0.7140420337824707
#
# Training model with regularization constant c = 50
# Partial AUC: 0.043532318014087266
# AUC: 0.7174172998990621
#
# Training model with regularization constant c = 100
# Partial AUC: 0.04479594102246598
# AUC: 0.7196077552847733
#
# Training model with regularization constant c = 500
# Partial AUC: 0.04317534662731683
# AUC: 0.7158904036616037
#
# Training model with regularization constant c = 1000
# Partial AUC: 0.04376375482874077
# AUC: 0.7161396309380447

# %%
best_partial_auc = np.max(np.array(partial_aucs))
best_auc= np.max(np.array(aucs))
best_index = np.where(partial_aucs==best_partial_auc)[0]
print('Best model with regularization constant c=',C[best_index[0]])
print('Best partial AUC (validation set):', best_partial_auc)
print('AUC of best model (validation set):', best_auc,'\n')

best_model = LogisticRegression(penalty='l2', C= C[best_index[0]],solver='lbfgs',max_iter=300)
best_model.fit(X_train,Y_train) # retrain the best
y_pred_proba_test = model.predict_proba(X_test)[:, 1]  
fpr_test, tpr_test, _ = roc_curve(Y_test, y_pred_proba_test)
auc_test= auc(fpr_test,tpr_test)

partial_fpr_test = fpr_test[fpr_test <= 0.2]
if (len(partial_fpr_test)<2):
    partial_auc_test=0
else:
    partial_tpr_test = tpr_test[:len(partial_fpr_test)]
    partial_auc_test = auc(partial_fpr_test, partial_tpr_test)
print('Best partial AUC (test set):', round(partial_auc_test,3))
print('AUC of best model (test set):', round(auc_test,3))
# Out:
# Best model with regularization constant c= 0.05
# Best partial AUC (validation set): 0.045206391570445204
# AUC of best model (validation set): 0.7223575468188852
#
# Best partial AUC (test set): 0.043
# AUC of best model (test set): 0.71

# %%
Y_pred = best_model.predict(X_test)
cm = confusion_matrix(Y_test,Y_pred)
log_cm = normalize_cm(cm)

print('Confusion matrix:')
print(log_cm)
plot_cm(log_cm,method_name='Logistic Regression')
# Out:
# Confusion matrix:
# [[0.347 0.653]
#  [0.053 0.947]]

# %% [markdown]
# Here we plot the best model for ROC curve

# %%
fpr_log = fpr_test
tpr_log = tpr_test
Q_log = log_cm[1][1]/ np.sqrt(log_cm[0][1])
print('Q value of best model:',Q_log)

plot_roc(fpr_log,tpr_log,auc_test,'Logistic Regression','#d173b8')
# Out:
# Q value of best model: 1.1719076475799426

# %% [markdown]
# ## Part 5.3: SVM
# In this part the same dataset is analyzed with soft SVM. Different kernels are tried (linear,poly with deg 3,rbf and sigmoid), as well as different values for parameters such as nu and gamma

# %%
alphaCol = data_rescaled_and_indexed['fAlpha'] 
data_rescaled_and_indexed = data_rescaled_and_indexed.drop('fAlpha',axis = 1)
print(np.shape(data_rescaled_and_indexed))
# Out:
# (19019, 10)

# %%
# list with all possible kernels (poly uses deg = 3 as standard value)
kernels = ['linear','poly','rbf','sigmoid']


# list with all nu values (upper bound on fraction of margin errors)
nus = [ 0.5 , 0.1 , 0.05 , 0.01 ]

# list with all gamma values (by default is 1/(n_features*X.var()) )
gammas = [ 0.1, 0.01, 0.001, 0.0001 ]

best_auc_score = 0

# tolerance for stopping criteria (default is 1e-3) (default max_iter is inf)
tolerance = 1e-6
max_iter = int(2e4)

# K fold definition
K = 5
limit = 0.2 
kf = KFold(n_splits=K, shuffle=True, random_state=42) 
kFoldInfo = 0

start_time = time()


for kernel_type in kernels:
    for nu in nus:
        for gamma in gammas:
            print(f'training SVM with {kernel_type} kernel...')
            partial_auc = 0
            auc_value = 0
            for train_idx, val_idx in kf.split(data_rescaled_and_indexed):  ###gets the index of training and validation set
                
                train_K=data_rescaled_and_indexed.iloc[train_idx]
                valid_K=data_rescaled_and_indexed.iloc[val_idx]
                X_train_K, Y_train_K = split_X_Y(train_K)
                X_valid_K, Y_valid_K = split_X_Y(valid_K)
                
                if kFoldInfo == 0:
                    print("Train fold size:",np.shape(X_train_K),"\t Test fold size:",np.shape(X_valid_K))
                    KFoldInfo = 1
                
                clf = make_pipeline(StandardScaler(), NuSVC(nu=nu,kernel=kernel_type,gamma=gamma,probability=True,tol=tolerance,max_iter=max_iter),verbose=False)
    
                fitted = clf.fit(X_train_K, Y_train_K)
                pred = clf.predict(X_valid_K)
                errors = np.sum(pred != Y_valid_K) / len(Y_valid_K)
                
                pred_prob = clf.predict_proba(X_valid_K)[:, 1]
                fpr, tpr, thresholds = roc_curve(Y_valid_K, pred_prob)
                
                auc_value_k = auc(fpr, tpr)
                fpr_filtered = fpr[fpr <= limit]

                if (len(fpr_filtered) < 2 ):
                    partial_auc=0
                else:
                    tpr_filtered = tpr[:len(fpr_filtered)]
                    partial_auc_k = np.trapz(fpr_filtered, tpr_filtered)
                partial_auc += partial_auc_k/K
                auc_value += auc_value_k/K                 
            if(partial_auc > best_auc_score):
                best_auc_score = partial_auc
                best_model = clf
                best_tpr = tpr
                best_fpr = fpr
                best_auc = auc_value
                best_kernel = kernel_type
                best_nu = nu
                best_gamma = gamma
                print(partial_auc.round(3),best_auc.round(3), kernel_type, nu, gamma)
            print('elapsed time:',round(time()-start_time,3),'s')
            start_time = time()

print('best results are for')
print('kernel:',best_kernel,'nu:',best_nu,'gamma:',best_gamma,'with auc:',best_auc)
# Out:
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# 0.02 0.504 linear 0.5 0.1
# elapsed time: 178.674 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# 0.025 0.548 linear 0.5 0.01
# elapsed time: 151.703 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# 0.026 0.559 linear 0.5 0.001
# elapsed time: 150.607 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# 0.026 0.557 linear 0.5 0.0001
# elapsed time: 147.174 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 61.214 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 60.582 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# 0.026 0.587 linear 0.1 0.001
# elapsed time: 72.562 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 66.372 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 54.547 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 56.039 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 58.425 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 59.045 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 45.337 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 44.249 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 46.122 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 45.203 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# 0.054 0.793 poly 0.5 0.1
# elapsed time: 198.024 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# 0.055 0.793 poly 0.5 0.01
# elapsed time: 210.675 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 174.415 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 103.432 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 75.049 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 72.205 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 27.14 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 18.048 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 61.47 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 59.995 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 13.931 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 8.834 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 48.206 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 46.655 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 3.978 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 2.065 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# 0.058 0.843 rbf 0.5 0.1
# elapsed time: 222.177 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 203.323 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 223.941 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 224.092 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 97.424 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 84.716 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 77.03 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 93.916 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 103.771 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 110.227 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 82.646 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 82.397 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 88.823 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 59.048 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 52.453 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 56.18 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 384.573 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 313.437 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 245.993 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 198.918 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 78.943 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 77.0 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 89.838 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 47.546 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 41.647 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 43.374 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 67.035 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 22.232 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 9.062 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 8.452 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 33.0 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 3.566 s
# best results are for
# kernel: rbf nu: 0.5 gamma: 0.1 with auc: 0.8425699775187071

# %% [markdown]
# Here we have the confusion matrix

# %%
best_pred = best_model.predict(X_test)
cm = confusion_matrix(Y_test,best_pred)
SVM_cm = normalize_cm(cm)

print('Confusion matrix:')
print(SVM_cm)
plot_cm(SVM_cm,method_name='SVM')
# Out:
# Confusion matrix:
# [[0.518 0.482]
#  [0.031 0.969]]

# %% [markdown]
# The best curve is then plotted and saved

# %%
tpr_SVM = best_tpr
fpr_SVM = best_fpr
Q_SVM = get_best_Q(fpr_SVM,tpr_SVM)
Q_SVM = SVM_cm[1][1]/ np.sqrt(SVM_cm[0][1])


print('best SVM Q value:',Q_SVM)

plot_roc(fpr_SVM,tpr_SVM,best_auc,"SVM","darkorange")
# Out:
# best SVM Q value: 1.3957262866407283

# %% [markdown]
# ## Part 5.4: Random Forest
# Here we are going to implement a Random Forest classification algorithm. A Random Forest is composed of different decision tree predictors. For each tree, at each iteration, the data are split into two branches according to a threshold value for one of the features. At each split, the best feature and the best threshold value are chosen by minimizing the entropy function
# 𝐻 given by:
# $$
# \displaystyle H = - \sum_{i=+1,-1} f_i \log_2(f_i)
# $$
# where $f_i$ is the fraction of points of class $i=+1,-1$ in the training set. The splitting continues until either a maximum depth for the tree is reached, in which case the most frequent class of the branch is assigned to all points, or the points of the branch all belong to the same class (in this case the branch is called a leaf). Different trees are built by randomly drawing data with replacement from the test set, applying the algorithm to each tree. The final label for a point is chosen based on a majority vote of the trees results.
#
# The hyper-parameters of the model are the **number of trees** and the **maximum depth** of the trees. We are going to implement a K-fold cross validation to choose as best hyper-parameters the ones that maximize the area under the ROC curve of the classifier. To build the ROC curve we need to estimate the probability for the points to belong to a certain class. This can be done because each tree, at the last decision step, assigns a class label based on the majority class of the training samples that reached that final leaf node, but also keeps track of the proportion of the classes in that leaf node. For example, suppose a test point ends up in a leaf node where, out of 100 training samples that ended up there, 80 belonged to class 1 and 20 belonged to class -1. The probability of the point belonging to class 1 would be 0.8, while the probability of it belonging to class -1 would be 0.2.\
#
# We will use the class `RandomForestClassifier` from `scikit-learn` to implement and train the Forest and to predict the labels with their probabilities.
#
#
# \
# **DA METTERE QUANDO SI INTRODUCE IL CONCETTO DI ROC CURVE?**
# The ROC curve plots the True Positive Rate (TPR), i.e: the fraction of actual gamma samples correctly identified as gamma, versus the False Positive Rate, i.e: the fraction of actual hadrons incorrectly classified as gamma by the model. To do so, it's necessary to estimate a probability for the predicted class, not just to assign the predicted label. Imposing different threshold values on the probability for the acceptance of an event as either gamma or hadron, we can obtain the ROC curve.   \
# \

# %%
from time import time

num_trees= np.arange(40,300,10)
max_depth= np.arange(10,40,2)
accuracies=[]
roc_areas=[]
best_area=0
best_acc=0
best_model= [] # stores best number of trees and best max depth
partial_aucs = []

start_time = time()

max_iter = len(num_trees) * len(max_depth)
iteration = 0

K = 5
kf = KFold(n_splits=K, shuffle=True, random_state=42) 

for tree in num_trees:
    for depth in max_depth:
        ############accuracies?
        partial_auc = 0
        auc_value = 0
        accuracy = 0
        for i, (train_index, test_index) in enumerate(kf.split(X)):
            print(f"  Fold n. {i}")
            train_K=data_rescaled_and_indexed.iloc[train_idx]
            valid_K = data_rescaled_and_indexed.iloc[test_index]

            X_train_K, Y_train_K = split_X_Y(train_K)
            X_valid_K, Y_valid_K = split_X_Y(valid_K)
            forest = RandomForestClassifier(n_estimators=tree,  # number of trees
                                           max_depth= depth, 
                                           max_features=X_train.shape[1],   # number of features for each split (random subset)
                                           bootstrap=True,    # bagging (sampling with replacement)
                                           max_samples=1.0,   # percentage of samples to use for each tree (100% of data)
                                           random_state=10,
                                           n_jobs=-1)
            # train each model, predict labels and probability of each label
            forest.fit(X_train_K, Y_train_K)
            Y_pred = forest.predict(X_valid_K)
            y_pred_prob = forest.predict_proba(X_valid_K)[:, 1] # probability for the validation points to belong to class +1 or -1
            # accuracy on validation set
            accuracy_k = accuracy_score(Y_valid_K, Y_pred)
            iteration +=1 
            print(f'elapsed time: {round(time()-start_time,2)}s, done {iteration} out of {max_iter*K}')
            print('Number of trees:',tree,', Maximum depth',depth,':') 
            print('Accuracy:',accuracy_k)
            # false positive rates and the true positive rates for different threshold values 
            fpr, tpr, thresholds = roc_curve(Y_valid_K, y_pred_prob)

            # area under the ROC curve on validation set 
            roc_auc_k = auc(fpr, tpr)
            roc_areas.append(roc_auc_k)
            '''if(roc_auc>best_area):
                best_area= roc_auc
                best_acc= accuracy
                best_model=[tree,depth]
                '''
            partial_fpr = fpr[fpr <= 0.2]
            if (len(partial_fpr) < 2 ):
                partial_auc = 0
            else:
                partial_tpr = tpr[:len(partial_fpr)]
                partial_auc_k = auc(partial_fpr, partial_tpr)
            partial_auc += partial_auc_k/K
            auc_value += roc_auc_k/K
        
        partial_aucs.append(partial_auc)
        if(partial_auc>best_area):
            best_area= partial_auc
            best_total_auc = auc_value
            best_acc= accuracy
            best_model=[tree,depth]
        print('\033[91mArea under ROC curve:',round(auc_value,3),'Selected area:',round(partial_auc,3),'\033[0m')
        print('\n')
        
print('Best number of trees:', best_model[0],'\n')
print('Best maximum depth:', best_model[1],'\n')
print('Area under ROC curve of best model:',best_area)
# Out:
#   Fold n. 0
# elapsed time: 1.39s, done 1 out of 1950
# Number of trees: 40 , Maximum depth 10 :
# Accuracy: 0.8554153522607781
#   Fold n. 1
# elapsed time: 2.72s, done 2 out of 1950
# Number of trees: 40 , Maximum depth 10 :
# Accuracy: 0.8509463722397477
#   Fold n. 2
# elapsed time: 4.01s, done 3 out of 1950
# Number of trees: 40 , Maximum depth 10 :
# Accuracy: 0.861198738170347
#   Fold n. 3
# elapsed time: 5.25s, done 4 out of 1950
# Number of trees: 40 , Maximum depth 10 :
# Accuracy: 0.8470031545741324
#   Fold n. 4
# elapsed time: 6.76s, done 5 out of 1950
# Number of trees: 40 , Maximum depth 10 :
# Accuracy: 0.8146200368130423
# Area under ROC curve: 0.894 Selected area: 0.111
#
#
#   Fold n. 0
# elapsed time: 8.19s, done 6 out of 1950
# Number of trees: 40 , Maximum depth 12 :
# Accuracy: 0.8824921135646687
#   Fold n. 1
# elapsed time: 9.62s, done 7 out of 1950
# Number of trees: 40 , Maximum depth 12 :
# Accuracy: 0.8777602523659306
#   Fold n. 2
# elapsed time: 11.21s, done 8 out of 1950
# Number of trees: 40 , Maximum depth 12 :
# Accuracy: 0.8853838065194533
#   Fold n. 3
# elapsed time: 12.67s, done 9 out of 1950
# Number of trees: 40 , Maximum depth 12 :
# Accuracy: 0.8782860147213459
#   Fold n. 4
# elapsed time: 14.07s, done 10 out of 1950
# Number of trees: 40 , Maximum depth 12 :
# Accuracy: 0.8248750986063634
# Area under ROC curve: 0.922 Selected area: 0.131
#
#
#   Fold n. 0
# elapsed time: 15.68s, done 11 out of 1950
# Number of trees: 40 , Maximum depth 14 :
# Accuracy: 0.905099894847529
#   Fold n. 1
# elapsed time: 17.23s, done 12 out of 1950
# Number of trees: 40 , Maximum depth 14 :
# Accuracy: 0.9053627760252366
#   Fold n. 2
# elapsed time: 19.01s, done 13 out of 1950
# Number of trees: 40 , Maximum depth 14 :
# Accuracy: 0.9077287066246057
#   Fold n. 3
# elapsed time: 20.63s, done 14 out of 1950
# Number of trees: 40 , Maximum depth 14 :
# Accuracy: 0.9037854889589906
#   Fold n. 4
# elapsed time: 22.3s, done 15 out of 1950
# Number of trees: 40 , Maximum depth 14 :
# Accuracy: 0.8311859058637917
# Area under ROC curve: 0.943 Selected area: 0.146
#
#
#   Fold n. 0
# elapsed time: 24.31s, done 16 out of 1950
# Number of trees: 40 , Maximum depth 16 :
# Accuracy: 0.9256046267087277
#   Fold n. 1
# elapsed time: 26.42s, done 17 out of 1950
# Number of trees: 40 , Maximum depth 16 :
# Accuracy: 0.9292849631966351
#   Fold n. 2
# elapsed time: 28.17s, done 18 out of 1950
# Number of trees: 40 , Maximum depth 16 :
# Accuracy: 0.9300736067297581
#   Fold n. 3
# elapsed time: 30.29s, done 19 out of 1950
# Number of trees: 40 , Maximum depth 16 :
# Accuracy: 0.9263932702418507
#   Fold n. 4
# elapsed time: 32.25s, done 20 out of 1950
# Number of trees: 40 , Maximum depth 16 :
# Accuracy: 0.8327636076781488
# Area under ROC curve: 0.958 Selected area: 0.155
#
#
#   Fold n. 0
# elapsed time: 34.12s, done 21 out of 1950
# Number of trees: 40 , Maximum depth 18 :
# Accuracy: 0.9413774973711883
#   Fold n. 1
# elapsed time: 36.25s, done 22 out of 1950
# Number of trees: 40 , Maximum depth 18 :
# Accuracy: 0.9437434279705573
#   Fold n. 2
# elapsed time: 38.25s, done 23 out of 1950
# Number of trees: 40 , Maximum depth 18 :
# Accuracy: 0.9487381703470031
#   Fold n. 3
# elapsed time: 40.25s, done 24 out of 1950
# Number of trees: 40 , Maximum depth 18 :
# Accuracy: 0.9408517350157729
#   Fold n. 4
# elapsed time: 42.27s, done 25 out of 1950
# Number of trees: 40 , Maximum depth 18 :
# Accuracy: 0.8340783591901131
# Area under ROC curve: 0.967 Selected area: 0.14
#
#
#   Fold n. 0
# elapsed time: 44.3s, done 26 out of 1950
# Number of trees: 40 , Maximum depth 20 :
# Accuracy: 0.9576761303890642
#   Fold n. 1
# elapsed time: 46.31s, done 27 out of 1950
# Number of trees: 40 , Maximum depth 20 :
# Accuracy: 0.9568874868559412
#   Fold n. 2
# elapsed time: 48.35s, done 28 out of 1950
# Number of trees: 40 , Maximum depth 20 :
# Accuracy: 0.961882229232387
#   Fold n. 3
# elapsed time: 50.42s, done 29 out of 1950
# Number of trees: 40 , Maximum depth 20 :
# Accuracy: 0.9558359621451105
#   Fold n. 4
# elapsed time: 52.5s, done 30 out of 1950
# Number of trees: 40 , Maximum depth 20 :
# Accuracy: 0.8346042597948987
# Area under ROC curve: 0.972 Selected area: 0.163
#
#
#   Fold n. 0
# elapsed time: 54.6s, done 31 out of 1950
# Number of trees: 40 , Maximum depth 22 :
# Accuracy: 0.9697686645636172
#   Fold n. 1
# elapsed time: 56.9s, done 32 out of 1950
# Number of trees: 40 , Maximum depth 22 :
# Accuracy: 0.9692429022082019
#   Fold n. 2
# elapsed time: 59.25s, done 33 out of 1950
# Number of trees: 40 , Maximum depth 22 :
# Accuracy: 0.9752891692954785
#   Fold n. 3
# elapsed time: 61.55s, done 34 out of 1950
# Number of trees: 40 , Maximum depth 22 :
# Accuracy: 0.9681913774973712
#   Fold n. 4
# elapsed time: 63.92s, done 35 out of 1950
# Number of trees: 40 , Maximum depth 22 :
# Accuracy: 0.8340783591901131
# Area under ROC curve: 0.975 Selected area: 0.171
#
#
#   Fold n. 0
# elapsed time: 66.28s, done 36 out of 1950
# Number of trees: 40 , Maximum depth 24 :
# Accuracy: 0.982912723449001
#   Fold n. 1
# elapsed time: 68.8s, done 37 out of 1950
# Number of trees: 40 , Maximum depth 24 :
# Accuracy: 0.9810725552050473
#   Fold n. 2
# elapsed time: 71.25s, done 38 out of 1950
# Number of trees: 40 , Maximum depth 24 :
# Accuracy: 0.9837013669821241
#   Fold n. 3
# elapsed time: 73.83s, done 39 out of 1950
# Number of trees: 40 , Maximum depth 24 :
# Accuracy: 0.979758149316509
#   Fold n. 4
# elapsed time: 76.34s, done 40 out of 1950
# Number of trees: 40 , Maximum depth 24 :
# Accuracy: 0.8330265579805417
# Area under ROC curve: 0.975 Selected area: 0.174
#
#
#   Fold n. 0
# elapsed time: 78.49s, done 41 out of 1950
# Number of trees: 40 , Maximum depth 26 :
# Accuracy: 0.9889589905362776
#   Fold n. 1
# elapsed time: 80.67s, done 42 out of 1950
# Number of trees: 40 , Maximum depth 26 :
# Accuracy: 0.9871188222923238
#   Fold n. 2
# elapsed time: 83.0s, done 43 out of 1950
# Number of trees: 40 , Maximum depth 26 :
# Accuracy: 0.9921135646687698
#   Fold n. 3
# elapsed time: 85.33s, done 44 out of 1950
# Number of trees: 40 , Maximum depth 26 :
# Accuracy: 0.9884332281808622
#   Fold n. 4
# elapsed time: 87.59s, done 45 out of 1950
# Number of trees: 40 , Maximum depth 26 :
# Accuracy: 0.835919011306863
# Area under ROC curve: 0.976 Selected area: 0.177
#
#
#   Fold n. 0
# elapsed time: 89.9s, done 46 out of 1950
# Number of trees: 40 , Maximum depth 28 :
# Accuracy: 0.9952681388012619
#   Fold n. 1
# elapsed time: 92.16s, done 47 out of 1950
# Number of trees: 40 , Maximum depth 28 :
# Accuracy: 0.9913249211356467
#   Fold n. 2
# elapsed time: 94.51s, done 48 out of 1950
# Number of trees: 40 , Maximum depth 28 :
# Accuracy: 0.9960567823343849
#   Fold n. 3
# elapsed time: 96.94s, done 49 out of 1950
# Number of trees: 40 , Maximum depth 28 :
# Accuracy: 0.9942166140904312
#   Fold n. 4
# elapsed time: 99.02s, done 50 out of 1950
# Number of trees: 40 , Maximum depth 28 :
# Accuracy: 0.8406521167499342
# Area under ROC curve: 0.976 Selected area: 0.18
#
#
#   Fold n. 0
# elapsed time: 101.26s, done 51 out of 1950
# Number of trees: 40 , Maximum depth 30 :
# Accuracy: 0.9971083070452156
#   Fold n. 1
# elapsed time: 103.51s, done 52 out of 1950
# Number of trees: 40 , Maximum depth 30 :
# Accuracy: 0.9963196635120926
#   Fold n. 2
# elapsed time: 106.1s, done 53 out of 1950
# Number of trees: 40 , Maximum depth 30 :
# Accuracy: 0.9978969505783386
#   Fold n. 3
# elapsed time: 108.48s, done 54 out of 1950
# Number of trees: 40 , Maximum depth 30 :
# Accuracy: 0.998422712933754
#   Fold n. 4
# elapsed time: 110.95s, done 55 out of 1950
# Number of trees: 40 , Maximum depth 30 :
# Accuracy: 0.8367078622140416
# Area under ROC curve: 0.976 Selected area: 0.173
#
#
#   Fold n. 0
# elapsed time: 113.41s, done 56 out of 1950
# Number of trees: 40 , Maximum depth 32 :
# Accuracy: 0.9986855941114616
#   Fold n. 1
# elapsed time: 115.47s, done 57 out of 1950
# Number of trees: 40 , Maximum depth 32 :
# Accuracy: 0.9989484752891693
#   Fold n. 2
# elapsed time: 117.56s, done 58 out of 1950
# Number of trees: 40 , Maximum depth 32 :
# Accuracy: 0.9989484752891693
#   Fold n. 3
# elapsed time: 119.67s, done 59 out of 1950
# Number of trees: 40 , Maximum depth 32 :
# Accuracy: 0.9989484752891693
#   Fold n. 4
# elapsed time: 122.26s, done 60 out of 1950
# Number of trees: 40 , Maximum depth 32 :
# Accuracy: 0.8364449119116487
# Area under ROC curve: 0.976 Selected area: 0.17
#
#
#   Fold n. 0
# elapsed time: 124.65s, done 61 out of 1950
# Number of trees: 40 , Maximum depth 34 :
# Accuracy: 0.9994742376445847
#   Fold n. 1
# elapsed time: 126.98s, done 62 out of 1950
# Number of trees: 40 , Maximum depth 34 :
# Accuracy: 0.9994742376445847
#   Fold n. 2
# elapsed time: 129.52s, done 63 out of 1950
# Number of trees: 40 , Maximum depth 34 :
# Accuracy: 0.9989484752891693
#   Fold n. 3
# elapsed time: 132.09s, done 64 out of 1950
# Number of trees: 40 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 134.55s, done 65 out of 1950
# Number of trees: 40 , Maximum depth 34 :
# Accuracy: 0.8348672100972916
# Area under ROC curve: 0.976 Selected area: 0.166
#
#
#   Fold n. 0
# elapsed time: 136.83s, done 66 out of 1950
# Number of trees: 40 , Maximum depth 36 :
# Accuracy: 0.9994742376445847
#   Fold n. 1
# elapsed time: 139.39s, done 67 out of 1950
# Number of trees: 40 , Maximum depth 36 :
# Accuracy: 0.9994742376445847
#   Fold n. 2
# elapsed time: 141.86s, done 68 out of 1950
# Number of trees: 40 , Maximum depth 36 :
# Accuracy: 0.9989484752891693
#   Fold n. 3
# elapsed time: 144.19s, done 69 out of 1950
# Number of trees: 40 , Maximum depth 36 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 146.53s, done 70 out of 1950
# Number of trees: 40 , Maximum depth 36 :
# Accuracy: 0.8367078622140416
# Area under ROC curve: 0.976 Selected area: 0.163
#
#
#   Fold n. 0
# elapsed time: 148.97s, done 71 out of 1950
# Number of trees: 40 , Maximum depth 38 :
# Accuracy: 0.9994742376445847
#   Fold n. 1
# elapsed time: 151.57s, done 72 out of 1950
# Number of trees: 40 , Maximum depth 38 :
# Accuracy: 0.9994742376445847
#   Fold n. 2
# elapsed time: 153.89s, done 73 out of 1950
# Number of trees: 40 , Maximum depth 38 :
# Accuracy: 0.9989484752891693
#   Fold n. 3
# elapsed time: 156.14s, done 74 out of 1950
# Number of trees: 40 , Maximum depth 38 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 158.59s, done 75 out of 1950
# Number of trees: 40 , Maximum depth 38 :
# Accuracy: 0.835919011306863
# Area under ROC curve: 0.976 Selected area: 0.164
#
#
#   Fold n. 0
# elapsed time: 160.35s, done 76 out of 1950
# Number of trees: 50 , Maximum depth 10 :
# Accuracy: 0.8551524710830705
#   Fold n. 1
# elapsed time: 162.12s, done 77 out of 1950
# Number of trees: 50 , Maximum depth 10 :
# Accuracy: 0.8533123028391167
#   Fold n. 2
# elapsed time: 163.79s, done 78 out of 1950
# Number of trees: 50 , Maximum depth 10 :
# Accuracy: 0.86198738170347
#   Fold n. 3
# elapsed time: 165.84s, done 79 out of 1950
# Number of trees: 50 , Maximum depth 10 :
# Accuracy: 0.8467402733964248
#   Fold n. 4
# elapsed time: 167.63s, done 80 out of 1950
# Number of trees: 50 , Maximum depth 10 :
# Accuracy: 0.815145937417828
# Area under ROC curve: 0.895 Selected area: 0.112
#
#
#   Fold n. 0
# elapsed time: 169.69s, done 81 out of 1950
# Number of trees: 50 , Maximum depth 12 :
# Accuracy: 0.8830178759200841
#   Fold n. 1
# elapsed time: 171.76s, done 82 out of 1950
# Number of trees: 50 , Maximum depth 12 :
# Accuracy: 0.8759200841219769
#   Fold n. 2
# elapsed time: 173.83s, done 83 out of 1950
# Number of trees: 50 , Maximum depth 12 :
# Accuracy: 0.8835436382754994
#   Fold n. 3
# elapsed time: 176.01s, done 84 out of 1950
# Number of trees: 50 , Maximum depth 12 :
# Accuracy: 0.8785488958990536
#   Fold n. 4
# elapsed time: 178.06s, done 85 out of 1950
# Number of trees: 50 , Maximum depth 12 :
# Accuracy: 0.8261898501183277
# Area under ROC curve: 0.923 Selected area: 0.131
#
#
#   Fold n. 0
# elapsed time: 180.1s, done 86 out of 1950
# Number of trees: 50 , Maximum depth 14 :
# Accuracy: 0.9056256572029443
#   Fold n. 1
# elapsed time: 182.15s, done 87 out of 1950
# Number of trees: 50 , Maximum depth 14 :
# Accuracy: 0.908254468980021
#   Fold n. 2
# elapsed time: 184.3s, done 88 out of 1950
# Number of trees: 50 , Maximum depth 14 :
# Accuracy: 0.9095688748685594
#   Fold n. 3
# elapsed time: 186.39s, done 89 out of 1950
# Number of trees: 50 , Maximum depth 14 :
# Accuracy: 0.9045741324921136
#   Fold n. 4
# elapsed time: 188.47s, done 90 out of 1950
# Number of trees: 50 , Maximum depth 14 :
# Accuracy: 0.8311859058637917
# Area under ROC curve: 0.944 Selected area: 0.149
#
#
#   Fold n. 0
# elapsed time: 190.64s, done 91 out of 1950
# Number of trees: 50 , Maximum depth 16 :
# Accuracy: 0.924553101997897
#   Fold n. 1
# elapsed time: 193.13s, done 92 out of 1950
# Number of trees: 50 , Maximum depth 16 :
# Accuracy: 0.9290220820189274
#   Fold n. 2
# elapsed time: 195.6s, done 93 out of 1950
# Number of trees: 50 , Maximum depth 16 :
# Accuracy: 0.9319137749737119
#   Fold n. 3
# elapsed time: 198.0s, done 94 out of 1950
# Number of trees: 50 , Maximum depth 16 :
# Accuracy: 0.9250788643533123
#   Fold n. 4
# elapsed time: 200.22s, done 95 out of 1950
# Number of trees: 50 , Maximum depth 16 :
# Accuracy: 0.8332895082829346
# Area under ROC curve: 0.958 Selected area: 0.152
#
#
#   Fold n. 0
# elapsed time: 202.81s, done 96 out of 1950
# Number of trees: 50 , Maximum depth 18 :
# Accuracy: 0.9421661409043113
#   Fold n. 1
# elapsed time: 205.59s, done 97 out of 1950
# Number of trees: 50 , Maximum depth 18 :
# Accuracy: 0.9453207150368034
#   Fold n. 2
# elapsed time: 208.4s, done 98 out of 1950
# Number of trees: 50 , Maximum depth 18 :
# Accuracy: 0.9471608832807571
#   Fold n. 3
# elapsed time: 210.98s, done 99 out of 1950
# Number of trees: 50 , Maximum depth 18 :
# Accuracy: 0.943217665615142
#   Fold n. 4
# elapsed time: 213.51s, done 100 out of 1950
# Number of trees: 50 , Maximum depth 18 :
# Accuracy: 0.8351301603996845
# Area under ROC curve: 0.967 Selected area: 0.145
#
#
#   Fold n. 0
# elapsed time: 216.2s, done 101 out of 1950
# Number of trees: 50 , Maximum depth 20 :
# Accuracy: 0.9582018927444795
#   Fold n. 1
# elapsed time: 218.79s, done 102 out of 1950
# Number of trees: 50 , Maximum depth 20 :
# Accuracy: 0.9584647739221872
#   Fold n. 2
# elapsed time: 221.25s, done 103 out of 1950
# Number of trees: 50 , Maximum depth 20 :
# Accuracy: 0.9639852786540484
#   Fold n. 3
# elapsed time: 223.79s, done 104 out of 1950
# Number of trees: 50 , Maximum depth 20 :
# Accuracy: 0.9584647739221872
#   Fold n. 4
# elapsed time: 226.28s, done 105 out of 1950
# Number of trees: 50 , Maximum depth 20 :
# Accuracy: 0.8351301603996845
# Area under ROC curve: 0.972 Selected area: 0.124
#
#
#   Fold n. 0
# elapsed time: 228.87s, done 106 out of 1950
# Number of trees: 50 , Maximum depth 22 :
# Accuracy: 0.9692429022082019
#   Fold n. 1
# elapsed time: 231.56s, done 107 out of 1950
# Number of trees: 50 , Maximum depth 22 :
# Accuracy: 0.9708201892744479
#   Fold n. 2
# elapsed time: 234.21s, done 108 out of 1950
# Number of trees: 50 , Maximum depth 22 :
# Accuracy: 0.9747634069400631
#   Fold n. 3
# elapsed time: 236.86s, done 109 out of 1950
# Number of trees: 50 , Maximum depth 22 :
# Accuracy: 0.9681913774973712
#   Fold n. 4
# elapsed time: 239.68s, done 110 out of 1950
# Number of trees: 50 , Maximum depth 22 :
# Accuracy: 0.8361819616092558
# Area under ROC curve: 0.975 Selected area: 0.172
#
#
#   Fold n. 0
# elapsed time: 242.69s, done 111 out of 1950
# Number of trees: 50 , Maximum depth 24 :
# Accuracy: 0.9818611987381703
#   Fold n. 1
# elapsed time: 245.3s, done 112 out of 1950
# Number of trees: 50 , Maximum depth 24 :
# Accuracy: 0.9826498422712934
#   Fold n. 2
# elapsed time: 248.0s, done 113 out of 1950
# Number of trees: 50 , Maximum depth 24 :
# Accuracy: 0.9850157728706624
#   Fold n. 3
# elapsed time: 250.57s, done 114 out of 1950
# Number of trees: 50 , Maximum depth 24 :
# Accuracy: 0.9800210304942166
#   Fold n. 4
# elapsed time: 253.07s, done 115 out of 1950
# Number of trees: 50 , Maximum depth 24 :
# Accuracy: 0.8374967131212201
# Area under ROC curve: 0.975 Selected area: 0.174
#
#
#   Fold n. 0
# elapsed time: 255.68s, done 116 out of 1950
# Number of trees: 50 , Maximum depth 26 :
# Accuracy: 0.9897476340694006
#   Fold n. 1
# elapsed time: 258.95s, done 117 out of 1950
# Number of trees: 50 , Maximum depth 26 :
# Accuracy: 0.9879074658254469
#   Fold n. 2
# elapsed time: 261.8s, done 118 out of 1950
# Number of trees: 50 , Maximum depth 26 :
# Accuracy: 0.9918506834910621
#   Fold n. 3
# elapsed time: 265.02s, done 119 out of 1950
# Number of trees: 50 , Maximum depth 26 :
# Accuracy: 0.9892218717139852
#   Fold n. 4
# elapsed time: 267.73s, done 120 out of 1950
# Number of trees: 50 , Maximum depth 26 :
# Accuracy: 0.8353931107020773
# Area under ROC curve: 0.976 Selected area: 0.176
#
#
#   Fold n. 0
# elapsed time: 270.49s, done 121 out of 1950
# Number of trees: 50 , Maximum depth 28 :
# Accuracy: 0.9944794952681388
#   Fold n. 1
# elapsed time: 273.26s, done 122 out of 1950
# Number of trees: 50 , Maximum depth 28 :
# Accuracy: 0.9926393270241851
#   Fold n. 2
# elapsed time: 276.29s, done 123 out of 1950
# Number of trees: 50 , Maximum depth 28 :
# Accuracy: 0.9971083070452156
#   Fold n. 3
# elapsed time: 279.37s, done 124 out of 1950
# Number of trees: 50 , Maximum depth 28 :
# Accuracy: 0.9957939011566772
#   Fold n. 4
# elapsed time: 282.42s, done 125 out of 1950
# Number of trees: 50 , Maximum depth 28 :
# Accuracy: 0.8409150670523271
# Area under ROC curve: 0.976 Selected area: 0.177
#
#
#   Fold n. 0
# elapsed time: 285.61s, done 126 out of 1950
# Number of trees: 50 , Maximum depth 30 :
# Accuracy: 0.9971083070452156
#   Fold n. 1
# elapsed time: 288.63s, done 127 out of 1950
# Number of trees: 50 , Maximum depth 30 :
# Accuracy: 0.9965825446898002
#   Fold n. 2
# elapsed time: 291.77s, done 128 out of 1950
# Number of trees: 50 , Maximum depth 30 :
# Accuracy: 0.9986855941114616
#   Fold n. 3
# elapsed time: 294.74s, done 129 out of 1950
# Number of trees: 50 , Maximum depth 30 :
# Accuracy: 0.9989484752891693
#   Fold n. 4
# elapsed time: 297.69s, done 130 out of 1950
# Number of trees: 50 , Maximum depth 30 :
# Accuracy: 0.8361819616092558
# Area under ROC curve: 0.976 Selected area: 0.174
#
#
#   Fold n. 0
# elapsed time: 300.65s, done 131 out of 1950
# Number of trees: 50 , Maximum depth 32 :
# Accuracy: 0.9989484752891693
#   Fold n. 1
# elapsed time: 303.51s, done 132 out of 1950
# Number of trees: 50 , Maximum depth 32 :
# Accuracy: 0.9989484752891693
#   Fold n. 2
# elapsed time: 306.56s, done 133 out of 1950
# Number of trees: 50 , Maximum depth 32 :
# Accuracy: 0.9994742376445847
#   Fold n. 3
# elapsed time: 309.97s, done 134 out of 1950
# Number of trees: 50 , Maximum depth 32 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 313.08s, done 135 out of 1950
# Number of trees: 50 , Maximum depth 32 :
# Accuracy: 0.8390744149355772
# Area under ROC curve: 0.976 Selected area: 0.178
#
#
#   Fold n. 0
# elapsed time: 316.03s, done 136 out of 1950
# Number of trees: 50 , Maximum depth 34 :
# Accuracy: 0.9997371188222923
#   Fold n. 1
# elapsed time: 318.86s, done 137 out of 1950
# Number of trees: 50 , Maximum depth 34 :
# Accuracy: 0.9997371188222923
#   Fold n. 2
# elapsed time: 321.56s, done 138 out of 1950
# Number of trees: 50 , Maximum depth 34 :
# Accuracy: 0.9994742376445847
#   Fold n. 3
# elapsed time: 324.5s, done 139 out of 1950
# Number of trees: 50 , Maximum depth 34 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 327.6s, done 140 out of 1950
# Number of trees: 50 , Maximum depth 34 :
# Accuracy: 0.8356560610044702
# Area under ROC curve: 0.976 Selected area: 0.177
#
#
#   Fold n. 0
# elapsed time: 330.27s, done 141 out of 1950
# Number of trees: 50 , Maximum depth 36 :
# Accuracy: 0.9997371188222923
#   Fold n. 1
# elapsed time: 332.94s, done 142 out of 1950
# Number of trees: 50 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 336.0s, done 143 out of 1950
# Number of trees: 50 , Maximum depth 36 :
# Accuracy: 0.9997371188222923
#   Fold n. 3
# elapsed time: 338.75s, done 144 out of 1950
# Number of trees: 50 , Maximum depth 36 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 341.71s, done 145 out of 1950
# Number of trees: 50 , Maximum depth 36 :
# Accuracy: 0.8385485143307915
# Area under ROC curve: 0.976 Selected area: 0.168
#
#
#   Fold n. 0
# elapsed time: 344.57s, done 146 out of 1950
# Number of trees: 50 , Maximum depth 38 :
# Accuracy: 0.9997371188222923
#   Fold n. 1
# elapsed time: 347.46s, done 147 out of 1950
# Number of trees: 50 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 350.52s, done 148 out of 1950
# Number of trees: 50 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 353.49s, done 149 out of 1950
# Number of trees: 50 , Maximum depth 38 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 356.85s, done 150 out of 1950
# Number of trees: 50 , Maximum depth 38 :
# Accuracy: 0.8369708125164343
# Area under ROC curve: 0.976 Selected area: 0.175
#
#
#   Fold n. 0
# elapsed time: 359.1s, done 151 out of 1950
# Number of trees: 60 , Maximum depth 10 :
# Accuracy: 0.8564668769716088
#   Fold n. 1
# elapsed time: 361.3s, done 152 out of 1950
# Number of trees: 60 , Maximum depth 10 :
# Accuracy: 0.8530494216614091
#   Fold n. 2
# elapsed time: 363.14s, done 153 out of 1950
# Number of trees: 60 , Maximum depth 10 :
# Accuracy: 0.8606729758149316
#   Fold n. 3
# elapsed time: 365.0s, done 154 out of 1950
# Number of trees: 60 , Maximum depth 10 :
# Accuracy: 0.8464773922187171
#   Fold n. 4
# elapsed time: 366.91s, done 155 out of 1950
# Number of trees: 60 , Maximum depth 10 :
# Accuracy: 0.8148829871154352
# Area under ROC curve: 0.895 Selected area: 0.112
#
#
#   Fold n. 0
# elapsed time: 369.06s, done 156 out of 1950
# Number of trees: 60 , Maximum depth 12 :
# Accuracy: 0.8803890641430073
#   Fold n. 1
# elapsed time: 371.32s, done 157 out of 1950
# Number of trees: 60 , Maximum depth 12 :
# Accuracy: 0.8751314405888538
#   Fold n. 2
# elapsed time: 373.82s, done 158 out of 1950
# Number of trees: 60 , Maximum depth 12 :
# Accuracy: 0.8838065194532071
#   Fold n. 3
# elapsed time: 375.98s, done 159 out of 1950
# Number of trees: 60 , Maximum depth 12 :
# Accuracy: 0.879074658254469
#   Fold n. 4
# elapsed time: 378.39s, done 160 out of 1950
# Number of trees: 60 , Maximum depth 12 :
# Accuracy: 0.8254009992111491
# Area under ROC curve: 0.923 Selected area: 0.131
#
#
#   Fold n. 0
# elapsed time: 381.28s, done 161 out of 1950
# Number of trees: 60 , Maximum depth 14 :
# Accuracy: 0.9045741324921136
#   Fold n. 1
# elapsed time: 383.57s, done 162 out of 1950
# Number of trees: 60 , Maximum depth 14 :
# Accuracy: 0.908254468980021
#   Fold n. 2
# elapsed time: 386.13s, done 163 out of 1950
# Number of trees: 60 , Maximum depth 14 :
# Accuracy: 0.9095688748685594
#   Fold n. 3
# elapsed time: 388.69s, done 164 out of 1950
# Number of trees: 60 , Maximum depth 14 :
# Accuracy: 0.9035226077812829
#   Fold n. 4
# elapsed time: 391.54s, done 165 out of 1950
# Number of trees: 60 , Maximum depth 14 :
# Accuracy: 0.8285564028398633
# Area under ROC curve: 0.944 Selected area: 0.15
#
#
#   Fold n. 0
# elapsed time: 394.36s, done 166 out of 1950
# Number of trees: 60 , Maximum depth 16 :
# Accuracy: 0.9242902208201893
#   Fold n. 1
# elapsed time: 397.39s, done 167 out of 1950
# Number of trees: 60 , Maximum depth 16 :
# Accuracy: 0.9305993690851735
#   Fold n. 2
# elapsed time: 400.18s, done 168 out of 1950
# Number of trees: 60 , Maximum depth 16 :
# Accuracy: 0.9311251314405888
#   Fold n. 3
# elapsed time: 403.12s, done 169 out of 1950
# Number of trees: 60 , Maximum depth 16 :
# Accuracy: 0.9250788643533123
#   Fold n. 4
# elapsed time: 405.96s, done 170 out of 1950
# Number of trees: 60 , Maximum depth 16 :
# Accuracy: 0.8303970549566132
# Area under ROC curve: 0.959 Selected area: 0.158
#
#
#   Fold n. 0
# elapsed time: 408.97s, done 171 out of 1950
# Number of trees: 60 , Maximum depth 18 :
# Accuracy: 0.9429547844374343
#   Fold n. 1
# elapsed time: 412.13s, done 172 out of 1950
# Number of trees: 60 , Maximum depth 18 :
# Accuracy: 0.944794952681388
#   Fold n. 2
# elapsed time: 415.16s, done 173 out of 1950
# Number of trees: 60 , Maximum depth 18 :
# Accuracy: 0.9463722397476341
#   Fold n. 3
# elapsed time: 418.52s, done 174 out of 1950
# Number of trees: 60 , Maximum depth 18 :
# Accuracy: 0.943217665615142
#   Fold n. 4
# elapsed time: 421.81s, done 175 out of 1950
# Number of trees: 60 , Maximum depth 18 :
# Accuracy: 0.8385485143307915
# Area under ROC curve: 0.968 Selected area: 0.15
#
#
#   Fold n. 0
# elapsed time: 425.17s, done 176 out of 1950
# Number of trees: 60 , Maximum depth 20 :
# Accuracy: 0.9582018927444795
#   Fold n. 1
# elapsed time: 428.34s, done 177 out of 1950
# Number of trees: 60 , Maximum depth 20 :
# Accuracy: 0.9582018927444795
#   Fold n. 2
# elapsed time: 431.28s, done 178 out of 1950
# Number of trees: 60 , Maximum depth 20 :
# Accuracy: 0.9624079915878023
#   Fold n. 3
# elapsed time: 434.15s, done 179 out of 1950
# Number of trees: 60 , Maximum depth 20 :
# Accuracy: 0.9579390115667719
#   Fold n. 4
# elapsed time: 437.1s, done 180 out of 1950
# Number of trees: 60 , Maximum depth 20 :
# Accuracy: 0.8353931107020773
# Area under ROC curve: 0.973 Selected area: 0.133
#
#
#   Fold n. 0
# elapsed time: 440.43s, done 181 out of 1950
# Number of trees: 60 , Maximum depth 22 :
# Accuracy: 0.9697686645636172
#   Fold n. 1
# elapsed time: 443.53s, done 182 out of 1950
# Number of trees: 60 , Maximum depth 22 :
# Accuracy: 0.9713459516298633
#   Fold n. 2
# elapsed time: 446.96s, done 183 out of 1950
# Number of trees: 60 , Maximum depth 22 :
# Accuracy: 0.9742376445846478
#   Fold n. 3
# elapsed time: 450.1s, done 184 out of 1950
# Number of trees: 60 , Maximum depth 22 :
# Accuracy: 0.9687171398527865
#   Fold n. 4
# elapsed time: 453.17s, done 185 out of 1950
# Number of trees: 60 , Maximum depth 22 :
# Accuracy: 0.834341309492506
# Area under ROC curve: 0.975 Selected area: 0.166
#
#
#   Fold n. 0
# elapsed time: 456.23s, done 186 out of 1950
# Number of trees: 60 , Maximum depth 24 :
# Accuracy: 0.9810725552050473
#   Fold n. 1
# elapsed time: 459.55s, done 187 out of 1950
# Number of trees: 60 , Maximum depth 24 :
# Accuracy: 0.981335436382755
#   Fold n. 2
# elapsed time: 462.93s, done 188 out of 1950
# Number of trees: 60 , Maximum depth 24 :
# Accuracy: 0.9852786540483701
#   Fold n. 3
# elapsed time: 466.03s, done 189 out of 1950
# Number of trees: 60 , Maximum depth 24 :
# Accuracy: 0.980546792849632
#   Fold n. 4
# elapsed time: 469.01s, done 190 out of 1950
# Number of trees: 60 , Maximum depth 24 :
# Accuracy: 0.8369708125164343
# Area under ROC curve: 0.976 Selected area: 0.177
#
#
#   Fold n. 0
# elapsed time: 472.09s, done 191 out of 1950
# Number of trees: 60 , Maximum depth 26 :
# Accuracy: 0.9886961093585699
#   Fold n. 1
# elapsed time: 475.64s, done 192 out of 1950
# Number of trees: 60 , Maximum depth 26 :
# Accuracy: 0.9884332281808622
#   Fold n. 2
# elapsed time: 479.03s, done 193 out of 1950
# Number of trees: 60 , Maximum depth 26 :
# Accuracy: 0.9915878023133544
#   Fold n. 3
# elapsed time: 482.27s, done 194 out of 1950
# Number of trees: 60 , Maximum depth 26 :
# Accuracy: 0.9889589905362776
#   Fold n. 4
# elapsed time: 485.72s, done 195 out of 1950
# Number of trees: 60 , Maximum depth 26 :
# Accuracy: 0.8348672100972916
# Area under ROC curve: 0.976 Selected area: 0.178
#
#
#   Fold n. 0
# elapsed time: 489.6s, done 196 out of 1950
# Number of trees: 60 , Maximum depth 28 :
# Accuracy: 0.9947423764458465
#   Fold n. 1
# elapsed time: 493.51s, done 197 out of 1950
# Number of trees: 60 , Maximum depth 28 :
# Accuracy: 0.9926393270241851
#   Fold n. 2
# elapsed time: 497.39s, done 198 out of 1950
# Number of trees: 60 , Maximum depth 28 :
# Accuracy: 0.9973711882229233
#   Fold n. 3
# elapsed time: 500.72s, done 199 out of 1950
# Number of trees: 60 , Maximum depth 28 :
# Accuracy: 0.9952681388012619
#   Fold n. 4
# elapsed time: 504.46s, done 200 out of 1950
# Number of trees: 60 , Maximum depth 28 :
# Accuracy: 0.8403891664475415
# Area under ROC curve: 0.976 Selected area: 0.173
#
#
#   Fold n. 0
# elapsed time: 508.05s, done 201 out of 1950
# Number of trees: 60 , Maximum depth 30 :
# Accuracy: 0.9971083070452156
#   Fold n. 1
# elapsed time: 511.3s, done 202 out of 1950
# Number of trees: 60 , Maximum depth 30 :
# Accuracy: 0.9973711882229233
#   Fold n. 2
# elapsed time: 514.67s, done 203 out of 1950
# Number of trees: 60 , Maximum depth 30 :
# Accuracy: 0.999211356466877
#   Fold n. 3
# elapsed time: 518.32s, done 204 out of 1950
# Number of trees: 60 , Maximum depth 30 :
# Accuracy: 0.998422712933754
#   Fold n. 4
# elapsed time: 521.79s, done 205 out of 1950
# Number of trees: 60 , Maximum depth 30 :
# Accuracy: 0.8356560610044702
# Area under ROC curve: 0.976 Selected area: 0.175
#
#
#   Fold n. 0
# elapsed time: 525.28s, done 206 out of 1950
# Number of trees: 60 , Maximum depth 32 :
# Accuracy: 0.9994742376445847
#   Fold n. 1
# elapsed time: 529.14s, done 207 out of 1950
# Number of trees: 60 , Maximum depth 32 :
# Accuracy: 0.9989484752891693
#   Fold n. 2
# elapsed time: 532.65s, done 208 out of 1950
# Number of trees: 60 , Maximum depth 32 :
# Accuracy: 0.9997371188222923
#   Fold n. 3
# elapsed time: 535.99s, done 209 out of 1950
# Number of trees: 60 , Maximum depth 32 :
# Accuracy: 0.9994742376445847
#   Fold n. 4
# elapsed time: 539.92s, done 210 out of 1950
# Number of trees: 60 , Maximum depth 32 :
# Accuracy: 0.8396003155403629
# Area under ROC curve: 0.976 Selected area: 0.174
#
#
#   Fold n. 0
# elapsed time: 543.34s, done 211 out of 1950
# Number of trees: 60 , Maximum depth 34 :
# Accuracy: 0.9997371188222923
#   Fold n. 1
# elapsed time: 546.48s, done 212 out of 1950
# Number of trees: 60 , Maximum depth 34 :
# Accuracy: 0.9994742376445847
#   Fold n. 2
# elapsed time: 549.78s, done 213 out of 1950
# Number of trees: 60 , Maximum depth 34 :
# Accuracy: 0.9997371188222923
#   Fold n. 3
# elapsed time: 553.44s, done 214 out of 1950
# Number of trees: 60 , Maximum depth 34 :
# Accuracy: 0.9994742376445847
#   Fold n. 4
# elapsed time: 557.0s, done 215 out of 1950
# Number of trees: 60 , Maximum depth 34 :
# Accuracy: 0.835919011306863
# Area under ROC curve: 0.976 Selected area: 0.17
#
#
#   Fold n. 0
# elapsed time: 560.79s, done 216 out of 1950
# Number of trees: 60 , Maximum depth 36 :
# Accuracy: 0.9997371188222923
#   Fold n. 1
# elapsed time: 564.57s, done 217 out of 1950
# Number of trees: 60 , Maximum depth 36 :
# Accuracy: 0.9997371188222923
#   Fold n. 2
# elapsed time: 567.9s, done 218 out of 1950
# Number of trees: 60 , Maximum depth 36 :
# Accuracy: 0.9997371188222923
#   Fold n. 3
# elapsed time: 571.3s, done 219 out of 1950
# Number of trees: 60 , Maximum depth 36 :
# Accuracy: 0.9994742376445847
#   Fold n. 4
# elapsed time: 575.09s, done 220 out of 1950
# Number of trees: 60 , Maximum depth 36 :
# Accuracy: 0.837759663423613
# Area under ROC curve: 0.976 Selected area: 0.167
#
#
#   Fold n. 0
# elapsed time: 578.43s, done 221 out of 1950
# Number of trees: 60 , Maximum depth 38 :
# Accuracy: 0.9997371188222923
#   Fold n. 1
# elapsed time: 581.63s, done 222 out of 1950
# Number of trees: 60 , Maximum depth 38 :
# Accuracy: 0.9997371188222923
#   Fold n. 2
# elapsed time: 585.13s, done 223 out of 1950
# Number of trees: 60 , Maximum depth 38 :
# Accuracy: 0.9997371188222923
#   Fold n. 3
# elapsed time: 588.91s, done 224 out of 1950
# Number of trees: 60 , Maximum depth 38 :
# Accuracy: 0.9994742376445847
#   Fold n. 4
# elapsed time: 592.27s, done 225 out of 1950
# Number of trees: 60 , Maximum depth 38 :
# Accuracy: 0.8367078622140416
# Area under ROC curve: 0.976 Selected area: 0.166
#
#
#   Fold n. 0
# elapsed time: 594.52s, done 226 out of 1950
# Number of trees: 70 , Maximum depth 10 :
# Accuracy: 0.8583070452155626
#   Fold n. 1
# elapsed time: 596.77s, done 227 out of 1950
# Number of trees: 70 , Maximum depth 10 :
# Accuracy: 0.852260778128286
#   Fold n. 2
# elapsed time: 598.9s, done 228 out of 1950
# Number of trees: 70 , Maximum depth 10 :
# Accuracy: 0.8643533123028391
#   Fold n. 3
# elapsed time: 601.08s, done 229 out of 1950
# Number of trees: 70 , Maximum depth 10 :
# Accuracy: 0.8480546792849631
#   Fold n. 4
# elapsed time: 603.68s, done 230 out of 1950
# Number of trees: 70 , Maximum depth 10 :
# Accuracy: 0.8159347883250065
# Area under ROC curve: 0.897 Selected area: 0.113
#
#
#   Fold n. 0
# elapsed time: 606.2s, done 231 out of 1950
# Number of trees: 70 , Maximum depth 12 :
# Accuracy: 0.8827549947423764
#   Fold n. 1
# elapsed time: 608.91s, done 232 out of 1950
# Number of trees: 70 , Maximum depth 12 :
# Accuracy: 0.8769716088328076
#   Fold n. 2
# elapsed time: 611.51s, done 233 out of 1950
# Number of trees: 70 , Maximum depth 12 :
# Accuracy: 0.8848580441640379
#   Fold n. 3
# elapsed time: 614.07s, done 234 out of 1950
# Number of trees: 70 , Maximum depth 12 :
# Accuracy: 0.879074658254469
#   Fold n. 4
# elapsed time: 616.81s, done 235 out of 1950
# Number of trees: 70 , Maximum depth 12 :
# Accuracy: 0.8264528004207204
# Area under ROC curve: 0.924 Selected area: 0.132
#
#
#   Fold n. 0
# elapsed time: 619.75s, done 236 out of 1950
# Number of trees: 70 , Maximum depth 14 :
# Accuracy: 0.9053627760252366
#   Fold n. 1
# elapsed time: 622.52s, done 237 out of 1950
# Number of trees: 70 , Maximum depth 14 :
# Accuracy: 0.9079915878023134
#   Fold n. 2
# elapsed time: 625.57s, done 238 out of 1950
# Number of trees: 70 , Maximum depth 14 :
# Accuracy: 0.9098317560462671
#   Fold n. 3
# elapsed time: 628.48s, done 239 out of 1950
# Number of trees: 70 , Maximum depth 14 :
# Accuracy: 0.9037854889589906
#   Fold n. 4
# elapsed time: 631.44s, done 240 out of 1950
# Number of trees: 70 , Maximum depth 14 :
# Accuracy: 0.8301341046542203
# Area under ROC curve: 0.945 Selected area: 0.15
#
#
#   Fold n. 0
# elapsed time: 634.88s, done 241 out of 1950
# Number of trees: 70 , Maximum depth 16 :
# Accuracy: 0.9256046267087277
#   Fold n. 1
# elapsed time: 638.19s, done 242 out of 1950
# Number of trees: 70 , Maximum depth 16 :
# Accuracy: 0.9282334384858044
#   Fold n. 2
# elapsed time: 641.4s, done 243 out of 1950
# Number of trees: 70 , Maximum depth 16 :
# Accuracy: 0.9295478443743428
#   Fold n. 3
# elapsed time: 644.63s, done 244 out of 1950
# Number of trees: 70 , Maximum depth 16 :
# Accuracy: 0.92534174553102
#   Fold n. 4
# elapsed time: 648.01s, done 245 out of 1950
# Number of trees: 70 , Maximum depth 16 :
# Accuracy: 0.8317118064685775
# Area under ROC curve: 0.959 Selected area: 0.157
#
#
#   Fold n. 0
# elapsed time: 651.55s, done 246 out of 1950
# Number of trees: 70 , Maximum depth 18 :
# Accuracy: 0.9413774973711883
#   Fold n. 1
# elapsed time: 655.23s, done 247 out of 1950
# Number of trees: 70 , Maximum depth 18 :
# Accuracy: 0.9463722397476341
#   Fold n. 2
# elapsed time: 658.9s, done 248 out of 1950
# Number of trees: 70 , Maximum depth 18 :
# Accuracy: 0.9471608832807571
#   Fold n. 3
# elapsed time: 662.38s, done 249 out of 1950
# Number of trees: 70 , Maximum depth 18 :
# Accuracy: 0.9434805467928497
#   Fold n. 4
# elapsed time: 665.52s, done 250 out of 1950
# Number of trees: 70 , Maximum depth 18 :
# Accuracy: 0.8353931107020773
# Area under ROC curve: 0.968 Selected area: 0.141
#
#
#   Fold n. 0
# elapsed time: 669.47s, done 251 out of 1950
# Number of trees: 70 , Maximum depth 20 :
# Accuracy: 0.9579390115667719
#   Fold n. 1
# elapsed time: 673.15s, done 252 out of 1950
# Number of trees: 70 , Maximum depth 20 :
# Accuracy: 0.9571503680336488
#   Fold n. 2
# elapsed time: 677.06s, done 253 out of 1950
# Number of trees: 70 , Maximum depth 20 :
# Accuracy: 0.964248159831756
#   Fold n. 3
# elapsed time: 680.49s, done 254 out of 1950
# Number of trees: 70 , Maximum depth 20 :
# Accuracy: 0.9576761303890642
#   Fold n. 4
# elapsed time: 684.01s, done 255 out of 1950
# Number of trees: 70 , Maximum depth 20 :
# Accuracy: 0.8364449119116487
# Area under ROC curve: 0.973 Selected area: 0.115
#
#
#   Fold n. 0
# elapsed time: 687.57s, done 256 out of 1950
# Number of trees: 70 , Maximum depth 22 :
# Accuracy: 0.9697686645636172
#   Fold n. 1
# elapsed time: 691.15s, done 257 out of 1950
# Number of trees: 70 , Maximum depth 22 :
# Accuracy: 0.9718717139852786
#   Fold n. 2
# elapsed time: 695.11s, done 258 out of 1950
# Number of trees: 70 , Maximum depth 22 :
# Accuracy: 0.9750262881177708
#   Fold n. 3
# elapsed time: 699.12s, done 259 out of 1950
# Number of trees: 70 , Maximum depth 22 :
# Accuracy: 0.9689800210304942
#   Fold n. 4
# elapsed time: 702.7s, done 260 out of 1950
# Number of trees: 70 , Maximum depth 22 :
# Accuracy: 0.835919011306863
# Area under ROC curve: 0.975 Selected area: 0.167
#
#
#   Fold n. 0
# elapsed time: 706.41s, done 261 out of 1950
# Number of trees: 70 , Maximum depth 24 :
# Accuracy: 0.9810725552050473
#   Fold n. 1
# elapsed time: 710.07s, done 262 out of 1950
# Number of trees: 70 , Maximum depth 24 :
# Accuracy: 0.981335436382755
#   Fold n. 2
# elapsed time: 713.61s, done 263 out of 1950
# Number of trees: 70 , Maximum depth 24 :
# Accuracy: 0.9855415352260778
#   Fold n. 3
# elapsed time: 717.72s, done 264 out of 1950
# Number of trees: 70 , Maximum depth 24 :
# Accuracy: 0.9789695057833859
#   Fold n. 4
# elapsed time: 721.9s, done 265 out of 1950
# Number of trees: 70 , Maximum depth 24 :
# Accuracy: 0.8367078622140416
# Area under ROC curve: 0.976 Selected area: 0.176
#
#
#   Fold n. 0
# elapsed time: 725.43s, done 266 out of 1950
# Number of trees: 70 , Maximum depth 26 :
# Accuracy: 0.9892218717139852
#   Fold n. 1
# elapsed time: 729.05s, done 267 out of 1950
# Number of trees: 70 , Maximum depth 26 :
# Accuracy: 0.9884332281808622
#   Fold n. 2
# elapsed time: 732.59s, done 268 out of 1950
# Number of trees: 70 , Maximum depth 26 :
# Accuracy: 0.9931650893796005
#   Fold n. 3
# elapsed time: 736.4s, done 269 out of 1950
# Number of trees: 70 , Maximum depth 26 :
# Accuracy: 0.9886961093585699
#   Fold n. 4
# elapsed time: 740.36s, done 270 out of 1950
# Number of trees: 70 , Maximum depth 26 :
# Accuracy: 0.8364449119116487
# Area under ROC curve: 0.976 Selected area: 0.177
#
#
#   Fold n. 0
# elapsed time: 744.45s, done 271 out of 1950
# Number of trees: 70 , Maximum depth 28 :
# Accuracy: 0.9952681388012619
#   Fold n. 1
# elapsed time: 748.66s, done 272 out of 1950
# Number of trees: 70 , Maximum depth 28 :
# Accuracy: 0.9934279705573081
#   Fold n. 2
# elapsed time: 753.1s, done 273 out of 1950
# Number of trees: 70 , Maximum depth 28 :
# Accuracy: 0.9981598317560463
#   Fold n. 3
# elapsed time: 757.06s, done 274 out of 1950
# Number of trees: 70 , Maximum depth 28 :
# Accuracy: 0.9963196635120926
#   Fold n. 4
# elapsed time: 761.09s, done 275 out of 1950
# Number of trees: 70 , Maximum depth 28 :
# Accuracy: 0.8382855640283986
# Area under ROC curve: 0.976 Selected area: 0.176
#
#
#   Fold n. 0
# elapsed time: 765.44s, done 276 out of 1950
# Number of trees: 70 , Maximum depth 30 :
# Accuracy: 0.998422712933754
#   Fold n. 1
# elapsed time: 769.46s, done 277 out of 1950
# Number of trees: 70 , Maximum depth 30 :
# Accuracy: 0.9976340694006309
#   Fold n. 2
# elapsed time: 773.48s, done 278 out of 1950
# Number of trees: 70 , Maximum depth 30 :
# Accuracy: 0.9989484752891693
#   Fold n. 3
# elapsed time: 777.22s, done 279 out of 1950
# Number of trees: 70 , Maximum depth 30 :
# Accuracy: 0.9986855941114616
#   Fold n. 4
# elapsed time: 780.81s, done 280 out of 1950
# Number of trees: 70 , Maximum depth 30 :
# Accuracy: 0.8374967131212201
# Area under ROC curve: 0.976 Selected area: 0.176
#
#
#   Fold n. 0
# elapsed time: 784.88s, done 281 out of 1950
# Number of trees: 70 , Maximum depth 32 :
# Accuracy: 0.9997371188222923
#   Fold n. 1
# elapsed time: 789.04s, done 282 out of 1950
# Number of trees: 70 , Maximum depth 32 :
# Accuracy: 0.9994742376445847
#   Fold n. 2
# elapsed time: 792.68s, done 283 out of 1950
# Number of trees: 70 , Maximum depth 32 :
# Accuracy: 0.9994742376445847
#   Fold n. 3
# elapsed time: 796.84s, done 284 out of 1950
# Number of trees: 70 , Maximum depth 32 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 800.85s, done 285 out of 1950
# Number of trees: 70 , Maximum depth 32 :
# Accuracy: 0.8380226137260058
# Area under ROC curve: 0.976 Selected area: 0.175
#
#
#   Fold n. 0
# elapsed time: 805.14s, done 286 out of 1950
# Number of trees: 70 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 808.72s, done 287 out of 1950
# Number of trees: 70 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 812.32s, done 288 out of 1950
# Number of trees: 70 , Maximum depth 34 :
# Accuracy: 0.9994742376445847
#   Fold n. 3
# elapsed time: 815.9s, done 289 out of 1950
# Number of trees: 70 , Maximum depth 34 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 820.04s, done 290 out of 1950
# Number of trees: 70 , Maximum depth 34 :
# Accuracy: 0.8364449119116487
# Area under ROC curve: 0.976 Selected area: 0.175
#
#
#   Fold n. 0
# elapsed time: 824.57s, done 291 out of 1950
# Number of trees: 70 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 828.64s, done 292 out of 1950
# Number of trees: 70 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 832.23s, done 293 out of 1950
# Number of trees: 70 , Maximum depth 36 :
# Accuracy: 0.9994742376445847
#   Fold n. 3
# elapsed time: 836.25s, done 294 out of 1950
# Number of trees: 70 , Maximum depth 36 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 839.91s, done 295 out of 1950
# Number of trees: 70 , Maximum depth 36 :
# Accuracy: 0.8356560610044702
# Area under ROC curve: 0.976 Selected area: 0.17
#
#
#   Fold n. 0
# elapsed time: 843.89s, done 296 out of 1950
# Number of trees: 70 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 847.99s, done 297 out of 1950
# Number of trees: 70 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 852.18s, done 298 out of 1950
# Number of trees: 70 , Maximum depth 38 :
# Accuracy: 0.9997371188222923
#   Fold n. 3
# elapsed time: 856.29s, done 299 out of 1950
# Number of trees: 70 , Maximum depth 38 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 860.87s, done 300 out of 1950
# Number of trees: 70 , Maximum depth 38 :
# Accuracy: 0.8346042597948987
# Area under ROC curve: 0.976 Selected area: 0.169
#
#
#   Fold n. 0
# elapsed time: 864.03s, done 301 out of 1950
# Number of trees: 80 , Maximum depth 10 :
# Accuracy: 0.8577812828601472
#   Fold n. 1
# elapsed time: 866.78s, done 302 out of 1950
# Number of trees: 80 , Maximum depth 10 :
# Accuracy: 0.8533123028391167
#   Fold n. 2
# elapsed time: 869.35s, done 303 out of 1950
# Number of trees: 80 , Maximum depth 10 :
# Accuracy: 0.8638275499474237
#   Fold n. 3
# elapsed time: 872.27s, done 304 out of 1950
# Number of trees: 80 , Maximum depth 10 :
# Accuracy: 0.8480546792849631
#   Fold n. 4
# elapsed time: 874.93s, done 305 out of 1950
# Number of trees: 80 , Maximum depth 10 :
# Accuracy: 0.8190901919537208
# Area under ROC curve: 0.896 Selected area: 0.113
#
#
#   Fold n. 0
# elapsed time: 878.29s, done 306 out of 1950
# Number of trees: 80 , Maximum depth 12 :
# Accuracy: 0.8830178759200841
#   Fold n. 1
# elapsed time: 881.13s, done 307 out of 1950
# Number of trees: 80 , Maximum depth 12 :
# Accuracy: 0.8780231335436383
#   Fold n. 2
# elapsed time: 884.22s, done 308 out of 1950
# Number of trees: 80 , Maximum depth 12 :
# Accuracy: 0.8851209253417456
#   Fold n. 3
# elapsed time: 887.17s, done 309 out of 1950
# Number of trees: 80 , Maximum depth 12 :
# Accuracy: 0.880651945320715
#   Fold n. 4
# elapsed time: 890.11s, done 310 out of 1950
# Number of trees: 80 , Maximum depth 12 :
# Accuracy: 0.8261898501183277
# Area under ROC curve: 0.923 Selected area: 0.131
#
#
#   Fold n. 0
# elapsed time: 893.54s, done 311 out of 1950
# Number of trees: 80 , Maximum depth 14 :
# Accuracy: 0.9061514195583596
#   Fold n. 1
# elapsed time: 896.96s, done 312 out of 1950
# Number of trees: 80 , Maximum depth 14 :
# Accuracy: 0.9093059936908517
#   Fold n. 2
# elapsed time: 900.36s, done 313 out of 1950
# Number of trees: 80 , Maximum depth 14 :
# Accuracy: 0.9098317560462671
#   Fold n. 3
# elapsed time: 903.68s, done 314 out of 1950
# Number of trees: 80 , Maximum depth 14 :
# Accuracy: 0.9043112513144059
#   Fold n. 4
# elapsed time: 906.96s, done 315 out of 1950
# Number of trees: 80 , Maximum depth 14 :
# Accuracy: 0.8322377070733631
# Area under ROC curve: 0.945 Selected area: 0.15
#
#
#   Fold n. 0
# elapsed time: 910.81s, done 316 out of 1950
# Number of trees: 80 , Maximum depth 16 :
# Accuracy: 0.9263932702418507
#   Fold n. 1
# elapsed time: 914.72s, done 317 out of 1950
# Number of trees: 80 , Maximum depth 16 :
# Accuracy: 0.9290220820189274
#   Fold n. 2
# elapsed time: 919.06s, done 318 out of 1950
# Number of trees: 80 , Maximum depth 16 :
# Accuracy: 0.9298107255520505
#   Fold n. 3
# elapsed time: 922.91s, done 319 out of 1950
# Number of trees: 80 , Maximum depth 16 :
# Accuracy: 0.926919032597266
#   Fold n. 4
# elapsed time: 926.73s, done 320 out of 1950
# Number of trees: 80 , Maximum depth 16 :
# Accuracy: 0.8327636076781488
# Area under ROC curve: 0.959 Selected area: 0.157
#
#
#   Fold n. 0
# elapsed time: 930.58s, done 321 out of 1950
# Number of trees: 80 , Maximum depth 18 :
# Accuracy: 0.942429022082019
#   Fold n. 1
# elapsed time: 934.54s, done 322 out of 1950
# Number of trees: 80 , Maximum depth 18 :
# Accuracy: 0.9466351209253417
#   Fold n. 2
# elapsed time: 938.48s, done 323 out of 1950
# Number of trees: 80 , Maximum depth 18 :
# Accuracy: 0.9474237644584648
#   Fold n. 3
# elapsed time: 942.55s, done 324 out of 1950
# Number of trees: 80 , Maximum depth 18 :
# Accuracy: 0.9434805467928497
#   Fold n. 4
# elapsed time: 946.58s, done 325 out of 1950
# Number of trees: 80 , Maximum depth 18 :
# Accuracy: 0.8353931107020773
# Area under ROC curve: 0.968 Selected area: 0.143
#
#
#   Fold n. 0
# elapsed time: 950.98s, done 326 out of 1950
# Number of trees: 80 , Maximum depth 20 :
# Accuracy: 0.9574132492113565
#   Fold n. 1
# elapsed time: 955.42s, done 327 out of 1950
# Number of trees: 80 , Maximum depth 20 :
# Accuracy: 0.9582018927444795
#   Fold n. 2
# elapsed time: 959.37s, done 328 out of 1950
# Number of trees: 80 , Maximum depth 20 :
# Accuracy: 0.9639852786540484
#   Fold n. 3
# elapsed time: 963.46s, done 329 out of 1950
# Number of trees: 80 , Maximum depth 20 :
# Accuracy: 0.9592534174553102
#   Fold n. 4
# elapsed time: 967.1s, done 330 out of 1950
# Number of trees: 80 , Maximum depth 20 :
# Accuracy: 0.835919011306863
# Area under ROC curve: 0.973 Selected area: 0.116
#
#
#   Fold n. 0
# elapsed time: 971.18s, done 331 out of 1950
# Number of trees: 80 , Maximum depth 22 :
# Accuracy: 0.9692429022082019
#   Fold n. 1
# elapsed time: 975.49s, done 332 out of 1950
# Number of trees: 80 , Maximum depth 22 :
# Accuracy: 0.9708201892744479
#   Fold n. 2
# elapsed time: 979.98s, done 333 out of 1950
# Number of trees: 80 , Maximum depth 22 :
# Accuracy: 0.9771293375394322
#   Fold n. 3
# elapsed time: 983.82s, done 334 out of 1950
# Number of trees: 80 , Maximum depth 22 :
# Accuracy: 0.9708201892744479
#   Fold n. 4
# elapsed time: 987.99s, done 335 out of 1950
# Number of trees: 80 , Maximum depth 22 :
# Accuracy: 0.8356560610044702
# Area under ROC curve: 0.975 Selected area: 0.169
#
#
#   Fold n. 0
# elapsed time: 992.04s, done 336 out of 1950
# Number of trees: 80 , Maximum depth 24 :
# Accuracy: 0.980546792849632
#   Fold n. 1
# elapsed time: 996.38s, done 337 out of 1950
# Number of trees: 80 , Maximum depth 24 :
# Accuracy: 0.982124079915878
#   Fold n. 2
# elapsed time: 1000.51s, done 338 out of 1950
# Number of trees: 80 , Maximum depth 24 :
# Accuracy: 0.9847528916929548
#   Fold n. 3
# elapsed time: 1004.86s, done 339 out of 1950
# Number of trees: 80 , Maximum depth 24 :
# Accuracy: 0.9794952681388013
#   Fold n. 4
# elapsed time: 1009.78s, done 340 out of 1950
# Number of trees: 80 , Maximum depth 24 :
# Accuracy: 0.8374967131212201
# Area under ROC curve: 0.976 Selected area: 0.174
#
#
#   Fold n. 0
# elapsed time: 1014.0s, done 341 out of 1950
# Number of trees: 80 , Maximum depth 26 :
# Accuracy: 0.9894847528916929
#   Fold n. 1
# elapsed time: 1018.65s, done 342 out of 1950
# Number of trees: 80 , Maximum depth 26 :
# Accuracy: 0.9886961093585699
#   Fold n. 2
# elapsed time: 1023.39s, done 343 out of 1950
# Number of trees: 80 , Maximum depth 26 :
# Accuracy: 0.9926393270241851
#   Fold n. 3
# elapsed time: 1027.87s, done 344 out of 1950
# Number of trees: 80 , Maximum depth 26 :
# Accuracy: 0.9894847528916929
#   Fold n. 4
# elapsed time: 1032.92s, done 345 out of 1950
# Number of trees: 80 , Maximum depth 26 :
# Accuracy: 0.8369708125164343
# Area under ROC curve: 0.976 Selected area: 0.178
#
#
#   Fold n. 0
# elapsed time: 1037.46s, done 346 out of 1950
# Number of trees: 80 , Maximum depth 28 :
# Accuracy: 0.9957939011566772
#   Fold n. 1
# elapsed time: 1041.61s, done 347 out of 1950
# Number of trees: 80 , Maximum depth 28 :
# Accuracy: 0.9931650893796005
#   Fold n. 2
# elapsed time: 1046.0s, done 348 out of 1950
# Number of trees: 80 , Maximum depth 28 :
# Accuracy: 0.9978969505783386
#   Fold n. 3
# elapsed time: 1050.29s, done 349 out of 1950
# Number of trees: 80 , Maximum depth 28 :
# Accuracy: 0.9965825446898002
#   Fold n. 4
# elapsed time: 1054.52s, done 350 out of 1950
# Number of trees: 80 , Maximum depth 28 :
# Accuracy: 0.8382855640283986
# Area under ROC curve: 0.976 Selected area: 0.176
#
#
#   Fold n. 0
# elapsed time: 1058.57s, done 351 out of 1950
# Number of trees: 80 , Maximum depth 30 :
# Accuracy: 0.9978969505783386
#   Fold n. 1
# elapsed time: 1063.16s, done 352 out of 1950
# Number of trees: 80 , Maximum depth 30 :
# Accuracy: 0.9976340694006309
#   Fold n. 2
# elapsed time: 1067.56s, done 353 out of 1950
# Number of trees: 80 , Maximum depth 30 :
# Accuracy: 0.9989484752891693
#   Fold n. 3
# elapsed time: 1072.28s, done 354 out of 1950
# Number of trees: 80 , Maximum depth 30 :
# Accuracy: 0.9994742376445847
#   Fold n. 4
# elapsed time: 1076.75s, done 355 out of 1950
# Number of trees: 80 , Maximum depth 30 :
# Accuracy: 0.8369708125164343
# ...
# Number of trees: 280 , Maximum depth 22 :
# Accuracy: 0.9716088328075709
#   Fold n. 4
# elapsed time: 12962.28s, done 1835 out of 1950
# Number of trees: 280 , Maximum depth 22 :
# Accuracy: 0.8380226137260058
# Area under ROC curve: 0.976 Selected area: 0.069
#
#
#   Fold n. 0
# elapsed time: 12975.46s, done 1836 out of 1950
# Number of trees: 280 , Maximum depth 24 :
# Accuracy: 0.9810725552050473
#   Fold n. 1
# elapsed time: 12988.63s, done 1837 out of 1950
# Number of trees: 280 , Maximum depth 24 :
# Accuracy: 0.9826498422712934
#   Fold n. 2
# elapsed time: 13001.75s, done 1838 out of 1950
# Number of trees: 280 , Maximum depth 24 :
# Accuracy: 0.9858044164037855
#   Fold n. 3
# elapsed time: 13014.86s, done 1839 out of 1950
# Number of trees: 280 , Maximum depth 24 :
# Accuracy: 0.980546792849632
#   Fold n. 4
# elapsed time: 13028.06s, done 1840 out of 1950
# Number of trees: 280 , Maximum depth 24 :
# Accuracy: 0.8414409676571128
# Area under ROC curve: 0.976 Selected area: 0.097
#
#
#   Fold n. 0
# elapsed time: 13041.51s, done 1841 out of 1950
# Number of trees: 280 , Maximum depth 26 :
# Accuracy: 0.9900105152471083
#   Fold n. 1
# elapsed time: 13054.88s, done 1842 out of 1950
# Number of trees: 280 , Maximum depth 26 :
# Accuracy: 0.9889589905362776
#   Fold n. 2
# elapsed time: 13068.28s, done 1843 out of 1950
# Number of trees: 280 , Maximum depth 26 :
# Accuracy: 0.9939537329127235
#   Fold n. 3
# elapsed time: 13081.7s, done 1844 out of 1950
# Number of trees: 280 , Maximum depth 26 :
# Accuracy: 0.9889589905362776
#   Fold n. 4
# elapsed time: 13095.06s, done 1845 out of 1950
# Number of trees: 280 , Maximum depth 26 :
# Accuracy: 0.8390744149355772
# Area under ROC curve: 0.977 Selected area: 0.171
#
#
#   Fold n. 0
# elapsed time: 13108.68s, done 1846 out of 1950
# Number of trees: 280 , Maximum depth 28 :
# Accuracy: 0.9950052576235542
#   Fold n. 1
# elapsed time: 13122.4s, done 1847 out of 1950
# Number of trees: 280 , Maximum depth 28 :
# Accuracy: 0.9942166140904312
#   Fold n. 2
# elapsed time: 13135.88s, done 1848 out of 1950
# Number of trees: 280 , Maximum depth 28 :
# Accuracy: 0.9976340694006309
#   Fold n. 3
# elapsed time: 13149.39s, done 1849 out of 1950
# Number of trees: 280 , Maximum depth 28 :
# Accuracy: 0.9973711882229233
#   Fold n. 4
# elapsed time: 13162.89s, done 1850 out of 1950
# Number of trees: 280 , Maximum depth 28 :
# Accuracy: 0.8403891664475415
# Area under ROC curve: 0.977 Selected area: 0.174
#
#
#   Fold n. 0
# elapsed time: 13176.51s, done 1851 out of 1950
# Number of trees: 280 , Maximum depth 30 :
# Accuracy: 0.998422712933754
#   Fold n. 1
# elapsed time: 13190.08s, done 1852 out of 1950
# Number of trees: 280 , Maximum depth 30 :
# Accuracy: 0.9976340694006309
#   Fold n. 2
# elapsed time: 13203.94s, done 1853 out of 1950
# Number of trees: 280 , Maximum depth 30 :
# Accuracy: 0.999211356466877
#   Fold n. 3
# elapsed time: 13217.58s, done 1854 out of 1950
# Number of trees: 280 , Maximum depth 30 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 13231.34s, done 1855 out of 1950
# Number of trees: 280 , Maximum depth 30 :
# Accuracy: 0.837759663423613
# Area under ROC curve: 0.977 Selected area: 0.179
#
#
#   Fold n. 0
# elapsed time: 13245.01s, done 1856 out of 1950
# Number of trees: 280 , Maximum depth 32 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 13258.69s, done 1857 out of 1950
# Number of trees: 280 , Maximum depth 32 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 13272.35s, done 1858 out of 1950
# Number of trees: 280 , Maximum depth 32 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 13286.05s, done 1859 out of 1950
# Number of trees: 280 , Maximum depth 32 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 13299.72s, done 1860 out of 1950
# Number of trees: 280 , Maximum depth 32 :
# Accuracy: 0.83933736523797
# Area under ROC curve: 0.977 Selected area: 0.18
#
#
#   Fold n. 0
# elapsed time: 13313.53s, done 1861 out of 1950
# Number of trees: 280 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 13327.26s, done 1862 out of 1950
# Number of trees: 280 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 13340.92s, done 1863 out of 1950
# Number of trees: 280 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 13354.72s, done 1864 out of 1950
# Number of trees: 280 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 13368.4s, done 1865 out of 1950
# Number of trees: 280 , Maximum depth 34 :
# Accuracy: 0.8398632658427557
# Area under ROC curve: 0.977 Selected area: 0.179
#
#
#   Fold n. 0
# elapsed time: 13382.08s, done 1866 out of 1950
# Number of trees: 280 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 13396.16s, done 1867 out of 1950
# Number of trees: 280 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 13409.9s, done 1868 out of 1950
# Number of trees: 280 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 13423.75s, done 1869 out of 1950
# Number of trees: 280 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 13437.49s, done 1870 out of 1950
# Number of trees: 280 , Maximum depth 36 :
# Accuracy: 0.8396003155403629
# Area under ROC curve: 0.977 Selected area: 0.181
#
#
#   Fold n. 0
# elapsed time: 13451.4s, done 1871 out of 1950
# Number of trees: 280 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 13465.09s, done 1872 out of 1950
# Number of trees: 280 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 13478.9s, done 1873 out of 1950
# Number of trees: 280 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 13492.63s, done 1874 out of 1950
# Number of trees: 280 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 13506.32s, done 1875 out of 1950
# Number of trees: 280 , Maximum depth 38 :
# Accuracy: 0.8403891664475415
# Area under ROC curve: 0.977 Selected area: 0.178
#
#
#   Fold n. 0
# elapsed time: 13514.54s, done 1876 out of 1950
# Number of trees: 290 , Maximum depth 10 :
# Accuracy: 0.860410094637224
#   Fold n. 1
# elapsed time: 13522.81s, done 1877 out of 1950
# Number of trees: 290 , Maximum depth 10 :
# Accuracy: 0.8548895899053628
#   Fold n. 2
# elapsed time: 13531.0s, done 1878 out of 1950
# Number of trees: 290 , Maximum depth 10 :
# Accuracy: 0.863564668769716
#   Fold n. 3
# elapsed time: 13539.2s, done 1879 out of 1950
# Number of trees: 290 , Maximum depth 10 :
# Accuracy: 0.8480546792849631
#   Fold n. 4
# elapsed time: 13547.46s, done 1880 out of 1950
# Number of trees: 290 , Maximum depth 10 :
# Accuracy: 0.8198790428608993
# Area under ROC curve: 0.898 Selected area: 0.114
#
#
#   Fold n. 0
# elapsed time: 13556.88s, done 1881 out of 1950
# Number of trees: 290 , Maximum depth 12 :
# Accuracy: 0.8835436382754994
#   Fold n. 1
# elapsed time: 13566.29s, done 1882 out of 1950
# Number of trees: 290 , Maximum depth 12 :
# Accuracy: 0.8788117770767613
#   Fold n. 2
# elapsed time: 13575.7s, done 1883 out of 1950
# Number of trees: 290 , Maximum depth 12 :
# Accuracy: 0.8861724500525763
#   Fold n. 3
# elapsed time: 13585.04s, done 1884 out of 1950
# Number of trees: 290 , Maximum depth 12 :
# Accuracy: 0.881440588853838
#   Fold n. 4
# elapsed time: 13594.41s, done 1885 out of 1950
# Number of trees: 290 , Maximum depth 12 :
# Accuracy: 0.8280305022350776
# Area under ROC curve: 0.925 Selected area: 0.133
#
#
#   Fold n. 0
# elapsed time: 13604.85s, done 1886 out of 1950
# Number of trees: 290 , Maximum depth 14 :
# Accuracy: 0.905888538380652
#   Fold n. 1
# elapsed time: 13615.23s, done 1887 out of 1950
# Number of trees: 290 , Maximum depth 14 :
# Accuracy: 0.9095688748685594
#   Fold n. 2
# elapsed time: 13625.73s, done 1888 out of 1950
# Number of trees: 290 , Maximum depth 14 :
# Accuracy: 0.9098317560462671
#   Fold n. 3
# elapsed time: 13636.43s, done 1889 out of 1950
# Number of trees: 290 , Maximum depth 14 :
# Accuracy: 0.9056256572029443
#   Fold n. 4
# elapsed time: 13646.88s, done 1890 out of 1950
# Number of trees: 290 , Maximum depth 14 :
# Accuracy: 0.8314488561661846
# Area under ROC curve: 0.946 Selected area: 0.151
#
#
#   Fold n. 0
# elapsed time: 13658.26s, done 1891 out of 1950
# Number of trees: 290 , Maximum depth 16 :
# Accuracy: 0.9282334384858044
#   Fold n. 1
# elapsed time: 13669.66s, done 1892 out of 1950
# Number of trees: 290 , Maximum depth 16 :
# Accuracy: 0.9295478443743428
#   Fold n. 2
# elapsed time: 13681.43s, done 1893 out of 1950
# Number of trees: 290 , Maximum depth 16 :
# Accuracy: 0.9300736067297581
#   Fold n. 3
# elapsed time: 13692.75s, done 1894 out of 1950
# Number of trees: 290 , Maximum depth 16 :
# Accuracy: 0.9274447949526814
#   Fold n. 4
# elapsed time: 13704.12s, done 1895 out of 1950
# Number of trees: 290 , Maximum depth 16 :
# Accuracy: 0.8340783591901131
# Area under ROC curve: 0.96 Selected area: 0.156
#
#
#   Fold n. 0
# elapsed time: 13716.31s, done 1896 out of 1950
# Number of trees: 290 , Maximum depth 18 :
# Accuracy: 0.942429022082019
#   Fold n. 1
# elapsed time: 13728.44s, done 1897 out of 1950
# Number of trees: 290 , Maximum depth 18 :
# Accuracy: 0.9453207150368034
#   Fold n. 2
# elapsed time: 13740.57s, done 1898 out of 1950
# Number of trees: 290 , Maximum depth 18 :
# Accuracy: 0.9476866456361724
#   Fold n. 3
# elapsed time: 13752.7s, done 1899 out of 1950
# Number of trees: 290 , Maximum depth 18 :
# Accuracy: 0.943217665615142
#   Fold n. 4
# elapsed time: 13765.16s, done 1900 out of 1950
# Number of trees: 290 , Maximum depth 18 :
# Accuracy: 0.8372337628188272
# Area under ROC curve: 0.969 Selected area: 0.131
#
#
#   Fold n. 0
# elapsed time: 13777.92s, done 1901 out of 1950
# Number of trees: 290 , Maximum depth 20 :
# Accuracy: 0.9571503680336488
#   Fold n. 1
# elapsed time: 13790.74s, done 1902 out of 1950
# Number of trees: 290 , Maximum depth 20 :
# Accuracy: 0.9563617245005258
#   Fold n. 2
# elapsed time: 13803.53s, done 1903 out of 1950
# Number of trees: 290 , Maximum depth 20 :
# Accuracy: 0.96267087276551
#   Fold n. 3
# elapsed time: 13816.71s, done 1904 out of 1950
# Number of trees: 290 , Maximum depth 20 :
# Accuracy: 0.9592534174553102
#   Fold n. 4
# elapsed time: 13829.85s, done 1905 out of 1950
# Number of trees: 290 , Maximum depth 20 :
# Accuracy: 0.8356560610044702
# Area under ROC curve: 0.974 Selected area: 0.103
#
#
#   Fold n. 0
# elapsed time: 13843.09s, done 1906 out of 1950
# Number of trees: 290 , Maximum depth 22 :
# Accuracy: 0.9700315457413249
#   Fold n. 1
# elapsed time: 13856.68s, done 1907 out of 1950
# Number of trees: 290 , Maximum depth 22 :
# Accuracy: 0.9718717139852786
#   Fold n. 2
# elapsed time: 13869.93s, done 1908 out of 1950
# Number of trees: 290 , Maximum depth 22 :
# Accuracy: 0.9760778128286015
#   Fold n. 3
# elapsed time: 13883.14s, done 1909 out of 1950
# Number of trees: 290 , Maximum depth 22 :
# Accuracy: 0.9713459516298633
#   Fold n. 4
# elapsed time: 13896.41s, done 1910 out of 1950
# Number of trees: 290 , Maximum depth 22 :
# Accuracy: 0.8385485143307915
# Area under ROC curve: 0.976 Selected area: 0.07
#
#
#   Fold n. 0
# elapsed time: 13910.06s, done 1911 out of 1950
# Number of trees: 290 , Maximum depth 24 :
# Accuracy: 0.9808096740273397
#   Fold n. 1
# elapsed time: 13923.79s, done 1912 out of 1950
# Number of trees: 290 , Maximum depth 24 :
# Accuracy: 0.9826498422712934
#   Fold n. 2
# elapsed time: 13937.45s, done 1913 out of 1950
# Number of trees: 290 , Maximum depth 24 :
# Accuracy: 0.9860672975814931
#   Fold n. 3
# elapsed time: 13951.11s, done 1914 out of 1950
# Number of trees: 290 , Maximum depth 24 :
# Accuracy: 0.9818611987381703
#   Fold n. 4
# elapsed time: 13964.85s, done 1915 out of 1950
# Number of trees: 290 , Maximum depth 24 :
# Accuracy: 0.8409150670523271
# Area under ROC curve: 0.976 Selected area: 0.139
#
#
#   Fold n. 0
# elapsed time: 13978.75s, done 1916 out of 1950
# Number of trees: 290 , Maximum depth 26 :
# Accuracy: 0.9892218717139852
#   Fold n. 1
# elapsed time: 13993.01s, done 1917 out of 1950
# Number of trees: 290 , Maximum depth 26 :
# Accuracy: 0.9889589905362776
#   Fold n. 2
# elapsed time: 14006.86s, done 1918 out of 1950
# Number of trees: 290 , Maximum depth 26 :
# Accuracy: 0.9939537329127235
#   Fold n. 3
# elapsed time: 14020.81s, done 1919 out of 1950
# Number of trees: 290 , Maximum depth 26 :
# Accuracy: 0.9889589905362776
#   Fold n. 4
# elapsed time: 14034.71s, done 1920 out of 1950
# Number of trees: 290 , Maximum depth 26 :
# Accuracy: 0.8396003155403629
# Area under ROC curve: 0.977 Selected area: 0.174
#
#
#   Fold n. 0
# elapsed time: 14048.81s, done 1921 out of 1950
# Number of trees: 290 , Maximum depth 28 :
# Accuracy: 0.9950052576235542
#   Fold n. 1
# elapsed time: 14062.93s, done 1922 out of 1950
# Number of trees: 290 , Maximum depth 28 :
# Accuracy: 0.9947423764458465
#   Fold n. 2
# elapsed time: 14076.95s, done 1923 out of 1950
# Number of trees: 290 , Maximum depth 28 :
# Accuracy: 0.9978969505783386
#   Fold n. 3
# elapsed time: 14090.99s, done 1924 out of 1950
# Number of trees: 290 , Maximum depth 28 :
# Accuracy: 0.9968454258675079
#   Fold n. 4
# elapsed time: 14104.99s, done 1925 out of 1950
# Number of trees: 290 , Maximum depth 28 :
# Accuracy: 0.8401262161451486
# Area under ROC curve: 0.977 Selected area: 0.175
#
#
#   Fold n. 0
# elapsed time: 14119.11s, done 1926 out of 1950
# Number of trees: 290 , Maximum depth 30 :
# Accuracy: 0.998422712933754
#   Fold n. 1
# elapsed time: 14133.62s, done 1927 out of 1950
# Number of trees: 290 , Maximum depth 30 :
# Accuracy: 0.9976340694006309
#   Fold n. 2
# elapsed time: 14147.79s, done 1928 out of 1950
# Number of trees: 290 , Maximum depth 30 :
# Accuracy: 0.9994742376445847
#   Fold n. 3
# elapsed time: 14162.15s, done 1929 out of 1950
# Number of trees: 290 , Maximum depth 30 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 14176.28s, done 1930 out of 1950
# Number of trees: 290 , Maximum depth 30 :
# Accuracy: 0.837759663423613
# Area under ROC curve: 0.977 Selected area: 0.179
#
#
#   Fold n. 0
# elapsed time: 14190.47s, done 1931 out of 1950
# Number of trees: 290 , Maximum depth 32 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 14204.78s, done 1932 out of 1950
# Number of trees: 290 , Maximum depth 32 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 14218.99s, done 1933 out of 1950
# Number of trees: 290 , Maximum depth 32 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 14233.18s, done 1934 out of 1950
# Number of trees: 290 , Maximum depth 32 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 14247.38s, done 1935 out of 1950
# Number of trees: 290 , Maximum depth 32 :
# Accuracy: 0.8390744149355772
# Area under ROC curve: 0.977 Selected area: 0.18
#
#
#   Fold n. 0
# elapsed time: 14261.64s, done 1936 out of 1950
# Number of trees: 290 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 14275.91s, done 1937 out of 1950
# Number of trees: 290 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 14290.2s, done 1938 out of 1950
# Number of trees: 290 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 14304.4s, done 1939 out of 1950
# Number of trees: 290 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 14318.57s, done 1940 out of 1950
# Number of trees: 290 , Maximum depth 34 :
# Accuracy: 0.8390744149355772
# Area under ROC curve: 0.977 Selected area: 0.18
#
#
#   Fold n. 0
# elapsed time: 14333.23s, done 1941 out of 1950
# Number of trees: 290 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 14347.53s, done 1942 out of 1950
# Number of trees: 290 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 14361.76s, done 1943 out of 1950
# Number of trees: 290 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 14376.03s, done 1944 out of 1950
# Number of trees: 290 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 14390.3s, done 1945 out of 1950
# Number of trees: 290 , Maximum depth 36 :
# Accuracy: 0.8388114646331843
# Area under ROC curve: 0.977 Selected area: 0.18
#
#
#   Fold n. 0
# elapsed time: 14404.56s, done 1946 out of 1950
# Number of trees: 290 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 14418.88s, done 1947 out of 1950
# Number of trees: 290 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 14433.11s, done 1948 out of 1950
# Number of trees: 290 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 14447.31s, done 1949 out of 1950
# Number of trees: 290 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 14461.59s, done 1950 out of 1950
# Number of trees: 290 , Maximum depth 38 :
# Accuracy: 0.8396003155403629
# Area under ROC curve: 0.977 Selected area: 0.181
#
#
# Best number of trees: 290
#
# Best maximum depth: 38
#
# Area under ROC curve of best model: 0.18122901956348395

# %%
print(round(best_area,3))
print(round(best_total_auc,3))
# Out:
# 0.181
# 0.977

# %% [markdown]
# Now we train again the best Random Forest found on the whole training set. We calculate its accuracy and $Q$ factor on the test set, and find the relative ROC curve of the classifier.

# %%
X_train_np = np.array(X_train)
Y_train_np = np.array(Y_train)
X_test_np = np.array(X_test)
Y_test_np = np.array(Y_test)

best_forest = RandomForestClassifier(n_estimators=best_model[0], max_depth= best_model[1], max_features=X_train_np.shape[1],bootstrap=True,max_samples=1.0,random_state=10,n_jobs=-1)

best_forest.fit(X_train_np,Y_train_np)
Y_pred = best_forest.predict(X_test_np)
accuracy = accuracy_score(Y_test_np, Y_pred)
print('Accuracy of best Random Forest:',round(accuracy,3))

y_pred_prob = best_forest.predict_proba(X_test_np)[:, 1]
fpr, tpr, thresholds = roc_curve(Y_test_np, y_pred_prob)
partial_fpr = fpr[fpr <= 0.2]
partial_tpr = tpr[:len(partial_fpr)]
partial_auc = auc(partial_fpr, partial_tpr)
roc_auc_best = auc(fpr, tpr)
print('Area under ROC curve of the best Random Forest:',round(roc_auc_best,3))
print('Partial area under ROC curve under 0.2 fpr:',round(partial_auc,3))
# Out:
# Accuracy of best Random Forest: 0.839
# Area under ROC curve of the best Random Forest: 0.882
# Partial area under ROC curve under 0.2 fpr: 0.11

# %% [markdown]
# Here we plot the confusion matrix

# %%
cm = confusion_matrix(Y_test,Y_pred)
RF_cm = normalize_cm(cm)

print('Confusion matrix:')
print(RF_cm)
plot_cm(RF_cm,method_name='Random Forest')
# Out:
# Confusion matrix:
# [[0.688 0.312]
#  [0.085 0.915]]

# %% [markdown]
# Finally we compute Q and plot the ROC curve

# %%
fpr_rforest = fpr
tpr_rforest = tpr
Q_rforest = RF_cm[1][1]/ np.sqrt(RF_cm[0][1])

print('best random forest Q:',Q_rforest)

plot_roc(fpr_rforest,tpr_rforest,roc_auc_best,"Random forest","darkgreen")
# Out:
# best random forest Q: 1.6381127743652029

# %% [markdown]
# ## Part 5.5: FFNN
# This part is about training a convolluted neural network to fit data. Different parameters are going to be trained in a manual grid search

# %%
# redefine NN cycle
hidden_layer_sizes = [(18,), (36,), (54,), (36,18), (54,18), (54,36), (54,36,18)]
learning_rate_init = [ 0.1 , 0.01 , 0.001 ]

start_time = time()

auc_scorer = make_scorer(full_auc_scorer, greater_is_better=True, response_method='predict' ) 

parameters = []
fprs = []
tprs = []
aucs = []
partial_aucs = []
hls = []
lrs = []
models = []
K = 5
kf = KFold(n_splits=K, shuffle=True, random_state=42) 

for size in hidden_layer_sizes:
    for lr in learning_rate_init:
        print(f"Training MLP of size {size} and lr {lr}...")
        lrs.append(lr)
        hls.append(size)
        partial_auc = 0
        auc_value = 0

        for i, (train_index, test_index) in enumerate(kf.split(X)):
            
            print(f" Fold n. {i}")
            train_K=data_rescaled_and_indexed.iloc[train_idx]
            valid_K=data_rescaled_and_indexed.iloc[val_idx]
            X_train_K, Y_train_K = split_X_Y(train_K)
            X_valid_K, Y_valid_K = split_X_Y(valid_K)
            
            MLP = MLPClassifier(hidden_layer_sizes=size,
                                activation='relu', 
                                max_iter=1000, 
                                alpha=1e-4, 
                                solver='adam', 
                                tol=1e-5, 
                                learning_rate='adaptive',
                                learning_rate_init=lr,
                                verbose=0)
            
            MLP.fit(X_train_K,Y_train_K)
            parameters.append(MLP.coefs_)
            models.append(MLP)
            
            y_pred_proba = MLP.predict_proba(X_valid_K)[:, 1]  
    
            fpr, tpr, _ = roc_curve(Y_valid_K, y_pred_proba)
            fprs.append(fpr)
            tprs.append(tpr)
            auc_value_k = auc(fpr, tpr)
            print("AUC (Test set):", round(auc_value_k,3))
            
            # search for fpr less than 0.2 (if not able fpr is set to zero)
            partial_fpr = fpr[fpr <= 0.2]
            if (len(partial_fpr) < 2 ):
                partial_auc = 0
            else:
                partial_tpr = tpr[:len(partial_fpr)]
                partial_auc_k = auc(partial_fpr, partial_tpr)
            partial_auc += partial_auc_k/K
            auc_value += auc_value_k/K                 
        partial_aucs.append(partial_auc)
        aucs.append(auc_value)
        
        elapsed_time = time() - start_time
        start_time = time()
        print('\n')
        print(f"Time needed for training: {elapsed_time:.2f} seconds")
        print("partial AUC:",round(partial_auc,3)," total AUC:",round(auc_value,3),'\n')
# Out:
# Training MLP of size (18,) and lr 0.1...
#  Fold n. 0
# AUC (Test set): 0.861
#  Fold n. 1
# AUC (Test set): 0.861
#  Fold n. 2
# AUC (Test set): 0.857
#  Fold n. 3
# AUC (Test set): 0.848
#  Fold n. 4
# AUC (Test set): 0.862
#
#
# Time needed for training: 6.89 seconds
# partial AUC: 0.094  total AUC: 0.858
#
# Training MLP of size (18,) and lr 0.01...
#  Fold n. 0
# AUC (Test set): 0.871
#  Fold n. 1
# AUC (Test set): 0.878
#  Fold n. 2
# AUC (Test set): 0.875
#  Fold n. 3
# AUC (Test set): 0.871
#  Fold n. 4
# AUC (Test set): 0.876
#
#
# Time needed for training: 16.98 seconds
# partial AUC: 0.103  total AUC: 0.874
#
# Training MLP of size (18,) and lr 0.001...
#  Fold n. 0
# AUC (Test set): 0.872
#  Fold n. 1
# AUC (Test set): 0.875
#  Fold n. 2
# AUC (Test set): 0.875
#  Fold n. 3
# AUC (Test set): 0.874
#  Fold n. 4
# AUC (Test set): 0.873
#
#
# Time needed for training: 54.46 seconds
# partial AUC: 0.104  total AUC: 0.874
#
# Training MLP of size (36,) and lr 0.1...
#  Fold n. 0
# AUC (Test set): 0.87
#  Fold n. 1
# AUC (Test set): 0.861
#  Fold n. 2
# AUC (Test set): 0.857
#  Fold n. 3
# AUC (Test set): 0.852
#  Fold n. 4
# AUC (Test set): 0.863
#
#
# Time needed for training: 7.05 seconds
# partial AUC: 0.095  total AUC: 0.861
#
# Training MLP of size (36,) and lr 0.01...
#  Fold n. 0
# AUC (Test set): 0.879
#  Fold n. 1
# AUC (Test set): 0.877
#  Fold n. 2
# AUC (Test set): 0.887
#  Fold n. 3
# AUC (Test set): 0.885
#  Fold n. 4
# AUC (Test set): 0.878
#
#
# Time needed for training: 18.38 seconds
# partial AUC: 0.107  total AUC: 0.881
#
# Training MLP of size (36,) and lr 0.001...
#  Fold n. 0
# AUC (Test set): 0.877
#  Fold n. 1
# AUC (Test set): 0.882
#  Fold n. 2
# AUC (Test set): 0.874
#  Fold n. 3
# AUC (Test set): 0.876
#  Fold n. 4
# AUC (Test set): 0.877
#
#
# Time needed for training: 71.78 seconds
# partial AUC: 0.106  total AUC: 0.877
#
# Training MLP of size (54,) and lr 0.1...
#  Fold n. 0
# AUC (Test set): 0.863
#  Fold n. 1
# AUC (Test set): 0.857
#  Fold n. 2
# AUC (Test set): 0.867
#  Fold n. 3
# AUC (Test set): 0.86
#  Fold n. 4
# AUC (Test set): 0.868
#
#
# Time needed for training: 7.02 seconds
# partial AUC: 0.095  total AUC: 0.863
#
# Training MLP of size (54,) and lr 0.01...
#  Fold n. 0
# AUC (Test set): 0.888
#  Fold n. 1
# AUC (Test set): 0.878
#  Fold n. 2
# AUC (Test set): 0.887
#  Fold n. 3
# AUC (Test set): 0.888
#  Fold n. 4
# AUC (Test set): 0.886
#
#
# Time needed for training: 24.64 seconds
# partial AUC: 0.111  total AUC: 0.885
#
# Training MLP of size (54,) and lr 0.001...
#  Fold n. 0
# AUC (Test set): 0.882
#  Fold n. 1
# AUC (Test set): 0.881
#  Fold n. 2
# AUC (Test set): 0.884
#  Fold n. 3
# AUC (Test set): 0.879
#  Fold n. 4
# AUC (Test set): 0.879
#
#
# Time needed for training: 94.96 seconds
# partial AUC: 0.107  total AUC: 0.881
#
# Training MLP of size (36, 18) and lr 0.1...
#  Fold n. 0
# AUC (Test set): 0.867
#  Fold n. 1
# AUC (Test set): 0.868
#  Fold n. 2
# AUC (Test set): 0.874
#  Fold n. 3
# AUC (Test set): 0.873
#  Fold n. 4
# AUC (Test set): 0.871
#
#
# Time needed for training: 13.45 seconds
# partial AUC: 0.085  total AUC: 0.87
#
# Training MLP of size (36, 18) and lr 0.01...
#  Fold n. 0
# AUC (Test set): 0.874
#  Fold n. 1
# AUC (Test set): 0.888
#  Fold n. 2
# AUC (Test set): 0.884
#  Fold n. 3
# AUC (Test set): 0.88
#  Fold n. 4
# AUC (Test set): 0.878
#
#
# Time needed for training: 39.18 seconds
# partial AUC: 0.108  total AUC: 0.881
#
# Training MLP of size (36, 18) and lr 0.001...
#  Fold n. 0
# AUC (Test set): 0.879
#  Fold n. 1
# AUC (Test set): 0.88
#  Fold n. 2
# AUC (Test set): 0.876
#  Fold n. 3
# AUC (Test set): 0.881
#  Fold n. 4
# AUC (Test set): 0.882
#
#
# Time needed for training: 89.21 seconds
# partial AUC: 0.106  total AUC: 0.879
#
# Training MLP of size (54, 18) and lr 0.1...
#  Fold n. 0
# AUC (Test set): 0.857
#  Fold n. 1
# AUC (Test set): 0.866
#  Fold n. 2
# AUC (Test set): 0.861
#  Fold n. 3
# AUC (Test set): 0.87
#  Fold n. 4
# AUC (Test set): 0.873
#
#
# Time needed for training: 14.53 seconds
# partial AUC: 0.099  total AUC: 0.865
#
# Training MLP of size (54, 18) and lr 0.01...
#  Fold n. 0
# AUC (Test set): 0.876
#  Fold n. 1
# AUC (Test set): 0.873
#  Fold n. 2
# AUC (Test set): 0.889
#  Fold n. 3
# AUC (Test set): 0.87
#  Fold n. 4
# AUC (Test set): 0.884
#
#
# Time needed for training: 69.49 seconds
# partial AUC: 0.104  total AUC: 0.878
#
# Training MLP of size (54, 18) and lr 0.001...
#  Fold n. 0
# AUC (Test set): 0.881
#  Fold n. 1
# AUC (Test set): 0.876
#  Fold n. 2
# AUC (Test set): 0.878
#  Fold n. 3
# AUC (Test set): 0.88
#  Fold n. 4
# AUC (Test set): 0.882
#
#
# Time needed for training: 114.46 seconds
# partial AUC: 0.107  total AUC: 0.879
#
# Training MLP of size (54, 36) and lr 0.1...
#  Fold n. 0
# AUC (Test set): 0.859
#  Fold n. 1
# AUC (Test set): 0.869
#  Fold n. 2
# AUC (Test set): 0.872
#  Fold n. 3
# AUC (Test set): 0.871
#  Fold n. 4
# AUC (Test set): 0.873
#
#
# Time needed for training: 24.03 seconds
# partial AUC: 0.1  total AUC: 0.869
#
# Training MLP of size (54, 36) and lr 0.01...
#  Fold n. 0
# AUC (Test set): 0.871
#  Fold n. 1
# AUC (Test set): 0.87
#  Fold n. 2
# AUC (Test set): 0.884
#  Fold n. 3
# AUC (Test set): 0.874
#  Fold n. 4
# AUC (Test set): 0.873
#
#
# Time needed for training: 84.11 seconds
# partial AUC: 0.103  total AUC: 0.874
#
# Training MLP of size (54, 36) and lr 0.001...
#  Fold n. 0
# AUC (Test set): 0.879
#  Fold n. 1
# AUC (Test set): 0.881
#  Fold n. 2
# AUC (Test set): 0.885
#  Fold n. 3
# AUC (Test set): 0.882
#  Fold n. 4
# AUC (Test set): 0.884
#
#
# Time needed for training: 160.03 seconds
# partial AUC: 0.109  total AUC: 0.882
#
# Training MLP of size (54, 36, 18) and lr 0.1...
#  Fold n. 0
# AUC (Test set): 0.871
#  Fold n. 1
# AUC (Test set): 0.866
#  Fold n. 2
# AUC (Test set): 0.841
#  Fold n. 3
# AUC (Test set): 0.865
#  Fold n. 4
# AUC (Test set): 0.863
#
#
# Time needed for training: 21.50 seconds
# partial AUC: 0.091  total AUC: 0.861
#
# Training MLP of size (54, 36, 18) and lr 0.01...
#  Fold n. 0
# AUC (Test set): 0.865
#  Fold n. 1
# AUC (Test set): 0.866
#  Fold n. 2
# AUC (Test set): 0.861
#  Fold n. 3
# AUC (Test set): 0.862
#  Fold n. 4
# AUC (Test set): 0.867
#
#
# Time needed for training: 118.90 seconds
# partial AUC: 0.096  total AUC: 0.864
#
# Training MLP of size (54, 36, 18) and lr 0.001...
#  Fold n. 0
# AUC (Test set): 0.876
#  Fold n. 1
# AUC (Test set): 0.876
#  Fold n. 2
# AUC (Test set): 0.889
#  Fold n. 3
# AUC (Test set): 0.871
#  Fold n. 4
# AUC (Test set): 0.871
#
#
# Time needed for training: 197.88 seconds
# partial AUC: 0.104  total AUC: 0.877

# %% [markdown]
# Saving the best model's performance and plotting it, as well as the confusion matrix

# %%
best_index_thresh = np.argmax(np.array(partial_aucs))
best_auc_thresh = aucs[best_index_thresh]
best_fpr_thresh = fprs[best_index_thresh]
best_tpr_thresh = tprs[best_index_thresh]
best_model_NN = models[best_index_thresh]

#print(best_model)
Y_pred = best_model_NN.predict(X_test)
cm = confusion_matrix(Y_test,Y_pred)
NN_cm = normalize_cm(cm)

print('Confusion matrix:')
print(NN_cm)
plot_cm(NN_cm,method_name='NN')
# Out:
# Confusion matrix:
# [[0.661 0.339]
#  [0.071 0.929]]

# %%
fpr_NN = best_fpr_thresh
tpr_NN = best_tpr_thresh
Q_NN = NN_cm[1][1]/ np.sqrt(NN_cm[0][1])
auc_value = auc(fpr_NN, tpr_NN)

print('best NN Q value:',round(Q_NN,3))

plot_roc(fpr_NN,tpr_NN,auc_value,"NN","red")
# Out:
# best NN Q value: 1.596

# %% [markdown]
# Now we plot them all

# %%
print('best NN Q value:',Q_NN.round(3))
print('best perceptron Q value:',Q_perceptron.round(3))
print('best SVM Q value:',Q_SVM.round(3))
print('best random forest Q value:',Q_rforest.round(3))
print('best log_reg Q value:',Q_log.round(3))

line_width = 3
transparency = 0.7
plt.figure(figsize=(10,8))
plt.grid()
plt.title('ROC comparison',fontsize=20)
plt.plot([0, 1], [0, 1], linestyle='--', color='grey')
plt.plot(fpr_log,tpr_log,label='log ROC',lw=line_width,alpha=transparency,c='pink')
plt.plot(fpr_perceptron,tpr_perceptron,label='perceptron ROC',lw=line_width,alpha=transparency,c='blue')
plt.plot(fpr_SVM,tpr_SVM,label='SVM ROC',lw=line_width,alpha=transparency,c='darkorange')
plt.plot(fpr_rforest,tpr_rforest,label='random forest ROC',lw=line_width,alpha=transparency,c='darkgreen')
plt.plot(fpr_NN,tpr_NN,c='red',label='NN ROC',lw=line_width,alpha=transparency)
plt.xlabel('false positive rate',fontsize=16)
plt.ylabel('true positive rate',fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc=4,fontsize=12)
plt.show()
# Out:
# best NN Q value: 1.596
# best perceptron Q value: 0.98
# best SVM Q value: 1.396
# best random forest Q value: 1.638
# best log_reg Q value: 1.172

# %% [markdown]
# # Part 6: cutting on alpha parameter
# In this section a cut on alpha parameter is going to be performed. The best value for alpha is going to be determined, as well as the value that lets only 10% of hadron to be accepted as fp
# ## NOTE: Alpha param is not rescaled!

# %%
X_train['fAlpha'] = train_alpha
X_test['fAlpha'] = test_alpha
print(X_train.columns[:])
print(X_train.shape[:])
# Out:
# Index(['fLength', 'fWidth', 'fSize', 'fConc', 'fConc1', 'fAsym', 'fM3Long',
#        'fM3Trans', 'fDist', 'fAlpha'],
#       dtype='object')
# (15216, 10)

# %%
tot_hadrons = len(Y_test[Y_test == -1])
tot_gammas = len(Y_test[Y_test == 1])
tot_hadrons_train = len(Y_train[Y_train == -1])
sel_label = 9
# sel label = Alpha == 9

cut_values = []
rates = []
absolute_tp = []
absolute_fp = []

# setting minimum threshold as 0.90 (editable)
thresh = 0.90

#print('cut value    tp    fp     tp / all')
for i in range(1,tot_hadrons):
    cut_value = find_max_cut_value(X_train,Y_train,sel_label,i)
    
    # to check how the cut value behaves we get the results on test set
    tp, fp = find_tp_fp(X_test,Y_test,sel_label,cut_value)
    if (tp+fp == 0):
        tp = 1
    #print(cut_value,'  ',tp,'  ',fp,'  ',tp/(tp+fp))
    cut_values.append(cut_value)
    rates.append(tp/(tp+fp))
    absolute_tp.append(tp)
    absolute_fp.append(fp)
    
    if (tp/(tp+fp) > thresh):
        best_cut_thresh = cut_value
        rate_thresh = tp/(tp+fp)
        tp_thresh = tp
        fp_thresh = fp

rates = np.array(rates)
mask = np.where(rates < 1,rates,0)
index = np.argmax(mask)
best_rate = rates[index]
best_cut = cut_values[index]
best_tp = absolute_tp[index]
best_fp = absolute_fp[index]

print('total gammas:',tot_gammas,'tot hadrons:',tot_hadrons,'tot test points:',tot_gammas+tot_hadrons)
print('best cut value is Alpha =',round(best_cut,4),'with rate:',round(best_rate,4))
print('#tp:',best_tp,'  #fp:',best_fp)
print('rate of saved gammas:',round(best_tp / tot_gammas,4))
print(' ')
print('given threshold rate = 0.9, best cut is:',round(best_cut_thresh,4),'with rate',round(rate_thresh,4))
print('#tp:',tp_thresh,'#fp:',fp_thresh,'rate of saved gammas:',round(tp_thresh / tot_gammas,4))

plt.axhline(y=0.9, color='g', linestyle=':',label='threshold')  # Dotted green line
plt.scatter(cut_values,rates, s= 5,label='tp / all accepted')
plt.scatter(best_cut,best_rate,c='red',s=10,label='best rate')
plt.scatter(best_cut_thresh,rate_thresh,c='orange',s=10,label='best thresh rate')
plt.legend()
plt.title('cut values for Alpha (tp / all rate)')
plt.xlabel('Alpha values')
plt.ylabel('TPR')
plt.show();
# Out:
# total gammas: 2518 tot hadrons: 1285 tot test points: 3803
# best cut value is Alpha = 0.1512 with rate: 0.973
# #tp: 36   #fp: 1
# rate of saved gammas: 0.0143
#
# given threshold rate = 0.9, best cut is: 9.474 with rate 0.9007
# #tp: 1188 #fp: 131 rate of saved gammas: 0.4718

# %% [markdown]
# # Part 7: Grid search for best gammaness and alpha cut

# %%
print(best_forest)
# Out:
# RandomForestClassifier(max_depth=38, max_features=9, max_samples=1.0,
#                        n_estimators=290, n_jobs=-1, random_state=10)

# %% [markdown]
# We now apply the best model found in the previous part, i.e: the Random Forest, to look for the combination of parameters *gammaness* and *alpha_cut* that maximizes the quality factor *Q*. What we do is label as background (hadrons) all samples with fAlpha greater than the *alpha_cut* value considered; then we apply the best Random Forest classification to the remaining samples, labelling as gammas only the samples with a predicted probability of belonging to class +1 greater than *gammaness*. Then we determine the TPR and FPR to calculate the correspondent Q value.
# To avoid choosing the best combination of *alpha cut* and *gammaness* solely on the performance on a specific test set, we run the same algorithm on different test sets and choose as best case the one that returns the highest average Q value over the iterations.

# %%
# !wget -q https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data

file_name="magic04.data"
data = pd.DataFrame(pd.read_csv(file_name))
data.columns=['fLength','fWidth','fSize',
        'fConc','fConc1','fAsym',
        'fM3Long','fM3Trans','fAlpha','fDist','category']

# %%
data_rescaled = data
original_alpha = data['fAlpha'].copy()

for i in data.drop(columns=['category']).columns:
    h = data[i]
    avg = np.mean(h.astype(float))
    std = np.std(h)
    h = h - avg
    h = h / std
    data_rescaled[i]= h
    
print('avg length:',np.average(data_rescaled['fLength']))
print('dev_std length:',np.std(data_rescaled['fLength']))
data_rescaled['fAlpha'] = original_alpha
data_rescaled['category'] = data['category']
data_rescaled['category'] = data_rescaled['category'].replace({'g':1,'h':-1})
# Out:
# avg length: 3.5865241407523854e-17
# dev_std length: 0.9999999999999971

# %%
N=10
test_predictions=[]
gammaness= np.arange(0.8,0.96,0.01)
alpha_cut= np.arange(2,15,1)

for i in range(1,N+1):
    print('Iteration:',i,'\n')
    
    train_set, test_set = split_train_test_set( data_rescaled, 5)
    X_train, Y_train = split_X_Y(train_set)
    X_test, Y_test = split_X_Y(test_set)
    
    best_forest.fit(X_train,Y_train) 

    for alpha in alpha_cut:
        print('\n')
        for g in gammaness:

            test_data = [ X_test[ X_test['fAlpha']<alpha], Y_test[X_test['fAlpha']<alpha] ] 
            discarded_data = X_test[X_test['fAlpha'] >= alpha]
            discarded_labels = Y_test[X_test['fAlpha'] >= alpha] # we directly classify these points as hadrons 
            
            y_pred_prob = best_forest.predict_proba(test_data[0])[:, 1]
            y_pred_label = np.where(y_pred_prob > g, 1, -1)
        
            selected_gammas= np.sum(y_pred_label==1)
            selected_hadrons= np.sum(y_pred_label==-1) + ( X_test.shape[0]-len(test_data[0])) # samples in alpha cut classified as hadron by the model + all samples previously discarded
    
            total_gammas = np.sum(Y_test==1) # over all the test set (before alpha cut)
            total_hadrons = np.sum(Y_test==-1)
            
            true_positives = np.sum( (y_pred_label==1) & (test_data[1]==1) )
            false_positives = np.sum( (y_pred_label==1) & (test_data[1]==-1) )
            true_negatives= np.sum((y_pred_label == -1) & (test_data[1] == -1)) + np.sum((discarded_labels == -1))
            false_negatives= np.sum((y_pred_label == -1) & (test_data[1] == 1)) + np.sum((discarded_labels == 1))
            
            if false_positives != 0:
                epsilon_gamma = true_positives / total_gammas # TPR
                epsilon_hadron = false_positives / total_hadrons # FPR
                Q = epsilon_gamma/np.sqrt(epsilon_hadron)
            else:
                epsilon_hadron= 0
                epsilon_gamma = true_positives / total_gammas
                Q = 'inf'
                
            test_predictions.append({
            'iteration': i,   
            'alpha_cut': alpha,
            'gamma': g,
            'test_data': test_data, 
            'pred_probs': y_pred_prob,
            'pred label': y_pred_label,
            'selected gammas': selected_gammas,
            'selected hadrons': selected_hadrons,
            'total gammas': total_gammas,
            'total hadrons': total_hadrons,
            'true positives': true_positives,
            'false positives': false_positives,
            'true negatives': true_negatives,
            'false negatives': false_negatives,
            'Q': Q })

            if Q != 'inf':
                print(f"With alpha cut {alpha} and gammaness {g:.2f}, Q = {Q:.4f}")
            else:
                print(f"With alpha cut {alpha} and gammanesss {g:.2f}, Q = {Q}")
            print(f"True positives {true_positives}; False positives {false_positives}")
# Out:
# Iteration: 1
#
#
#
# With alpha cut 2 and gammaness 0.80, Q = 1.5612
# True positives 334; False positives 10
# With alpha cut 2 and gammaness 0.81, Q = 1.5565
# True positives 333; False positives 10
# With alpha cut 2 and gammaness 0.82, Q = 1.6358
# True positives 332; False positives 9
# With alpha cut 2 and gammaness 0.83, Q = 1.7298
# True positives 331; False positives 8
# With alpha cut 2 and gammaness 0.84, Q = 1.7089
# True positives 327; False positives 8
# With alpha cut 2 and gammaness 0.85, Q = 1.9612
# True positives 325; False positives 6
# With alpha cut 2 and gammaness 0.86, Q = 2.1352
# True positives 323; False positives 5
# With alpha cut 2 and gammaness 0.87, Q = 2.1087
# True positives 319; False positives 5
# With alpha cut 2 and gammaness 0.88, Q = 2.0889
# True positives 316; False positives 5
# With alpha cut 2 and gammaness 0.89, Q = 2.2911
# True positives 310; False positives 4
# With alpha cut 2 and gammaness 0.90, Q = 2.2837
# True positives 309; False positives 4
# With alpha cut 2 and gammaness 0.91, Q = 2.2468
# True positives 304; False positives 4
# With alpha cut 2 and gammaness 0.92, Q = 2.5346
# True positives 297; False positives 3
# With alpha cut 2 and gammaness 0.93, Q = 2.4493
# True positives 287; False positives 3
# With alpha cut 2 and gammaness 0.94, Q = 2.3639
# True positives 277; False positives 3
# With alpha cut 2 and gammaness 0.95, Q = 2.2615
# True positives 265; False positives 3
#
#
# With alpha cut 3 and gammaness 0.80, Q = 1.6967
# True positives 487; False positives 18
# With alpha cut 3 and gammaness 0.81, Q = 1.6932
# True positives 486; False positives 18
# With alpha cut 3 and gammaness 0.82, Q = 1.7352
# True positives 484; False positives 17
# With alpha cut 3 and gammaness 0.83, Q = 1.7849
# True positives 483; False positives 16
# With alpha cut 3 and gammaness 0.84, Q = 1.7701
# True positives 479; False positives 16
# With alpha cut 3 and gammaness 0.85, Q = 1.9473
# True positives 475; False positives 13
# With alpha cut 3 and gammaness 0.86, Q = 2.0991
# True positives 471; False positives 11
# With alpha cut 3 and gammaness 0.87, Q = 2.0679
# True positives 464; False positives 11
# With alpha cut 3 and gammaness 0.88, Q = 2.0412
# True positives 458; False positives 11
# With alpha cut 3 and gammaness 0.89, Q = 2.1034
# True positives 450; False positives 10
# With alpha cut 3 and gammaness 0.90, Q = 2.0941
# True positives 448; False positives 10
# With alpha cut 3 and gammaness 0.91, Q = 2.0614
# True positives 441; False positives 10
# With alpha cut 3 and gammaness 0.92, Q = 2.1138
# True positives 429; False positives 9
# With alpha cut 3 and gammaness 0.93, Q = 2.0497
# True positives 416; False positives 9
# With alpha cut 3 and gammaness 0.94, Q = 2.1113
# True positives 404; False positives 8
# With alpha cut 3 and gammaness 0.95, Q = 2.0277
# True positives 388; False positives 8
#
#
# With alpha cut 4 and gammaness 0.80, Q = 1.8828
# True positives 624; False positives 24
# With alpha cut 4 and gammaness 0.81, Q = 1.9202
# True positives 623; False positives 23
# With alpha cut 4 and gammaness 0.82, Q = 2.0526
# True positives 621; False positives 20
# With alpha cut 4 and gammaness 0.83, Q = 2.1025
# True positives 620; False positives 19
# With alpha cut 4 and gammaness 0.84, Q = 2.0821
# True positives 614; False positives 19
# With alpha cut 4 and gammaness 0.85, Q = 2.2542
# True positives 610; False positives 16
# With alpha cut 4 and gammaness 0.86, Q = 2.3822
# True positives 603; False positives 14
# With alpha cut 4 and gammaness 0.87, Q = 2.3466
# True positives 594; False positives 14
# With alpha cut 4 and gammaness 0.88, Q = 2.2992
# True positives 582; False positives 14
# With alpha cut 4 and gammaness 0.89, Q = 2.4408
# True positives 572; False positives 12
# With alpha cut 4 and gammaness 0.90, Q = 2.4280
# True positives 569; False positives 12
# With alpha cut 4 and gammaness 0.91, Q = 2.5047
# True positives 562; False positives 11
# With alpha cut 4 and gammaness 0.92, Q = 2.5522
# True positives 546; False positives 10
# With alpha cut 4 and gammaness 0.93, Q = 2.4540
# True positives 525; False positives 10
# With alpha cut 4 and gammaness 0.94, Q = 2.5030
# True positives 508; False positives 9
# With alpha cut 4 and gammaness 0.95, Q = 2.3749
# True positives 482; False positives 9
#
#
# With alpha cut 5 and gammaness 0.80, Q = 2.0252
# True positives 725; False positives 28
# With alpha cut 5 and gammaness 0.81, Q = 2.0596
# True positives 724; False positives 27
# With alpha cut 5 and gammaness 0.82, Q = 2.1785
# True positives 722; False positives 24
# With alpha cut 5 and gammaness 0.83, Q = 2.2192
# True positives 720; False positives 23
# With alpha cut 5 and gammaness 0.84, Q = 2.2007
# True positives 714; False positives 23
# With alpha cut 5 and gammaness 0.85, Q = 2.3368
# True positives 707; False positives 20
# With alpha cut 5 and gammaness 0.86, Q = 2.4353
# True positives 699; False positives 18
# With alpha cut 5 and gammaness 0.87, Q = 2.4040
# True positives 690; False positives 18
# With alpha cut 5 and gammaness 0.88, Q = 2.3552
# True positives 676; False positives 18
# With alpha cut 5 and gammaness 0.89, Q = 2.4574
# True positives 665; False positives 16
# With alpha cut 5 and gammaness 0.90, Q = 2.4389
# True positives 660; False positives 16
# With alpha cut 5 and gammaness 0.91, Q = 2.4922
# True positives 653; False positives 15
# With alpha cut 5 and gammaness 0.92, Q = 2.5125
# True positives 636; False positives 14
# With alpha cut 5 and gammaness 0.93, Q = 2.4256
# True positives 614; False positives 14
# With alpha cut 5 and gammaness 0.94, Q = 2.4188
# True positives 590; False positives 13
# With alpha cut 5 and gammaness 0.95, Q = 2.2753
# True positives 555; False positives 13
#
#
# With alpha cut 6 and gammaness 0.80, Q = 2.2755
# True positives 829; False positives 29
# With alpha cut 6 and gammaness 0.81, Q = 2.3130
# True positives 828; False positives 28
# With alpha cut 6 and gammaness 0.82, Q = 2.4419
# True positives 826; False positives 25
# With alpha cut 6 and gammaness 0.83, Q = 2.4832
# True positives 823; False positives 24
# With alpha cut 6 and gammaness 0.84, Q = 2.4651
# True positives 817; False positives 24
# With alpha cut 6 and gammaness 0.85, Q = 2.6673
# True positives 807; False positives 20
# With alpha cut 6 and gammaness 0.86, Q = 2.7733
# True positives 796; False positives 18
# With alpha cut 6 and gammaness 0.87, Q = 2.7350
# True positives 785; False positives 18
# With alpha cut 6 and gammaness 0.88, Q = 2.6757
# True positives 768; False positives 18
# With alpha cut 6 and gammaness 0.89, Q = 2.7863
# True positives 754; False positives 16
# With alpha cut 6 and gammaness 0.90, Q = 2.7567
# True positives 746; False positives 16
# With alpha cut 6 and gammaness 0.91, Q = 2.8204
# True positives 739; False positives 15
# With alpha cut 6 and gammaness 0.92, Q = 2.8444
# True positives 720; False positives 14
# With alpha cut 6 and gammaness 0.93, Q = 2.7417
# True positives 694; False positives 14
# With alpha cut 6 and gammaness 0.94, Q = 2.7304
# True positives 666; False positives 13
# With alpha cut 6 and gammaness 0.95, Q = 2.5582
# True positives 624; False positives 13
#
#
# With alpha cut 7 and gammaness 0.80, Q = 2.3726
# True positives 908; False positives 32
# With alpha cut 7 and gammaness 0.81, Q = 2.4079
# True positives 907; False positives 31
# With alpha cut 7 and gammaness 0.82, Q = 2.5745
# True positives 905; False positives 27
# With alpha cut 7 and gammaness 0.83, Q = 2.6119
# True positives 901; False positives 26
# With alpha cut 7 and gammaness 0.84, Q = 2.6459
# True positives 895; False positives 25
# With alpha cut 7 and gammaness 0.85, Q = 2.8514
# True positives 884; False positives 21
# With alpha cut 7 and gammaness 0.86, Q = 3.0346
# True positives 871; False positives 18
# With alpha cut 7 and gammaness 0.87, Q = 2.9858
# True positives 857; False positives 18
# With alpha cut 7 and gammaness 0.88, Q = 2.9196
# True positives 838; False positives 18
# With alpha cut 7 and gammaness 0.89, Q = 3.0265
# True positives 819; False positives 16
# With alpha cut 7 and gammaness 0.90, Q = 2.9896
# True positives 809; False positives 16
# With alpha cut 7 and gammaness 0.91, Q = 3.0609
# True positives 802; False positives 15
# With alpha cut 7 and gammaness 0.92, Q = 3.0893
# True positives 782; False positives 14
# With alpha cut 7 and gammaness 0.93, Q = 2.9826
# True positives 755; False positives 14
# With alpha cut 7 and gammaness 0.94, Q = 2.9599
# True positives 722; False positives 13
# With alpha cut 7 and gammaness 0.95, Q = 2.7632
# True positives 674; False positives 13
#
#
# With alpha cut 8 and gammaness 0.80, Q = 2.3960
# True positives 986; False positives 37
# With alpha cut 8 and gammaness 0.81, Q = 2.4266
# True positives 985; False positives 36
# With alpha cut 8 and gammaness 0.82, Q = 2.5660
# True positives 982; False positives 32
# With alpha cut 8 and gammaness 0.83, Q = 2.5911
# True positives 976; False positives 31
# With alpha cut 8 and gammaness 0.84, Q = 2.6151
# True positives 969; False positives 30
# With alpha cut 8 and gammaness 0.85, Q = 2.7742
# True positives 957; False positives 26
# With alpha cut 8 and gammaness 0.86, Q = 2.9034
# True positives 942; False positives 23
# With alpha cut 8 and gammaness 0.87, Q = 2.8479
# True positives 924; False positives 23
# With alpha cut 8 and gammaness 0.88, Q = 2.7863
# True positives 904; False positives 23
# With alpha cut 8 and gammaness 0.89, Q = 2.8546
# True positives 885; False positives 21
# With alpha cut 8 and gammaness 0.90, Q = 2.8095
# True positives 871; False positives 21
# With alpha cut 8 and gammaness 0.91, Q = 2.8524
# True positives 863; False positives 20
# With alpha cut 8 and gammaness 0.92, Q = 2.8417
# True positives 838; False positives 19
# With alpha cut 8 and gammaness 0.93, Q = 2.8221
# True positives 810; False positives 18
# With alpha cut 8 and gammaness 0.94, Q = 2.9502
# True positives 773; False positives 15
# With alpha cut 8 and gammaness 0.95, Q = 2.7594
# True positives 723; False positives 15
#
#
# With alpha cut 9 and gammaness 0.80, Q = 2.4177
# True positives 1060; False positives 42
# With alpha cut 9 and gammaness 0.81, Q = 2.4447
# True positives 1059; False positives 41
# With alpha cut 9 and gammaness 0.82, Q = 2.5637
# True positives 1055; False positives 37
# With alpha cut 9 and gammaness 0.83, Q = 2.5818
# True positives 1048; False positives 36
# With alpha cut 9 and gammaness 0.84, Q = 2.5985
# True positives 1040; False positives 35
# With alpha cut 9 and gammaness 0.85, Q = 2.7689
# True positives 1026; False positives 30
# With alpha cut 9 and gammaness 0.86, Q = 2.9250
# True positives 1009; False positives 26
# With alpha cut 9 and gammaness 0.87, Q = 2.8728
# True positives 991; False positives 26
# With alpha cut 9 and gammaness 0.88, Q = 2.8003
# True positives 966; False positives 26
# With alpha cut 9 and gammaness 0.89, Q = 2.8513
# True positives 945; False positives 24
# With alpha cut 9 and gammaness 0.90, Q = 2.7970
# True positives 927; False positives 24
# With alpha cut 9 and gammaness 0.91, Q = 2.8263
# True positives 917; False positives 23
# With alpha cut 9 and gammaness 0.92, Q = 2.7985
# True positives 888; False positives 22
# With alpha cut 9 and gammaness 0.93, Q = 2.7579
# True positives 855; False positives 21
# With alpha cut 9 and gammaness 0.94, Q = 3.0191
# True positives 817; False positives 16
# With alpha cut 9 and gammaness 0.95, Q = 2.8233
# True positives 764; False positives 16
#
#
# With alpha cut 10 and gammaness 0.80, Q = 2.4657
# True positives 1119; False positives 45
# With alpha cut 10 and gammaness 0.81, Q = 2.4913
# True positives 1118; False positives 44
# With alpha cut 10 and gammaness 0.82, Q = 2.6344
# True positives 1113; False positives 39
# With alpha cut 10 and gammaness 0.83, Q = 2.6425
# True positives 1102; False positives 38
# With alpha cut 10 and gammaness 0.84, Q = 2.6927
# True positives 1093; False positives 36
# With alpha cut 10 and gammaness 0.85, Q = 2.8646
# True positives 1079; False positives 31
# With alpha cut 10 and gammaness 0.86, Q = 3.0211
# True positives 1062; False positives 27
# With alpha cut 10 and gammaness 0.87, Q = 2.9642
# True positives 1042; False positives 27
# With alpha cut 10 and gammaness 0.88, Q = 2.8845
# True positives 1014; False positives 27
# With alpha cut 10 and gammaness 0.89, Q = 2.9961
# True positives 993; False positives 24
# With alpha cut 10 and gammaness 0.90, Q = 2.9418
# True positives 975; False positives 24
# With alpha cut 10 and gammaness 0.91, Q = 2.9743
# True positives 965; False positives 23
# With alpha cut 10 and gammaness 0.92, Q = 2.9434
# True positives 934; False positives 22
# With alpha cut 10 and gammaness 0.93, Q = 2.8933
# True positives 897; False positives 21
# With alpha cut 10 and gammaness 0.94, Q = 3.1558
# True positives 854; False positives 16
# With alpha cut 10 and gammaness 0.95, Q = 2.9304
# True positives 793; False positives 16
#
#
# With alpha cut 11 and gammaness 0.80, Q = 2.4984
# True positives 1171; False positives 48
# With alpha cut 11 and gammaness 0.81, Q = 2.5226
# True positives 1170; False positives 47
# With alpha cut 11 and gammaness 0.82, Q = 2.6572
# True positives 1165; False positives 42
# With alpha cut 11 and gammaness 0.83, Q = 2.6971
# True positives 1154; False positives 40
# With alpha cut 11 and gammaness 0.84, Q = 2.7432
# True positives 1144; False positives 38
# With alpha cut 11 and gammaness 0.85, Q = 2.9025
# True positives 1128; False positives 33
# With alpha cut 11 and gammaness 0.86, Q = 3.1035
# True positives 1111; False positives 28
# With alpha cut 11 and gammaness 0.87, Q = 3.0421
# True positives 1089; False positives 28
# With alpha cut 11 and gammaness 0.88, Q = 2.9583
# True positives 1059; False positives 28
# With alpha cut 11 and gammaness 0.89, Q = 3.0686
# True positives 1038; False positives 25
# With alpha cut 11 and gammaness 0.90, Q = 3.0125
# True positives 1019; False positives 25
# With alpha cut 11 and gammaness 0.91, Q = 3.0354
# True positives 1006; False positives 24
# With alpha cut 11 and gammaness 0.92, Q = 2.9989
# True positives 973; False positives 23
# With alpha cut 11 and gammaness 0.93, Q = 3.0095
# True positives 933; False positives 21
# With alpha cut 11 and gammaness 0.94, Q = 3.2778
# True positives 887; False positives 16
# With alpha cut 11 and gammaness 0.95, Q = 3.0265
# True positives 819; False positives 16
#
#
# With alpha cut 12 and gammaness 0.80, Q = 2.4690
# True positives 1216; False positives 53
# With alpha cut 12 and gammaness 0.81, Q = 2.4844
# True positives 1212; False positives 52
# With alpha cut 12 and gammaness 0.82, Q = 2.5959
# True positives 1204; False positives 47
# With alpha cut 12 and gammaness 0.83, Q = 2.6288
# True positives 1193; False positives 45
# With alpha cut 12 and gammaness 0.84, Q = 2.6959
# True positives 1182; False positives 42
# With alpha cut 12 and gammaness 0.85, Q = 2.8701
# True positives 1165; False positives 36
# With alpha cut 12 and gammaness 0.86, Q = 3.0477
# True positives 1148; False positives 31
# With alpha cut 12 and gammaness 0.87, Q = 3.0280
# True positives 1122; False positives 30
# With alpha cut 12 and gammaness 0.88, Q = 2.9416
# True positives 1090; False positives 30
# With alpha cut 12 and gammaness 0.89, Q = 3.0381
# True positives 1068; False positives 27
# With alpha cut 12 and gammaness 0.90, Q = 2.9812
# True positives 1048; False positives 27
# With alpha cut 12 and gammaness 0.91, Q = 2.9975
# True positives 1034; False positives 26
# With alpha cut 12 and gammaness 0.92, Q = 3.0022
# True positives 995; False positives 24
# With alpha cut 12 and gammaness 0.93, Q = 3.0002
# True positives 952; False positives 22
# With alpha cut 12 and gammaness 0.94, Q = 3.2409
# True positives 904; False positives 17
# With alpha cut 12 and gammaness 0.95, Q = 3.0782
# True positives 833; False positives 16
#
#
# With alpha cut 13 and gammaness 0.80, Q = 2.4473
# True positives 1239; False positives 56
# With alpha cut 13 and gammaness 0.81, Q = 2.4615
# True positives 1235; False positives 55
# With alpha cut 13 and gammaness 0.82, Q = 2.5649
# True positives 1227; False positives 50
# With alpha cut 13 and gammaness 0.83, Q = 2.5944
# True positives 1216; False positives 48
# With alpha cut 13 and gammaness 0.84, Q = 2.6852
# True positives 1205; False positives 44
# With alpha cut 13 and gammaness 0.85, Q = 2.8439
# True positives 1186; False positives 38
# With alpha cut 13 and gammaness 0.86, Q = 3.0054
# True positives 1168; False positives 33
# With alpha cut 13 and gammaness 0.87, Q = 2.9815
# True positives 1141; False positives 32
# With alpha cut 13 and gammaness 0.88, Q = 2.8978
# True positives 1109; False positives 32
# With alpha cut 13 and gammaness 0.89, Q = 2.9809
# True positives 1086; False positives 29
# With alpha cut 13 and gammaness 0.90, Q = 2.9750
# True positives 1065; False positives 28
# With alpha cut 13 and gammaness 0.91, Q = 2.9869
# True positives 1050; False positives 27
# With alpha cut 13 and gammaness 0.92, Q = 2.9859
# True positives 1010; False positives 25
# With alpha cut 13 and gammaness 0.93, Q = 2.9743
# True positives 965; False positives 23
# With alpha cut 13 and gammaness 0.94, Q = 3.1914
# True positives 916; False positives 18
# With alpha cut 13 and gammaness 0.95, Q = 3.1152
# True positives 843; False positives 16
#
#
# With alpha cut 14 and gammaness 0.80, Q = 2.4785
# True positives 1277; False positives 58
# With alpha cut 14 and gammaness 0.81, Q = 2.4904
# True positives 1272; False positives 57
# With alpha cut 14 and gammaness 0.82, Q = 2.6163
# True positives 1264; False positives 51
# With alpha cut 14 and gammaness 0.83, Q = 2.6459
# True positives 1253; False positives 49
# With alpha cut 14 and gammaness 0.84, Q = 2.7345
# True positives 1241; False positives 45
# With alpha cut 14 and gammaness 0.85, Q = 2.8900
# True positives 1221; False positives 39
# With alpha cut 14 and gammaness 0.86, Q = 3.0445
# True positives 1201; False positives 34
# With alpha cut 14 and gammaness 0.87, Q = 3.0080
# True positives 1169; False positives 33
# With alpha cut 14 and gammaness 0.88, Q = 2.9231
# True positives 1136; False positives 33
# With alpha cut 14 and gammaness 0.89, Q = 2.9956
# True positives 1110; False positives 30
# With alpha cut 14 and gammaness 0.90, Q = 2.9837
# True positives 1087; False positives 29
# With alpha cut 14 and gammaness 0.91, Q = 2.9946
# True positives 1072; False positives 28
# With alpha cut 14 and gammaness 0.92, Q = 2.9830
# True positives 1029; False positives 26
# With alpha cut 14 and gammaness 0.93, Q = 2.9599
# True positives 981; False positives 24
# With alpha cut 14 and gammaness 0.94, Q = 3.1571
# True positives 931; False positives 19
# With alpha cut 14 and gammaness 0.95, Q = 3.1632
# True positives 856; False positives 16
# Iteration: 2
#
#
#
# With alpha cut 2 and gammaness 0.80, Q = 1.7105
# True positives 319; False positives 8
# With alpha cut 2 and gammaness 0.81, Q = 1.7051
# True positives 318; False positives 8
# With alpha cut 2 and gammaness 0.82, Q = 1.6997
# True positives 317; False positives 8
# With alpha cut 2 and gammaness 0.83, Q = 1.8114
# True positives 316; False positives 7
# With alpha cut 2 and gammaness 0.84, Q = 1.9379
# True positives 313; False positives 6
# With alpha cut 2 and gammaness 0.85, Q = 1.9132
# True positives 309; False positives 6
# With alpha cut 2 and gammaness 0.86, Q = 1.9008
# True positives 307; False positives 6
# With alpha cut 2 and gammaness 0.87, Q = 1.8760
# True positives 303; False positives 6
# With alpha cut 2 and gammaness 0.88, Q = 1.8513
# True positives 299; False positives 6
# With alpha cut 2 and gammaness 0.89, Q = 1.8265
# True positives 295; False positives 6
# With alpha cut 2 and gammaness 0.90, Q = 1.7770
# True positives 287; False positives 6
# With alpha cut 2 and gammaness 0.91, Q = 1.7584
# True positives 284; False positives 6
# With alpha cut 2 and gammaness 0.92, Q = 1.8855
# True positives 278; False positives 5
# With alpha cut 2 and gammaness 0.93, Q = 1.8380
# True positives 271; False positives 5
# With alpha cut 2 and gammaness 0.94, Q = 2.2416
# True positives 256; False positives 3
# With alpha cut 2 and gammaness 0.95, Q = 2.1190
# True positives 242; False positives 3
#
#
# With alpha cut 3 and gammaness 0.80, Q = 1.8992
# True positives 485; False positives 15
# With alpha cut 3 and gammaness 0.81, Q = 1.8913
# True positives 483; False positives 15
# With alpha cut 3 and gammaness 0.82, Q = 1.8874
# True positives 482; False positives 15
# With alpha cut 3 and gammaness 0.83, Q = 1.9456
# True positives 480; False positives 14
# With alpha cut 3 and gammaness 0.84, Q = 2.0752
# True positives 474; False positives 12
# With alpha cut 3 and gammaness 0.85, Q = 2.0533
# True positives 469; False positives 12
# With alpha cut 3 and gammaness 0.86, Q = 2.0445
# True positives 467; False positives 12
# With alpha cut 3 and gammaness 0.87, Q = 2.1126
# True positives 462; False positives 11
# With alpha cut 3 and gammaness 0.88, Q = 2.0806
# True positives 455; False positives 11
# With alpha cut 3 and gammaness 0.89, Q = 2.0440
# True positives 447; False positives 11
# With alpha cut 3 and gammaness 0.90, Q = 2.2092
# True positives 437; False positives 9
# With alpha cut 3 and gammaness 0.91, Q = 2.1788
# True positives 431; False positives 9
# With alpha cut 3 and gammaness 0.92, Q = 2.2574
# True positives 421; False positives 8
# With alpha cut 3 and gammaness 0.93, Q = 2.1823
# True positives 407; False positives 8
# With alpha cut 3 and gammaness 0.94, Q = 2.6384
# True positives 389; False positives 5
# With alpha cut 3 and gammaness 0.95, Q = 2.5231
# True positives 372; False positives 5
#
#
# With alpha cut 4 and gammaness 0.80, Q = 2.0958
# True positives 618; False positives 20
# With alpha cut 4 and gammaness 0.81, Q = 2.0788
# True positives 613; False positives 20
# With alpha cut 4 and gammaness 0.82, Q = 2.0754
# True positives 612; False positives 20
# With alpha cut 4 and gammaness 0.83, Q = 2.1224
# True positives 610; False positives 19
# With alpha cut 4 and gammaness 0.84, Q = 2.2217
# True positives 604; False positives 17
# With alpha cut 4 and gammaness 0.85, Q = 2.1996
# True positives 598; False positives 17
# With alpha cut 4 and gammaness 0.86, Q = 2.2559
# True positives 595; False positives 16
# With alpha cut 4 and gammaness 0.87, Q = 2.3914
# True positives 590; False positives 14
# With alpha cut 4 and gammaness 0.88, Q = 2.3550
# True positives 581; False positives 14
# With alpha cut 4 and gammaness 0.89, Q = 2.3185
# True positives 572; False positives 14
# With alpha cut 4 and gammaness 0.90, Q = 2.4473
# True positives 559; False positives 12
# With alpha cut 4 and gammaness 0.91, Q = 2.4035
# True positives 549; False positives 12
# With alpha cut 4 and gammaness 0.92, Q = 2.4464
# True positives 535; False positives 11
# With alpha cut 4 and gammaness 0.93, Q = 2.3641
# True positives 517; False positives 11
# With alpha cut 4 and gammaness 0.94, Q = 2.6542
# True positives 495; False positives 8
# With alpha cut 4 and gammaness 0.95, Q = 2.5148
# True positives 469; False positives 8
#
#
# With alpha cut 5 and gammaness 0.80, Q = 2.2258
# True positives 719; False positives 24
# With alpha cut 5 and gammaness 0.81, Q = 2.2073
# True positives 713; False positives 24
# With alpha cut 5 and gammaness 0.82, Q = 2.2011
# True positives 711; False positives 24
# With alpha cut 5 and gammaness 0.83, Q = 2.2421
# True positives 709; False positives 23
# With alpha cut 5 and gammaness 0.84, Q = 2.3840
# True positives 703; False positives 20
# With alpha cut 5 and gammaness 0.85, Q = 2.3535
# True positives 694; False positives 20
# With alpha cut 5 and gammaness 0.86, Q = 2.4665
# True positives 690; False positives 18
# With alpha cut 5 and gammaness 0.87, Q = 2.5896
# True positives 683; False positives 16
# With alpha cut 5 and gammaness 0.88, Q = 2.5479
# True positives 672; False positives 16
# With alpha cut 5 and gammaness 0.89, Q = 2.5100
# True positives 662; False positives 16
# With alpha cut 5 and gammaness 0.90, Q = 2.6103
# True positives 644; False positives 14
# With alpha cut 5 and gammaness 0.91, Q = 2.5617
# True positives 632; False positives 14
# With alpha cut 5 and gammaness 0.92, Q = 2.5995
# True positives 618; False positives 13
# With alpha cut 5 and gammaness 0.93, Q = 2.5111
# True positives 597; False positives 13
# With alpha cut 5 and gammaness 0.94, Q = 2.7385
# True positives 571; False positives 10
# With alpha cut 5 and gammaness 0.95, Q = 2.5946
# True positives 541; False positives 10
#
#
# With alpha cut 6 and gammaness 0.80, Q = 2.3445
# True positives 818; False positives 28
# With alpha cut 6 and gammaness 0.81, Q = 2.3244
# True positives 811; False positives 28
# With alpha cut 6 and gammaness 0.82, Q = 2.3158
# True positives 808; False positives 28
# With alpha cut 6 and gammaness 0.83, Q = 2.3495
# True positives 805; False positives 27
# With alpha cut 6 and gammaness 0.84, Q = 2.4735
# True positives 799; False positives 24
# With alpha cut 6 and gammaness 0.85, Q = 2.4982
# True positives 790; False positives 23
# With alpha cut 6 and gammaness 0.86, Q = 2.6013
# True positives 786; False positives 21
# With alpha cut 6 and gammaness 0.87, Q = 2.7847
# True positives 779; False positives 18
# With alpha cut 6 and gammaness 0.88, Q = 2.8176
# True positives 766; False positives 17
# With alpha cut 6 and gammaness 0.89, Q = 2.7808
# True positives 756; False positives 17
# With alpha cut 6 and gammaness 0.90, Q = 2.8821
# True positives 736; False positives 15
# With alpha cut 6 and gammaness 0.91, Q = 2.9265
# True positives 722; False positives 14
# With alpha cut 6 and gammaness 0.92, Q = 2.9738
# True positives 707; False positives 13
# With alpha cut 6 and gammaness 0.93, Q = 2.8771
# True positives 684; False positives 13
# With alpha cut 6 and gammaness 0.94, Q = 3.1365
# True positives 654; False positives 10
# With alpha cut 6 and gammaness 0.95, Q = 2.9591
# True positives 617; False positives 10
#
#
# With alpha cut 7 and gammaness 0.80, Q = 2.3382
# True positives 899; False positives 34
# With alpha cut 7 and gammaness 0.81, Q = 2.3200
# True positives 892; False positives 34
# With alpha cut 7 and gammaness 0.82, Q = 2.3096
# True positives 888; False positives 34
# With alpha cut 7 and gammaness 0.83, Q = 2.3338
# True positives 884; False positives 33
# With alpha cut 7 and gammaness 0.84, Q = 2.4256
# True positives 876; False positives 30
# With alpha cut 7 and gammaness 0.85, Q = 2.4417
# True positives 867; False positives 29
# With alpha cut 7 and gammaness 0.86, Q = 2.5159
# True positives 862; False positives 27
# With alpha cut 7 and gammaness 0.87, Q = 2.6376
# True positives 852; False positives 24
# With alpha cut 7 and gammaness 0.88, Q = 2.6500
# True positives 838; False positives 23
# With alpha cut 7 and gammaness 0.89, Q = 2.6708
# True positives 826; False positives 22
# With alpha cut 7 and gammaness 0.90, Q = 2.8008
# True positives 805; False positives 19
# With alpha cut 7 and gammaness 0.91, Q = 2.8204
# True positives 789; False positives 18
# With alpha cut 7 and gammaness 0.92, Q = 2.8396
# True positives 772; False positives 17
# With alpha cut 7 and gammaness 0.93, Q = 2.8322
# True positives 747; False positives 16
# With alpha cut 7 and gammaness 0.94, Q = 3.0075
# True positives 715; False positives 13
# With alpha cut 7 and gammaness 0.95, Q = 2.8308
# True positives 673; False positives 13
#
#
# With alpha cut 8 and gammaness 0.80, Q = 2.2512
# True positives 962; False positives 42
# With alpha cut 8 and gammaness 0.81, Q = 2.2619
# True positives 955; False positives 41
# With alpha cut 8 and gammaness 0.82, Q = 2.2525
# True positives 951; False positives 41
# With alpha cut 8 and gammaness 0.83, Q = 2.2998
# True positives 947; False positives 39
# With alpha cut 8 and gammaness 0.84, Q = 2.3735
# True positives 939; False positives 36
# With alpha cut 8 and gammaness 0.85, Q = 2.4163
# True positives 929; False positives 34
# With alpha cut 8 and gammaness 0.86, Q = 2.4719
# True positives 922; False positives 32
# With alpha cut 8 and gammaness 0.87, Q = 2.5684
# True positives 912; False positives 29
# With alpha cut 8 and gammaness 0.88, Q = 2.5738
# True positives 898; False positives 28
# With alpha cut 8 and gammaness 0.89, Q = 2.5860
# True positives 886; False positives 27
# With alpha cut 8 and gammaness 0.90, Q = 2.6747
# True positives 864; False positives 24
# With alpha cut 8 and gammaness 0.91, Q = 2.6785
# True positives 847; False positives 23
# With alpha cut 8 and gammaness 0.92, Q = 2.7436
# True positives 829; False positives 21
# With alpha cut 8 and gammaness 0.93, Q = 2.7164
# True positives 801; False positives 20
# With alpha cut 8 and gammaness 0.94, Q = 2.9043
# True positives 766; False positives 16
# With alpha cut 8 and gammaness 0.95, Q = 2.8077
# True positives 717; False positives 15
#
#
# With alpha cut 9 and gammaness 0.80, Q = 2.3121
# True positives 1034; False positives 46
# With alpha cut 9 and gammaness 0.81, Q = 2.3218
# True positives 1027; False positives 45
# With alpha cut 9 and gammaness 0.82, Q = 2.3128
# True positives 1023; False positives 45
# With alpha cut 9 and gammaness 0.83, Q = 2.3567
# True positives 1019; False positives 43
# With alpha cut 9 and gammaness 0.84, Q = 2.4479
# True positives 1008; False positives 39
# With alpha cut 9 and gammaness 0.85, Q = 2.5226
# True positives 998; False positives 36
# With alpha cut 9 and gammaness 0.86, Q = 2.5697
# True positives 988; False positives 34
# With alpha cut 9 and gammaness 0.87, Q = 2.6558
# True positives 975; False positives 31
# With alpha cut 9 and gammaness 0.88, Q = 2.6526
# True positives 958; False positives 30
# With alpha cut 9 and gammaness 0.89, Q = 2.6614
# True positives 945; False positives 29
# With alpha cut 9 and gammaness 0.90, Q = 2.7966
# True positives 922; False positives 25
# With alpha cut 9 and gammaness 0.91, Q = 2.7924
# True positives 902; False positives 24
# With alpha cut 9 and gammaness 0.92, Q = 2.8519
# True positives 882; False positives 22
# With alpha cut 9 and gammaness 0.93, Q = 2.8724
# True positives 847; False positives 20
# With alpha cut 9 and gammaness 0.94, Q = 3.0673
# True positives 809; False positives 16
# With alpha cut 9 and gammaness 0.95, Q = 2.9721
# True positives 759; False positives 15
#
#
# With alpha cut 10 and gammaness 0.80, Q = 2.3282
# True positives 1107; False positives 52
# With alpha cut 10 and gammaness 0.81, Q = 2.3360
# True positives 1100; False positives 51
# With alpha cut 10 and gammaness 0.82, Q = 2.3212
# True positives 1093; False positives 51
# With alpha cut 10 and gammaness 0.83, Q = 2.3529
# True positives 1086; False positives 49
# With alpha cut 10 and gammaness 0.84, Q = 2.4281
# True positives 1074; False positives 45
# With alpha cut 10 and gammaness 0.85, Q = 2.4852
# True positives 1062; False positives 42
# With alpha cut 10 and gammaness 0.86, Q = 2.5402
# True positives 1046; False positives 39
# With alpha cut 10 and gammaness 0.87, Q = 2.6085
# True positives 1032; False positives 36
# With alpha cut 10 and gammaness 0.88, Q = 2.5943
# True positives 1012; False positives 35
# With alpha cut 10 and gammaness 0.89, Q = 2.6269
# True positives 995; False positives 33
# With alpha cut 10 and gammaness 0.90, Q = 2.7261
# True positives 968; False positives 29
# With alpha cut 10 and gammaness 0.91, Q = 2.7142
# True positives 947; False positives 28
# With alpha cut 10 and gammaness 0.92, Q = 2.8027
# True positives 924; False positives 25
# With alpha cut 10 and gammaness 0.93, Q = 2.8081
# True positives 888; False positives 23
# With alpha cut 10 and gammaness 0.94, Q = 3.0099
# True positives 842; False positives 18
# With alpha cut 10 and gammaness 0.95, Q = 2.8948
# True positives 787; False positives 17
#
#
# With alpha cut 11 and gammaness 0.80, Q = 2.3001
# True positives 1155; False positives 58
# With alpha cut 11 and gammaness 0.81, Q = 2.3041
# True positives 1147; False positives 57
# With alpha cut 11 and gammaness 0.82, Q = 2.2880
# True positives 1139; False positives 57
# With alpha cut 11 and gammaness 0.83, Q = 2.3149
# True positives 1132; False positives 55
# With alpha cut 11 and gammaness 0.84, Q = 2.3785
# True positives 1120; False positives 51
# With alpha cut 11 and gammaness 0.85, Q = 2.4511
# True positives 1108; False positives 47
# With alpha cut 11 and gammaness 0.86, Q = 2.4898
# True positives 1089; False positives 44
# With alpha cut 11 and gammaness 0.87, Q = 2.5682
# True positives 1071; False positives 40
# With alpha cut 11 and gammaness 0.88, Q = 2.5499
# True positives 1050; False positives 39
# With alpha cut 11 and gammaness 0.89, Q = 2.5755
# True positives 1033; False positives 37
# With alpha cut 11 and gammaness 0.90, Q = 2.6453
# True positives 1002; False positives 33
# With alpha cut 11 and gammaness 0.91, Q = 2.6274
# True positives 980; False positives 32
# With alpha cut 11 and gammaness 0.92, Q = 2.6895
# True positives 955; False positives 29
# With alpha cut 11 and gammaness 0.93, Q = 2.6706
# True positives 915; False positives 27
# With alpha cut 11 and gammaness 0.94, Q = 2.8034
# True positives 867; False positives 22
# With alpha cut 11 and gammaness 0.95, Q = 2.7469
# True positives 810; False positives 20
#
#
# With alpha cut 12 and gammaness 0.80, Q = 2.3456
# True positives 1198; False positives 60
# With alpha cut 12 and gammaness 0.81, Q = 2.3496
# True positives 1190; False positives 59
# With alpha cut 12 and gammaness 0.82, Q = 2.3318
# True positives 1181; False positives 59
# With alpha cut 12 and gammaness 0.83, Q = 2.3543
# True positives 1172; False positives 57
# With alpha cut 12 and gammaness 0.84, Q = 2.4165
# True positives 1160; False positives 53
# With alpha cut 12 and gammaness 0.85, Q = 2.4851
# True positives 1147; False positives 49
# With alpha cut 12 and gammaness 0.86, Q = 2.5502
# True positives 1128; False positives 45
# With alpha cut 12 and gammaness 0.87, Q = 2.6243
# True positives 1108; False positives 41
# With alpha cut 12 and gammaness 0.88, Q = 2.5994
# True positives 1084; False positives 40
# With alpha cut 12 and gammaness 0.89, Q = 2.6202
# True positives 1065; False positives 38
# With alpha cut 12 and gammaness 0.90, Q = 2.6816
# True positives 1031; False positives 34
# With alpha cut 12 and gammaness 0.91, Q = 2.6585
# True positives 1007; False positives 33
# With alpha cut 12 and gammaness 0.92, Q = 2.7543
# True positives 978; False positives 29
# With alpha cut 12 and gammaness 0.93, Q = 2.7261
# True positives 934; False positives 27
# With alpha cut 12 and gammaness 0.94, Q = 2.8583
# True positives 884; False positives 22
# With alpha cut 12 and gammaness 0.95, Q = 2.8045
# True positives 827; False positives 20
#
#
# With alpha cut 13 and gammaness 0.80, Q = 2.3521
# True positives 1231; False positives 63
# With alpha cut 13 and gammaness 0.81, Q = 2.3709
# True positives 1221; False positives 61
# With alpha cut 13 and gammaness 0.82, Q = 2.3515
# True positives 1211; False positives 61
# With alpha cut 13 and gammaness 0.83, Q = 2.3713
# True positives 1201; False positives 59
# With alpha cut 13 and gammaness 0.84, Q = 2.4315
# True positives 1189; False positives 55
# With alpha cut 13 and gammaness 0.85, Q = 2.4953
# True positives 1175; False positives 51
# With alpha cut 13 and gammaness 0.86, Q = 2.5529
# True positives 1154; False positives 47
# With alpha cut 13 and gammaness 0.87, Q = 2.6537
# True positives 1134; False positives 42
# With alpha cut 13 and gammaness 0.88, Q = 2.6267
# True positives 1109; False positives 41
# With alpha cut 13 and gammaness 0.89, Q = 2.6422
# True positives 1088; False positives 39
# With alpha cut 13 and gammaness 0.90, Q = 2.6943
# True positives 1051; False positives 35
# With alpha cut 13 and gammaness 0.91, Q = 2.6660
# True positives 1025; False positives 34
# With alpha cut 13 and gammaness 0.92, Q = 2.7551
# True positives 995; False positives 30
# With alpha cut 13 and gammaness 0.93, Q = 2.7228
# True positives 950; False positives 28
# With alpha cut 13 and gammaness 0.94, Q = 2.8334
# True positives 896; False positives 23
# With alpha cut 13 and gammaness 0.95, Q = 2.7700
# True positives 837; False positives 21
#
#
# With alpha cut 14 and gammaness 0.80, Q = 2.3549
# True positives 1271; False positives 67
# With alpha cut 14 and gammaness 0.81, Q = 2.3702
# True positives 1260; False positives 65
# With alpha cut 14 and gammaness 0.82, Q = 2.3514
# True positives 1250; False positives 65
# With alpha cut 14 and gammaness 0.83, Q = 2.3674
# True positives 1239; False positives 63
# With alpha cut 14 and gammaness 0.84, Q = 2.4207
# True positives 1226; False positives 59
# With alpha cut 14 and gammaness 0.85, Q = 2.4785
# True positives 1212; False positives 55
# With alpha cut 14 and gammaness 0.86, Q = 2.5502
# True positives 1189; False positives 50
# With alpha cut 14 and gammaness 0.87, Q = 2.6406
# True positives 1168; False positives 45
# With alpha cut 14 and gammaness 0.88, Q = 2.6042
# True positives 1139; False positives 44
# With alpha cut 14 and gammaness 0.89, Q = 2.6116
# True positives 1116; False positives 42
# With alpha cut 14 and gammaness 0.90, Q = 2.6546
# True positives 1079; False positives 38
# With alpha cut 14 and gammaness 0.91, Q = 2.6591
# True positives 1052; False positives 36
# With alpha cut 14 and gammaness 0.92, Q = 2.7239
# True positives 1016; False positives 32
# With alpha cut 14 and gammaness 0.93, Q = 2.6831
# True positives 969; False positives 30
# With alpha cut 14 and gammaness 0.94, Q = 2.8264
# True positives 913; False positives 24
# With alpha cut 14 and gammaness 0.95, Q = 2.7581
# True positives 853; False positives 22
# Iteration: 3
#
#
#
# With alpha cut 2 and gammaness 0.80, Q = 1.4511
# True positives 333; False positives 12
# With alpha cut 2 and gammaness 0.81, Q = 1.4424
# True positives 331; False positives 12
# With alpha cut 2 and gammaness 0.82, Q = 1.4929
# True positives 328; False positives 11
# With alpha cut 2 and gammaness 0.83, Q = 1.4747
# True positives 324; False positives 11
# With alpha cut 2 and gammaness 0.84, Q = 1.5180
# True positives 318; False positives 10
# With alpha cut 2 and gammaness 0.85, Q = 1.5951
# True positives 317; False positives 9
# With alpha cut 2 and gammaness 0.86, Q = 1.5901
# True positives 316; False positives 9
# With alpha cut 2 and gammaness 0.87, Q = 1.7801
# True positives 312; False positives 7
# With alpha cut 2 and gammaness 0.88, Q = 1.7630
# True positives 309; False positives 7
# With alpha cut 2 and gammaness 0.89, Q = 2.0388
# True positives 302; False positives 5
# With alpha cut 2 and gammaness 0.90, Q = 1.9983
# True positives 296; False positives 5
# With alpha cut 2 and gammaness 0.91, Q = 2.2115
# True positives 293; False positives 4
# With alpha cut 2 and gammaness 0.92, Q = 2.1285
# True positives 282; False positives 4
# With alpha cut 2 and gammaness 0.93, Q = 2.3880
# True positives 274; False positives 3
# With alpha cut 2 and gammaness 0.94, Q = 2.3357
# True positives 268; False positives 3
# With alpha cut 2 and gammaness 0.95, Q = 2.7005
# True positives 253; False positives 2
#
#
# With alpha cut 3 and gammaness 0.80, Q = 1.8124
# True positives 465; False positives 15
# With alpha cut 3 and gammaness 0.81, Q = 1.8046
# True positives 463; False positives 15
# With alpha cut 3 and gammaness 0.82, Q = 1.8478
# True positives 458; False positives 14
# With alpha cut 3 and gammaness 0.83, Q = 1.8316
# True positives 454; False positives 14
# With alpha cut 3 and gammaness 0.84, Q = 1.8757
# True positives 448; False positives 13
# With alpha cut 3 and gammaness 0.85, Q = 1.9392
# True positives 445; False positives 12
# With alpha cut 3 and gammaness 0.86, Q = 1.9305
# True positives 443; False positives 12
# With alpha cut 3 and gammaness 0.87, Q = 2.0861
# True positives 437; False positives 10
# With alpha cut 3 and gammaness 0.88, Q = 2.0670
# True positives 433; False positives 10
# With alpha cut 3 and gammaness 0.89, Q = 2.2682
# True positives 425; False positives 8
# With alpha cut 3 and gammaness 0.90, Q = 2.2255
# True positives 417; False positives 8
# With alpha cut 3 and gammaness 0.91, Q = 2.3564
# True positives 413; False positives 7
# With alpha cut 3 and gammaness 0.92, Q = 2.4651
# True positives 400; False positives 6
# With alpha cut 3 and gammaness 0.93, Q = 2.9134
# True positives 386; False positives 4
# With alpha cut 3 and gammaness 0.94, Q = 2.8153
# True positives 373; False positives 4
# With alpha cut 3 and gammaness 0.95, Q = 3.0765
# True positives 353; False positives 3
#
#
# With alpha cut 4 and gammaness 0.80, Q = 1.9913
# True positives 575; False positives 19
# With alpha cut 4 and gammaness 0.81, Q = 1.9844
# True positives 573; False positives 19
# With alpha cut 4 and gammaness 0.82, Q = 2.0174
# True positives 567; False positives 18
# With alpha cut 4 and gammaness 0.83, Q = 1.9996
# True positives 562; False positives 18
# With alpha cut 4 and gammaness 0.84, Q = 2.0356
# True positives 556; False positives 17
# With alpha cut 4 and gammaness 0.85, Q = 2.0869
# True positives 553; False positives 16
# With alpha cut 4 and gammaness 0.86, Q = 2.0794
# True positives 551; False positives 16
# With alpha cut 4 and gammaness 0.87, Q = 2.1826
# True positives 541; False positives 14
# With alpha cut 4 and gammaness 0.88, Q = 2.1625
# True positives 536; False positives 14
# With alpha cut 4 and gammaness 0.89, Q = 2.2921
# True positives 526; False positives 12
# With alpha cut 4 and gammaness 0.90, Q = 2.2573
# True positives 518; False positives 12
# With alpha cut 4 and gammaness 0.91, Q = 2.3303
# True positives 512; False positives 11
# With alpha cut 4 and gammaness 0.92, Q = 2.3486
# True positives 492; False positives 10
# With alpha cut 4 and gammaness 0.93, Q = 2.5404
# True positives 476; False positives 8
# With alpha cut 4 and gammaness 0.94, Q = 2.4550
# True positives 460; False positives 8
# With alpha cut 4 and gammaness 0.95, Q = 2.5047
# True positives 439; False positives 7
#
#
# With alpha cut 5 and gammaness 0.80, Q = 2.0737
# True positives 673; False positives 24
# With alpha cut 5 and gammaness 0.81, Q = 2.0614
# True positives 669; False positives 24
# With alpha cut 5 and gammaness 0.82, Q = 2.0869
# True positives 663; False positives 23
# With alpha cut 5 and gammaness 0.83, Q = 2.0680
# True positives 657; False positives 23
# With alpha cut 5 and gammaness 0.84, Q = 2.0952
# True positives 651; False positives 22
# With alpha cut 5 and gammaness 0.85, Q = 2.1839
# True positives 647; False positives 20
# With alpha cut 5 and gammaness 0.86, Q = 2.1704
# True positives 643; False positives 20
# With alpha cut 5 and gammaness 0.87, Q = 2.2380
# True positives 629; False positives 18
# With alpha cut 5 and gammaness 0.88, Q = 2.2202
# True positives 624; False positives 18
# With alpha cut 5 and gammaness 0.89, Q = 2.3931
# True positives 614; False positives 15
# With alpha cut 5 and gammaness 0.90, Q = 2.3542
# True positives 604; False positives 15
# With alpha cut 5 and gammaness 0.91, Q = 2.4045
# True positives 596; False positives 14
# With alpha cut 5 and gammaness 0.92, Q = 2.3990
# True positives 573; False positives 13
# With alpha cut 5 and gammaness 0.93, Q = 2.5261
# True positives 555; False positives 11
# With alpha cut 5 and gammaness 0.94, Q = 2.4305
# True positives 534; False positives 11
# With alpha cut 5 and gammaness 0.95, Q = 2.4345
# True positives 510; False positives 10
#
#
# With alpha cut 6 and gammaness 0.80, Q = 2.2280
# True positives 781; False positives 28
# With alpha cut 6 and gammaness 0.81, Q = 2.2138
# True positives 776; False positives 28
# With alpha cut 6 and gammaness 0.82, Q = 2.2369
# True positives 770; False positives 27
# With alpha cut 6 and gammaness 0.83, Q = 2.2195
# True positives 764; False positives 27
# With alpha cut 6 and gammaness 0.84, Q = 2.2440
# True positives 758; False positives 26
# With alpha cut 6 and gammaness 0.85, Q = 2.3702
# True positives 753; False positives 23
# With alpha cut 6 and gammaness 0.86, Q = 2.4640
# True positives 748; False positives 21
# With alpha cut 6 and gammaness 0.87, Q = 2.5385
# True positives 733; False positives 19
# With alpha cut 6 and gammaness 0.88, Q = 2.5073
# True positives 724; False positives 19
# With alpha cut 6 and gammaness 0.89, Q = 2.6870
# True positives 712; False positives 16
# With alpha cut 6 and gammaness 0.90, Q = 2.6342
# True positives 698; False positives 16
# With alpha cut 6 and gammaness 0.91, Q = 2.6738
# True positives 686; False positives 15
# With alpha cut 6 and gammaness 0.92, Q = 2.6708
# True positives 662; False positives 14
# With alpha cut 6 and gammaness 0.93, Q = 2.7889
# True positives 640; False positives 12
# With alpha cut 6 and gammaness 0.94, Q = 2.7991
# True positives 615; False positives 11
# With alpha cut 6 and gammaness 0.95, Q = 2.7878
# True positives 584; False positives 10
#
#
# With alpha cut 7 and gammaness 0.80, Q = 2.3109
# True positives 866; False positives 32
# With alpha cut 7 and gammaness 0.81, Q = 2.2923
# True positives 859; False positives 32
# With alpha cut 7 and gammaness 0.82, Q = 2.3073
# True positives 851; False positives 31
# With alpha cut 7 and gammaness 0.83, Q = 2.2910
# True positives 845; False positives 31
# With alpha cut 7 and gammaness 0.84, Q = 2.3068
# True positives 837; False positives 30
# With alpha cut 7 and gammaness 0.85, Q = 2.4142
# True positives 831; False positives 27
# With alpha cut 7 and gammaness 0.86, Q = 2.4877
# True positives 824; False positives 25
# With alpha cut 7 and gammaness 0.87, Q = 2.5401
# True positives 807; False positives 23
# With alpha cut 7 and gammaness 0.88, Q = 2.5554
# True positives 794; False positives 22
# With alpha cut 7 and gammaness 0.89, Q = 2.6978
# True positives 779; False positives 19
# With alpha cut 7 and gammaness 0.90, Q = 2.6389
# True positives 762; False positives 19
# With alpha cut 7 and gammaness 0.91, Q = 2.6650
# True positives 749; False positives 18
# With alpha cut 7 and gammaness 0.92, Q = 2.6361
# True positives 720; False positives 17
# With alpha cut 7 and gammaness 0.93, Q = 2.6972
# True positives 692; False positives 15
# With alpha cut 7 and gammaness 0.94, Q = 2.6829
# True positives 665; False positives 14
# With alpha cut 7 and gammaness 0.95, Q = 2.7366
# True positives 628; False positives 12
#
#
# With alpha cut 8 and gammaness 0.80, Q = 2.3055
# True positives 929; False positives 37
# With alpha cut 8 and gammaness 0.81, Q = 2.2881
# True positives 922; False positives 37
# With alpha cut 8 and gammaness 0.82, Q = 2.2970
# True positives 913; False positives 36
# With alpha cut 8 and gammaness 0.83, Q = 2.2794
# True positives 906; False positives 36
# With alpha cut 8 and gammaness 0.84, Q = 2.2862
# True positives 896; False positives 35
# With alpha cut 8 and gammaness 0.85, Q = 2.3670
# True positives 887; False positives 32
# With alpha cut 8 and gammaness 0.86, Q = 2.4640
# True positives 879; False positives 29
# With alpha cut 8 and gammaness 0.87, Q = 2.5042
# True positives 862; False positives 27
# With alpha cut 8 and gammaness 0.88, Q = 2.5602
# True positives 848; False positives 25
# With alpha cut 8 and gammaness 0.89, Q = 2.6745
# True positives 831; False positives 22
# With alpha cut 8 and gammaness 0.90, Q = 2.6748
# True positives 812; False positives 21
# With alpha cut 8 and gammaness 0.91, Q = 2.6936
# True positives 798; False positives 20
# With alpha cut 8 and gammaness 0.92, Q = 2.7326
# True positives 768; False positives 18
# With alpha cut 8 and gammaness 0.93, Q = 2.7776
# True positives 736; False positives 16
# With alpha cut 8 and gammaness 0.94, Q = 2.8483
# True positives 706; False positives 14
# With alpha cut 8 and gammaness 0.95, Q = 2.8935
# True positives 664; False positives 12
#
#
# With alpha cut 9 and gammaness 0.80, Q = 2.4269
# True positives 1004; False positives 39
# With alpha cut 9 and gammaness 0.81, Q = 2.4100
# True positives 997; False positives 39
# With alpha cut 9 and gammaness 0.82, Q = 2.4145
# True positives 986; False positives 38
# With alpha cut 9 and gammaness 0.83, Q = 2.3949
# True positives 978; False positives 38
# With alpha cut 9 and gammaness 0.84, Q = 2.3998
# True positives 967; False positives 37
# With alpha cut 9 and gammaness 0.85, Q = 2.4749
# True positives 956; False positives 34
# With alpha cut 9 and gammaness 0.86, Q = 2.5702
# True positives 948; False positives 31
# With alpha cut 9 and gammaness 0.87, Q = 2.6097
# True positives 931; False positives 29
# With alpha cut 9 and gammaness 0.88, Q = 2.6582
# True positives 915; False positives 27
# With alpha cut 9 and gammaness 0.89, Q = 2.8869
# True positives 897; False positives 22
# With alpha cut 9 and gammaness 0.90, Q = 2.8725
# True positives 872; False positives 21
# With alpha cut 9 and gammaness 0.91, Q = 2.8894
# True positives 856; False positives 20
# With alpha cut 9 and gammaness 0.92, Q = 2.9318
# True positives 824; False positives 18
# With alpha cut 9 and gammaness 0.93, Q = 2.9738
# True positives 788; False positives 16
# With alpha cut 9 and gammaness 0.94, Q = 3.0500
# True positives 756; False positives 14
# With alpha cut 9 and gammaness 0.95, Q = 3.1027
# True positives 712; False positives 12
#
#
# With alpha cut 10 and gammaness 0.80, Q = 2.4947
# True positives 1071; False positives 42
# With alpha cut 10 and gammaness 0.81, Q = 2.4784
# True positives 1064; False positives 42
# With alpha cut 10 and gammaness 0.82, Q = 2.5133
# True positives 1053; False positives 40
# With alpha cut 10 and gammaness 0.83, Q = 2.4894
# ...
# With alpha cut 3 and gammaness 0.90, Q = 2.8225
# True positives 458; False positives 6
# With alpha cut 3 and gammaness 0.91, Q = 2.7732
# True positives 450; False positives 6
# With alpha cut 3 and gammaness 0.92, Q = 2.9434
# True positives 436; False positives 5
# With alpha cut 3 and gammaness 0.93, Q = 3.6256
# True positives 416; False positives 3
# With alpha cut 3 and gammaness 0.94, Q = 3.5384
# True positives 406; False positives 3
# With alpha cut 3 and gammaness 0.95, Q = 3.3816
# True positives 388; False positives 3
#
#
# With alpha cut 4 and gammaness 0.80, Q = 2.0179
# True positives 627; False positives 22
# With alpha cut 4 and gammaness 0.81, Q = 2.0147
# True positives 626; False positives 22
# With alpha cut 4 and gammaness 0.82, Q = 2.1063
# True positives 624; False positives 20
# With alpha cut 4 and gammaness 0.83, Q = 2.1506
# True positives 621; False positives 19
# With alpha cut 4 and gammaness 0.84, Q = 2.1333
# True positives 616; False positives 19
# With alpha cut 4 and gammaness 0.85, Q = 2.1740
# True positives 611; False positives 18
# With alpha cut 4 and gammaness 0.86, Q = 2.1526
# True positives 605; False positives 18
# With alpha cut 4 and gammaness 0.87, Q = 2.3464
# True positives 602; False positives 15
# With alpha cut 4 and gammaness 0.88, Q = 2.3152
# True positives 594; False positives 15
# With alpha cut 4 and gammaness 0.89, Q = 2.4367
# True positives 582; False positives 13
# With alpha cut 4 and gammaness 0.90, Q = 2.7353
# True positives 573; False positives 10
# With alpha cut 4 and gammaness 0.91, Q = 2.6780
# True positives 561; False positives 10
# With alpha cut 4 and gammaness 0.92, Q = 2.7423
# True positives 545; False positives 9
# With alpha cut 4 and gammaness 0.93, Q = 2.9726
# True positives 521; False positives 7
# With alpha cut 4 and gammaness 0.94, Q = 2.8984
# True positives 508; False positives 7
# With alpha cut 4 and gammaness 0.95, Q = 2.7501
# True positives 482; False positives 7
#
#
# With alpha cut 5 and gammaness 0.80, Q = 2.0127
# True positives 718; False positives 29
# With alpha cut 5 and gammaness 0.81, Q = 2.0099
# True positives 717; False positives 29
# With alpha cut 5 and gammaness 0.82, Q = 2.0772
# True positives 715; False positives 27
# With alpha cut 5 and gammaness 0.83, Q = 2.1078
# True positives 712; False positives 26
# With alpha cut 5 and gammaness 0.84, Q = 2.0871
# True positives 705; False positives 26
# With alpha cut 5 and gammaness 0.85, Q = 2.1073
# True positives 698; False positives 25
# With alpha cut 5 and gammaness 0.86, Q = 2.0832
# True positives 690; False positives 25
# With alpha cut 5 and gammaness 0.87, Q = 2.2110
# True positives 687; False positives 22
# With alpha cut 5 and gammaness 0.88, Q = 2.2334
# True positives 678; False positives 21
# With alpha cut 5 and gammaness 0.89, Q = 2.3625
# True positives 664; False positives 18
# With alpha cut 5 and gammaness 0.90, Q = 2.5452
# True positives 653; False positives 15
# With alpha cut 5 and gammaness 0.91, Q = 2.4945
# True positives 640; False positives 15
# With alpha cut 5 and gammaness 0.92, Q = 2.5916
# True positives 619; False positives 13
# With alpha cut 5 and gammaness 0.93, Q = 2.6990
# True positives 593; False positives 11
# With alpha cut 5 and gammaness 0.94, Q = 2.7544
# True positives 577; False positives 10
# With alpha cut 5 and gammaness 0.95, Q = 2.6112
# True positives 547; False positives 10
#
#
# With alpha cut 6 and gammaness 0.80, Q = 2.0642
# True positives 809; False positives 35
# With alpha cut 6 and gammaness 0.81, Q = 2.1232
# True positives 808; False positives 33
# With alpha cut 6 and gammaness 0.82, Q = 2.1825
# True positives 805; False positives 31
# With alpha cut 6 and gammaness 0.83, Q = 2.2103
# True positives 802; False positives 30
# With alpha cut 6 and gammaness 0.84, Q = 2.2285
# True positives 795; False positives 29
# With alpha cut 6 and gammaness 0.85, Q = 2.2423
# True positives 786; False positives 28
# With alpha cut 6 and gammaness 0.86, Q = 2.2195
# True positives 778; False positives 28
# With alpha cut 6 and gammaness 0.87, Q = 2.3338
# True positives 773; False positives 25
# With alpha cut 6 and gammaness 0.88, Q = 2.4016
# True positives 763; False positives 23
# With alpha cut 6 and gammaness 0.89, Q = 2.5215
# True positives 747; False positives 20
# With alpha cut 6 and gammaness 0.90, Q = 2.6873
# True positives 734; False positives 17
# With alpha cut 6 and gammaness 0.91, Q = 2.6324
# True positives 719; False positives 17
# With alpha cut 6 and gammaness 0.92, Q = 2.7127
# True positives 696; False positives 15
# With alpha cut 6 and gammaness 0.93, Q = 2.8009
# True positives 669; False positives 13
# With alpha cut 6 and gammaness 0.94, Q = 2.9448
# True positives 647; False positives 11
# With alpha cut 6 and gammaness 0.95, Q = 2.9262
# True positives 613; False positives 10
#
#
# With alpha cut 7 and gammaness 0.80, Q = 2.0637
# True positives 886; False positives 42
# With alpha cut 7 and gammaness 0.81, Q = 2.1123
# True positives 885; False positives 40
# With alpha cut 7 and gammaness 0.82, Q = 2.1598
# True positives 882; False positives 38
# With alpha cut 7 and gammaness 0.83, Q = 2.2090
# True positives 878; False positives 36
# With alpha cut 7 and gammaness 0.84, Q = 2.2224
# True positives 871; False positives 35
# With alpha cut 7 and gammaness 0.85, Q = 2.2316
# True positives 862; False positives 34
# With alpha cut 7 and gammaness 0.86, Q = 2.2441
# True positives 854; False positives 33
# With alpha cut 7 and gammaness 0.87, Q = 2.3771
# True positives 848; False positives 29
# With alpha cut 7 and gammaness 0.88, Q = 2.4200
# True positives 833; False positives 27
# With alpha cut 7 and gammaness 0.89, Q = 2.4990
# True positives 811; False positives 24
# With alpha cut 7 and gammaness 0.90, Q = 2.6869
# True positives 796; False positives 20
# With alpha cut 7 and gammaness 0.91, Q = 2.6328
# True positives 780; False positives 20
# With alpha cut 7 and gammaness 0.92, Q = 2.6863
# True positives 755; False positives 18
# With alpha cut 7 and gammaness 0.93, Q = 2.7210
# True positives 721; False positives 16
# With alpha cut 7 and gammaness 0.94, Q = 2.7999
# True positives 694; False positives 14
# With alpha cut 7 and gammaness 0.95, Q = 2.8543
# True positives 655; False positives 12
#
#
# With alpha cut 8 and gammaness 0.80, Q = 2.1715
# True positives 965; False positives 45
# With alpha cut 8 and gammaness 0.81, Q = 2.2192
# True positives 964; False positives 43
# With alpha cut 8 and gammaness 0.82, Q = 2.2632
# True positives 960; False positives 41
# With alpha cut 8 and gammaness 0.83, Q = 2.3060
# True positives 954; False positives 39
# With alpha cut 8 and gammaness 0.84, Q = 2.3141
# True positives 945; False positives 38
# With alpha cut 8 and gammaness 0.85, Q = 2.3204
# True positives 935; False positives 37
# With alpha cut 8 and gammaness 0.86, Q = 2.3297
# True positives 926; False positives 36
# With alpha cut 8 and gammaness 0.87, Q = 2.4497
# True positives 918; False positives 32
# With alpha cut 8 and gammaness 0.88, Q = 2.4832
# True positives 901; False positives 30
# With alpha cut 8 and gammaness 0.89, Q = 2.5507
# True positives 878; False positives 27
# With alpha cut 8 and gammaness 0.90, Q = 2.7132
# True positives 862; False positives 23
# With alpha cut 8 and gammaness 0.91, Q = 2.6597
# True positives 845; False positives 23
# With alpha cut 8 and gammaness 0.92, Q = 2.6880
# True positives 816; False positives 21
# With alpha cut 8 and gammaness 0.93, Q = 2.6943
# True positives 778; False positives 19
# With alpha cut 8 and gammaness 0.94, Q = 2.8304
# True positives 750; False positives 16
# With alpha cut 8 and gammaness 0.95, Q = 2.8564
# True positives 708; False positives 14
#
#
# With alpha cut 9 and gammaness 0.80, Q = 2.2834
# True positives 1037; False positives 47
# With alpha cut 9 and gammaness 0.81, Q = 2.3313
# True positives 1036; False positives 45
# With alpha cut 9 and gammaness 0.82, Q = 2.3734
# True positives 1031; False positives 43
# With alpha cut 9 and gammaness 0.83, Q = 2.4141
# True positives 1024; False positives 41
# With alpha cut 9 and gammaness 0.84, Q = 2.4202
# True positives 1014; False positives 40
# With alpha cut 9 and gammaness 0.85, Q = 2.4245
# True positives 1003; False positives 39
# With alpha cut 9 and gammaness 0.86, Q = 2.4317
# True positives 993; False positives 38
# With alpha cut 9 and gammaness 0.87, Q = 2.5500
# True positives 985; False positives 34
# With alpha cut 9 and gammaness 0.88, Q = 2.6218
# True positives 967; False positives 31
# With alpha cut 9 and gammaness 0.89, Q = 2.6845
# True positives 941; False positives 28
# With alpha cut 9 and gammaness 0.90, Q = 2.8410
# True positives 922; False positives 24
# With alpha cut 9 and gammaness 0.91, Q = 2.7855
# True positives 904; False positives 24
# With alpha cut 9 and gammaness 0.92, Q = 2.8128
# True positives 874; False positives 22
# With alpha cut 9 and gammaness 0.93, Q = 2.8117
# True positives 833; False positives 20
# With alpha cut 9 and gammaness 0.94, Q = 2.9363
# True positives 802; False positives 17
# With alpha cut 9 and gammaness 0.95, Q = 2.9466
# True positives 756; False positives 15
#
#
# With alpha cut 10 and gammaness 0.80, Q = 2.3483
# True positives 1100; False positives 50
# With alpha cut 10 and gammaness 0.81, Q = 2.4177
# True positives 1098; False positives 47
# With alpha cut 10 and gammaness 0.82, Q = 2.4551
# True positives 1091; False positives 45
# With alpha cut 10 and gammaness 0.83, Q = 2.4954
# True positives 1084; False positives 43
# With alpha cut 10 and gammaness 0.84, Q = 2.4923
# True positives 1070; False positives 42
# With alpha cut 10 and gammaness 0.85, Q = 2.5252
# True positives 1058; False positives 40
# With alpha cut 10 and gammaness 0.86, Q = 2.5236
# True positives 1044; False positives 39
# With alpha cut 10 and gammaness 0.87, Q = 2.6358
# True positives 1033; False positives 35
# With alpha cut 10 and gammaness 0.88, Q = 2.7329
# True positives 1008; False positives 31
# With alpha cut 10 and gammaness 0.89, Q = 2.7900
# True positives 978; False positives 28
# With alpha cut 10 and gammaness 0.90, Q = 2.9519
# True positives 958; False positives 24
# With alpha cut 10 and gammaness 0.91, Q = 2.8965
# True positives 940; False positives 24
# With alpha cut 10 and gammaness 0.92, Q = 2.9223
# True positives 908; False positives 22
# With alpha cut 10 and gammaness 0.93, Q = 2.9198
# True positives 865; False positives 20
# With alpha cut 10 and gammaness 0.94, Q = 3.0315
# True positives 828; False positives 17
# With alpha cut 10 and gammaness 0.95, Q = 3.0168
# True positives 774; False positives 15
#
#
# With alpha cut 11 and gammaness 0.80, Q = 2.3428
# True positives 1151; False positives 55
# With alpha cut 11 and gammaness 0.81, Q = 2.4011
# True positives 1147; False positives 52
# With alpha cut 11 and gammaness 0.82, Q = 2.4316
# True positives 1139; False positives 50
# With alpha cut 11 and gammaness 0.83, Q = 2.4621
# True positives 1130; False positives 48
# With alpha cut 11 and gammaness 0.84, Q = 2.4573
# True positives 1116; False positives 47
# With alpha cut 11 and gammaness 0.85, Q = 2.5368
# True positives 1102; False positives 43
# With alpha cut 11 and gammaness 0.86, Q = 2.5249
# True positives 1084; False positives 42
# With alpha cut 11 and gammaness 0.87, Q = 2.6276
# True positives 1073; False positives 38
# With alpha cut 11 and gammaness 0.88, Q = 2.7079
# True positives 1046; False positives 34
# With alpha cut 11 and gammaness 0.89, Q = 2.7974
# True positives 1015; False positives 30
# With alpha cut 11 and gammaness 0.90, Q = 2.9457
# True positives 995; False positives 26
# With alpha cut 11 and gammaness 0.91, Q = 2.8835
# True positives 974; False positives 26
# With alpha cut 11 and gammaness 0.92, Q = 2.9588
# True positives 940; False positives 23
# With alpha cut 11 and gammaness 0.93, Q = 2.9416
# True positives 893; False positives 21
# With alpha cut 11 and gammaness 0.94, Q = 3.0208
# True positives 849; False positives 18
# With alpha cut 11 and gammaness 0.95, Q = 2.9851
# True positives 791; False positives 16
#
#
# With alpha cut 12 and gammaness 0.80, Q = 2.3327
# True positives 1197; False positives 60
# With alpha cut 12 and gammaness 0.81, Q = 2.3833
# True positives 1192; False positives 57
# With alpha cut 12 and gammaness 0.82, Q = 2.4080
# True positives 1183; False positives 55
# With alpha cut 12 and gammaness 0.83, Q = 2.4322
# True positives 1173; False positives 53
# With alpha cut 12 and gammaness 0.84, Q = 2.4241
# True positives 1158; False positives 52
# With alpha cut 12 and gammaness 0.85, Q = 2.5146
# True positives 1142; False positives 47
# With alpha cut 12 and gammaness 0.86, Q = 2.4995
# True positives 1123; False positives 46
# With alpha cut 12 and gammaness 0.87, Q = 2.5808
# True positives 1108; False positives 42
# With alpha cut 12 and gammaness 0.88, Q = 2.6423
# True positives 1079; False positives 38
# With alpha cut 12 and gammaness 0.89, Q = 2.7131
# True positives 1048; False positives 34
# With alpha cut 12 and gammaness 0.90, Q = 2.8222
# True positives 1024; False positives 30
# With alpha cut 12 and gammaness 0.91, Q = 2.8032
# True positives 1000; False positives 29
# With alpha cut 12 and gammaness 0.92, Q = 2.8539
# True positives 964; False positives 26
# With alpha cut 12 and gammaness 0.93, Q = 2.8256
# True positives 917; False positives 24
# With alpha cut 12 and gammaness 0.94, Q = 2.8626
# True positives 869; False positives 21
# With alpha cut 12 and gammaness 0.95, Q = 2.8051
# True positives 810; False positives 19
#
#
# With alpha cut 13 and gammaness 0.80, Q = 2.3260
# True positives 1223; False positives 63
# With alpha cut 13 and gammaness 0.81, Q = 2.3717
# True positives 1217; False positives 60
# With alpha cut 13 and gammaness 0.82, Q = 2.3924
# True positives 1207; False positives 58
# With alpha cut 13 and gammaness 0.83, Q = 2.4146
# True positives 1197; False positives 56
# With alpha cut 13 and gammaness 0.84, Q = 2.4059
# True positives 1182; False positives 55
# With alpha cut 13 and gammaness 0.85, Q = 2.5145
# True positives 1166; False positives 49
# With alpha cut 13 and gammaness 0.86, Q = 2.4970
# True positives 1146; False positives 48
# With alpha cut 13 and gammaness 0.87, Q = 2.5738
# True positives 1131; False positives 44
# With alpha cut 13 and gammaness 0.88, Q = 2.6303
# True positives 1102; False positives 40
# With alpha cut 13 and gammaness 0.89, Q = 2.6945
# True positives 1071; False positives 36
# With alpha cut 13 and gammaness 0.90, Q = 2.7913
# True positives 1046; False positives 32
# With alpha cut 13 and gammaness 0.91, Q = 2.7654
# True positives 1020; False positives 31
# With alpha cut 13 and gammaness 0.92, Q = 2.8557
# True positives 983; False positives 27
# With alpha cut 13 and gammaness 0.93, Q = 2.8811
# True positives 935; False positives 24
# With alpha cut 13 and gammaness 0.94, Q = 2.9153
# True positives 885; False positives 21
# With alpha cut 13 and gammaness 0.95, Q = 2.8502
# True positives 823; False positives 19
#
#
# With alpha cut 14 and gammaness 0.80, Q = 2.3648
# True positives 1263; False positives 65
# With alpha cut 14 and gammaness 0.81, Q = 2.4060
# True positives 1255; False positives 62
# With alpha cut 14 and gammaness 0.82, Q = 2.4263
# True positives 1245; False positives 60
# With alpha cut 14 and gammaness 0.83, Q = 2.4400
# True positives 1231; False positives 58
# With alpha cut 14 and gammaness 0.84, Q = 2.4313
# True positives 1216; False positives 57
# With alpha cut 14 and gammaness 0.85, Q = 2.5344
# True positives 1199; False positives 51
# With alpha cut 14 and gammaness 0.86, Q = 2.5127
# True positives 1177; False positives 50
# With alpha cut 14 and gammaness 0.87, Q = 2.5818
# True positives 1160; False positives 46
# With alpha cut 14 and gammaness 0.88, Q = 2.6344
# True positives 1131; False positives 42
# With alpha cut 14 and gammaness 0.89, Q = 2.6863
# True positives 1097; False positives 38
# With alpha cut 14 and gammaness 0.90, Q = 2.7675
# True positives 1069; False positives 34
# With alpha cut 14 and gammaness 0.91, Q = 2.7381
# True positives 1042; False positives 33
# With alpha cut 14 and gammaness 0.92, Q = 2.8116
# True positives 1003; False positives 29
# With alpha cut 14 and gammaness 0.93, Q = 2.8184
# True positives 952; False positives 26
# With alpha cut 14 and gammaness 0.94, Q = 2.8266
# True positives 898; False positives 23
# With alpha cut 14 and gammaness 0.95, Q = 2.7374
# True positives 831; False positives 21

# %% [markdown]
# To handle the very few cases that return 0 false positives and thus an "infinite" Q value, we decide to consider the median of the Q values across the different iterations instead of the average. To estimate the standard deviation of the values found we ignore these cases.

# %%
test_predictions_df = pd.DataFrame(test_predictions)
test_predictions_df['Q'] = test_predictions_df['Q'].replace('inf', 1e20) # assign very high value to Q to find median
test_predictions_df.groupby(['alpha_cut', 'gamma'])['Q'].agg(
    median_Q = 'median',
    std= lambda x: np.std(x[x != 1e20])).reset_index()
# Out:
#      alpha_cut  gamma  median_Q       std
# 0            2   0.80  1.648333  0.248293
# 1            2   0.81  1.643473  0.237242
# 2            2   0.82  1.711508  0.246810
# 3            2   0.83  1.770597  0.238391
# 4            2   0.84  1.772009  0.337973
# ..         ...    ...       ...       ...
# 203         14   0.91  2.997778  0.235895
# 204         14   0.92  2.975360  0.253990
# 205         14   0.93  2.986158  0.292435
# 206         14   0.94  3.132253  0.295596
# 207         14   0.95  3.167040  0.444671
#
# [208 rows x 4 columns]

# %%
grouped_pred = test_predictions_df.groupby(['alpha_cut', 'gamma'])['Q'].agg(
    median= 'median',
    std= lambda x: np.std(x[x != 1e20]) ).reset_index()

max_mean_row = grouped_pred.loc[grouped_pred['median'].idxmax()]

max_mean = max_mean_row['median']
std_dev = max_mean_row['std']

print(f"The best average Q value found is {max_mean:.2f} ± {std_dev/(N)**0.5:.2f}")
print(f"The best Alpha cut found is {max_mean_row['alpha_cut']:.0f}° ")
print(f"The best gammaness found is {max_mean_row['gamma']:.2f}")
# Out:
# The best average Q value found is 3.18 ± 0.09
# The best Alpha cut found is 11°
# The best gammaness found is 0.94

# %%
selected = test_predictions_df[
    (test_predictions_df['gamma'] == max_mean_row['gamma']) & 
    (test_predictions_df['alpha_cut'] == max_mean_row['alpha_cut'])]

selected_gammas = selected['selected gammas']/selected['total gammas']
avg_selected_gammas= selected_gammas.mean()
std_selected_gammas= selected_gammas.std()
print(f"With these best parameters, the average fraction of selected gammas is ({avg_selected_gammas*100:.2f} ± {std_selected_gammas*100/(N)**0.5:.2f})%")
# Out:
# With these best parameters, the average fraction of selected gammas is (35.93 ± 0.35)%

# %% [markdown]
# This means that, applying this technique on the given dataset with $N_{\gamma} = 12332$ true gamma events, we would identify $n_{\gamma} = (4199 ± 1)$ events as gamma, disregarding the remaining as backgorund. In particular we have the following average performance for the algorithm in terms of TPR, FPR, TNR, FNR:

# %%
tpr = selected['true positives']/selected['total gammas']
tpr_avg = tpr.mean()

fpr = selected['false positives']/selected['total hadrons']
fpr_avg = fpr.mean()

tnr = selected['true negatives']/selected['total hadrons']
tnr_avg= tnr.mean()

fnr = selected['false negatives']/selected['total gammas']
fnr_avg= fnr.mean()

confusion_matrix = np.array([[tpr_avg, fnr_avg], [fpr_avg, tnr_avg]])

fig, ax = plt.subplots(figsize=(9, 9))
cax = ax.matshow(confusion_matrix, cmap='seismic',alpha=0.75)

ax.set_xticks([0, 1])
ax.set_xticklabels(['gamma', 'background'],fontsize=12)
ax.xaxis.set_ticks_position('bottom')
ax.set_yticks([0, 1])
ax.set_yticklabels(['gamma', 'background'],fontsize=12)

path_effects_white = [path_effects.withStroke(linewidth=1.8, foreground='white')]

# Adding text with white contour
text_params = {'ha': 'center', 'va': 'center', 'color': 'black', 'fontsize': 12, 'path_effects': path_effects_white}


ax.text(0, 0, f'TPR: {tpr_avg:.3f}', ha='center', va='center', color='black',fontsize=12)
ax.text(1, 0, f'FNR: {fnr_avg:.3f}', **text_params)
ax.text(0, 1, f'FPR: {fpr_avg:.3f}', **text_params)
ax.text(1, 1, f'TNR: {tnr_avg:.3f}', **text_params)

fig.colorbar(cax)

ax.set_title('Confusion matrix of final classification strategy',fontsize=15)
ax.set_xlabel('Assigned Labels',fontsize=13.5)
ax.set_ylabel('True Labels',fontsize=13.5)

plt.show()

# %% [markdown]
# # Part 8: Calculation of the observation time

# %% [markdown]
# Assuming that the telescope has a collection area of 10^9 cm^2 and that we are observing gamma rays between 50 GeV and 50 TeV, to what observation time does this measurement corresponds? (assume here the Crab spectrum measured by HEGRA [Aharonian, F. et al. 2000])

# %% [markdown]
# ------da rivedere descrizione-------
# - da capire +- 0.5
# - da capire se vogliamo dividere il range 0.05 Tev - 50 Tev in due e usare il primo integrale per 1-50 e il secondo (log) per 0.05-1 (al momento non sono divisi)

# %% [markdown]
# To calculate the observation time corresponding to the Cherenkov telescope measurement, we use the Crab Nebula spectrum measured by HEGRA. Then, converting the telescope's collection area to square meters ( $A = 10^9 \, \text{cm}^2 = 10^5 \, \text{m}^2 $), we can determine
# the event rate by integrating the flux over the energy range from **50 GeV to 50 TeV**:
#
# $$
# R = A \cdot J_{\gamma} =  A \int_{0.05 \, TeV}^{50 \, TeV} \frac{dJ_{\gamma}}{dE} dE
# $$
#
# This integration provides the **event rate in photons per second**. Given the total number of recorded events $n_\gamma$, we can then calculate the **observation time** by dividing the number of events by the event rate:
#
# $$
# \Delta t = \frac{n_{\gamma}}{R}
# $$

# %%
# Constants
A = 10**9 * 1e-4  # collection area in m^2
E0 = 1.0  # TeV
Emin = 0.05  # TeV = 50 GeV
Emax = 50  # TeV
n_gamma, sigma_n_gamma = 4000, 200 #--------------------------------------insert our value here---------------------------

# Constants for the first integral
alpha1, alpha1_err = 2.59, 0.03
c1, c1_err = 2.79e-7, 0.02e-7

# Constants for the second integral
c2, c2_err = 2.67e-7, 0.01e-7
alpha2, alpha2_err = 2.47, 0.1
beta, beta_err = 0.11, 0.1

# %% [markdown]
# Primo integrale con errore dato da derivate parziali

# %% [markdown]
# # First integral
# According to the study by **Aharonian et al. (2000)**, the differential flux of gamma rays in the range of $1-20 \, \text{TeV}$ is given by:
#
# $$
# \frac{dJ_{\gamma}}{dE} = (2.79 \pm 0.02) \times 10^{-7} \left( \frac{E}{1 \, \text{TeV}} \right)^{(-2.59 \pm 0.03)} \, \text{ph} \, \text{m}^{-2} \, \text{s}^{-1} \, \text{TeV}^{-1}
# $$
# $$
# \frac{dJ_{\gamma}}{dE} = c_1 \cdot \left( \frac{E}{E_0} \right)^{- \alpha_1} \, \text{ph} \, \text{m}^{-2} \, \text{s}^{-1} \, \text{TeV}^{-1}
# $$
# with:
# $$
# c_1 = (2.79 \pm 0.02) \times 10^{-7}, E_0 = 1 \, \text{TeV}, \alpha_1 = 2.59 \pm 0.03
# $$
# so the integral will be:
# $$
# J_\gamma = \frac{E_0^{\alpha_1} \cdot c_1}{-\alpha_1 + 1} \cdot \left( E_{\text{max}}^{-\alpha_1 + 1} - E_{\text{min}}^{-\alpha_1 + 1} \right)
# $$
# with $E_{\text{min}} = 0.05 \, \text{TeV}, E_{\text{max}} = 50 \, \text{TeV} $

# %% [markdown]
# ### Error Propagation
#
# We have uncertainties in the following parameters:
#
# $$
# c_1 = (2.79 \pm 0.02) \times 10^{-7}
# $$
# $$
# \alpha_1 = 2.59 \pm 0.03
# $$
#
# Using the general error propagation formula the total uncertainty in R:
#
# $$
# \sigma_R = \sqrt{ \left( \frac{\partial R}{\partial c_1} \sigma_{c_1} \right)^2 + \left( \frac{\partial R}{\partial \alpha_1} \sigma_{\alpha_1} \right)^2 }
# $$
#
# The error for the time will be:
# $$
# \sigma_t = t \sqrt{ \left( \frac{\sigma_{n_{\gamma}}}{n_{\gamma}} \right)^2 + \left( \frac{\sigma_R}{R} \right)^2 }
# $$

# %%
import sympy as sp

def uncertainty(A, E0, Emin, Emax, c1, c1_err, alpha1, alpha1_err):
    #definisco i simboli
    c1_sym, alpha1_sym, Emin_sym, Emax_sym, E0_sym, A_sym = sp.symbols('c1 alpha1 Emin Emax E0 A')
    
    #definizione di R 
    R = (A_sym * c1_sym * (E0_sym**alpha1_sym) / (-alpha1_sym + 1)) * (Emax_sym**(-alpha1_sym + 1) - Emin_sym**(-alpha1_sym + 1))

    #calcolo le derivate parziali rispetto a c1 e alpha1
    dR_dc1 = sp.diff(R, c1_sym)
    dR_dalpha1 = sp.diff(R, alpha1_sym)
    
    #conversione a funzioni
    dR_dc1_func = sp.lambdify((A_sym, E0_sym, Emin_sym, Emax_sym, c1_sym, alpha1_sym), dR_dc1, 'numpy')
    dR_dalpha1_func = sp.lambdify((A_sym, E0_sym, Emin_sym, Emax_sym, c1_sym, alpha1_sym), dR_dalpha1, 'numpy')
    
    #calcolo il valore delle derivate e di R
    dR_dc1_val = dR_dc1_func(A, E0, Emin, Emax, c1, alpha1)
    dR_dalpha1_val = dR_dalpha1_func(A, E0, Emin, Emax, c1, alpha1)
    R_val = (A * c1 * (E0**alpha1) / (-alpha1 + 1)) * (Emax**(-alpha1 + 1) - Emin**(-alpha1 + 1))
    
    #incertezza totale su R
    sigma_R = np.sqrt((dR_dc1_val * c1_err) ** 2 + (dR_dalpha1_val * alpha1_err) ** 2)
    
    return R_val, sigma_R


#valore dell'errore su R
R_val, sigma_R = uncertainty(A, E0, Emin, Emax, c1, c1_err, alpha1, alpha1_err)

t1 = (n_gamma / R_val) / 60
sigma_t1 = t1 * (np.sqrt((sigma_n_gamma / n_gamma)**2 + (sigma_R/R_val)**2)) / 60

print(f"t1 = {t1:.2f} ± {sigma_t1:.2f} minutes")
# Out:
# t1 = 32.44 ± 0.05 minutes

# %% [markdown]
# ## Second integral
# At low energies there is a slight flattening of the spectrum. A fit with a logarithmic steepening of the power law spectrum gives (according to the study by **Aharonian et al. (2000)**):
# $$
# \frac{dJ_{\gamma}}{dE} = (2.67 \pm 0.01) \times 10^{-7} \left( \frac{E}{1 \, \text{TeV}} \right)^{(-2.47 \pm 0.1) -(0.11 \pm 0.1) \, \log(E)} \, \text{ph} \, \text{m}^{-2} \, \text{s}^{-1} \, \text{TeV}^{-1}
# $$
# $$
# \frac{dJ_{\gamma}}{dE} = c_2 \cdot \left( \frac{E}{E_0} \right)^{- \alpha_2 - \beta \, \log(E)} \, \text{ph} \, \text{m}^{-2} \, \text{s}^{-1} \, \text{TeV}^{-1}
# $$
# with:
# $$
# c_2 = (2.67 \pm 0.01) \times 10^{-7}, E_0 = 1 \, \text{TeV}, \alpha_2 = 2.47 \pm 0.1, \beta = 0.11 \pm 0.1
# $$
# Because of the logarithmic correction, it's impossible to integrate it analytically in a straightforward way. Hence, to calculate this integral, we use two numerical integration methods: Romberg integration and Simpson's Rule.

# %% [markdown]
# ###  Romberg integration
# usando romb - da capire
# #### using .quad

# %%
from scipy.integrate import quad

#definisco l'integranda
def dJ_gamma(E, c2, alpha2, beta):
    return c2 * (E / E0) ** (-alpha2 - beta * np.log(E))

#definisco R
def R(c2, alpha2, beta):
    integral, _ = quad(dJ_gamma, Emin, Emax, args=(c2, alpha2, beta))
    return A * integral

#Monte Carlo for the error
N = 10000
c2_mc = np.random.normal(c2, c2_err, N)
alpha2_mc = np.random.normal(alpha2, alpha2_err, N)
beta_mc = np.random.normal(beta, beta_err, N)

R_mc = np.array([R(c2, alpha2, beta) for c2, alpha2, beta in zip(c2_mc, alpha2_mc, beta_mc)])

#calcolo valor medio e errore di R
R_mean = np.mean(R_mc)
R_std = np.std(R_mc)

#propago su t
t2 = (n_gamma / R_mean)/60
sigma_t2 = t2 * (np.sqrt((sigma_n_gamma / n_gamma)**2 + (R_std/R_mean)**2)) / 60

print(f"t2 = {t2:.2f} +- {sigma_t2:.2f} minutes")
# Out:
# t2 = 67.99 +- 0.75 minutes

# %% [markdown]
# ### Simpson's Rule

# %% [markdown]
# The trapezoidal rule estimates the area under a curve by approximating the curve with straight-line segments. We can often get a
# better result if we approximate the function instead with curves of some kind, Simpson’s rule does exactly this, using quadratic curves.

# %%
import numpy as np
from scipy.integrate import simpson

n = int(10e5)
E_values = np.linspace(Emin, Emax, n)

def dJ_gamma2(E, c2, alpha2, beta):
    return c2 * (E / E0) ** (-alpha2 - beta * np.log(E))

J_gamma_values = dJ_gamma2(E_values, c2, alpha2, beta)
J_gamma = simpson(J_gamma_values, E_values)

R = A * J_gamma

def partial_derivatives():
    dJ_dc2 = J_gamma / c2
    dJ_dalpha2 = -J_gamma * np.log(E_values / E0)
    dJ_dalpha2 = simpson(dJ_dalpha2, E_values)
    dJ_dbeta = -J_gamma * np.log(E_values/E0) * np.log(E_values)
    dJ_dbeta = simpson(dJ_dbeta, E_values)

    return dJ_dc2, dJ_dalpha2, dJ_dbeta

dJ_dc2, dJ_dalpha2, dJ_dbeta = partial_derivatives()

sigma_J = np.sqrt(
    (dJ_dc2 * c2_err) ** 2 +
    (dJ_dalpha2 * alpha2_err) ** 2 +
    (dJ_dbeta * beta_err) ** 2
)

sigma_R = sigma_J

t2_s = (n_gamma / R)/60
sigma_t2_s = t2_s * (np.sqrt((sigma_n_gamma / n_gamma)**2 + (sigma_R/R)**2)) / 60

print(f"t2 = {t2_s:.2f} +- {sigma_t2_s:.2f} minutes")
# Out:
# t2 = 82.09 +- 0.07 minutes
