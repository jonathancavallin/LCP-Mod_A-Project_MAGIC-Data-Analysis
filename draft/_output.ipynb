# %% [markdown]
# # LCP Project: analysis of MAGIC04 dataset
# ### Description
#
# The data are Monte Carlo generated to simulate registration of high energy gamma particles in a ground-based atmospheric Cherenkov gamma telescope using the imaging technique. Cherenkov gamma telescope observes high energy gamma rays, taking advantage of the radiation emitted by charged particles produced inside the electromagnetic showers initiated by the gammas, and developing in the atmosphere. This Cherenkov radiation (of visible to UV wavelengths) leaks through the atmosphere and gets recorded in the detector, allowing reconstruction of the shower parameters. The available information consists of pulses left by the incoming Cherenkov photons on the photomultiplier tubes, arranged in a plane, the camera. Depending on the energy of the primary gamma, a total of few hundreds to some 10000 Cherenkov photons get collected, in patterns (called the shower image), allowing to discriminate statistically those caused by primary gammas (signal) from the images of hadronic showers initiated by cosmic rays in the upper atmosphere (background).
#
# Typically, the image of a shower after some pre-processing is an elongated cluster. Its long axis is oriented towards the camera center if the shower axis is parallel to the telescope's optical axis, i.e. if the telescope axis is directed towards a point source. A principal component analysis is performed in the camera plane, which results in a correlation axis and defines an ellipse. If the depositions were distributed as a bivariate Gaussian, this would be an equidensity ellipse. The characteristic parameters of this ellipse (often called Hillas parameters) are among the image parameters that can be used for discrimination. The energy depositions are typically asymmetric along the major axis, and this asymmetry can also be used in discrimination. There are, in addition, further discriminating characteristics, like the extent of the cluster in the image plane, or the total sum of depositions.
#
# The program was run with parameters allowing to observe events with energies down to below 50 GeV.
#
# ### Dataset
#
# Attribute Information:
#
# 1. fLength: continuous # major axis of ellipse [mm]
# 2. fWidth: continuous # minor axis of ellipse [mm]
# 3. fSize: continuous # 10-log of sum of content of all pixels [in #phot]
# 4. fConc: continuous # ratio of sum of two highest pixels over fSize [ratio]
# 5. fConc1: continuous # ratio of highest pixel over fSize [ratio]
# 6. fAsym: continuous # distance from highest pixel to center, projected onto major axis [mm]
# 7. fM3Long: continuous # 3rd root of third moment along major axis [mm]
# 8. fM3Trans: continuous # 3rd root of third moment along minor axis [mm]
# 9. fAlpha: continuous # angle of major axis with vector to origin [deg]
# 10. fDist: continuous # distance from origin to center of ellipse [mm]
# 11. class: g,h # gamma (signal), hadron (background)
#
# g = gamma (signal): 12332
# h = hadron (background): 6688
#
# For technical reasons, the number of h events is underestimated. In the real data, the h class represents the majority of the events.
#
# The simple classification accuracy is not meaningful for this data, since classifying a background event as signal is worse than classifying a signal event as background. For comparison of different classifiers an ROC curve has to be used. The relevant points on this curve are those, where the probability of accepting a background event as signal is below one of the following thresholds: 0.01, 0.02, 0.05, 0.1, 0.2 depending on the required quality of the sample of the accepted events for different experiments.
#
#
# ### References
#
# [1] Bock, R.K., Chilingarian, A., Gaug, M., Hakl, F., Hengstebeck, T., Jirina, M., Klaschka, J., Kotrc, E., Savicky, P., Towers, S., Vaicilius, A., Wittek W. (2004).
# Methods for multidimensional event classification: a case study using images from a Cherenkov gamma-ray telescope.
# Nucl.Instr.Meth. A, 516, pp. 511-528.
#
# [2] P. Savicky, E. Kotrc.
# Experimental Study of Leaf Confidences for Random Forest.
# Proceedings of COMPSTAT 2004, In: Computational Statistics. (Ed.: Antoch J.) - Heidelberg, Physica Verlag 2004, pp. 1767-1774.
#
# [3] J. Dvorak, P. Savicky.
# Softening Splits in Decision Trees Using Simulated Annealing.
# Proceedings of ICANNGA 2007, Warsaw, (Ed.: Beliczynski et. al), Part I, LNCS 4431, pp. 721-729.
#
# [4] Aharonian, F. et al.
# The Energy Spectrum of TeV Gamma-Rays from the Crab Nebula as measured by the HEGRA system of imaging air Cherenkov telescopes
# Astrophys. J. 539 (2000) 317-324
#
# [5] Aleksic, J. et al.
# Measurement of the Crab Nebula spectrum over three decades in energy with the MAGIC telescopes
# Journal of High Energy Astrophysics, 5–6 (2015) 30-38.

# %% [markdown]
# # Part 0: setup
# First, we import the libraries

# %%
# math libraries
import numpy as np
import pandas as pd
import numpy.random as npr
import matplotlib.pyplot as plt
from scipy import linalg as la
from matplotlib import patches
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
import matplotlib.patheffects as path_effects
import seaborn as sns
import random as rnd

# general OS libraries
from time import time
import gzip
import os
import operator
import warnings
from IPython.core.interactiveshell import InteractiveShell

# ML libraries
import sklearn
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, roc_auc_score, auc
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Perceptron
from sklearn.datasets import make_classification
from sklearn.svm import NuSVC
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.exceptions import ConvergenceWarning
from sklearn.model_selection import train_test_split
from sklearn.metrics import make_scorer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression

warnings.filterwarnings('ignore')

# %% [markdown]
# Then, we import the dataset and we put it into a DataFrame:

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data

file_name="magic04.data"
data = pd.DataFrame(pd.read_csv(file_name))
data.columns=['fLength','fWidth','fSize',
        'fConc','fConc1','fAsym',
        'fM3Long','fM3Trans','fAlpha','fDist','category']
data   
#### save data in a DataFrame
# Out:
# --2025-03-12 16:10:43--  https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘magic04.data.9’
#
# magic04.data.9          [                 <=>]   1.41M   370KB/s    in 4.6s
#
# 2025-03-12 16:10:50 (313 KB/s) - ‘magic04.data.9’ saved [1477391]
#         fLength    fWidth   fSize   fConc  fConc1     fAsym   fM3Long  \
# 0       31.6036   11.7235  2.5185  0.5303  0.3773   26.2722   23.8238
# 1      162.0520  136.0310  4.0612  0.0374  0.0187  116.7410  -64.8580
# 2       23.8172    9.5728  2.3385  0.6147  0.3922   27.2107   -6.4633
# 3       75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277   28.5525
# 4       51.6240   21.1502  2.9085  0.2420  0.1340   50.8761   43.1887
# ...         ...       ...     ...     ...     ...       ...       ...
# 19014   21.3846   10.9170  2.6161  0.5857  0.3934   15.2618   11.5245
# 19015   28.9452    6.7020  2.2672  0.5351  0.2784   37.0816   13.1853
# 19016   75.4455   47.5305  3.4483  0.1417  0.0549   -9.3561   41.0562
# 19017  120.5135   76.9018  3.9939  0.0944  0.0683    5.8043  -93.5224
# 19018  187.1814   53.0014  3.2093  0.2876  0.1539 -167.3125 -168.4558
#
#        fM3Trans   fAlpha     fDist category
# 0       -9.9574   6.3609  205.2610        g
# 1      -45.2160  76.9600  256.7880        g
# 2       -7.1513  10.4490  116.7370        g
# 3       21.8393   4.6480  356.4620        g
# 4        9.8145   3.6130  238.0980        g
# ...         ...      ...       ...      ...
# 19014    2.8766   2.4229  106.8258        h
# 19015   -2.9632  86.7975  247.4560        h
# 19016   -9.4662  30.2987  256.5166        h
# 19017  -63.8389  84.6874  408.3166        h
# 19018   31.4755  52.7310  272.3174        h
#
# [19019 rows x 11 columns]

# %% [markdown]
# In this cell we print the number of data of each label and the relative frequence

# %%
print('All data points:',len(data['fAlpha']),'points for',len(data.columns[:]),'columns')
print('labels and their relative frequencies:')

ngamma = len(data[data['category'] == 'g'] )
nback = len(data[data['category'] == 'h'] )
print(f'signal: \t{ngamma} \t {round(ngamma/len(data['fAlpha'])*100,2)}%')
print(f'background:\t {nback} \t {round(nback/len(data['fAlpha'])*100,2)}%')
# Out:
# All data points: 19019 points for 11 columns
# labels and their relative frequencies:
# signal: 	12331 	 64.84%
# background:	 6688 	 35.16%

# %% [markdown]
# We observe that about 2/3 of the dataset is labelled as signal, while only 1/3 as background. The dataset is indeed built underestimating the amount of background signal acquired.

# %% [markdown]
# Here we write some useful functions for the code

# %% [markdown]
# ## ML functions

# %%
# this function divides the dataset in input in parts_to_be_split parts. One of them is returned as test_set
# the other ones are the training_set. Indexes of the chosen data can be accessed (test_indexes, train_indexes)
# (for example in a K-fold)

def split_train_test_set(data,parts_to_be_split):
    indexes = np.arange(0,data.shape[0],1)
    rnd.shuffle(indexes)
    len_test_set = int(len(indexes) / parts_to_be_split)

    test_indexes = indexes[:len_test_set]
    train_indexes = indexes[len_test_set:]

    train_set = data.iloc[train_indexes]
    test_set = data.iloc[test_indexes]
    
    return train_set, test_set

# this function takes col category and returns as Y (target), the other columns are X (labels)
def split_X_Y(data):
    Y = data['category']
    X = data.drop('category',axis=1)

    return X,Y

# this function takes the point that has the lowest distance from FPR=0 and TPR=1 and computes Q for that point values
def get_best_Q(fpr,tpr):
    distances = np.zeros(len(fpr))
    
    for i in range(len(fpr)):
        distances[i] = np.sqrt(fpr[i]**2+(1-tpr[i])**2)
        
    min_dist_idx = np.argmin(distances)
    
    best_Q = tpr[min_dist_idx] / np.sqrt(fpr[min_dist_idx])
    return best_Q

# %% [markdown]
# ## Other functions
# ### Cutting functions

# %%
# this function finds cut value starting from possible max
def find_max_cut_value(X_train,Y_train,sel_label,min_hadrons):
    new_X = X_train[X_train.columns[sel_label]]
    new_data = np.vstack((new_X,Y_train))
    new_data_sorted = new_data[:, new_data[0].argsort()]
    
    #new_data_sorted_reversed = new_data_sorted[:, ::-1] #reverse!! STARTING FROM MAXX
    
    # setup vars, cut value is  set to max of the label, so that in worst scenario all points are true hadrons
    true_hadrons = 0
    max_cut_value = new_data_sorted[0,0]
    
    for i in range(new_data_sorted.shape[1]):
        if new_data_sorted[1,i] == -1:
            true_hadrons += 1
        if true_hadrons == min_hadrons:
            max_cut_value = new_data_sorted[0,i]
            
    return max_cut_value

# this functions returns the number of true positive and false positive points on test set
def find_tp_fp(X_test,Y_test,sel_label,cut_value):
    new_X = X_test[X_test.columns[sel_label]]
    new_data = np.vstack((new_X,Y_test))
    new_data_sorted = new_data[:, new_data[0].argsort()]
    new_data_sorted_reversed = new_data_sorted[:, ::-1] #reverse!! STARTING FROM MAXX
    fp = 0
    tp = 0
    
    for i in range(new_data_sorted_reversed.shape[1]):
        if new_data_sorted_reversed[0,i] < cut_value:
            if new_data_sorted_reversed[1,i] == 1:
                tp += 1
            if new_data_sorted_reversed[1,i] == -1:
                fp += 1
                
    return tp, fp # true positive, false positive

# %% [markdown]
# # Part 1: study of the dataset

# %% [markdown]
# ### Part 1.1 Camera plane reconstruction
# The following code recontrsucts the traces detected by the telescope camera. In orange and red are represented the detected gammas, while in blue are represented the detected hadrons

# %%
datasig = data[data['category'] == 'g'] 
databkg = data[data['category'] == 'h'] 
# visualize data
n_ellipses = 20

# ellipse parameters
random_angle_sig = 2 * np.pi * np.random.uniform(0, 1, size=n_ellipses)
sig_idx = np.random.randint(0,10000, size=n_ellipses)
sig_ellipse_params = [ 
    {
        'center': (datasig['fDist'][idx] * np.cos(random_angle_sig[i]), datasig['fDist'][idx] * np.sin(random_angle_sig[i])),  
        'width': datasig['fWidth'][idx], 
        'height': datasig['fLength'][idx], 
        'angle': datasig['fAlpha'][idx],
        'alpha': datasig['fSize'][idx]/data['fSize'].max()
        } 
    for i, idx in enumerate(sig_idx)
    ]

random_angle_bkg = 2 * np.pi * np.random.uniform(0, 1, size=n_ellipses)
bkg_idx = np.random.randint(13000,19000, size=n_ellipses)
bkg_ellipse_params = [ 
    {
        'center': (databkg['fDist'][idx] * np.cos(random_angle_bkg[i]), databkg['fDist'][idx] * np.sin(random_angle_bkg[i])),
        'width': databkg['fWidth'][idx], 
        'height': databkg['fLength'][idx], 
        'angle': databkg['fAlpha'][idx],
        'alpha': databkg['fSize'][idx]/data['fSize'].max()
        } 
    for i, idx in enumerate(bkg_idx)
    ]

fig, ax = plt.subplots(figsize=(10,12))

ax.grid(alpha=0.3)

# plot ellipses
radius = 500
camera_circle = patches.Circle((0,0), radius, alpha=0.2, color='grey')
ax.add_patch(camera_circle)

bkg_ellipses = []
sig_ellipses = []

for params in bkg_ellipse_params:
    ellipse = patches.Ellipse(
        xy=params['center'], 
        width=params['width'], 
        height=params['height'], 
        angle=(params['angle'] - 90 + 180*np.arctan(params['center'][1] / params['center'][0])/np.pi), 
        fill=True, 
        alpha=params['alpha'], 
        color='C0'
        )
    ax.add_patch(ellipse)
    bkg_ellipses.append(ellipse)

for params in sig_ellipse_params:
    ellipse = patches.Ellipse(
        xy=params['center'], 
        width=params['width'], 
        height=params['height'], 
        angle=(params['angle'] - 90 + 180*np.arctan(params['center'][1] / params['center'][0])/np.pi),
        alpha=params['alpha'], 
        color='C1'
        )
    ax.add_patch(ellipse)
    sig_ellipses.append(ellipse)

ax.set_xlim(-radius, radius)
ax.set_ylim(-radius, radius)
ax.set_aspect('equal')

legend_labels = ['Camera Plane', 'Hadron', 'Gamma']
legend_handles = [camera_circle, bkg_ellipses[0], sig_ellipses[0]]
ax.legend(legend_handles, legend_labels, loc='lower right')

center_cross_size = 15
ax.plot([0, 0], [-center_cross_size, center_cross_size], color='black', linewidth=1)
ax.plot([-center_cross_size, center_cross_size], [0, 0], color='black', linewidth=1)

# color scale indicating alpha for background ellipses
bkg_alphas = [params['alpha'] for params in bkg_ellipse_params]
bkg_norm = Normalize(vmin=0, vmax=100)
bkg_scalar_map = ScalarMappable(norm=bkg_norm, cmap='Blues')
bkg_scalar_map.set_array(bkg_alphas)
bkg_colorbar = plt.colorbar(bkg_scalar_map, ax=ax, fraction=0.033, pad = 0.15)
bkg_colorbar.set_label('hadron #photons %')

# color scale indicating alpha for signal ellipses
sig_alphas = [params['alpha'] for params in sig_ellipse_params]
sig_norm = Normalize(vmin=0, vmax=100)
sig_scalar_map = ScalarMappable(norm=sig_norm, cmap='Oranges')
sig_scalar_map.set_array(sig_alphas)
sig_colorbar = plt.colorbar(sig_scalar_map, ax=ax, fraction=0.04, pad = 0.1)
sig_colorbar.set_label('gamma #photons %')

ax.set_xlabel('X-axis (mm)')
ax.set_ylabel('Y-axis (mm)')

plt.show();

# %% [markdown]
# This recontstruction resembles the acquisition of some signals. It is observed that the orange ellypses, representing data labeled as "gamma", are mostly radially oriented, while the orientation of the "hadrons" ellypses seems random. We can conclude that the photon shower axis is parallel to the telescope's optical axis. The colorbars represent the alpha parameter of the represented particles.

# %% [markdown]
# ### Part 1.2 plot of the features
# the following code plots histograms for each feature, in red there are gammas (signal), in blue hadrons (background). The code saves the histograms in a directory named 'part_1_plots'

# %%
fig, ax = plt.subplots(nrows=5, ncols=2, figsize=(20, 34))
fig.subplots_adjust(hspace=0.3)

udm = ['fLength ', 'fWidth ', 'fSize ', 'fConc ', 'fConc1 ', 
       'fAsym ', 'fM3Long ', 'fM3Trans ', 'fAlpha ', 'fDist ']

units = ['(mm)','(mm)','(#phot)','(ratio)','(ratio)','(mm)','(mm)','(mm)','(deg)','(mm)']
features = ['fLength', 'fWidth', 'fSize', 'fConc', 'fConc1', 
            'fAsym', 'fM3Long', 'fM3Trans', 'fAlpha', 'fDist']
bins = 40

avgs_g = []
avgs_h = []
stds_g = []
stds_h = []
lambdas = []

for i in range(5):
    for j in range(2):
            
        idx = 2 * i + j  # Update index to match new layout
        if (udm[idx] == 'fWidth (mm)'):
            bins = 50
        
        min_val = min(datasig[features[idx]].min(), databkg[features[idx]].min())
        max_val = max(datasig[features[idx]].max(), databkg[features[idx]].max())
        common_bins = np.linspace(min_val, max_val, bins + 1)
        
        #ax[i, j].grid()
        sns.histplot(datasig[features[idx]], bins = common_bins, kde=False, color='red', alpha=0.6, label='gamma', ax=ax[i, j], edgecolor='#383734', linewidth=0.5)
        sns.histplot(databkg[features[idx]], bins = common_bins, kde=False, color='blue', alpha=0.5, label='hadron', ax=ax[i, j], edgecolor='#383734', linewidth=0.5)
        mu_g = np.mean(datasig[features[idx]])
        mu_h = np.mean(databkg[features[idx]])
        std_g = np.std(datasig[features[idx]])
        std_h = np.std(databkg[features[idx]])
        avgs_g.append(mu_g)
        avgs_h.append(mu_h)
        stds_g.append(std_g)
        stds_h.append(std_h)
        lambdas.append(abs(mu_g-mu_h)/(std_g**2 + std_h**2)**(1/2))
        
        ax[i, j].axvline(mu_g,c='#990000', label= f'$\gamma$ mean = {round(mu_g,1)}±{round(std_g,1)}', lw=1.8)
        ax[i, j].axvline(mu_h,c='navy',label= f'h mean = {round(mu_h,1)}±{round(std_h,1)}', lw=1.7,alpha=0.7)
        ax[i, j].set_xlabel(f'{udm[idx]}{units[idx]}', fontsize=24)
        ax[i, j].set_ylabel(f'counts / {round(common_bins[1]-common_bins[0],2)} {units[idx]}', fontsize=24)
        ax[i, j].tick_params(axis='both', which='major', labelsize=16)
        ax[i, j].legend(loc='best', fontsize=18)
        ax[i, j].set_title(f'Histogram of {udm[idx]}', fontsize=26)
        
        '''if (udm[idx] == 'fLength (mm)'):
            ax[i, j].set_xlim(-5,260)
        if (udm[idx] == 'fWidth (mm)'):
            ax[i, j].set_xlim(-10,120)'''
            
        
        #ax[i, j].text(x=3,y=160,s=fr"$\mu_{{g}}$={mu_g:.2f} $\pm$ {l_std_g_high:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='#990000'))
        #ax[i, j].text(x=3,y=130,s=fr"$\mu_{{h}}$={mu_h:.2f} $\pm$ {l_std_h_high:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='navy'))

    
#plt.tight_layout()
plt.show();

# %%
print(f'feature \t gamma \t \thadrons \tcompatibility (lambda)')
for i in range(len(avgs_g)):
    print(f'{udm[i]}{units[i]}\t',f'{round(avgs_g[i],1)} \u00B1 {round(stds_g[i],1)}', f'\t{round(avgs_h[i],1)} \u00B1 {round(stds_h[i],1)}', f'\t\033[32m{round(lambdas[i],2)}\033[0m')
# Out:
# feature 	 gamma 	 	hadrons 	compatibility (lambda)
# fLength (mm)	 43.7 ± 26.2 	70.9 ± 57.9 	0.43
# fWidth (mm)	 18.6 ± 9.0 	28.8 ± 27.2 	0.36
# fSize (#phot)	 2.8 ± 0.5 	2.9 ± 0.5 	0.17
# fConc (ratio)	 0.4 ± 0.2 	0.4 ± 0.2 	0.04
# fConc1 (ratio)	 0.2 ± 0.1 	0.2 ± 0.1 	0.01
# fAsym (mm)	 3.2 ± 39.6 	-18.3 ± 82.3 	0.24
# fM3Long (mm)	 17.8 ± 33.9 	-2.8 ± 70.7 	0.26
# fM3Trans (mm)	 0.2 ± 13.6 	0.4 ± 29.9 	0.01
# fAlpha (deg)	 18.8 ± 21.5 	44.0 ± 26.0 	0.75
# fDist (mm)	 190.2 ± 70.3 	200.4 ± 81.9 	0.09

# %% [markdown]
# We observe that the mean values of all features for hadrons and gammas are compatible. Also they distribute in similar shapes, except for `fAlpha`. Therefore is not possible to distinguish signal from background from the distributions.

# %% [markdown]
# # Part 2: studying the correlations
# in this section each feature will be confronted with all the others. Results will be put in a 2D correlation matrix (n_features x n_features) to visualize the results
#
# First we rescale all features to have average = 0 and dev_std = 1 (Alpha is rescaled in this part, but will be restored for the later sections).

# %%
X = data[['fLength','fWidth','fSize',
        'fConc','fConc1','fAsym',
        'fM3Long','fM3Trans','fAlpha','fDist']]
Y = data['category']
print(X['fAlpha'])
# Out:
# 0         6.3609
# 1        76.9600
# 2        10.4490
# 3         4.6480
# 4         3.6130
#           ...
# 19014     2.4229
# 19015    86.7975
# 19016    30.2987
# 19017    84.6874
# 19018    52.7310
# Name: fAlpha, Length: 19019, dtype: float64

# %%
X_rescaled = X.copy()
original_alpha = X['fAlpha'].copy()

for i in range(X.shape[1]):
    h = X[str(X.columns[i])]
    avg = np.average(h)
    std = np.std(h)
    h = h - avg
    h = h / std
    X_rescaled[str(X_rescaled.columns[i])] = h
    
print('avg length:',round(np.average(X_rescaled['fLength']),15))
print('std length:',round(np.std(X_rescaled['fLength']),15))
# Out:
# avg length: 0.0
# std length: 0.999999999999997

# %% [markdown]
# The following cell computes the correlation matrix taking apart gammas from hadrons

# %%
Xg_rescaled = X_rescaled[Y == 'g']
Xh_rescaled = X_rescaled[Y == 'h']
features = features[:10]


cov = np.zeros((Xg_rescaled.shape[1],Xg_rescaled.shape[1]))
for i in range(Xg_rescaled.shape[1]):
    h = Xg_rescaled[str(Xg_rescaled.columns[i])]
    for j in range(Xg_rescaled.shape[1]):
        v = Xg_rescaled[str(Xg_rescaled.columns[j])]
        cov[i,j] = (np.cov(h,v)[0,1])
        
std_devs = np.std(Xg_rescaled, axis=0)
cov = cov / np.outer(std_devs, std_devs) # the data for gamma events are not normalized with respsect to themselv   



ticks = np.arange(0,10,1)
x_ticks = np.arange(cov.shape[1]) + 0.5
y_ticks = np.arange(cov.shape[0]) + 0.5

fig, ax = plt.subplots(1, 2, figsize=(16, 8))
cax = ax[0].imshow(cov, cmap='coolwarm', interpolation='nearest')
fig.colorbar(cax)
ax[0].set_xticks(ticks, minor=False)
ax[0].set_yticks(ticks, minor=False)
ax[0].set_xticklabels(features,rotation=90)
ax[0].set_yticklabels(features)
ax[0].grid(which='minor', color='black', linewidth=2)

for i in range(cov.shape[0]):
    for j in range(cov.shape[1]):
        ax[0].text(j, i, f'{cov[i, j]:.2f}', ha='center', va='center', color='black', fontsize=10)

#ax[0].plot([-0.5, cov.shape[1]-0.5], [-0.5, cov.shape[0]-0.5], color='black', linewidth=2, linestyle='-')
#ax[0].plot([-0.5, cov.shape[1]-0.5], [-0.5, cov.shape[0]-0.5], color='black', linewidth=2, linestyle='-')
ax[0].set_title('GAMMA EVENTS FEATURES CORRELATION')

cov = np.zeros((Xh_rescaled.shape[1],Xh_rescaled.shape[1]))
for i in range(Xh_rescaled.shape[1]):
    h = Xh_rescaled[str(Xh_rescaled.columns[i])]
    for j in range(Xh_rescaled.shape[1]):
        v = Xh_rescaled[str(Xh_rescaled.columns[j])]
        cov[i,j] = (np.cov(h,v)[0,1])
        
std_devs = np.std(Xh_rescaled, axis=0)
cov = cov / np.outer(std_devs, std_devs)

cax = ax[1].imshow(cov, cmap='coolwarm', interpolation='nearest')
fig.colorbar(cax)
ax[1].set_xticks(ticks, minor=False)
ax[1].set_yticks(ticks, minor=False)
ax[1].set_xticklabels(features, rotation=90)
ax[1].set_yticklabels(features)
ax[1].grid(which='minor', color='black', linewidth=1)

for i in range(cov.shape[0]):
    for j in range(cov.shape[1]):
        ax[1].text(j, i, f'{cov[i, j]:.2f}', ha='center', va='center', color='black', fontsize=10)

#ax[1].plot([-0.5, cov.shape[1]-0.5], [-0.5, cov.shape[0]-0.5], color='black', linewidth=2, linestyle='-')
ax[1].set_title('HADRON EVENTS FEATURES CORRELATION')

plt.show();

# %% [markdown]
# We observe that the most correlated features are the first 5. The correlation between the first 3 is positive, while correlation between `fConc1` and `fConc2` is negative, and very close to 1. This is in agreement for both signal and background events. Differences can be seen while observing other parameters:
# - `fAlpha`: this parameter is slightly correlated to the others for gamma events, but sees almost no correlation for background ones
# - `fAsym`: this parameter sees the opposite than `fAlpha`
# - `fM3Long`: the correlation of this parameter is present for both signal and background events, but has its sign swapped

# %% [markdown]
# ## Part 2.1: Correlation between features and label
# In this part we check the correlation between features and label Y. This is done to find the most informative parameters for the classification.

# %%
# Calculate the correlation between each feature and the label Y

Y_array = np.where(Y == 'g', 1, -1)
Y_array = np.array(Y_array) 
feature_names = data.columns[:10]

correlations = np.zeros(X_rescaled.shape[1])  
for i in range(X_rescaled.shape[1]):
    feature = X_rescaled.iloc[:, i]  
    correlations[i] = np.corrcoef(feature, Y_array)[0, 1]

# create a bar plot to display the correlations
fig, ax = plt.subplots(figsize=(14.5, 10))

bars = ax.bar(feature_names, correlations, color='teal', edgecolor='black', linewidth=1.2,alpha=0.8)

# add correlation values on top of each bar
for i, corr in enumerate(correlations):
    ax.text(i, corr + 0.035 if corr>=0 else corr-0.035, f'{corr:.2f}', ha='center', va='bottom', fontsize=12, color='black', fontweight='bold')

ax.set_ylabel('Correlation with Label Y', fontsize=16, fontweight='bold')
ax.set_ylim(-0.53,0.3)
ax.set_title('Correlation between features and label Y', fontsize=20, fontweight='bold')
ax.set_xticks(np.arange(len(feature_names)))
ax.set_xticklabels(feature_names, fontsize=16, fontweight='bold', rotation=20, ha='right')

x_line = np.linspace(-0.6,len(feature_names),100)
y_line = np.linspace(0,0,100)
ax.plot(x_line, y_line, linestyle='dotted', color='black') 
ax.set_xlim(-0.6,9.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# The features most strongly correlated with the label Y, and thus most informative for distinguishing between gamma and hadron events, are `fAlpha`
# , `flength` and `fWidth` This is coherent with our observations from the feature histograms, where these features exhibit more distinct distributions between the two classes.

# %% [markdown]
# # Part 3: comparison of the features rescaled

# %% [markdown]
# In this section we analyze the distributions of the `fWidth` and `fLength` parameters. First of all we have computed the mean and standard deviation for both samples and we rescaled them. Then the distribution of both "`fWidth` and `fLength` was plotted dividing the gamma from the hadron events.
#
# We then used the `fSize` parameter to apply a cut to both the signals (gamma) and background (hadron) events and considered only the tails of their distribution. Since `fSize` is proportional to the number of photons, for both the width and lenght distribution we defined as "High energy events" the data points higher than 𝜇+𝜎
# (right-side tail) and as "Low energy events" the data points lower than 𝜇−𝜎. Considering 𝜇 and 𝜎 rispectively as the mean and standard deviation of the rescaled width and lenght distributions.
#
# From this comparison we can clearly see that in the high energy tail the signal is more clustered and separated from the background, despite having a smaller number of gamma events in this energy region. Meanwhile in the low energy tail signal and background events are more evenly distributed.
#
# Therefore,considering only the high energy region could give us an edge while classifying the events into signal and background.

# %%
## find mean and std

mu_l=data['fLength'].mean()
std_l=data['fLength'].std()
mu_w=data['fWidth'].mean()
std_w=data['fWidth'].std()
print('Length attribute:   mean = ', round(mu_l,3), '    std = ', round(std_l,3))
print('Width attribute:    mean = ', round(mu_w,3), '   std = ', round(std_w,3))
data['scaled_fLength']= (data['fLength']-mu_l)/std_l   ##add a scaled comlumn to the DataFrame
data['scaled_fWidth']= (data['fWidth']-mu_w)/std_w
# Out:
# Length attribute:   mean =  53.251     std =  42.366
# Width attribute:    mean =  22.181    std =  18.346

# %%
###plots of the scaled distribution before cutting 

bins = 32
common_bins = np.linspace(min(data['scaled_fLength']), max(data['scaled_fLength']), bins + 1)

fig, ax = plt.subplots(1, 2, figsize=(12,5))
sns.histplot(data,x=data['scaled_fLength'],hue='category',bins = common_bins, kde=False, ax=ax[0], palette=['red','blue'], edgecolor='#383734', linewidth=0.5)
ax[0].set_title("Distribution of Scaled fLenght", fontsize=14)
ax[0].set_xlabel("Scaled fWidth", fontsize=12)
ax[0].set_ylabel("Count", fontsize=12)
ax[0].set_xlim(-1.5, 5.5)  
legend = ax[0].get_legend()

ax[0].legend(['Hadron', 'Gamma'], title='Category')

bins = 45
common_bins = np.linspace(min(data['scaled_fWidth']), max(data['scaled_fWidth']), bins + 1)
sns.histplot(data,x=data['scaled_fWidth'],hue='category',bins = common_bins, kde=False, ax=ax[1], palette=['red','blue'], edgecolor='#383734', linewidth=0.5)
ax[1].set_title("Distribution of Scaled fWidth", fontsize=14)
ax[1].set_xlabel("Scaled fLength", fontsize=12)
ax[1].set_ylabel("Count", fontsize=12)
ax[1].set_xticks(range(-1,9))
ax[1].set_xlim(-1.5, 6)  
legend = ax[1].get_legend()
ax[1].legend(['Hadron', 'Gamma'], title='Category');

# %%
median_fSize = data['fSize'].median()
min_fSize = data['fSize'].min()
max_fSize = data['fSize'].max()
mean_fSize = data['fSize'].mean()
std_fSize = data['fSize'].std()
print("Statistichal informations of fSize: \nmedian=",median_fSize, '\nmin=', min_fSize, '\nmax=', max_fSize, '\nmean=', round(mean_fSize,3), '\nstd=', round(std_fSize,3))
# Out:
# Statistichal informations of fSize:
# median= 2.7396
# min= 1.9413
# max= 5.3233
# mean= 2.825
# std= 0.473

# %%
#### plots at high energy

fig, ax = plt.subplots(1, 2, figsize=(12,5))
fig.suptitle('High Energy Events (high fSize values)', fontsize=18)

fig.subplots_adjust(top=0.85)  

##useful variables
ng_high=len(data[data['category'] == 'g']['scaled_fLength'][data['fSize'] >= mean_fSize+std_fSize])
nh_high=len(data[data['category'] == 'h']['scaled_fLength'][data['fSize'] >= mean_fSize+std_fSize])
l_mu_g_high=data[data['category'] == 'g']['scaled_fLength'][data['fSize'] >= mean_fSize+std_fSize].mean()
l_mu_h_high=data[data['category'] == 'h']['scaled_fLength'][data['fSize'] >= mean_fSize+std_fSize].mean()
l_std_g_high=data[data['category'] == 'g']['scaled_fLength'][data['fSize'] >= mean_fSize+std_fSize].std()
l_std_h_high=data[data['category'] == 'h']['scaled_fLength'][data['fSize'] >= mean_fSize+std_fSize].std()
w_mu_g_high=data[data['category'] == 'g']['scaled_fWidth'][data['fSize'] >= mean_fSize+std_fSize].mean()
w_mu_h_high=data[data['category'] == 'h']['scaled_fWidth'][data['fSize'] >= mean_fSize+std_fSize].mean()
w_std_g_high=data[data['category'] == 'g']['scaled_fWidth'][data['fSize'] >= mean_fSize+std_fSize].std()
w_std_h_high=data[data['category'] == 'h']['scaled_fWidth'][data['fSize'] >= mean_fSize+std_fSize].std()

##plot length - high energy
sns.histplot(data,x=data['scaled_fLength'][data['fSize'] >= mean_fSize+std_fSize],hue='category',hue_order=['g', 'h'], kde=False, color='blue', ax=ax[0], palette=['red','blue'], edgecolor='#383734', linewidth=0.5,bins=32)
ax[0].set_title("Distribution of Scaled fLenght", fontsize=14)
ax[0].set_xlabel("Scaled fLength", fontsize=12)
ax[0].set_ylabel("Count", fontsize=12)
ax[0].axvline(l_mu_g_high,c='#990000', label= r'$\mu_{g}$', lw=1.8)
ax[0].axvline(l_mu_h_high,c='navy',label=r'$\mu_{h}$', lw=1.7)
legend = ax[0].get_legend()
ax[0].legend(['Hadron', 'Gamma'], title='Category')
ax[0].text(x=3,y=180,s=f"# of gamma events: {ng_high} \n# of hadron events: {nh_high}", fontsize=9, color='black')
ax[0].text(x=3,y=160,s=fr"$\mu_{{g}}$={l_mu_g_high:.2f} $\pm$ {l_std_g_high:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='#990000'))
ax[0].text(x=3,y=130,s=fr"$\mu_{{h}}$={l_mu_h_high:.2f} $\pm$ {l_std_h_high:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='navy'))

#plot width - high energy
sns.histplot(data,x=data['scaled_fWidth'][data['fSize'] >= mean_fSize+std_fSize],hue='category', kde=False, color='blue', ax=ax[1], palette=['red','blue'], edgecolor='#383734', linewidth=0.5,bins=40)
ax[1].set_title("Distribution of Scaled fWidth", fontsize=14)
ax[1].set_xlabel("Scaled fWidth", fontsize=12)
ax[1].set_ylabel("Count", fontsize=12)
ax[1].set_xlim(-1,8.5)
ax[1].axvline(w_mu_g_high,c='#990000', lw = 1.8) #label= r'$\mu_{g}$', lw=1.8)
ax[1].axvline(w_mu_h_high,c='navy', lw = 1.7) #label=r'$\mu_{h}$', lw=1.7)
legend = ax[1].get_legend()
ax[1].legend(['Hadron', 'Gamma'], title='Category')
ax[1].text(x=4,y=350,s=f"# of gamma events: {ng_high} \n# of hadron events: {nh_high}", fontsize=9, color='black')
ax[1].text(x=4,y=315,s=fr"$\mu_{{g}}$={w_mu_g_high:.2f} $\pm$ {w_std_g_high:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='#990000'))
ax[1].text(x=4,y=260,s=fr"$\mu_{{h}}$={w_mu_h_high:.2f} $\pm$ {w_std_h_high:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='navy'))

#### plots at low energy

fig1, ax1 = plt.subplots(1, 2, figsize=(12,5))
fig1.suptitle('Low Energy Events (low fSize values)', fontsize=18)
fig.subplots_adjust(top=0.85)  
###useful variables
ng_low=len(data[data['category'] == 'g']['scaled_fLength'][data['fSize'] <= mean_fSize-std_fSize])
nh_low=len(data[data['category'] == 'h']['scaled_fLength'][data['fSize'] <= mean_fSize-std_fSize])
l_mu_g_low=data[data['category'] == 'g']['scaled_fLength'][data['fSize'] <= mean_fSize-std_fSize].mean()
l_mu_h_low=data[data['category'] == 'h']['scaled_fLength'][data['fSize'] <= mean_fSize-std_fSize].mean()
l_std_g_low=data[data['category'] == 'g']['scaled_fLength'][data['fSize'] <= mean_fSize-std_fSize].std()
l_std_h_low=data[data['category'] == 'h']['scaled_fLength'][data['fSize'] <= mean_fSize-std_fSize].std()
w_mu_g_low=data[data['category'] == 'g']['scaled_fWidth'][data['fSize'] <= mean_fSize-std_fSize].mean()
w_mu_h_low=data[data['category'] == 'h']['scaled_fWidth'][data['fSize'] <= mean_fSize-std_fSize].mean()
w_std_g_low=data[data['category'] == 'g']['scaled_fWidth'][data['fSize'] <= mean_fSize-std_fSize].std()
w_std_h_low=data[data['category'] == 'h']['scaled_fWidth'][data['fSize'] <= mean_fSize-std_fSize].std()

## plot length - low energy
sns.histplot(data,x=data['scaled_fLength'][data['fSize'] <= mean_fSize-std_fSize],hue='category', kde=False, color='blue', ax=ax1[0], palette=['red','blue'],edgecolor='#383734', linewidth=0.5, bins=180)
ax1[0].set_title("Distribution of Scaled fLenght", fontsize=14)
ax1[0].set_xlabel("Scaled fLength", fontsize=12)
ax1[0].set_ylabel("Count", fontsize=12)
ax1[0].axvline(l_mu_g_low,c='#990000', label= r'$\mu_{g}$', lw=1.8)
ax1[0].axvline(l_mu_h_low,c='navy',label=r'$\mu_{h}$', lw=1.7,alpha=0.7)
legend = ax[0].get_legend()
ax1[0].legend(['Hadron', 'Gamma'], title='Category')
ax1[0].set_xlim(-1.1,-0.1)
ax1[0].text(x=-0.55,y=230,s=f"# of gamma events: {ng_low} \n# of hadron events: {nh_low} ", fontsize=9, color='black')
ax1[0].text(x=-0.55,y=208,s=fr"$\mu_{{g}}$={l_mu_g_low:.2f} $\pm$ {l_std_g_low:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='#990000'))
ax1[0].text(x=-0.55,y=178,s=fr"$\mu_{{h}}$={l_mu_h_low:.2f} $\pm$ {l_std_h_low:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='navy'))

## plot width - low energy
sns.histplot(data,x=data['scaled_fWidth'][data['fSize'] <= mean_fSize-std_fSize],hue='category', kde=False, color='blue', ax=ax1[1], palette=['red','blue'], edgecolor='#383734', linewidth=0.5,bins=30)
ax1[1].set_title("Distribution of Scaled fWidth", fontsize=14)
ax1[1].set_xlabel("Scaled fWidth", fontsize=12)
ax1[1].set_ylabel("Count", fontsize=12)
ax1[1].set_xlim(-1.3,0.0)
ax1[1].axvline(w_mu_g_low,c='#990000', label= r'$\mu_{g}$', lw=1.8)
ax1[1].axvline(w_mu_h_low,c='navy',label=r'$\mu_{h}$', lw=1.7)
legend = ax[1].get_legend()
ax1[1].legend(['Hadron', 'Gamma'], title='Category')
ax1[1].text(x=-0.54,y=350,s=f"# of gamma events: {ng_low} \n# of hadron events: {nh_low}", fontsize=9, color='black')
ax1[1].text(x=-0.54,y=320,s=fr"$\mu_{{g}}$={l_mu_g_low:.2f} $\pm$ {l_std_g_low:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='#990000'))
ax1[1].text(x=-0.54,y=280,s=fr"$\mu_{{h}}$={l_mu_h_low:.2f} $\pm$ {l_std_h_low:.2f}", fontsize=9, color='black',  bbox=dict(facecolor='white', alpha=0.5, edgecolor='navy'))


plt.show();

# %% [markdown]
# # Part 4: PCA
# In this part we will perform Principal Component Analysis (PCA). PCA is a statistical tecnique used for reducing the dimensionality of the problem. PCA is done studying in which directions of the feature space the dataset shows significant patterns. This is done computing the covariance matrix and finding its eigenvalues and eigenvectors using Linalg library (la). The eigenvectors are then used to redefine the feature space and aling data along them. Eigenvectors whose eigenvalues are higher correspond to directions of highest variance in the dataset. This way we can reduce the dimensionality of the problem and focus on the most significant directions. PCA is done separately for signal and background events, to find significative differences in spread for different labels.

# %%
file_name="magic04.data"
data = pd.DataFrame(pd.read_csv(file_name))

df= pd.DataFrame(data.values, columns=['fLength','fWidth','fSize','fConc','fConc1','fAsym','fM3Long','fM3Trans','fAlpha','fDist','class'])
df_1=df[df['class']=='g']
df_0=df[df['class']=='h']
df_1 = df_1.drop(columns=['class']) # no need for label to perform PCA
df_0 = df_0.drop(columns=['class']) 

print("Shape of signal data frame:",np.shape(df_1))
print("Shape of bkg data frame:",np.shape(df_0))
# Out:
# Shape of signal data frame: (12331, 10)
# Shape of bkg data frame: (6688, 10)

# %%
# We re-scale the data-set to mean zero and unitary std before executing the PCA   
for column in df_1.columns: 
    mean =df_1[column].mean()
    std= df_1[column].std()
    df_1[column]= (df_1[column]-mean)/std
for column in df_0.columns: 
    mean =df_0[column].mean()
    std= df_0[column].std()
    df_0[column]= (df_0[column]-mean)/std

# %%
df_1
# Out:
#         fLength     fWidth     fSize     fConc    fConc1     fAsym   fM3Long  \
# 0      -0.46046  -0.760816 -0.573381  0.823995  1.527718  0.581262  0.177195
# 1      4.523403  13.006763  2.757867  -1.94532 -1.848775   2.86389 -2.435386
# 2     -0.757944  -0.999015 -0.962066  1.298189  1.668012  0.604942 -0.715068
# 3      1.202731   1.365333  0.814225 -0.375535 -0.299882 -0.221084  0.316503
# 4      0.304432   0.283231   0.26877 -0.795793 -0.763137  1.202046  0.747688
# ...         ...        ...       ...       ...       ...       ...       ...
# 12326 -1.176177  -0.791727 -0.870077  1.979703  1.557848 -0.462468 -0.368425
# 12327 -0.641711   0.221696  0.197295 -0.223838  0.001423 -0.168803 -1.113903
# 12328 -0.823883  -0.852587 -1.057078  0.867819  0.723612  0.303856  0.012389
# 12329  0.480086   0.012071  0.314549 -0.741856 -0.713234    2.3551 -1.741272
# 12330  -0.46394    0.07684  0.375227 -0.483971 -0.598361  0.881792  0.113829
#
#        fM3Trans    fAlpha     fDist
# 0     -0.748903 -0.578221  0.213696
# 1     -3.350675  2.708118  0.946671
# 2     -0.541838 -0.387922 -1.045563
# 3      1.597412 -0.657955   2.36454
# 4      0.710088 -0.706133  0.680804
# ...         ...       ...       ...
# 12326  0.843377  0.103778  0.196285
# 12327 -0.682203 -0.688826  0.217067
# 12328  0.531735  0.106385 -0.952475
# 12329  0.825343 -0.599163  0.099156
# 12330 -0.904986 -0.055937  -0.27044
#
# [12331 rows x 10 columns]

# %%
df_0
# Out:
#         fLength    fWidth     fSize     fConc    fConc1     fAsym   fM3Long  \
# 12331  0.392734  0.336335  0.509333 -1.078145 -0.955834  0.869326  1.300189
# 12332  0.535902 -0.249909  0.864505 -1.400203 -1.198949 -0.434994  0.649403
# 12333  0.506171 -0.254443  0.435676 -0.325283 -0.587349 -0.363269  0.855943
# 12334    0.3574 -0.366573 -0.397221  0.336609  1.084807 -0.417957  -1.34382
# 12335 -0.568118 -0.592947 -0.053908  0.178717 -0.179052 -0.403375  0.158383
# ...         ...       ...       ...       ...       ...       ...       ...
# 19014 -0.855161 -0.657545 -0.591972  1.105678  1.520212  0.407652  0.203334
# 19015 -0.724699  -0.81255 -1.317922  0.841131  0.546058  0.672784  0.226829
# 19016  0.077684  0.688905  1.139571 -1.215647 -1.347189  0.108521  0.621122
# 19017  0.855352  1.769025  2.274791 -1.462941 -1.233679  0.292734 -1.282777
# 19018  2.005736  0.890095  0.642288 -0.452851  -0.50857 -1.810805 -2.342868
#
#        fM3Trans    fAlpha     fDist
# 12331   0.38302 -1.149281  0.384367
# 12332 -0.515505  1.711764  0.910031
# 12333 -0.333989 -0.892876  1.783286
# 12334 -0.583383  0.765787 -0.850547
# 12335  0.254152 -0.748348 -0.446646
# ...         ...       ...       ...
# 19014  0.084175  -1.59954 -1.143376
# 19015 -0.111018  1.647644   0.57434
# 19016 -0.328377 -0.526731   0.68501
# 19017 -2.145759  1.566436  2.539158
# 19018   1.04008  0.336584  0.878007
#
# [6688 rows x 10 columns]

# %%
cov_1 = df_1.cov()
cov_0 = df_0.cov()
cov_1
# Out:
#            fLength    fWidth     fSize     fConc    fConc1     fAsym  \
# fLength   1.000000  0.695644  0.766118 -0.710209 -0.679994 -0.120212
# fWidth    0.695644  1.000000  0.855155 -0.761340 -0.731434 -0.002589
# fSize     0.766118  0.855155  1.000000 -0.863440 -0.825395  0.029039
# fConc    -0.710209 -0.761340 -0.863440  1.000000  0.979332 -0.033398
# fConc1   -0.679994 -0.731434 -0.825395  0.979332  1.000000 -0.037624
# fAsym    -0.120212 -0.002589  0.029039 -0.033398 -0.037624  1.000000
# fM3Long   0.542507  0.422045  0.540963 -0.452184 -0.433913  0.162435
# fM3Trans  0.012337  0.044016  0.022622 -0.017356 -0.016053 -0.005598
# fAlpha   -0.443232 -0.296886 -0.458023  0.482322  0.463536 -0.004571
# fDist     0.602479  0.389206  0.459641 -0.368592 -0.347123 -0.178190
#
#            fM3Long  fM3Trans    fAlpha     fDist
# fLength   0.542507  0.012337 -0.443232  0.602479
# fWidth    0.422045  0.044016 -0.296886  0.389206
# fSize     0.540963  0.022622 -0.458023  0.459641
# fConc    -0.452184 -0.017356  0.482322 -0.368592
# fConc1   -0.433913 -0.016053  0.463536 -0.347123
# fAsym     0.162435 -0.005598 -0.004571 -0.178190
# fM3Long   1.000000  0.008234 -0.271465  0.294765
# fM3Trans  0.008234  1.000000 -0.007311  0.009752
# fAlpha   -0.271465 -0.007311  1.000000 -0.425032
# fDist     0.294765  0.009752 -0.425032  1.000000

# %%
cov_0
# Out:
#            fLength    fWidth     fSize     fConc    fConc1     fAsym  \
# fLength   1.000000  0.773884  0.747319 -0.688524 -0.651879 -0.423194
# fWidth    0.773884  1.000000  0.790355 -0.672618 -0.638750 -0.304118
# fSize     0.747319  0.790355  1.000000 -0.839128 -0.796837 -0.305340
# fConc    -0.688524 -0.672618 -0.839128  1.000000  0.972725  0.238806
# fConc1   -0.651879 -0.638750 -0.796837  0.972725  1.000000  0.220317
# fAsym    -0.423194 -0.304118 -0.305340  0.238806  0.220317  1.000000
# fM3Long  -0.307349 -0.296956 -0.223553  0.124154  0.115716  0.285738
# fM3Trans  0.013007  0.039519  0.010992 -0.007704 -0.008235  0.006849
# fAlpha   -0.009282  0.041617 -0.004228 -0.010714 -0.015137  0.053334
# fDist     0.325267  0.354997  0.394842 -0.267684 -0.245179 -0.229049
#
#            fM3Long  fM3Trans    fAlpha     fDist
# fLength  -0.307349  0.013007 -0.009282  0.325267
# fWidth   -0.296956  0.039519  0.041617  0.354997
# fSize    -0.223553  0.010992 -0.004228  0.394842
# fConc     0.124154 -0.007704 -0.010714 -0.267684
# fConc1    0.115716 -0.008235 -0.015137 -0.245179
# fAsym     0.285738  0.006849  0.053334 -0.229049
# fM3Long   1.000000 -0.026806 -0.001489 -0.131121
# fM3Trans -0.026806  1.000000  0.010832  0.013150
# fAlpha   -0.001489  0.010832  1.000000 -0.097112
# fDist    -0.131121  0.013150 -0.097112  1.000000

# %%
l_1,V_1= la.eig(cov_1)
l_1=l_1.real
V_1=V_1.real
print("Eigenvalues Gamma events:", l_1,'\n')
print("Eigenvectors Gamma events:", V_1,'\n')
# Out:
# Eigenvalues Gamma events: [5.04135896 1.18671249 1.00189813 0.86259252 0.73828989 0.52867675
#  0.01763177 0.10500615 0.29317529 0.22465805]
#
# Eigenvectors Gamma events: [[ 3.86563154e-01  1.64161550e-01 -1.87852855e-02 -5.17321758e-02
#    2.27306595e-01 -6.21165157e-02  1.64670468e-02  2.62838530e-02
#   -3.75283692e-02  8.73323351e-01]
#  [ 3.76614052e-01 -6.58692554e-02  5.96665086e-02  3.13862948e-01
#    9.53882263e-02 -2.55432045e-01 -4.24256844e-03  4.90484637e-01
#   -6.23609927e-01 -2.18920288e-01]
#  [ 4.17121017e-01 -7.65050692e-02  1.22260020e-02  1.38753617e-01
#    1.93685374e-02 -6.00347575e-02  1.05957925e-01 -8.36960174e-01
#   -2.44851708e-01 -1.58410555e-01]
#  [-4.09538760e-01  1.17040480e-01 -9.64678415e-03 -2.30228965e-01
#    2.25834045e-01 -6.25170832e-02  7.50095221e-01 -4.79749462e-02
#   -3.77875580e-01  5.32663335e-02]
#  [-3.98738464e-01  1.26974491e-01 -9.56015222e-03 -2.43724055e-01
#    2.46152389e-01 -7.37984117e-02 -6.52335699e-01 -1.94150192e-01
#   -4.81400557e-01  6.61244443e-02]
#  [-1.90622395e-03 -8.04052066e-01 -3.28590356e-02 -3.80203807e-01
#   -9.19693200e-02 -4.28997470e-01 -9.83604836e-04  9.79016721e-03
#    1.56041455e-02  1.22574473e-01]
#  [ 2.71903952e-01 -2.41249770e-01 -3.78642354e-02 -3.23906107e-01
#    6.32530906e-01  5.46456330e-01 -8.61015132e-03  1.03440095e-01
#    5.50948287e-02 -2.21356334e-01]
#  [ 1.26092933e-02  7.19184389e-03  9.93064376e-01 -1.11114138e-01
#   -9.57172582e-03  1.53254329e-02  2.12728561e-04 -9.64915066e-03
#    2.61091729e-02  1.28354940e-02]
#  [-2.57574835e-01 -1.45524116e-01  6.79277022e-02  5.49090461e-01
#    6.21464113e-01 -3.39978798e-01 -1.14649466e-02 -7.84584893e-02
#    3.13437642e-01  5.46497448e-03]
#  [ 2.59975576e-01  4.55091241e-01 -4.94837864e-02 -4.51483873e-01
#    1.80007439e-01 -5.65210973e-01 -9.61549203e-03  3.45139415e-02
#    2.70203068e-01 -3.04727483e-01]]

# %%
l_0,V_0= la.eig(cov_0)
l_0=l_0.real
V_0=V_0.real
print("Eigenvalues background events:", l_0,'\n')
print("Eigenvectors background events:", V_0,'\n')
# Out:
# Eigenvalues background events: [4.42388448 0.02391582 0.14984033 0.2221564  0.43740477 1.20808117
#  0.69931975 0.80384168 1.03760086 0.99395472]
#
# Eigenvectors background events: [[-4.13567164e-01 -2.63725151e-02 -1.06784542e-01  7.64522513e-01
#   -4.62230622e-01 -8.23597651e-02 -5.41729191e-02  7.12962716e-02
#    4.76672675e-02 -4.04817037e-02]
#  [-4.10369824e-01  1.18010294e-02  4.74225410e-01 -4.98487549e-01
#   -5.76267380e-01 -9.62312079e-03  1.32890905e-01 -2.68784361e-02
#    8.66124162e-02 -4.11274819e-03]
#  [-4.39407630e-01 -1.02147327e-01 -8.06450398e-01 -3.56019314e-01
#   -3.84986171e-02  1.09655517e-01  5.96543774e-02 -1.63618469e-02
#   -4.11859284e-02  1.85943597e-02]
#  [ 4.26015621e-01 -7.48302786e-01 -1.36062501e-01 -5.34223025e-02
#   -3.57161556e-01 -2.95977603e-01  2.83083846e-02 -1.28650819e-01
#    6.42454683e-02 -2.32311900e-02]
#  [ 4.12889561e-01  6.54722945e-01 -2.94628020e-01 -7.73629598e-02
#   -4.28069468e-01 -3.13905698e-01  2.86139245e-02 -1.45244984e-01
#    6.18974490e-02 -2.33016102e-02]
#  [ 2.10557832e-01 -7.40397142e-04 -3.55910497e-02  1.47422983e-01
#   -1.46018555e-01  5.34160663e-01  7.75942210e-01 -3.19883815e-02
#   -6.50820677e-02  1.36639359e-01]
#  [ 1.56723710e-01 -9.82568990e-03 -1.68716012e-03 -8.72677373e-03
#   -2.86536343e-01  5.81070528e-01 -5.65135446e-01 -2.90368802e-01
#   -3.54285779e-01  1.62189920e-01]
#  [-1.12947495e-02  3.15103998e-04 -1.47230802e-02  1.26216402e-02
#    2.33848465e-02 -3.73288613e-02 -8.88561614e-02  3.08618973e-02
#    4.39405146e-01  8.91981616e-01]
#  [ 2.80804609e-03  1.13046169e-03 -2.41165114e-02  3.27484558e-02
#    6.09854767e-02  3.00604868e-01 -9.24616134e-02 -4.17620174e-01
#    7.67868956e-01 -3.62871549e-01]
#  [-2.15592824e-01  3.67233256e-03  7.71910499e-02  9.15713297e-02
#    1.85143711e-01 -2.83254481e-01  1.90571725e-01 -8.34016294e-01
#   -2.60993030e-01  1.56949242e-01]]

# %%
#GAMMA EVENTS
# sort eigenvalues in descending order and get sorted indices
sorted_indices = np.argsort(l_1)[::-1]
l_sorted = l_1[sorted_indices] 
 
variance_explained = l_sorted / np.sum(l_sorted) # ratio of the variance of the data explained by each feature

# cumulative variance explained
cumulative_variance = np.cumsum(variance_explained)

feature_names = df_1.columns.tolist()
pca_list = []
for i in range(len(feature_names)):
    pca_list.append(f'PC_{i+1}')

# features ordered from most important to least important to variability 
top_features = []
for i in range(len(feature_names)):
    most_important_feature_idx = sorted_indices[i]  # Index of the feature with the largest eigenvalue
    top_features.append(feature_names[most_important_feature_idx])

fig, ax1 = plt.subplots(figsize=(16, 8))

ax1.bar(pca_list, variance_explained, color='Orange', edgecolor='black',alpha=0.75)

ax2 = ax1.twinx()
ax2.plot(pca_list, cumulative_variance, label='Cumulative Variance Explained', marker='o', color='red')

ax1.set_ylabel('Variance Explained',fontsize=20)
ax2.set_ylabel('Cumulative Variance Explained',fontsize=20)
ax1.set_xlabel('# Principal component',fontsize=20)

plt.title('Gamma events: variance explained by each feature',fontsize=26)
ax2.legend(loc='upper center',fontsize=16)

plt.xticks(rotation=45, ha='right', fontsize=45)  
ax1.tick_params(axis='y', labelsize=16)  
ax2.tick_params(axis='y', labelsize=16)
ax1.tick_params(axis='x', labelsize=16)
plt.grid()
plt.show()
print("\n")

#BACKGROUND EVENTS 
sorted_indices = np.argsort(l_0)[::-1]
l_sorted = l_0[sorted_indices] 
 
variance_explained = l_sorted / np.sum(l_sorted) # ratio of the variance of the data explained by each feature

# cumulative variance explained
cumulative_variance = np.cumsum(variance_explained)

feature_names = df_0.columns.tolist()

# features ordered from most important to least important to variability 
top_features = []
for i in range(len(feature_names)):
    most_important_feature_idx = sorted_indices[i]  # Index of the feature with the largest eigenvalue
    top_features.append(feature_names[most_important_feature_idx])

fig, ax1 = plt.subplots(figsize=(16, 8))

ax1.bar(pca_list, variance_explained, color='Orange', edgecolor='black',alpha=0.75)

ax2 = ax1.twinx()
ax2.plot(pca_list, cumulative_variance, label='Cumulative Variance Explained', marker='o', color='blue')

ax1.set_ylabel('Variance Explained',fontsize=20)
ax1.set_xlabel('# Principal component',fontsize=20)
ax2.set_ylabel('Cumulative Variance Explained',fontsize=20)


plt.title('Background events: variance explained by each feature',fontsize=26)
ax2.legend(loc='upper center',fontsize=16)

plt.xticks(rotation=45, ha='right', fontsize=18)  
ax1.tick_params(axis='y', labelsize=16)  
ax2.tick_params(axis='y', labelsize=16)
ax1.tick_params(axis='x', labelsize=16)
plt.grid()
plt.show()

# %% [markdown]
# We notice that, for both signal and background events, the first principal component explains about half of the variance of the dataset, while the other component are responsible for about 10% at maximum. Being the principal components linear combinations of the features of the dataset, it is not possible to identify which features of the dataset are most influential. Therefore we perform the following analysis keeping the original dataset.

# %% [markdown]
# # Part 5: Machine Learning Analysis
# In this section we are going to implement several ML algorithms to classify the data in signal and background classes. Metrics used to evaluate data are the area under ROC curve in the range [0-0.2] (false positive rate values), since we mostly want to avoid accpeting hadrons, and the quality factor $Q=\frac{\epsilon_{\gamma}}{\sqrt{\epsilon_h}}$, where ${\epsilon_{\gamma}}$ represents the fraction of correctly classified signals, and ${{\epsilon_h}}$ represents the fraction of hadrons classified as signals. Our objective is to correctly identify signals while also minimizing the false positives (background identified as signals). To this extent, our aim is maximizing area under the ROC curve and the quality factor Q, ignoring the fraction of gamma points classified as background. This way we ensure to have better quality results.
#
# The models are going to be trained on the training set with a K-fold. Moreover, a grid search on the hyperparameters is going to be run.

# %% [markdown]
# ## Part 5.1: Perceptron
# The following code is about Perceptron algorithm. Scikit learn library is going to be used. Also, all the training is going to be performed keeping out the feature Alpha.
#
# First, we associate +1 label to gammas and -1 label to hadrons. Then we split train and test set (20% of total data)

# %%
# Alpha has not to be normalized (reset to original value)
X_rescaled['fAlpha'] = original_alpha.copy()

new_Y = []

# gammas are +1    hadrons are -1

for i in range(len(Y)):
    if (Y.iloc[i] == 'g'):
        new_Y.append(1)
    if(Y.iloc[i] == 'h'):
        new_Y.append(-1)
        
Y_df = pd.DataFrame({'category' : new_Y})
data_rescaled_and_indexed = pd.merge(X_rescaled, Y_df,left_index=True, right_index=True)

# divide dataset in 5 parts, taking 1 as test set ( 20 % )
# remove alpha

parts_to_be_split = 5 
train_set, test_set = split_train_test_set( data_rescaled_and_indexed , parts_to_be_split )
train_alpha = train_set['fAlpha']
train_set = train_set.drop('fAlpha',axis=1)
test_alpha = test_set['fAlpha']
test_set = test_set.drop('fAlpha',axis=1)
X_train, Y_train = split_X_Y(train_set)
X_test, Y_test = split_X_Y(test_set)

print('Train set shapes:',np.shape(X_train),np.shape(Y_train))
print('Absolute and relative frequence of points in Training set:')
print(f'Signal: {len(Y_train[Y_train == 1])} points \t {round(len(Y_train[Y_train == 1])/len(Y_train)*100,2)}%')
print(f'Back: {len(Y_train[Y_train == -1])} points \t {round(len(Y_train[Y_train == -1])/len(Y_train)*100,2)}%\n')

print('Test set shapes:',np.shape(X_test),np.shape(Y_test))
print('Absolute and relative frequence of points in Test set:')
print(f'Signal: {len(Y_test[Y_test == 1])} points \t {round(len(Y_test[Y_test == 1])/len(Y_test)*100,2)}%')
print(f'Back: {len(Y_test[Y_test == -1])} points \t {round(len(Y_test[Y_test == -1])/len(Y_test)*100,2)}%\n')
# Out:
# Train set shapes: (15216, 9) (15216,)
# Absolute and relative frequence of points in Training set:
# Signal: 9868 points 	 64.85%
# Back: 5348 points 	 35.15%
#
# Test set shapes: (3803, 9) (3803,)
# Absolute and relative frequence of points in Test set:
# Signal: 2463 points 	 64.76%
# Back: 1340 points 	 35.24%

# %% [markdown]
# The following cell performs the training. The parameters are set at the beginning and the best model criterion is the one that maximizes ROC area in range [0-0.2]

# %%
n_attempts = 10000
limit = 0.2 
best_scores = []
best_f = []
best_t = []
best_score = 0

# K fold definition
K = 5
limit = 0.2 
kf = KFold(n_splits=K, shuffle=True, random_state=42) 

#print('n_iter, score')
for i in range (n_attempts):
    auc_fold = 0
    filtered_auc_fold = 0
    
    state = abs(np.random.normal(size=1))
    state = int(state[0] * 1000000)
    perceptron = Perceptron(alpha=0.01,penalty='l2',max_iter=10000,tol=1e-4,random_state=state,n_iter_no_change=10)
    
    for train_idx, val_idx in kf.split(data_rescaled_and_indexed):  ###gets the index of training and validation set
                
        train_K=data_rescaled_and_indexed.iloc[train_idx]
        valid_K=data_rescaled_and_indexed.iloc[val_idx]
        X_train_K, Y_train_K = split_X_Y(train_K)
        X_valid_K, Y_valid_K = split_X_Y(valid_K)
    
    
        fitted = perceptron.fit(X_train_K,Y_train_K)
    
        decision_values = perceptron.decision_function(X_valid_K)

        fpr, tpr, thresholds = roc_curve(Y_valid_K, decision_values)
    
        # here i filter data to compute roc curve area for fpr in range 0 -> 0.8
        fpr_filtered = fpr[fpr <= limit]
        tpr_filtered = tpr[:len(fpr_filtered)]
    
        auc_filtered_K = np.trapz(tpr_filtered, fpr_filtered)
        auc_K = roc_auc_score(Y_valid_K, decision_values)
        auc_fold += auc_K / K
        filtered_auc_fold += auc_filtered_K / K
    
    # score is better if filtered is better, though saving all 
    if (filtered_auc_fold > best_score):
        best_score = filtered_auc_fold
        best_scores.append(auc_fold)
        #best_f.append(fpr)
        best_fpr = fpr
        best_tpr = tpr
        #best_t.append(tpr)
        best_perceptron = perceptron
        #print(i, auc)

print('Trained',n_attempts,'perceptrons')
print("best AUC-ROC Score:")
print(round(best_scores[len(best_scores)-1],3))
# Out:
# Trained 10000 perceptrons
# best AUC-ROC Score:
# 0.798

# %% [markdown]
# Here we plot the confusion matrix for the best model:

# %%
def normalize_cm(cm):
    norm_cm = np.zeros(shape=(2,2))
    bkg = cm[0,0] + cm[0,1]  # first row is bkg
    sig = cm[1,0] + cm[1,1]  # second row is signal
    norm_cm[0,0] = round(cm[0,0] / bkg,3)
    norm_cm[0,1] = round(cm[0,1] / bkg,3)
    norm_cm[1,0] = round(cm[1,0] / sig,3)
    norm_cm[1,1] = round(cm[1,1] / sig,3)
    
    return norm_cm


def plot_cm(cm,method_name):
    fig = plt.figure()
    im = plt.imshow(cm, cmap='seismic',alpha=0.8, interpolation='nearest')
    plt.xticks([0,1], ['bkg', 'signal'],ha="right",rotation=0)
    plt.yticks([0,1], ['bkg', 'signal'],ha="right",rotation=0)
    fmt = '.2f'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            text = plt.text(j, i, format(cm[i, j], fmt),
            ha="center", va="center",
            color="white")
            text.set_path_effects([path_effects.withStroke(linewidth=1.5, foreground='black')])
            
    fig.tight_layout()
    fig.colorbar(im, location = 'right') 

    plt.xlabel('predicted label')
    plt.ylabel('true label')

    plt.title(f'{method_name} confusion matrix')
    plt.show()

# %%
model = best_perceptron
best_perceptron.fit(X_train,Y_train)
Y_pred = model.predict(X_test)

cm = confusion_matrix(Y_test,Y_pred)

# %%
perceptron_cm = normalize_cm(cm)

print('Confusion matrix:')
print(perceptron_cm)
plot_cm(perceptron_cm,method_name='Perceptron')
# Out:
# Confusion matrix:
# [[0.419 0.581]
#  [0.268 0.732]]

# %% [markdown]
# In the end we take the ROC curve and the best Q value (the one closest to the point (0,1)). We save it in a variable that will be used later as confrontation.

# %%
fig = plt.figure(figsize=(8, 6))

fpr_perceptron = best_fpr
tpr_perceptron = best_tpr

Q_perceptron = perceptron_cm[1][1]/ np.sqrt(perceptron_cm[0][1])
print('Perceptron Q value:',round(Q_perceptron,3))
plt.plot(fpr_perceptron, tpr_perceptron, label=f'ROC Curve (AUC = {best_scores[len(best_f)-1]:.3f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Diagonal line (random classifier)
plt.title('Perceptron ROC Curve')
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.legend(loc='lower right')
plt.grid(True)
plt.show();
# Out:
# Perceptron Q value: 0.96

# %% [markdown]
# ## Part 5.2: Logistic Regression (version 3)

# %% [markdown]
# Logistic regression allows to pose a classification problem as a regression problem, where the predicted label is the probability for a sample to belong to a certain class. Thus, in our case the output of the algorithm is the *gammaness*. We can then choose a threshold for the *gammaness* to assign gamma (+1) as the predicted label. The learning problem is to find the sigmoid function
# $\sigma_{\mathbf{w}}(\mathbf{x}) =\frac{1}{1 + e^{-(\mathbf{w}^T \mathbf{x})}}$
# that minimizes the loss:
#
# $$
# \mathcal{L}(\mathbf{y}, \sigma_{\mathbf{w}}(\mathbf{x})) + \lambda||\mathbf{w}||^2
# $$
# where:
# $$
# \mathcal{L}(\mathbf{y}, \sigma_{\mathbf{w}}(\mathbf{x})) = -\sum_{i=1}^{n} \left[ y_i \log(\sigma_{\mathbf{w}}(\mathbf{x}_i)) + (1 - y_i) \log(1 - \sigma_{\mathbf{w}}(\mathbf{x}_i)) \right]$$
# and we use the Tikhonov regularization technique to prevent overfitting.
#
# To find the best hyper-parameter $C=\frac{1}{\lambda}$ for model we choose the usual 0.5 threshold for the *gammaness* and perform a K-fold cross validation, where again we keep as best model the one that maximizes the partial AUC.

# %%
# this function determines the partial area under the curve, up to FPR<=0.2
def partial_auc_at_fpr(y_true, y_pred_proba):
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_proba)
    valid_indices = fpr <= 0.2  # indices where FPR <= 0.2
    partial_fpr = fpr[valid_indices]
    partial_tpr = tpr[valid_indices]
    # check if there are at least 2 points for partial AUC calculation
    if len(partial_fpr) < 2:
        return 0  # return 0 if not enough points to calculate AUC

    partial_auc = auc(partial_fpr, partial_tpr)
    return partial_auc

def full_auc_scorer(y_true, y_pred_proba):
    fpr, tpr, _ = roc_curve(y_true, y_pred_proba)
    return auc(fpr, tpr)

# create scoring function (partial AUC) to implement a grid-search
partial_auc_scorer = make_scorer(partial_auc_at_fpr, greater_is_better=True)

# %%
auc_scorer = make_scorer(full_auc_scorer, greater_is_better=True, response_method='predict') 

# hyper-parameters 
param_grid = {'C': [0.001,0.005,0.01,0.05,0.1,0.5,1,5,10,50,100,500,1000]} # we use Tikhonov regularization: in the loss we add a term proportional to the norm squared of w (C=1/lambda)

# grid search with K-fold validation
K=5

fprs = []
tprs = []
aucs = []
partial_aucs = []
C = []
for c in param_grid['C']:
        auc_value=0
        partial_auc=0
        print(f"Training model with regularization constant c = {c}")
        C.append(c)
        for i in range(K):
            train_K, valid_K = split_train_test_set(train_set,K)
            X_train_K, Y_train_K = split_X_Y(train_K)
            X_valid_K, Y_valid_K = split_X_Y(valid_K)
            model= LogisticRegression(penalty='l2',tol=1e-5,C=c,solver='lbfgs',max_iter=int(1e6)) # 'lbfgs' approximates up to the the second derivative of the loss function to optimize the coefficients, best for large datasets 
            model.fit(X_train_K,Y_train_K)
                    
            y_pred_proba = model.predict_proba(X_valid_K)[:, 1]  
            fpr, tpr, _ = roc_curve(Y_valid_K, y_pred_proba)
            fprs.append(fpr)
            tprs.append(tpr)
            auc_value_k = auc(fpr, tpr)
            # keep fpr less than 0.2 (if not able to find it, partial auc is set to zero)
            partial_fpr = fpr[fpr <= 0.2]
            if (len(partial_fpr) < 2 ):
                partial_auc=0
            else:
                partial_tpr = tpr[:len(partial_fpr)]
                partial_auc_k = auc(partial_fpr, partial_tpr)
            partial_auc += partial_auc_k/K
            auc_value += auc_value_k/K
        print('Partial AUC:', partial_auc)
        partial_aucs.append(partial_auc)
        print('AUC:', auc_value,'\n')
        aucs.append(auc_value)
# Out:
# Training model with regularization constant c = 0.001
# Partial AUC: 0.04139197446904923
# AUC: 0.6984437528875256
#
# Training model with regularization constant c = 0.005
# Partial AUC: 0.04569182025028978
# AUC: 0.7151156053890375
#
# Training model with regularization constant c = 0.01
# Partial AUC: 0.04496026584990355
# AUC: 0.7186701131844131
#
# Training model with regularization constant c = 0.05
# Partial AUC: 0.04291911388505856
# AUC: 0.7152189950861552
#
# Training model with regularization constant c = 0.1
# Partial AUC: 0.042888681475701906
# AUC: 0.7144333300790808
#
# Training model with regularization constant c = 0.5
# Partial AUC: 0.042438078391245145
# AUC: 0.7122828464709854
#
# Training model with regularization constant c = 1
# Partial AUC: 0.04250136226929782
# AUC: 0.7184956889989256
#
# Training model with regularization constant c = 5
# Partial AUC: 0.04265953600960503
# AUC: 0.7140485630175593
#
# Training model with regularization constant c = 10
# Partial AUC: 0.044227372676915525
# AUC: 0.7165388949097505
#
# Training model with regularization constant c = 50
# Partial AUC: 0.04433382798710397
# AUC: 0.7184488019011281
#
# Training model with regularization constant c = 100
# Partial AUC: 0.042940191818390754
# AUC: 0.7109308176102211
#
# Training model with regularization constant c = 500
# Partial AUC: 0.043154859296788965
# AUC: 0.7139727609127458
#
# Training model with regularization constant c = 1000
# Partial AUC: 0.041993773742586074
# AUC: 0.7134626468011739

# %%
best_partial_auc = np.max(np.array(partial_aucs))
best_auc= np.max(np.array(aucs))
best_index = np.where(partial_aucs==best_partial_auc)[0]
print('Best model with regularization constant c=',C[best_index[0]])
print('Best partial AUC (validation set):', best_partial_auc)
print('AUC of best model (validation set):', best_auc,'\n')

best_model = LogisticRegression(penalty='l2', C= C[best_index[0]],solver='lbfgs',max_iter=300)
best_model.fit(X_train,Y_train) # retrain the best
y_pred_proba_test = model.predict_proba(X_test)[:, 1]  
fpr_test, tpr_test, _ = roc_curve(Y_test, y_pred_proba_test)
auc_test= auc(fpr_test,tpr_test)

partial_fpr_test = fpr_test[fpr_test <= 0.2]
if (len(partial_fpr_test)<2):
    partial_auc_test=0
else:
    partial_tpr_test = tpr_test[:len(partial_fpr_test)]
    partial_auc_test = auc(partial_fpr_test, partial_tpr_test)
print('Best partial AUC (test set):', partial_auc_test)
print('AUC of best model (test set):', auc_test)
# Out:
# Best model with regularization constant c= 0.005
# Best partial AUC (validation set): 0.04569182025028978
# AUC of best model (validation set): 0.7186701131844131
#
# Best partial AUC (test set): 0.04235642736379006
# AUC of best model (test set): 0.7039734336841977

# %%
Y_pred = best_model.predict(X_test)
cm = confusion_matrix(Y_test,Y_pred)
log_cm = normalize_cm(cm)

print('Confusion matrix:')
print(log_cm)
plot_cm(log_cm,method_name='Logistic Regression')
# Out:
# Confusion matrix:
# [[0.304 0.696]
#  [0.041 0.959]]

# %% [markdown]
# Here we plot the best model for ROC curve

# %%
fpr_log = fpr_test
tpr_log = tpr_test
Q_log = log_cm[1][1]/ np.sqrt(log_cm[0][1])
print('Q value of best model:',Q_log)

plt.figure()
plt.plot(fpr_test, tpr_test, color='#d173b8', lw=2, label=f'ROC curve (AUC = {auc_test:.3f})')
plt.plot([0, 1], [0, 1], color='red', linestyle='--') 
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.02])
plt.xlabel('False Positive Rate',fontsize=13.8)
plt.ylabel('True Positive Rate',fontsize=13.8)
plt.title('Logistic Regression ROC Curve',fontsize=14.3)
plt.grid(alpha=0.4)
plt.legend(loc='best')
plt.show()
# Out:
# Q value of best model: 1.1495132653112086

# %% [markdown]
# Here we plot the two ROCs computed until now

# %%
plt.figure()
plt.plot(fpr_perceptron, tpr_perceptron, label=f'ROC Curve (AUC = {best_scores[len(best_f)-1]:.3f})')
plt.plot(fpr_test, tpr_test, color='#d173b8', lw=2, label=f'ROC curve (AUC = {auc_test:.3f})')
plt.plot([0, 1], [0, 1], color='red', linestyle='--') 
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.02])
plt.xlabel('False Positive Rate',fontsize=13.8)
plt.ylabel('True Positive Rate',fontsize=13.8)
plt.title('Logistic Regression VS Perceptron',fontsize=14.3)
plt.grid(alpha=0.4)
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## Part 5.3: SVM
# In this part the same dataset is analyzed with soft SVM. Different kernels are tried (linear,poly with deg 3,rbf and sigmoid), as well as different values for parameters such as nu and gamma

# %%
alphaCol = data_rescaled_and_indexed['fAlpha'] 
data_rescaled_and_indexed = data_rescaled_and_indexed.drop('fAlpha',axis = 1)
print(np.shape(data_rescaled_and_indexed))
# Out:
# (19019, 10)

# %%
# list with all possible kernels (poly uses deg = 3 as standard value)
kernels = ['linear','poly','rbf','sigmoid']


# list with all nu values (upper bound on fraction of margin errors)
nus = [ 0.5 , 0.1 , 0.05 , 0.01 ]

# list with all gamma values (by default is 1/(n_features*X.var()) )
gammas = [ 0.1, 0.01, 0.001, 0.0001 ]

best_auc_score = 0

# tolerance for stopping criteria (default is 1e-3) (default max_iter is inf)
tolerance = 1e-6
max_iter = int(2e4)

# K fold definition
K = 5
limit = 0.2 
kf = KFold(n_splits=K, shuffle=True, random_state=42) 
kFoldInfo = 0

start_time = time()


for kernel_type in kernels:
    for nu in nus:
        for gamma in gammas:
            print(f'training SVM with {kernel_type} kernel...')
            partial_auc = 0
            auc_value = 0
            for train_idx, val_idx in kf.split(data_rescaled_and_indexed):  ###gets the index of training and validation set
                
                train_K=data_rescaled_and_indexed.iloc[train_idx]
                valid_K=data_rescaled_and_indexed.iloc[val_idx]
                X_train_K, Y_train_K = split_X_Y(train_K)
                X_valid_K, Y_valid_K = split_X_Y(valid_K)
                
                if kFoldInfo == 0:
                    print("Train fold size:",np.shape(X_train_K),"\t Test fold size:",np.shape(X_valid_K))
                    KFoldInfo = 1
                
                clf = make_pipeline(StandardScaler(), NuSVC(nu=nu,kernel=kernel_type,gamma=gamma,probability=True,tol=tolerance,max_iter=max_iter),verbose=False)
    
                fitted = clf.fit(X_train_K, Y_train_K)
                pred = clf.predict(X_valid_K)
                errors = np.sum(pred != Y_valid_K) / len(Y_valid_K)
                
                pred_prob = clf.predict_proba(X_valid_K)[:, 1]
                fpr, tpr, thresholds = roc_curve(Y_valid_K, pred_prob)
                
                auc_value_k = auc(fpr, tpr)
                fpr_filtered = fpr[fpr <= limit]

                if (len(fpr_filtered) < 2 ):
                    partial_auc=0
                else:
                    tpr_filtered = tpr[:len(fpr_filtered)]
                    partial_auc_k = np.trapz(fpr_filtered, tpr_filtered)
                partial_auc += partial_auc_k/K
                auc_value += auc_value_k/K                 
            if(partial_auc > best_auc_score):
                best_auc_score = partial_auc
                best_model = clf
                best_tpr = tpr
                best_fpr = fpr
                best_auc = auc_value
                best_kernel = kernel_type
                best_nu = nu
                best_gamma = gamma
                print(partial_auc.round(3),best_auc.round(3), kernel_type, nu, gamma)
            print('elapsed time:',round(time()-start_time,3),'s')
            start_time = time()

print('best results are for')
print('kernel:',best_kernel,'nu:',best_nu,'gamma:',best_gamma,'with auc:',best_auc)
# Out:
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# 0.022 0.505 linear 0.5 0.1
# elapsed time: 136.013 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# 0.026 0.554 linear 0.5 0.01
# elapsed time: 124.198 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 133.948 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 124.295 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 63.043 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# 0.026 0.586 linear 0.1 0.01
# elapsed time: 63.039 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 61.57 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# 0.027 0.594 linear 0.1 0.0001
# elapsed time: 63.033 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 55.505 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 47.663 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 1414.646 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 78.685 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 58.098 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 40.322 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 40.159 s
# training SVM with linear kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 35.405 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# 0.054 0.793 poly 0.5 0.1
# elapsed time: 168.861 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# 0.055 0.793 poly 0.5 0.01
# elapsed time: 168.006 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 129.995 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 83.081 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 62.854 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 62.239 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 21.231 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 16.006 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 50.023 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 49.41 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 11.605 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 7.602 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 41.57 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 39.174 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 3.567 s
# training SVM with poly kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 1.724 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# 0.058 0.843 rbf 0.5 0.1
# elapsed time: 214.462 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 233.736 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 256.76 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 250.301 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 108.03 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 94.367 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 86.415 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 85.722 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 84.935 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 67.907 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 62.701 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 68.753 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 75.908 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 53.827 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 48.386 s
# training SVM with rbf kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 49.256 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 312.936 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 269.055 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 218.827 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 180.667 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 73.182 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 70.36 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 79.485 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 37.13 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 37.611 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 33.288 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 57.723 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 21.645 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 8.808 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 7.218 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 30.971 s
# training SVM with sigmoid kernel...
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15215, 9) 	 Test fold size: (3804, 9)
# Train fold size: (15216, 9) 	 Test fold size: (3803, 9)
# elapsed time: 3.411 s
# best results are for
# kernel: rbf nu: 0.5 gamma: 0.1 with auc: 0.8425684870625865

# %% [markdown]
# Here we have the confusion matrix

# %%
best_pred = best_model.predict(X_test)
cm = confusion_matrix(Y_test,best_pred)
SVM_cm = normalize_cm(cm)

print('Confusion matrix:')
print(SVM_cm)
plot_cm(SVM_cm,method_name='SVM')
# Out:
# Confusion matrix:
# [[0.494 0.506]
#  [0.034 0.966]]

# %% [markdown]
# The best curve is then plotted and saved

# %%
tpr_SVM = best_tpr
fpr_SVM = best_fpr
Q_SVM = get_best_Q(fpr_SVM,tpr_SVM)
Q_SVM = SVM_cm[1][1]/ np.sqrt(SVM_cm[0][1])


print('best SVM Q value:',Q_SVM)
plt.figure(figsize=(8, 6))
plt.plot(best_fpr, best_tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % best_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'ROC Curve for SVM with {best_kernel} kernel')
plt.legend(loc='lower right')
plt.show();
# Out:
# best SVM Q value: 1.3580065604340128

# %% [markdown]
# Let's check how SVM performed in comparison to Perceptron

# %%
plt.figure(figsize=(8, 6))
plt.plot(fpr_SVM, tpr_SVM, color='darkorange', lw=2, label='SVM ROC' % best_auc)
plt.plot(fpr_perceptron, tpr_perceptron, color='blue', lw=2, label='Perceptron ROC' % best_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'ROC Curve for SVM with {best_kernel} kernel')
plt.legend(loc='lower right')
plt.show();

# %% [markdown]
# ## Part 5.4: Random Forest
# Here we are going to implement a Random Forest classification algorithm. A Random Forest is composed of different decision tree predictors. For each tree, at each iteration, the data are split into two branches according to a threshold value for one of the features. At each split, the best feature and the best threshold value are chosen by minimizing the entropy function
# 𝐻 given by:
# $$
# \displaystyle H = - \sum_{i=+1,-1} f_i \log_2(f_i)
# $$
# where $f_i$ is the fraction of points of class $i=+1,-1$ in the training set. The splitting continues until either a maximum depth for the tree is reached, in which case the most frequent class of the branch is assigned to all points, or the points of the branch all belong to the same class (in this case the branch is called a leaf). Different trees are built by randomly drawing data with replacement from the test set, applying the algorithm to each tree. The final label for a point is chosen based on a majority vote of the trees results.
#
# The hyper-parameters of the model are the **number of trees** and the **maximum depth** of the trees. We are going to implement a K-fold cross validation to choose as best hyper-parameters the ones that maximize the area under the ROC curve of the classifier. To build the ROC curve we need to estimate the probability for the points to belong to a certain class. This can be done because each tree, at the last decision step, assigns a class label based on the majority class of the training samples that reached that final leaf node, but also keeps track of the proportion of the classes in that leaf node. For example, suppose a test point ends up in a leaf node where, out of 100 training samples that ended up there, 80 belonged to class 1 and 20 belonged to class -1. The probability of the point belonging to class 1 would be 0.8, while the probability of it belonging to class -1 would be 0.2.\
#
# We will use the class `RandomForestClassifier` from `scikit-learn` to implement and train the Forest and to predict the labels with their probabilities.
#
#
# \
# **DA METTERE QUANDO SI INTRODUCE IL CONCETTO DI ROC CURVE?**
# The ROC curve plots the True Positive Rate (TPR), i.e: the fraction of actual gamma samples correctly identified as gamma, versus the False Positive Rate, i.e: the fraction of actual hadrons incorrectly classified as gamma by the model. To do so, it's necessary to estimate a probability for the predicted class, not just to assign the predicted label. Imposing different threshold values on the probability for the acceptance of an event as either gamma or hadron, we can obtain the ROC curve.   \
# \

# %%
from time import time

num_trees= np.arange(40,300,10)
max_depth= np.arange(10,40,2)
accuracies=[]
roc_areas=[]
best_area=0
best_acc=0
best_model= [] # stores best number of trees and best max depth
partial_aucs = []

start_time = time()

max_iter = len(num_trees) * len(max_depth)
iteration = 0

K = 5
kf = KFold(n_splits=K, shuffle=True, random_state=42) 

for tree in num_trees:
    for depth in max_depth:
        ############accuracies?
        partial_auc = 0
        auc_value = 0
        accuracy = 0
        for i, (train_index, test_index) in enumerate(kf.split(X)):
            print(f"  Fold n. {i}")
            train_K=data_rescaled_and_indexed.iloc[train_idx]
            valid_K = data_rescaled_and_indexed.iloc[test_index]

            X_train_K, Y_train_K = split_X_Y(train_K)
            X_valid_K, Y_valid_K = split_X_Y(valid_K)
            forest = RandomForestClassifier(n_estimators=tree,  # number of trees
                                           max_depth= depth, 
                                           max_features=X_train.shape[1],   # number of features for each split (random subset)
                                           bootstrap=True,    # bagging (sampling with replacement)
                                           max_samples=1.0,   # percentage of samples to use for each tree (100% of data)
                                           random_state=10,
                                           n_jobs=-1)
            # train each model, predict labels and probability of each label
            forest.fit(X_train_K, Y_train_K)
            Y_pred = forest.predict(X_valid_K)
            y_pred_prob = forest.predict_proba(X_valid_K)[:, 1] # probability for the validation points to belong to class +1 or -1
            # accuracy on validation set
            accuracy_k = accuracy_score(Y_valid_K, Y_pred)
            iteration +=1 
            print(f'elapsed time: {round(time()-start_time,2)}s, done {iteration} out of {max_iter*K}')
            print('Number of trees:',tree,', Maximum depth',depth,':') 
            print('Accuracy:',accuracy_k)
            # false positive rates and the true positive rates for different threshold values 
            fpr, tpr, thresholds = roc_curve(Y_valid_K, y_pred_prob)

            # area under the ROC curve on validation set 
            roc_auc_k = auc(fpr, tpr)
            roc_areas.append(roc_auc_k)
            '''if(roc_auc>best_area):
                best_area= roc_auc
                best_acc= accuracy
                best_model=[tree,depth]
                '''
            partial_fpr = fpr[fpr <= 0.2]
            if (len(partial_fpr) < 2 ):
                partial_auc = 0
            else:
                partial_tpr = tpr[:len(partial_fpr)]
                partial_auc_k = auc(partial_fpr, partial_tpr)
            partial_auc += partial_auc_k/K
            auc_value += roc_auc_k/K
        
        partial_aucs.append(partial_auc)
        if(partial_auc>best_area):
            best_area= partial_auc
            best_total_auc = auc_value
            best_acc= accuracy
            best_model=[tree,depth]
        print('\033[91mArea under ROC curve:',round(auc_value,3),'Selected area:',round(partial_auc,3),'\033[0m')
        print('\n')
        
print('Best number of trees:', best_model[0],'\n')
print('Best maximum depth:', best_model[1],'\n')
print('Area under ROC curve of best model:',best_area)
# Out:
#   Fold n. 0
# elapsed time: 1.1s, done 1 out of 1950
# Number of trees: 40 , Maximum depth 10 :
# Accuracy: 0.8554153522607781
#   Fold n. 1
# elapsed time: 2.14s, done 2 out of 1950
# Number of trees: 40 , Maximum depth 10 :
# Accuracy: 0.8509463722397477
#   Fold n. 2
# elapsed time: 3.09s, done 3 out of 1950
# Number of trees: 40 , Maximum depth 10 :
# Accuracy: 0.861198738170347
#   Fold n. 3
# elapsed time: 4.0s, done 4 out of 1950
# Number of trees: 40 , Maximum depth 10 :
# Accuracy: 0.8470031545741324
#   Fold n. 4
# elapsed time: 4.95s, done 5 out of 1950
# Number of trees: 40 , Maximum depth 10 :
# Accuracy: 0.8146200368130423
# Area under ROC curve: 0.894 Selected area: 0.111
#
#
#   Fold n. 0
# elapsed time: 6.16s, done 6 out of 1950
# Number of trees: 40 , Maximum depth 12 :
# Accuracy: 0.8824921135646687
#   Fold n. 1
# elapsed time: 7.35s, done 7 out of 1950
# Number of trees: 40 , Maximum depth 12 :
# Accuracy: 0.8777602523659306
#   Fold n. 2
# elapsed time: 8.5s, done 8 out of 1950
# Number of trees: 40 , Maximum depth 12 :
# Accuracy: 0.8853838065194533
#   Fold n. 3
# elapsed time: 9.54s, done 9 out of 1950
# Number of trees: 40 , Maximum depth 12 :
# Accuracy: 0.8782860147213459
#   Fold n. 4
# elapsed time: 10.6s, done 10 out of 1950
# Number of trees: 40 , Maximum depth 12 :
# Accuracy: 0.8248750986063634
# Area under ROC curve: 0.922 Selected area: 0.131
#
#
#   Fold n. 0
# elapsed time: 11.83s, done 11 out of 1950
# Number of trees: 40 , Maximum depth 14 :
# Accuracy: 0.905099894847529
#   Fold n. 1
# elapsed time: 13.16s, done 12 out of 1950
# Number of trees: 40 , Maximum depth 14 :
# Accuracy: 0.9053627760252366
#   Fold n. 2
# elapsed time: 14.44s, done 13 out of 1950
# Number of trees: 40 , Maximum depth 14 :
# Accuracy: 0.9077287066246057
#   Fold n. 3
# elapsed time: 15.62s, done 14 out of 1950
# Number of trees: 40 , Maximum depth 14 :
# Accuracy: 0.9037854889589906
#   Fold n. 4
# elapsed time: 16.91s, done 15 out of 1950
# Number of trees: 40 , Maximum depth 14 :
# Accuracy: 0.8311859058637917
# Area under ROC curve: 0.943 Selected area: 0.146
#
#
#   Fold n. 0
# elapsed time: 18.23s, done 16 out of 1950
# Number of trees: 40 , Maximum depth 16 :
# Accuracy: 0.9256046267087277
#   Fold n. 1
# elapsed time: 19.65s, done 17 out of 1950
# Number of trees: 40 , Maximum depth 16 :
# Accuracy: 0.9292849631966351
#   Fold n. 2
# elapsed time: 21.05s, done 18 out of 1950
# Number of trees: 40 , Maximum depth 16 :
# Accuracy: 0.9300736067297581
#   Fold n. 3
# elapsed time: 22.72s, done 19 out of 1950
# Number of trees: 40 , Maximum depth 16 :
# Accuracy: 0.9263932702418507
#   Fold n. 4
# elapsed time: 24.07s, done 20 out of 1950
# Number of trees: 40 , Maximum depth 16 :
# Accuracy: 0.8327636076781488
# Area under ROC curve: 0.958 Selected area: 0.155
#
#
#   Fold n. 0
# elapsed time: 25.59s, done 21 out of 1950
# Number of trees: 40 , Maximum depth 18 :
# Accuracy: 0.9413774973711883
#   Fold n. 1
# elapsed time: 27.17s, done 22 out of 1950
# Number of trees: 40 , Maximum depth 18 :
# Accuracy: 0.9437434279705573
#   Fold n. 2
# elapsed time: 28.68s, done 23 out of 1950
# Number of trees: 40 , Maximum depth 18 :
# Accuracy: 0.9487381703470031
#   Fold n. 3
# elapsed time: 30.15s, done 24 out of 1950
# Number of trees: 40 , Maximum depth 18 :
# Accuracy: 0.9408517350157729
#   Fold n. 4
# elapsed time: 31.69s, done 25 out of 1950
# Number of trees: 40 , Maximum depth 18 :
# Accuracy: 0.8340783591901131
# Area under ROC curve: 0.967 Selected area: 0.14
#
#
#   Fold n. 0
# elapsed time: 33.47s, done 26 out of 1950
# Number of trees: 40 , Maximum depth 20 :
# Accuracy: 0.9576761303890642
#   Fold n. 1
# elapsed time: 35.19s, done 27 out of 1950
# Number of trees: 40 , Maximum depth 20 :
# Accuracy: 0.9568874868559412
#   Fold n. 2
# elapsed time: 36.93s, done 28 out of 1950
# Number of trees: 40 , Maximum depth 20 :
# Accuracy: 0.961882229232387
#   Fold n. 3
# elapsed time: 38.45s, done 29 out of 1950
# Number of trees: 40 , Maximum depth 20 :
# Accuracy: 0.9558359621451105
#   Fold n. 4
# elapsed time: 39.97s, done 30 out of 1950
# Number of trees: 40 , Maximum depth 20 :
# Accuracy: 0.8346042597948987
# Area under ROC curve: 0.972 Selected area: 0.163
#
#
#   Fold n. 0
# elapsed time: 41.94s, done 31 out of 1950
# Number of trees: 40 , Maximum depth 22 :
# Accuracy: 0.9697686645636172
#   Fold n. 1
# elapsed time: 43.82s, done 32 out of 1950
# Number of trees: 40 , Maximum depth 22 :
# Accuracy: 0.9692429022082019
#   Fold n. 2
# elapsed time: 45.56s, done 33 out of 1950
# Number of trees: 40 , Maximum depth 22 :
# Accuracy: 0.9752891692954785
#   Fold n. 3
# elapsed time: 47.81s, done 34 out of 1950
# Number of trees: 40 , Maximum depth 22 :
# Accuracy: 0.9681913774973712
#   Fold n. 4
# elapsed time: 50.04s, done 35 out of 1950
# Number of trees: 40 , Maximum depth 22 :
# Accuracy: 0.8340783591901131
# Area under ROC curve: 0.975 Selected area: 0.171
#
#
#   Fold n. 0
# elapsed time: 51.92s, done 36 out of 1950
# Number of trees: 40 , Maximum depth 24 :
# Accuracy: 0.982912723449001
#   Fold n. 1
# elapsed time: 53.7s, done 37 out of 1950
# Number of trees: 40 , Maximum depth 24 :
# Accuracy: 0.9810725552050473
#   Fold n. 2
# elapsed time: 55.53s, done 38 out of 1950
# Number of trees: 40 , Maximum depth 24 :
# Accuracy: 0.9837013669821241
#   Fold n. 3
# elapsed time: 57.26s, done 39 out of 1950
# Number of trees: 40 , Maximum depth 24 :
# Accuracy: 0.979758149316509
#   Fold n. 4
# elapsed time: 58.85s, done 40 out of 1950
# Number of trees: 40 , Maximum depth 24 :
# Accuracy: 0.8330265579805417
# Area under ROC curve: 0.975 Selected area: 0.174
#
#
#   Fold n. 0
# elapsed time: 60.62s, done 41 out of 1950
# Number of trees: 40 , Maximum depth 26 :
# Accuracy: 0.9889589905362776
#   Fold n. 1
# elapsed time: 62.5s, done 42 out of 1950
# Number of trees: 40 , Maximum depth 26 :
# Accuracy: 0.9871188222923238
#   Fold n. 2
# elapsed time: 64.47s, done 43 out of 1950
# Number of trees: 40 , Maximum depth 26 :
# Accuracy: 0.9921135646687698
#   Fold n. 3
# elapsed time: 66.14s, done 44 out of 1950
# Number of trees: 40 , Maximum depth 26 :
# Accuracy: 0.9884332281808622
#   Fold n. 4
# elapsed time: 67.78s, done 45 out of 1950
# Number of trees: 40 , Maximum depth 26 :
# Accuracy: 0.835919011306863
# Area under ROC curve: 0.976 Selected area: 0.177
#
#
#   Fold n. 0
# elapsed time: 69.51s, done 46 out of 1950
# Number of trees: 40 , Maximum depth 28 :
# Accuracy: 0.9952681388012619
#   Fold n. 1
# elapsed time: 71.18s, done 47 out of 1950
# Number of trees: 40 , Maximum depth 28 :
# Accuracy: 0.9913249211356467
#   Fold n. 2
# elapsed time: 73.01s, done 48 out of 1950
# Number of trees: 40 , Maximum depth 28 :
# Accuracy: 0.9960567823343849
#   Fold n. 3
# elapsed time: 74.86s, done 49 out of 1950
# Number of trees: 40 , Maximum depth 28 :
# Accuracy: 0.9942166140904312
#   Fold n. 4
# elapsed time: 76.81s, done 50 out of 1950
# Number of trees: 40 , Maximum depth 28 :
# Accuracy: 0.8406521167499342
# Area under ROC curve: 0.976 Selected area: 0.18
#
#
#   Fold n. 0
# elapsed time: 78.75s, done 51 out of 1950
# Number of trees: 40 , Maximum depth 30 :
# Accuracy: 0.9971083070452156
#   Fold n. 1
# elapsed time: 80.67s, done 52 out of 1950
# Number of trees: 40 , Maximum depth 30 :
# Accuracy: 0.9963196635120926
#   Fold n. 2
# elapsed time: 82.65s, done 53 out of 1950
# Number of trees: 40 , Maximum depth 30 :
# Accuracy: 0.9978969505783386
#   Fold n. 3
# elapsed time: 84.45s, done 54 out of 1950
# Number of trees: 40 , Maximum depth 30 :
# Accuracy: 0.998422712933754
#   Fold n. 4
# elapsed time: 86.28s, done 55 out of 1950
# Number of trees: 40 , Maximum depth 30 :
# Accuracy: 0.8367078622140416
# Area under ROC curve: 0.976 Selected area: 0.173
#
#
#   Fold n. 0
# elapsed time: 88.16s, done 56 out of 1950
# Number of trees: 40 , Maximum depth 32 :
# Accuracy: 0.9986855941114616
#   Fold n. 1
# elapsed time: 90.11s, done 57 out of 1950
# Number of trees: 40 , Maximum depth 32 :
# Accuracy: 0.9989484752891693
#   Fold n. 2
# elapsed time: 91.91s, done 58 out of 1950
# Number of trees: 40 , Maximum depth 32 :
# Accuracy: 0.9989484752891693
#   Fold n. 3
# elapsed time: 93.83s, done 59 out of 1950
# Number of trees: 40 , Maximum depth 32 :
# Accuracy: 0.9989484752891693
#   Fold n. 4
# elapsed time: 95.72s, done 60 out of 1950
# Number of trees: 40 , Maximum depth 32 :
# Accuracy: 0.8364449119116487
# Area under ROC curve: 0.976 Selected area: 0.17
#
#
#   Fold n. 0
# elapsed time: 97.54s, done 61 out of 1950
# Number of trees: 40 , Maximum depth 34 :
# Accuracy: 0.9994742376445847
#   Fold n. 1
# elapsed time: 99.41s, done 62 out of 1950
# Number of trees: 40 , Maximum depth 34 :
# Accuracy: 0.9994742376445847
#   Fold n. 2
# elapsed time: 101.46s, done 63 out of 1950
# Number of trees: 40 , Maximum depth 34 :
# Accuracy: 0.9989484752891693
#   Fold n. 3
# elapsed time: 103.28s, done 64 out of 1950
# Number of trees: 40 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 105.07s, done 65 out of 1950
# Number of trees: 40 , Maximum depth 34 :
# Accuracy: 0.8348672100972916
# Area under ROC curve: 0.976 Selected area: 0.166
#
#
#   Fold n. 0
# elapsed time: 107.01s, done 66 out of 1950
# Number of trees: 40 , Maximum depth 36 :
# Accuracy: 0.9994742376445847
#   Fold n. 1
# elapsed time: 109.15s, done 67 out of 1950
# Number of trees: 40 , Maximum depth 36 :
# Accuracy: 0.9994742376445847
#   Fold n. 2
# elapsed time: 110.92s, done 68 out of 1950
# Number of trees: 40 , Maximum depth 36 :
# Accuracy: 0.9989484752891693
#   Fold n. 3
# elapsed time: 112.77s, done 69 out of 1950
# Number of trees: 40 , Maximum depth 36 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 114.61s, done 70 out of 1950
# Number of trees: 40 , Maximum depth 36 :
# Accuracy: 0.8367078622140416
# Area under ROC curve: 0.976 Selected area: 0.163
#
#
#   Fold n. 0
# elapsed time: 116.44s, done 71 out of 1950
# Number of trees: 40 , Maximum depth 38 :
# Accuracy: 0.9994742376445847
#   Fold n. 1
# elapsed time: 118.19s, done 72 out of 1950
# Number of trees: 40 , Maximum depth 38 :
# Accuracy: 0.9994742376445847
#   Fold n. 2
# elapsed time: 119.94s, done 73 out of 1950
# Number of trees: 40 , Maximum depth 38 :
# Accuracy: 0.9989484752891693
#   Fold n. 3
# elapsed time: 121.68s, done 74 out of 1950
# Number of trees: 40 , Maximum depth 38 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 123.53s, done 75 out of 1950
# Number of trees: 40 , Maximum depth 38 :
# Accuracy: 0.835919011306863
# Area under ROC curve: 0.976 Selected area: 0.164
#
#
#   Fold n. 0
# elapsed time: 124.8s, done 76 out of 1950
# Number of trees: 50 , Maximum depth 10 :
# Accuracy: 0.8551524710830705
#   Fold n. 1
# elapsed time: 126.15s, done 77 out of 1950
# Number of trees: 50 , Maximum depth 10 :
# Accuracy: 0.8533123028391167
#   Fold n. 2
# elapsed time: 127.46s, done 78 out of 1950
# Number of trees: 50 , Maximum depth 10 :
# Accuracy: 0.86198738170347
#   Fold n. 3
# elapsed time: 128.75s, done 79 out of 1950
# Number of trees: 50 , Maximum depth 10 :
# Accuracy: 0.8467402733964248
#   Fold n. 4
# elapsed time: 130.0s, done 80 out of 1950
# Number of trees: 50 , Maximum depth 10 :
# Accuracy: 0.815145937417828
# Area under ROC curve: 0.895 Selected area: 0.112
#
#
#   Fold n. 0
# elapsed time: 131.43s, done 81 out of 1950
# Number of trees: 50 , Maximum depth 12 :
# Accuracy: 0.8830178759200841
#   Fold n. 1
# elapsed time: 132.87s, done 82 out of 1950
# Number of trees: 50 , Maximum depth 12 :
# Accuracy: 0.8759200841219769
#   Fold n. 2
# elapsed time: 134.3s, done 83 out of 1950
# Number of trees: 50 , Maximum depth 12 :
# Accuracy: 0.8835436382754994
#   Fold n. 3
# elapsed time: 135.75s, done 84 out of 1950
# Number of trees: 50 , Maximum depth 12 :
# Accuracy: 0.8785488958990536
#   Fold n. 4
# elapsed time: 137.21s, done 85 out of 1950
# Number of trees: 50 , Maximum depth 12 :
# Accuracy: 0.8261898501183277
# Area under ROC curve: 0.923 Selected area: 0.131
#
#
#   Fold n. 0
# elapsed time: 138.84s, done 86 out of 1950
# Number of trees: 50 , Maximum depth 14 :
# Accuracy: 0.9056256572029443
#   Fold n. 1
# elapsed time: 140.6s, done 87 out of 1950
# Number of trees: 50 , Maximum depth 14 :
# Accuracy: 0.908254468980021
#   Fold n. 2
# elapsed time: 142.33s, done 88 out of 1950
# Number of trees: 50 , Maximum depth 14 :
# Accuracy: 0.9095688748685594
#   Fold n. 3
# elapsed time: 144.08s, done 89 out of 1950
# Number of trees: 50 , Maximum depth 14 :
# Accuracy: 0.9045741324921136
#   Fold n. 4
# elapsed time: 145.8s, done 90 out of 1950
# Number of trees: 50 , Maximum depth 14 :
# Accuracy: 0.8311859058637917
# Area under ROC curve: 0.944 Selected area: 0.149
#
#
#   Fold n. 0
# elapsed time: 147.76s, done 91 out of 1950
# Number of trees: 50 , Maximum depth 16 :
# Accuracy: 0.924553101997897
#   Fold n. 1
# elapsed time: 149.88s, done 92 out of 1950
# Number of trees: 50 , Maximum depth 16 :
# Accuracy: 0.9290220820189274
#   Fold n. 2
# elapsed time: 151.85s, done 93 out of 1950
# Number of trees: 50 , Maximum depth 16 :
# Accuracy: 0.9319137749737119
#   Fold n. 3
# elapsed time: 153.73s, done 94 out of 1950
# Number of trees: 50 , Maximum depth 16 :
# Accuracy: 0.9250788643533123
#   Fold n. 4
# elapsed time: 155.69s, done 95 out of 1950
# Number of trees: 50 , Maximum depth 16 :
# Accuracy: 0.8332895082829346
# Area under ROC curve: 0.958 Selected area: 0.152
#
#
#   Fold n. 0
# elapsed time: 158.06s, done 96 out of 1950
# Number of trees: 50 , Maximum depth 18 :
# Accuracy: 0.9421661409043113
#   Fold n. 1
# elapsed time: 160.44s, done 97 out of 1950
# Number of trees: 50 , Maximum depth 18 :
# Accuracy: 0.9453207150368034
#   Fold n. 2
# elapsed time: 162.76s, done 98 out of 1950
# Number of trees: 50 , Maximum depth 18 :
# Accuracy: 0.9471608832807571
#   Fold n. 3
# elapsed time: 165.06s, done 99 out of 1950
# Number of trees: 50 , Maximum depth 18 :
# Accuracy: 0.943217665615142
#   Fold n. 4
# elapsed time: 167.5s, done 100 out of 1950
# Number of trees: 50 , Maximum depth 18 :
# Accuracy: 0.8351301603996845
# Area under ROC curve: 0.967 Selected area: 0.145
#
#
#   Fold n. 0
# elapsed time: 170.11s, done 101 out of 1950
# Number of trees: 50 , Maximum depth 20 :
# Accuracy: 0.9582018927444795
#   Fold n. 1
# elapsed time: 172.74s, done 102 out of 1950
# Number of trees: 50 , Maximum depth 20 :
# Accuracy: 0.9584647739221872
#   Fold n. 2
# elapsed time: 175.25s, done 103 out of 1950
# Number of trees: 50 , Maximum depth 20 :
# Accuracy: 0.9639852786540484
#   Fold n. 3
# elapsed time: 177.91s, done 104 out of 1950
# Number of trees: 50 , Maximum depth 20 :
# Accuracy: 0.9584647739221872
#   Fold n. 4
# elapsed time: 180.42s, done 105 out of 1950
# Number of trees: 50 , Maximum depth 20 :
# Accuracy: 0.8351301603996845
# Area under ROC curve: 0.972 Selected area: 0.124
#
#
#   Fold n. 0
# elapsed time: 182.99s, done 106 out of 1950
# Number of trees: 50 , Maximum depth 22 :
# Accuracy: 0.9692429022082019
#   Fold n. 1
# elapsed time: 185.62s, done 107 out of 1950
# Number of trees: 50 , Maximum depth 22 :
# Accuracy: 0.9708201892744479
#   Fold n. 2
# elapsed time: 188.26s, done 108 out of 1950
# Number of trees: 50 , Maximum depth 22 :
# Accuracy: 0.9747634069400631
#   Fold n. 3
# elapsed time: 190.86s, done 109 out of 1950
# Number of trees: 50 , Maximum depth 22 :
# Accuracy: 0.9681913774973712
#   Fold n. 4
# elapsed time: 193.69s, done 110 out of 1950
# Number of trees: 50 , Maximum depth 22 :
# Accuracy: 0.8361819616092558
# Area under ROC curve: 0.975 Selected area: 0.172
#
#
#   Fold n. 0
# elapsed time: 196.4s, done 111 out of 1950
# Number of trees: 50 , Maximum depth 24 :
# Accuracy: 0.9818611987381703
#   Fold n. 1
# elapsed time: 199.29s, done 112 out of 1950
# Number of trees: 50 , Maximum depth 24 :
# Accuracy: 0.9826498422712934
#   Fold n. 2
# elapsed time: 201.94s, done 113 out of 1950
# Number of trees: 50 , Maximum depth 24 :
# Accuracy: 0.9850157728706624
#   Fold n. 3
# elapsed time: 204.79s, done 114 out of 1950
# Number of trees: 50 , Maximum depth 24 :
# Accuracy: 0.9800210304942166
#   Fold n. 4
# elapsed time: 207.44s, done 115 out of 1950
# Number of trees: 50 , Maximum depth 24 :
# Accuracy: 0.8374967131212201
# Area under ROC curve: 0.975 Selected area: 0.174
#
#
#   Fold n. 0
# elapsed time: 210.26s, done 116 out of 1950
# Number of trees: 50 , Maximum depth 26 :
# Accuracy: 0.9897476340694006
#   Fold n. 1
# elapsed time: 213.13s, done 117 out of 1950
# Number of trees: 50 , Maximum depth 26 :
# Accuracy: 0.9879074658254469
#   Fold n. 2
# elapsed time: 215.87s, done 118 out of 1950
# Number of trees: 50 , Maximum depth 26 :
# Accuracy: 0.9918506834910621
#   Fold n. 3
# elapsed time: 218.62s, done 119 out of 1950
# Number of trees: 50 , Maximum depth 26 :
# Accuracy: 0.9892218717139852
#   Fold n. 4
# elapsed time: 221.48s, done 120 out of 1950
# Number of trees: 50 , Maximum depth 26 :
# Accuracy: 0.8353931107020773
# Area under ROC curve: 0.976 Selected area: 0.176
#
#
#   Fold n. 0
# elapsed time: 224.31s, done 121 out of 1950
# Number of trees: 50 , Maximum depth 28 :
# Accuracy: 0.9944794952681388
#   Fold n. 1
# elapsed time: 227.19s, done 122 out of 1950
# Number of trees: 50 , Maximum depth 28 :
# Accuracy: 0.9926393270241851
#   Fold n. 2
# elapsed time: 230.0s, done 123 out of 1950
# Number of trees: 50 , Maximum depth 28 :
# Accuracy: 0.9971083070452156
#   Fold n. 3
# elapsed time: 232.82s, done 124 out of 1950
# Number of trees: 50 , Maximum depth 28 :
# Accuracy: 0.9957939011566772
#   Fold n. 4
# elapsed time: 235.55s, done 125 out of 1950
# Number of trees: 50 , Maximum depth 28 :
# Accuracy: 0.8409150670523271
# Area under ROC curve: 0.976 Selected area: 0.177
#
#
#   Fold n. 0
# elapsed time: 238.33s, done 126 out of 1950
# Number of trees: 50 , Maximum depth 30 :
# Accuracy: 0.9971083070452156
#   Fold n. 1
# elapsed time: 241.21s, done 127 out of 1950
# Number of trees: 50 , Maximum depth 30 :
# Accuracy: 0.9965825446898002
#   Fold n. 2
# elapsed time: 244.16s, done 128 out of 1950
# Number of trees: 50 , Maximum depth 30 :
# Accuracy: 0.9986855941114616
#   Fold n. 3
# elapsed time: 247.02s, done 129 out of 1950
# Number of trees: 50 , Maximum depth 30 :
# Accuracy: 0.9989484752891693
#   Fold n. 4
# elapsed time: 249.91s, done 130 out of 1950
# Number of trees: 50 , Maximum depth 30 :
# Accuracy: 0.8361819616092558
# Area under ROC curve: 0.976 Selected area: 0.174
#
#
#   Fold n. 0
# elapsed time: 252.76s, done 131 out of 1950
# Number of trees: 50 , Maximum depth 32 :
# Accuracy: 0.9989484752891693
#   Fold n. 1
# elapsed time: 255.54s, done 132 out of 1950
# Number of trees: 50 , Maximum depth 32 :
# Accuracy: 0.9989484752891693
#   Fold n. 2
# elapsed time: 258.38s, done 133 out of 1950
# Number of trees: 50 , Maximum depth 32 :
# Accuracy: 0.9994742376445847
#   Fold n. 3
# elapsed time: 261.24s, done 134 out of 1950
# Number of trees: 50 , Maximum depth 32 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 264.2s, done 135 out of 1950
# Number of trees: 50 , Maximum depth 32 :
# Accuracy: 0.8390744149355772
# Area under ROC curve: 0.976 Selected area: 0.178
#
#
#   Fold n. 0
# elapsed time: 266.98s, done 136 out of 1950
# Number of trees: 50 , Maximum depth 34 :
# Accuracy: 0.9997371188222923
#   Fold n. 1
# elapsed time: 269.91s, done 137 out of 1950
# Number of trees: 50 , Maximum depth 34 :
# Accuracy: 0.9997371188222923
#   Fold n. 2
# elapsed time: 272.69s, done 138 out of 1950
# Number of trees: 50 , Maximum depth 34 :
# Accuracy: 0.9994742376445847
#   Fold n. 3
# elapsed time: 275.51s, done 139 out of 1950
# Number of trees: 50 , Maximum depth 34 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 278.34s, done 140 out of 1950
# Number of trees: 50 , Maximum depth 34 :
# Accuracy: 0.8356560610044702
# Area under ROC curve: 0.976 Selected area: 0.177
#
#
#   Fold n. 0
# elapsed time: 281.17s, done 141 out of 1950
# Number of trees: 50 , Maximum depth 36 :
# Accuracy: 0.9997371188222923
#   Fold n. 1
# elapsed time: 284.12s, done 142 out of 1950
# Number of trees: 50 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 286.97s, done 143 out of 1950
# Number of trees: 50 , Maximum depth 36 :
# Accuracy: 0.9997371188222923
#   Fold n. 3
# elapsed time: 290.02s, done 144 out of 1950
# Number of trees: 50 , Maximum depth 36 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 292.98s, done 145 out of 1950
# Number of trees: 50 , Maximum depth 36 :
# Accuracy: 0.8385485143307915
# Area under ROC curve: 0.976 Selected area: 0.168
#
#
#   Fold n. 0
# elapsed time: 295.93s, done 146 out of 1950
# Number of trees: 50 , Maximum depth 38 :
# Accuracy: 0.9997371188222923
#   Fold n. 1
# elapsed time: 298.84s, done 147 out of 1950
# Number of trees: 50 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 301.71s, done 148 out of 1950
# Number of trees: 50 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 304.6s, done 149 out of 1950
# Number of trees: 50 , Maximum depth 38 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 307.46s, done 150 out of 1950
# Number of trees: 50 , Maximum depth 38 :
# Accuracy: 0.8369708125164343
# Area under ROC curve: 0.976 Selected area: 0.175
#
#
#   Fold n. 0
# elapsed time: 309.53s, done 151 out of 1950
# Number of trees: 60 , Maximum depth 10 :
# Accuracy: 0.8564668769716088
#   Fold n. 1
# elapsed time: 311.69s, done 152 out of 1950
# Number of trees: 60 , Maximum depth 10 :
# Accuracy: 0.8530494216614091
#   Fold n. 2
# elapsed time: 313.61s, done 153 out of 1950
# Number of trees: 60 , Maximum depth 10 :
# Accuracy: 0.8606729758149316
#   Fold n. 3
# elapsed time: 315.5s, done 154 out of 1950
# Number of trees: 60 , Maximum depth 10 :
# Accuracy: 0.8464773922187171
#   Fold n. 4
# elapsed time: 317.39s, done 155 out of 1950
# Number of trees: 60 , Maximum depth 10 :
# Accuracy: 0.8148829871154352
# Area under ROC curve: 0.895 Selected area: 0.112
#
#
#   Fold n. 0
# elapsed time: 319.57s, done 156 out of 1950
# Number of trees: 60 , Maximum depth 12 :
# Accuracy: 0.8803890641430073
#   Fold n. 1
# elapsed time: 322.01s, done 157 out of 1950
# Number of trees: 60 , Maximum depth 12 :
# Accuracy: 0.8751314405888538
#   Fold n. 2
# elapsed time: 324.34s, done 158 out of 1950
# Number of trees: 60 , Maximum depth 12 :
# Accuracy: 0.8838065194532071
#   Fold n. 3
# elapsed time: 326.52s, done 159 out of 1950
# Number of trees: 60 , Maximum depth 12 :
# Accuracy: 0.879074658254469
#   Fold n. 4
# elapsed time: 328.87s, done 160 out of 1950
# Number of trees: 60 , Maximum depth 12 :
# Accuracy: 0.8254009992111491
# Area under ROC curve: 0.923 Selected area: 0.131
#
#
#   Fold n. 0
# elapsed time: 331.55s, done 161 out of 1950
# Number of trees: 60 , Maximum depth 14 :
# Accuracy: 0.9045741324921136
#   Fold n. 1
# elapsed time: 334.0s, done 162 out of 1950
# Number of trees: 60 , Maximum depth 14 :
# Accuracy: 0.908254468980021
#   Fold n. 2
# elapsed time: 336.57s, done 163 out of 1950
# Number of trees: 60 , Maximum depth 14 :
# Accuracy: 0.9095688748685594
#   Fold n. 3
# elapsed time: 339.01s, done 164 out of 1950
# Number of trees: 60 , Maximum depth 14 :
# Accuracy: 0.9035226077812829
#   Fold n. 4
# elapsed time: 341.48s, done 165 out of 1950
# Number of trees: 60 , Maximum depth 14 :
# Accuracy: 0.8285564028398633
# Area under ROC curve: 0.944 Selected area: 0.15
#
#
#   Fold n. 0
# elapsed time: 344.14s, done 166 out of 1950
# Number of trees: 60 , Maximum depth 16 :
# Accuracy: 0.9242902208201893
#   Fold n. 1
# elapsed time: 346.84s, done 167 out of 1950
# Number of trees: 60 , Maximum depth 16 :
# Accuracy: 0.9305993690851735
#   Fold n. 2
# elapsed time: 349.72s, done 168 out of 1950
# Number of trees: 60 , Maximum depth 16 :
# Accuracy: 0.9311251314405888
#   Fold n. 3
# elapsed time: 352.53s, done 169 out of 1950
# Number of trees: 60 , Maximum depth 16 :
# Accuracy: 0.9250788643533123
#   Fold n. 4
# elapsed time: 355.28s, done 170 out of 1950
# Number of trees: 60 , Maximum depth 16 :
# Accuracy: 0.8303970549566132
# Area under ROC curve: 0.959 Selected area: 0.158
#
#
#   Fold n. 0
# elapsed time: 358.37s, done 171 out of 1950
# Number of trees: 60 , Maximum depth 18 :
# Accuracy: 0.9429547844374343
#   Fold n. 1
# elapsed time: 361.07s, done 172 out of 1950
# Number of trees: 60 , Maximum depth 18 :
# Accuracy: 0.944794952681388
#   Fold n. 2
# elapsed time: 363.77s, done 173 out of 1950
# Number of trees: 60 , Maximum depth 18 :
# Accuracy: 0.9463722397476341
#   Fold n. 3
# elapsed time: 366.54s, done 174 out of 1950
# Number of trees: 60 , Maximum depth 18 :
# Accuracy: 0.943217665615142
#   Fold n. 4
# elapsed time: 369.41s, done 175 out of 1950
# Number of trees: 60 , Maximum depth 18 :
# Accuracy: 0.8385485143307915
# Area under ROC curve: 0.968 Selected area: 0.15
#
#
#   Fold n. 0
# elapsed time: 372.28s, done 176 out of 1950
# Number of trees: 60 , Maximum depth 20 :
# Accuracy: 0.9582018927444795
#   Fold n. 1
# elapsed time: 375.22s, done 177 out of 1950
# Number of trees: 60 , Maximum depth 20 :
# Accuracy: 0.9582018927444795
#   Fold n. 2
# elapsed time: 378.15s, done 178 out of 1950
# Number of trees: 60 , Maximum depth 20 :
# Accuracy: 0.9624079915878023
#   Fold n. 3
# elapsed time: 381.09s, done 179 out of 1950
# Number of trees: 60 , Maximum depth 20 :
# Accuracy: 0.9579390115667719
#   Fold n. 4
# elapsed time: 384.0s, done 180 out of 1950
# Number of trees: 60 , Maximum depth 20 :
# Accuracy: 0.8353931107020773
# Area under ROC curve: 0.973 Selected area: 0.133
#
#
#   Fold n. 0
# elapsed time: 387.0s, done 181 out of 1950
# Number of trees: 60 , Maximum depth 22 :
# Accuracy: 0.9697686645636172
#   Fold n. 1
# elapsed time: 390.02s, done 182 out of 1950
# Number of trees: 60 , Maximum depth 22 :
# Accuracy: 0.9713459516298633
#   Fold n. 2
# elapsed time: 393.08s, done 183 out of 1950
# Number of trees: 60 , Maximum depth 22 :
# Accuracy: 0.9742376445846478
#   Fold n. 3
# elapsed time: 396.06s, done 184 out of 1950
# Number of trees: 60 , Maximum depth 22 :
# Accuracy: 0.9687171398527865
#   Fold n. 4
# elapsed time: 399.12s, done 185 out of 1950
# Number of trees: 60 , Maximum depth 22 :
# Accuracy: 0.834341309492506
# Area under ROC curve: 0.975 Selected area: 0.166
#
#
#   Fold n. 0
# elapsed time: 402.25s, done 186 out of 1950
# Number of trees: 60 , Maximum depth 24 :
# Accuracy: 0.9810725552050473
#   Fold n. 1
# elapsed time: 405.34s, done 187 out of 1950
# Number of trees: 60 , Maximum depth 24 :
# Accuracy: 0.981335436382755
#   Fold n. 2
# elapsed time: 408.39s, done 188 out of 1950
# Number of trees: 60 , Maximum depth 24 :
# Accuracy: 0.9852786540483701
#   Fold n. 3
# elapsed time: 411.67s, done 189 out of 1950
# Number of trees: 60 , Maximum depth 24 :
# Accuracy: 0.980546792849632
#   Fold n. 4
# elapsed time: 414.75s, done 190 out of 1950
# Number of trees: 60 , Maximum depth 24 :
# Accuracy: 0.8369708125164343
# Area under ROC curve: 0.976 Selected area: 0.177
#
#
#   Fold n. 0
# elapsed time: 417.85s, done 191 out of 1950
# Number of trees: 60 , Maximum depth 26 :
# Accuracy: 0.9886961093585699
#   Fold n. 1
# elapsed time: 420.99s, done 192 out of 1950
# Number of trees: 60 , Maximum depth 26 :
# Accuracy: 0.9884332281808622
#   Fold n. 2
# elapsed time: 424.22s, done 193 out of 1950
# Number of trees: 60 , Maximum depth 26 :
# Accuracy: 0.9915878023133544
#   Fold n. 3
# elapsed time: 427.43s, done 194 out of 1950
# Number of trees: 60 , Maximum depth 26 :
# Accuracy: 0.9889589905362776
#   Fold n. 4
# elapsed time: 430.61s, done 195 out of 1950
# Number of trees: 60 , Maximum depth 26 :
# Accuracy: 0.8348672100972916
# Area under ROC curve: 0.976 Selected area: 0.178
#
#
#   Fold n. 0
# elapsed time: 433.85s, done 196 out of 1950
# Number of trees: 60 , Maximum depth 28 :
# Accuracy: 0.9947423764458465
#   Fold n. 1
# elapsed time: 437.06s, done 197 out of 1950
# Number of trees: 60 , Maximum depth 28 :
# Accuracy: 0.9926393270241851
#   Fold n. 2
# elapsed time: 440.23s, done 198 out of 1950
# Number of trees: 60 , Maximum depth 28 :
# Accuracy: 0.9973711882229233
#   Fold n. 3
# elapsed time: 443.37s, done 199 out of 1950
# Number of trees: 60 , Maximum depth 28 :
# Accuracy: 0.9952681388012619
#   Fold n. 4
# elapsed time: 446.56s, done 200 out of 1950
# Number of trees: 60 , Maximum depth 28 :
# Accuracy: 0.8403891664475415
# Area under ROC curve: 0.976 Selected area: 0.173
#
#
#   Fold n. 0
# elapsed time: 449.78s, done 201 out of 1950
# Number of trees: 60 , Maximum depth 30 :
# Accuracy: 0.9971083070452156
#   Fold n. 1
# elapsed time: 453.01s, done 202 out of 1950
# Number of trees: 60 , Maximum depth 30 :
# Accuracy: 0.9973711882229233
#   Fold n. 2
# elapsed time: 456.25s, done 203 out of 1950
# Number of trees: 60 , Maximum depth 30 :
# Accuracy: 0.999211356466877
#   Fold n. 3
# elapsed time: 459.49s, done 204 out of 1950
# Number of trees: 60 , Maximum depth 30 :
# Accuracy: 0.998422712933754
#   Fold n. 4
# elapsed time: 462.76s, done 205 out of 1950
# Number of trees: 60 , Maximum depth 30 :
# Accuracy: 0.8356560610044702
# Area under ROC curve: 0.976 Selected area: 0.175
#
#
#   Fold n. 0
# elapsed time: 465.96s, done 206 out of 1950
# Number of trees: 60 , Maximum depth 32 :
# Accuracy: 0.9994742376445847
#   Fold n. 1
# elapsed time: 469.19s, done 207 out of 1950
# Number of trees: 60 , Maximum depth 32 :
# Accuracy: 0.9989484752891693
#   Fold n. 2
# elapsed time: 472.52s, done 208 out of 1950
# Number of trees: 60 , Maximum depth 32 :
# Accuracy: 0.9997371188222923
#   Fold n. 3
# elapsed time: 475.74s, done 209 out of 1950
# Number of trees: 60 , Maximum depth 32 :
# Accuracy: 0.9994742376445847
#   Fold n. 4
# elapsed time: 478.95s, done 210 out of 1950
# Number of trees: 60 , Maximum depth 32 :
# Accuracy: 0.8396003155403629
# Area under ROC curve: 0.976 Selected area: 0.174
#
#
#   Fold n. 0
# elapsed time: 482.14s, done 211 out of 1950
# Number of trees: 60 , Maximum depth 34 :
# Accuracy: 0.9997371188222923
#   Fold n. 1
# elapsed time: 485.34s, done 212 out of 1950
# Number of trees: 60 , Maximum depth 34 :
# Accuracy: 0.9994742376445847
#   Fold n. 2
# elapsed time: 488.63s, done 213 out of 1950
# Number of trees: 60 , Maximum depth 34 :
# Accuracy: 0.9997371188222923
#   Fold n. 3
# elapsed time: 491.89s, done 214 out of 1950
# Number of trees: 60 , Maximum depth 34 :
# Accuracy: 0.9994742376445847
#   Fold n. 4
# elapsed time: 495.12s, done 215 out of 1950
# Number of trees: 60 , Maximum depth 34 :
# Accuracy: 0.835919011306863
# Area under ROC curve: 0.976 Selected area: 0.17
#
#
#   Fold n. 0
# elapsed time: 498.36s, done 216 out of 1950
# Number of trees: 60 , Maximum depth 36 :
# Accuracy: 0.9997371188222923
#   Fold n. 1
# elapsed time: 501.57s, done 217 out of 1950
# Number of trees: 60 , Maximum depth 36 :
# Accuracy: 0.9997371188222923
#   Fold n. 2
# elapsed time: 504.85s, done 218 out of 1950
# Number of trees: 60 , Maximum depth 36 :
# Accuracy: 0.9997371188222923
#   Fold n. 3
# elapsed time: 508.07s, done 219 out of 1950
# Number of trees: 60 , Maximum depth 36 :
# Accuracy: 0.9994742376445847
#   Fold n. 4
# elapsed time: 511.27s, done 220 out of 1950
# Number of trees: 60 , Maximum depth 36 :
# Accuracy: 0.837759663423613
# Area under ROC curve: 0.976 Selected area: 0.167
#
#
#   Fold n. 0
# elapsed time: 514.6s, done 221 out of 1950
# Number of trees: 60 , Maximum depth 38 :
# Accuracy: 0.9997371188222923
#   Fold n. 1
# elapsed time: 517.8s, done 222 out of 1950
# Number of trees: 60 , Maximum depth 38 :
# Accuracy: 0.9997371188222923
#   Fold n. 2
# elapsed time: 521.08s, done 223 out of 1950
# Number of trees: 60 , Maximum depth 38 :
# Accuracy: 0.9997371188222923
#   Fold n. 3
# elapsed time: 524.32s, done 224 out of 1950
# Number of trees: 60 , Maximum depth 38 :
# Accuracy: 0.9994742376445847
#   Fold n. 4
# elapsed time: 527.58s, done 225 out of 1950
# Number of trees: 60 , Maximum depth 38 :
# Accuracy: 0.8367078622140416
# Area under ROC curve: 0.976 Selected area: 0.166
#
#
#   Fold n. 0
# elapsed time: 529.9s, done 226 out of 1950
# Number of trees: 70 , Maximum depth 10 :
# Accuracy: 0.8583070452155626
#   Fold n. 1
# elapsed time: 532.19s, done 227 out of 1950
# Number of trees: 70 , Maximum depth 10 :
# Accuracy: 0.852260778128286
#   Fold n. 2
# elapsed time: 534.43s, done 228 out of 1950
# Number of trees: 70 , Maximum depth 10 :
# Accuracy: 0.8643533123028391
#   Fold n. 3
# elapsed time: 536.68s, done 229 out of 1950
# Number of trees: 70 , Maximum depth 10 :
# Accuracy: 0.8480546792849631
#   Fold n. 4
# elapsed time: 538.89s, done 230 out of 1950
# Number of trees: 70 , Maximum depth 10 :
# Accuracy: 0.8159347883250065
# Area under ROC curve: 0.897 Selected area: 0.113
#
#
#   Fold n. 0
# elapsed time: 541.48s, done 231 out of 1950
# Number of trees: 70 , Maximum depth 12 :
# Accuracy: 0.8827549947423764
#   Fold n. 1
# elapsed time: 543.98s, done 232 out of 1950
# Number of trees: 70 , Maximum depth 12 :
# Accuracy: 0.8769716088328076
#   Fold n. 2
# elapsed time: 546.48s, done 233 out of 1950
# Number of trees: 70 , Maximum depth 12 :
# Accuracy: 0.8848580441640379
#   Fold n. 3
# elapsed time: 548.94s, done 234 out of 1950
# Number of trees: 70 , Maximum depth 12 :
# Accuracy: 0.879074658254469
#   Fold n. 4
# elapsed time: 551.44s, done 235 out of 1950
# Number of trees: 70 , Maximum depth 12 :
# Accuracy: 0.8264528004207204
# Area under ROC curve: 0.924 Selected area: 0.132
#
#
#   Fold n. 0
# elapsed time: 554.15s, done 236 out of 1950
# Number of trees: 70 , Maximum depth 14 :
# Accuracy: 0.9053627760252366
#   Fold n. 1
# elapsed time: 556.92s, done 237 out of 1950
# Number of trees: 70 , Maximum depth 14 :
# Accuracy: 0.9079915878023134
#   Fold n. 2
# elapsed time: 559.72s, done 238 out of 1950
# Number of trees: 70 , Maximum depth 14 :
# Accuracy: 0.9098317560462671
#   Fold n. 3
# elapsed time: 562.53s, done 239 out of 1950
# Number of trees: 70 , Maximum depth 14 :
# Accuracy: 0.9037854889589906
#   Fold n. 4
# elapsed time: 565.33s, done 240 out of 1950
# Number of trees: 70 , Maximum depth 14 :
# Accuracy: 0.8301341046542203
# Area under ROC curve: 0.945 Selected area: 0.15
#
#
#   Fold n. 0
# elapsed time: 568.37s, done 241 out of 1950
# Number of trees: 70 , Maximum depth 16 :
# Accuracy: 0.9256046267087277
#   Fold n. 1
# elapsed time: 571.32s, done 242 out of 1950
# Number of trees: 70 , Maximum depth 16 :
# Accuracy: 0.9282334384858044
#   Fold n. 2
# elapsed time: 574.28s, done 243 out of 1950
# Number of trees: 70 , Maximum depth 16 :
# Accuracy: 0.9295478443743428
#   Fold n. 3
# elapsed time: 577.36s, done 244 out of 1950
# Number of trees: 70 , Maximum depth 16 :
# Accuracy: 0.92534174553102
#   Fold n. 4
# elapsed time: 580.43s, done 245 out of 1950
# Number of trees: 70 , Maximum depth 16 :
# Accuracy: 0.8317118064685775
# Area under ROC curve: 0.959 Selected area: 0.157
#
#
#   Fold n. 0
# elapsed time: 583.61s, done 246 out of 1950
# Number of trees: 70 , Maximum depth 18 :
# Accuracy: 0.9413774973711883
#   Fold n. 1
# elapsed time: 586.78s, done 247 out of 1950
# Number of trees: 70 , Maximum depth 18 :
# Accuracy: 0.9463722397476341
#   Fold n. 2
# elapsed time: 590.07s, done 248 out of 1950
# Number of trees: 70 , Maximum depth 18 :
# Accuracy: 0.9471608832807571
#   Fold n. 3
# elapsed time: 593.37s, done 249 out of 1950
# Number of trees: 70 , Maximum depth 18 :
# Accuracy: 0.9434805467928497
#   Fold n. 4
# elapsed time: 596.55s, done 250 out of 1950
# Number of trees: 70 , Maximum depth 18 :
# Accuracy: 0.8353931107020773
# Area under ROC curve: 0.968 Selected area: 0.141
#
#
#   Fold n. 0
# elapsed time: 599.98s, done 251 out of 1950
# Number of trees: 70 , Maximum depth 20 :
# Accuracy: 0.9579390115667719
#   Fold n. 1
# elapsed time: 603.3s, done 252 out of 1950
# Number of trees: 70 , Maximum depth 20 :
# Accuracy: 0.9571503680336488
#   Fold n. 2
# elapsed time: 606.61s, done 253 out of 1950
# Number of trees: 70 , Maximum depth 20 :
# Accuracy: 0.964248159831756
#   Fold n. 3
# elapsed time: 609.87s, done 254 out of 1950
# Number of trees: 70 , Maximum depth 20 :
# Accuracy: 0.9576761303890642
#   Fold n. 4
# elapsed time: 613.21s, done 255 out of 1950
# Number of trees: 70 , Maximum depth 20 :
# Accuracy: 0.8364449119116487
# Area under ROC curve: 0.973 Selected area: 0.115
#
#
#   Fold n. 0
# elapsed time: 616.7s, done 256 out of 1950
# Number of trees: 70 , Maximum depth 22 :
# Accuracy: 0.9697686645636172
#   Fold n. 1
# elapsed time: 620.14s, done 257 out of 1950
# Number of trees: 70 , Maximum depth 22 :
# Accuracy: 0.9718717139852786
#   Fold n. 2
# elapsed time: 623.56s, done 258 out of 1950
# Number of trees: 70 , Maximum depth 22 :
# Accuracy: 0.9750262881177708
#   Fold n. 3
# elapsed time: 627.09s, done 259 out of 1950
# Number of trees: 70 , Maximum depth 22 :
# Accuracy: 0.9689800210304942
#   Fold n. 4
# elapsed time: 630.56s, done 260 out of 1950
# Number of trees: 70 , Maximum depth 22 :
# Accuracy: 0.835919011306863
# Area under ROC curve: 0.975 Selected area: 0.167
#
#
#   Fold n. 0
# elapsed time: 634.2s, done 261 out of 1950
# Number of trees: 70 , Maximum depth 24 :
# Accuracy: 0.9810725552050473
#   Fold n. 1
# elapsed time: 637.77s, done 262 out of 1950
# Number of trees: 70 , Maximum depth 24 :
# Accuracy: 0.981335436382755
#   Fold n. 2
# elapsed time: 641.31s, done 263 out of 1950
# Number of trees: 70 , Maximum depth 24 :
# Accuracy: 0.9855415352260778
#   Fold n. 3
# elapsed time: 644.87s, done 264 out of 1950
# Number of trees: 70 , Maximum depth 24 :
# Accuracy: 0.9789695057833859
#   Fold n. 4
# elapsed time: 648.55s, done 265 out of 1950
# Number of trees: 70 , Maximum depth 24 :
# Accuracy: 0.8367078622140416
# Area under ROC curve: 0.976 Selected area: 0.176
#
#
#   Fold n. 0
# elapsed time: 652.34s, done 266 out of 1950
# Number of trees: 70 , Maximum depth 26 :
# Accuracy: 0.9892218717139852
#   Fold n. 1
# elapsed time: 655.9s, done 267 out of 1950
# Number of trees: 70 , Maximum depth 26 :
# Accuracy: 0.9884332281808622
#   Fold n. 2
# elapsed time: 659.51s, done 268 out of 1950
# Number of trees: 70 , Maximum depth 26 :
# Accuracy: 0.9931650893796005
#   Fold n. 3
# elapsed time: 663.08s, done 269 out of 1950
# Number of trees: 70 , Maximum depth 26 :
# Accuracy: 0.9886961093585699
#   Fold n. 4
# elapsed time: 666.79s, done 270 out of 1950
# Number of trees: 70 , Maximum depth 26 :
# Accuracy: 0.8364449119116487
# Area under ROC curve: 0.976 Selected area: 0.177
#
#
#   Fold n. 0
# elapsed time: 670.43s, done 271 out of 1950
# Number of trees: 70 , Maximum depth 28 :
# Accuracy: 0.9952681388012619
#   Fold n. 1
# elapsed time: 674.18s, done 272 out of 1950
# Number of trees: 70 , Maximum depth 28 :
# Accuracy: 0.9934279705573081
#   Fold n. 2
# elapsed time: 677.79s, done 273 out of 1950
# Number of trees: 70 , Maximum depth 28 :
# Accuracy: 0.9981598317560463
#   Fold n. 3
# elapsed time: 681.44s, done 274 out of 1950
# Number of trees: 70 , Maximum depth 28 :
# Accuracy: 0.9963196635120926
#   Fold n. 4
# elapsed time: 685.11s, done 275 out of 1950
# Number of trees: 70 , Maximum depth 28 :
# Accuracy: 0.8382855640283986
# Area under ROC curve: 0.976 Selected area: 0.176
#
#
#   Fold n. 0
# elapsed time: 688.76s, done 276 out of 1950
# Number of trees: 70 , Maximum depth 30 :
# Accuracy: 0.998422712933754
#   Fold n. 1
# elapsed time: 692.45s, done 277 out of 1950
# Number of trees: 70 , Maximum depth 30 :
# Accuracy: 0.9976340694006309
#   Fold n. 2
# elapsed time: 696.14s, done 278 out of 1950
# Number of trees: 70 , Maximum depth 30 :
# Accuracy: 0.9989484752891693
#   Fold n. 3
# elapsed time: 699.89s, done 279 out of 1950
# Number of trees: 70 , Maximum depth 30 :
# Accuracy: 0.9986855941114616
#   Fold n. 4
# elapsed time: 703.53s, done 280 out of 1950
# Number of trees: 70 , Maximum depth 30 :
# Accuracy: 0.8374967131212201
# Area under ROC curve: 0.976 Selected area: 0.176
#
#
#   Fold n. 0
# elapsed time: 707.2s, done 281 out of 1950
# Number of trees: 70 , Maximum depth 32 :
# Accuracy: 0.9997371188222923
#   Fold n. 1
# elapsed time: 711.02s, done 282 out of 1950
# Number of trees: 70 , Maximum depth 32 :
# Accuracy: 0.9994742376445847
#   Fold n. 2
# elapsed time: 714.9s, done 283 out of 1950
# Number of trees: 70 , Maximum depth 32 :
# Accuracy: 0.9994742376445847
#   Fold n. 3
# elapsed time: 718.72s, done 284 out of 1950
# Number of trees: 70 , Maximum depth 32 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 722.39s, done 285 out of 1950
# Number of trees: 70 , Maximum depth 32 :
# Accuracy: 0.8380226137260058
# Area under ROC curve: 0.976 Selected area: 0.175
#
#
#   Fold n. 0
# elapsed time: 726.17s, done 286 out of 1950
# Number of trees: 70 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 729.84s, done 287 out of 1950
# Number of trees: 70 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 733.5s, done 288 out of 1950
# Number of trees: 70 , Maximum depth 34 :
# Accuracy: 0.9994742376445847
#   Fold n. 3
# elapsed time: 737.19s, done 289 out of 1950
# Number of trees: 70 , Maximum depth 34 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 740.85s, done 290 out of 1950
# Number of trees: 70 , Maximum depth 34 :
# Accuracy: 0.8364449119116487
# Area under ROC curve: 0.976 Selected area: 0.175
#
#
#   Fold n. 0
# elapsed time: 744.66s, done 291 out of 1950
# Number of trees: 70 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 748.41s, done 292 out of 1950
# Number of trees: 70 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 752.06s, done 293 out of 1950
# Number of trees: 70 , Maximum depth 36 :
# Accuracy: 0.9994742376445847
#   Fold n. 3
# elapsed time: 755.76s, done 294 out of 1950
# Number of trees: 70 , Maximum depth 36 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 759.41s, done 295 out of 1950
# Number of trees: 70 , Maximum depth 36 :
# Accuracy: 0.8356560610044702
# Area under ROC curve: 0.976 Selected area: 0.17
#
#
#   Fold n. 0
# elapsed time: 763.06s, done 296 out of 1950
# Number of trees: 70 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 766.72s, done 297 out of 1950
# Number of trees: 70 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 770.43s, done 298 out of 1950
# Number of trees: 70 , Maximum depth 38 :
# Accuracy: 0.9997371188222923
#   Fold n. 3
# elapsed time: 774.3s, done 299 out of 1950
# Number of trees: 70 , Maximum depth 38 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 777.98s, done 300 out of 1950
# Number of trees: 70 , Maximum depth 38 :
# Accuracy: 0.8346042597948987
# Area under ROC curve: 0.976 Selected area: 0.169
#
#
#   Fold n. 0
# elapsed time: 780.44s, done 301 out of 1950
# Number of trees: 80 , Maximum depth 10 :
# Accuracy: 0.8577812828601472
#   Fold n. 1
# elapsed time: 782.97s, done 302 out of 1950
# Number of trees: 80 , Maximum depth 10 :
# Accuracy: 0.8533123028391167
#   Fold n. 2
# elapsed time: 785.51s, done 303 out of 1950
# Number of trees: 80 , Maximum depth 10 :
# Accuracy: 0.8638275499474237
#   Fold n. 3
# elapsed time: 787.99s, done 304 out of 1950
# Number of trees: 80 , Maximum depth 10 :
# Accuracy: 0.8480546792849631
#   Fold n. 4
# elapsed time: 790.52s, done 305 out of 1950
# Number of trees: 80 , Maximum depth 10 :
# Accuracy: 0.8190901919537208
# Area under ROC curve: 0.896 Selected area: 0.113
#
#
#   Fold n. 0
# elapsed time: 793.4s, done 306 out of 1950
# Number of trees: 80 , Maximum depth 12 :
# Accuracy: 0.8830178759200841
#   Fold n. 1
# elapsed time: 796.19s, done 307 out of 1950
# Number of trees: 80 , Maximum depth 12 :
# Accuracy: 0.8780231335436383
#   Fold n. 2
# elapsed time: 799.05s, done 308 out of 1950
# Number of trees: 80 , Maximum depth 12 :
# Accuracy: 0.8851209253417456
#   Fold n. 3
# elapsed time: 801.84s, done 309 out of 1950
# Number of trees: 80 , Maximum depth 12 :
# Accuracy: 0.880651945320715
#   Fold n. 4
# elapsed time: 804.65s, done 310 out of 1950
# Number of trees: 80 , Maximum depth 12 :
# Accuracy: 0.8261898501183277
# Area under ROC curve: 0.923 Selected area: 0.131
#
#
#   Fold n. 0
# elapsed time: 807.75s, done 311 out of 1950
# Number of trees: 80 , Maximum depth 14 :
# Accuracy: 0.9061514195583596
#   Fold n. 1
# elapsed time: 810.94s, done 312 out of 1950
# Number of trees: 80 , Maximum depth 14 :
# Accuracy: 0.9093059936908517
#   Fold n. 2
# elapsed time: 814.01s, done 313 out of 1950
# Number of trees: 80 , Maximum depth 14 :
# Accuracy: 0.9098317560462671
#   Fold n. 3
# elapsed time: 817.13s, done 314 out of 1950
# Number of trees: 80 , Maximum depth 14 :
# Accuracy: 0.9043112513144059
#   Fold n. 4
# elapsed time: 820.21s, done 315 out of 1950
# Number of trees: 80 , Maximum depth 14 :
# Accuracy: 0.8322377070733631
# Area under ROC curve: 0.945 Selected area: 0.15
#
#
#   Fold n. 0
# elapsed time: 823.58s, done 316 out of 1950
# Number of trees: 80 , Maximum depth 16 :
# Accuracy: 0.9263932702418507
#   Fold n. 1
# elapsed time: 826.94s, done 317 out of 1950
# Number of trees: 80 , Maximum depth 16 :
# Accuracy: 0.9290220820189274
#   Fold n. 2
# elapsed time: 830.38s, done 318 out of 1950
# Number of trees: 80 , Maximum depth 16 :
# Accuracy: 0.9298107255520505
#   Fold n. 3
# elapsed time: 833.84s, done 319 out of 1950
# Number of trees: 80 , Maximum depth 16 :
# Accuracy: 0.926919032597266
#   Fold n. 4
# elapsed time: 837.22s, done 320 out of 1950
# Number of trees: 80 , Maximum depth 16 :
# Accuracy: 0.8327636076781488
# Area under ROC curve: 0.959 Selected area: 0.157
#
#
#   Fold n. 0
# elapsed time: 840.8s, done 321 out of 1950
# Number of trees: 80 , Maximum depth 18 :
# Accuracy: 0.942429022082019
#   Fold n. 1
# elapsed time: 844.37s, done 322 out of 1950
# Number of trees: 80 , Maximum depth 18 :
# Accuracy: 0.9466351209253417
#   Fold n. 2
# elapsed time: 847.93s, done 323 out of 1950
# Number of trees: 80 , Maximum depth 18 :
# Accuracy: 0.9474237644584648
#   Fold n. 3
# elapsed time: 851.62s, done 324 out of 1950
# Number of trees: 80 , Maximum depth 18 :
# Accuracy: 0.9434805467928497
#   Fold n. 4
# elapsed time: 855.17s, done 325 out of 1950
# Number of trees: 80 , Maximum depth 18 :
# Accuracy: 0.8353931107020773
# Area under ROC curve: 0.968 Selected area: 0.143
#
#
#   Fold n. 0
# elapsed time: 859.01s, done 326 out of 1950
# Number of trees: 80 , Maximum depth 20 :
# Accuracy: 0.9574132492113565
#   Fold n. 1
# elapsed time: 862.88s, done 327 out of 1950
# Number of trees: 80 , Maximum depth 20 :
# Accuracy: 0.9582018927444795
#   Fold n. 2
# elapsed time: 866.61s, done 328 out of 1950
# Number of trees: 80 , Maximum depth 20 :
# Accuracy: 0.9639852786540484
#   Fold n. 3
# elapsed time: 870.32s, done 329 out of 1950
# Number of trees: 80 , Maximum depth 20 :
# Accuracy: 0.9592534174553102
#   Fold n. 4
# elapsed time: 874.17s, done 330 out of 1950
# Number of trees: 80 , Maximum depth 20 :
# Accuracy: 0.835919011306863
# Area under ROC curve: 0.973 Selected area: 0.116
#
#
#   Fold n. 0
# elapsed time: 878.04s, done 331 out of 1950
# Number of trees: 80 , Maximum depth 22 :
# Accuracy: 0.9692429022082019
#   Fold n. 1
# elapsed time: 881.92s, done 332 out of 1950
# Number of trees: 80 , Maximum depth 22 :
# Accuracy: 0.9708201892744479
#   Fold n. 2
# elapsed time: 885.92s, done 333 out of 1950
# Number of trees: 80 , Maximum depth 22 :
# Accuracy: 0.9771293375394322
#   Fold n. 3
# elapsed time: 889.75s, done 334 out of 1950
# Number of trees: 80 , Maximum depth 22 :
# Accuracy: 0.9708201892744479
#   Fold n. 4
# elapsed time: 893.8s, done 335 out of 1950
# Number of trees: 80 , Maximum depth 22 :
# Accuracy: 0.8356560610044702
# Area under ROC curve: 0.975 Selected area: 0.169
#
#
#   Fold n. 0
# elapsed time: 897.9s, done 336 out of 1950
# Number of trees: 80 , Maximum depth 24 :
# Accuracy: 0.980546792849632
#   Fold n. 1
# elapsed time: 901.87s, done 337 out of 1950
# Number of trees: 80 , Maximum depth 24 :
# Accuracy: 0.982124079915878
#   Fold n. 2
# elapsed time: 905.78s, done 338 out of 1950
# Number of trees: 80 , Maximum depth 24 :
# Accuracy: 0.9847528916929548
#   Fold n. 3
# elapsed time: 909.79s, done 339 out of 1950
# Number of trees: 80 , Maximum depth 24 :
# Accuracy: 0.9794952681388013
#   Fold n. 4
# elapsed time: 913.91s, done 340 out of 1950
# Number of trees: 80 , Maximum depth 24 :
# Accuracy: 0.8374967131212201
# Area under ROC curve: 0.976 Selected area: 0.174
#
#
#   Fold n. 0
# elapsed time: 917.9s, done 341 out of 1950
# Number of trees: 80 , Maximum depth 26 :
# Accuracy: 0.9894847528916929
#   Fold n. 1
# elapsed time: 921.93s, done 342 out of 1950
# Number of trees: 80 , Maximum depth 26 :
# Accuracy: 0.9886961093585699
#   Fold n. 2
# elapsed time: 925.97s, done 343 out of 1950
# Number of trees: 80 , Maximum depth 26 :
# Accuracy: 0.9926393270241851
#   Fold n. 3
# elapsed time: 930.02s, done 344 out of 1950
# Number of trees: 80 , Maximum depth 26 :
# Accuracy: 0.9894847528916929
#   Fold n. 4
# elapsed time: 934.05s, done 345 out of 1950
# Number of trees: 80 , Maximum depth 26 :
# Accuracy: 0.8369708125164343
# Area under ROC curve: 0.976 Selected area: 0.178
#
#
#   Fold n. 0
# elapsed time: 938.19s, done 346 out of 1950
# Number of trees: 80 , Maximum depth 28 :
# Accuracy: 0.9957939011566772
#   Fold n. 1
# elapsed time: 942.29s, done 347 out of 1950
# Number of trees: 80 , Maximum depth 28 :
# Accuracy: 0.9931650893796005
#   Fold n. 2
# elapsed time: 946.44s, done 348 out of 1950
# Number of trees: 80 , Maximum depth 28 :
# Accuracy: 0.9978969505783386
#   Fold n. 3
# elapsed time: 950.63s, done 349 out of 1950
# Number of trees: 80 , Maximum depth 28 :
# Accuracy: 0.9965825446898002
#   Fold n. 4
# elapsed time: 954.82s, done 350 out of 1950
# Number of trees: 80 , Maximum depth 28 :
# Accuracy: 0.8382855640283986
# Area under ROC curve: 0.976 Selected area: 0.176
#
#
#   Fold n. 0
# elapsed time: 958.92s, done 351 out of 1950
# Number of trees: 80 , Maximum depth 30 :
# Accuracy: 0.9978969505783386
#   Fold n. 1
# elapsed time: 963.2s, done 352 out of 1950
# Number of trees: 80 , Maximum depth 30 :
# Accuracy: 0.9976340694006309
#   Fold n. 2
# elapsed time: 967.43s, done 353 out of 1950
# Number of trees: 80 , Maximum depth 30 :
# Accuracy: 0.9989484752891693
#   Fold n. 3
# elapsed time: 971.64s, done 354 out of 1950
# Number of trees: 80 , Maximum depth 30 :
# Accuracy: 0.9994742376445847
#   Fold n. 4
# elapsed time: 975.85s, done 355 out of 1950
# Number of trees: 80 , Maximum depth 30 :
# Accuracy: 0.8369708125164343
# ...
# Number of trees: 280 , Maximum depth 22 :
# Accuracy: 0.9716088328075709
#   Fold n. 4
# elapsed time: 13045.42s, done 1835 out of 1950
# Number of trees: 280 , Maximum depth 22 :
# Accuracy: 0.8380226137260058
# Area under ROC curve: 0.976 Selected area: 0.069
#
#
#   Fold n. 0
# elapsed time: 13058.86s, done 1836 out of 1950
# Number of trees: 280 , Maximum depth 24 :
# Accuracy: 0.9810725552050473
#   Fold n. 1
# elapsed time: 13072.37s, done 1837 out of 1950
# Number of trees: 280 , Maximum depth 24 :
# Accuracy: 0.9826498422712934
#   Fold n. 2
# elapsed time: 13085.83s, done 1838 out of 1950
# Number of trees: 280 , Maximum depth 24 :
# Accuracy: 0.9858044164037855
#   Fold n. 3
# elapsed time: 13099.36s, done 1839 out of 1950
# Number of trees: 280 , Maximum depth 24 :
# Accuracy: 0.980546792849632
#   Fold n. 4
# elapsed time: 13113.0s, done 1840 out of 1950
# Number of trees: 280 , Maximum depth 24 :
# Accuracy: 0.8414409676571128
# Area under ROC curve: 0.976 Selected area: 0.097
#
#
#   Fold n. 0
# elapsed time: 13126.69s, done 1841 out of 1950
# Number of trees: 280 , Maximum depth 26 :
# Accuracy: 0.9900105152471083
#   Fold n. 1
# elapsed time: 13140.49s, done 1842 out of 1950
# Number of trees: 280 , Maximum depth 26 :
# Accuracy: 0.9889589905362776
#   Fold n. 2
# elapsed time: 13154.15s, done 1843 out of 1950
# Number of trees: 280 , Maximum depth 26 :
# Accuracy: 0.9939537329127235
#   Fold n. 3
# elapsed time: 13168.09s, done 1844 out of 1950
# Number of trees: 280 , Maximum depth 26 :
# Accuracy: 0.9889589905362776
#   Fold n. 4
# elapsed time: 13181.84s, done 1845 out of 1950
# Number of trees: 280 , Maximum depth 26 :
# Accuracy: 0.8390744149355772
# Area under ROC curve: 0.977 Selected area: 0.171
#
#
#   Fold n. 0
# elapsed time: 13195.72s, done 1846 out of 1950
# Number of trees: 280 , Maximum depth 28 :
# Accuracy: 0.9950052576235542
#   Fold n. 1
# elapsed time: 13209.78s, done 1847 out of 1950
# Number of trees: 280 , Maximum depth 28 :
# Accuracy: 0.9942166140904312
#   Fold n. 2
# elapsed time: 13223.75s, done 1848 out of 1950
# Number of trees: 280 , Maximum depth 28 :
# Accuracy: 0.9976340694006309
#   Fold n. 3
# elapsed time: 13237.56s, done 1849 out of 1950
# Number of trees: 280 , Maximum depth 28 :
# Accuracy: 0.9973711882229233
#   Fold n. 4
# elapsed time: 13251.44s, done 1850 out of 1950
# Number of trees: 280 , Maximum depth 28 :
# Accuracy: 0.8403891664475415
# Area under ROC curve: 0.977 Selected area: 0.174
#
#
#   Fold n. 0
# elapsed time: 13265.39s, done 1851 out of 1950
# Number of trees: 280 , Maximum depth 30 :
# Accuracy: 0.998422712933754
#   Fold n. 1
# elapsed time: 13279.36s, done 1852 out of 1950
# Number of trees: 280 , Maximum depth 30 :
# Accuracy: 0.9976340694006309
#   Fold n. 2
# elapsed time: 13293.44s, done 1853 out of 1950
# Number of trees: 280 , Maximum depth 30 :
# Accuracy: 0.999211356466877
#   Fold n. 3
# elapsed time: 13307.41s, done 1854 out of 1950
# Number of trees: 280 , Maximum depth 30 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 13321.43s, done 1855 out of 1950
# Number of trees: 280 , Maximum depth 30 :
# Accuracy: 0.837759663423613
# Area under ROC curve: 0.977 Selected area: 0.179
#
#
#   Fold n. 0
# elapsed time: 13335.57s, done 1856 out of 1950
# Number of trees: 280 , Maximum depth 32 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 13350.11s, done 1857 out of 1950
# Number of trees: 280 , Maximum depth 32 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 13364.22s, done 1858 out of 1950
# Number of trees: 280 , Maximum depth 32 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 13378.22s, done 1859 out of 1950
# Number of trees: 280 , Maximum depth 32 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 13392.19s, done 1860 out of 1950
# Number of trees: 280 , Maximum depth 32 :
# Accuracy: 0.83933736523797
# Area under ROC curve: 0.977 Selected area: 0.18
#
#
#   Fold n. 0
# elapsed time: 13406.36s, done 1861 out of 1950
# Number of trees: 280 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 13420.49s, done 1862 out of 1950
# Number of trees: 280 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 13434.54s, done 1863 out of 1950
# Number of trees: 280 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 13448.59s, done 1864 out of 1950
# Number of trees: 280 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 13462.67s, done 1865 out of 1950
# Number of trees: 280 , Maximum depth 34 :
# Accuracy: 0.8398632658427557
# Area under ROC curve: 0.977 Selected area: 0.179
#
#
#   Fold n. 0
# elapsed time: 13476.77s, done 1866 out of 1950
# Number of trees: 280 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 13490.8s, done 1867 out of 1950
# Number of trees: 280 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 13504.84s, done 1868 out of 1950
# Number of trees: 280 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 13518.96s, done 1869 out of 1950
# Number of trees: 280 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 13533.16s, done 1870 out of 1950
# Number of trees: 280 , Maximum depth 36 :
# Accuracy: 0.8396003155403629
# Area under ROC curve: 0.977 Selected area: 0.181
#
#
#   Fold n. 0
# elapsed time: 13547.31s, done 1871 out of 1950
# Number of trees: 280 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 13561.37s, done 1872 out of 1950
# Number of trees: 280 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 13575.41s, done 1873 out of 1950
# Number of trees: 280 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 13589.74s, done 1874 out of 1950
# Number of trees: 280 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 13603.78s, done 1875 out of 1950
# Number of trees: 280 , Maximum depth 38 :
# Accuracy: 0.8403891664475415
# Area under ROC curve: 0.977 Selected area: 0.178
#
#
#   Fold n. 0
# elapsed time: 13612.2s, done 1876 out of 1950
# Number of trees: 290 , Maximum depth 10 :
# Accuracy: 0.860410094637224
#   Fold n. 1
# elapsed time: 13620.55s, done 1877 out of 1950
# Number of trees: 290 , Maximum depth 10 :
# Accuracy: 0.8548895899053628
#   Fold n. 2
# elapsed time: 13628.96s, done 1878 out of 1950
# Number of trees: 290 , Maximum depth 10 :
# Accuracy: 0.863564668769716
#   Fold n. 3
# elapsed time: 13637.35s, done 1879 out of 1950
# Number of trees: 290 , Maximum depth 10 :
# Accuracy: 0.8480546792849631
#   Fold n. 4
# elapsed time: 13646.11s, done 1880 out of 1950
# Number of trees: 290 , Maximum depth 10 :
# Accuracy: 0.8198790428608993
# Area under ROC curve: 0.898 Selected area: 0.114
#
#
#   Fold n. 0
# elapsed time: 13655.93s, done 1881 out of 1950
# Number of trees: 290 , Maximum depth 12 :
# Accuracy: 0.8835436382754994
#   Fold n. 1
# elapsed time: 13665.76s, done 1882 out of 1950
# Number of trees: 290 , Maximum depth 12 :
# Accuracy: 0.8788117770767613
#   Fold n. 2
# elapsed time: 13675.33s, done 1883 out of 1950
# Number of trees: 290 , Maximum depth 12 :
# Accuracy: 0.8861724500525763
#   Fold n. 3
# elapsed time: 13685.22s, done 1884 out of 1950
# Number of trees: 290 , Maximum depth 12 :
# Accuracy: 0.881440588853838
#   Fold n. 4
# elapsed time: 13695.03s, done 1885 out of 1950
# Number of trees: 290 , Maximum depth 12 :
# Accuracy: 0.8280305022350776
# Area under ROC curve: 0.925 Selected area: 0.133
#
#
#   Fold n. 0
# elapsed time: 13706.13s, done 1886 out of 1950
# Number of trees: 290 , Maximum depth 14 :
# Accuracy: 0.905888538380652
#   Fold n. 1
# elapsed time: 13716.78s, done 1887 out of 1950
# Number of trees: 290 , Maximum depth 14 :
# Accuracy: 0.9095688748685594
#   Fold n. 2
# elapsed time: 13727.71s, done 1888 out of 1950
# Number of trees: 290 , Maximum depth 14 :
# Accuracy: 0.9098317560462671
#   Fold n. 3
# elapsed time: 13738.41s, done 1889 out of 1950
# Number of trees: 290 , Maximum depth 14 :
# Accuracy: 0.9056256572029443
#   Fold n. 4
# elapsed time: 13749.07s, done 1890 out of 1950
# Number of trees: 290 , Maximum depth 14 :
# Accuracy: 0.8314488561661846
# Area under ROC curve: 0.946 Selected area: 0.151
#
#
#   Fold n. 0
# elapsed time: 13761.02s, done 1891 out of 1950
# Number of trees: 290 , Maximum depth 16 :
# Accuracy: 0.9282334384858044
#   Fold n. 1
# elapsed time: 13772.73s, done 1892 out of 1950
# Number of trees: 290 , Maximum depth 16 :
# Accuracy: 0.9295478443743428
#   Fold n. 2
# elapsed time: 13784.56s, done 1893 out of 1950
# Number of trees: 290 , Maximum depth 16 :
# Accuracy: 0.9300736067297581
#   Fold n. 3
# elapsed time: 13796.19s, done 1894 out of 1950
# Number of trees: 290 , Maximum depth 16 :
# Accuracy: 0.9274447949526814
#   Fold n. 4
# elapsed time: 13807.81s, done 1895 out of 1950
# Number of trees: 290 , Maximum depth 16 :
# Accuracy: 0.8340783591901131
# Area under ROC curve: 0.96 Selected area: 0.156
#
#
#   Fold n. 0
# elapsed time: 13820.63s, done 1896 out of 1950
# Number of trees: 290 , Maximum depth 18 :
# Accuracy: 0.942429022082019
#   Fold n. 1
# elapsed time: 13833.21s, done 1897 out of 1950
# Number of trees: 290 , Maximum depth 18 :
# Accuracy: 0.9453207150368034
#   Fold n. 2
# elapsed time: 13845.57s, done 1898 out of 1950
# Number of trees: 290 , Maximum depth 18 :
# Accuracy: 0.9476866456361724
#   Fold n. 3
# elapsed time: 13858.07s, done 1899 out of 1950
# Number of trees: 290 , Maximum depth 18 :
# Accuracy: 0.943217665615142
#   Fold n. 4
# elapsed time: 13870.92s, done 1900 out of 1950
# Number of trees: 290 , Maximum depth 18 :
# Accuracy: 0.8372337628188272
# Area under ROC curve: 0.969 Selected area: 0.131
#
#
#   Fold n. 0
# elapsed time: 13884.03s, done 1901 out of 1950
# Number of trees: 290 , Maximum depth 20 :
# Accuracy: 0.9571503680336488
#   Fold n. 1
# elapsed time: 13897.16s, done 1902 out of 1950
# Number of trees: 290 , Maximum depth 20 :
# Accuracy: 0.9563617245005258
#   Fold n. 2
# elapsed time: 13910.23s, done 1903 out of 1950
# Number of trees: 290 , Maximum depth 20 :
# Accuracy: 0.96267087276551
#   Fold n. 3
# elapsed time: 13923.34s, done 1904 out of 1950
# Number of trees: 290 , Maximum depth 20 :
# Accuracy: 0.9592534174553102
#   Fold n. 4
# elapsed time: 13936.39s, done 1905 out of 1950
# Number of trees: 290 , Maximum depth 20 :
# Accuracy: 0.8356560610044702
# Area under ROC curve: 0.974 Selected area: 0.103
#
#
#   Fold n. 0
# elapsed time: 13950.46s, done 1906 out of 1950
# Number of trees: 290 , Maximum depth 22 :
# Accuracy: 0.9700315457413249
#   Fold n. 1
# elapsed time: 13964.02s, done 1907 out of 1950
# Number of trees: 290 , Maximum depth 22 :
# Accuracy: 0.9718717139852786
#   Fold n. 2
# elapsed time: 13977.66s, done 1908 out of 1950
# Number of trees: 290 , Maximum depth 22 :
# Accuracy: 0.9760778128286015
#   Fold n. 3
# elapsed time: 13991.22s, done 1909 out of 1950
# Number of trees: 290 , Maximum depth 22 :
# Accuracy: 0.9713459516298633
#   Fold n. 4
# elapsed time: 14004.9s, done 1910 out of 1950
# Number of trees: 290 , Maximum depth 22 :
# Accuracy: 0.8385485143307915
# Area under ROC curve: 0.976 Selected area: 0.07
#
#
#   Fold n. 0
# elapsed time: 14018.93s, done 1911 out of 1950
# Number of trees: 290 , Maximum depth 24 :
# Accuracy: 0.9808096740273397
#   Fold n. 1
# elapsed time: 14032.94s, done 1912 out of 1950
# Number of trees: 290 , Maximum depth 24 :
# Accuracy: 0.9826498422712934
#   Fold n. 2
# elapsed time: 14046.89s, done 1913 out of 1950
# Number of trees: 290 , Maximum depth 24 :
# Accuracy: 0.9860672975814931
#   Fold n. 3
# elapsed time: 14060.82s, done 1914 out of 1950
# Number of trees: 290 , Maximum depth 24 :
# Accuracy: 0.9818611987381703
#   Fold n. 4
# elapsed time: 14075.0s, done 1915 out of 1950
# Number of trees: 290 , Maximum depth 24 :
# Accuracy: 0.8409150670523271
# Area under ROC curve: 0.976 Selected area: 0.139
#
#
#   Fold n. 0
# elapsed time: 14089.23s, done 1916 out of 1950
# Number of trees: 290 , Maximum depth 26 :
# Accuracy: 0.9892218717139852
#   Fold n. 1
# elapsed time: 14103.73s, done 1917 out of 1950
# Number of trees: 290 , Maximum depth 26 :
# Accuracy: 0.9889589905362776
#   Fold n. 2
# elapsed time: 14117.97s, done 1918 out of 1950
# Number of trees: 290 , Maximum depth 26 :
# Accuracy: 0.9939537329127235
#   Fold n. 3
# elapsed time: 14132.31s, done 1919 out of 1950
# Number of trees: 290 , Maximum depth 26 :
# Accuracy: 0.9889589905362776
#   Fold n. 4
# elapsed time: 14146.55s, done 1920 out of 1950
# Number of trees: 290 , Maximum depth 26 :
# Accuracy: 0.8396003155403629
# Area under ROC curve: 0.977 Selected area: 0.174
#
#
#   Fold n. 0
# elapsed time: 14160.96s, done 1921 out of 1950
# Number of trees: 290 , Maximum depth 28 :
# Accuracy: 0.9950052576235542
#   Fold n. 1
# elapsed time: 14175.36s, done 1922 out of 1950
# Number of trees: 290 , Maximum depth 28 :
# Accuracy: 0.9947423764458465
#   Fold n. 2
# elapsed time: 14189.82s, done 1923 out of 1950
# Number of trees: 290 , Maximum depth 28 :
# Accuracy: 0.9978969505783386
#   Fold n. 3
# elapsed time: 14204.21s, done 1924 out of 1950
# Number of trees: 290 , Maximum depth 28 :
# Accuracy: 0.9968454258675079
#   Fold n. 4
# elapsed time: 14218.6s, done 1925 out of 1950
# Number of trees: 290 , Maximum depth 28 :
# Accuracy: 0.8401262161451486
# Area under ROC curve: 0.977 Selected area: 0.175
#
#
#   Fold n. 0
# elapsed time: 14233.08s, done 1926 out of 1950
# Number of trees: 290 , Maximum depth 30 :
# Accuracy: 0.998422712933754
#   Fold n. 1
# elapsed time: 14247.8s, done 1927 out of 1950
# Number of trees: 290 , Maximum depth 30 :
# Accuracy: 0.9976340694006309
#   Fold n. 2
# elapsed time: 14262.28s, done 1928 out of 1950
# Number of trees: 290 , Maximum depth 30 :
# Accuracy: 0.9994742376445847
#   Fold n. 3
# elapsed time: 14276.83s, done 1929 out of 1950
# Number of trees: 290 , Maximum depth 30 :
# Accuracy: 0.9997371188222923
#   Fold n. 4
# elapsed time: 14291.39s, done 1930 out of 1950
# Number of trees: 290 , Maximum depth 30 :
# Accuracy: 0.837759663423613
# Area under ROC curve: 0.977 Selected area: 0.179
#
#
#   Fold n. 0
# elapsed time: 14305.94s, done 1931 out of 1950
# Number of trees: 290 , Maximum depth 32 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 14320.58s, done 1932 out of 1950
# Number of trees: 290 , Maximum depth 32 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 14335.27s, done 1933 out of 1950
# Number of trees: 290 , Maximum depth 32 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 14349.88s, done 1934 out of 1950
# Number of trees: 290 , Maximum depth 32 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 14364.44s, done 1935 out of 1950
# Number of trees: 290 , Maximum depth 32 :
# Accuracy: 0.8390744149355772
# Area under ROC curve: 0.977 Selected area: 0.18
#
#
#   Fold n. 0
# elapsed time: 14379.18s, done 1936 out of 1950
# Number of trees: 290 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 14393.77s, done 1937 out of 1950
# Number of trees: 290 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 14408.33s, done 1938 out of 1950
# Number of trees: 290 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 14422.94s, done 1939 out of 1950
# Number of trees: 290 , Maximum depth 34 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 14438.09s, done 1940 out of 1950
# Number of trees: 290 , Maximum depth 34 :
# Accuracy: 0.8390744149355772
# Area under ROC curve: 0.977 Selected area: 0.18
#
#
#   Fold n. 0
# elapsed time: 14452.66s, done 1941 out of 1950
# Number of trees: 290 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 14467.26s, done 1942 out of 1950
# Number of trees: 290 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 14481.87s, done 1943 out of 1950
# Number of trees: 290 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 14497.09s, done 1944 out of 1950
# Number of trees: 290 , Maximum depth 36 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 14511.69s, done 1945 out of 1950
# Number of trees: 290 , Maximum depth 36 :
# Accuracy: 0.8388114646331843
# Area under ROC curve: 0.977 Selected area: 0.18
#
#
#   Fold n. 0
# elapsed time: 14526.27s, done 1946 out of 1950
# Number of trees: 290 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 1
# elapsed time: 14540.85s, done 1947 out of 1950
# Number of trees: 290 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 2
# elapsed time: 14555.56s, done 1948 out of 1950
# Number of trees: 290 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 3
# elapsed time: 14570.18s, done 1949 out of 1950
# Number of trees: 290 , Maximum depth 38 :
# Accuracy: 1.0
#   Fold n. 4
# elapsed time: 14584.83s, done 1950 out of 1950
# Number of trees: 290 , Maximum depth 38 :
# Accuracy: 0.8396003155403629
# Area under ROC curve: 0.977 Selected area: 0.181
#
#
# Best number of trees: 290
#
# Best maximum depth: 38
#
# Area under ROC curve of best model: 0.18122901956348395

# %%
print(round(best_area,3))
print(round(best_total_auc,3))
# Out:
# 0.18122901956348395
# 0.9767659747832987

# %% [markdown]
# Now we train again the best Random Forest found on the whole training set. We calculate its accuracy and $Q$ factor on the test set, and find the relative ROC curve of the classifier.

# %%
X_train_np = np.array(X_train)
Y_train_np = np.array(Y_train)
X_test_np = np.array(X_test)
Y_test_np = np.array(Y_test)

best_forest = RandomForestClassifier(n_estimators=best_model[0], max_depth= best_model[1], max_features=X_train_np.shape[1],bootstrap=True,max_samples=1.0,random_state=10,n_jobs=-1)

best_forest.fit(X_train_np,Y_train_np)
Y_pred = best_forest.predict(X_test_np)
accuracy = accuracy_score(Y_test_np, Y_pred)
print('Accuracy of best Random Forest:',round(accuracy,3))

y_pred_prob = best_forest.predict_proba(X_test_np)[:, 1]
fpr, tpr, thresholds = roc_curve(Y_test_np, y_pred_prob)
partial_fpr = fpr[fpr <= 0.2]
partial_tpr = tpr[:len(partial_fpr)]
partial_auc = auc(partial_fpr, partial_tpr)
roc_auc_best = auc(fpr, tpr)
print('Area under ROC curve of the best Random Forest:',round(roc_auc_best,3))
print('Partial area under ROC curve under 0.2 fpr:',round(partial_auc,3))
# Out:
# Accuracy of best Random Forest: 0.8296082040494347
# Area under ROC curve of the best Random Forest: 0.18122901956348395
# Partial area under ROC curve under 0.2 fpr: 0.10369271183667533

# %% [markdown]
# Here we plot the confusion matrix

# %%
cm = confusion_matrix(Y_test,Y_pred)
RF_cm = normalize_cm(cm)

print('Confusion matrix:')
print(RF_cm)
plot_cm(RF_cm,method_name='Random Forest')
# Out:
# Confusion matrix:
# [[0.652 0.348]
#  [0.074 0.926]]

# %% [markdown]
# Finally we compute Q and plot the ROC curve

# %%
fpr_rforest = fpr
tpr_rforest = tpr
Q_rforest = RF_cm[1][1]/ np.sqrt(RF_cm[0][1])

print('best random forest Q:',Q_rforest)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=1.5, label=f'ROC curve (AUC = {roc_auc_best:.3f})')
plt.plot([0, 1], [0, 1], color='red', linestyle='--') 
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.02])
plt.xlabel('False Positive Rate',fontsize=13.8)
plt.ylabel('True Positive Rate',fontsize=13.8)
plt.title('Random Forest ROC Curve',fontsize=14.3)
plt.grid(alpha=0.4)
plt.legend(loc='best')
plt.show()
# Out:
# best random forest Q: 1.5697170108821763

# %% [markdown]
# ## Part 5.5: FFNN
# This part is about training a convolluted neural network to fit data. Different parameters are going to be trained in a manual grid search

# %%
# redefine NN cycle
hidden_layer_sizes = [(18,), (36,), (54,), (36,18), (54,18), (54,36), (54,36,18)]
learning_rate_init = [ 0.1 , 0.01 , 0.001 ]

start_time = time()

auc_scorer = make_scorer(full_auc_scorer, greater_is_better=True, response_method='predict' ) 

parameters = []
fprs = []
tprs = []
aucs = []
partial_aucs = []
hls = []
lrs = []
models = []
K = 5
kf = KFold(n_splits=K, shuffle=True, random_state=42) 

for size in hidden_layer_sizes:
    for lr in learning_rate_init:
        print(f"Training MLP of size {size} and lr {lr}...")
        lrs.append(lr)
        hls.append(size)
        partial_auc = 0
        auc_value = 0

        for i, (train_index, test_index) in enumerate(kf.split(X)):
            
            print(f" Fold n. {i}")
            train_K=data_rescaled_and_indexed.iloc[train_idx]
            valid_K=data_rescaled_and_indexed.iloc[val_idx]
            X_train_K, Y_train_K = split_X_Y(train_K)
            X_valid_K, Y_valid_K = split_X_Y(valid_K)
            
            MLP = MLPClassifier(hidden_layer_sizes=size,
                                activation='relu', 
                                max_iter=1000, 
                                alpha=1e-4, 
                                solver='adam', 
                                tol=1e-5, 
                                learning_rate='adaptive',
                                learning_rate_init=lr,
                                verbose=0)
            
            MLP.fit(X_train_K,Y_train_K)
            parameters.append(MLP.coefs_)
            models.append(MLP)
            
            y_pred_proba = MLP.predict_proba(X_valid_K)[:, 1]  
    
            fpr, tpr, _ = roc_curve(Y_valid_K, y_pred_proba)
            fprs.append(fpr)
            tprs.append(tpr)
            auc_value_k = auc(fpr, tpr)
            print("AUC (Test set):", round(auc_value_k,3))
            
            # search for fpr less than 0.2 (if not able fpr is set to zero)
            partial_fpr = fpr[fpr <= 0.2]
            if (len(partial_fpr) < 2 ):
                partial_auc = 0
            else:
                partial_tpr = tpr[:len(partial_fpr)]
                partial_auc_k = auc(partial_fpr, partial_tpr)
            partial_auc += partial_auc_k/K
            auc_value += auc_value_k/K                 
        partial_aucs.append(partial_auc)
        aucs.append(auc_value)
        
        elapsed_time = time() - start_time
        start_time = time()
        print('\n')
        print(f"Time needed for training: {elapsed_time:.2f} seconds")
        print("partial AUC:",round(partial_auc,3)," total AUC:",round(auc_value,3),'\n')
# Out:
# Training MLP of size (18,) and lr 0.1...
#  Fold n. 0
# AUC (Test set): 0.863
#  Fold n. 1
# AUC (Test set): 0.845
#  Fold n. 2
# AUC (Test set): 0.864
#  Fold n. 3
# AUC (Test set): 0.856
#  Fold n. 4
# AUC (Test set): 0.861
#
#
# Time needed for training: 8.05 seconds
# partial AUC: 0.095  total AUC: 0.858
#
# Training MLP of size (18,) and lr 0.01...
#  Fold n. 0
# AUC (Test set): 0.876
#  Fold n. 1
# AUC (Test set): 0.872
#  Fold n. 2
# AUC (Test set): 0.87
#  Fold n. 3
# AUC (Test set): 0.882
#  Fold n. 4
# AUC (Test set): 0.878
#
#
# Time needed for training: 24.64 seconds
# partial AUC: 0.104  total AUC: 0.876
#
# Training MLP of size (18,) and lr 0.001...
#  Fold n. 0
# AUC (Test set): 0.872
#  Fold n. 1
# AUC (Test set): 0.871
#  Fold n. 2
# AUC (Test set): 0.874
#  Fold n. 3
# AUC (Test set): 0.871
#  Fold n. 4
# AUC (Test set): 0.871
#
#
# Time needed for training: 51.14 seconds
# partial AUC: 0.103  total AUC: 0.872
#
# Training MLP of size (36,) and lr 0.1...
#  Fold n. 0
# AUC (Test set): 0.86
#  Fold n. 1
# AUC (Test set): 0.865
#  Fold n. 2
# AUC (Test set): 0.867
#  Fold n. 3
# AUC (Test set): 0.865
#  Fold n. 4
# AUC (Test set): 0.863
#
#
# Time needed for training: 13.20 seconds
# partial AUC: 0.097  total AUC: 0.864
#
# Training MLP of size (36,) and lr 0.01...
#  Fold n. 0
# AUC (Test set): 0.888
#  Fold n. 1
# AUC (Test set): 0.876
#  Fold n. 2
# AUC (Test set): 0.894
#  Fold n. 3
# AUC (Test set): 0.88
#  Fold n. 4
# AUC (Test set): 0.89
#
#
# Time needed for training: 30.65 seconds
# partial AUC: 0.11  total AUC: 0.886
#
# Training MLP of size (36,) and lr 0.001...
#  Fold n. 0
# AUC (Test set): 0.876
#  Fold n. 1
# AUC (Test set): 0.88
#  Fold n. 2
# AUC (Test set): 0.877
#  Fold n. 3
# AUC (Test set): 0.872
#  Fold n. 4
# AUC (Test set): 0.879
#
#
# Time needed for training: 61.91 seconds
# partial AUC: 0.106  total AUC: 0.877
#
# Training MLP of size (54,) and lr 0.1...
#  Fold n. 0
# AUC (Test set): 0.861
#  Fold n. 1
# AUC (Test set): 0.856
#  Fold n. 2
# AUC (Test set): 0.868
#  Fold n. 3
# AUC (Test set): 0.852
#  Fold n. 4
# AUC (Test set): 0.86
#
#
# Time needed for training: 12.33 seconds
# partial AUC: 0.095  total AUC: 0.859
#
# Training MLP of size (54,) and lr 0.01...
#  Fold n. 0
# AUC (Test set): 0.884
#  Fold n. 1
# AUC (Test set): 0.882
#  Fold n. 2
# AUC (Test set): 0.888
#  Fold n. 3
# AUC (Test set): 0.892
#  Fold n. 4
# AUC (Test set): 0.888
#
#
# Time needed for training: 52.12 seconds
# partial AUC: 0.11  total AUC: 0.887
#
# Training MLP of size (54,) and lr 0.001...
#  Fold n. 0
# AUC (Test set): 0.877
#  Fold n. 1
# AUC (Test set): 0.878
#  Fold n. 2
# AUC (Test set): 0.879
#  Fold n. 3
# AUC (Test set): 0.874
#  Fold n. 4
# AUC (Test set): 0.876
#
#
# Time needed for training: 90.40 seconds
# partial AUC: 0.106  total AUC: 0.877
#
# Training MLP of size (36, 18) and lr 0.1...
#  Fold n. 0
# AUC (Test set): 0.871
#  Fold n. 1
# AUC (Test set): 0.859
#  Fold n. 2
# AUC (Test set): 0.87
#  Fold n. 3
# AUC (Test set): 0.882
#  Fold n. 4
# AUC (Test set): 0.867
#
#
# Time needed for training: 27.14 seconds
# partial AUC: 0.091  total AUC: 0.87
#
# Training MLP of size (36, 18) and lr 0.01...
#  Fold n. 0
# AUC (Test set): 0.876
#  Fold n. 1
# AUC (Test set): 0.882
#  Fold n. 2
# AUC (Test set): 0.883
#  Fold n. 3
# AUC (Test set): 0.877
#  Fold n. 4
# AUC (Test set): 0.881
#
#
# Time needed for training: 63.00 seconds
# partial AUC: 0.106  total AUC: 0.88
#
# Training MLP of size (36, 18) and lr 0.001...
#  Fold n. 0
# AUC (Test set): 0.881
#  Fold n. 1
# AUC (Test set): 0.879
#  Fold n. 2
# AUC (Test set): 0.878
#  Fold n. 3
# AUC (Test set): 0.877
#  Fold n. 4
# AUC (Test set): 0.887
#
#
# Time needed for training: 133.14 seconds
# partial AUC: 0.107  total AUC: 0.88
#
# Training MLP of size (54, 18) and lr 0.1...
#  Fold n. 0
# AUC (Test set): 0.854
#  Fold n. 1
# AUC (Test set): 0.862
#  Fold n. 2
# AUC (Test set): 0.866
#  Fold n. 3
# AUC (Test set): 0.868
#  Fold n. 4
# AUC (Test set): 0.874
#
#
# Time needed for training: 27.51 seconds
# partial AUC: 0.062  total AUC: 0.865
#
# Training MLP of size (54, 18) and lr 0.01...
#  Fold n. 0
# AUC (Test set): 0.879
#  Fold n. 1
# AUC (Test set): 0.88
#  Fold n. 2
# AUC (Test set): 0.873
#  Fold n. 3
# AUC (Test set): 0.883
#  Fold n. 4
# AUC (Test set): 0.879
#
#
# Time needed for training: 62.07 seconds
# partial AUC: 0.106  total AUC: 0.879
#
# Training MLP of size (54, 18) and lr 0.001...
#  Fold n. 0
# AUC (Test set): 0.881
#  Fold n. 1
# AUC (Test set): 0.882
#  Fold n. 2
# AUC (Test set): 0.876
#  Fold n. 3
# AUC (Test set): 0.883
#  Fold n. 4
# AUC (Test set): 0.884
#
#
# Time needed for training: 176.79 seconds
# partial AUC: 0.107  total AUC: 0.881
#
# Training MLP of size (54, 36) and lr 0.1...
#  Fold n. 0
# AUC (Test set): 0.875
#  Fold n. 1
# AUC (Test set): 0.867
#  Fold n. 2
# AUC (Test set): 0.873
#  Fold n. 3
# AUC (Test set): 0.87
#  Fold n. 4
# AUC (Test set): 0.875
#
#
# Time needed for training: 38.84 seconds
# partial AUC: 0.096  total AUC: 0.872
#
# Training MLP of size (54, 36) and lr 0.01...
#  Fold n. 0
# AUC (Test set): 0.88
#  Fold n. 1
# AUC (Test set): 0.873
#  Fold n. 2
# AUC (Test set): 0.867
#  Fold n. 3
# AUC (Test set): 0.869
#  Fold n. 4
# AUC (Test set): 0.871
#
#
# Time needed for training: 95.79 seconds
# partial AUC: 0.103  total AUC: 0.872
#
# Training MLP of size (54, 36) and lr 0.001...
#  Fold n. 0
# AUC (Test set): 0.879
#  Fold n. 1
# AUC (Test set): 0.881
#  Fold n. 2
# AUC (Test set): 0.883
#  Fold n. 3
# AUC (Test set): 0.882
#  Fold n. 4
# AUC (Test set): 0.884
#
#
# Time needed for training: 227.27 seconds
# partial AUC: 0.108  total AUC: 0.882
#
# Training MLP of size (54, 36, 18) and lr 0.1...
#  Fold n. 0
# AUC (Test set): 0.873
#  Fold n. 1
# AUC (Test set): 0.867
#  Fold n. 2
# AUC (Test set): 0.857
#  Fold n. 3
# AUC (Test set): 0.854
#  Fold n. 4
# AUC (Test set): 0.871
#
#
# Time needed for training: 29.33 seconds
# partial AUC: 0.098  total AUC: 0.865
#
# Training MLP of size (54, 36, 18) and lr 0.01...
#  Fold n. 0
# AUC (Test set): 0.872
#  Fold n. 1
# AUC (Test set): 0.869
#  Fold n. 2
# AUC (Test set): 0.864
#  Fold n. 3
# AUC (Test set): 0.874
#  Fold n. 4
# AUC (Test set): 0.876
#
#
# Time needed for training: 114.51 seconds
# partial AUC: 0.101  total AUC: 0.871
#
# Training MLP of size (54, 36, 18) and lr 0.001...
#  Fold n. 0
# AUC (Test set): 0.885
#  Fold n. 1
# AUC (Test set): 0.876
#  Fold n. 2
# AUC (Test set): 0.87
#  Fold n. 3
# AUC (Test set): 0.883
#  Fold n. 4
# AUC (Test set): 0.868
#
#
# Time needed for training: 259.21 seconds
# partial AUC: 0.105  total AUC: 0.876

# %% [markdown]
# Saving the best model's performance and plotting it, as well as the confusion matrix

# %%
best_index_thresh = np.argmax(np.array(partial_aucs))
best_auc_thresh = aucs[best_index_thresh]
best_fpr_thresh = fprs[best_index_thresh]
best_tpr_thresh = tprs[best_index_thresh]
best_model_NN = models[best_index_thresh]

#print(best_model)
Y_pred = best_model_NN.predict(X_test)
cm = confusion_matrix(Y_test,Y_pred)
NN_cm = normalize_cm(cm)

print('Confusion matrix:')
print(NN_cm)
plot_cm(NN_cm,method_name='NN')
# Out:
# Confusion matrix:
# [[0.591 0.409]
#  [0.053 0.947]]

# %%
fpr_NN = best_fpr_thresh
tpr_NN = best_tpr_thresh
Q_NN = NN_cm[1][1]/ np.sqrt(NN_cm[0][1])
auc_value = auc(fpr_NN, tpr_NN)

print('best NN Q value:',round(Q_NN,3))
print('best NN ROC area:',round(auc_value,3))

plt.grid()
plt.title('NN best ROC')
plt.plot([0, 1], [0, 1], linestyle='--', color='darkgrey')
plt.plot(best_fpr_thresh,best_tpr_thresh,label='NN ROC',lw=2,alpha=1,c='#197ce6')
plt.xlabel('false positive rate')
plt.ylabel('true positive rate')
plt.legend()
plt.show()
# Out:
# best NN Q value: 1.481
# best NN ROC area: 0.87

# %% [markdown]
# Now we plot them all

# %%
print('best NN Q value:',Q_NN.round(3))
print('best perceptron Q value:',Q_perceptron.round(3))
print('best SVM Q value:',Q_SVM.round(3))
print('best random forest Q value:',Q_rforest.round(3))
print('best log_reg Q value:',Q_log.round(3))

line_width = 3
plt.figure(figsize=(10,8))
plt.grid()
plt.title('ROC comparison',fontsize=24)
plt.plot([0, 1], [0, 1], linestyle='--', color='grey')
plt.plot(fpr_log,tpr_log,label='log ROC',lw=line_width,alpha=1,c='pink')
plt.plot(fpr_perceptron,tpr_perceptron,label='perceptron ROC',lw=line_width,alpha=1,c='red')
plt.plot(fpr_SVM,tpr_SVM,label='SVM ROC',lw=line_width,alpha=1,c='orange')
plt.plot(fpr_rforest,tpr_rforest,label='random forest ROC',lw=line_width,alpha=1,c='#1aff1a')
plt.plot(fpr_NN,tpr_NN,c='#197ce6',label='NN ROC',lw=line_width,alpha=1)
plt.xlabel('false positive rate',fontsize=18)
plt.ylabel('true positive rate',fontsize=18)
plt.legend(loc=4)
plt.show()
# Out:
# best NN Q value: 1.481
# best perceptron Q value: 0.96
# best SVM Q value: 1.358
# best random forest Q value: 1.57
# best log_reg Q value: 1.157

# %% [markdown]
# # Part 6: cutting on alpha parameter
# In this section a cut on alpha parameter is going to be performed. The best value for alpha is going to be determined, as well as the value that lets only 10% of hadron to be accepted as fp
# ## NOTE: Alpha param is not rescaled!

# %%
X_train['fAlpha'] = train_alpha
X_test['fAlpha'] = test_alpha
print(X_train.columns[:])
print(X_train.shape[:])
# Out:
# Index(['fLength', 'fWidth', 'fSize', 'fConc', 'fConc1', 'fAsym', 'fM3Long',
#        'fM3Trans', 'fDist', 'fAlpha'],
#       dtype='object')
# (15216, 10)

# %%
tot_hadrons = len(Y_test[Y_test == -1])
tot_gammas = len(Y_test[Y_test == 1])
tot_hadrons_train = len(Y_train[Y_train == -1])
sel_label = 9
# sel label = Alpha == 9

cut_values = []
rates = []
absolute_tp = []
absolute_fp = []

# setting minimum threshold as 0.90 (editable)
thresh = 0.90

#print('cut value    tp    fp     tp / all')
for i in range(1,tot_hadrons):
    cut_value = find_max_cut_value(X_train,Y_train,sel_label,i)
    
    # to check how the cut value behaves we get the results on test set
    tp, fp = find_tp_fp(X_test,Y_test,sel_label,cut_value)
    if (tp+fp == 0):
        tp = 1
    #print(cut_value,'  ',tp,'  ',fp,'  ',tp/(tp+fp))
    cut_values.append(cut_value)
    rates.append(tp/(tp+fp))
    absolute_tp.append(tp)
    absolute_fp.append(fp)
    
    if (tp/(tp+fp) > thresh):
        best_cut_thresh = cut_value
        rate_thresh = tp/(tp+fp)
        tp_thresh = tp
        fp_thresh = fp

rates = np.array(rates)
mask = np.where(rates < 1,rates,0)
index = np.argmax(mask)
best_rate = rates[index]
best_cut = cut_values[index]
best_tp = absolute_tp[index]
best_fp = absolute_fp[index]

print('total gammas:',tot_gammas,'tot hadrons:',tot_hadrons,'tot test points:',tot_gammas+tot_hadrons)
print('best cut value is Alpha =',round(best_cut,4),'with rate:',round(best_rate,4))
print('#tp:',best_tp,'  #fp:',best_fp)
print('rate of saved gammas:',round(best_tp / tot_gammas,4))
print(' ')
print('given threshold rate = 0.9, best cut is:',round(best_cut_thresh,4),'with rate',round(rate_thresh,4))
print('#tp:',tp_thresh,'#fp:',fp_thresh,'rate of saved gammas:',round(tp_thresh / tot_gammas,4))

plt.axhline(y=0.9, color='g', linestyle=':',label='threshold')  # Dotted green line
plt.scatter(cut_values,rates, s= 5,label='tp / all accepted')
plt.scatter(best_cut,best_rate,c='red',s=10,label='best rate')
plt.scatter(best_cut_thresh,rate_thresh,c='orange',s=10,label='best thresh rate')
plt.legend()
plt.title('cut values for Alpha (tp / all rate)')
plt.xlabel('Alpha values')
plt.ylabel('TPR')
plt.show();
# Out:
# total gammas: 2463 tot hadrons: 1340 tot test points: 3803
# best cut value is Alpha = 0.098 with rate: 0.95
# #tp: 19   #fp: 1
# rate of saved gammas: 0.0077
#
# given threshold rate = 0.9, best cut is: 2.4225 with rate 0.9008
# #tp: 436 #fp: 48 rate of saved gammas: 0.177

# %% [markdown]
# # Part 7: Grid search for best gammaness and alpha cut

# %%
print(best_forest)
# Out:
# RandomForestClassifier(max_depth=38, max_features=9, max_samples=1.0,
#                        n_estimators=290, n_jobs=-1, random_state=10)

# %% [markdown]
# We now apply the best model found in the previous part, i.e: the Random Forest, to look for the combination of parameters *gammaness* and *alpha_cut* that maximizes the quality factor *Q*. What we do is label as background (hadrons) all samples with fAlpha greater than the *alpha_cut* value considered; then we apply the best Random Forest classification to the remaining samples, labelling as gammas only the samples with a predicted probability of belonging to class +1 greater than *gammaness*. Then we determine the TPR and FPR to calculate the correspondent Q value.
# To avoid choosing the best combination of *alpha cut* and *gammaness* solely on the performance on a specific test set, we run the same algorithm on different test sets and choose as best case the one that returns the highest average Q value over the iterations.

# %%
# !wget -q https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data

file_name="magic04.data"
data = pd.DataFrame(pd.read_csv(file_name))
data.columns=['fLength','fWidth','fSize',
        'fConc','fConc1','fAsym',
        'fM3Long','fM3Trans','fAlpha','fDist','category']

# %%
data_rescaled = data
original_alpha = data['fAlpha'].copy()

for i in data.drop(columns=['category']).columns:
    h = data[i]
    avg = np.mean(h.astype(float))
    std = np.std(h)
    h = h - avg
    h = h / std
    data_rescaled[i]= h
    
print('avg length:',np.average(data_rescaled['fLength']))
print('dev_std length:',np.std(data_rescaled['fLength']))
data_rescaled['fAlpha'] = original_alpha
data_rescaled['category'] = data['category']
data_rescaled['category'] = data_rescaled['category'].replace({'g':1,'h':-1})
# Out:
# avg length: 3.5865241407523854e-17
# dev_std length: 0.9999999999999971

# %%
N=10
test_predictions=[]
gammaness= np.arange(0.8,0.96,0.01)
alpha_cut= np.arange(2,15,1)

for i in range(1,N+1):
    print('Iteration:',i,'\n')
    
    train_set, test_set = split_train_test_set( data_rescaled, 5)
    X_train, Y_train = split_X_Y(train_set)
    X_test, Y_test = split_X_Y(test_set)
    
    best_forest.fit(X_train,Y_train) 

    for alpha in alpha_cut:
        print('\n')
        for g in gammaness:

            test_data = [ X_test[ X_test['fAlpha']<alpha], Y_test[X_test['fAlpha']<alpha] ] 
            discarded_data = X_test[X_test['fAlpha'] >= alpha]
            discarded_labels = Y_test[X_test['fAlpha'] >= alpha] # we directly classify these points as hadrons 
            
            y_pred_prob = best_forest.predict_proba(test_data[0])[:, 1]
            y_pred_label = np.where(y_pred_prob > g, 1, -1)
        
            selected_gammas= np.sum(y_pred_label==1)
            selected_hadrons= np.sum(y_pred_label==-1) + ( X_test.shape[0]-len(test_data[0])) # samples in alpha cut classified as hadron by the model + all samples previously discarded
    
            total_gammas = np.sum(Y_test==1) # over all the test set (before alpha cut)
            total_hadrons = np.sum(Y_test==-1)
            
            true_positives = np.sum( (y_pred_label==1) & (test_data[1]==1) )
            false_positives = np.sum( (y_pred_label==1) & (test_data[1]==-1) )
            true_negatives= np.sum((y_pred_label == -1) & (test_data[1] == -1)) + np.sum((discarded_labels == -1))
            false_negatives= np.sum((y_pred_label == -1) & (test_data[1] == 1)) + np.sum((discarded_labels == 1))
            
            if false_positives != 0:
                epsilon_gamma = true_positives / total_gammas # TPR
                epsilon_hadron = false_positives / total_hadrons # FPR
                Q = epsilon_gamma/np.sqrt(epsilon_hadron)
            else:
                epsilon_hadron= 0
                epsilon_gamma = true_positives / total_gammas
                Q = 'inf'
                
            test_predictions.append({
            'iteration': i,   
            'alpha_cut': alpha,
            'gamma': g,
            'test_data': test_data, 
            'pred_probs': y_pred_prob,
            'pred label': y_pred_label,
            'selected gammas': selected_gammas,
            'selected hadrons': selected_hadrons,
            'total gammas': total_gammas,
            'total hadrons': total_hadrons,
            'true positives': true_positives,
            'false positives': false_positives,
            'true negatives': true_negatives,
            'false negatives': false_negatives,
            'Q': Q })

            if Q != 'inf':
                print(f"With alpha cut {alpha} and gammaness {g:.2f}, Q = {Q:.4f}")
            else:
                print(f"With alpha cut {alpha} and gammanesss {g:.2f}, Q = {Q}")
            print(f"True positives {true_positives}; False positives {false_positives}")
# Out:
# Iteration: 1
#
#
#
# With alpha cut 2 and gammaness 0.80, Q = 1.4078
# True positives 341; False positives 13
# With alpha cut 2 and gammaness 0.81, Q = 1.4037
# True positives 340; False positives 13
# With alpha cut 2 and gammaness 0.82, Q = 1.3954
# True positives 338; False positives 13
# With alpha cut 2 and gammaness 0.83, Q = 1.4395
# True positives 335; False positives 12
# With alpha cut 2 and gammaness 0.84, Q = 1.5534
# True positives 330; False positives 10
# With alpha cut 2 and gammaness 0.85, Q = 1.6324
# True positives 329; False positives 9
# With alpha cut 2 and gammaness 0.86, Q = 1.7104
# True positives 325; False positives 8
# With alpha cut 2 and gammaness 0.87, Q = 1.6946
# True positives 322; False positives 8
# With alpha cut 2 and gammaness 0.88, Q = 1.6631
# True positives 316; False positives 8
# With alpha cut 2 and gammaness 0.89, Q = 1.7329
# True positives 308; False positives 7
# With alpha cut 2 and gammaness 0.90, Q = 1.8353
# True positives 302; False positives 6
# With alpha cut 2 and gammaness 0.91, Q = 1.8109
# True positives 298; False positives 6
# With alpha cut 2 and gammaness 0.92, Q = 1.9172
# True positives 288; False positives 5
# With alpha cut 2 and gammaness 0.93, Q = 1.8573
# True positives 279; False positives 5
# With alpha cut 2 and gammaness 0.94, Q = 1.7575
# True positives 264; False positives 5
# With alpha cut 2 and gammaness 0.95, Q = 1.8532
# True positives 249; False positives 4
#
#
# With alpha cut 3 and gammaness 0.80, Q = 1.8160
# True positives 503; False positives 17
# With alpha cut 3 and gammaness 0.81, Q = 1.8644
# True positives 501; False positives 16
# With alpha cut 3 and gammaness 0.82, Q = 1.8532
# True positives 498; False positives 16
# With alpha cut 3 and gammaness 0.83, Q = 1.8910
# True positives 492; False positives 15
# With alpha cut 3 and gammaness 0.84, Q = 2.0065
# True positives 486; False positives 13
# With alpha cut 3 and gammaness 0.85, Q = 2.0798
# True positives 484; False positives 12
# With alpha cut 3 and gammaness 0.86, Q = 2.1498
# True positives 479; False positives 11
# With alpha cut 3 and gammaness 0.87, Q = 2.1319
# True positives 475; False positives 11
# With alpha cut 3 and gammaness 0.88, Q = 2.0825
# True positives 464; False positives 11
# With alpha cut 3 and gammaness 0.89, Q = 2.1418
# True positives 455; False positives 10
# With alpha cut 3 and gammaness 0.90, Q = 2.3420
# True positives 445; False positives 8
# With alpha cut 3 and gammaness 0.91, Q = 2.3104
# True positives 439; False positives 8
# With alpha cut 3 and gammaness 0.92, Q = 2.4024
# True positives 427; False positives 7
# With alpha cut 3 and gammaness 0.93, Q = 2.3292
# True positives 414; False positives 7
# With alpha cut 3 and gammaness 0.94, Q = 2.1886
# True positives 389; False positives 7
# With alpha cut 3 and gammaness 0.95, Q = 2.2242
# True positives 366; False positives 6
#
#
# With alpha cut 4 and gammaness 0.80, Q = 2.0533
# True positives 647; False positives 22
# With alpha cut 4 and gammaness 0.81, Q = 2.0919
# True positives 644; False positives 21
# With alpha cut 4 and gammaness 0.82, Q = 2.0822
# True positives 641; False positives 21
# With alpha cut 4 and gammaness 0.83, Q = 2.1103
# True positives 634; False positives 20
# With alpha cut 4 and gammaness 0.84, Q = 2.1999
# True positives 627; False positives 18
# With alpha cut 4 and gammaness 0.85, Q = 2.2528
# True positives 624; False positives 17
# With alpha cut 4 and gammaness 0.86, Q = 2.2961
# True positives 617; False positives 16
# With alpha cut 4 and gammaness 0.87, Q = 2.2700
# True positives 610; False positives 16
# With alpha cut 4 and gammaness 0.88, Q = 2.2179
# True positives 596; False positives 16
# With alpha cut 4 and gammaness 0.89, Q = 2.2369
# True positives 582; False positives 15
# With alpha cut 4 and gammaness 0.90, Q = 2.3450
# True positives 568; False positives 13
# With alpha cut 4 and gammaness 0.91, Q = 2.3202
# True positives 562; False positives 13
# With alpha cut 4 and gammaness 0.92, Q = 2.4595
# True positives 548; False positives 11
# With alpha cut 4 and gammaness 0.93, Q = 2.3742
# True positives 529; False positives 11
# With alpha cut 4 and gammaness 0.94, Q = 2.3489
# True positives 499; False positives 10
# With alpha cut 4 and gammaness 0.95, Q = 2.4841
# True positives 472; False positives 8
#
#
# With alpha cut 5 and gammaness 0.80, Q = 2.2179
# True positives 745; False positives 25
# With alpha cut 5 and gammaness 0.81, Q = 2.2515
# True positives 741; False positives 24
# With alpha cut 5 and gammaness 0.82, Q = 2.2394
# True positives 737; False positives 24
# With alpha cut 5 and gammaness 0.83, Q = 2.2658
# True positives 730; False positives 23
# With alpha cut 5 and gammaness 0.84, Q = 2.3453
# True positives 722; False positives 21
# With alpha cut 5 and gammaness 0.85, Q = 2.3899
# True positives 718; False positives 20
# With alpha cut 5 and gammaness 0.86, Q = 2.4246
# True positives 710; False positives 19
# With alpha cut 5 and gammaness 0.87, Q = 2.3939
# True positives 701; False positives 19
# With alpha cut 5 and gammaness 0.88, Q = 2.3427
# True positives 686; False positives 19
# With alpha cut 5 and gammaness 0.89, Q = 2.3542
# True positives 671; False positives 18
# With alpha cut 5 and gammaness 0.90, Q = 2.4375
# True positives 655; False positives 16
# With alpha cut 5 and gammaness 0.91, Q = 2.4040
# True positives 646; False positives 16
# With alpha cut 5 and gammaness 0.92, Q = 2.5024
# True positives 629; False positives 14
# With alpha cut 5 and gammaness 0.93, Q = 2.4109
# True positives 606; False positives 14
# With alpha cut 5 and gammaness 0.94, Q = 2.4407
# True positives 568; False positives 12
# With alpha cut 5 and gammaness 0.95, Q = 2.5372
# True positives 539; False positives 10
#
#
# With alpha cut 6 and gammaness 0.80, Q = 2.4350
# True positives 850; False positives 27
# With alpha cut 6 and gammaness 0.81, Q = 2.4668
# True positives 845; False positives 26
# With alpha cut 6 and gammaness 0.82, Q = 2.4434
# True positives 837; False positives 26
# With alpha cut 6 and gammaness 0.83, Q = 2.4650
# True positives 828; False positives 25
# With alpha cut 6 and gammaness 0.84, Q = 2.5421
# True positives 819; False positives 23
# With alpha cut 6 and gammaness 0.85, Q = 2.5833
# True positives 814; False positives 22
# With alpha cut 6 and gammaness 0.86, Q = 2.6181
# True positives 806; False positives 21
# With alpha cut 6 and gammaness 0.87, Q = 2.6428
# True positives 794; False positives 20
# With alpha cut 6 and gammaness 0.88, Q = 2.5896
# True positives 778; False positives 20
# With alpha cut 6 and gammaness 0.89, Q = 2.6022
# True positives 762; False positives 19
# With alpha cut 6 and gammaness 0.90, Q = 2.6897
# True positives 745; False positives 17
# With alpha cut 6 and gammaness 0.91, Q = 2.6355
# True positives 730; False positives 17
# With alpha cut 6 and gammaness 0.92, Q = 2.7404
# True positives 713; False positives 15
# With alpha cut 6 and gammaness 0.93, Q = 2.6520
# True positives 690; False positives 15
# With alpha cut 6 and gammaness 0.94, Q = 2.6588
# True positives 644; False positives 13
# With alpha cut 6 and gammaness 0.95, Q = 2.7333
# True positives 609; False positives 11
#
#
# With alpha cut 7 and gammaness 0.80, Q = 2.3601
# True positives 938; False positives 35
# With alpha cut 7 and gammaness 0.81, Q = 2.4150
# True positives 932; False positives 33
# With alpha cut 7 and gammaness 0.82, Q = 2.3917
# True positives 923; False positives 33
# With alpha cut 7 and gammaness 0.83, Q = 2.4025
# True positives 913; False positives 32
# With alpha cut 7 and gammaness 0.84, Q = 2.4514
# True positives 902; False positives 30
# With alpha cut 7 and gammaness 0.85, Q = 2.5234
# True positives 897; False positives 28
# With alpha cut 7 and gammaness 0.86, Q = 2.5410
# True positives 887; False positives 27
# With alpha cut 7 and gammaness 0.87, Q = 2.5515
# True positives 874; False positives 26
# With alpha cut 7 and gammaness 0.88, Q = 2.5018
# True positives 857; False positives 26
# With alpha cut 7 and gammaness 0.89, Q = 2.4978
# True positives 839; False positives 25
# With alpha cut 7 and gammaness 0.90, Q = 2.5421
# True positives 819; False positives 23
# With alpha cut 7 and gammaness 0.91, Q = 2.4893
# True positives 802; False positives 23
# With alpha cut 7 and gammaness 0.92, Q = 2.6029
# True positives 782; False positives 20
# With alpha cut 7 and gammaness 0.93, Q = 2.5164
# True positives 756; False positives 20
# With alpha cut 7 and gammaness 0.94, Q = 2.5344
# True positives 702; False positives 17
# With alpha cut 7 and gammaness 0.95, Q = 2.5367
# True positives 660; False positives 15
#
#
# With alpha cut 8 and gammaness 0.80, Q = 2.4814
# True positives 1014; False positives 37
# With alpha cut 8 and gammaness 0.81, Q = 2.5337
# True positives 1007; False positives 35
# With alpha cut 8 and gammaness 0.82, Q = 2.5086
# True positives 997; False positives 35
# With alpha cut 8 and gammaness 0.83, Q = 2.5171
# True positives 986; False positives 34
# With alpha cut 8 and gammaness 0.84, Q = 2.5630
# True positives 974; False positives 32
# With alpha cut 8 and gammaness 0.85, Q = 2.6757
# True positives 968; False positives 29
# With alpha cut 8 and gammaness 0.86, Q = 2.6865
# True positives 955; False positives 28
# With alpha cut 8 and gammaness 0.87, Q = 2.6986
# True positives 942; False positives 27
# With alpha cut 8 and gammaness 0.88, Q = 2.6441
# True positives 923; False positives 27
# With alpha cut 8 and gammaness 0.89, Q = 2.6244
# True positives 899; False positives 26
# With alpha cut 8 and gammaness 0.90, Q = 2.6678
# True positives 878; False positives 24
# With alpha cut 8 and gammaness 0.91, Q = 2.6070
# True positives 858; False positives 24
# With alpha cut 8 and gammaness 0.92, Q = 2.7156
# True positives 836; False positives 21
# With alpha cut 8 and gammaness 0.93, Q = 2.6214
# True positives 807; False positives 21
# With alpha cut 8 and gammaness 0.94, Q = 2.6314
# True positives 750; False positives 18
# With alpha cut 8 and gammaness 0.95, Q = 2.7019
# True positives 703; False positives 15
#
#
# With alpha cut 9 and gammaness 0.80, Q = 2.5061
# True positives 1078; False positives 41
# With alpha cut 9 and gammaness 0.81, Q = 2.5528
# True positives 1071; False positives 39
# With alpha cut 9 and gammaness 0.82, Q = 2.5290
# True positives 1061; False positives 39
# With alpha cut 9 and gammaness 0.83, Q = 2.5331
# True positives 1049; False positives 38
# With alpha cut 9 and gammaness 0.84, Q = 2.5678
# True positives 1035; False positives 36
# With alpha cut 9 and gammaness 0.85, Q = 2.6638
# True positives 1028; False positives 33
# With alpha cut 9 and gammaness 0.86, Q = 2.6656
# True positives 1013; False positives 32
# With alpha cut 9 and gammaness 0.87, Q = 2.6708
# True positives 999; False positives 31
# With alpha cut 9 and gammaness 0.88, Q = 2.7061
# True positives 979; False positives 29
# With alpha cut 9 and gammaness 0.89, Q = 2.7358
# True positives 955; False positives 27
# With alpha cut 9 and gammaness 0.90, Q = 2.7747
# True positives 932; False positives 25
# With alpha cut 9 and gammaness 0.91, Q = 2.7650
# True positives 910; False positives 24
# With alpha cut 9 and gammaness 0.92, Q = 2.8812
# True positives 887; False positives 21
# With alpha cut 9 and gammaness 0.93, Q = 2.7773
# True positives 855; False positives 21
# With alpha cut 9 and gammaness 0.94, Q = 2.7928
# True positives 796; False positives 18
# With alpha cut 9 and gammaness 0.95, Q = 2.8710
# True positives 747; False positives 15
#
#
# With alpha cut 10 and gammaness 0.80, Q = 2.5341
# True positives 1142; False positives 45
# With alpha cut 10 and gammaness 0.81, Q = 2.5742
# True positives 1134; False positives 43
# With alpha cut 10 and gammaness 0.82, Q = 2.5492
# True positives 1123; False positives 43
# With alpha cut 10 and gammaness 0.83, Q = 2.5518
# True positives 1111; False positives 42
# With alpha cut 10 and gammaness 0.84, Q = 2.6148
# True positives 1097; False positives 39
# With alpha cut 10 and gammaness 0.85, Q = 2.6943
# True positives 1086; False positives 36
# With alpha cut 10 and gammaness 0.86, Q = 2.6897
# True positives 1069; False positives 35
# With alpha cut 10 and gammaness 0.87, Q = 2.6830
# True positives 1051; False positives 34
# With alpha cut 10 and gammaness 0.88, Q = 2.7051
# True positives 1028; False positives 32
# With alpha cut 10 and gammaness 0.89, Q = 2.8215
# True positives 1003; False positives 28
# With alpha cut 10 and gammaness 0.90, Q = 2.8492
# True positives 976; False positives 26
# With alpha cut 10 and gammaness 0.91, Q = 2.8866
# True positives 950; False positives 24
# With alpha cut 10 and gammaness 0.92, Q = 3.0014
# True positives 924; False positives 21
# With alpha cut 10 and gammaness 0.93, Q = 2.8780
# True positives 886; False positives 21
# With alpha cut 10 and gammaness 0.94, Q = 2.8805
# True positives 821; False positives 18
# With alpha cut 10 and gammaness 0.95, Q = 2.9594
# True positives 770; False positives 15
#
#
# With alpha cut 11 and gammaness 0.80, Q = 2.4967
# True positives 1186; False positives 50
# With alpha cut 11 and gammaness 0.81, Q = 2.5310
# True positives 1178; False positives 48
# With alpha cut 11 and gammaness 0.82, Q = 2.5274
# True positives 1164; False positives 47
# With alpha cut 11 and gammaness 0.83, Q = 2.5262
# True positives 1151; False positives 46
# With alpha cut 11 and gammaness 0.84, Q = 2.6116
# True positives 1137; False positives 42
# With alpha cut 11 and gammaness 0.85, Q = 2.6815
# True positives 1125; False positives 39
# With alpha cut 11 and gammaness 0.86, Q = 2.6731
# True positives 1107; False positives 38
# With alpha cut 11 and gammaness 0.87, Q = 2.6625
# True positives 1088; False positives 37
# With alpha cut 11 and gammaness 0.88, Q = 2.6771
# True positives 1064; False positives 35
# With alpha cut 11 and gammaness 0.89, Q = 2.7644
# True positives 1034; False positives 31
# With alpha cut 11 and gammaness 0.90, Q = 2.7835
# True positives 1007; False positives 29
# With alpha cut 11 and gammaness 0.91, Q = 2.8046
# True positives 979; False positives 27
# With alpha cut 11 and gammaness 0.92, Q = 2.8866
# True positives 950; False positives 24
# With alpha cut 11 and gammaness 0.93, Q = 2.7620
# True positives 909; False positives 24
# With alpha cut 11 and gammaness 0.94, Q = 2.7383
# True positives 843; False positives 21
# With alpha cut 11 and gammaness 0.95, Q = 2.7612
# True positives 787; False positives 18
#
#
# With alpha cut 12 and gammaness 0.80, Q = 2.4895
# True positives 1229; False positives 54
# With alpha cut 12 and gammaness 0.81, Q = 2.5184
# True positives 1220; False positives 52
# With alpha cut 12 and gammaness 0.82, Q = 2.5138
# True positives 1206; False positives 51
# With alpha cut 12 and gammaness 0.83, Q = 2.5093
# True positives 1192; False positives 50
# With alpha cut 12 and gammaness 0.84, Q = 2.5788
# True positives 1175; False positives 46
# With alpha cut 12 and gammaness 0.85, Q = 2.6355
# True positives 1161; False positives 43
# With alpha cut 12 and gammaness 0.86, Q = 2.6230
# True positives 1142; False positives 42
# With alpha cut 12 and gammaness 0.87, Q = 2.6384
# True positives 1121; False positives 40
# With alpha cut 12 and gammaness 0.88, Q = 2.6796
# True positives 1095; False positives 37
# With alpha cut 12 and gammaness 0.89, Q = 2.7946
# True positives 1062; False positives 32
# With alpha cut 12 and gammaness 0.90, Q = 2.8047
# True positives 1032; False positives 30
# With alpha cut 12 and gammaness 0.91, Q = 2.8215
# True positives 1003; False positives 28
# With alpha cut 12 and gammaness 0.92, Q = 2.8908
# True positives 971; False positives 25
# With alpha cut 12 and gammaness 0.93, Q = 2.8228
# True positives 929; False positives 24
# With alpha cut 12 and gammaness 0.94, Q = 2.7870
# True positives 858; False positives 21
# With alpha cut 12 and gammaness 0.95, Q = 2.7998
# True positives 798; False positives 18
#
#
# With alpha cut 13 and gammaness 0.80, Q = 2.4922
# True positives 1264; False positives 57
# With alpha cut 13 and gammaness 0.81, Q = 2.5170
# True positives 1254; False positives 55
# With alpha cut 13 and gammaness 0.82, Q = 2.5098
# True positives 1239; False positives 54
# With alpha cut 13 and gammaness 0.83, Q = 2.5047
# True positives 1225; False positives 53
# With alpha cut 13 and gammaness 0.84, Q = 2.5667
# True positives 1207; False positives 49
# With alpha cut 13 and gammaness 0.85, Q = 2.6183
# True positives 1193; False positives 46
# With alpha cut 13 and gammaness 0.86, Q = 2.6345
# True positives 1174; False positives 44
# With alpha cut 13 and gammaness 0.87, Q = 2.6460
# True positives 1152; False positives 42
# With alpha cut 13 and gammaness 0.88, Q = 2.7118
# True positives 1123; False positives 38
# With alpha cut 13 and gammaness 0.89, Q = 2.8193
# True positives 1088; False positives 33
# With alpha cut 13 and gammaness 0.90, Q = 2.8179
# True positives 1054; False positives 31
# With alpha cut 13 and gammaness 0.91, Q = 2.8305
# True positives 1024; False positives 29
# With alpha cut 13 and gammaness 0.92, Q = 2.8872
# True positives 989; False positives 26
# With alpha cut 13 and gammaness 0.93, Q = 2.8104
# True positives 944; False positives 25
# With alpha cut 13 and gammaness 0.94, Q = 2.7610
# True positives 870; False positives 22
# With alpha cut 13 and gammaness 0.95, Q = 2.7559
# True positives 807; False positives 19
#
#
# With alpha cut 14 and gammaness 0.80, Q = 2.4519
# True positives 1297; False positives 62
# With alpha cut 14 and gammaness 0.81, Q = 2.4922
# True positives 1286; False positives 59
# With alpha cut 14 and gammaness 0.82, Q = 2.4823
# True positives 1270; False positives 58
# With alpha cut 14 and gammaness 0.83, Q = 2.4744
# True positives 1255; False positives 57
# With alpha cut 14 and gammaness 0.84, Q = 2.5272
# True positives 1236; False positives 53
# With alpha cut 14 and gammaness 0.85, Q = 2.5704
# True positives 1221; False positives 50
# With alpha cut 14 and gammaness 0.86, Q = 2.5783
# True positives 1200; False positives 48
# With alpha cut 14 and gammaness 0.87, Q = 2.5854
# True positives 1178; False positives 46
# With alpha cut 14 and gammaness 0.88, Q = 2.6665
# True positives 1147; False positives 41
# With alpha cut 14 and gammaness 0.89, Q = 2.7588
# True positives 1112; False positives 36
# With alpha cut 14 and gammaness 0.90, Q = 2.7494
# True positives 1077; False positives 34
# With alpha cut 14 and gammaness 0.91, Q = 2.7551
# True positives 1047; False positives 32
# With alpha cut 14 and gammaness 0.92, Q = 2.7863
# True positives 1008; False positives 29
# With alpha cut 14 and gammaness 0.93, Q = 2.7006
# True positives 960; False positives 28
# With alpha cut 14 and gammaness 0.94, Q = 2.6347
# True positives 885; False positives 25
# With alpha cut 14 and gammaness 0.95, Q = 2.7227
# True positives 818; False positives 20
# Iteration: 2
#
#
#
# With alpha cut 2 and gammaness 0.80, Q = 1.5046
# True positives 329; False positives 10
# With alpha cut 2 and gammaness 0.81, Q = 1.5046
# True positives 329; False positives 10
# With alpha cut 2 and gammaness 0.82, Q = 1.5000
# True positives 328; False positives 10
# With alpha cut 2 and gammaness 0.83, Q = 1.4908
# True positives 326; False positives 10
# With alpha cut 2 and gammaness 0.84, Q = 1.4634
# True positives 320; False positives 10
# With alpha cut 2 and gammaness 0.85, Q = 1.5329
# True positives 318; False positives 9
# With alpha cut 2 and gammaness 0.86, Q = 1.5233
# True positives 316; False positives 9
# With alpha cut 2 and gammaness 0.87, Q = 1.5136
# True positives 314; False positives 9
# With alpha cut 2 and gammaness 0.88, Q = 1.5088
# True positives 313; False positives 9
# With alpha cut 2 and gammaness 0.89, Q = 1.5850
# True positives 310; False positives 8
# With alpha cut 2 and gammaness 0.90, Q = 1.6726
# True positives 306; False positives 7
# With alpha cut 2 and gammaness 0.91, Q = 1.6562
# True positives 303; False positives 7
# With alpha cut 2 and gammaness 0.92, Q = 1.6070
# True positives 294; False positives 7
# With alpha cut 2 and gammaness 0.93, Q = 1.6413
# True positives 278; False positives 6
# With alpha cut 2 and gammaness 0.94, Q = 1.5704
# True positives 266; False positives 6
# With alpha cut 2 and gammaness 0.95, Q = 1.4760
# True positives 250; False positives 6
#
#
# With alpha cut 3 and gammaness 0.80, Q = 1.5328
# True positives 462; False positives 19
# With alpha cut 3 and gammaness 0.81, Q = 1.5261
# True positives 460; False positives 19
# With alpha cut 3 and gammaness 0.82, Q = 1.5162
# True positives 457; False positives 19
# With alpha cut 3 and gammaness 0.83, Q = 1.5062
# True positives 454; False positives 19
# With alpha cut 3 and gammaness 0.84, Q = 1.4797
# True positives 446; False positives 19
# With alpha cut 3 and gammaness 0.85, Q = 1.5134
# True positives 444; False positives 18
# With alpha cut 3 and gammaness 0.86, Q = 1.5468
# True positives 441; False positives 17
# With alpha cut 3 and gammaness 0.87, Q = 1.5363
# True positives 438; False positives 17
# With alpha cut 3 and gammaness 0.88, Q = 1.5222
# True positives 434; False positives 17
# With alpha cut 3 and gammaness 0.89, Q = 1.6619
# True positives 430; False positives 14
# With alpha cut 3 and gammaness 0.90, Q = 1.6966
# True positives 423; False positives 13
# With alpha cut 3 and gammaness 0.91, Q = 1.7408
# True positives 417; False positives 12
# With alpha cut 3 and gammaness 0.92, Q = 1.7659
# True positives 405; False positives 11
# With alpha cut 3 and gammaness 0.93, Q = 1.8511
# True positives 384; False positives 9
# With alpha cut 3 and gammaness 0.94, Q = 1.7836
# True positives 370; False positives 9
# With alpha cut 3 and gammaness 0.95, Q = 1.7016
# True positives 353; False positives 9
#
#
# With alpha cut 4 and gammaness 0.80, Q = 1.7759
# True positives 614; False positives 25
# With alpha cut 4 and gammaness 0.81, Q = 1.7672
# True positives 611; False positives 25
# With alpha cut 4 and gammaness 0.82, Q = 1.7556
# True positives 607; False positives 25
# With alpha cut 4 and gammaness 0.83, Q = 1.7469
# True positives 604; False positives 25
# With alpha cut 4 and gammaness 0.84, Q = 1.7594
# True positives 596; False positives 24
# With alpha cut 4 and gammaness 0.85, Q = 1.7791
# True positives 590; False positives 23
# With alpha cut 4 and gammaness 0.86, Q = 1.8006
# True positives 584; False positives 22
# With alpha cut 4 and gammaness 0.87, Q = 1.8303
# True positives 580; False positives 21
# With alpha cut 4 and gammaness 0.88, Q = 1.8114
# True positives 574; False positives 21
# With alpha cut 4 and gammaness 0.89, Q = 1.9361
# True positives 568; False positives 18
# With alpha cut 4 and gammaness 0.90, Q = 1.9536
# True positives 557; False positives 17
# With alpha cut 4 and gammaness 0.91, Q = 1.9848
# True positives 549; False positives 16
# With alpha cut 4 and gammaness 0.92, Q = 1.9827
# True positives 531; False positives 15
# With alpha cut 4 and gammaness 0.93, Q = 2.0999
# True positives 503; False positives 12
# With alpha cut 4 and gammaness 0.94, Q = 2.0247
# True positives 485; False positives 12
# With alpha cut 4 and gammaness 0.95, Q = 2.0101
# True positives 461; False positives 11
#
#
# With alpha cut 5 and gammaness 0.80, Q = 1.8831
# True positives 725; False positives 31
# With alpha cut 5 and gammaness 0.81, Q = 1.8753
# True positives 722; False positives 31
# With alpha cut 5 and gammaness 0.82, Q = 1.8649
# True positives 718; False positives 31
# With alpha cut 5 and gammaness 0.83, Q = 1.8545
# True positives 714; False positives 31
# With alpha cut 5 and gammaness 0.84, Q = 1.8588
# True positives 704; False positives 30
# With alpha cut 5 and gammaness 0.85, Q = 1.8744
# True positives 698; False positives 29
# With alpha cut 5 and gammaness 0.86, Q = 1.8912
# True positives 692; False positives 28
# With alpha cut 5 and gammaness 0.87, Q = 1.9899
# True positives 688; False positives 25
# With alpha cut 5 and gammaness 0.88, Q = 1.9697
# True positives 681; False positives 25
# With alpha cut 5 and gammaness 0.89, Q = 2.1730
# True positives 672; False positives 20
# With alpha cut 5 and gammaness 0.90, Q = 2.2429
# True positives 658; False positives 18
# With alpha cut 5 and gammaness 0.91, Q = 2.2693
# True positives 647; False positives 17
# With alpha cut 5 and gammaness 0.92, Q = 2.2668
# True positives 627; False positives 16
# With alpha cut 5 and gammaness 0.93, Q = 2.3905
# True positives 596; False positives 13
# With alpha cut 5 and gammaness 0.94, Q = 2.2902
# True positives 571; False positives 13
# With alpha cut 5 and gammaness 0.95, Q = 2.2668
# True positives 543; False positives 12
#
#
# With alpha cut 6 and gammaness 0.80, Q = 2.0970
# True positives 833; False positives 33
# With alpha cut 6 and gammaness 0.81, Q = 2.0844
# True positives 828; False positives 33
# With alpha cut 6 and gammaness 0.82, Q = 2.0744
# True positives 824; False positives 33
# With alpha cut 6 and gammaness 0.83, Q = 2.0618
# True positives 819; False positives 33
# With alpha cut 6 and gammaness 0.84, Q = 2.0656
# True positives 808; False positives 32
# With alpha cut 6 and gammaness 0.85, Q = 2.0805
# True positives 801; False positives 31
# With alpha cut 6 and gammaness 0.86, Q = 2.0990
# True positives 795; False positives 30
# With alpha cut 6 and gammaness 0.87, Q = 2.2405
# True positives 790; False positives 26
# With alpha cut 6 and gammaness 0.88, Q = 2.2179
# True positives 782; False positives 26
# With alpha cut 6 and gammaness 0.89, Q = 2.4268
# True positives 769; False positives 21
# With alpha cut 6 and gammaness 0.90, Q = 2.5015
# True positives 754; False positives 19
# With alpha cut 6 and gammaness 0.91, Q = 2.5990
# True positives 741; False positives 17
# With alpha cut 6 and gammaness 0.92, Q = 2.5995
# True positives 719; False positives 16
# With alpha cut 6 and gammaness 0.93, Q = 2.7394
# True positives 683; False positives 13
# With alpha cut 6 and gammaness 0.94, Q = 2.6271
# True positives 655; False positives 13
# With alpha cut 6 and gammaness 0.95, Q = 2.5841
# True positives 619; False positives 12
#
#
# With alpha cut 7 and gammaness 0.80, Q = 2.1536
# True positives 918; False positives 38
# With alpha cut 7 and gammaness 0.81, Q = 2.1419
# True positives 913; False positives 38
# With alpha cut 7 and gammaness 0.82, Q = 2.1325
# True positives 909; False positives 38
# With alpha cut 7 and gammaness 0.83, Q = 2.1207
# True positives 904; False positives 38
# With alpha cut 7 and gammaness 0.84, Q = 2.1112
# True positives 888; False positives 37
# With alpha cut 7 and gammaness 0.85, Q = 2.1210
# True positives 880; False positives 36
# With alpha cut 7 and gammaness 0.86, Q = 2.1340
# True positives 873; False positives 35
# With alpha cut 7 and gammaness 0.87, Q = 2.2519
# True positives 867; False positives 31
# With alpha cut 7 and gammaness 0.88, Q = 2.2233
# True positives 856; False positives 31
# With alpha cut 7 and gammaness 0.89, Q = 2.4266
# True positives 839; False positives 25
# With alpha cut 7 and gammaness 0.90, Q = 2.4757
# True positives 821; False positives 23
# With alpha cut 7 and gammaness 0.91, Q = 2.5435
# True positives 806; False positives 21
# With alpha cut 7 and gammaness 0.92, Q = 2.5287
# True positives 782; False positives 20
# With alpha cut 7 and gammaness 0.93, Q = 2.6898
# True positives 744; False positives 16
# With alpha cut 7 and gammaness 0.94, Q = 2.6660
# True positives 714; False positives 15
# With alpha cut 7 and gammaness 0.95, Q = 2.5895
# True positives 670; False positives 14
#
#
# With alpha cut 8 and gammaness 0.80, Q = 2.2477
# True positives 983; False positives 40
# With alpha cut 8 and gammaness 0.81, Q = 2.2317
# True positives 976; False positives 40
# With alpha cut 8 and gammaness 0.82, Q = 2.2180
# True positives 970; False positives 40
# With alpha cut 8 and gammaness 0.83, Q = 2.2042
# True positives 964; False positives 40
# With alpha cut 8 and gammaness 0.84, Q = 2.1930
# True positives 947; False positives 39
# With alpha cut 8 and gammaness 0.85, Q = 2.1982
# True positives 937; False positives 38
# With alpha cut 8 and gammaness 0.86, Q = 2.2110
# True positives 930; False positives 37
# With alpha cut 8 and gammaness 0.87, Q = 2.3622
# True positives 924; False positives 32
# With alpha cut 8 and gammaness 0.88, Q = 2.3289
# True positives 911; False positives 32
# With alpha cut 8 and gammaness 0.89, Q = 2.5298
# True positives 892; False positives 26
# With alpha cut 8 and gammaness 0.90, Q = 2.5741
# True positives 872; False positives 24
# With alpha cut 8 and gammaness 0.91, Q = 2.6361
# True positives 855; False positives 22
# With alpha cut 8 and gammaness 0.92, Q = 2.6161
# True positives 829; False positives 21
# With alpha cut 8 and gammaness 0.93, Q = 2.7674
# True positives 789; False positives 17
# With alpha cut 8 and gammaness 0.94, Q = 2.7224
# True positives 753; False positives 16
# With alpha cut 8 and gammaness 0.95, Q = 2.7132
# True positives 702; False positives 14
#
#
# With alpha cut 9 and gammaness 0.80, Q = 2.2695
# True positives 1041; False positives 44
# With alpha cut 9 and gammaness 0.81, Q = 2.2803
# True positives 1034; False positives 43
# With alpha cut 9 and gammaness 0.82, Q = 2.2939
# True positives 1028; False positives 42
# With alpha cut 9 and gammaness 0.83, Q = 2.2805
# True positives 1022; False positives 42
# With alpha cut 9 and gammaness 0.84, Q = 2.2675
# True positives 1004; False positives 41
# With alpha cut 9 and gammaness 0.85, Q = 2.2706
# True positives 993; False positives 40
# With alpha cut 9 and gammaness 0.86, Q = 2.2810
# True positives 985; False positives 39
# With alpha cut 9 and gammaness 0.87, Q = 2.4256
# True positives 978; False positives 34
# With alpha cut 9 and gammaness 0.88, Q = 2.3859
# True positives 962; False positives 34
# With alpha cut 9 and gammaness 0.89, Q = 2.5690
# True positives 940; False positives 28
# With alpha cut 9 and gammaness 0.90, Q = 2.6036
# True positives 918; False positives 26
# With alpha cut 9 and gammaness 0.91, Q = 2.6567
# True positives 900; False positives 24
# With alpha cut 9 and gammaness 0.92, Q = 2.6325
# True positives 873; False positives 23
# With alpha cut 9 and gammaness 0.93, Q = 2.7504
# True positives 829; False positives 19
# With alpha cut 9 and gammaness 0.94, Q = 2.6826
# True positives 787; False positives 18
# With alpha cut 9 and gammaness 0.95, Q = 2.6428
# True positives 731; False positives 16
#
#
# With alpha cut 10 and gammaness 0.80, Q = 2.3518
# True positives 1103; False positives 46
# With alpha cut 10 and gammaness 0.81, Q = 2.3606
# True positives 1095; False positives 45
# With alpha cut 10 and gammaness 0.82, Q = 2.3720
# True positives 1088; False positives 44
# With alpha cut 10 and gammaness 0.83, Q = 2.3524
# True positives 1079; False positives 44
# With alpha cut 10 and gammaness 0.84, Q = 2.3377
# True positives 1060; False positives 43
# With alpha cut 10 and gammaness 0.85, Q = 2.3363
# True positives 1047; False positives 42
# With alpha cut 10 and gammaness 0.86, Q = 2.3735
# True positives 1038; False positives 40
# With alpha cut 10 and gammaness 0.87, Q = 2.5104
# True positives 1027; False positives 35
# With alpha cut 10 and gammaness 0.88, Q = 2.4689
# True positives 1010; False positives 35
# With alpha cut 10 and gammaness 0.89, Q = 2.6532
# True positives 988; False positives 29
# With alpha cut 10 and gammaness 0.90, Q = 2.7284
# True positives 962; False positives 26
# With alpha cut 10 and gammaness 0.91, Q = 2.7748
# True positives 940; False positives 24
# With alpha cut 10 and gammaness 0.92, Q = 2.7440
# True positives 910; False positives 23
# With alpha cut 10 and gammaness 0.93, Q = 2.8698
# True positives 865; False positives 19
# With alpha cut 10 and gammaness 0.94, Q = 2.7916
# True positives 819; False positives 18
# With alpha cut 10 and gammaness 0.95, Q = 2.7332
# True positives 756; False positives 16
#
#
# With alpha cut 11 and gammaness 0.80, Q = 2.4364
# True positives 1155; False positives 47
# With alpha cut 11 and gammaness 0.81, Q = 2.4435
# True positives 1146; False positives 46
# With alpha cut 11 and gammaness 0.82, Q = 2.4511
# True positives 1137; False positives 45
# With alpha cut 11 and gammaness 0.83, Q = 2.4274
# True positives 1126; False positives 45
# With alpha cut 11 and gammaness 0.84, Q = 2.4069
# True positives 1104; False positives 44
# With alpha cut 11 and gammaness 0.85, Q = 2.4038
# True positives 1090; False positives 43
# With alpha cut 11 and gammaness 0.86, Q = 2.4392
# True positives 1080; False positives 41
# With alpha cut 11 and gammaness 0.87, Q = 2.5693
# True positives 1066; False positives 36
# With alpha cut 11 and gammaness 0.88, Q = 2.5187
# True positives 1045; False positives 36
# With alpha cut 11 and gammaness 0.89, Q = 2.6931
# True positives 1020; False positives 30
# With alpha cut 11 and gammaness 0.90, Q = 2.7553
# True positives 990; False positives 27
# With alpha cut 11 and gammaness 0.91, Q = 2.7853
# True positives 963; False positives 25
# With alpha cut 11 and gammaness 0.92, Q = 2.7453
# True positives 930; False positives 24
# With alpha cut 11 and gammaness 0.93, Q = 2.8586
# True positives 884; False positives 20
# With alpha cut 11 and gammaness 0.94, Q = 2.7736
# True positives 836; False positives 19
# With alpha cut 11 and gammaness 0.95, Q = 2.7077
# True positives 772; False positives 17
#
#
# With alpha cut 12 and gammaness 0.80, Q = 2.4542
# True positives 1200; False positives 50
# With alpha cut 12 and gammaness 0.81, Q = 2.4585
# True positives 1190; False positives 49
# With alpha cut 12 and gammaness 0.82, Q = 2.4610
# True positives 1179; False positives 48
# With alpha cut 12 and gammaness 0.83, Q = 2.4359
# True positives 1167; False positives 48
# With alpha cut 12 and gammaness 0.84, Q = 2.4393
# True positives 1144; False positives 46
# With alpha cut 12 and gammaness 0.85, Q = 2.4339
# True positives 1129; False positives 45
# With alpha cut 12 and gammaness 0.86, Q = 2.4634
# True positives 1117; False positives 43
# With alpha cut 12 and gammaness 0.87, Q = 2.5853
# True positives 1102; False positives 38
# With alpha cut 12 and gammaness 0.88, Q = 2.5360
# True positives 1081; False positives 38
# With alpha cut 12 and gammaness 0.89, Q = 2.6919
# True positives 1053; False positives 32
# With alpha cut 12 and gammaness 0.90, Q = 2.7472
# True positives 1023; False positives 29
# With alpha cut 12 and gammaness 0.91, Q = 2.7636
# True positives 993; False positives 27
# With alpha cut 12 and gammaness 0.92, Q = 2.7198
# True positives 959; False positives 26
# With alpha cut 12 and gammaness 0.93, Q = 2.8119
# True positives 912; False positives 22
# With alpha cut 12 and gammaness 0.94, Q = 2.7171
# True positives 861; False positives 21
# With alpha cut 12 and gammaness 0.95, Q = 2.6376
# True positives 795; False positives 19
#
#
# With alpha cut 13 and gammaness 0.80, Q = 2.4258
# True positives 1244; False positives 55
# With alpha cut 13 and gammaness 0.81, Q = 2.4285
# True positives 1234; False positives 54
# With alpha cut 13 and gammaness 0.82, Q = 2.4294
# True positives 1223; False positives 53
# With alpha cut 13 and gammaness 0.83, Q = 2.3996
# True positives 1208; False positives 53
# With alpha cut 13 and gammaness 0.84, Q = 2.3956
# True positives 1183; False positives 51
# With alpha cut 13 and gammaness 0.85, Q = 2.4380
# True positives 1168; False positives 48
# With alpha cut 13 and gammaness 0.86, Q = 2.4899
# True positives 1155; False positives 45
# With alpha cut 13 and gammaness 0.87, Q = 2.5952
# True positives 1135; False positives 40
# With alpha cut 13 and gammaness 0.88, Q = 2.5750
# True positives 1112; False positives 39
# With alpha cut 13 and gammaness 0.89, Q = 2.7289
# True positives 1084; False positives 33
# With alpha cut 13 and gammaness 0.90, Q = 2.7829
# True positives 1054; False positives 30
# With alpha cut 13 and gammaness 0.91, Q = 2.7986
# True positives 1024; False positives 28
# With alpha cut 13 and gammaness 0.92, Q = 2.7414
# True positives 985; False positives 27
# With alpha cut 13 and gammaness 0.93, Q = 2.8224
# True positives 936; False positives 23
# With alpha cut 13 and gammaness 0.94, Q = 2.7163
# True positives 881; False positives 22
# With alpha cut 13 and gammaness 0.95, Q = 2.6906
# True positives 811; False positives 19
#
#
# With alpha cut 14 and gammaness 0.80, Q = 2.4326
# True positives 1270; False positives 57
# With alpha cut 14 and gammaness 0.81, Q = 2.4349
# True positives 1260; False positives 56
# With alpha cut 14 and gammaness 0.82, Q = 2.4336
# True positives 1248; False positives 55
# With alpha cut 14 and gammaness 0.83, Q = 2.4024
# True positives 1232; False positives 55
# With alpha cut 14 and gammaness 0.84, Q = 2.3917
# True positives 1204; False positives 53
# With alpha cut 14 and gammaness 0.85, Q = 2.4297
# True positives 1188; False positives 50
# With alpha cut 14 and gammaness 0.86, Q = 2.4786
# True positives 1175; False positives 47
# With alpha cut 14 and gammaness 0.87, Q = 2.6041
# True positives 1153; False positives 41
# With alpha cut 14 and gammaness 0.88, Q = 2.5792
# True positives 1128; False positives 40
# With alpha cut 14 and gammaness 0.89, Q = 2.7281
# True positives 1100; False positives 34
# With alpha cut 14 and gammaness 0.90, Q = 2.7766
# True positives 1069; False positives 31
# With alpha cut 14 and gammaness 0.91, Q = 2.7848
# True positives 1037; False positives 29
# With alpha cut 14 and gammaness 0.92, Q = 2.7248
# True positives 997; False positives 28
# With alpha cut 14 and gammaness 0.93, Q = 2.7925
# True positives 946; False positives 24
# With alpha cut 14 and gammaness 0.94, Q = 2.6867
# True positives 891; False positives 23
# With alpha cut 14 and gammaness 0.95, Q = 2.6549
# True positives 821; False positives 20
# Iteration: 3
#
#
#
# With alpha cut 2 and gammaness 0.80, Q = 2.2024
# True positives 327; False positives 5
# With alpha cut 2 and gammaness 0.81, Q = 2.2024
# True positives 327; False positives 5
# With alpha cut 2 and gammaness 0.82, Q = 2.1957
# True positives 326; False positives 5
# With alpha cut 2 and gammaness 0.83, Q = 2.1889
# True positives 325; False positives 5
# With alpha cut 2 and gammaness 0.84, Q = 2.4096
# True positives 320; False positives 4
# With alpha cut 2 and gammaness 0.85, Q = 2.7824
# True positives 320; False positives 3
# With alpha cut 2 and gammaness 0.86, Q = 2.7650
# True positives 318; False positives 3
# With alpha cut 2 and gammaness 0.87, Q = 2.7476
# True positives 316; False positives 3
# With alpha cut 2 and gammaness 0.88, Q = 2.7042
# True positives 311; False positives 3
# With alpha cut 2 and gammaness 0.89, Q = 2.6259
# True positives 302; False positives 3
# With alpha cut 2 and gammaness 0.90, Q = 2.5650
# True positives 295; False positives 3
# With alpha cut 2 and gammaness 0.91, Q = 3.1096
# True positives 292; False positives 2
# With alpha cut 2 and gammaness 0.92, Q = 3.0137
# True positives 283; False positives 2
# With alpha cut 2 and gammaness 0.93, Q = 2.9498
# True positives 277; False positives 2
# With alpha cut 2 and gammaness 0.94, Q = 2.7901
# True positives 262; False positives 2
# With alpha cut 2 and gammaness 0.95, Q = 3.7500
# True positives 249; False positives 1
#
#
# With alpha cut 3 and gammaness 0.80, Q = 2.1907
# True positives 460; False positives 10
# With alpha cut 3 and gammaness 0.81, Q = 2.1907
# True positives 460; False positives 10
# With alpha cut 3 and gammaness 0.82, Q = 2.1765
# True positives 457; False positives 10
# With alpha cut 3 and gammaness 0.83, Q = 2.1669
# True positives 455; False positives 10
# With alpha cut 3 and gammaness 0.84, Q = 2.3908
# True positives 449; False positives 8
# With alpha cut 3 and gammaness 0.85, Q = 2.5501
# True positives 448; False positives 7
# With alpha cut 3 and gammaness 0.86, Q = 2.5331
# True positives 445; False positives 7
# With alpha cut 3 and gammaness 0.87, Q = 2.5217
# True positives 443; False positives 7
# With alpha cut 3 and gammaness 0.88, Q = 2.6684
# True positives 434; False positives 6
# With alpha cut 3 and gammaness 0.89, Q = 2.6007
# True positives 423; False positives 6
# With alpha cut 3 and gammaness 0.90, Q = 2.5454
# True positives 414; False positives 6
# With alpha cut 3 and gammaness 0.91, Q = 2.7345
# True positives 406; False positives 5
# With alpha cut 3 and gammaness 0.92, Q = 2.9593
# True positives 393; False positives 4
# With alpha cut 3 and gammaness 0.93, Q = 3.3476
# True positives 385; False positives 3
# With alpha cut 3 and gammaness 0.94, Q = 3.1911
# True positives 367; False positives 3
# With alpha cut 3 and gammaness 0.95, Q = 3.7272
# True positives 350; False positives 2
#
#
# With alpha cut 4 and gammaness 0.80, Q = 2.3565
# True positives 606; False positives 15
# With alpha cut 4 and gammaness 0.81, Q = 2.3565
# True positives 606; False positives 15
# With alpha cut 4 and gammaness 0.82, Q = 2.4150
# True positives 600; False positives 14
# With alpha cut 4 and gammaness 0.83, Q = 2.4070
# True positives 598; False positives 14
# With alpha cut 4 and gammaness 0.84, Q = 2.5694
# True positives 591; False positives 12
# With alpha cut 4 and gammaness 0.85, Q = 2.6700
# True positives 588; False positives 11
# With alpha cut 4 and gammaness 0.86, Q = 2.6564
# True positives 585; False positives 11
# With alpha cut 4 and gammaness 0.87, Q = 2.6428
# True positives 582; False positives 11
# With alpha cut 4 and gammaness 0.88, Q = 2.7146
# True positives 570; False positives 10
# With alpha cut 4 and gammaness 0.89, Q = 2.6622
# True positives 559; False positives 10
# With alpha cut 4 and gammaness 0.90, Q = 2.6003
# True positives 546; False positives 10
# With alpha cut 4 and gammaness 0.91, Q = 2.6757
# True positives 533; False positives 9
# With alpha cut 4 and gammaness 0.92, Q = 2.9315
# True positives 515; False positives 7
# With alpha cut 4 and gammaness 0.93, Q = 3.0865
# True positives 502; False positives 6
# With alpha cut 4 and gammaness 0.94, Q = 2.9143
# True positives 474; False positives 6
# With alpha cut 4 and gammaness 0.95, Q = 3.3961
# True positives 451; False positives 4
#
#
# With alpha cut 5 and gammaness 0.80, Q = 2.5913
# True positives 730; False positives 18
# With alpha cut 5 and gammaness 0.81, Q = 2.5913
# True positives 730; False positives 18
# With alpha cut 5 and gammaness 0.82, Q = 2.6445
# True positives 724; False positives 17
# With alpha cut 5 and gammaness 0.83, Q = 2.6372
# True positives 722; False positives 17
# With alpha cut 5 and gammaness 0.84, Q = 2.7725
# True positives 713; False positives 15
# With alpha cut 5 and gammaness 0.85, Q = 2.8578
# True positives 710; False positives 14
# With alpha cut 5 and gammaness 0.86, Q = 2.8457
# True positives 707; False positives 14
# With alpha cut 5 and gammaness 0.87, Q = 2.8296
# True positives 703; False positives 14
# With alpha cut 5 and gammaness 0.88, Q = 2.8738
# True positives 688; False positives 13
# With alpha cut 5 and gammaness 0.89, Q = 2.8195
# True positives 675; False positives 13
# With alpha cut 5 and gammaness 0.90, Q = 2.7443
# True positives 657; False positives 13
# With alpha cut 5 and gammaness 0.91, Q = 2.7911
# True positives 642; False positives 12
# With alpha cut 5 and gammaness 0.92, Q = 2.9480
# True positives 619; False positives 10
# With alpha cut 5 and gammaness 0.93, Q = 3.0221
# True positives 602; False positives 9
# With alpha cut 5 and gammaness 0.94, Q = 2.8514
# True positives 568; False positives 9
# With alpha cut 5 and gammaness 0.95, Q = 3.0966
# True positives 544; False positives 7
#
#
# With alpha cut 6 and gammaness 0.80, Q = 2.6347
# True positives 839; False positives 23
# With alpha cut 6 and gammaness 0.81, Q = 2.6347
# True positives 839; False positives 23
# With alpha cut 6 and gammaness 0.82, Q = 2.6747
# True positives 833; False positives 22
# With alpha cut 6 and gammaness 0.83, Q = 2.7179
# True positives 827; False positives 21
# With alpha cut 6 and gammaness 0.84, Q = 2.9037
# True positives 818; False positives 18
# With alpha cut 6 and gammaness 0.85, Q = 3.0685
# True positives 815; False positives 16
# With alpha cut 6 and gammaness 0.86, Q = 3.0572
# True positives 812; False positives 16
# With alpha cut 6 and gammaness 0.87, Q = 3.0196
# True positives 802; False positives 16
# With alpha cut 6 and gammaness 0.88, Q = 3.0525
# True positives 785; False positives 15
# With alpha cut 6 and gammaness 0.89, Q = 3.0020
# True positives 772; False positives 15
# With alpha cut 6 and gammaness 0.90, Q = 2.9281
# True positives 753; False positives 15
# With alpha cut 6 and gammaness 0.91, Q = 2.9705
# True positives 738; False positives 14
# With alpha cut 6 and gammaness 0.92, Q = 3.2285
# True positives 711; False positives 11
# With alpha cut 6 and gammaness 0.93, Q = 3.2956
# True positives 692; False positives 10
# With alpha cut 6 and gammaness 0.94, Q = 3.1194
# True positives 655; False positives 10
# With alpha cut 6 and gammaness 0.95, Q = 3.3279
# True positives 625; False positives 8
#
#
# With alpha cut 7 and gammaness 0.80, Q = 2.5928
# True positives 911; False positives 28
# With alpha cut 7 and gammaness 0.81, Q = 2.5928
# True positives 911; False positives 28
# With alpha cut 7 and gammaness 0.82, Q = 2.6201
# True positives 904; False positives 27
# With alpha cut 7 and gammaness 0.83, Q = 2.6464
# True positives 896; False positives 26
# With alpha cut 7 and gammaness 0.84, Q = 2.8448
# True positives 886; False positives 22
# With alpha cut 7 and gammaness 0.85, Q = 2.9736
# True positives 883; False positives 20
# With alpha cut 7 and gammaness 0.86, Q = 2.9567
# True positives 878; False positives 20
# With alpha cut 7 and gammaness 0.87, Q = 2.9886
# True positives 865; False positives 19
# With alpha cut 7 and gammaness 0.88, Q = 3.0031
# True positives 846; False positives 18
# With alpha cut 7 and gammaness 0.89, Q = 2.9463
# True positives 830; False positives 18
# With alpha cut 7 and gammaness 0.90, Q = 2.8753
# True positives 810; False positives 18
# With alpha cut 7 and gammaness 0.91, Q = 2.8893
# True positives 791; False positives 17
# With alpha cut 7 and gammaness 0.92, Q = 3.0711
# True positives 763; False positives 14
# With alpha cut 7 and gammaness 0.93, Q = 3.0951
# True positives 741; False positives 13
# With alpha cut 7 and gammaness 0.94, Q = 2.9364
# True positives 703; False positives 13
# With alpha cut 7 and gammaness 0.95, Q = 3.1909
# True positives 670; False positives 10
#
#
# With alpha cut 8 and gammaness 0.80, Q = 2.5931
# True positives 974; False positives 32
# With alpha cut 8 and gammaness 0.81, Q = 2.5931
# True positives 974; False positives 32
# With alpha cut 8 and gammaness 0.82, Q = 2.6102
# True positives 965; False positives 31
# With alpha cut 8 and gammaness 0.83, Q = 2.6286
# True positives 956; False positives 30
# With alpha cut 8 and gammaness 0.84, Q = 2.7911
# True positives 945; False positives 26
# With alpha cut 8 and gammaness 0.85, Q = 2.8897
# True positives 940; False positives 24
# With alpha cut 8 and gammaness 0.86, Q = 2.8713
# True positives 934; False positives 24
# With alpha cut 8 and gammaness 0.87, Q = 2.8859
# True positives 919; False positives 23
# With alpha cut 8 and gammaness 0.88, Q = 2.8866
# True positives 899; False positives 22
# With alpha cut 8 and gammaness 0.89, Q = 2.8320
# True positives 882; False positives 22
# With alpha cut 8 and gammaness 0.90, Q = 2.7646
# True positives 861; False positives 22
# With alpha cut 8 and gammaness 0.91, Q = 2.7639
# True positives 841; False positives 21
# With alpha cut 8 and gammaness 0.92, Q = 2.8788
# True positives 811; False positives 18
# With alpha cut 8 and gammaness 0.93, Q = 2.8783
# True positives 788; False positives 17
# With alpha cut 8 and gammaness 0.94, Q = 2.7139
# True positives 743; False positives 17
# With alpha cut 8 and gammaness 0.95, Q = 3.0824
# True positives 709; False positives 12
#
#
# With alpha cut 9 and gammaness 0.80, Q = 2.7378
# True positives 1060; False positives 34
# With alpha cut 9 and gammaness 0.81, Q = 2.7378
# True positives 1060; False positives 34
# With alpha cut 9 and gammaness 0.82, Q = 2.7527
# True positives 1050; False positives 33
# With alpha cut 9 and gammaness 0.83, Q = 2.7688
# True positives 1040; False positives 32
# With alpha cut 9 and gammaness 0.84, Q = 2.9230
# True positives 1027; False positives 28
# With alpha cut 9 and gammaness 0.85, Q = 3.0156
# True positives 1021; False positives 26
# With alpha cut 9 and gammaness 0.86, Q = 2.9979
# True positives 1015; False positives 26
# With alpha cut 9 and gammaness 0.87, Q = 3.0060
# True positives 998; False positives 25
# With alpha cut 9 and gammaness 0.88, Q = 3.0004
# True positives 976; False positives 24
# With alpha cut 9 and gammaness 0.89, Q = 2.9358
# True positives 955; False positives 24
# With alpha cut 9 and gammaness 0.90, Q = 2.8651
# True positives 932; False positives 24
# With alpha cut 9 and gammaness 0.91, Q = 2.8545
# True positives 909; False positives 23
# With alpha cut 9 and gammaness 0.92, Q = 2.9466
# True positives 875; False positives 20
# With alpha cut 9 and gammaness 0.93, Q = 2.9995
# True positives 845; False positives 18
# With alpha cut 9 and gammaness 0.94, Q = 2.8078
# True positives 791; False positives 18
# With alpha cut 9 and gammaness 0.95, Q = 3.1453
# True positives 753; False positives 13
#
#
# With alpha cut 10 and gammaness 0.80, Q = 2.7082
# True positives 1123; False positives 39
# With alpha cut 10 and gammaness 0.81, Q = 2.7082
# True positives 1123; False positives 39
# With alpha cut 10 and gammaness 0.82, Q = 2.7167
# True positives 1112; False positives 38
# With alpha cut 10 and gammaness 0.83, Q = 2.7611
# ...
# With alpha cut 3 and gammaness 0.90, Q = 1.8974
# True positives 412; False positives 10
# With alpha cut 3 and gammaness 0.91, Q = 1.9758
# True positives 407; False positives 9
# With alpha cut 3 and gammaness 0.92, Q = 2.0339
# True positives 395; False positives 8
# With alpha cut 3 and gammaness 0.93, Q = 2.2593
# True positives 380; False positives 6
# With alpha cut 3 and gammaness 0.94, Q = 2.3708
# True positives 364; False positives 5
# With alpha cut 3 and gammaness 0.95, Q = 2.1819
# True positives 335; False positives 5
#
#
# With alpha cut 4 and gammaness 0.80, Q = 1.9354
# True positives 609; False positives 21
# With alpha cut 4 and gammaness 0.81, Q = 1.9291
# True positives 607; False positives 21
# With alpha cut 4 and gammaness 0.82, Q = 1.9604
# True positives 602; False positives 20
# With alpha cut 4 and gammaness 0.83, Q = 1.9913
# True positives 596; False positives 19
# With alpha cut 4 and gammaness 0.84, Q = 2.0946
# True positives 593; False positives 17
# With alpha cut 4 and gammaness 0.85, Q = 2.1409
# True positives 588; False positives 16
# With alpha cut 4 and gammaness 0.86, Q = 2.1810
# True positives 580; False positives 15
# With alpha cut 4 and gammaness 0.87, Q = 2.1622
# True positives 575; False positives 15
# With alpha cut 4 and gammaness 0.88, Q = 2.1797
# True positives 560; False positives 14
# With alpha cut 4 and gammaness 0.89, Q = 2.1408
# True positives 550; False positives 14
# With alpha cut 4 and gammaness 0.90, Q = 2.1650
# True positives 536; False positives 13
# With alpha cut 4 and gammaness 0.91, Q = 2.2324
# True positives 531; False positives 12
# With alpha cut 4 and gammaness 0.92, Q = 2.3764
# True positives 516; False positives 10
# With alpha cut 4 and gammaness 0.93, Q = 2.5642
# True positives 498; False positives 8
# With alpha cut 4 and gammaness 0.94, Q = 2.6257
# True positives 477; False positives 7
# With alpha cut 4 and gammaness 0.95, Q = 2.4385
# True positives 443; False positives 7
#
#
# With alpha cut 5 and gammaness 0.80, Q = 2.0119
# True positives 731; False positives 28
# With alpha cut 5 and gammaness 0.81, Q = 2.0037
# True positives 728; False positives 28
# With alpha cut 5 and gammaness 0.82, Q = 2.0236
# True positives 722; False positives 27
# With alpha cut 5 and gammaness 0.83, Q = 2.0826
# True positives 715; False positives 25
# With alpha cut 5 and gammaness 0.84, Q = 2.1591
# True positives 711; False positives 23
# With alpha cut 5 and gammaness 0.85, Q = 2.1859
# True positives 704; False positives 22
# With alpha cut 5 and gammaness 0.86, Q = 2.2024
# True positives 693; False positives 21
# With alpha cut 5 and gammaness 0.87, Q = 2.1770
# True positives 685; False positives 21
# With alpha cut 5 and gammaness 0.88, Q = 2.1819
# True positives 670; False positives 20
# With alpha cut 5 and gammaness 0.89, Q = 2.2587
# True positives 658; False positives 18
# With alpha cut 5 and gammaness 0.90, Q = 2.2642
# True positives 641; False positives 17
# With alpha cut 5 and gammaness 0.91, Q = 2.3156
# True positives 636; False positives 16
# With alpha cut 5 and gammaness 0.92, Q = 2.4132
# True positives 620; False positives 14
# With alpha cut 5 and gammaness 0.93, Q = 2.5267
# True positives 601; False positives 12
# With alpha cut 5 and gammaness 0.94, Q = 2.6620
# True positives 578; False positives 10
# With alpha cut 5 and gammaness 0.95, Q = 2.4685
# True positives 536; False positives 10
#
#
# With alpha cut 6 and gammaness 0.80, Q = 2.2077
# True positives 844; False positives 31
# With alpha cut 6 and gammaness 0.81, Q = 2.1998
# True positives 841; False positives 31
# With alpha cut 6 and gammaness 0.82, Q = 2.2202
# True positives 835; False positives 30
# With alpha cut 6 and gammaness 0.83, Q = 2.2789
# True positives 828; False positives 28
# With alpha cut 6 and gammaness 0.84, Q = 2.3506
# True positives 823; False positives 26
# With alpha cut 6 and gammaness 0.85, Q = 2.4228
# True positives 815; False positives 24
# With alpha cut 6 and gammaness 0.86, Q = 2.4324
# True positives 801; False positives 23
# With alpha cut 6 and gammaness 0.87, Q = 2.4051
# True positives 792; False positives 23
# With alpha cut 6 and gammaness 0.88, Q = 2.4095
# True positives 776; False positives 22
# With alpha cut 6 and gammaness 0.89, Q = 2.4815
# True positives 762; False positives 20
# With alpha cut 6 and gammaness 0.90, Q = 2.4758
# True positives 741; False positives 19
# With alpha cut 6 and gammaness 0.91, Q = 2.5927
# True positives 734; False positives 17
# With alpha cut 6 and gammaness 0.92, Q = 2.6774
# True positives 712; False positives 15
# With alpha cut 6 and gammaness 0.93, Q = 2.7871
# True positives 690; False positives 13
# With alpha cut 6 and gammaness 0.94, Q = 2.9157
# True positives 664; False positives 11
# With alpha cut 6 and gammaness 0.95, Q = 2.7093
# True positives 617; False positives 11
#
#
# With alpha cut 7 and gammaness 0.80, Q = 2.1781
# True positives 934; False positives 39
# With alpha cut 7 and gammaness 0.81, Q = 2.1688
# True positives 930; False positives 39
# With alpha cut 7 and gammaness 0.82, Q = 2.1806
# True positives 923; False positives 38
# With alpha cut 7 and gammaness 0.83, Q = 2.2525
# True positives 915; False positives 35
# With alpha cut 7 and gammaness 0.84, Q = 2.3071
# True positives 910; False positives 33
# With alpha cut 7 and gammaness 0.85, Q = 2.3594
# True positives 902; False positives 31
# With alpha cut 7 and gammaness 0.86, Q = 2.3585
# True positives 887; False positives 30
# With alpha cut 7 and gammaness 0.87, Q = 2.3718
# True positives 877; False positives 29
# With alpha cut 7 and gammaness 0.88, Q = 2.3670
# True positives 860; False positives 28
# With alpha cut 7 and gammaness 0.89, Q = 2.4106
# True positives 844; False positives 26
# With alpha cut 7 and gammaness 0.90, Q = 2.3943
# True positives 822; False positives 25
# With alpha cut 7 and gammaness 0.91, Q = 2.4628
# True positives 811; False positives 23
# With alpha cut 7 and gammaness 0.92, Q = 2.6295
# True positives 787; False positives 19
# With alpha cut 7 and gammaness 0.93, Q = 2.6916
# True positives 762; False positives 17
# With alpha cut 7 and gammaness 0.94, Q = 2.7563
# True positives 733; False positives 15
# With alpha cut 7 and gammaness 0.95, Q = 2.6429
# True positives 679; False positives 14
#
#
# With alpha cut 8 and gammaness 0.80, Q = 2.1350
# True positives 1005; False positives 47
# With alpha cut 8 and gammaness 0.81, Q = 2.1243
# True positives 1000; False positives 47
# With alpha cut 8 and gammaness 0.82, Q = 2.1323
# True positives 993; False positives 46
# With alpha cut 8 and gammaness 0.83, Q = 2.1854
# True positives 984; False positives 43
# With alpha cut 8 and gammaness 0.84, Q = 2.2267
# True positives 979; False positives 41
# With alpha cut 8 and gammaness 0.85, Q = 2.2574
# True positives 968; False positives 39
# With alpha cut 8 and gammaness 0.86, Q = 2.2769
# True positives 951; False positives 37
# With alpha cut 8 and gammaness 0.87, Q = 2.2841
# True positives 941; False positives 36
# With alpha cut 8 and gammaness 0.88, Q = 2.2722
# True positives 923; False positives 35
# With alpha cut 8 and gammaness 0.89, Q = 2.2969
# True positives 906; False positives 33
# With alpha cut 8 and gammaness 0.90, Q = 2.3097
# True positives 883; False positives 31
# With alpha cut 8 and gammaness 0.91, Q = 2.3528
# True positives 870; False positives 29
# With alpha cut 8 and gammaness 0.92, Q = 2.4554
# True positives 843; False positives 25
# With alpha cut 8 and gammaness 0.93, Q = 2.4780
# True positives 816; False positives 23
# With alpha cut 8 and gammaness 0.94, Q = 2.6228
# True positives 785; False positives 19
# With alpha cut 8 and gammaness 0.95, Q = 2.5750
# True positives 729; False positives 17
#
#
# With alpha cut 9 and gammaness 0.80, Q = 2.2059
# True positives 1071; False positives 50
# With alpha cut 9 and gammaness 0.81, Q = 2.1956
# True positives 1066; False positives 50
# With alpha cut 9 and gammaness 0.82, Q = 2.2033
# True positives 1059; False positives 49
# With alpha cut 9 and gammaness 0.83, Q = 2.2525
# True positives 1049; False positives 46
# With alpha cut 9 and gammaness 0.84, Q = 2.2922
# True positives 1044; False positives 44
# With alpha cut 9 and gammaness 0.85, Q = 2.3191
# True positives 1032; False positives 42
# With alpha cut 9 and gammaness 0.86, Q = 2.3373
# True positives 1015; False positives 40
# With alpha cut 9 and gammaness 0.87, Q = 2.3437
# True positives 1005; False positives 39
# With alpha cut 9 and gammaness 0.88, Q = 2.3318
# True positives 987; False positives 38
# With alpha cut 9 and gammaness 0.89, Q = 2.3805
# True positives 967; False positives 35
# With alpha cut 9 and gammaness 0.90, Q = 2.3882
# True positives 942; False positives 33
# With alpha cut 9 and gammaness 0.91, Q = 2.4248
# True positives 927; False positives 31
# With alpha cut 9 and gammaness 0.92, Q = 2.5141
# True positives 897; False positives 27
# With alpha cut 9 and gammaness 0.93, Q = 2.5195
# True positives 865; False positives 25
# With alpha cut 9 and gammaness 0.94, Q = 2.6410
# True positives 831; False positives 21
# With alpha cut 9 and gammaness 0.95, Q = 2.5727
# True positives 770; False positives 19
#
#
# With alpha cut 10 and gammaness 0.80, Q = 2.2902
# True positives 1123; False positives 51
# With alpha cut 10 and gammaness 0.81, Q = 2.2779
# True positives 1117; False positives 51
# With alpha cut 10 and gammaness 0.82, Q = 2.2841
# True positives 1109; False positives 50
# With alpha cut 10 and gammaness 0.83, Q = 2.3304
# True positives 1097; False positives 47
# With alpha cut 10 and gammaness 0.84, Q = 2.3664
# True positives 1090; False positives 45
# With alpha cut 10 and gammaness 0.85, Q = 2.3920
# True positives 1077; False positives 43
# With alpha cut 10 and gammaness 0.86, Q = 2.4041
# True positives 1057; False positives 41
# With alpha cut 10 and gammaness 0.87, Q = 2.4064
# True positives 1045; False positives 40
# With alpha cut 10 and gammaness 0.88, Q = 2.3904
# True positives 1025; False positives 39
# With alpha cut 10 and gammaness 0.89, Q = 2.4370
# True positives 1004; False positives 36
# With alpha cut 10 and gammaness 0.90, Q = 2.4427
# True positives 978; False positives 34
# With alpha cut 10 and gammaness 0.91, Q = 2.4715
# True positives 960; False positives 32
# With alpha cut 10 and gammaness 0.92, Q = 2.5569
# True positives 929; False positives 28
# With alpha cut 10 and gammaness 0.93, Q = 2.5563
# True positives 895; False positives 26
# With alpha cut 10 and gammaness 0.94, Q = 2.7172
# True positives 855; False positives 21
# With alpha cut 10 and gammaness 0.95, Q = 2.6328
# True positives 788; False positives 19
#
#
# With alpha cut 11 and gammaness 0.80, Q = 2.3586
# True positives 1179; False positives 53
# With alpha cut 11 and gammaness 0.81, Q = 2.3690
# True positives 1173; False positives 52
# With alpha cut 11 and gammaness 0.82, Q = 2.3738
# True positives 1164; False positives 51
# With alpha cut 11 and gammaness 0.83, Q = 2.4216
# True positives 1152; False positives 48
# With alpha cut 11 and gammaness 0.84, Q = 2.4587
# True positives 1145; False positives 46
# With alpha cut 11 and gammaness 0.85, Q = 2.4810
# True positives 1130; False positives 44
# With alpha cut 11 and gammaness 0.86, Q = 2.4877
# True positives 1107; False positives 42
# With alpha cut 11 and gammaness 0.87, Q = 2.5169
# True positives 1093; False positives 40
# With alpha cut 11 and gammaness 0.88, Q = 2.5023
# True positives 1073; False positives 39
# With alpha cut 11 and gammaness 0.89, Q = 2.5414
# True positives 1047; False positives 36
# With alpha cut 11 and gammaness 0.90, Q = 2.5451
# True positives 1019; False positives 34
# With alpha cut 11 and gammaness 0.91, Q = 2.5668
# True positives 997; False positives 32
# With alpha cut 11 and gammaness 0.92, Q = 2.6477
# True positives 962; False positives 28
# With alpha cut 11 and gammaness 0.93, Q = 2.6420
# True positives 925; False positives 26
# With alpha cut 11 and gammaness 0.94, Q = 2.8031
# True positives 882; False positives 21
# With alpha cut 11 and gammaness 0.95, Q = 2.7130
# True positives 812; False positives 19
#
#
# With alpha cut 12 and gammaness 0.80, Q = 2.4238
# True positives 1223; False positives 54
# With alpha cut 12 and gammaness 0.81, Q = 2.4346
# True positives 1217; False positives 53
# With alpha cut 12 and gammaness 0.82, Q = 2.4397
# True positives 1208; False positives 52
# With alpha cut 12 and gammaness 0.83, Q = 2.4862
# True positives 1195; False positives 49
# With alpha cut 12 and gammaness 0.84, Q = 2.5173
# True positives 1185; False positives 47
# With alpha cut 12 and gammaness 0.85, Q = 2.5358
# True positives 1168; False positives 45
# With alpha cut 12 and gammaness 0.86, Q = 2.5363
# True positives 1142; False positives 43
# With alpha cut 12 and gammaness 0.87, Q = 2.5565
# True positives 1124; False positives 41
# With alpha cut 12 and gammaness 0.88, Q = 2.5399
# True positives 1103; False positives 40
# With alpha cut 12 and gammaness 0.89, Q = 2.5762
# True positives 1076; False positives 37
# With alpha cut 12 and gammaness 0.90, Q = 2.5750
# True positives 1046; False positives 35
# With alpha cut 12 and gammaness 0.91, Q = 2.5961
# True positives 1024; False positives 33
# With alpha cut 12 and gammaness 0.92, Q = 2.6693
# True positives 987; False positives 29
# With alpha cut 12 and gammaness 0.93, Q = 2.7048
# True positives 947; False positives 26
# With alpha cut 12 and gammaness 0.94, Q = 2.8666
# True positives 902; False positives 21
# With alpha cut 12 and gammaness 0.95, Q = 2.7631
# True positives 827; False positives 19
#
#
# With alpha cut 13 and gammaness 0.80, Q = 2.3852
# True positives 1258; False positives 59
# With alpha cut 13 and gammaness 0.81, Q = 2.4151
# True positives 1252; False positives 57
# With alpha cut 13 and gammaness 0.82, Q = 2.4191
# True positives 1243; False positives 56
# With alpha cut 13 and gammaness 0.83, Q = 2.4586
# True positives 1229; False positives 53
# With alpha cut 13 and gammaness 0.84, Q = 2.5107
# True positives 1219; False positives 50
# With alpha cut 13 and gammaness 0.85, Q = 2.5246
# True positives 1201; False positives 48
# With alpha cut 13 and gammaness 0.86, Q = 2.5209
# True positives 1174; False positives 46
# With alpha cut 13 and gammaness 0.87, Q = 2.5381
# True positives 1156; False positives 44
# With alpha cut 13 and gammaness 0.88, Q = 2.5208
# True positives 1135; False positives 43
# With alpha cut 13 and gammaness 0.89, Q = 2.5793
# True positives 1106; False positives 39
# With alpha cut 13 and gammaness 0.90, Q = 2.5738
# True positives 1075; False positives 37
# With alpha cut 13 and gammaness 0.91, Q = 2.5873
# True positives 1051; False positives 35
# With alpha cut 13 and gammaness 0.92, Q = 2.6471
# True positives 1012; False positives 31
# With alpha cut 13 and gammaness 0.93, Q = 2.6670
# True positives 969; False positives 28
# With alpha cut 13 and gammaness 0.94, Q = 2.7999
# True positives 922; False positives 23
# With alpha cut 13 and gammaness 0.95, Q = 2.6855
# True positives 845; False positives 21
#
#
# With alpha cut 14 and gammaness 0.80, Q = 2.4573
# True positives 1296; False positives 59
# With alpha cut 14 and gammaness 0.81, Q = 2.4884
# True positives 1290; False positives 57
# With alpha cut 14 and gammaness 0.82, Q = 2.4930
# True positives 1281; False positives 56
# With alpha cut 14 and gammaness 0.83, Q = 2.5346
# True positives 1267; False positives 53
# With alpha cut 14 and gammaness 0.84, Q = 2.5848
# True positives 1255; False positives 50
# With alpha cut 14 and gammaness 0.85, Q = 2.5982
# True positives 1236; False positives 48
# With alpha cut 14 and gammaness 0.86, Q = 2.5918
# True positives 1207; False positives 46
# With alpha cut 14 and gammaness 0.87, Q = 2.6061
# True positives 1187; False positives 44
# With alpha cut 14 and gammaness 0.88, Q = 2.5874
# True positives 1165; False positives 43
# With alpha cut 14 and gammaness 0.89, Q = 2.6446
# True positives 1134; False positives 39
# With alpha cut 14 and gammaness 0.90, Q = 2.6361
# True positives 1101; False positives 37
# With alpha cut 14 and gammaness 0.91, Q = 2.6488
# True positives 1076; False positives 35
# With alpha cut 14 and gammaness 0.92, Q = 2.7099
# True positives 1036; False positives 31
# With alpha cut 14 and gammaness 0.93, Q = 2.7303
# True positives 992; False positives 28
# With alpha cut 14 and gammaness 0.94, Q = 2.8667
# True positives 944; False positives 23
# With alpha cut 14 and gammaness 0.95, Q = 2.7490
# True positives 865; False positives 21

# %% [markdown]
# To handle the very few cases that return 0 false positives and thus an "infinite" Q value, we decide to consider the median of the Q values across the different iterations instead of the average. To estimate the standard deviation of the values found we ignore these cases.

# %%
test_predictions_df = pd.DataFrame(test_predictions)
test_predictions_df['Q'] = test_predictions_df['Q'].replace('inf', 1e20) # assign very high value to Q to find median
test_predictions_df.groupby(['alpha_cut', 'gamma'])['Q'].agg(
    median_Q = 'median',
    std= lambda x: np.std(x[x != 1e20])).reset_index()
# Out:
#      alpha_cut  gamma  median_Q       std
# 0            2   0.80  1.636112  0.314715
# 1            2   0.81  1.681152  0.304126
# 2            2   0.82  1.729169  0.303036
# 3            2   0.83  1.710345  0.300811
# 4            2   0.84  1.786641  0.373921
# ..         ...    ...       ...       ...
# 203         14   0.91  2.736572  0.246648
# 204         14   0.92  2.717327  0.253454
# 205         14   0.93  2.766283  0.284368
# 206         14   0.94  2.750368  0.416959
# 207         14   0.95  2.800135  0.324491
#
# [208 rows x 4 columns]

# %%
grouped_pred = test_predictions_df.groupby(['alpha_cut', 'gamma'])['Q'].agg(
    median= 'median',
    std= lambda x: np.std(x[x != 1e20]) ).reset_index()

max_mean_row = grouped_pred.loc[grouped_pred['median'].idxmax()]

max_mean = max_mean_row['median']
std_dev = max_mean_row['std']

print(f"The best average Q value found is {max_mean:.2f} ± {std_dev/(N)**0.5:.2f}")
print(f"The best Alpha cut found is {max_mean_row['alpha_cut']:.0f}° ")
print(f"The best gammaness found is {max_mean_row['gamma']:.2f}")
# Out:
# The best average Q value found is 2.89 ± 0.09
# The best Alpha cut found is 10°
# The best gammaness found is 0.95

# %%
selected = test_predictions_df[
    (test_predictions_df['gamma'] == max_mean_row['gamma']) & 
    (test_predictions_df['alpha_cut'] == max_mean_row['alpha_cut'])]

selected_gammas = selected['selected gammas']/selected['total gammas']
avg_selected_gammas= selected_gammas.mean()
std_selected_gammas= selected_gammas.std()
print(f"With these best parameters, the average fraction of selected gammas is ({avg_selected_gammas*100:.2f} ± {std_selected_gammas*100/(N)**0.5:.2f})%")
# Out:
# With these best parameters, the average fraction of selected gammas is (32.90 ± 0.41)%

# %% [markdown]
# This means that, applying this technique on the given dataset with $N_{\gamma} = 12332$ true gamma events, we would identify $n_{\gamma} = (4199 ± 1)$ events as gamma, disregarding the remaining as backgorund. In particular we have the following average performance for the algorithm in terms of TPR, FPR, TNR, FNR:

# %%
tpr = selected['true positives']/selected['total gammas']
tpr_avg = tpr.mean()

fpr = selected['false positives']/selected['total hadrons']
fpr_avg = fpr.mean()

tnr = selected['true negatives']/selected['total hadrons']
tnr_avg= tnr.mean()

fnr = selected['false negatives']/selected['total gammas']
fnr_avg= fnr.mean()

confusion_matrix = np.array([[tpr_avg, fpr_avg], [fnr_avg, tnr_avg]])

fig, ax = plt.subplots(figsize=(9, 9))
cax = ax.matshow(confusion_matrix, cmap='Blues')

ax.set_xticks([0, 1])
ax.set_xticklabels(['gamma', 'background'],fontsize=12)
ax.set_yticks([0, 1])
ax.set_yticklabels(['gamma', 'background'],fontsize=12)

path_effects_white = [path_effects.withStroke(linewidth=1.8, foreground='white')]

# Adding text with white contour
text_params = {'ha': 'center', 'va': 'center', 'color': 'black', 'fontsize': 12, 'path_effects': path_effects_white}


ax.text(0, 0, f'TPR: {tpr_avg:.3f}', ha='center', va='center', color='black',fontsize=12)
ax.text(1, 0, f'FNR: {fnr_avg:.3f}', **text_params)
ax.text(0, 1, f'FPR: {fpr_avg:.3f}', **text_params)
ax.text(1, 1, f'TNR: {tnr_avg:.3f}', **text_params)

fig.colorbar(cax)

ax.set_title('Confusion matrix of final classification strategy',fontsize=15)
ax.set_xlabel('Assigned Labels',fontsize=13.5)
ax.set_ylabel('True Labels',fontsize=13.5)

plt.show()

# %% [markdown]
# # Part 8: Calculation of the observation time

# %% [markdown]
# Assuming that the telescope has a collection area of 10^9 cm^2 and that we are observing gamma rays between 50 GeV and 50 TeV, to what observation time does this measurement corresponds? (assume here the Crab spectrum measured by HEGRA [Aharonian, F. et al. 2000])

# %% [markdown]
# ------da rivedere descrizione-------
# - da capire +- 0.5
# - da capire se vogliamo dividere il range 0.05 Tev - 50 Tev in due e usare il primo integrale per 1-50 e il secondo (log) per 0.05-1 (al momento non sono divisi)

# %% [markdown]
# To calculate the observation time corresponding to the Cherenkov telescope measurement, we use the Crab Nebula spectrum measured by HEGRA. Then, converting the telescope's collection area to square meters ( $A = 10^9 \, \text{cm}^2 = 10^5 \, \text{m}^2 $), we can determine
# the event rate by integrating the flux over the energy range from **50 GeV to 50 TeV**:
#
# $$
# R = A \cdot J_{\gamma} =  A \int_{0.05 \, TeV}^{50 \, TeV} \frac{dJ_{\gamma}}{dE} dE
# $$
#
# This integration provides the **event rate in photons per second**. Given the total number of recorded events $n_\gamma$, we can then calculate the **observation time** by dividing the number of events by the event rate:
#
# $$
# \Delta t = \frac{n_{\gamma}}{R}
# $$

# %%
# Constants
A = 10**9 * 1e-4  # collection area in m^2
E0 = 1.0  # TeV
Emin = 0.05  # TeV = 50 GeV
Emax = 50  # TeV
n_gamma, sigma_n_gamma = 4000, 200 #--------------------------------------insert our value here---------------------------

# Constants for the first integral
alpha1, alpha1_err = 2.59, 0.03
c1, c1_err = 2.79e-7, 0.02e-7

# Constants for the second integral
c2, c2_err = 2.67e-7, 0.01e-7
alpha2, alpha2_err = 2.47, 0.1
beta, beta_err = 0.11, 0.1

# %% [markdown]
# Primo integrale con errore dato da derivate parziali

# %% [markdown]
# # First integral
# According to the study by **Aharonian et al. (2000)**, the differential flux of gamma rays in the range of $1-20 \, \text{TeV}$ is given by:
#
# $$
# \frac{dJ_{\gamma}}{dE} = (2.79 \pm 0.02) \times 10^{-7} \left( \frac{E}{1 \, \text{TeV}} \right)^{(-2.59 \pm 0.03)} \, \text{ph} \, \text{m}^{-2} \, \text{s}^{-1} \, \text{TeV}^{-1}
# $$
# $$
# \frac{dJ_{\gamma}}{dE} = c_1 \cdot \left( \frac{E}{E_0} \right)^{- \alpha_1} \, \text{ph} \, \text{m}^{-2} \, \text{s}^{-1} \, \text{TeV}^{-1}
# $$
# with:
# $$
# c_1 = (2.79 \pm 0.02) \times 10^{-7}, E_0 = 1 \, \text{TeV}, \alpha_1 = 2.59 \pm 0.03
# $$
# so the integral will be:
# $$
# J_\gamma = \frac{E_0^{\alpha_1} \cdot c_1}{-\alpha_1 + 1} \cdot \left( E_{\text{max}}^{-\alpha_1 + 1} - E_{\text{min}}^{-\alpha_1 + 1} \right)
# $$
# with $E_{\text{min}} = 0.05 \, \text{TeV}, E_{\text{max}} = 50 \, \text{TeV} $

# %% [markdown]
# ### Error Propagation
#
# We have uncertainties in the following parameters:
#
# $$
# c_1 = (2.79 \pm 0.02) \times 10^{-7}
# $$
# $$
# \alpha_1 = 2.59 \pm 0.03
# $$
#
# Using the general error propagation formula the total uncertainty in R:
#
# $$
# \sigma_R = \sqrt{ \left( \frac{\partial R}{\partial c_1} \sigma_{c_1} \right)^2 + \left( \frac{\partial R}{\partial \alpha_1} \sigma_{\alpha_1} \right)^2 }
# $$
#
# The error for the time will be:
# $$
# \sigma_t = t \sqrt{ \left( \frac{\sigma_{n_{\gamma}}}{n_{\gamma}} \right)^2 + \left( \frac{\sigma_R}{R} \right)^2 }
# $$

# %%
import sympy as sp

def uncertainty(A, E0, Emin, Emax, c1, c1_err, alpha1, alpha1_err):
    #definisco i simboli
    c1_sym, alpha1_sym, Emin_sym, Emax_sym, E0_sym, A_sym = sp.symbols('c1 alpha1 Emin Emax E0 A')
    
    #definizione di R 
    R = (A_sym * c1_sym * (E0_sym**alpha1_sym) / (-alpha1_sym + 1)) * (Emax_sym**(-alpha1_sym + 1) - Emin_sym**(-alpha1_sym + 1))

    #calcolo le derivate parziali rispetto a c1 e alpha1
    dR_dc1 = sp.diff(R, c1_sym)
    dR_dalpha1 = sp.diff(R, alpha1_sym)
    
    #conversione a funzioni
    dR_dc1_func = sp.lambdify((A_sym, E0_sym, Emin_sym, Emax_sym, c1_sym, alpha1_sym), dR_dc1, 'numpy')
    dR_dalpha1_func = sp.lambdify((A_sym, E0_sym, Emin_sym, Emax_sym, c1_sym, alpha1_sym), dR_dalpha1, 'numpy')
    
    #calcolo il valore delle derivate e di R
    dR_dc1_val = dR_dc1_func(A, E0, Emin, Emax, c1, alpha1)
    dR_dalpha1_val = dR_dalpha1_func(A, E0, Emin, Emax, c1, alpha1)
    R_val = (A * c1 * (E0**alpha1) / (-alpha1 + 1)) * (Emax**(-alpha1 + 1) - Emin**(-alpha1 + 1))
    
    #incertezza totale su R
    sigma_R = np.sqrt((dR_dc1_val * c1_err) ** 2 + (dR_dalpha1_val * alpha1_err) ** 2)
    
    return R_val, sigma_R


#valore dell'errore su R
R_val, sigma_R = uncertainty(A, E0, Emin, Emax, c1, c1_err, alpha1, alpha1_err)

t1 = (n_gamma / R_val) / 60
sigma_t1 = t1 * (np.sqrt((sigma_n_gamma / n_gamma)**2 + (sigma_R/R_val)**2)) / 60

print(f"t1 = {t1:.2f} ± {sigma_t1:.2f} minutes")
# Out:
# t1 = 32.44 ± 0.05 minutes

# %% [markdown]
# ## Second integral
# At low energies there is a slight flattening of the spectrum. A fit with a logarithmic steepening of the power law spectrum gives (according to the study by **Aharonian et al. (2000)**):
# $$
# \frac{dJ_{\gamma}}{dE} = (2.67 \pm 0.01) \times 10^{-7} \left( \frac{E}{1 \, \text{TeV}} \right)^{(-2.47 \pm 0.1) -(0.11 \pm 0.1) \, \log(E)} \, \text{ph} \, \text{m}^{-2} \, \text{s}^{-1} \, \text{TeV}^{-1}
# $$
# $$
# \frac{dJ_{\gamma}}{dE} = c_2 \cdot \left( \frac{E}{E_0} \right)^{- \alpha_2 - \beta \, \log(E)} \, \text{ph} \, \text{m}^{-2} \, \text{s}^{-1} \, \text{TeV}^{-1}
# $$
# with:
# $$
# c_2 = (2.67 \pm 0.01) \times 10^{-7}, E_0 = 1 \, \text{TeV}, \alpha_2 = 2.47 \pm 0.1, \beta = 0.11 \pm 0.1
# $$
# Because of the logarithmic correction, it's impossible to integrate it analytically in a straightforward way. Hence, to calculate this integral, we use two numerical integration methods: Romberg integration and Simpson's Rule.

# %% [markdown]
# ###  Romberg integration
# usando romb - da capire
# #### using .quad

# %%
from scipy.integrate import quad

#definisco l'integranda
def dJ_gamma(E, c2, alpha2, beta):
    return c2 * (E / E0) ** (-alpha2 - beta * np.log(E))

#definisco R
def R(c2, alpha2, beta):
    integral, _ = quad(dJ_gamma, Emin, Emax, args=(c2, alpha2, beta))
    return A * integral

#Monte Carlo for the error
N = 10000
c2_mc = np.random.normal(c2, c2_err, N)
alpha2_mc = np.random.normal(alpha2, alpha2_err, N)
beta_mc = np.random.normal(beta, beta_err, N)

R_mc = np.array([R(c2, alpha2, beta) for c2, alpha2, beta in zip(c2_mc, alpha2_mc, beta_mc)])

#calcolo valor medio e errore di R
R_mean = np.mean(R_mc)
R_std = np.std(R_mc)

#propago su t
t2 = (n_gamma / R_mean)/60
sigma_t2 = t2 * (np.sqrt((sigma_n_gamma / n_gamma)**2 + (R_std/R_mean)**2)) / 60

print(f"t2 = {t2:.2f} +- {sigma_t2:.2f} minutes")
# Out:
# t2 = 66.54 +- 0.77 minutes

# %% [markdown]
# ### Simpson's Rule

# %% [markdown]
# The trapezoidal rule estimates the area under a curve by approximating the curve with straight-line segments. We can often get a
# better result if we approximate the function instead with curves of some kind, Simpson’s rule does exactly this, using quadratic curves.

# %%
import numpy as np
from scipy.integrate import simpson

n = int(10e5)
E_values = np.linspace(Emin, Emax, n)

def dJ_gamma2(E, c2, alpha2, beta):
    return c2 * (E / E0) ** (-alpha2 - beta * np.log(E))

J_gamma_values = dJ_gamma2(E_values, c2, alpha2, beta)
J_gamma = simpson(J_gamma_values, E_values)

R = A * J_gamma

def partial_derivatives():
    dJ_dc2 = J_gamma / c2
    dJ_dalpha2 = -J_gamma * np.log(E_values / E0)
    dJ_dalpha2 = simpson(dJ_dalpha2, E_values)
    dJ_dbeta = -J_gamma * np.log(E_values/E0) * np.log(E_values)
    dJ_dbeta = simpson(dJ_dbeta, E_values)

    return dJ_dc2, dJ_dalpha2, dJ_dbeta

dJ_dc2, dJ_dalpha2, dJ_dbeta = partial_derivatives()

sigma_J = np.sqrt(
    (dJ_dc2 * c2_err) ** 2 +
    (dJ_dalpha2 * alpha2_err) ** 2 +
    (dJ_dbeta * beta_err) ** 2
)

sigma_R = sigma_J

t2_s = (n_gamma / R)/60
sigma_t2_s = t2_s * (np.sqrt((sigma_n_gamma / n_gamma)**2 + (sigma_R/R)**2)) / 60

print(f"t2 = {t2_s:.2f} +- {sigma_t2_s:.2f} minutes")
# Out:
# t2 = 82.09 +- 0.07 minutes
