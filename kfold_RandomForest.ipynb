# %% [markdown]
# ## Part 5.3: Random Forest
# Here we are going to implement a Random Forest classification algorithm. A Random Forest is composed of different decision tree predictors. For each tree, at each iteration, the data are split into two branches according to a threshold value for one of the features. At each split, the best feature and the best threshold value are chosen by minimizing the entropy function
# 𝐻 given by:
# $$
# \displaystyle H = - \sum_{i=+1,-1} f_i \log_2(f_i)
# $$
# where $f_i$ is the fraction of points of class $i=+1,-1$ in the training set. The splitting continues until either a maximum depth for the tree is reached, in which case the most frequent class of the branch is assigned to all points, or the points of the branch all belong to the same class (in this case the branch is called a leaf). Different trees are built by randomly drawing data with replacement from the test set, applying the algorithm to each tree. The final label for a point is chosen based on a majority vote of the trees results.
#
# The hyper-parameters of the model are the **number of trees** and the **maximum depth** of the trees. We are going to implement a K-fold cross validation to choose as best hyper-parameters the ones that maximize the area under the ROC curve of the classifier. To build the ROC curve we need to estimate the probability for the points to belong to a certain class. This can be done because each tree, at the last decision step, assigns a class label based on the majority class of the training samples that reached that final leaf node, but also keeps track of the proportion of the classes in that leaf node. For example, suppose a test point ends up in a leaf node where, out of 100 training samples that ended up there, 80 belonged to class 1 and 20 belonged to class -1. The probability of the point belonging to class 1 would be 0.8, while the probability of it belonging to class -1 would be 0.2.
#
# We will use the class `RandomForestClassifier` from `scikit-learn` to implement and train the Forest and to predict the labels with their probabilities.
#
#
# **UTILIZZIAMO COME CRITERIO L'INTERA AREA SOTTO LA CURVA O SOLO FINO AD UNA CERTA SOGLIA DI FALSE POSITIVES??**

# %%
import time
num_trees= np.arange(40,300,10)
max_depth= np.arange(10,40,2)
accuracies=[]
roc_areas=[]
best_area=0
best_acc=0
best_model= [] # stores best number of trees and best max depth
partial_aucs = []

start_time = time.time()

max_iter = len(num_trees) * len(max_depth)
iteration = 0

K = 5
kf = KFold(n_splits=K, shuffle=True, random_state=42) 

for tree in num_trees:
    for depth in max_depth:
        ############accuracies?
        partial_auc = 0
        auc_value = 0
        accuracy = 0
        for i, (train_index, test_index) in enumerate(kf.split(X)):
            print(f"  Fold n. {i}")
            train_K=data_rescaled_and_indexed.iloc[train_idx]
            valid_K=data_rescaled_and_indexed.iloc[val_idx]
            X_train_K, Y_train_K = split_X_Y(train_K)
            X_valid_K, Y_valid_K = split_X_Y(valid_K)
            forest = RandomForestClassifier(n_estimators=tree,  # number of trees
                                           max_depth= depth, 
                                           max_features=X_train.shape[1],   # number of features for each split (random subset)
                                           bootstrap=True,    # bagging (sampling with replacement)
                                           max_samples=1.0,   # percentage of samples to use for each tree (100% of data)
                                           random_state=10,
                                           n_jobs=-1)
            # train each model, predict labels and probability of each label
            forest.fit(X_train_K, Y_train_K)
            Y_pred = forest.predict(X_valid_K)
            y_pred_prob = forest.predict_proba(X_valid_K)[:, 1] # probability for the validation points to belong to class +1 or -1
            # accuracy on validation set
            accuracy_k = accuracy_score(Y_valid_K, Y_pred)
            iteration +=1 
            print(f'elapsed time: {round(time.time()-start_time,2)}s, done {iteration} out of {max_iter}')
            print('Number of trees:',tree,', Maximum depth',depth,':') 
            print('Accuracy:',accuracy_k)
            # false positive rates and the true positive rates for different threshold values 
            fpr, tpr, thresholds = roc_curve(Y_test, y_pred_prob)
            # area under the ROC curve on validation set 
            roc_auc_k = auc(fpr, tpr)
            roc_areas.append(roc_auc_k)
            '''if(roc_auc>best_area):
                best_area= roc_auc
                best_acc= accuracy
                best_model=[tree,depth]
                '''
            partial_fpr = fpr[fpr <= 0.2]
            if (len(partial_fpr) < 2 ):
                partial_auc = 0
            else:
                partial_tpr = tpr[:len(partial_fpr)]
                partial_auc_k = auc(partial_fpr, partial_tpr)
            partial_auc += partial_auc_k/K
            auc_value += roc_auc_k/K
        
        partial_aucs.append(partial_auc)
        if(partial_auc>best_area):
            best_area= partial_auc
            best_total_auc = roc_auc
            best_acc= accuracy
            best_model=[tree,depth]
        print('Area under ROC curve:',roc_auc,'Selected area:',partial_auc,'\n')
        
print('Best number of trees:', best_model[0],'\n')
print('Best maximum depth:', best_model[1],'\n')
print('Area under ROC curve of best model:',best_area)
# Out:
#   Fold n. 0
# elapsed time: 0.44s, done 1 out of 390
# Number of trees: 40 , Maximum depth 10 :
# Accuracy: 0.8125164343938995
#   Fold n. 1
# elapsed time: 0.87s, done 2 out of 390
# Number of trees: 40 , Maximum depth 10 :
# Accuracy: 0.8125164343938995
#   Fold n. 2
# elapsed time: 1.27s, done 3 out of 390
# Number of trees: 40 , Maximum depth 10 :
# Accuracy: 0.8125164343938995
#   Fold n. 3
# elapsed time: 1.66s, done 4 out of 390
# Number of trees: 40 , Maximum depth 10 :
# Accuracy: 0.8125164343938995
#   Fold n. 4
# elapsed time: 2.03s, done 5 out of 390
# Number of trees: 40 , Maximum depth 10 :
# Accuracy: 0.8125164343938995
# Area under ROC curve: 0.8638111382393521 Selected area: 0.09767014902808546
#
#   Fold n. 0
# elapsed time: 2.47s, done 6 out of 390
# Number of trees: 40 , Maximum depth 12 :
# Accuracy: 0.8161977386273994
#   Fold n. 1
# elapsed time: 2.9s, done 7 out of 390
# Number of trees: 40 , Maximum depth 12 :
# Accuracy: 0.8161977386273994
#   Fold n. 2
# elapsed time: 3.31s, done 8 out of 390
# Number of trees: 40 , Maximum depth 12 :
# Accuracy: 0.8161977386273994
#   Fold n. 3
# elapsed time: 3.75s, done 9 out of 390
# Number of trees: 40 , Maximum depth 12 :
# Accuracy: 0.8161977386273994
#   Fold n. 4
# elapsed time: 4.2s, done 10 out of 390
# Number of trees: 40 , Maximum depth 12 :
# Accuracy: 0.8161977386273994
# Area under ROC curve: 0.8745217506722871 Selected area: 0.10477454725531907
#
#   Fold n. 0
# elapsed time: 4.66s, done 11 out of 390
# Number of trees: 40 , Maximum depth 14 :
# Accuracy: 0.8214567446752564
#   Fold n. 1
# elapsed time: 5.12s, done 12 out of 390
# Number of trees: 40 , Maximum depth 14 :
# Accuracy: 0.8214567446752564
#   Fold n. 2
# elapsed time: 5.56s, done 13 out of 390
# Number of trees: 40 , Maximum depth 14 :
# Accuracy: 0.8214567446752564
#   Fold n. 3
# elapsed time: 6.03s, done 14 out of 390
# Number of trees: 40 , Maximum depth 14 :
# Accuracy: 0.8214567446752564
#   Fold n. 4
# elapsed time: 6.51s, done 15 out of 390
# Number of trees: 40 , Maximum depth 14 :
# Accuracy: 0.8214567446752564
# Area under ROC curve: 0.8770257891560312 Selected area: 0.1062055751907938
#
#   Fold n. 0
# elapsed time: 7.03s, done 16 out of 390
# Number of trees: 40 , Maximum depth 16 :
# Accuracy: 0.8246121483039706
#   Fold n. 1
# elapsed time: 7.52s, done 17 out of 390
# Number of trees: 40 , Maximum depth 16 :
# Accuracy: 0.8246121483039706
#   Fold n. 2
# elapsed time: 8.08s, done 18 out of 390
# Number of trees: 40 , Maximum depth 16 :
# Accuracy: 0.8246121483039706
#   Fold n. 3
# elapsed time: 8.63s, done 19 out of 390
# Number of trees: 40 , Maximum depth 16 :
# Accuracy: 0.8246121483039706
#   Fold n. 4
# elapsed time: 9.19s, done 20 out of 390
# Number of trees: 40 , Maximum depth 16 :
# Accuracy: 0.8246121483039706
# Area under ROC curve: 0.8787690034914879 Selected area: 0.10750744307136659
#
#   Fold n. 0
# elapsed time: 9.79s, done 21 out of 390
# Number of trees: 40 , Maximum depth 18 :
# Accuracy: 0.8222455955824349
#   Fold n. 1
# elapsed time: 10.41s, done 22 out of 390
# Number of trees: 40 , Maximum depth 18 :
# Accuracy: 0.8222455955824349
#   Fold n. 2
# elapsed time: 11.01s, done 23 out of 390
# Number of trees: 40 , Maximum depth 18 :
# Accuracy: 0.8222455955824349
#   Fold n. 3
# elapsed time: 11.61s, done 24 out of 390
# Number of trees: 40 , Maximum depth 18 :
# Accuracy: 0.8222455955824349
#   Fold n. 4
# elapsed time: 12.2s, done 25 out of 390
# Number of trees: 40 , Maximum depth 18 :
# Accuracy: 0.8222455955824349
# Area under ROC curve: 0.8797475248290861 Selected area: 0.10821588894854191
#
#   Fold n. 0
# elapsed time: 12.82s, done 26 out of 390
# Number of trees: 40 , Maximum depth 20 :
# Accuracy: 0.8254009992111491
#   Fold n. 1
# elapsed time: 13.56s, done 27 out of 390
# Number of trees: 40 , Maximum depth 20 :
# Accuracy: 0.8254009992111491
#   Fold n. 2
# elapsed time: 14.17s, done 28 out of 390
# Number of trees: 40 , Maximum depth 20 :
# Accuracy: 0.8254009992111491
#   Fold n. 3
# elapsed time: 14.81s, done 29 out of 390
# Number of trees: 40 , Maximum depth 20 :
# Accuracy: 0.8254009992111491
#   Fold n. 4
# elapsed time: 15.43s, done 30 out of 390
# Number of trees: 40 , Maximum depth 20 :
# Accuracy: 0.8254009992111491
# Area under ROC curve: 0.8793316235002255 Selected area: 0.10768600535924944
#
#   Fold n. 0
# elapsed time: 16.09s, done 31 out of 390
# Number of trees: 40 , Maximum depth 22 :
# Accuracy: 0.8232973967920063
#   Fold n. 1
# elapsed time: 16.75s, done 32 out of 390
# Number of trees: 40 , Maximum depth 22 :
# Accuracy: 0.8232973967920063
#   Fold n. 2
# elapsed time: 17.41s, done 33 out of 390
# Number of trees: 40 , Maximum depth 22 :
# Accuracy: 0.8232973967920063
#   Fold n. 3
# elapsed time: 18.05s, done 34 out of 390
# Number of trees: 40 , Maximum depth 22 :
# Accuracy: 0.8232973967920063
#   Fold n. 4
# elapsed time: 18.71s, done 35 out of 390
# Number of trees: 40 , Maximum depth 22 :
# Accuracy: 0.8232973967920063
# Area under ROC curve: 0.8799219206635851 Selected area: 0.10685717873965973
#
#   Fold n. 0
# elapsed time: 19.35s, done 36 out of 390
# Number of trees: 40 , Maximum depth 24 :
# Accuracy: 0.8272416513278991
#   Fold n. 1
# elapsed time: 20.02s, done 37 out of 390
# Number of trees: 40 , Maximum depth 24 :
# Accuracy: 0.8272416513278991
#   Fold n. 2
# elapsed time: 20.71s, done 38 out of 390
# Number of trees: 40 , Maximum depth 24 :
# Accuracy: 0.8272416513278991
#   Fold n. 3
# elapsed time: 21.38s, done 39 out of 390
# Number of trees: 40 , Maximum depth 24 :
# Accuracy: 0.8272416513278991
#   Fold n. 4
# elapsed time: 22.06s, done 40 out of 390
# Number of trees: 40 , Maximum depth 24 :
# Accuracy: 0.8272416513278991
# Area under ROC curve: 0.8794095956992679 Selected area: 0.10709273215775858
#
#   Fold n. 0
# elapsed time: 22.72s, done 41 out of 390
# Number of trees: 40 , Maximum depth 26 :
# Accuracy: 0.8259268998159348
#   Fold n. 1
# elapsed time: 23.41s, done 42 out of 390
# Number of trees: 40 , Maximum depth 26 :
# Accuracy: 0.8259268998159348
#   Fold n. 2
# elapsed time: 24.05s, done 43 out of 390
# Number of trees: 40 , Maximum depth 26 :
# Accuracy: 0.8259268998159348
#   Fold n. 3
# elapsed time: 23.85s, done 44 out of 390
# Number of trees: 40 , Maximum depth 26 :
# Accuracy: 0.8259268998159348
#   Fold n. 4
# elapsed time: 24.52s, done 45 out of 390
# Number of trees: 40 , Maximum depth 26 :
# Accuracy: 0.8259268998159348
# Area under ROC curve: 0.8799293607589136 Selected area: 0.10778957148622152
#
#   Fold n. 0
# elapsed time: 25.21s, done 46 out of 390
# Number of trees: 40 , Maximum depth 28 :
# Accuracy: 0.8269787010255062
#   Fold n. 1
# elapsed time: 25.9s, done 47 out of 390
# Number of trees: 40 , Maximum depth 28 :
# Accuracy: 0.8269787010255062
#   Fold n. 2
# elapsed time: 26.6s, done 48 out of 390
# Number of trees: 40 , Maximum depth 28 :
# Accuracy: 0.8269787010255062
#   Fold n. 3
# elapsed time: 27.29s, done 49 out of 390
# Number of trees: 40 , Maximum depth 28 :
# Accuracy: 0.8269787010255062
#   Fold n. 4
# elapsed time: 27.97s, done 50 out of 390
# Number of trees: 40 , Maximum depth 28 :
# Accuracy: 0.8269787010255062
# Area under ROC curve: 0.880342881257269 Selected area: 0.10790087531233519
#
#   Fold n. 0
# elapsed time: 28.66s, done 51 out of 390
# Number of trees: 40 , Maximum depth 30 :
# Accuracy: 0.8285564028398633
#   Fold n. 1
# elapsed time: 29.36s, done 52 out of 390
# Number of trees: 40 , Maximum depth 30 :
# Accuracy: 0.8285564028398633
#   Fold n. 2
# elapsed time: 30.04s, done 53 out of 390
# Number of trees: 40 , Maximum depth 30 :
# Accuracy: 0.8285564028398633
#   Fold n. 3
# elapsed time: 30.73s, done 54 out of 390
# Number of trees: 40 , Maximum depth 30 :
# Accuracy: 0.8285564028398633
#   Fold n. 4
# elapsed time: 31.42s, done 55 out of 390
# Number of trees: 40 , Maximum depth 30 :
# Accuracy: 0.8285564028398633
# Area under ROC curve: 0.8798458828893284 Selected area: 0.1055782263526986
#
#   Fold n. 0
# elapsed time: 32.13s, done 56 out of 390
# Number of trees: 40 , Maximum depth 32 :
# Accuracy: 0.8280305022350776
#   Fold n. 1
# elapsed time: 32.8s, done 57 out of 390
# Number of trees: 40 , Maximum depth 32 :
# Accuracy: 0.8280305022350776
#   Fold n. 2
# elapsed time: 33.49s, done 58 out of 390
# Number of trees: 40 , Maximum depth 32 :
# Accuracy: 0.8280305022350776
#   Fold n. 3
# elapsed time: 34.19s, done 59 out of 390
# Number of trees: 40 , Maximum depth 32 :
# Accuracy: 0.8280305022350776
#   Fold n. 4
# elapsed time: 34.87s, done 60 out of 390
# Number of trees: 40 , Maximum depth 32 :
# Accuracy: 0.8280305022350776
# Area under ROC curve: 0.8801579204874036 Selected area: 0.10793376053368696
#
#   Fold n. 0
# elapsed time: 35.54s, done 61 out of 390
# Number of trees: 40 , Maximum depth 34 :
# Accuracy: 0.8269787010255062
#   Fold n. 1
# elapsed time: 36.23s, done 62 out of 390
# Number of trees: 40 , Maximum depth 34 :
# Accuracy: 0.8269787010255062
#   Fold n. 2
# elapsed time: 36.91s, done 63 out of 390
# Number of trees: 40 , Maximum depth 34 :
# Accuracy: 0.8269787010255062
#   Fold n. 3
# elapsed time: 37.63s, done 64 out of 390
# Number of trees: 40 , Maximum depth 34 :
# Accuracy: 0.8269787010255062
#   Fold n. 4
# elapsed time: 38.31s, done 65 out of 390
# Number of trees: 40 , Maximum depth 34 :
# Accuracy: 0.8269787010255062
# Area under ROC curve: 0.8794334040043189 Selected area: 0.10545576238359226
#
#   Fold n. 0
# elapsed time: 39.02s, done 66 out of 390
# Number of trees: 40 , Maximum depth 36 :
# Accuracy: 0.8296082040494347
#   Fold n. 1
# elapsed time: 39.71s, done 67 out of 390
# Number of trees: 40 , Maximum depth 36 :
# Accuracy: 0.8296082040494347
#   Fold n. 2
# elapsed time: 40.4s, done 68 out of 390
# Number of trees: 40 , Maximum depth 36 :
# Accuracy: 0.8296082040494347
#   Fold n. 3
# elapsed time: 41.13s, done 69 out of 390
# Number of trees: 40 , Maximum depth 36 :
# Accuracy: 0.8296082040494347
#   Fold n. 4
# elapsed time: 41.84s, done 70 out of 390
# Number of trees: 40 , Maximum depth 36 :
# Accuracy: 0.8296082040494347
# Area under ROC curve: 0.8797543697167884 Selected area: 0.10411907485688232
#
#   Fold n. 0
# elapsed time: 42.52s, done 71 out of 390
# Number of trees: 40 , Maximum depth 38 :
# Accuracy: 0.8282934525374704
#   Fold n. 1
# elapsed time: 43.2s, done 72 out of 390
# Number of trees: 40 , Maximum depth 38 :
# Accuracy: 0.8282934525374704
#   Fold n. 2
# elapsed time: 43.89s, done 73 out of 390
# Number of trees: 40 , Maximum depth 38 :
# Accuracy: 0.8282934525374704
#   Fold n. 3
# elapsed time: 44.6s, done 74 out of 390
# Number of trees: 40 , Maximum depth 38 :
# Accuracy: 0.8282934525374704
#   Fold n. 4
# elapsed time: 45.3s, done 75 out of 390
# Number of trees: 40 , Maximum depth 38 :
# Accuracy: 0.8282934525374704
# Area under ROC curve: 0.8797549649244146 Selected area: 0.10199567165014171
#
#   Fold n. 0
# elapsed time: 45.86s, done 76 out of 390
# Number of trees: 50 , Maximum depth 10 :
# Accuracy: 0.8135682356034709
#   Fold n. 1
# elapsed time: 46.4s, done 77 out of 390
# Number of trees: 50 , Maximum depth 10 :
# Accuracy: 0.8135682356034709
#   Fold n. 2
# elapsed time: 46.95s, done 78 out of 390
# Number of trees: 50 , Maximum depth 10 :
# Accuracy: 0.8135682356034709
#   Fold n. 3
# elapsed time: 47.5s, done 79 out of 390
# Number of trees: 50 , Maximum depth 10 :
# Accuracy: 0.8135682356034709
#   Fold n. 4
# elapsed time: 48.04s, done 80 out of 390
# Number of trees: 50 , Maximum depth 10 :
# Accuracy: 0.8135682356034709
# Area under ROC curve: 0.8647305852200423 Selected area: 0.09889255669055036
#
#   Fold n. 0
# elapsed time: 48.65s, done 81 out of 390
# Number of trees: 50 , Maximum depth 12 :
# Accuracy: 0.8156718380226137
#   Fold n. 1
# elapsed time: 49.24s, done 82 out of 390
# Number of trees: 50 , Maximum depth 12 :
# Accuracy: 0.8156718380226137
#   Fold n. 2
# elapsed time: 49.83s, done 83 out of 390
# Number of trees: 50 , Maximum depth 12 :
# Accuracy: 0.8156718380226137
#   Fold n. 3
# elapsed time: 50.5s, done 84 out of 390
# Number of trees: 50 , Maximum depth 12 :
# Accuracy: 0.8156718380226137
#   Fold n. 4
# elapsed time: 51.1s, done 85 out of 390
# Number of trees: 50 , Maximum depth 12 :
# Accuracy: 0.8156718380226137
# Area under ROC curve: 0.8744814253556067 Selected area: 0.10226217586480692
#
#   Fold n. 0
# elapsed time: 51.75s, done 86 out of 390
# Number of trees: 50 , Maximum depth 14 :
# Accuracy: 0.8196160925585064
#   Fold n. 1
# elapsed time: 52.41s, done 87 out of 390
# Number of trees: 50 , Maximum depth 14 :
# Accuracy: 0.8196160925585064
#   Fold n. 2
# elapsed time: 53.17s, done 88 out of 390
# Number of trees: 50 , Maximum depth 14 :
# Accuracy: 0.8196160925585064
#   Fold n. 3
# elapsed time: 53.86s, done 89 out of 390
# Number of trees: 50 , Maximum depth 14 :
# Accuracy: 0.8196160925585064
#   Fold n. 4
# elapsed time: 54.52s, done 90 out of 390
# Number of trees: 50 , Maximum depth 14 :
# Accuracy: 0.8196160925585064
# Area under ROC curve: 0.8771330753306675 Selected area: 0.1064571992148021
#
#   Fold n. 0
# elapsed time: 55.3s, done 91 out of 390
# Number of trees: 50 , Maximum depth 16 :
# Accuracy: 0.8246121483039706
#   Fold n. 1
# elapsed time: 55.18s, done 92 out of 390
# Number of trees: 50 , Maximum depth 16 :
# Accuracy: 0.8246121483039706
#   Fold n. 2
# elapsed time: 55.91s, done 93 out of 390
# Number of trees: 50 , Maximum depth 16 :
# Accuracy: 0.8246121483039706
#   Fold n. 3
# elapsed time: 56.61s, done 94 out of 390
# Number of trees: 50 , Maximum depth 16 :
# Accuracy: 0.8246121483039706
#   Fold n. 4
# elapsed time: 57.32s, done 95 out of 390
# Number of trees: 50 , Maximum depth 16 :
# Accuracy: 0.8246121483039706
# Area under ROC curve: 0.8785911852131376 Selected area: 0.10715850260046211
#
#   Fold n. 0
# elapsed time: 58.09s, done 96 out of 390
# Number of trees: 50 , Maximum depth 18 :
# Accuracy: 0.8248750986063634
#   Fold n. 1
# elapsed time: 58.82s, done 97 out of 390
# Number of trees: 50 , Maximum depth 18 :
# Accuracy: 0.8248750986063634
#   Fold n. 2
# elapsed time: 59.58s, done 98 out of 390
# Number of trees: 50 , Maximum depth 18 :
# Accuracy: 0.8248750986063634
#   Fold n. 3
# elapsed time: 60.34s, done 99 out of 390
# Number of trees: 50 , Maximum depth 18 :
# Accuracy: 0.8248750986063634
#   Fold n. 4
# elapsed time: 61.08s, done 100 out of 390
# Number of trees: 50 , Maximum depth 18 :
# Accuracy: 0.8248750986063634
# Area under ROC curve: 0.8808627951188214 Selected area: 0.10860441072659374
#
#   Fold n. 0
# elapsed time: 61.94s, done 101 out of 390
# Number of trees: 50 , Maximum depth 20 :
# Accuracy: 0.8259268998159348
#   Fold n. 1
# elapsed time: 62.78s, done 102 out of 390
# Number of trees: 50 , Maximum depth 20 :
# Accuracy: 0.8259268998159348
#   Fold n. 2
# elapsed time: 63.6s, done 103 out of 390
# Number of trees: 50 , Maximum depth 20 :
# Accuracy: 0.8259268998159348
#   Fold n. 3
# elapsed time: 64.43s, done 104 out of 390
# Number of trees: 50 , Maximum depth 20 :
# Accuracy: 0.8259268998159348
#   Fold n. 4
# elapsed time: 65.23s, done 105 out of 390
# Number of trees: 50 , Maximum depth 20 :
# Accuracy: 0.8259268998159348
# Area under ROC curve: 0.8803915394807171 Selected area: 0.10820889525893317
#
#   Fold n. 0
# elapsed time: 66.05s, done 106 out of 390
# Number of trees: 50 , Maximum depth 22 :
# Accuracy: 0.8261898501183277
#   Fold n. 1
# elapsed time: 66.94s, done 107 out of 390
# Number of trees: 50 , Maximum depth 22 :
# Accuracy: 0.8261898501183277
#   Fold n. 2
# elapsed time: 67.78s, done 108 out of 390
# Number of trees: 50 , Maximum depth 22 :
# Accuracy: 0.8261898501183277
#   Fold n. 3
# elapsed time: 68.66s, done 109 out of 390
# Number of trees: 50 , Maximum depth 22 :
# Accuracy: 0.8261898501183277
#   Fold n. 4
# elapsed time: 69.51s, done 110 out of 390
# Number of trees: 50 , Maximum depth 22 :
# Accuracy: 0.8261898501183277
# Area under ROC curve: 0.8814889535416639 Selected area: 0.10885454673153638
#
#   Fold n. 0
# elapsed time: 70.53s, done 111 out of 390
# Number of trees: 50 , Maximum depth 24 :
# Accuracy: 0.829082303444649
#   Fold n. 1
# elapsed time: 71.5s, done 112 out of 390
# Number of trees: 50 , Maximum depth 24 :
# Accuracy: 0.829082303444649
#   Fold n. 2
# elapsed time: 72.48s, done 113 out of 390
# Number of trees: 50 , Maximum depth 24 :
# Accuracy: 0.829082303444649
#   Fold n. 3
# elapsed time: 73.5s, done 114 out of 390
# Number of trees: 50 , Maximum depth 24 :
# Accuracy: 0.829082303444649
#   Fold n. 4
# elapsed time: 74.46s, done 115 out of 390
# Number of trees: 50 , Maximum depth 24 :
# Accuracy: 0.829082303444649
# Area under ROC curve: 0.8807482176507632 Selected area: 0.10791024983244904
#
#   Fold n. 0
# elapsed time: 75.45s, done 116 out of 390
# Number of trees: 50 , Maximum depth 26 :
# Accuracy: 0.8272416513278991
#   Fold n. 1
# elapsed time: 76.42s, done 117 out of 390
# Number of trees: 50 , Maximum depth 26 :
# Accuracy: 0.8272416513278991
#   Fold n. 2
# elapsed time: 77.37s, done 118 out of 390
# Number of trees: 50 , Maximum depth 26 :
# Accuracy: 0.8272416513278991
#   Fold n. 3
# elapsed time: 78.32s, done 119 out of 390
# Number of trees: 50 , Maximum depth 26 :
# Accuracy: 0.8272416513278991
#   Fold n. 4
# elapsed time: 79.4s, done 120 out of 390
# Number of trees: 50 , Maximum depth 26 :
# Accuracy: 0.8272416513278991
# Area under ROC curve: 0.8810712665899247 Selected area: 0.10843566936454443
#
#   Fold n. 0
# elapsed time: 80.51s, done 121 out of 390
# Number of trees: 50 , Maximum depth 28 :
# Accuracy: 0.8261898501183277
#   Fold n. 1
# elapsed time: 81.54s, done 122 out of 390
# Number of trees: 50 , Maximum depth 28 :
# Accuracy: 0.8261898501183277
#   Fold n. 2
# elapsed time: 82.66s, done 123 out of 390
# Number of trees: 50 , Maximum depth 28 :
# Accuracy: 0.8261898501183277
#   Fold n. 3
# elapsed time: 83.67s, done 124 out of 390
# Number of trees: 50 , Maximum depth 28 :
# Accuracy: 0.8261898501183277
#   Fold n. 4
# elapsed time: 84.63s, done 125 out of 390
# Number of trees: 50 , Maximum depth 28 :
# Accuracy: 0.8261898501183277
# Area under ROC curve: 0.8821993338436246 Selected area: 0.10803836827400501
#
#   Fold n. 0
# elapsed time: 85.63s, done 126 out of 390
# Number of trees: 50 , Maximum depth 30 :
# Accuracy: 0.8298711543518275
#   Fold n. 1
# elapsed time: 86.61s, done 127 out of 390
# Number of trees: 50 , Maximum depth 30 :
# Accuracy: 0.8298711543518275
#   Fold n. 2
# elapsed time: 86.76s, done 128 out of 390
# Number of trees: 50 , Maximum depth 30 :
# Accuracy: 0.8298711543518275
#   Fold n. 3
# elapsed time: 87.75s, done 129 out of 390
# Number of trees: 50 , Maximum depth 30 :
# Accuracy: 0.8298711543518275
#   Fold n. 4
# elapsed time: 88.76s, done 130 out of 390
# Number of trees: 50 , Maximum depth 30 :
# Accuracy: 0.8298711543518275
# Area under ROC curve: 0.8811807847931594 Selected area: 0.10577821611512744
#
#   Fold n. 0
# elapsed time: 89.75s, done 131 out of 390
# Number of trees: 50 , Maximum depth 32 :
# Accuracy: 0.8282934525374704
#   Fold n. 1
# elapsed time: 90.79s, done 132 out of 390
# Number of trees: 50 , Maximum depth 32 :
# Accuracy: 0.8282934525374704
#   Fold n. 2
# elapsed time: 91.76s, done 133 out of 390
# Number of trees: 50 , Maximum depth 32 :
# Accuracy: 0.8282934525374704
#   Fold n. 3
# elapsed time: 92.78s, done 134 out of 390
# Number of trees: 50 , Maximum depth 32 :
# Accuracy: 0.8282934525374704
#   Fold n. 4
# elapsed time: 93.78s, done 135 out of 390
# Number of trees: 50 , Maximum depth 32 :
# Accuracy: 0.8282934525374704
# Area under ROC curve: 0.8817960806768225 Selected area: 0.10191546742250099
#
#   Fold n. 0
# elapsed time: 94.8s, done 136 out of 390
# Number of trees: 50 , Maximum depth 34 :
# Accuracy: 0.8296082040494347
#   Fold n. 1
# elapsed time: 95.68s, done 137 out of 390
# Number of trees: 50 , Maximum depth 34 :
# Accuracy: 0.8296082040494347
#   Fold n. 2
# elapsed time: 96.55s, done 138 out of 390
# Number of trees: 50 , Maximum depth 34 :
# Accuracy: 0.8296082040494347
#   Fold n. 3
# elapsed time: 97.42s, done 139 out of 390
# Number of trees: 50 , Maximum depth 34 :
# Accuracy: 0.8296082040494347
#   Fold n. 4
# elapsed time: 98.29s, done 140 out of 390
# Number of trees: 50 , Maximum depth 34 :
# Accuracy: 0.8296082040494347
# Area under ROC curve: 0.8812328654604585 Selected area: 0.10133097353349768
#
#   Fold n. 0
# elapsed time: 99.23s, done 141 out of 390
# Number of trees: 50 , Maximum depth 36 :
# Accuracy: 0.8301341046542203
#   Fold n. 1
# elapsed time: 100.14s, done 142 out of 390
# Number of trees: 50 , Maximum depth 36 :
# Accuracy: 0.8301341046542203
#   Fold n. 2
# elapsed time: 101.04s, done 143 out of 390
# Number of trees: 50 , Maximum depth 36 :
# Accuracy: 0.8301341046542203
#   Fold n. 3
# elapsed time: 101.94s, done 144 out of 390
# Number of trees: 50 , Maximum depth 36 :
# Accuracy: 0.8301341046542203
#   Fold n. 4
# elapsed time: 102.8s, done 145 out of 390
# Number of trees: 50 , Maximum depth 36 :
# Accuracy: 0.8301341046542203
# Area under ROC curve: 0.8812227469308119 Selected area: 0.09881056684003081
#
#   Fold n. 0
# elapsed time: 103.68s, done 146 out of 390
# Number of trees: 50 , Maximum depth 38 :
# Accuracy: 0.8277675519326847
#   Fold n. 1
# elapsed time: 104.59s, done 147 out of 390
# Number of trees: 50 , Maximum depth 38 :
# Accuracy: 0.8277675519326847
#   Fold n. 2
# elapsed time: 105.61s, done 148 out of 390
# Number of trees: 50 , Maximum depth 38 :
# Accuracy: 0.8277675519326847
#   Fold n. 3
# elapsed time: 106.68s, done 149 out of 390
# Number of trees: 50 , Maximum depth 38 :
# Accuracy: 0.8277675519326847
#   Fold n. 4
# elapsed time: 107.74s, done 150 out of 390
# Number of trees: 50 , Maximum depth 38 :
# Accuracy: 0.8277675519326847
# Area under ROC curve: 0.8812825652972526 Selected area: 0.10149019157352661
#
#   Fold n. 0
# elapsed time: 108.55s, done 151 out of 390
# Number of trees: 60 , Maximum depth 10 :
# Accuracy: 0.8148829871154352
#   Fold n. 1
# elapsed time: 109.3s, done 152 out of 390
# Number of trees: 60 , Maximum depth 10 :
# Accuracy: 0.8148829871154352
#   Fold n. 2
# elapsed time: 110.02s, done 153 out of 390
# Number of trees: 60 , Maximum depth 10 :
# Accuracy: 0.8148829871154352
#   Fold n. 3
# elapsed time: 110.81s, done 154 out of 390
# Number of trees: 60 , Maximum depth 10 :
# Accuracy: 0.8148829871154352
#   Fold n. 4
# elapsed time: 111.62s, done 155 out of 390
# Number of trees: 60 , Maximum depth 10 :
# Accuracy: 0.8148829871154352
# Area under ROC curve: 0.8652119593877934 Selected area: 0.09881458449150818
#
#   Fold n. 0
# elapsed time: 112.54s, done 156 out of 390
# Number of trees: 60 , Maximum depth 12 :
# Accuracy: 0.8180383907441493
#   Fold n. 1
# elapsed time: 113.4s, done 157 out of 390
# Number of trees: 60 , Maximum depth 12 :
# Accuracy: 0.8180383907441493
#   Fold n. 2
# elapsed time: 114.45s, done 158 out of 390
# Number of trees: 60 , Maximum depth 12 :
# Accuracy: 0.8180383907441493
#   Fold n. 3
# elapsed time: 115.5s, done 159 out of 390
# Number of trees: 60 , Maximum depth 12 :
# Accuracy: 0.8180383907441493
#   Fold n. 4
# elapsed time: 116.61s, done 160 out of 390
# Number of trees: 60 , Maximum depth 12 :
# Accuracy: 0.8180383907441493
# Area under ROC curve: 0.8750620503950393 Selected area: 0.10520681679390222
#
#   Fold n. 0
# elapsed time: 117.68s, done 161 out of 390
# Number of trees: 60 , Maximum depth 14 :
# Accuracy: 0.8193531422561136
#   Fold n. 1
# elapsed time: 117.71s, done 162 out of 390
# Number of trees: 60 , Maximum depth 14 :
# Accuracy: 0.8193531422561136
#   Fold n. 2
# elapsed time: 118.76s, done 163 out of 390
# Number of trees: 60 , Maximum depth 14 :
# Accuracy: 0.8193531422561136
#   Fold n. 3
# elapsed time: 119.67s, done 164 out of 390
# Number of trees: 60 , Maximum depth 14 :
# Accuracy: 0.8193531422561136
#   Fold n. 4
# elapsed time: 120.59s, done 165 out of 390
# Number of trees: 60 , Maximum depth 14 :
# Accuracy: 0.8193531422561136
# Area under ROC curve: 0.8773047927308483 Selected area: 0.10465446411671783
#
#   Fold n. 0
# elapsed time: 121.4s, done 166 out of 390
# Number of trees: 60 , Maximum depth 16 :
# Accuracy: 0.8261898501183277
#   Fold n. 1
# elapsed time: 122.39s, done 167 out of 390
# Number of trees: 60 , Maximum depth 16 :
# Accuracy: 0.8261898501183277
#   Fold n. 2
# elapsed time: 123.32s, done 168 out of 390
# Number of trees: 60 , Maximum depth 16 :
# Accuracy: 0.8261898501183277
#   Fold n. 3
# elapsed time: 124.15s, done 169 out of 390
# Number of trees: 60 , Maximum depth 16 :
# Accuracy: 0.8261898501183277
#   Fold n. 4
# elapsed time: 125.06s, done 170 out of 390
# Number of trees: 60 , Maximum depth 16 :
# Accuracy: 0.8261898501183277
# Area under ROC curve: 0.8789048596321855 Selected area: 0.10703841946186088
#
#   Fold n. 0
# elapsed time: 126.39s, done 171 out of 390
# Number of trees: 60 , Maximum depth 18 :
# Accuracy: 0.8267157507231133
#   Fold n. 1
# elapsed time: 127.59s, done 172 out of 390
# Number of trees: 60 , Maximum depth 18 :
# Accuracy: 0.8267157507231133
#   Fold n. 2
# elapsed time: 128.79s, done 173 out of 390
# Number of trees: 60 , Maximum depth 18 :
# Accuracy: 0.8267157507231133
#   Fold n. 3
# elapsed time: 129.81s, done 174 out of 390
# Number of trees: 60 , Maximum depth 18 :
# Accuracy: 0.8267157507231133
#   Fold n. 4
# elapsed time: 130.65s, done 175 out of 390
# Number of trees: 60 , Maximum depth 18 :
# Accuracy: 0.8267157507231133
# Area under ROC curve: 0.8818497981650939 Selected area: 0.10898683162647625
#
#   Fold n. 0
# elapsed time: 131.53s, done 176 out of 390
# Number of trees: 60 , Maximum depth 20 :
# Accuracy: 0.8243491980015777
#   Fold n. 1
# elapsed time: 132.55s, done 177 out of 390
# Number of trees: 60 , Maximum depth 20 :
# Accuracy: 0.8243491980015777
#   Fold n. 2
# elapsed time: 133.59s, done 178 out of 390
# Number of trees: 60 , Maximum depth 20 :
# Accuracy: 0.8243491980015777
#   Fold n. 3
# elapsed time: 134.67s, done 179 out of 390
# Number of trees: 60 , Maximum depth 20 :
# Accuracy: 0.8243491980015777
#   Fold n. 4
# elapsed time: 135.86s, done 180 out of 390
# Number of trees: 60 , Maximum depth 20 :
# Accuracy: 0.8243491980015777
# Area under ROC curve: 0.8810398693876385 Selected area: 0.10816380828124275
#
#   Fold n. 0
# elapsed time: 136.97s, done 181 out of 390
# Number of trees: 60 , Maximum depth 22 :
# Accuracy: 0.8261898501183277
#   Fold n. 1
# elapsed time: 138.08s, done 182 out of 390
# Number of trees: 60 , Maximum depth 22 :
# Accuracy: 0.8261898501183277
#   Fold n. 2
# elapsed time: 139.09s, done 183 out of 390
# Number of trees: 60 , Maximum depth 22 :
# Accuracy: 0.8261898501183277
#   Fold n. 3
# elapsed time: 139.97s, done 184 out of 390
# Number of trees: 60 , Maximum depth 22 :
# Accuracy: 0.8261898501183277
#   Fold n. 4
# elapsed time: 140.92s, done 185 out of 390
# Number of trees: 60 , Maximum depth 22 :
# Accuracy: 0.8261898501183277
# Area under ROC curve: 0.8817602194173393 Selected area: 0.10866720513116589
#
#   Fold n. 0
# elapsed time: 141.91s, done 186 out of 390
# Number of trees: 60 , Maximum depth 24 :
# Accuracy: 0.8285564028398633
#   Fold n. 1
# elapsed time: 142.97s, done 187 out of 390
# Number of trees: 60 , Maximum depth 24 :
# Accuracy: 0.8285564028398633
#   Fold n. 2
# elapsed time: 144.06s, done 188 out of 390
# Number of trees: 60 , Maximum depth 24 :
# Accuracy: 0.8285564028398633
#   Fold n. 3
# elapsed time: 145.18s, done 189 out of 390
# Number of trees: 60 , Maximum depth 24 :
# Accuracy: 0.8285564028398633
#   Fold n. 4
# elapsed time: 146.24s, done 190 out of 390
# Number of trees: 60 , Maximum depth 24 :
# Accuracy: 0.8285564028398633
# Area under ROC curve: 0.8815951981029542 Selected area: 0.10821335931613023
#
#   Fold n. 0
# elapsed time: 147.37s, done 191 out of 390
# Number of trees: 60 , Maximum depth 26 :
# Accuracy: 0.8275046016302918
#   Fold n. 1
# elapsed time: 148.6s, done 192 out of 390
# Number of trees: 60 , Maximum depth 26 :
# Accuracy: 0.8275046016302918
#   Fold n. 2
# elapsed time: 149.81s, done 193 out of 390
# Number of trees: 60 , Maximum depth 26 :
# Accuracy: 0.8275046016302918
#   Fold n. 3
# elapsed time: 150.24s, done 194 out of 390
# Number of trees: 60 , Maximum depth 26 :
# Accuracy: 0.8275046016302918
#   Fold n. 4
# elapsed time: 151.37s, done 195 out of 390
# Number of trees: 60 , Maximum depth 26 :
# Accuracy: 0.8275046016302918
# Area under ROC curve: 0.8815877580076257 Selected area: 0.1064686569616079
#
#   Fold n. 0
# elapsed time: 152.37s, done 196 out of 390
# Number of trees: 60 , Maximum depth 28 :
# Accuracy: 0.8301341046542203
#   Fold n. 1
# elapsed time: 153.41s, done 197 out of 390
# Number of trees: 60 , Maximum depth 28 :
# Accuracy: 0.8301341046542203
#   Fold n. 2
# elapsed time: 154.46s, done 198 out of 390
# Number of trees: 60 , Maximum depth 28 :
# Accuracy: 0.8301341046542203
#   Fold n. 3
# elapsed time: 155.46s, done 199 out of 390
# Number of trees: 60 , Maximum depth 28 :
# Accuracy: 0.8301341046542203
#   Fold n. 4
# elapsed time: 156.53s, done 200 out of 390
# Number of trees: 60 , Maximum depth 28 :
# Accuracy: 0.8301341046542203
# Area under ROC curve: 0.8820183907252368 Selected area: 0.10784671141834405
#
#   Fold n. 0
# elapsed time: 157.57s, done 201 out of 390
# Number of trees: 60 , Maximum depth 30 :
# Accuracy: 0.8303970549566132
#   Fold n. 1
# elapsed time: 158.52s, done 202 out of 390
# Number of trees: 60 , Maximum depth 30 :
# Accuracy: 0.8303970549566132
#   Fold n. 2
# elapsed time: 159.59s, done 203 out of 390
# Number of trees: 60 , Maximum depth 30 :
# Accuracy: 0.8303970549566132
#   Fold n. 3
# elapsed time: 160.61s, done 204 out of 390
# Number of trees: 60 , Maximum depth 30 :
# Accuracy: 0.8303970549566132
#   Fold n. 4
# elapsed time: 161.69s, done 205 out of 390
# Number of trees: 60 , Maximum depth 30 :
# Accuracy: 0.8303970549566132
# Area under ROC curve: 0.8815554679939004 Selected area: 0.10804104670832325
#
#   Fold n. 0
# elapsed time: 162.74s, done 206 out of 390
# Number of trees: 60 , Maximum depth 32 :
# Accuracy: 0.829082303444649
#   Fold n. 1
# elapsed time: 163.72s, done 207 out of 390
# Number of trees: 60 , Maximum depth 32 :
# Accuracy: 0.829082303444649
#   Fold n. 2
# elapsed time: 164.78s, done 208 out of 390
# Number of trees: 60 , Maximum depth 32 :
# Accuracy: 0.829082303444649
#   Fold n. 3
# elapsed time: 165.79s, done 209 out of 390
# Number of trees: 60 , Maximum depth 32 :
# Accuracy: 0.829082303444649
#   Fold n. 4
# elapsed time: 166.74s, done 210 out of 390
# Number of trees: 60 , Maximum depth 32 :
# Accuracy: 0.829082303444649
# Area under ROC curve: 0.8820500855313359 Selected area: 0.10558149999464311
#
#   Fold n. 0
# elapsed time: 167.73s, done 211 out of 390
# Number of trees: 60 , Maximum depth 34 :
# Accuracy: 0.8288193531422561
#   Fold n. 1
# elapsed time: 168.71s, done 212 out of 390
# Number of trees: 60 , Maximum depth 34 :
# Accuracy: 0.8288193531422561
#   Fold n. 2
# elapsed time: 169.68s, done 213 out of 390
# Number of trees: 60 , Maximum depth 34 :
# Accuracy: 0.8288193531422561
#   Fold n. 3
# elapsed time: 170.65s, done 214 out of 390
# Number of trees: 60 , Maximum depth 34 :
# Accuracy: 0.8288193531422561
#   Fold n. 4
# elapsed time: 171.7s, done 215 out of 390
# Number of trees: 60 , Maximum depth 34 :
# Accuracy: 0.8288193531422561
# Area under ROC curve: 0.8817072459386007 Selected area: 0.10742991727804409
#
#   Fold n. 0
# elapsed time: 172.92s, done 216 out of 390
# Number of trees: 60 , Maximum depth 36 :
# Accuracy: 0.8293452537470418
#   Fold n. 1
# elapsed time: 174.06s, done 217 out of 390
# Number of trees: 60 , Maximum depth 36 :
# Accuracy: 0.8293452537470418
#   Fold n. 2
# elapsed time: 175.15s, done 218 out of 390
# Number of trees: 60 , Maximum depth 36 :
# Accuracy: 0.8293452537470418
#   Fold n. 3
# elapsed time: 176.31s, done 219 out of 390
# Number of trees: 60 , Maximum depth 36 :
# Accuracy: 0.8293452537470418
#   Fold n. 4
# elapsed time: 177.5s, done 220 out of 390
# Number of trees: 60 , Maximum depth 36 :
# Accuracy: 0.8293452537470418
# Area under ROC curve: 0.8821253792960599 Selected area: 0.10702428328073682
#
#   Fold n. 0
# elapsed time: 178.59s, done 221 out of 390
# Number of trees: 60 , Maximum depth 38 :
# Accuracy: 0.8293452537470418
#   Fold n. 1
# elapsed time: 179.68s, done 222 out of 390
# Number of trees: 60 , Maximum depth 38 :
# Accuracy: 0.8293452537470418
#   Fold n. 2
# elapsed time: 180.77s, done 223 out of 390
# Number of trees: 60 , Maximum depth 38 :
# Accuracy: 0.8293452537470418
#   Fold n. 3
# elapsed time: 181.0s, done 224 out of 390
# Number of trees: 60 , Maximum depth 38 :
# Accuracy: 0.8293452537470418
#   Fold n. 4
# elapsed time: 182.29s, done 225 out of 390
# Number of trees: 60 , Maximum depth 38 :
# Accuracy: 0.8293452537470418
# Area under ROC curve: 0.8821444259401008 Selected area: 0.09577069269073132
#
#   Fold n. 0
# elapsed time: 183.21s, done 226 out of 390
# Number of trees: 70 , Maximum depth 10 :
# Accuracy: 0.8154088877202209
#   Fold n. 1
# elapsed time: 184.1s, done 227 out of 390
# Number of trees: 70 , Maximum depth 10 :
# Accuracy: 0.8154088877202209
#   Fold n. 2
# elapsed time: 184.96s, done 228 out of 390
# Number of trees: 70 , Maximum depth 10 :
# Accuracy: 0.8154088877202209
#   Fold n. 3
# elapsed time: 185.83s, done 229 out of 390
# Number of trees: 70 , Maximum depth 10 :
# Accuracy: 0.8154088877202209
#   Fold n. 4
# elapsed time: 186.69s, done 230 out of 390
# Number of trees: 70 , Maximum depth 10 :
# Accuracy: 0.8154088877202209
# Area under ROC curve: 0.8652588319883625 Selected area: 0.09904031698377345
#
#   Fold n. 0
# elapsed time: 187.71s, done 231 out of 390
# Number of trees: 70 , Maximum depth 12 :
# Accuracy: 0.8183013410465422
#   Fold n. 1
# elapsed time: 188.75s, done 232 out of 390
# Number of trees: 70 , Maximum depth 12 :
# Accuracy: 0.8183013410465422
#   Fold n. 2
# elapsed time: 189.69s, done 233 out of 390
# Number of trees: 70 , Maximum depth 12 :
# Accuracy: 0.8183013410465422
#   Fold n. 3
# elapsed time: 190.62s, done 234 out of 390
# Number of trees: 70 , Maximum depth 12 :
# Accuracy: 0.8183013410465422
#   Fold n. 4
# elapsed time: 191.55s, done 235 out of 390
# Number of trees: 70 , Maximum depth 12 :
# Accuracy: 0.8183013410465422
# Area under ROC curve: 0.874497942367236 Selected area: 0.10507587111612143
#
#   Fold n. 0
# elapsed time: 192.6s, done 236 out of 390
# Number of trees: 70 , Maximum depth 14 :
# Accuracy: 0.8206678937680778
#   Fold n. 1
# elapsed time: 193.62s, done 237 out of 390
# Number of trees: 70 , Maximum depth 14 :
# Accuracy: 0.8206678937680778
#   Fold n. 2
# elapsed time: 194.65s, done 238 out of 390
# Number of trees: 70 , Maximum depth 14 :
# Accuracy: 0.8206678937680778
#   Fold n. 3
# elapsed time: 195.67s, done 239 out of 390
# Number of trees: 70 , Maximum depth 14 :
# Accuracy: 0.8206678937680778
#   Fold n. 4
# elapsed time: 196.73s, done 240 out of 390
# Number of trees: 70 , Maximum depth 14 :
# Accuracy: 0.8206678937680778
# Area under ROC curve: 0.8767829444445105 Selected area: 0.1057533661967304
#
#   Fold n. 0
# elapsed time: 197.89s, done 241 out of 390
# Number of trees: 70 , Maximum depth 16 :
# Accuracy: 0.8240862476991848
#   Fold n. 1
# elapsed time: 198.95s, done 242 out of 390
# Number of trees: 70 , Maximum depth 16 :
# Accuracy: 0.8240862476991848
#   Fold n. 2
# elapsed time: 200.05s, done 243 out of 390
# Number of trees: 70 , Maximum depth 16 :
# Accuracy: 0.8240862476991848
#   Fold n. 3
# elapsed time: 201.15s, done 244 out of 390
# Number of trees: 70 , Maximum depth 16 :
# Accuracy: 0.8240862476991848
#   Fold n. 4
# elapsed time: 202.24s, done 245 out of 390
# Number of trees: 70 , Maximum depth 16 :
# Accuracy: 0.8240862476991848
# Area under ROC curve: 0.8779882398877201 Selected area: 0.10631598620546805
#
#   Fold n. 0
# elapsed time: 203.41s, done 246 out of 390
# Number of trees: 70 , Maximum depth 18 :
# Accuracy: 0.8275046016302918
#   Fold n. 1
# elapsed time: 204.64s, done 247 out of 390
# Number of trees: 70 , Maximum depth 18 :
# Accuracy: 0.8275046016302918
#   Fold n. 2
# elapsed time: 205.85s, done 248 out of 390
# Number of trees: 70 , Maximum depth 18 :
# Accuracy: 0.8275046016302918
#   Fold n. 3
# elapsed time: 207.01s, done 249 out of 390
# Number of trees: 70 , Maximum depth 18 :
# Accuracy: 0.8275046016302918
#   Fold n. 4
# elapsed time: 208.22s, done 250 out of 390
# Number of trees: 70 , Maximum depth 18 :
# Accuracy: 0.8275046016302918
# Area under ROC curve: 0.8809309463920298 Selected area: 0.10835382831593143
#
#   Fold n. 0
# elapsed time: 209.47s, done 251 out of 390
# Number of trees: 70 , Maximum depth 20 :
# Accuracy: 0.8232973967920063
#   Fold n. 1
# elapsed time: 210.69s, done 252 out of 390
# Number of trees: 70 , Maximum depth 20 :
# Accuracy: 0.8232973967920063
#   Fold n. 2
# elapsed time: 211.94s, done 253 out of 390
# Number of trees: 70 , Maximum depth 20 :
# Accuracy: 0.8232973967920063
#   Fold n. 3
# elapsed time: 212.26s, done 254 out of 390
# Number of trees: 70 , Maximum depth 20 :
# Accuracy: 0.8232973967920063
#   Fold n. 4
# elapsed time: 213.37s, done 255 out of 390
# Number of trees: 70 , Maximum depth 20 :
# Accuracy: 0.8232973967920063
# Area under ROC curve: 0.8804553754986352 Selected area: 0.10797036580270293
#
#   Fold n. 0
# elapsed time: 214.5s, done 256 out of 390
# Number of trees: 70 , Maximum depth 22 :
# Accuracy: 0.8261898501183277
#   Fold n. 1
# elapsed time: 215.7s, done 257 out of 390
# Number of trees: 70 , Maximum depth 22 :
# Accuracy: 0.8261898501183277
#   Fold n. 2
# elapsed time: 217.07s, done 258 out of 390
# Number of trees: 70 , Maximum depth 22 :
# Accuracy: 0.8261898501183277
#   Fold n. 3
# elapsed time: 218.49s, done 259 out of 390
# Number of trees: 70 , Maximum depth 22 :
# Accuracy: 0.8261898501183277
#   Fold n. 4
# elapsed time: 219.82s, done 260 out of 390
# Number of trees: 70 , Maximum depth 22 :
# Accuracy: 0.8261898501183277
# Area under ROC curve: 0.8808607118921293 Selected area: 0.10815607058210114
#
#   Fold n. 0
# elapsed time: 221.08s, done 261 out of 390
# Number of trees: 70 , Maximum depth 24 :
# Accuracy: 0.829082303444649
#   Fold n. 1
# elapsed time: 222.3s, done 262 out of 390
# Number of trees: 70 , Maximum depth 24 :
# Accuracy: 0.829082303444649
#   Fold n. 2
# elapsed time: 223.57s, done 263 out of 390
# Number of trees: 70 , Maximum depth 24 :
# Accuracy: 0.829082303444649
#   Fold n. 3
# elapsed time: 224.86s, done 264 out of 390
# Number of trees: 70 , Maximum depth 24 :
# Accuracy: 0.829082303444649
#   Fold n. 4
# elapsed time: 226.15s, done 265 out of 390
# Number of trees: 70 , Maximum depth 24 :
# Accuracy: 0.829082303444649
# Area under ROC curve: 0.8807089339474289 Selected area: 0.10760550352779558
#
#   Fold n. 0
# elapsed time: 227.45s, done 266 out of 390
# Number of trees: 70 , Maximum depth 26 :
# Accuracy: 0.8280305022350776
#   Fold n. 1
# elapsed time: 228.72s, done 267 out of 390
# Number of trees: 70 , Maximum depth 26 :
# Accuracy: 0.8280305022350776
#   Fold n. 2
# elapsed time: 230.03s, done 268 out of 390
# Number of trees: 70 , Maximum depth 26 :
# Accuracy: 0.8280305022350776
#   Fold n. 3
# elapsed time: 231.34s, done 269 out of 390
# Number of trees: 70 , Maximum depth 26 :
# Accuracy: 0.8280305022350776
#   Fold n. 4
# elapsed time: 232.61s, done 270 out of 390
# Number of trees: 70 , Maximum depth 26 :
# Accuracy: 0.8280305022350776
# Area under ROC curve: 0.8807434559897529 Selected area: 0.10701342074155726
#
#   Fold n. 0
# elapsed time: 233.84s, done 271 out of 390
# Number of trees: 70 , Maximum depth 28 :
# Accuracy: 0.8275046016302918
#   Fold n. 1
# elapsed time: 235.0s, done 272 out of 390
# Number of trees: 70 , Maximum depth 28 :
# Accuracy: 0.8275046016302918
#   Fold n. 2
# elapsed time: 236.32s, done 273 out of 390
# Number of trees: 70 , Maximum depth 28 :
# Accuracy: 0.8275046016302918
#   Fold n. 3
# elapsed time: 237.7s, done 274 out of 390
# Number of trees: 70 , Maximum depth 28 :
# Accuracy: 0.8275046016302918
#   Fold n. 4
# elapsed time: 239.0s, done 275 out of 390
# Number of trees: 70 , Maximum depth 28 :
# Accuracy: 0.8275046016302918
# Area under ROC curve: 0.8815748122417544 Selected area: 0.10763035344619264
#
#   Fold n. 0
# elapsed time: 240.31s, done 276 out of 390
# Number of trees: 70 , Maximum depth 30 :
# Accuracy: 0.8275046016302918
#   Fold n. 1
# elapsed time: 241.61s, done 277 out of 390
# Number of trees: 70 , Maximum depth 30 :
# Accuracy: 0.8275046016302918
#   Fold n. 2
# elapsed time: 242.9s, done 278 out of 390
# Number of trees: 70 , Maximum depth 30 :
# Accuracy: 0.8275046016302918
#   Fold n. 3
# elapsed time: 243.26s, done 279 out of 390
# Number of trees: 70 , Maximum depth 30 :
# Accuracy: 0.8275046016302918
#   Fold n. 4
# elapsed time: 244.45s, done 280 out of 390
# Number of trees: 70 , Maximum depth 30 :
# Accuracy: 0.8275046016302918
# Area under ROC curve: 0.8803153529045538 Selected area: 0.10718439413220512
#
#   Fold n. 0
# elapsed time: 245.65s, done 281 out of 390
# Number of trees: 70 , Maximum depth 32 :
# Accuracy: 0.8264528004207204
#   Fold n. 1
# elapsed time: 246.81s, done 282 out of 390
# Number of trees: 70 , Maximum depth 32 :
# Accuracy: 0.8264528004207204
#   Fold n. 2
# elapsed time: 247.92s, done 283 out of 390
# Number of trees: 70 , Maximum depth 32 :
# Accuracy: 0.8264528004207204
#   Fold n. 3
# elapsed time: 249.09s, done 284 out of 390
# Number of trees: 70 , Maximum depth 32 :
# Accuracy: 0.8264528004207204
#   Fold n. 4
# elapsed time: 250.2s, done 285 out of 390
# Number of trees: 70 , Maximum depth 32 :
# Accuracy: 0.8264528004207204
# Area under ROC curve: 0.8811264720972616 Selected area: 0.10739807367003831
#
#   Fold n. 0
# elapsed time: 251.3s, done 286 out of 390
# Number of trees: 70 , Maximum depth 34 :
# Accuracy: 0.8296082040494347
#   Fold n. 1
# elapsed time: 252.5s, done 287 out of 390
# Number of trees: 70 , Maximum depth 34 :
# Accuracy: 0.8296082040494347
#   Fold n. 2
# elapsed time: 253.7s, done 288 out of 390
# Number of trees: 70 , Maximum depth 34 :
# Accuracy: 0.8296082040494347
#   Fold n. 3
# elapsed time: 255.0s, done 289 out of 390
# Number of trees: 70 , Maximum depth 34 :
# Accuracy: 0.8296082040494347
#   Fold n. 4
# elapsed time: 256.37s, done 290 out of 390
# Number of trees: 70 , Maximum depth 34 :
# Accuracy: 0.8296082040494347
# Area under ROC curve: 0.881111145500885 Selected area: 0.1076305022480992
#
#   Fold n. 0
# elapsed time: 257.83s, done 291 out of 390
# Number of trees: 70 , Maximum depth 36 :
# Accuracy: 0.8293452537470418
#   Fold n. 1
# elapsed time: 259.34s, done 292 out of 390
# Number of trees: 70 , Maximum depth 36 :
# Accuracy: 0.8293452537470418
#   Fold n. 2
# elapsed time: 260.85s, done 293 out of 390
# Number of trees: 70 , Maximum depth 36 :
# Accuracy: 0.8293452537470418
#   Fold n. 3
# elapsed time: 262.2s, done 294 out of 390
# Number of trees: 70 , Maximum depth 36 :
# Accuracy: 0.8293452537470418
#   Fold n. 4
# elapsed time: 263.46s, done 295 out of 390
# Number of trees: 70 , Maximum depth 36 :
# Accuracy: 0.8293452537470418
# Area under ROC curve: 0.8811476019679945 Selected area: 0.1027533709583914
#
#   Fold n. 0
# elapsed time: 264.76s, done 296 out of 390
# Number of trees: 70 , Maximum depth 38 :
# Accuracy: 0.8280305022350776
#   Fold n. 1
# elapsed time: 266.0s, done 297 out of 390
# Number of trees: 70 , Maximum depth 38 :
# Accuracy: 0.8280305022350776
#   Fold n. 2
# elapsed time: 267.28s, done 298 out of 390
# Number of trees: 70 , Maximum depth 38 :
# Accuracy: 0.8280305022350776
#   Fold n. 3
# elapsed time: 268.46s, done 299 out of 390
# Number of trees: 70 , Maximum depth 38 :
# Accuracy: 0.8280305022350776
#   Fold n. 4
# elapsed time: 269.77s, done 300 out of 390
# Number of trees: 70 , Maximum depth 38 :
# Accuracy: 0.8280305022350776
# Area under ROC curve: 0.8812095035611271 Selected area: 0.10472216898420678
#
#   Fold n. 0
# elapsed time: 270.66s, done 301 out of 390
# Number of trees: 80 , Maximum depth 10 :
# Accuracy: 0.8143570865106495
#   Fold n. 1
# elapsed time: 271.55s, done 302 out of 390
# Number of trees: 80 , Maximum depth 10 :
# Accuracy: 0.8143570865106495
#   Fold n. 2
# elapsed time: 272.53s, done 303 out of 390
# Number of trees: 80 , Maximum depth 10 :
# Accuracy: 0.8143570865106495
#   Fold n. 3
# elapsed time: 273.41s, done 304 out of 390
# Number of trees: 80 , Maximum depth 10 :
# Accuracy: 0.8143570865106495
#   Fold n. 4
# elapsed time: 274.33s, done 305 out of 390
# Number of trees: 80 , Maximum depth 10 :
# Accuracy: 0.8143570865106495
# Area under ROC curve: 0.8652964788707245 Selected area: 0.09913450859063165
#
#   Fold n. 0
# elapsed time: 274.38s, done 306 out of 390
# Number of trees: 80 , Maximum depth 12 :
# Accuracy: 0.8175124901393637
#   Fold n. 1
# elapsed time: 275.43s, done 307 out of 390
# Number of trees: 80 , Maximum depth 12 :
# Accuracy: 0.8175124901393637
#   Fold n. 2
# elapsed time: 276.33s, done 308 out of 390
# Number of trees: 80 , Maximum depth 12 :
# Accuracy: 0.8175124901393637
#   Fold n. 3
# elapsed time: 277.25s, done 309 out of 390
# Number of trees: 80 , Maximum depth 12 :
# Accuracy: 0.8175124901393637
#   Fold n. 4
# elapsed time: 278.12s, done 310 out of 390
# Number of trees: 80 , Maximum depth 12 :
# Accuracy: 0.8175124901393637
# Area under ROC curve: 0.8745506182421615 Selected area: 0.10516872350582053
#
#   Fold n. 0
# elapsed time: 279.08s, done 311 out of 390
# Number of trees: 80 , Maximum depth 14 :
# Accuracy: 0.818564291348935
#   Fold n. 1
# elapsed time: 280.05s, done 312 out of 390
# Number of trees: 80 , Maximum depth 14 :
# Accuracy: 0.818564291348935
#   Fold n. 2
# elapsed time: 281.05s, done 313 out of 390
# Number of trees: 80 , Maximum depth 14 :
# Accuracy: 0.818564291348935
#   Fold n. 3
# elapsed time: 282.16s, done 314 out of 390
# Number of trees: 80 , Maximum depth 14 :
# Accuracy: 0.818564291348935
#   Fold n. 4
# elapsed time: 283.27s, done 315 out of 390
# Number of trees: 80 , Maximum depth 14 :
# Accuracy: 0.818564291348935
# Area under ROC curve: 0.8765380165062978 Selected area: 0.10568819096165313
#
#   Fold n. 0
# elapsed time: 284.73s, done 316 out of 390
# Number of trees: 80 , Maximum depth 16 :
# Accuracy: 0.8232973967920063
#   Fold n. 1
# elapsed time: 286.13s, done 317 out of 390
# Number of trees: 80 , Maximum depth 16 :
# Accuracy: 0.8232973967920063
#   Fold n. 2
# elapsed time: 287.58s, done 318 out of 390
# Number of trees: 80 , Maximum depth 16 :
# Accuracy: 0.8232973967920063
#   Fold n. 3
# elapsed time: 288.87s, done 319 out of 390
# Number of trees: 80 , Maximum depth 16 :
# Accuracy: 0.8232973967920063
#   Fold n. 4
# elapsed time: 290.12s, done 320 out of 390
# Number of trees: 80 , Maximum depth 16 :
# Accuracy: 0.8232973967920063
# Area under ROC curve: 0.8776759046858315 Selected area: 0.10562614056661385
#
#   Fold n. 0
# elapsed time: 291.39s, done 321 out of 390
# Number of trees: 80 , Maximum depth 18 :
# Accuracy: 0.8254009992111491
#   Fold n. 1
# elapsed time: 292.63s, done 322 out of 390
# Number of trees: 80 , Maximum depth 18 :
# Accuracy: 0.8254009992111491
#   Fold n. 2
# elapsed time: 293.81s, done 323 out of 390
# Number of trees: 80 , Maximum depth 18 :
# Accuracy: 0.8254009992111491
#   Fold n. 3
# elapsed time: 295.1s, done 324 out of 390
# Number of trees: 80 , Maximum depth 18 :
# Accuracy: 0.8254009992111491
#   Fold n. 4
# elapsed time: 296.3s, done 325 out of 390
# Number of trees: 80 , Maximum depth 18 :
# Accuracy: 0.8254009992111491
# Area under ROC curve: 0.8801839608210531 Selected area: 0.10811291802919612
#
#   Fold n. 0
# elapsed time: 297.53s, done 326 out of 390
# Number of trees: 80 , Maximum depth 20 :
# Accuracy: 0.8254009992111491
#   Fold n. 1
# elapsed time: 298.72s, done 327 out of 390
# Number of trees: 80 , Maximum depth 20 :
# Accuracy: 0.8254009992111491
#   Fold n. 2
# elapsed time: 299.97s, done 328 out of 390
# Number of trees: 80 , Maximum depth 20 :
# Accuracy: 0.8254009992111491
#   Fold n. 3
# elapsed time: 301.11s, done 329 out of 390
# Number of trees: 80 , Maximum depth 20 :
# Accuracy: 0.8254009992111491
#   Fold n. 4
# elapsed time: 302.49s, done 330 out of 390
# Number of trees: 80 , Maximum depth 20 :
# Accuracy: 0.8254009992111491
# Area under ROC curve: 0.8800859003646242 Selected area: 0.10773600279985668
#
#   Fold n. 0
# elapsed time: 304.18s, done 331 out of 390
# Number of trees: 80 , Maximum depth 22 :
# Accuracy: 0.8259268998159348
#   Fold n. 1
# elapsed time: 305.88s, done 332 out of 390
# Number of trees: 80 , Maximum depth 22 :
# Accuracy: 0.8259268998159348
#   Fold n. 2
# elapsed time: 306.48s, done 333 out of 390
# Number of trees: 80 , Maximum depth 22 :
# Accuracy: 0.8259268998159348
#   Fold n. 3
# elapsed time: 307.95s, done 334 out of 390
# Number of trees: 80 , Maximum depth 22 :
# Accuracy: 0.8259268998159348
#   Fold n. 4
# elapsed time: 309.23s, done 335 out of 390
# Number of trees: 80 , Maximum depth 22 :
# Accuracy: 0.8259268998159348
# Area under ROC curve: 0.8800933404599528 Selected area: 0.10711564765137022
#
#   Fold n. 0
# elapsed time: 310.61s, done 336 out of 390
# Number of trees: 80 , Maximum depth 24 :
# Accuracy: 0.8280305022350776
#   Fold n. 1
# elapsed time: 311.83s, done 337 out of 390
# Number of trees: 80 , Maximum depth 24 :
# Accuracy: 0.8280305022350776
#   Fold n. 2
# elapsed time: 313.16s, done 338 out of 390
# Number of trees: 80 , Maximum depth 24 :
# Accuracy: 0.8280305022350776
#   Fold n. 3
# elapsed time: 314.47s, done 339 out of 390
# Number of trees: 80 , Maximum depth 24 :
# Accuracy: 0.8280305022350776
#   Fold n. 4
# elapsed time: 315.72s, done 340 out of 390
# Number of trees: 80 , Maximum depth 24 :
# Accuracy: 0.8280305022350776
# Area under ROC curve: 0.880309698432104 Selected area: 0.10700255820237772
#
#   Fold n. 0
# elapsed time: 317.05s, done 341 out of 390
# Number of trees: 80 , Maximum depth 26 :
# Accuracy: 0.8285564028398633
#   Fold n. 1
# elapsed time: 318.35s, done 342 out of 390
# Number of trees: 80 , Maximum depth 26 :
# Accuracy: 0.8285564028398633
#   Fold n. 2
# elapsed time: 319.6s, done 343 out of 390
# Number of trees: 80 , Maximum depth 26 :
# Accuracy: 0.8285564028398633
#   Fold n. 3
# elapsed time: 320.9s, done 344 out of 390
# Number of trees: 80 , Maximum depth 26 :
# Accuracy: 0.8285564028398633
#   Fold n. 4
# ...
# Accuracy: 0.8288193531422561
#   Fold n. 1
# elapsed time: 865.53s, done 667 out of 390
# Number of trees: 120 , Maximum depth 36 :
# Accuracy: 0.8288193531422561
#   Fold n. 2
# elapsed time: 867.47s, done 668 out of 390
# Number of trees: 120 , Maximum depth 36 :
# Accuracy: 0.8288193531422561
#   Fold n. 3
# elapsed time: 869.4s, done 669 out of 390
# Number of trees: 120 , Maximum depth 36 :
# Accuracy: 0.8288193531422561
#   Fold n. 4
# elapsed time: 871.32s, done 670 out of 390
# Number of trees: 120 , Maximum depth 36 :
# Accuracy: 0.8288193531422561
# Area under ROC curve: 0.882564940128065 Selected area: 0.10858953053593684
#
#   Fold n. 0
# elapsed time: 873.23s, done 671 out of 390
# Number of trees: 120 , Maximum depth 38 :
# Accuracy: 0.8275046016302918
#   Fold n. 1
# elapsed time: 875.18s, done 672 out of 390
# Number of trees: 120 , Maximum depth 38 :
# Accuracy: 0.8275046016302918
#   Fold n. 2
# elapsed time: 877.18s, done 673 out of 390
# Number of trees: 120 , Maximum depth 38 :
# Accuracy: 0.8275046016302918
#   Fold n. 3
# elapsed time: 879.2s, done 674 out of 390
# Number of trees: 120 , Maximum depth 38 :
# Accuracy: 0.8275046016302918
#   Fold n. 4
# elapsed time: 881.16s, done 675 out of 390
# Number of trees: 120 , Maximum depth 38 :
# Accuracy: 0.8275046016302918
# Area under ROC curve: 0.882081482733622 Selected area: 0.10722724908129701
#
#   Fold n. 0
# elapsed time: 882.39s, done 676 out of 390
# Number of trees: 130 , Maximum depth 10 :
# Accuracy: 0.8143570865106495
#   Fold n. 1
# elapsed time: 883.65s, done 677 out of 390
# Number of trees: 130 , Maximum depth 10 :
# Accuracy: 0.8143570865106495
#   Fold n. 2
# elapsed time: 884.93s, done 678 out of 390
# Number of trees: 130 , Maximum depth 10 :
# Accuracy: 0.8143570865106495
#   Fold n. 3
# elapsed time: 885.21s, done 679 out of 390
# Number of trees: 130 , Maximum depth 10 :
# Accuracy: 0.8143570865106495
#   Fold n. 4
# elapsed time: 886.54s, done 680 out of 390
# Number of trees: 130 , Maximum depth 10 :
# Accuracy: 0.8143570865106495
# Area under ROC curve: 0.8653301081016089 Selected area: 0.09897201690865824
#
#   Fold n. 0
# elapsed time: 887.93s, done 681 out of 390
# Number of trees: 130 , Maximum depth 12 :
# Accuracy: 0.8177754404417565
#   Fold n. 1
# elapsed time: 889.33s, done 682 out of 390
# Number of trees: 130 , Maximum depth 12 :
# Accuracy: 0.8177754404417565
#   Fold n. 2
# elapsed time: 890.99s, done 683 out of 390
# Number of trees: 130 , Maximum depth 12 :
# Accuracy: 0.8177754404417565
#   Fold n. 3
# elapsed time: 892.72s, done 684 out of 390
# Number of trees: 130 , Maximum depth 12 :
# Accuracy: 0.8177754404417565
#   Fold n. 4
# elapsed time: 894.41s, done 685 out of 390
# Number of trees: 130 , Maximum depth 12 :
# Accuracy: 0.8177754404417565
# Area under ROC curve: 0.8747778387534924 Selected area: 0.10524669570486272
#
#   Fold n. 0
# elapsed time: 896.41s, done 686 out of 390
# Number of trees: 130 , Maximum depth 14 :
# Accuracy: 0.8204049434656849
#   Fold n. 1
# elapsed time: 898.25s, done 687 out of 390
# Number of trees: 130 , Maximum depth 14 :
# Accuracy: 0.8204049434656849
#   Fold n. 2
# elapsed time: 900.1s, done 688 out of 390
# Number of trees: 130 , Maximum depth 14 :
# Accuracy: 0.8204049434656849
#   Fold n. 3
# elapsed time: 901.92s, done 689 out of 390
# Number of trees: 130 , Maximum depth 14 :
# Accuracy: 0.8204049434656849
#   Fold n. 4
# elapsed time: 903.7s, done 690 out of 390
# Number of trees: 130 , Maximum depth 14 :
# Accuracy: 0.8204049434656849
# Area under ROC curve: 0.877820093733297 Selected area: 0.10646300248915828
#
#   Fold n. 0
# elapsed time: 905.73s, done 691 out of 390
# Number of trees: 130 , Maximum depth 16 :
# Accuracy: 0.8243491980015777
#   Fold n. 1
# elapsed time: 907.75s, done 692 out of 390
# Number of trees: 130 , Maximum depth 16 :
# Accuracy: 0.8243491980015777
#   Fold n. 2
# elapsed time: 909.68s, done 693 out of 390
# Number of trees: 130 , Maximum depth 16 :
# Accuracy: 0.8243491980015777
#   Fold n. 3
# elapsed time: 911.7s, done 694 out of 390
# Number of trees: 130 , Maximum depth 16 :
# Accuracy: 0.8243491980015777
#   Fold n. 4
# elapsed time: 913.72s, done 695 out of 390
# Number of trees: 130 , Maximum depth 16 :
# Accuracy: 0.8243491980015777
# Area under ROC curve: 0.8794569147055566 Selected area: 0.10752782893256652
#
#   Fold n. 0
# elapsed time: 915.84s, done 696 out of 390
# Number of trees: 130 , Maximum depth 18 :
# Accuracy: 0.8256639495135419
#   Fold n. 1
# elapsed time: 916.84s, done 697 out of 390
# Number of trees: 130 , Maximum depth 18 :
# Accuracy: 0.8256639495135419
#   Fold n. 2
# elapsed time: 918.71s, done 698 out of 390
# Number of trees: 130 , Maximum depth 18 :
# Accuracy: 0.8256639495135419
#   Fold n. 3
# elapsed time: 920.66s, done 699 out of 390
# Number of trees: 130 , Maximum depth 18 :
# Accuracy: 0.8256639495135419
#   Fold n. 4
# elapsed time: 922.59s, done 700 out of 390
# Number of trees: 130 , Maximum depth 18 :
# Accuracy: 0.8256639495135419
# Area under ROC curve: 0.8809178518242519 Selected area: 0.10850426704347275
#
#   Fold n. 0
# elapsed time: 924.61s, done 701 out of 390
# Number of trees: 130 , Maximum depth 20 :
# Accuracy: 0.8230344464896134
#   Fold n. 1
# elapsed time: 926.49s, done 702 out of 390
# Number of trees: 130 , Maximum depth 20 :
# Accuracy: 0.8230344464896134
#   Fold n. 2
# elapsed time: 928.42s, done 703 out of 390
# Number of trees: 130 , Maximum depth 20 :
# Accuracy: 0.8230344464896134
#   Fold n. 3
# elapsed time: 930.35s, done 704 out of 390
# Number of trees: 130 , Maximum depth 20 :
# Accuracy: 0.8230344464896134
#   Fold n. 4
# elapsed time: 932.5s, done 705 out of 390
# Number of trees: 130 , Maximum depth 20 :
# Accuracy: 0.8230344464896134
# Area under ROC curve: 0.8816477251759732 Selected area: 0.10890424656833042
#
#   Fold n. 0
# elapsed time: 934.7s, done 706 out of 390
# Number of trees: 130 , Maximum depth 22 :
# Accuracy: 0.8282934525374704
#   Fold n. 1
# elapsed time: 936.62s, done 707 out of 390
# Number of trees: 130 , Maximum depth 22 :
# Accuracy: 0.8282934525374704
#   Fold n. 2
# elapsed time: 938.67s, done 708 out of 390
# Number of trees: 130 , Maximum depth 22 :
# Accuracy: 0.8282934525374704
#   Fold n. 3
# elapsed time: 940.87s, done 709 out of 390
# Number of trees: 130 , Maximum depth 22 :
# Accuracy: 0.8282934525374704
#   Fold n. 4
# elapsed time: 942.86s, done 710 out of 390
# Number of trees: 130 , Maximum depth 22 :
# Accuracy: 0.8282934525374704
# Area under ROC curve: 0.8820974045376249 Selected area: 0.10898579001313027
#
#   Fold n. 0
# elapsed time: 945.03s, done 711 out of 390
# Number of trees: 130 , Maximum depth 24 :
# Accuracy: 0.8269787010255062
#   Fold n. 1
# elapsed time: 947.2s, done 712 out of 390
# Number of trees: 130 , Maximum depth 24 :
# Accuracy: 0.8269787010255062
#   Fold n. 2
# elapsed time: 948.18s, done 713 out of 390
# Number of trees: 130 , Maximum depth 24 :
# Accuracy: 0.8269787010255062
#   Fold n. 3
# elapsed time: 950.3s, done 714 out of 390
# Number of trees: 130 , Maximum depth 24 :
# Accuracy: 0.8269787010255062
#   Fold n. 4
# elapsed time: 952.66s, done 715 out of 390
# Number of trees: 130 , Maximum depth 24 :
# Accuracy: 0.8269787010255062
# Area under ROC curve: 0.8826372578546574 Selected area: 0.10941850595743312
#
#   Fold n. 0
# elapsed time: 955.04s, done 716 out of 390
# Number of trees: 130 , Maximum depth 26 :
# Accuracy: 0.8254009992111491
#   Fold n. 1
# elapsed time: 957.07s, done 717 out of 390
# Number of trees: 130 , Maximum depth 26 :
# Accuracy: 0.8254009992111491
#   Fold n. 2
# elapsed time: 959.27s, done 718 out of 390
# Number of trees: 130 , Maximum depth 26 :
# Accuracy: 0.8254009992111491
#   Fold n. 3
# elapsed time: 961.43s, done 719 out of 390
# Number of trees: 130 , Maximum depth 26 :
# Accuracy: 0.8254009992111491
#   Fold n. 4
# elapsed time: 963.96s, done 720 out of 390
# Number of trees: 130 , Maximum depth 26 :
# Accuracy: 0.8254009992111491
# Area under ROC curve: 0.8829076309188933 Selected area: 0.1095869497156693
#
#   Fold n. 0
# elapsed time: 966.43s, done 721 out of 390
# Number of trees: 130 , Maximum depth 28 :
# Accuracy: 0.8277675519326847
#   Fold n. 1
# elapsed time: 969.18s, done 722 out of 390
# Number of trees: 130 , Maximum depth 28 :
# Accuracy: 0.8277675519326847
#   Fold n. 2
# elapsed time: 971.98s, done 723 out of 390
# Number of trees: 130 , Maximum depth 28 :
# Accuracy: 0.8277675519326847
#   Fold n. 3
# elapsed time: 974.55s, done 724 out of 390
# Number of trees: 130 , Maximum depth 28 :
# Accuracy: 0.8277675519326847
#   Fold n. 4
# elapsed time: 977.12s, done 725 out of 390
# Number of trees: 130 , Maximum depth 28 :
# Accuracy: 0.8277675519326847
# Area under ROC curve: 0.8835134034805361 Selected area: 0.10783272403912655
#
#   Fold n. 0
# elapsed time: 979.01s, done 726 out of 390
# Number of trees: 130 , Maximum depth 30 :
# Accuracy: 0.8282934525374704
#   Fold n. 1
# elapsed time: 981.67s, done 727 out of 390
# Number of trees: 130 , Maximum depth 30 :
# Accuracy: 0.8282934525374704
#   Fold n. 2
# elapsed time: 984.37s, done 728 out of 390
# Number of trees: 130 , Maximum depth 30 :
# Accuracy: 0.8282934525374704
#   Fold n. 3
# elapsed time: 987.22s, done 729 out of 390
# Number of trees: 130 , Maximum depth 30 :
# Accuracy: 0.8282934525374704
#   Fold n. 4
# elapsed time: 989.93s, done 730 out of 390
# Number of trees: 130 , Maximum depth 30 :
# Accuracy: 0.8282934525374704
# Area under ROC curve: 0.8826708870855422 Selected area: 0.10884055935231884
#
#   Fold n. 0
# elapsed time: 992.51s, done 731 out of 390
# Number of trees: 130 , Maximum depth 32 :
# Accuracy: 0.8280305022350776
#   Fold n. 1
# elapsed time: 995.08s, done 732 out of 390
# Number of trees: 130 , Maximum depth 32 :
# Accuracy: 0.8280305022350776
#   Fold n. 2
# elapsed time: 997.34s, done 733 out of 390
# Number of trees: 130 , Maximum depth 32 :
# Accuracy: 0.8280305022350776
#   Fold n. 3
# elapsed time: 999.59s, done 734 out of 390
# Number of trees: 130 , Maximum depth 32 :
# Accuracy: 0.8280305022350776
#   Fold n. 4
# elapsed time: 1001.96s, done 735 out of 390
# Number of trees: 130 , Maximum depth 32 :
# Accuracy: 0.8280305022350776
# Area under ROC curve: 0.8836058094645156 Selected area: 0.10878862748692626
#
#   Fold n. 0
# elapsed time: 1004.53s, done 736 out of 390
# Number of trees: 130 , Maximum depth 34 :
# Accuracy: 0.8296082040494347
#   Fold n. 1
# elapsed time: 1007.07s, done 737 out of 390
# Number of trees: 130 , Maximum depth 34 :
# Accuracy: 0.8296082040494347
#   Fold n. 2
# elapsed time: 1009.56s, done 738 out of 390
# Number of trees: 130 , Maximum depth 34 :
# Accuracy: 0.8296082040494347
#   Fold n. 3
# elapsed time: 1011.1s, done 739 out of 390
# Number of trees: 130 , Maximum depth 34 :
# Accuracy: 0.8296082040494347
#   Fold n. 4
# elapsed time: 1013.57s, done 740 out of 390
# Number of trees: 130 , Maximum depth 34 :
# Accuracy: 0.8296082040494347
# Area under ROC curve: 0.8832733860052402 Selected area: 0.10748675960635348
#
#   Fold n. 0
# elapsed time: 1016.11s, done 741 out of 390
# Number of trees: 130 , Maximum depth 36 :
# Accuracy: 0.8303970549566132
#   Fold n. 1
# elapsed time: 1018.48s, done 742 out of 390
# Number of trees: 130 , Maximum depth 36 :
# Accuracy: 0.8303970549566132
#   Fold n. 2
# elapsed time: 1020.85s, done 743 out of 390
# Number of trees: 130 , Maximum depth 36 :
# Accuracy: 0.8303970549566132
#   Fold n. 3
# elapsed time: 1023.34s, done 744 out of 390
# Number of trees: 130 , Maximum depth 36 :
# Accuracy: 0.8303970549566132
#   Fold n. 4
# elapsed time: 1025.88s, done 745 out of 390
# Number of trees: 130 , Maximum depth 36 :
# Accuracy: 0.8303970549566132
# Area under ROC curve: 0.8832832069310737 Selected area: 0.10606912384246997
#
#   Fold n. 0
# elapsed time: 1028.42s, done 746 out of 390
# Number of trees: 130 , Maximum depth 38 :
# Accuracy: 0.8280305022350776
#   Fold n. 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 38
#      30 forest = RandomForestClassifier(n_estimators=tree,  # number of trees
#      31                                max_depth= depth,
#      32                                max_features=X_train.shape[1],   # number of features for each split (random subset)
#    (...)
#      35                                random_state=10,
#      36                                n_jobs=-1)
#      37 # train each model, predict labels and probability of each label
# ---> 38 forest.fit(X_train, Y_train)
#      39 Y_pred = forest.predict(X_test)
#      40 y_pred_prob = forest.predict_proba(X_test)[:, 1] # probability for the validation points to belong to class +1 or -1
#
# File ~/miniconda3/envs/myenv/lib/python3.9/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:489, in BaseForest.fit(self, X, y, sample_weight)
#     478 trees = [
#     479     self._make_estimator(append=False, random_state=random_state)
#     480     for i in range(n_more_estimators)
#     481 ]
#     483 # Parallel loop: we prefer the threading backend as the Cython code
#     484 # for fitting the trees is internally releasing the Python GIL
#     485 # making threading more efficient than multiprocessing in
#     486 # that case. However, for joblib 0.12+ we respect any
#     487 # parallel_backend contexts set at a higher level,
#     488 # since correctness does not rely on using threads.
# --> 489 trees = Parallel(
#     490     n_jobs=self.n_jobs,
#     491     verbose=self.verbose,
#     492     prefer="threads",
#     493 )(
#     494     delayed(_parallel_build_trees)(
#     495         t,
#     496         self.bootstrap,
#     497         X,
#     498         y,
#     499         sample_weight,
#     500         i,
#     501         len(trees),
#     502         verbose=self.verbose,
#     503         class_weight=self.class_weight,
#     504         n_samples_bootstrap=n_samples_bootstrap,
#     505         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     506     )
#     507     for i, t in enumerate(trees)
#     508 )
#     510 # Collect newly grown trees
#     511 self.estimators_.extend(trees)
#
# File ~/miniconda3/envs/myenv/lib/python3.9/site-packages/sklearn/utils/parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File ~/miniconda3/envs/myenv/lib/python3.9/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File ~/miniconda3/envs/myenv/lib/python3.9/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File ~/miniconda3/envs/myenv/lib/python3.9/site-packages/joblib/parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
print("Best partial AUC", best_area)
print("Best total AUC", best_total_auc)

# %% [markdown]
# Now we train again the best Random Forest found on the whole training set. We calculate its accuracy and $Q$ factor on the test set, and find the relative ROC curve of the classifier.

# %%
X_train_np = np.array(X_train)
Y_train_np = np.array(Y_train)
X_test_np = np.array(X_test)
Y_test_np = np.array(Y_test)

best_forest = RandomForestClassifier(n_estimators=best_model[0], max_depth= best_model[1], max_features=X_train_np.shape[1],bootstrap=True,max_samples=1.0,random_state=10,n_jobs=-1)

best_forest.fit(X_train_np,Y_train_np)
Y_pred = best_forest.predict(X_test_np)
accuracy = accuracy_score(Y_test_np, Y_pred)
print('Accuracy of best Random Forest:',accuracy)

y_pred_prob = best_forest.predict_proba(X_test_np)[:, 1]
fpr, tpr, thresholds = roc_curve(Y_test_np, y_pred_prob)
roc_auc = auc(fpr, tpr)
partial_fpr = fpr[fpr <= 0.2]
partial_tpr = tpr[:len(partial_fpr)]
partial_auc = auc(partial_fpr, partial_tpr)
roc_auc_best = auc(fpr, tpr)
print('Partial AUC of the best Random Forest:',partial_auc)
print('AUC of the best Random Forest',roc_auc)

# %%
Q_rforest = get_best_Q(fpr,tpr)
fpr_rforest = fpr
tpr_rforest = tpr

print('best random forest Q:',Q_rforest)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=1.5, label=f'ROC curve (AUC = {roc_auc_best:.3f})')
plt.plot([0, 1], [0, 1], color='red', linestyle='--') 
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.02])
plt.xlabel('False Positive Rate',fontsize=13.8)
plt.ylabel('True Positive Rate',fontsize=13.8)
plt.title('Random Forest ROC Curve',fontsize=14.3)
plt.grid(alpha=0.4)
plt.legend(loc='best')
plt.show()
